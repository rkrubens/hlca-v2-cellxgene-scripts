# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import anndata2ri
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"

# %%
DATASET_ID = "Morrisey_publ"
DATA_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
# Name constants
AUTHOR_CELL_TYPE_L0 = 'author_cell_type_level_0'
AUTHOR_CELL_TYPE_L1 = 'author_cell_type_level_1'
AUTHOR_CELL_TYPE_L2 = 'author_cell_type_level_2'

CELL_TYPE_ONTOLOGY_ID_L0 = 'cell_type_ontology_term_id_level_0'
CELL_TYPE_ONTOLOGY_ID_L1 = 'cell_type_ontology_term_id_level_1'

CELL_TYPE_ONTOLOGY_LABEL_L0 = 'cell_type_ontology_term_label_level_0'
CELL_TYPE_ONTOLOGY_LABEL_L1 = 'cell_type_ontology_term_label_level_1'

AUTHOR_CELL_TYPE_DESCRIPTION_L0 = 'author_cell_type_description_level_0'
AUTHOR_CELL_TYPE_DESCRIPTION_L1 = 'author_cell_type_description_level_1'

MARKER_GENES_L0 = 'author_cell_type_markers_level_0'
MARKER_GENES_L1 = 'author_cell_type_markers_level_1'

# Finest grained annotation will be generic dataset cell type
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'
CELL_TYPE_ONTOLOGY_LABEL = 'cell_type_ontology_term_label'
MARKER_GENES = 'author_cell_type_markers'
AUTHOR_CELL_TYPE_DESCRIPTION = 'author_cell_type_description'

# %% [markdown]
# # Load data

# %%
obs = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "obs")
uns = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "uns")

# %%
file_names = os.listdir(DATA_PATH)
file_names_csv = [f for f in file_names if f.endswith(".csv")]

for file in file_names_csv:
    print(f"Processing {file}")
    df = pd.read_csv(join(DATA_PATH, file))
    print(df.columns)
    print(df.shape)
    print("-----------------------")
# Out:
# Processing EEM-scRNA-R42-2_meta.csv
# Index(['cellbarcode', 'orig.ident', 'nCount_RNA', 'nFeature_RNA',
#        'scrublet_score', 'scrublet_call', 'ident', 'cxds_score', 'cxds_call',
#        'bcds_score', 'bcds_call', 'hybrid_score', 'hybrid_call',
#        'percent.mito', 'S.Score', 'G2M.Score', 'Phase', 'nCount_SCT',
#        'nFeature_SCT', 'SCT_snn_res.0.6', 'seurat_clusters', 'orig_cluster',
#        'predicted.lineage_level1.score', 'predicted.lineage_level1',
#        'predicted.lineage_level2.score', 'predicted.lineage_level2',
#        'predicted.celltype_level1.score', 'predicted.celltype_level1',
#        'predicted.celltype_level2.score', 'predicted.celltype_level2',
#        'predicted.celltype_level3.score', 'predicted.celltype_level3'],
#       dtype='object')
# (11184, 32)
# -----------------------
# Processing EEM-scRNA-021_meta.csv
# Index(['cellbarcode', 'orig.ident', 'nCount_RNA', 'nFeature_RNA',
#        'scrublet_score', 'scrublet_call', 'ident', 'cxds_score', 'cxds_call',
#        'bcds_score', 'bcds_call', 'hybrid_score', 'hybrid_call',
#        'percent.mito', 'S.Score', 'G2M.Score', 'Phase', 'nCount_SCT',
#        'nFeature_SCT', 'SCT_snn_res.0.6', 'seurat_clusters', 'orig_cluster',
#        'predicted.lineage_level1.score', 'predicted.lineage_level1',
#        'predicted.lineage_level2.score', 'predicted.lineage_level2',
#        'predicted.celltype_level1.score', 'predicted.celltype_level1',
#        'predicted.celltype_level2.score', 'predicted.celltype_level2',
#        'predicted.celltype_level3.score', 'predicted.celltype_level3'],
#       dtype='object')
# (14627, 32)
# -----------------------
# Processing EEM-scRNA-R43-2_meta.csv
# Index(['cellbarcode', 'orig.ident', 'nCount_RNA', 'nFeature_RNA',
#        'scrublet_score', 'scrublet_call', 'ident', 'cxds_score', 'cxds_call',
#        'bcds_score', 'bcds_call', 'hybrid_score', 'hybrid_call',
#        'percent.mito', 'S.Score', 'G2M.Score', 'Phase', 'nCount_SCT',
#        'nFeature_SCT', 'SCT_snn_res.0.6', 'seurat_clusters', 'orig_cluster',
#        'predicted.lineage_level1.score', 'predicted.lineage_level1',
#        'predicted.lineage_level2.score', 'predicted.lineage_level2',
#        'predicted.celltype_level1.score', 'predicted.celltype_level1',
#        'predicted.celltype_level2.score', 'predicted.celltype_level2',
#        'predicted.celltype_level3.score', 'predicted.celltype_level3'],
#       dtype='object')
# (11727, 32)
# -----------------------
# Processing EEM-scRNA-R37-2_meta.csv
# Index(['cellbarcode', 'orig.ident', 'nCount_RNA', 'nFeature_RNA',
#        'scrublet_score', 'scrublet_call', 'ident', 'cxds_score', 'cxds_call',
#        'bcds_score', 'bcds_call', 'hybrid_score', 'hybrid_call',
#        'percent.mito', 'S.Score', 'G2M.Score', 'Phase', 'nCount_SCT',
#        'nFeature_SCT', 'SCT_snn_res.0.6', 'seurat_clusters', 'orig_cluster',
#        'predicted.lineage_level1.score', 'predicted.lineage_level1',
#        'predicted.lineage_level2.score', 'predicted.lineage_level2',
#        'predicted.celltype_level1.score', 'predicted.celltype_level1',
#        'predicted.celltype_level2.score', 'predicted.celltype_level2',
#        'predicted.celltype_level3.score', 'predicted.celltype_level3'],
#       dtype='object')
# (10352, 32)
# -----------------------
# Processing EEM-scRNA-R37-1_meta.csv
# Index(['cellbarcode', 'orig.ident', 'nCount_RNA', 'nFeature_RNA',
#        'scrublet_score', 'scrublet_call', 'ident', 'cxds_score', 'cxds_call',
#        'bcds_score', 'bcds_call', 'hybrid_score', 'hybrid_call',
#        'percent.mito', 'S.Score', 'G2M.Score', 'Phase', 'nCount_SCT',
#        'nFeature_SCT', 'SCT_snn_res.0.6', 'seurat_clusters', 'orig_cluster',
#        'predicted.lineage_level1.score', 'predicted.lineage_level1',
#        'predicted.lineage_level2.score', 'predicted.lineage_level2',
#        'predicted.celltype_level1.score', 'predicted.celltype_level1',
#        'predicted.celltype_level2.score', 'predicted.celltype_level2',
#        'predicted.celltype_level3.score', 'predicted.celltype_level3'],
#       dtype='object')
# (10612, 32)
# -----------------------
# Processing EEM-scRNA-R43-1_meta.csv
# Index(['cellbarcode', 'orig.ident', 'nCount_RNA', 'nFeature_RNA',
#        'scrublet_score', 'scrublet_call', 'ident', 'cxds_score', 'cxds_call',
#        'bcds_score', 'bcds_call', 'hybrid_score', 'hybrid_call',
#        'percent.mito', 'S.Score', 'G2M.Score', 'Phase', 'nCount_SCT',
#        'nFeature_SCT', 'SCT_snn_res.0.6', 'seurat_clusters', 'orig_cluster',
#        'predicted.lineage_level1.score', 'predicted.lineage_level1',
#        'predicted.lineage_level2.score', 'predicted.lineage_level2',
#        'predicted.celltype_level1.score', 'predicted.celltype_level1',
#        'predicted.celltype_level2.score', 'predicted.celltype_level2',
#        'predicted.celltype_level3.score', 'predicted.celltype_level3'],
#       dtype='object')
# (9722, 32)
# -----------------------
# Processing EEM-scRNA-R42-1_meta.csv
# Index(['cellbarcode', 'orig.ident', 'nCount_RNA', 'nFeature_RNA',
#        'scrublet_score', 'scrublet_call', 'ident', 'cxds_score', 'cxds_call',
#        'bcds_score', 'bcds_call', 'hybrid_score', 'hybrid_call',
#        'percent.mito', 'S.Score', 'G2M.Score', 'Phase', 'nCount_SCT',
#        'nFeature_SCT', 'SCT_snn_res.0.6', 'seurat_clusters', 'orig_cluster',
#        'predicted.lineage_level1.score', 'predicted.lineage_level1',
#        'predicted.lineage_level2.score', 'predicted.lineage_level2',
#        'predicted.celltype_level1.score', 'predicted.celltype_level1',
#        'predicted.celltype_level2.score', 'predicted.celltype_level2',
#        'predicted.celltype_level3.score', 'predicted.celltype_level3'],
#       dtype='object')
# (11180, 32)
# -----------------------

# %%
file_names = os.listdir(DATA_PATH)
file_names = [f for f in file_names if not f.endswith(".csv")]

adatas = {}
for file_name in file_names:
        adata = sc.read_10x_mtx(join(DATA_PATH, file_name))
        metadata = pd.read_csv(join(DATA_PATH, f"{file_name}_meta.csv"))
        if len(np.intersect1d(adata.obs.index, metadata.cellbarcode)) == 0:
            metadata['cellbarcode'] = metadata['cellbarcode'].apply(lambda x: x + "-1")
        print(f"Processing {file_name}")
        print(adata)
        print(np.intersect1d(adata.obs.index, metadata.cellbarcode).shape)
        print("-----------------------")
        adata.obs = pd.merge(
            adata.obs, metadata,
            left_index=True,
            right_on='cellbarcode',
            how='left').set_index('cellbarcode')
        adata.obs.index.name = None
        adatas[file_name] = adata

#adatas
# Out:
# Processing EEM-scRNA-R37-2
# AnnData object with n_obs × n_vars = 10343 × 33538
#     var: 'gene_ids', 'feature_types'
# (10338,)
# -----------------------
# Processing EEM-scRNA-021
# AnnData object with n_obs × n_vars = 14627 × 36601
#     var: 'gene_ids', 'feature_types'
# (14627,)
# -----------------------
# Processing EEM-scRNA-R37-1
# AnnData object with n_obs × n_vars = 10591 × 33538
#     var: 'gene_ids', 'feature_types'
# (10585,)
# -----------------------
# Processing EEM-scRNA-R42-2
# AnnData object with n_obs × n_vars = 11169 × 33538
#     var: 'gene_ids', 'feature_types'
# (11153,)
# -----------------------
# Processing EEM-scRNA-R42-1
# AnnData object with n_obs × n_vars = 11169 × 33538
#     var: 'gene_ids', 'feature_types'
# (11155,)
# -----------------------
# Processing EEM-scRNA-R43-2
# AnnData object with n_obs × n_vars = 12809 × 33538
#     var: 'gene_ids', 'feature_types'
# (11727,)
# -----------------------
# Processing EEM-scRNA-R43-1
# AnnData object with n_obs × n_vars = 9722 × 33538
#     var: 'gene_ids', 'feature_types'
# (9680,)
# -----------------------

# %%
gene_symbols = []
ensembl_ids = []

for adata in adatas.values():
    gene_symbols.append(adata.var.index)
    ensembl_ids.append(adata.var['gene_ids'])

# create mapping dict from gene symbol to ensembl id
gene_symbol_to_ensembl_id = {}

for gene_symbol, ensembl_id in zip(gene_symbols, ensembl_ids):
    for gs, ei in zip(gene_symbol, ensembl_id):
        gene_symbol_to_ensembl_id[gs] = ei

gene_symbol_to_ensembl_id
# Out:
# {'MIR1302-2HG': 'ENSG00000243485',
#  'FAM138A': 'ENSG00000237613',
#  'OR4F5': 'ENSG00000186092',
#  'AL627309.1': 'ENSG00000238009',
#  'AL627309.3': 'ENSG00000239945',
#  'AL627309.2': 'ENSG00000239906',
#  'AL627309.4': 'ENSG00000241599',
#  'AL732372.1': 'ENSG00000236601',
#  'OR4F29': 'ENSG00000284733',
#  'AC114498.1': 'ENSG00000235146',
#  'OR4F16': 'ENSG00000284662',
#  'AL669831.2': 'ENSG00000229905',
#  'AL669831.5': 'ENSG00000237491',
#  'FAM87B': 'ENSG00000177757',
#  'LINC00115': 'ENSG00000225880',
#  'FAM41C': 'ENSG00000230368',
#  'AL645608.7': 'ENSG00000272438',
#  'AL645608.3': 'ENSG00000230699',
#  'AL645608.5': 'ENSG00000241180',
#  'AL645608.1': 'ENSG00000223764',
#  'SAMD11': 'ENSG00000187634',
#  'NOC2L': 'ENSG00000188976',
#  'KLHL17': 'ENSG00000187961',
#  'PLEKHN1': 'ENSG00000187583',
#  'PERM1': 'ENSG00000187642',
#  'AL645608.8': 'ENSG00000272512',
#  'HES4': 'ENSG00000188290',
#  'ISG15': 'ENSG00000187608',
#  'AL645608.2': 'ENSG00000224969',
#  'AGRN': 'ENSG00000188157',
#  'AL645608.9': 'ENSG00000273443',
#  'RNF223': 'ENSG00000237330',
#  'C1orf159': 'ENSG00000131591',
#  'LINC01342': 'ENSG00000223823',
#  'AL390719.2': 'ENSG00000272141',
#  'TTLL10-AS1': 'ENSG00000205231',
#  'TTLL10': 'ENSG00000162571',
#  'TNFRSF18': 'ENSG00000186891',
#  'TNFRSF4': 'ENSG00000186827',
#  'SDF4': 'ENSG00000078808',
#  'B3GALT6': 'ENSG00000176022',
#  'C1QTNF12': 'ENSG00000184163',
#  'AL162741.1': 'ENSG00000260179',
#  'UBE2J2': 'ENSG00000160087',
#  'LINC01786': 'ENSG00000230415',
#  'SCNN1D': 'ENSG00000162572',
#  'ACAP3': 'ENSG00000131584',
#  'PUSL1': 'ENSG00000169972',
#  'INTS11': 'ENSG00000127054',
#  'CPTP': 'ENSG00000224051',
#  'TAS1R3': 'ENSG00000169962',
#  'DVL1': 'ENSG00000107404',
#  'TRABD2B': 'ENSG00000269113',
#  'AL691459.1': 'ENSG00000223814',
#  'AC096541.1': 'ENSG00000225028',
#  'AL356289.1': 'ENSG00000226133',
#  'AL356289.2': 'ENSG00000231413',
#  'AL109659.1': 'ENSG00000223720',
#  'SLC5A9': 'ENSG00000117834',
#  'AL109659.2': 'ENSG00000272491',
#  'SPATA6': 'ENSG00000132122',
#  'AGBL4': 'ENSG00000186094',
#  'BEND5': 'ENSG00000162373',
#  'AC099788.1': 'ENSG00000229846',
#  'AL590432.1': 'ENSG00000230114',
#  'ELAVL4': 'ENSG00000162374',
#  'AL592182.2': 'ENSG00000237337',
#  'AL592182.1': 'ENSG00000233407',
#  'AL596275.2': 'ENSG00000284696',
#  ...}

# %%
adata = ad.concat(adatas, join="outer", label="library_ID", index_unique="_")

# %%
val_workflow = ValidationWorkflow(
    input = uns,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                                                title           study_PI  \
# 0  Human distal airways contain a multipotent sec...  Edward,E,Morrisey
#
#   batch_condition default_embedding unpublished comments
# 0                              UMAP   published

# %%
val_workflow = ValidationWorkflow(
    input = obs,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation workflow successful. Returning OBS dataframe.
#       sample_ID donor_id                               protocol_URL  \
# 0  copd1_periph    COPD1  dx.doi.org/10.17504/protocols.io.b54gq8tw
# 1  copd1_periph    COPD1  dx.doi.org/10.17504/protocols.io.b54gq8tw
# 2  copd2_periph    COPD2  dx.doi.org/10.17504/protocols.io.b54gq8tw
# 3  copd2_periph    COPD2  dx.doi.org/10.17504/protocols.io.b54gq8tw
# 4  copd3_periph    COPD3  dx.doi.org/10.17504/protocols.io.b54gq8tw
# 5  copd3_periph    COPD3  dx.doi.org/10.17504/protocols.io.b54gq8tw
# 6  copd4_periph    COPD4  dx.doi.org/10.17504/protocols.io.b54gq8tw
#
#                     institute      sample_collection_site  \
# 0  University of Pennsylvania  University of Pennsylvania
# 1  University of Pennsylvania  University of Pennsylvania
# 2  University of Pennsylvania  University of Pennsylvania
# 3  University of Pennsylvania  University of Pennsylvania
# 4  University of Pennsylvania  University of Pennsylvania
# 5  University of Pennsylvania  University of Pennsylvania
# 6  University of Pennsylvania  University of Pennsylvania
#
#   sample_collection_relative_time_point       library_ID  \
# 0                                   N/A  EEM-scRNA-R37-1
# 1                                   N/A  EEM-scRNA-R37-2
# 2                                   N/A  EEM-scRNA-R42-1
# 3                                   N/A  EEM-scRNA-R42-2
# 4                                   N/A  EEM-scRNA-R43-1
# 5                                   N/A  EEM-scRNA-R43-2
# 6                                   N/A    EEM-scRNA-021
#
#   library_ID_repository author_batch_notes organism_ontology_term_id  ...  \
# 0            GSM5133588                               NCBITaxon:9606  ...
# 1            GSM5133589                               NCBITaxon:9606  ...
# 2            GSM5133590                               NCBITaxon:9606  ...
# 3            GSM5133591                               NCBITaxon:9606  ...
# 4            GSM5133592                               NCBITaxon:9606  ...
# 5            GSM5133593                               NCBITaxon:9606  ...
# 6            GSM5133594                               NCBITaxon:9606  ...
#
#   sequenced_fragment sequencing_platform is_primary_data reference_genome  \
# 0        3 prime tag         EFO:0008565            true           GRCh38
# 1        3 prime tag         EFO:0008565            true           GRCh38
# 2        3 prime tag         EFO:0008565            true           GRCh38
# 3        3 prime tag         EFO:0008565            true           GRCh38
# 4        3 prime tag         EFO:0008565            true           GRCh38
# 5        3 prime tag         EFO:0008565            true           GRCh38
# 6        3 prime tag         EFO:0008565            true           GRCh38
#
#   gene_annotation_version             alignment_software intron_inclusion  \
# 0  GENCODE v44/Ensembl110               CellRanger 3.0.0               no
# 1  GENCODE v44/Ensembl110               CellRanger 3.0.0               no
# 2  GENCODE v44/Ensembl110               CellRanger 3.0.0               no
# 3  GENCODE v44/Ensembl110               CellRanger 3.0.0               no
# 4  GENCODE v44/Ensembl110               CellRanger 3.0.0               no
# 5  GENCODE v44/Ensembl110               CellRanger 3.0.0               no
# 6  GENCODE v44/Ensembl110  STARsolo 2.7.9a_EmptyDrops_CR               no
#
#   disease_ontology_term_id self_reported_ethnicity_ontology_term_id  \
# 0            MONDO:0005002                                  unknown
# 1            MONDO:0005002                                  unknown
# 2            MONDO:0005002                                  unknown
# 3            MONDO:0005002                                  unknown
# 4            MONDO:0005002                                  unknown
# 5            MONDO:0005002                                  unknown
# 6            MONDO:0005002                                  unknown
#
#   development_stage_ontology_term_id
# 0                     HsapDv:0000241
# 1                     HsapDv:0000241
# 2                     HsapDv:0000241
# 3                     HsapDv:0000241
# 4                     HsapDv:0000241
# 5                     HsapDv:0000241
# 6                     HsapDv:0000241
#
# [7 rows x 37 columns]

# %% [markdown]
# # Validate obs and uns from adata

# %%
adata_ids = adata.obs['library_ID'].value_counts().index.tolist()
obs_ids = obs['library_ID'].value_counts().index.tolist()

non_overlap = list(set(adata_ids) - set(obs_ids))
non_overlap_other_side = list(set(obs_ids) - set(adata_ids))

# %%
non_overlap
# Out:
# []

# %%
non_overlap_other_side
# Out:
# []

# %%
merger = AnnDataMerger(
    adata = adata,
    uns_df = uns
)

adata = merger.add_uns_metadata()

adata
# Out:
# AnnData object with n_obs × n_vars = 80430 × 38224
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'scrublet_score', 'scrublet_call', 'ident', 'cxds_score', 'cxds_call', 'bcds_score', 'bcds_call', 'hybrid_score', 'hybrid_call', 'percent.mito', 'S.Score', 'G2M.Score', 'Phase', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.6', 'seurat_clusters', 'orig_cluster', 'predicted.lineage_level1.score', 'predicted.lineage_level1', 'predicted.lineage_level2.score', 'predicted.lineage_level2', 'predicted.celltype_level1.score', 'predicted.celltype_level1', 'predicted.celltype_level2.score', 'predicted.celltype_level2', 'predicted.celltype_level3.score', 'predicted.celltype_level3', 'library_ID'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments'

# %%
# Merge obs and uns
merger = AnnDataMerger(
    adata = adata,
    obs_df = obs
)

adata = merger.add_obs_metadata(
    adata_col = 'library_ID',
    df_col = 'library_ID',
    skip = None,
)

adata.obs
# Out:
#                                          orig.ident  nCount_RNA  nFeature_RNA  \
# AAACCTGAGAGCTGGT-1_EEM-scRNA-R37-2  EEM-scRNA-R37-2      1549.0         706.0
# AAACCTGAGAGGACGG-1_EEM-scRNA-R37-2  EEM-scRNA-R37-2      5117.0        1514.0
# AAACCTGAGAGGACGG-1_EEM-scRNA-R37-2    0.007264     False  ...
# AAACCTGAGCCCTAAT-1_EEM-scRNA-R37-2    0.038610     False  ...
# AAACCTGAGCGGCTTC-1_EEM-scRNA-R37-2    0.045413     False  ...
# AAACCTGAGGTTCCTA-1_EEM-scRNA-R37-2    0.014858     False  ...
# ...                                        ...       ...  ...
# TTTGTTGCACATACTG-1_EEM-scRNA-R43-1    0.013615     False  ...
# TTTGTTGCACTCCGGA-1_EEM-scRNA-R43-1    0.003144     False  ...
# TTTGTTGGTAATGTGA-1_EEM-scRNA-R43-1    0.001179     False  ...
# TTTGTTGGTCTGGTTA-1_EEM-scRNA-R43-1    0.000816     False  ...
# TTTGTTGGTTAGTTCG-1_EEM-scRNA-R43-1    0.002305     False  ...
#
#                                     sequenced_fragment sequencing_platform  \
# AAACCTGAGAGCTGGT-1_EEM-scRNA-R37-2         3 prime tag         EFO:0008565
# AAACCTGAGAGGACGG-1_EEM-scRNA-R37-2         3 prime tag         EFO:0008565
# AAACCTGAGCCCTAAT-1_EEM-scRNA-R37-2         3 prime tag         EFO:0008565
# AAACCTGAGCGGCTTC-1_EEM-scRNA-R37-2         3 prime tag         EFO:0008565
# AAACCTGAGGTTCCTA-1_EEM-scRNA-R37-2         3 prime tag         EFO:0008565
# ...                                                ...                 ...
# TTTGTTGCACATACTG-1_EEM-scRNA-R43-1         3 prime tag         EFO:0008565
# TTTGTTGCACTCCGGA-1_EEM-scRNA-R43-1         3 prime tag         EFO:0008565
# TTTGTTGGTAATGTGA-1_EEM-scRNA-R43-1         3 prime tag         EFO:0008565
# TTTGTTGGTCTGGTTA-1_EEM-scRNA-R43-1         3 prime tag         EFO:0008565
# TTTGTTGGTTAGTTCG-1_EEM-scRNA-R43-1         3 prime tag         EFO:0008565
#
#                                     is_primary_data  reference_genome  \
# AAACCTGAGAGCTGGT-1_EEM-scRNA-R37-2             true            GRCh38
# AAACCTGAGAGGACGG-1_EEM-scRNA-R37-2             true            GRCh38
# AAACCTGAGCCCTAAT-1_EEM-scRNA-R37-2             true            GRCh38
# AAACCTGAGCGGCTTC-1_EEM-scRNA-R37-2             true            GRCh38
# AAACCTGAGGTTCCTA-1_EEM-scRNA-R37-2             true            GRCh38
# ...                                             ...               ...
# TTTGTTGCACATACTG-1_EEM-scRNA-R43-1             true            GRCh38
# TTTGTTGCACTCCGGA-1_EEM-scRNA-R43-1             true            GRCh38
# TTTGTTGGTAATGTGA-1_EEM-scRNA-R43-1             true            GRCh38
# TTTGTTGGTCTGGTTA-1_EEM-scRNA-R43-1             true            GRCh38
# TTTGTTGGTTAGTTCG-1_EEM-scRNA-R43-1             true            GRCh38
#
#                                     gene_annotation_version  \
# AAACCTGAGAGCTGGT-1_EEM-scRNA-R37-2   GENCODE v44/Ensembl110
# AAACCTGAGAGGACGG-1_EEM-scRNA-R37-2   GENCODE v44/Ensembl110
# AAACCTGAGCCCTAAT-1_EEM-scRNA-R37-2   GENCODE v44/Ensembl110
# AAACCTGAGCGGCTTC-1_EEM-scRNA-R37-2   GENCODE v44/Ensembl110
# AAACCTGAGGTTCCTA-1_EEM-scRNA-R37-2   GENCODE v44/Ensembl110
# ...                                                     ...
# TTTGTTGCACATACTG-1_EEM-scRNA-R43-1   GENCODE v44/Ensembl110
# TTTGTTGCACTCCGGA-1_EEM-scRNA-R43-1   GENCODE v44/Ensembl110
# TTTGTTGGTAATGTGA-1_EEM-scRNA-R43-1   GENCODE v44/Ensembl110
# TTTGTTGGTCTGGTTA-1_EEM-scRNA-R43-1   GENCODE v44/Ensembl110
# TTTGTTGGTTAGTTCG-1_EEM-scRNA-R43-1   GENCODE v44/Ensembl110
#
#                                    alignment_software  intron_inclusion  \
# AAACCTGAGAGCTGGT-1_EEM-scRNA-R37-2   CellRanger 3.0.0                no
# AAACCTGAGAGGACGG-1_EEM-scRNA-R37-2   CellRanger 3.0.0                no
# AAACCTGAGCCCTAAT-1_EEM-scRNA-R37-2   CellRanger 3.0.0                no
# AAACCTGAGCGGCTTC-1_EEM-scRNA-R37-2   CellRanger 3.0.0                no
# AAACCTGAGGTTCCTA-1_EEM-scRNA-R37-2   CellRanger 3.0.0                no
# ...                                               ...               ...
# TTTGTTGCACATACTG-1_EEM-scRNA-R43-1   CellRanger 3.0.0                no
# TTTGTTGCACTCCGGA-1_EEM-scRNA-R43-1   CellRanger 3.0.0                no
# TTTGTTGGTAATGTGA-1_EEM-scRNA-R43-1   CellRanger 3.0.0                no
# TTTGTTGGTCTGGTTA-1_EEM-scRNA-R43-1   CellRanger 3.0.0                no
# TTTGTTGGTTAGTTCG-1_EEM-scRNA-R43-1   CellRanger 3.0.0                no
#
#                                     disease_ontology_term_id  \
# AAACCTGAGAGCTGGT-1_EEM-scRNA-R37-2             MONDO:0005002
# AAACCTGAGAGGACGG-1_EEM-scRNA-R37-2             MONDO:0005002
# AAACCTGAGCCCTAAT-1_EEM-scRNA-R37-2             MONDO:0005002
# AAACCTGAGCGGCTTC-1_EEM-scRNA-R37-2             MONDO:0005002
# AAACCTGAGGTTCCTA-1_EEM-scRNA-R37-2             MONDO:0005002
# ...                                                      ...
# TTTGTTGCACATACTG-1_EEM-scRNA-R43-1             MONDO:0005002
# TTTGTTGCACTCCGGA-1_EEM-scRNA-R43-1             MONDO:0005002
# TTTGTTGGTAATGTGA-1_EEM-scRNA-R43-1             MONDO:0005002
# TTTGTTGGTCTGGTTA-1_EEM-scRNA-R43-1             MONDO:0005002
# TTTGTTGGTTAGTTCG-1_EEM-scRNA-R43-1             MONDO:0005002
#
#                                     self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGAGCTGGT-1_EEM-scRNA-R37-2                                   unknown
# AAACCTGAGAGGACGG-1_EEM-scRNA-R37-2                                   unknown
# AAACCTGAGCCCTAAT-1_EEM-scRNA-R37-2                                   unknown
# AAACCTGAGCGGCTTC-1_EEM-scRNA-R37-2                                   unknown
# AAACCTGAGGTTCCTA-1_EEM-scRNA-R37-2                                   unknown
# ...                                                                      ...
# TTTGTTGCACATACTG-1_EEM-scRNA-R43-1                                   unknown
# TTTGTTGCACTCCGGA-1_EEM-scRNA-R43-1                                   unknown
# TTTGTTGGTAATGTGA-1_EEM-scRNA-R43-1                                   unknown
# TTTGTTGGTCTGGTTA-1_EEM-scRNA-R43-1                                   unknown
# TTTGTTGGTTAGTTCG-1_EEM-scRNA-R43-1                                   unknown
#
#                                     development_stage_ontology_term_id
# AAACCTGAGAGCTGGT-1_EEM-scRNA-R37-2                      HsapDv:0000241
# AAACCTGAGAGGACGG-1_EEM-scRNA-R37-2                      HsapDv:0000241
# AAACCTGAGCCCTAAT-1_EEM-scRNA-R37-2                      HsapDv:0000241
# AAACCTGAGCGGCTTC-1_EEM-scRNA-R37-2                      HsapDv:0000241
# AAACCTGAGGTTCCTA-1_EEM-scRNA-R37-2                      HsapDv:0000241
# ...                                                                ...
# TTTGTTGCACATACTG-1_EEM-scRNA-R43-1                      HsapDv:0000241
# TTTGTTGCACTCCGGA-1_EEM-scRNA-R43-1                      HsapDv:0000241
# TTTGTTGGTAATGTGA-1_EEM-scRNA-R43-1                      HsapDv:0000241
# TTTGTTGGTCTGGTTA-1_EEM-scRNA-R43-1                      HsapDv:0000241
# TTTGTTGGTTAGTTCG-1_EEM-scRNA-R43-1                      HsapDv:0000241
#
# [80430 rows x 68 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 80430 × 38224
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'scrublet_score', 'scrublet_call', 'ident', 'cxds_score', 'cxds_call', 'bcds_score', 'bcds_call', 'hybrid_score', 'hybrid_call', 'percent.mito', 'S.Score', 'G2M.Score', 'Phase', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.6', 'seurat_clusters', 'orig_cluster', 'predicted.lineage_level1.score', 'predicted.lineage_level1', 'predicted.lineage_level2.score', 'predicted.lineage_level2', 'predicted.celltype_level1.score', 'predicted.celltype_level1', 'predicted.celltype_level2.score', 'predicted.celltype_level2', 'predicted.celltype_level3.score', 'predicted.celltype_level3', 'library_ID', 'sample_ID', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments'

# %% [markdown]
# # Add author cell type markers to UNS
#
# Lungmap CellRef was used for reference mapping

# %%
adata.obs[AUTHOR_CELL_TYPE_L0] = adata.obs['predicted.celltype_level1']
adata.obs[AUTHOR_CELL_TYPE_L1] = adata.obs['predicted.celltype_level2']
adata.obs[AUTHOR_CELL_TYPE_L2] = adata.obs['predicted.celltype_level3']

# %%
adata.obs[AUTHOR_CELL_TYPE] = adata.obs['predicted.celltype_level3']

# %%
adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False).index.tolist()
# Out:
# ['AT2',
#  'AM',
#  'CAP1',
#  'AT1',
#  'CD4_T',
#  'AF1',
#  'Plasma',
#  'VSMC',
#  'CAP2',
#  'VEC',
#  'Pericyte',
#  'LEC',
#  'B',
#  'Serous',
#  'RAS',
#  'AEC',
#  'SCMF',
#  'Ciliated',
#  'SVEC',
#  'NK',
#  'Secretory',
#  'AF2',
#  nan,
#  'CD8_T',
#  'IM',
#  'Mast/Basophil',
#  'ASMC',
#  'Mesothelial',
#  'Basal',
#  'Suprabasal',
#  'iMON',
#  'Neutrophil',
#  'cDC2',
#  'PNEC',
#  'pDC',
#  'pMON',
#  'Goblet',
#  'cDC1',
#  'maDC',
#  'Tuft',
#  'Treg',
#  'Ionocyte',
#  'Megakaryocyte/Platelet',
#  'SMG_Basal/Duct']

# %%
ontology_marker_genes_df = pd.read_csv("../lungMAP/lungMAP_ontologies_marker_genes.csv")
ontology_marker_genes_df
# Out:
#                            author_cell_type cell_type_ontology_term_id  \
# 0               Alveolar fibroblast 2 (AF2)                 CL:4028006
# 1               Alveolar fibroblast 1 (AF1)                 CL:4028004
# 2                  Alveolar macrophage (AM)                 CL:0000583
# 3                Alveolar type 1 cell (AT1)                 CL:0002062
# 4                Alveolar type 2 cell (AT2)                 CL:0002063
# 5                                B cell (B)                 CL:0000236
# 6                        Basal cell (Basal)                 CL:0002633
# 7                       CD4+ T cell (CD4 T)                 CL:0000624
# 8                       CD8+ T cell (CD8 T)                 CL:0000625
# 9              Inflammatory monocyte (iMON)                 CL:0000860
# 10               Secretory cell (Secretory)                 CL:0000158
# 11             Classical DC subset 1 (cDC1)                 CL:0000990
# 12             Classical DC subset 2 (cDC2)                 CL:0002399
# 13         Deuterosomal cell (Deuterosomal)                 CL:4033044
# 14                  Capillary 2 cell (CAP2)                 CL:4028003
# 15          Arterial endothelial cell (AEC)                 CL:1001568
# 16                  Capillary 1 cell (CAP1)                 CL:4028002
# 17            Venous endothelial cell (VEC)                 CL:0002543
# 18  Systemic venous endothelial cell (SVEC)             UBERON:0001592
# 19         Airway smooth muscle cell (ASMC)                 CL:0019019
# 20                     Goblet cell (Goblet)                 CL:0000160
# 21             Interstitial macrophage (IM)                 CL:4033043
# 22                 Ionocyte cell (Ionocyte)                 CL:0005006
# 23         Lymphatic endothelial cell (LEC)                 CL:0002138
# 24            Mast/Basophil (Mast/Basophil)                 CL:0000097
# 25           Mesothelial cell (Mesothelial)                 CL:0000077
# 26                  Mature DC subset (maDC)                 CL:4033045
# 27                 Ciliated cell (Ciliated)                 CL:4030034
# 28     Secondary crest myofibroblast (SCMF)                 CL:0000186
# 29     Pulmonary neuroendocrine cell (PNEC)                 CL:1000223
# 30                 Natural killer cell (NK)                 CL:0000623
# 31               Patrolling monocyte (pMON)                 CL:0000875
# 32                      Pericyte (Pericyte)                 CL:0009089
# 33                     Plasma cell (Plasma)                 CL:0000786
# 34                    Plasmacytoid DC (pDC)                 CL:0000784
# 35     SMG Basal/Duct cell (SMG Basal/Duct)                 CL:4033024
# 36                     Mucous cell (Mucous)                 CL:4033022
# 37                     Serous cell (Serous)                 CL:4033005
# 38       Vascular smooth muscle cell (VSMC)                 CL:0000359
# 39             Suprabasal cell (Suprabasal)                 CL:4033048
# 40  Respiratory airway secretory cell (RAS)             UBERON:0001955
# 41                         Tuft cell (Tuft)                 CL:0002075
# 42                 Myoepithelial cell (MEC)                 CL:4033003
# 43                               Neutrophil                 CL:0000775
# 44                   Megakaryocyte/Platelet                 CL:0000556
# 45                 T regulatory cell (Treg)                 CL:0000815
# 46               Innate lymphoid cell (ILC)                 CL:0001065
# 47                              Chondrocyte                 CL:0000138
#
#                                               Comment  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Please advise if there is a better term for th...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18     Please advise if there is a cell ontology term
# 19            Please advise if there is a better term
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  Not unambiguous, could be either CL:0000097 or...
# 25                                                NaN
# 26  Based on the correlation mapping to HLCA migra...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40     Please advise if there is a cell ontology term
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
#
#                             full_name            abbreviation  \
# 0               Alveolar fibroblast 2                     AF2
# 1               Alveolar fibroblast 1                     AF1
# 2                 Alveolar macrophage                      AM
# 3                Alveolar type 1 cell                     AT1
# 4                Alveolar type 2 cell                     AT2
# 5                              B cell                       B
# 6                          Basal cell                   Basal
# 7                         CD4+ T cell                   CD4 T
# 8                         CD8+ T cell                   CD8 T
# 9               Inflammatory monocyte                    iMON
# 10                     Secretory cell               Secretory
# 11              Classical DC subset 1                    cDC1
# 12              Classical DC subset 2                    cDC2
# 13                  Deuterosomal cell            Deuterosomal
# 14                   Capillary 2 cell                    CAP2
# 15          Arterial endothelial cell                     AEC
# 16                   Capillary 1 cell                    CAP1
# 17            Venous endothelial cell                     VEC
# 18   Systemic venous endothelial cell                    SVEC
# 19          Airway smooth muscle cell                    ASMC
# 20                        Goblet cell                  Goblet
# 21            Interstitial macrophage                      IM
# 22                      Ionocyte cell                Ionocyte
# 23         Lymphatic endothelial cell                     LEC
# 24                      Mast/Basophil           Mast/Basophil
# 25                   Mesothelial cell             Mesothelial
# 26                   Mature DC subset                    maDC
# 27                      Ciliated cell                Ciliated
# 28      Secondary crest myofibroblast                    SCMF
# 29      Pulmonary neuroendocrine cell                    PNEC
# 30                Natural killer cell                      NK
# 31                Patrolling monocyte                    pMON
# 32                           Pericyte                Pericyte
# 33                        Plasma cell                  Plasma
# 34                    Plasmacytoid DC                     pDC
# 35                SMG Basal/Duct cell          SMG Basal/Duct
# 36                        Mucous cell                  Mucous
# 37                        Serous cell                  Serous
# 38        Vascular smooth muscle cell                    VSMC
# 39                    Suprabasal cell              Suprabasal
# 40  Respiratory airway secretory cell                     RAS
# 41                          Tuft cell                    Tuft
# 42                 Myoepithelial cell                     MEC
# 43                         Neutrophil              Neutrophil
# 44             Megakaryocyte/Platelet  Megakaryocyte/Platelet
# 45                  T regulatory cell                    Treg
# 46               Innate lymphoid cell                     ILC
# 47                        Chondrocyte             Chondrocyte
#
#                              author_cell_type_markers
# 0   MFAP5; SCARA5; CDON; DCN; PLA2G2A; SFRP2; LUM;...
# 1   TCF21; PCDH15; WNT2; ROBO2; LUM; SLIT2; DCN; P...
# 2   FABP4; MARCO; CYP27A1; PPARG; ABCG1; SIGLEC1; ...
# 3   AGER; RTKN2; SEMA3B; NTM; NCKAP5; LMO7; KHDRBS...
# 4   ABCA3; LAMP3; KCNJ15; SFTPC; SFTPA1; SFTPA2; S...
# 5   BANK1; MS4A1; CD19; BACH2; IGHM; EBF1; CD79A; ...
# 6   KRT5; TP63; NGFR; KRT15; KRT17; MMP10; S100A2;...
# 7   CD3E; LEF1; CD40LG; MAL; CD4; CD69; ITK; LTB; ...
# 8   CD8A; CD3E; CD8B; CCL5; NKG7; GZMA; GZMH; IL32...
# 9   VCAN; FCN1; CD14; S100A8; JARID2; S100A12; THB...
# 10  SCGB1A1; BPIFB1; LCN2; TSPAN8; SCUBE2; SAA2; C...
# 11  CLEC9A; FLT3; ZBTB46; LGALS2; DNASE1L3; WDFY4;...
# 12  CD1E; CLEC10A; FCGR2B; CD1C; CCL17; FCER1A; MS...
# 13                       CDC20B; DEUP1; FOXN4; SHISA8
# 14  HPGD; EDNRB; CA4; APLN; SOSTDC1; CLDN5; EMCN; ...
# 15  DKK2; GJA5; BMX; IGFBP3; FAM107A; MT1A; PTPRB;...
# 16  FCN3; IL7R; GPIHBP1; TMEM100; SLC6A4; IL1RL1; ...
# 17  ACKR1; EPHB4; HDAC9; VWF; CCL23; C7; LIFR; PTP...
# 18  ACKR1; COL15A1; VWA1; ABCB1; CCL14; PLVAP; AQP...
# 19  DES; LGR6; BCHE; PLN; ASPN; PRUNE2; HSPB7; GRE...
# 20  MUC5AC; AGR2; SPDEF; SLC4A11; PSCA; LYPD2; MUC...
# 21  F13A1; STAB1; FOLR2; SLC40A1; CD163L1; MERTK; ...
# 22  ASCL3; FOXI1; CFTR; CEL; TMEM61; SCNN1B; BPIFA...
# 23  CCL21; MMRN1; PROX1; LYVE1; PPFIBP1; GNG11; SN...
# 24  TPSB2; TPSAB1; MS4A2; CPA3; HPGDS; RGS1; VWA5A...
# 25  UPK3B; CALB2; WT1; HP; ITLN1; PLA2G2A; PRG4; T...
# 26  CCR7; LAD1; NCCRP1; CCL19; CCL22; CCL17; IL4I1...
# 27  RSPH1; CDHR3; FOXJ1; CDHR4; CAPS; C20orf85; C9...
# 28  ITGBL1; FGF18; PDGFRA; ASPN; CCN5; COL3A1; PRE...
# 29  GRP; CALCA; ASCL1; NRXN1; PCSK1N; SCG2; CHGA; ...
# 30  NKG7; KLRD1; KLRC1; NCAM1; GNLY; GZMB; CCL4; P...
# 31  FCGR3A; FCN1; TNFRSF8; LST1; AIF1; SMIM25; SER...
# 32  PDGFRB; LAMC3; CSPG4; TRPC6; COX4I2; HIGD1B; B...
# 33  CD38; CD27; SDC1; JCHAIN; IGLC3; IGHM; IGHG1; ...
# 34  PLD4; LILRA4; CLEC4C; GZMB; IRF7; IRF8; GPR183...
# 35  RARRES1; MIA; ALDH1A3; KRT14; SOX9; MMP7; SAA2...
# 36  BPIFB2; MUC5B; SPDEF; TFF1; AZGP1; TCN1; FAM3D...
# 37  LYZ; LTF; LPO; PRB3; PRR4; PRB1; AC020656.1; P...
# 38  CNN1; NTRK3; ITGA7; TAGLN; MUSTN1; C11orf96; A...
# 39  KRT19; SERPINB4; NOTCH3; SERPINB3; S100A2; KRT...
# 40           SCGB3A2; MGP; SOX4; KLK11; TMEM45A; CTSE
# 41  IL23A; POU2F3; ASCL2; NREP; HEPACAM2; NMU; MYB...
# 42  KRT14; MYH11; KRT17; SAA1; TPM2; ACTG2; MYLK; ...
# 43  FCGR3B; CSF3R; IL1B; S100A8; S100A12; G0S2; BC...
# 44  GP1BB; ITGA2B; ITGB3; PPBP; PF4; TUBB1; ACRBP;...
# 45  IL2RA; FOXP3; CTLA4; TRAC; LTB; TRBC1; CD3D; T...
# 46                                 IL7R; CXCR3; TBX21
# 47                         ACAN; HAPLN1; COL2A1; SOX9

# %%
len(adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False).index.tolist())
# Out:
# 44

# %%
len(np.intersect1d(adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=True).index.tolist(), ontology_marker_genes_df['abbreviation']))
# Out:
# 40

# %%
# show non overlapping cell types

non_overlap = list(set(adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False).index.tolist()) - set(ontology_marker_genes_df['abbreviation']))
non_overlap
# Out:
# ['SMG_Basal/Duct', nan, 'CD8_T', 'CD4_T']

# %%
# replace in ontology_marker_genes_df['abbreviation'] every ' ' with a '_'
ontology_marker_genes_df['abbreviation'] = ontology_marker_genes_df['abbreviation'].apply(lambda x: x.replace(' ', '_'))

list(set(adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False).index.tolist()) - set(ontology_marker_genes_df['abbreviation']))
# Out:
# [nan]

# %%
ontology_marker_genes_df.drop(columns=AUTHOR_CELL_TYPE, inplace=True)
ontology_marker_genes_df.rename(columns={'abbreviation': AUTHOR_CELL_TYPE}, inplace=True)

ontology_marker_genes_df
# Out:
#    cell_type_ontology_term_id  \
# 0                  CL:4028006
# 1                  CL:4028004
# 2                  CL:0000583
# 3                  CL:0002062
# 4                  CL:0002063
# 5                  CL:0000236
# 6                  CL:0002633
# 7                  CL:0000624
# 8                  CL:0000625
# 9                  CL:0000860
# 10                 CL:0000158
# 11                 CL:0000990
# 12                 CL:0002399
# 13                 CL:4033044
# 14                 CL:4028003
# 15                 CL:1001568
# 16                 CL:4028002
# 17                 CL:0002543
# 18             UBERON:0001592
# 19                 CL:0019019
# 20                 CL:0000160
# 21                 CL:4033043
# 22                 CL:0005006
# 23                 CL:0002138
# 24                 CL:0000097
# 25                 CL:0000077
# 26                 CL:4033045
# 27                 CL:4030034
# 28                 CL:0000186
# 29                 CL:1000223
# 30                 CL:0000623
# 31                 CL:0000875
# 32                 CL:0009089
# 33                 CL:0000786
# 34                 CL:0000784
# 35                 CL:4033024
# 36                 CL:4033022
# 37                 CL:4033005
# 38                 CL:0000359
# 39                 CL:4033048
# 40             UBERON:0001955
# 41                 CL:0002075
# 42                 CL:4033003
# 43                 CL:0000775
# 44                 CL:0000556
# 45                 CL:0000815
# 46                 CL:0001065
# 47                 CL:0000138
#
#                                               Comment  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Please advise if there is a better term for th...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18     Please advise if there is a cell ontology term
# 19            Please advise if there is a better term
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  Not unambiguous, could be either CL:0000097 or...
# 25                                                NaN
# 26  Based on the correlation mapping to HLCA migra...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40     Please advise if there is a cell ontology term
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
#
#                             full_name        author_cell_type  \
# 0               Alveolar fibroblast 2                     AF2
# 1               Alveolar fibroblast 1                     AF1
# 2                 Alveolar macrophage                      AM
# 3                Alveolar type 1 cell                     AT1
# 4                Alveolar type 2 cell                     AT2
# 5                              B cell                       B
# 6                          Basal cell                   Basal
# 7                         CD4+ T cell                   CD4_T
# 8                         CD8+ T cell                   CD8_T
# 9               Inflammatory monocyte                    iMON
# 10                     Secretory cell               Secretory
# 11              Classical DC subset 1                    cDC1
# 12              Classical DC subset 2                    cDC2
# 13                  Deuterosomal cell            Deuterosomal
# 14                   Capillary 2 cell                    CAP2
# 15          Arterial endothelial cell                     AEC
# 16                   Capillary 1 cell                    CAP1
# 17            Venous endothelial cell                     VEC
# 18   Systemic venous endothelial cell                    SVEC
# 19          Airway smooth muscle cell                    ASMC
# 20                        Goblet cell                  Goblet
# 21            Interstitial macrophage                      IM
# 22                      Ionocyte cell                Ionocyte
# 23         Lymphatic endothelial cell                     LEC
# 24                      Mast/Basophil           Mast/Basophil
# 25                   Mesothelial cell             Mesothelial
# 26                   Mature DC subset                    maDC
# 27                      Ciliated cell                Ciliated
# 28      Secondary crest myofibroblast                    SCMF
# 29      Pulmonary neuroendocrine cell                    PNEC
# 30                Natural killer cell                      NK
# 31                Patrolling monocyte                    pMON
# 32                           Pericyte                Pericyte
# 33                        Plasma cell                  Plasma
# 34                    Plasmacytoid DC                     pDC
# 35                SMG Basal/Duct cell          SMG_Basal/Duct
# 36                        Mucous cell                  Mucous
# 37                        Serous cell                  Serous
# 38        Vascular smooth muscle cell                    VSMC
# 39                    Suprabasal cell              Suprabasal
# 40  Respiratory airway secretory cell                     RAS
# 41                          Tuft cell                    Tuft
# 42                 Myoepithelial cell                     MEC
# 43                         Neutrophil              Neutrophil
# 44             Megakaryocyte/Platelet  Megakaryocyte/Platelet
# 45                  T regulatory cell                    Treg
# 46               Innate lymphoid cell                     ILC
# 47                        Chondrocyte             Chondrocyte
#
#                              author_cell_type_markers
# 0   MFAP5; SCARA5; CDON; DCN; PLA2G2A; SFRP2; LUM;...
# 1   TCF21; PCDH15; WNT2; ROBO2; LUM; SLIT2; DCN; P...
# 2   FABP4; MARCO; CYP27A1; PPARG; ABCG1; SIGLEC1; ...
# 3   AGER; RTKN2; SEMA3B; NTM; NCKAP5; LMO7; KHDRBS...
# 4   ABCA3; LAMP3; KCNJ15; SFTPC; SFTPA1; SFTPA2; S...
# 5   BANK1; MS4A1; CD19; BACH2; IGHM; EBF1; CD79A; ...
# 6   KRT5; TP63; NGFR; KRT15; KRT17; MMP10; S100A2;...
# 7   CD3E; LEF1; CD40LG; MAL; CD4; CD69; ITK; LTB; ...
# 8   CD8A; CD3E; CD8B; CCL5; NKG7; GZMA; GZMH; IL32...
# 9   VCAN; FCN1; CD14; S100A8; JARID2; S100A12; THB...
# 10  SCGB1A1; BPIFB1; LCN2; TSPAN8; SCUBE2; SAA2; C...
# 11  CLEC9A; FLT3; ZBTB46; LGALS2; DNASE1L3; WDFY4;...
# 12  CD1E; CLEC10A; FCGR2B; CD1C; CCL17; FCER1A; MS...
# 13                       CDC20B; DEUP1; FOXN4; SHISA8
# 14  HPGD; EDNRB; CA4; APLN; SOSTDC1; CLDN5; EMCN; ...
# 15  DKK2; GJA5; BMX; IGFBP3; FAM107A; MT1A; PTPRB;...
# 16  FCN3; IL7R; GPIHBP1; TMEM100; SLC6A4; IL1RL1; ...
# 17  ACKR1; EPHB4; HDAC9; VWF; CCL23; C7; LIFR; PTP...
# 18  ACKR1; COL15A1; VWA1; ABCB1; CCL14; PLVAP; AQP...
# 19  DES; LGR6; BCHE; PLN; ASPN; PRUNE2; HSPB7; GRE...
# 20  MUC5AC; AGR2; SPDEF; SLC4A11; PSCA; LYPD2; MUC...
# 21  F13A1; STAB1; FOLR2; SLC40A1; CD163L1; MERTK; ...
# 22  ASCL3; FOXI1; CFTR; CEL; TMEM61; SCNN1B; BPIFA...
# 23  CCL21; MMRN1; PROX1; LYVE1; PPFIBP1; GNG11; SN...
# 24  TPSB2; TPSAB1; MS4A2; CPA3; HPGDS; RGS1; VWA5A...
# 25  UPK3B; CALB2; WT1; HP; ITLN1; PLA2G2A; PRG4; T...
# 26  CCR7; LAD1; NCCRP1; CCL19; CCL22; CCL17; IL4I1...
# 27  RSPH1; CDHR3; FOXJ1; CDHR4; CAPS; C20orf85; C9...
# 28  ITGBL1; FGF18; PDGFRA; ASPN; CCN5; COL3A1; PRE...
# 29  GRP; CALCA; ASCL1; NRXN1; PCSK1N; SCG2; CHGA; ...
# 30  NKG7; KLRD1; KLRC1; NCAM1; GNLY; GZMB; CCL4; P...
# 31  FCGR3A; FCN1; TNFRSF8; LST1; AIF1; SMIM25; SER...
# 32  PDGFRB; LAMC3; CSPG4; TRPC6; COX4I2; HIGD1B; B...
# 33  CD38; CD27; SDC1; JCHAIN; IGLC3; IGHM; IGHG1; ...
# 34  PLD4; LILRA4; CLEC4C; GZMB; IRF7; IRF8; GPR183...
# 35  RARRES1; MIA; ALDH1A3; KRT14; SOX9; MMP7; SAA2...
# 36  BPIFB2; MUC5B; SPDEF; TFF1; AZGP1; TCN1; FAM3D...
# 37  LYZ; LTF; LPO; PRB3; PRR4; PRB1; AC020656.1; P...
# 38  CNN1; NTRK3; ITGA7; TAGLN; MUSTN1; C11orf96; A...
# 39  KRT19; SERPINB4; NOTCH3; SERPINB3; S100A2; KRT...
# 40           SCGB3A2; MGP; SOX4; KLK11; TMEM45A; CTSE
# 41  IL23A; POU2F3; ASCL2; NREP; HEPACAM2; NMU; MYB...
# 42  KRT14; MYH11; KRT17; SAA1; TPM2; ACTG2; MYLK; ...
# 43  FCGR3B; CSF3R; IL1B; S100A8; S100A12; G0S2; BC...
# 44  GP1BB; ITGA2B; ITGB3; PPBP; PF4; TUBB1; ACRBP;...
# 45  IL2RA; FOXP3; CTLA4; TRAC; LTB; TRBC1; CD3D; T...
# 46                                 IL7R; CXCR3; TBX21
# 47                         ACAN; HAPLN1; COL2A1; SOX9

# %%
adata.uns[MARKER_GENES] = ontology_marker_genes_df

# %% [markdown]
# # Check author cell type annotations and Cell Ontology IDs

# %%
adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False)
# Out:
# AT2                       13700
# AM                         8448
# CAP1                       6457
# AT1                        5658
# CD4_T                      4060
# AF1                        3909
# Plasma                     3362
# VSMC                       2857
# CAP2                       2692
# VEC                        2506
# Pericyte                   2406
# LEC                        2239
# B                          2174
# Serous                     2147
# RAS                        2014
# AEC                        1929
# SCMF                       1793
# Ciliated                   1785
# SVEC                       1742
# NK                         1557
# Secretory                  1317
# AF2                        1206
# NaN                        1165
# CD8_T                       741
# IM                          513
# Mast/Basophil               481
# ASMC                        473
# Mesothelial                 206
# Basal                       184
# Suprabasal                  159
# iMON                        158
# Neutrophil                   91
# cDC2                         84
# PNEC                         47
# pDC                          40
# pMON                         33
# Goblet                       30
# cDC1                         28
# maDC                         18
# Tuft                          6
# Treg                          5
# Ionocyte                      4
# Megakaryocyte/Platelet        3
# SMG_Basal/Duct                3
# Name: author_cell_type, dtype: int64

# %%
adata.obs[CELL_TYPE_ONTOLOGY_ID] = adata.obs[AUTHOR_CELL_TYPE].map(dict(zip(ontology_marker_genes_df[AUTHOR_CELL_TYPE], ontology_marker_genes_df['cell_type_ontology_term_id'])))

adata.obs[CELL_TYPE_ONTOLOGY_ID].value_counts(dropna=False)
# Out:
# CL:0002063        13700
# CL:0000583         8448
# CL:4028002         6457
# CL:0002062         5658
# CL:0000624         4060
# CL:4028004         3909
# CL:0000786         3362
# CL:0000359         2857
# CL:4028003         2692
# CL:0002543         2506
# CL:0009089         2406
# CL:0002138         2239
# CL:0000236         2174
# CL:4033005         2147
# UBERON:0001955     2014
# CL:1001568         1929
# CL:0000186         1793
# CL:4030034         1785
# UBERON:0001592     1742
# CL:0000623         1557
# CL:0000158         1317
# CL:4028006         1206
# NaN                1165
# CL:0000625          741
# CL:4033043          513
# CL:0000097          481
# CL:0019019          473
# CL:0000077          206
# CL:0002633          184
# CL:4033048          159
# CL:0000860          158
# CL:0000775           91
# CL:0002399           84
# CL:1000223           47
# CL:0000784           40
# CL:0000875           33
# CL:0000160           30
# CL:0000990           28
# CL:4033045           18
# CL:0002075            6
# CL:0000815            5
# CL:0005006            4
# CL:0000556            3
# CL:4033024            3
# Name: cell_type_ontology_term_id, dtype: int64

# %%
adata.obs[MARKER_GENES] = adata.obs[AUTHOR_CELL_TYPE].map(dict(zip(ontology_marker_genes_df[AUTHOR_CELL_TYPE], ontology_marker_genes_df['author_cell_type_markers'])))

adata.obs[MARKER_GENES].value_counts(dropna=False)
# Out:
# ABCA3; LAMP3; KCNJ15; SFTPC; SFTPA1; SFTPA2; SFTPB; PGC; NAPSA; SFTPD            13700
# FABP4; MARCO; CYP27A1; PPARG; ABCG1; SIGLEC1; C1QB; APOC1; C1QA; C1QC             8448
# FCN3; IL7R; GPIHBP1; TMEM100; SLC6A4; IL1RL1; EDN1; BTNL9; CLEC14A; POSTN         6457
# AGER; RTKN2; SEMA3B; NTM; NCKAP5; LMO7; KHDRBS2; LIMCH1; LAMA3; SCEL              5658
# CD3E; LEF1; CD40LG; MAL; CD4; CD69; ITK; LTB; TRAC; RHOH                          4060
# TCF21; PCDH15; WNT2; ROBO2; LUM; SLIT2; DCN; PRKG1; SCN7A; MFAP4                  3909
# CD38; CD27; SDC1; JCHAIN; IGLC3; IGHM; IGHG1; IGHG3; IGHA2; MZB1                  3362
# CNN1; NTRK3; ITGA7; TAGLN; MUSTN1; C11orf96; ACTA2; MYH11; TPM2; RERGL            2857
# HPGD; EDNRB; CA4; APLN; SOSTDC1; CLDN5; EMCN; RAMP2; IL1RL1; AQP1                 2692
# ACKR1; EPHB4; HDAC9; VWF; CCL23; C7; LIFR; PTPRB; SLCO2A1; RAMP3                  2506
# PDGFRB; LAMC3; CSPG4; TRPC6; COX4I2; HIGD1B; BGN; NDUFA4L2; PTN; EGFL6            2406
# CCL21; MMRN1; PROX1; LYVE1; PPFIBP1; GNG11; SNCG; AKAP12; NRP2; PKHD1L1           2239
# BANK1; MS4A1; CD19; BACH2; IGHM; EBF1; CD79A; BLK; PAX5; CD79B                    2174
# LYZ; LTF; LPO; PRB3; PRR4; PRB1; AC020656.1; PRB4; PIP; PRH2                      2147
# SCGB3A2; MGP; SOX4; KLK11; TMEM45A; CTSE                                          2014
# DKK2; GJA5; BMX; IGFBP3; FAM107A; MT1A; PTPRB; CLEC14A; LDB2; SRPX                1929
# ITGBL1; FGF18; PDGFRA; ASPN; CCN5; COL3A1; PRELP; DPT; LTBP2; COL1A2              1793
# RSPH1; CDHR3; FOXJ1; CDHR4; CAPS; C20orf85; C9orf24; TMEM190; TPPP3; C1orf194     1785
# ACKR1; COL15A1; VWA1; ABCB1; CCL14; PLVAP; AQP1; VWF; TSPAN7; ECSCR               1742
# NKG7; KLRD1; KLRC1; NCAM1; GNLY; GZMB; CCL4; PRF1; CD247; CCL5                    1557
# SCGB1A1; BPIFB1; LCN2; TSPAN8; SCUBE2; SAA2; CCL20; CP; TMEM45A; MMP7             1317
# MFAP5; SCARA5; CDON; DCN; PLA2G2A; SFRP2; LUM; ADH1B; COL1A2; LAMA2               1206
# NaN                                                                               1165
# CD8A; CD3E; CD8B; CCL5; NKG7; GZMA; GZMH; IL32; CD3D; CCL4                         741
# F13A1; STAB1; FOLR2; SLC40A1; CD163L1; MERTK; GPR183; FPR3; C9                     513
# TPSB2; TPSAB1; MS4A2; CPA3; HPGDS; RGS1; VWA5A; LTC4S; KIT; RHEX                   481
# DES; LGR6; BCHE; PLN; ASPN; PRUNE2; HSPB7; GREM2; TYRP1; ATP1A2                    473
# UPK3B; CALB2; WT1; HP; ITLN1; PLA2G2A; PRG4; TFPI2; HAS1; BCHE                     206
# KRT5; TP63; NGFR; KRT15; KRT17; MMP10; S100A2; ALDH3A1; SERPINF1; TACSTD2          184
# KRT19; SERPINB4; NOTCH3; SERPINB3; S100A2; KRT6A; AQP3; KRT5; TACSTD2; KRT13       159
# VCAN; FCN1; CD14; S100A8; JARID2; S100A12; THBS1; EREG; IL1R2; SCHLAP1             158
# FCGR3B; CSF3R; IL1B; S100A8; S100A12; G0S2; BCL2A1; BASP1; PTGS2; MNDA              91
# CD1E; CLEC10A; FCGR2B; CD1C; CCL17; FCER1A; MS4A6A; AIF1; HLA-DMB; C1QC             84
# GRP; CALCA; ASCL1; NRXN1; PCSK1N; SCG2; CHGA; SCG5; GP2; CHGB                       47
# PLD4; LILRA4; CLEC4C; GZMB; IRF7; IRF8; GPR183; TCL1A; CXCR3; CLIC3                 40
# FCGR3A; FCN1; TNFRSF8; LST1; AIF1; SMIM25; SERPINA1; LILRB2; MS4A7; CFP             33
# MUC5AC; AGR2; SPDEF; SLC4A11; PSCA; LYPD2; MUC5B; CEACAM5; CYP2F1; FCGBP            30
# CLEC9A; FLT3; ZBTB46; LGALS2; DNASE1L3; WDFY4; HLA-DOB; XCR1; CLNK; BATF3           28
# CCR7; LAD1; NCCRP1; CCL19; CCL22; CCL17; IL4I1; EBI3; SLCO5A1; CD80                 18
# IL23A; POU2F3; ASCL2; NREP; HEPACAM2; NMU; MYB; FOXI1; COLCA2; NOS2                  6
# IL2RA; FOXP3; CTLA4; TRAC; LTB; TRBC1; CD3D; TRBC2; CD2; TNFRSF4                     5
# ASCL3; FOXI1; CFTR; CEL; TMEM61; SCNN1B; BPIFA2; TFCP2L1; CLCNKB; ATP6V1G3           4
# GP1BB; ITGA2B; ITGB3; PPBP; PF4; TUBB1; ACRBP; GP9; PTCRA; CMTM5                     3
# RARRES1; MIA; ALDH1A3; KRT14; SOX9; MMP7; SAA2; PI3; STATH; CFB                      3
# Name: author_cell_type_markers, dtype: int64

# %% [markdown]
# # Check whether ENSEMBL IDs in var

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [A1BG, A1BG-AS1, A1CF, A2M, A2M-AS1, A2ML1, A2ML1-AS1, A2ML1-AS2, A3GALT2, A4GALT, A4GNT, AAAS, AACS, AADAC, AADACL2, AADACL2-AS1, AADACL3, AADACL4, AADAT, AAED1, AAGAB, AAK1, AAMDC, AAMP, AANAT, AAR2, AARD, AARS, AARS2, AARSD1, AASDH, AASDHPPT, AASS, AATBC, AATF, AATK, AB015752.1, ABALON, ABAT, ABCA1, ABCA10, ABCA12, ABCA13, ABCA2, ABCA3, ABCA4, ABCA5, ABCA6, ABCA7, ABCA8, ABCA9, ABCA9-AS1, ABCB1, ABCB10, ABCB11, ABCB4, ABCB5, ABCB6, ABCB7, ABCB8, ABCB9, ABCC1, ABCC10, ABCC11, ABCC12, ABCC2, ABCC3, ABCC4, ABCC5, ABCC5-AS1, ABCC6, ABCC8, ABCC9, ABCD1, ABCD2, ABCD3, ABCD4, ABCE1, ABCF1, ABCF2, ABCF2-1, ABCF3, ABCG1, ABCG2, ABCG4, ABCG5, ABCG8, ABHD1, ABHD10, ABHD11, ABHD12, ABHD12B, ABHD13, ABHD14A, ABHD14A-ACY1, ABHD14B, ABHD15, ABHD15-AS1, ABHD16A, ABHD16B, ...]
#
# [38224 rows x 0 columns]

# %%
adata.var['gene_symbol'] = adata.var.index
adata.var.index.name = 'index'
adata.var['ensembl_id'] = adata.var['gene_symbol'].map(gene_symbol_to_ensembl_id)

adata.var
# Out:
#                gene_symbol       ensembl_id
# index
# A1BG                  A1BG  ENSG00000121410
# A1BG-AS1          A1BG-AS1  ENSG00000268895
# A1CF                  A1CF  ENSG00000148584
# A2M                    A2M  ENSG00000175899
# A2M-AS1            A2M-AS1  ENSG00000245105
# ...                    ...              ...
# ZYG11B              ZYG11B  ENSG00000162378
# ZYX                    ZYX  ENSG00000159840
# ZZEF1                ZZEF1  ENSG00000074755
# hsa-mir-1253  hsa-mir-1253  ENSG00000272920
# hsa-mir-423    hsa-mir-423  ENSG00000266919
#
# [38224 rows x 2 columns]

# %% [markdown]
# # Check raw data

# %%
import pandas as pd

# Make specific columns numeric
adata.obs['cell_viability_percentage'] = pd.to_numeric(
    adata.obs['cell_viability_percentage'], errors='coerce'
)
adata.obs['cell_number_loaded'] = pd.to_numeric(
    adata.obs['cell_number_loaded'], errors='coerce'
)
adata.obs['sample_collection_year'] = pd.to_numeric(
    adata.obs['sample_collection_year'], errors='coerce'
)

numeric_cols = [
    'nCount_RNA', 'nFeature_RNA', 'percent.mito', 'scrublet_score',
    'cxds_score', 'bcds_score', 'hybrid_score', 'S.Score', 'G2M.Score',
    'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.6', 'seurat_clusters',
    'orig_cluster', 'predicted.lineage_level1.score',
    'predicted.lineage_level2.score', 'predicted.celltype_level1.score',
    'predicted.celltype_level2.score', 'predicted.celltype_level3.score'
]
for col in numeric_cols:
    adata.obs[col] = pd.to_numeric(adata.obs[col], errors='coerce')

bool_cols = ['scrublet_call', 'cxds_call', 'bcds_call', 'hybrid_call']
for col in bool_cols:
    adata.obs[col] = adata.obs[col].astype('bool')

# Make df indices str
adata.obs.index = adata.obs.index.astype(str)
adata.var.index = adata.var.index.astype(str)
adata.var_names = adata.var_names.astype(str)

# %%
adata.uns[MARKER_GENES] = adata.uns[MARKER_GENES].astype(str)

# %%
adata.X.toarray().max()
# Out:
# 47908

# %%
adata.X = adata.X.astype(np.int64)

# %%
adata.raw = adata

# %%
adata.X
# Out:
# <80430x38224 sparse matrix of type '<class 'numpy.int64'>'
# 	with 146200515 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <80430x38224 sparse matrix of type '<class 'numpy.int64'>'
# 	with 146200515 stored elements in Compressed Sparse Row format>

# %%
adata.X.toarray().max()
# Out:
# 47908

# %%
adata.raw.X.toarray().max()
# Out:
# 47908

# %% [markdown]
# ## Validation result
#
# ### UNS Validation
# - OK: Tier 1 UNS Google Sheet
# - OK: Tier 1 UNS AnnData Object
#
# ### OBS Validation
# - OK
# - OK

# %% [markdown]
# # Data Submission Status
#
# - CHECK: Raw counts in X and in raw
# - CHECK: Tier 1 Metadata in OBS
# - CHECK: Cell Ontology IDs in OBS
# - CHECK: Author cell type in OBS
# - CHECK: Marker genes in UNS
# - CHECK: ENSEMBL IDs in var
#
# ### Revision:
#
# DONE

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"))
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"))
