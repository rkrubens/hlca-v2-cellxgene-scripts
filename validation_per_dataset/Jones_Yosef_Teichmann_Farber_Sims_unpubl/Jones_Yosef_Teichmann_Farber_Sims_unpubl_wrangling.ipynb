# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import anndata2ri
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"
# Out:
# Warning message:
# package ‘methods’ was built under R version 4.3.3
# During startup - Warning messages:
# 1: package ‘datasets’ was built under R version 4.3.3
# 2: package ‘utils’ was built under R version 4.3.3
# 3: package ‘grDevices’ was built under R version 4.3.3
# 4: package ‘graphics’ was built under R version 4.3.3
# 5: package ‘stats’ was built under R version 4.3.3

# %%
DATASET_ID = "Jones_Yosef_Teichmann_Farber_Sims_unpubl"
H5AD_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/LNG_BAL.h5ad"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
# Name constants
AUTHOR_CELL_TYPE_L0 = 'author_cell_type_level_0'
AUTHOR_CELL_TYPE_L1 = 'author_cell_type_level_1'

CELL_TYPE_ONTOLOGY_ID_L0 = 'cell_type_ontology_term_id_level_0'
CELL_TYPE_ONTOLOGY_ID_L1 = 'cell_type_ontology_term_id_level_1'

CELL_TYPE_ONTOLOGY_LABEL_L0 = 'cell_type_ontology_term_label_level_0'
CELL_TYPE_ONTOLOGY_LABEL_L1 = 'cell_type_ontology_term_label_level_1'

AUTHOR_CELL_TYPE_DESCRIPTION_L0 = 'author_cell_type_description_level_0'
AUTHOR_CELL_TYPE_DESCRIPTION_L1 = 'author_cell_type_description_level_1'

MARKER_GENES_L0 = 'author_cell_type_markers_level_0'
MARKER_GENES_L1 = 'author_cell_type_markers_level_1'

# Finest grained annotation will be generic dataset cell type
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'
CELL_TYPE_ONTOLOGY_LABEL = 'cell_type_ontology_term_label'
MARKER_GENES = 'author_cell_type_markers'
AUTHOR_CELL_TYPE_DESCRIPTION = 'author_cell_type_description'

# %% [markdown]
# # Load data

# %%
adata = sc.read_h5ad(H5AD_PATH)
obs = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "obs")
uns = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "uns")

# %%
adata.obsm['IA_citeseq']
# Out:
#                                          CD29  CD158_KIR2DL1S1S3S5      CD13  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14     2.865287             0.938573  2.229138
# ATTGGTGCAGGACCCT-1_CZINY-0296-7      3.150692             1.108785  0.000000
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  1.346032             0.745392  0.000000
# GTACTCCTCATGTCCC-1_CZINY-0415-14     2.821273             1.163267  0.906886
# CTCGAGGAGCAAATCA-1_CZINY-0718-5      0.760329             1.295633  1.778761
# ...                                       ...                  ...       ...
# CTACACCTCCAACCAA-1_CZINY-0533-11     1.358824             0.000000  1.603847
# AACACGTGTAAGCACG-1_CZINY-0289-0      2.002050             0.754334  0.895048
# GAATGAAAGGCGCTCT-1_CZINY-0521-0      2.931868             1.124898  1.681039
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      0.000000             3.556541  0.000000
# ACGTCAAAGACTCGGA-1_CZINY-0527-6      2.854753             0.600938  3.167956
#
#                                          CD26     CD328      CD24      CD81  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14     1.445073  0.497841  0.814310  1.591212
# ATTGGTGCAGGACCCT-1_CZINY-0296-7      1.741231  2.636025  1.624155  1.576952
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  2.907756  1.000948  0.598141  0.494489
# GTACTCCTCATGTCCC-1_CZINY-0415-14     1.338294  0.000000  0.000000  1.078555
# CTCGAGGAGCAAATCA-1_CZINY-0718-5      2.025420  0.000000  0.617703  1.056568
# ...                                       ...       ...       ...       ...
# CTACACCTCCAACCAA-1_CZINY-0533-11     0.609587  0.000000  1.820306  1.088400
# AACACGTGTAAGCACG-1_CZINY-0289-0      1.095168  1.338161  1.421913  1.103527
# GAATGAAAGGCGCTCT-1_CZINY-0521-0      1.662697  0.895162  1.127001  1.422002
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      0.000000  1.154812  0.000000  0.701526
# ACGTCAAAGACTCGGA-1_CZINY-0527-6      0.983469  0.878421  1.082575  1.665083
#
#                                      CD335_NKp46     CD267      CD64  ...  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14        1.222092  0.924770  0.767056  ...
# ATTGGTGCAGGACCCT-1_CZINY-0296-7         0.806773  1.134909  0.000000  ...
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0     0.479987  0.587279  0.000000  ...
# GTACTCCTCATGTCCC-1_CZINY-0415-14        1.624472  0.432306  1.212327  ...
# CTCGAGGAGCAAATCA-1_CZINY-0718-5         1.194696  1.630790  0.000000  ...
# ...                                          ...       ...       ...  ...
# CTACACCTCCAACCAA-1_CZINY-0533-11        1.401133  1.041646  0.837987  ...
# AACACGTGTAAGCACG-1_CZINY-0289-0         1.491194  1.126372  0.000000  ...
# GAATGAAAGGCGCTCT-1_CZINY-0521-0         0.962425  1.108449  1.845154  ...
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2         0.000000  0.000000  0.696846  ...
# ACGTCAAAGACTCGGA-1_CZINY-0527-6         0.797643  0.796747  0.809453  ...
#
#                                         CD163   HLA_ABC   CLEC12A      CD25  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14     3.207902  0.805624  2.166313  0.735361
# ATTGGTGCAGGACCCT-1_CZINY-0296-7      2.227445  1.610850  0.000000  1.447411
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  0.465401  0.811864  1.242215  0.277549
# GTACTCCTCATGTCCC-1_CZINY-0415-14     0.000000  1.178647  0.000000  0.564379
# CTCGAGGAGCAAATCA-1_CZINY-0718-5      2.385144  0.589961  1.195846  0.497666
# ...                                       ...       ...       ...       ...
# CTACACCTCCAACCAA-1_CZINY-0533-11     1.248043  0.931391  0.000000  1.320854
# AACACGTGTAAGCACG-1_CZINY-0289-0      1.987500  1.035060  0.000000  0.884831
# GAATGAAAGGCGCTCT-1_CZINY-0521-0      2.962512  0.651585  0.540787  0.621478
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      0.000000  1.239386  0.000000  0.000000
# ACGTCAAAGACTCGGA-1_CZINY-0527-6      2.422799  1.477438  2.216927  0.746434
#
#                                         TIGIT     GPR56  CD272_BTLA     CD161  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14     1.131723  1.262107    1.249455  0.767000
# ATTGGTGCAGGACCCT-1_CZINY-0296-7      1.202476  0.000000    1.587987  1.370273
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  0.730812  0.000000    0.718137  0.970610
# GTACTCCTCATGTCCC-1_CZINY-0415-14     0.987174  2.744332    0.692202  1.262532
# CTCGAGGAGCAAATCA-1_CZINY-0718-5      0.572293  0.772411    1.350455  0.614312
# ...                                       ...       ...         ...       ...
# CTACACCTCCAACCAA-1_CZINY-0533-11     1.163974  0.722213    1.358763  0.566485
# AACACGTGTAAGCACG-1_CZINY-0289-0      1.239298  0.000000    0.944579  0.867654
# GAATGAAAGGCGCTCT-1_CZINY-0521-0      1.155079  0.715027    1.311276  1.243934
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      0.706267  1.983207    0.715932  2.056127
# ACGTCAAAGACTCGGA-1_CZINY-0527-6      0.862392  1.061218    0.840315  1.248840
#
#                                          CD71  Ig_light_chain_kappa
# CGAATGTCAATAAGCA-1_CZINY-0536-14     3.413924              1.687741
# ATTGGTGCAGGACCCT-1_CZINY-0296-7      3.223774              2.652998
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  2.144278              0.635351
# GTACTCCTCATGTCCC-1_CZINY-0415-14     0.900506              0.820304
# CTCGAGGAGCAAATCA-1_CZINY-0718-5      4.233798              1.091276
# ...                                       ...                   ...
# CTACACCTCCAACCAA-1_CZINY-0533-11     0.904706              3.839344
# AACACGTGTAAGCACG-1_CZINY-0289-0      1.410110              1.834831
# GAATGAAAGGCGCTCT-1_CZINY-0521-0      1.822557              2.619655
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      0.692224              1.401790
# ACGTCAAAGACTCGGA-1_CZINY-0527-6      1.352130              3.300667
#
# [213154 rows x 127 columns]

# %% [markdown]
# # Validate obs and uns from Tier 1 Metadata Template

# %%
val_workflow = ValidationWorkflow(
    input = uns,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                                                title  \
# 0  LNG samples from donors 637C, 640C, D496 and D...
#
#                                             study_PI   batch_condition  \
# 0  Jo Jones, Sarah Teichmann, Donna Farber, Peter...  donor, chemistry
#
#   default_embedding                              unpublished  \
# 0            X_umap  UNPUBLISHED data, please do not release
#
#                                             comments
# 0  Lung tissue was collected from Both University...

# %%
val_workflow = ValidationWorkflow(
    input = obs,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation workflow successful. Returning OBS dataframe.
#    sample_ID donor_id                        protocol_URL  \
# 0   583B_LNG     583B  doi:10.17504/protocols.io.bz4qp8vw
# 1   591C_LNG     591C  doi:10.17504/protocols.io.bz4qp8vw
# 2   637C_LNG     637C  doi:10.17504/protocols.io.bz4qp8vw
# 3   640C_LNG     640C  doi:10.17504/protocols.io.bz4qp8vw
# 4   689C_LNG     689C  doi:10.17504/protocols.io.bz4qp8vw
# 5   768B_LNG     768B  doi:10.17504/protocols.io.bz4qp8vw
# 6   778C_LNG     778C  doi:10.17504/protocols.io.bz4qp8vw
# 7   D496_LNG     D496  doi:10.17504/protocols.io.bwr9pd96
# 8   D533_LNG     D533  doi:10.17504/protocols.io.bwr9pd96
# 9   D503_BAL     D503  doi:10.17504/protocols.io.bwrjpd4n
# 10  D512_BAL     D512  doi:10.17504/protocols.io.bwrjpd4n
# 11  D520_BAL     D520  doi:10.17504/protocols.io.bwrjpd4n
# 12  D523_BAL     D523  doi:10.17504/protocols.io.bwrjpd4n
# 13  D528_BAL     D528  doi:10.17504/protocols.io.bwrjpd4n
# 14  D529_BAL     D529  doi:10.17504/protocols.io.bwrjpd4n
# 15  D534_BAL     D534  doi:10.17504/protocols.io.bwrjpd4n
# 16  D543_BAL     D543  doi:10.17504/protocols.io.bwrjpd4n
# 17  D564_BAL     D564  doi:10.17504/protocols.io.bwrjpd4n
# 18  D570_BAL     D570  doi:10.17504/protocols.io.bwrjpd4n
# 19  D503_LNG     D503  doi:10.17504/protocols.io.bwr9pd96
# 20  D512_LNG     D512  doi:10.17504/protocols.io.bwr9pd96
# 21  D520_LNG     D520  doi:10.17504/protocols.io.bwr9pd96
# 22  D523_LNG     D523  doi:10.17504/protocols.io.bwr9pd96
# 23  D528_LNG     D528  doi:10.17504/protocols.io.bwr9pd96
# 24  D529_LNG     D529  doi:10.17504/protocols.io.bwr9pd96
# 25  D534_LNG     D534  doi:10.17504/protocols.io.bwr9pd96
# 26  D543_LNG     D543  doi:10.17504/protocols.io.bwr9pd96
# 27  D564_LNG     D564  doi:10.17504/protocols.io.bwr9pd96
# 28  D570_LNG     D570  doi:10.17504/protocols.io.bwr9pd96
#
#                             institute sample_collection_site  \
# 0         University of Cambridge, UK              IA_site_1
# 1         University of Cambridge, UK              IA_site_1
# 2         University of Cambridge, UK              IA_site_1
# 3         University of Cambridge, UK              IA_site_1
# 4         University of Cambridge, UK              IA_site_1
# 5         University of Cambridge, UK              IA_site_1
# 6         University of Cambridge, UK              IA_site_1
# 7   Columbia University, New York, US              IA_site_2
# 8   Columbia University, New York, US              IA_site_2
# 9   Columbia University, New York, US              IA_site_2
# 10  Columbia University, New York, US              IA_site_2
# 11  Columbia University, New York, US              IA_site_2
# 12  Columbia University, New York, US              IA_site_2
# 13  Columbia University, New York, US              IA_site_2
# 14  Columbia University, New York, US              IA_site_2
# 15  Columbia University, New York, US              IA_site_2
# 16  Columbia University, New York, US              IA_site_2
# 17  Columbia University, New York, US              IA_site_2
# 18  Columbia University, New York, US              IA_site_2
# 19  Columbia University, New York, US              IA_site_2
# 20  Columbia University, New York, US              IA_site_2
# 21  Columbia University, New York, US              IA_site_2
# 22  Columbia University, New York, US              IA_site_2
# 23  Columbia University, New York, US              IA_site_2
# 24  Columbia University, New York, US              IA_site_2
# 25  Columbia University, New York, US              IA_site_2
# 26  Columbia University, New York, US              IA_site_2
# 27  Columbia University, New York, US              IA_site_2
# 28  Columbia University, New York, US              IA_site_2
#
#    sample_collection_relative_time_point  \
# 0                                    N/A
# 1                                    N/A
# 2                                    N/A
# 3                                    N/A
# 4                                    N/A
# 5                                    N/A
# 6                                    N/A
# 7                                    N/A
# 8                                    N/A
# 9                                    N/A
# 10                                   N/A
# 11                                   N/A
# 12                                   N/A
# 13                                   N/A
# 14                                   N/A
# 15                                   N/A
# 16                                   N/A
# 17                                   N/A
# 18                                   N/A
# 19                                   N/A
# 20                                   N/A
# 21                                   N/A
# 22                                   N/A
# 23                                   N/A
# 24                                   N/A
# 25                                   N/A
# 26                                   N/A
# 27                                   N/A
# 28                                   N/A
#
#                                            library_ID library_ID_repository  \
# 0                                       CZI-IA9924325          E-MTAB-11536
# 1   CZI-IA10034920,CZI-IA10034921,CZI-IA10034922,C...          E-MTAB-11536
# 2                                      CZI-IA10466285          E-MTAB-11536
# 3        CZI-IA10471911,CZI-IA10471912,CZI-IA10471913          E-MTAB-11536
# 4                       CZI-IA11485685,CZI-IA11485686            Not public
# 5   CZI-IA13073099,CZI-IA13073100,CZI-IA13073101,C...            Not public
# 6   CZI-IA13003091,CZI-IA13003092,CZI-IA13003093,C...            Not public
# 7   CZINY-0097,CZINY-0098,CZINY-0099,CZINY-0100,CZ...          E-MTAB-11536
# 8   CZINY-0481,CZINY-0482,CZINY-0483,CZINY-0484,CZ...            Not public
# 9   CZINY-0049,CZINY-0050,CZINY-0051,CZINY-0052,CZ...            Not public
# 10  CZINY-0161,CZINY-0162,CZINY-0163,CZINY-0164,CZ...            Not public
# 11  CZINY-0225,CZINY-0226,CZINY-0227,CZINY-0228,CZ...            Not public
# 12  CZINY-0289,CZINY-0290,CZINY-0291,CZINY-0292,CZ...            Not public
# 13  CZINY-0337,CZINY-0338,CZINY-0339,CZINY-0340,CZ...            Not public
# 14  CZINY-0401,CZINY-0402,CZINY-0403,CZINY-0404,CZ...            Not public
# 15  CZINY-0521,CZINY-0522,CZINY-0523,CZINY-0524,CZ...            Not public
# 16  CZINY-0585,CZINY-0586,CZINY-0587,CZINY-0588,CZ...            Not public
# 17  CZINY-0649,CZINY-0650,CZINY-0651,CZINY-0652,CZ...            Not public
# 18  CZINY-0713,CZINY-0714,CZINY-0715,CZINY-0716,CZ...            Not public
# 19  CZINY-0049,CZINY-0050,CZINY-0051,CZINY-0052,CZ...          E-MTAB-11536
# 20  CZINY-0161,CZINY-0162,CZINY-0163,CZINY-0164,CZ...            Not public
# 21  CZINY-0225,CZINY-0226,CZINY-0227,CZINY-0228,CZ...            Not public
# 22  CZINY-0289,CZINY-0290,CZINY-0291,CZINY-0292,CZ...            Not public
# 23  CZINY-0337,CZINY-0338,CZINY-0339,CZINY-0340,CZ...            Not public
# 24  CZINY-0401,CZINY-0402,CZINY-0403,CZINY-0404,CZ...            Not public
# 25  CZINY-0521,CZINY-0522,CZINY-0523,CZINY-0524,CZ...            Not public
# 26  CZINY-0585,CZINY-0586,CZINY-0587,CZINY-0588,CZ...            Not public
# 27  CZINY-0649,CZINY-0650,CZINY-0651,CZINY-0652,CZ...            Not public
# 28  CZINY-0713,CZINY-0714,CZINY-0715,CZINY-0716,CZ...            Not public
#
#    author_batch_notes organism_ontology_term_id  ...  sequenced_fragment  \
# 0                 N/A            NCBITaxon:9606  ...         5 prime tag
# 1                 N/A            NCBITaxon:9606  ...         5 prime tag
# 2                 N/A            NCBITaxon:9606  ...         5 prime tag
# 3                 N/A            NCBITaxon:9606  ...         5 prime tag
# 4                 N/A            NCBITaxon:9606  ...         5 prime tag
# 5                 N/A            NCBITaxon:9606  ...         5 prime tag
# 6                 N/A            NCBITaxon:9606  ...         5 prime tag
# 7                 N/A            NCBITaxon:9606  ...         3 prime tag
# 8                 N/A            NCBITaxon:9606  ...         5 prime tag
# 9                 N/A            NCBITaxon:9606  ...         3 prime tag
# 10                N/A            NCBITaxon:9606  ...         5 prime tag
# 11                N/A            NCBITaxon:9606  ...         5 prime tag
# 12                N/A            NCBITaxon:9606  ...         5 prime tag
# 13                N/A            NCBITaxon:9606  ...         5 prime tag
# 14                N/A            NCBITaxon:9606  ...         5 prime tag
# 15                N/A            NCBITaxon:9606  ...         5 prime tag
# 16                N/A            NCBITaxon:9606  ...         5 prime tag
# 17                N/A            NCBITaxon:9606  ...         5 prime tag
# 18                N/A            NCBITaxon:9606  ...         5 prime tag
# 19                N/A            NCBITaxon:9606  ...         3 prime tag
# 20                N/A            NCBITaxon:9606  ...         5 prime tag
# 21                N/A            NCBITaxon:9606  ...         5 prime tag
# 22                N/A            NCBITaxon:9606  ...         5 prime tag
# 23                N/A            NCBITaxon:9606  ...         5 prime tag
# 24                N/A            NCBITaxon:9606  ...         5 prime tag
# 25                N/A            NCBITaxon:9606  ...         5 prime tag
# 26                N/A            NCBITaxon:9606  ...         5 prime tag
# 27                N/A            NCBITaxon:9606  ...         5 prime tag
# 28                N/A            NCBITaxon:9606  ...         5 prime tag
#
#    sequencing_platform is_primary_data reference_genome  \
# 0          EFO_0008637            true           GRCh38
# 1          EFO_0008637            true           GRCh38
# 2          EFO_0008637            true           GRCh38
# 3          EFO_0008637            true           GRCh38
# 4          EFO_0008637            true           GRCh38
# 5          EFO_0008637            true           GRCh38
# 6          EFO_0008637            true           GRCh38
# 7                  N/A            true           GRCh38
# 8                  N/A            true           GRCh38
# 9                  N/A            true           GRCh38
# 10                 N/A            true           GRCh38
# 11                 N/A            true           GRCh38
# 12                 N/A            true           GRCh38
# 13                 N/A            true           GRCh38
# 14                 N/A            true           GRCh38
# 15                 N/A            true           GRCh38
# 16                 N/A            true           GRCh38
# 17                 N/A            true           GRCh38
# 18                 N/A            true           GRCh38
# 19                 N/A            true           GRCh38
# 20                 N/A            true           GRCh38
# 21                 N/A            true           GRCh38
# 22                 N/A            true           GRCh38
# 23                 N/A            true           GRCh38
# 24                 N/A            true           GRCh38
# 25                 N/A            true           GRCh38
# 26                 N/A            true           GRCh38
# 27                 N/A            true           GRCh38
# 28                 N/A            true           GRCh38
#
#    gene_annotation_version alignment_software intron_inclusion  \
# 0                      N/A  cell ranger 6.0.0              yes
# 1                      N/A  cell ranger 6.0.0              yes
# 2                      N/A  cell ranger 6.0.0              yes
# 3                      N/A  cell ranger 6.0.0              yes
# 4                      N/A  cell ranger 6.0.0              yes
# 5                      N/A  cell ranger 6.0.0              yes
# 6                      N/A  cell ranger 6.0.0              yes
# 7                      N/A  cell ranger 6.0.0              yes
# 8                      N/A  cell ranger 6.0.0              yes
# 9                      N/A  cell ranger 6.0.0              yes
# 10                     N/A  cell ranger 6.0.0              yes
# 11                     N/A  cell ranger 6.0.0              yes
# 12                     N/A  cell ranger 6.0.0              yes
# 13                     N/A  cell ranger 6.0.0              yes
# 14                     N/A  cell ranger 6.0.0              yes
# 15                     N/A  cell ranger 6.0.0              yes
# 16                     N/A  cell ranger 6.0.0              yes
# 17                     N/A  cell ranger 6.0.0              yes
# 18                     N/A  cell ranger 6.0.0              yes
# 19                     N/A  cell ranger 6.0.0              yes
# 20                     N/A  cell ranger 6.0.0              yes
# 21                     N/A  cell ranger 6.0.0              yes
# 22                     N/A  cell ranger 6.0.0              yes
# 23                     N/A  cell ranger 6.0.0              yes
# 24                     N/A  cell ranger 6.0.0              yes
# 25                     N/A  cell ranger 6.0.0              yes
# 26                     N/A  cell ranger 6.0.0              yes
# 27                     N/A  cell ranger 6.0.0              yes
# 28                     N/A  cell ranger 6.0.0              yes
#
#    disease_ontology_term_id self_reported_ethnicity_ontology_term_id  \
# 0              PATO:0000461                                    White
# 1              PATO:0000461                                    White
# 2              PATO:0000461                                    White
# 3              PATO:0000461                                    White
# 4              PATO:0000461                                    White
# 5              PATO:0000461                                  Unknown
# 6              PATO:0000461                                  Unknown
# 7              PATO:0000461                                 Hispanic
# 8              PATO:0000461                                    Asian
# 9              PATO:0000461                                    White
# 10             PATO:0000461                                 Hispanic
# 11             PATO:0000461                           Middle Eastern
# 12             PATO:0000461                                 Hispanic
# 13             PATO:0000461                                    Black
# 14             PATO:0000461                                 Hispanic
# 15             PATO:0000461                                    White
# 16             PATO:0000461                                 Hispanic
# 17             PATO:0000461                                    White
# 18             PATO:0000461                                    White
# 19             PATO:0000461                                    White
# 20             PATO:0000461                                 Hispanic
# 21             PATO:0000461                           Middle Eastern
# 22             PATO:0000461                                 Hispanic
# 23             PATO:0000461                                    Black
# 24             PATO:0000461                                 Hispanic
# 25             PATO:0000461                                    White
# 26             PATO:0000461                                 Hispanic
# 27             PATO:0000461                                    White
# 28             PATO:0000461                                    White
#
#    development_stage_ontology_term_id
# 0                      HsapDv:0000237
# 1                      HsapDv:0000238
# 2                      HsapDv:0000240
# 3                      HsapDv:0000242
# 4                      HsapDv:0000239
# 5                      HsapDv:0000237
# 6                      HsapDv:0000240
# 7                      HsapDv:0000240
# 8                      HsapDv:0000242
# 9                      HsapDv:0000241
# 10                     HsapDv:0000237
# 11                     HsapDv:0000237
# 12                     HsapDv:0000237
# 13                     HsapDv:0000241
# 14                     HsapDv:0000241
# 15                     HsapDv:0000238
# 16                     HsapDv:0000237
# 17                     HsapDv:0000239
# 18                     HsapDv:0000242
# 19                     HsapDv:0000241
# 20                     HsapDv:0000237
# 21                     HsapDv:0000237
# 22                     HsapDv:0000237
# 23                     HsapDv:0000241
# 24                     HsapDv:0000241
# 25                     HsapDv:0000238
# 26                     HsapDv:0000237
# 27                     HsapDv:0000239
# 28                     HsapDv:0000242
#
# [29 rows x 37 columns]

# %% [markdown]
# # Validate obs and uns from adata

# %%
merger = AnnDataMerger(
    adata = adata,
    uns_df = uns
)

adata_merged = merger.add_uns_metadata()

adata_merged.uns.keys()
# Out:
# dict_keys(['gross_annotation_colors', 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments'])

# %%
# Create sample_id in anndata for unique matching
adata.obs['sample_id'] = adata.obs['donor'].astype(str) + "_" + adata.obs['tissue'].astype(str)

adata.obs
# Out:
#                                      n_genes  n_genes_by_counts  total_counts  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14        4809               4809       24285.0
# ATTGGTGCAGGACCCT-1_CZINY-0296-7         1651               1651        3246.0
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0     1708               1708        4865.0
# GTACTCCTCATGTCCC-1_CZINY-0415-14        1323               1323        2611.0
# CTCGAGGAGCAAATCA-1_CZINY-0718-5          622                622        1470.0
# ...                                      ...                ...           ...
# CTACACCTCCAACCAA-1_CZINY-0533-11        1786               1786        4039.0
# AACACGTGTAAGCACG-1_CZINY-0289-0         1387               1387        3420.0
# GAATGAAAGGCGCTCT-1_CZINY-0521-0         4026               4026       17359.0
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2         2270               2270        5138.0
# ACGTCAAAGACTCGGA-1_CZINY-0527-6         3320               3320       11283.0
#
#                                             library donor site     sex  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14         CZINY-0536  D534   NY    Male
# ATTGGTGCAGGACCCT-1_CZINY-0296-7          CZINY-0296  D523   NY  Female
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  CZI-IA10034924  591C   UK    Male
# GTACTCCTCATGTCCC-1_CZINY-0415-14         CZINY-0415  D529   NY  Female
# CTCGAGGAGCAAATCA-1_CZINY-0718-5          CZINY-0718  D570   NY    Male
# ...                                             ...   ...  ...     ...
# CTACACCTCCAACCAA-1_CZINY-0533-11         CZINY-0533  D534   NY    Male
# AACACGTGTAAGCACG-1_CZINY-0289-0          CZINY-0289  D523   NY  Female
# GAATGAAAGGCGCTCT-1_CZINY-0521-0          CZINY-0521  D534   NY    Male
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2          CZINY-0051  D503   NY  Female
# ACGTCAAAGACTCGGA-1_CZINY-0527-6          CZINY-0527  D534   NY    Male
#
#                                          sample chemistry tissue batch  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14     D534-BAL-1      5'v2    BAL   166
# ATTGGTGCAGGACCCT-1_CZINY-0296-7      D523-LNG-1      5'v2    LNG   135
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  591C-LNG-3      5'v2    LNG    17
# GTACTCCTCATGTCCC-1_CZINY-0415-14     D529-LNG-1      5'v2    LNG   154
# CTCGAGGAGCAAATCA-1_CZINY-0718-5      D570-LNG-1      5'v2    LNG   202
# ...                                         ...       ...    ...   ...
# CTACACCTCCAACCAA-1_CZINY-0533-11     D534-BAL-1      5'v2    BAL   166
# AACACGTGTAAGCACG-1_CZINY-0289-0      D523-BAL-1      5'v2    BAL   128
# GAATGAAAGGCGCTCT-1_CZINY-0521-0      D534-BAL-1      5'v2    BAL   166
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      D503-BAL-1      3'v3    BAL   102
# ACGTCAAAGACTCGGA-1_CZINY-0527-6      D534-LNG-1      5'v2    LNG   173
#
#                                     MMoCHi_annotation  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14           macrophage
# ATTGGTGCAGGACCCT-1_CZINY-0296-7            macrophage
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0           cd4_tem
# GTACTCCTCATGTCCC-1_CZINY-0415-14           nk_cd56dim
# CTCGAGGAGCAAATCA-1_CZINY-0718-5            macrophage
# ...                                               ...
# CTACACCTCCAACCAA-1_CZINY-0533-11              b_naive
# AACACGTGTAAGCACG-1_CZINY-0289-0              b_memory
# GAATGAAAGGCGCTCT-1_CZINY-0521-0            macrophage
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2            nk_cd56dim
# ACGTCAAAGACTCGGA-1_CZINY-0527-6            macrophage
#
#                                                                          Cell_ontology  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14                                            macrophage
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                                             macrophage
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0    effector memory CD4-positive, alpha-beta T cell
# GTACTCCTCATGTCCC-1_CZINY-0415-14     CD16-positive, CD56-dim natural killer cell, h...
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                                             macrophage
# ...                                                                                ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                                          naive b cell
# AACACGTGTAAGCACG-1_CZINY-0289-0                                          memory b cell
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                                             macrophage
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      CD16-positive, CD56-dim natural killer cell, h...
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                                             macrophage
#
#                                     gross_annotation       cmv   ages  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14                   m  positive     33
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                    m  positive     20
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0                t  positive  35-39
# GTACTCCTCATGTCCC-1_CZINY-0415-14              nk_ilc  positive     68
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                    m  positive     73
# ...                                              ...       ...    ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                   b  positive     33
# AACACGTGTAAGCACG-1_CZINY-0289-0                    b  positive     20
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                    m  positive     33
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2               nk_ilc  positive     67
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                    m  positive     33
#
#                                     sample_id
# CGAATGTCAATAAGCA-1_CZINY-0536-14     D534_BAL
# ATTGGTGCAGGACCCT-1_CZINY-0296-7      D523_LNG
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  591C_LNG
# GTACTCCTCATGTCCC-1_CZINY-0415-14     D529_LNG
# CTCGAGGAGCAAATCA-1_CZINY-0718-5      D570_LNG
# ...                                       ...
# CTACACCTCCAACCAA-1_CZINY-0533-11     D534_BAL
# AACACGTGTAAGCACG-1_CZINY-0289-0      D523_BAL
# GAATGAAAGGCGCTCT-1_CZINY-0521-0      D534_BAL
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      D503_BAL
# ACGTCAAAGACTCGGA-1_CZINY-0527-6      D534_LNG
#
# [213154 rows x 17 columns]

# %%
merger = AnnDataMerger(
    adata = adata,
    obs_df = obs
)

adata_merged = merger.add_obs_metadata(
    adata_col = 'sample_id',
    df_col = 'sample_ID',
    skip = None
)

adata_merged.obs
# Out:
#                                      n_genes  n_genes_by_counts  total_counts  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14        4809               4809       24285.0
# ATTGGTGCAGGACCCT-1_CZINY-0296-7         1651               1651        3246.0
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0     1708               1708        4865.0
# GTACTCCTCATGTCCC-1_CZINY-0415-14        1323               1323        2611.0
# CTCGAGGAGCAAATCA-1_CZINY-0718-5          622                622        1470.0
# ...                                      ...                ...           ...
# CTACACCTCCAACCAA-1_CZINY-0533-11        1786               1786        4039.0
# AACACGTGTAAGCACG-1_CZINY-0289-0         1387               1387        3420.0
# GAATGAAAGGCGCTCT-1_CZINY-0521-0         4026               4026       17359.0
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2         2270               2270        5138.0
# ACGTCAAAGACTCGGA-1_CZINY-0527-6         3320               3320       11283.0
#
#                                             library donor site     sex  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14         CZINY-0536  D534   NY    Male
# ATTGGTGCAGGACCCT-1_CZINY-0296-7          CZINY-0296  D523   NY  Female
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  CZI-IA10034924  591C   UK    Male
# GTACTCCTCATGTCCC-1_CZINY-0415-14         CZINY-0415  D529   NY  Female
# CTCGAGGAGCAAATCA-1_CZINY-0718-5          CZINY-0718  D570   NY    Male
# ...                                             ...   ...  ...     ...
# CTACACCTCCAACCAA-1_CZINY-0533-11         CZINY-0533  D534   NY    Male
# AACACGTGTAAGCACG-1_CZINY-0289-0          CZINY-0289  D523   NY  Female
# GAATGAAAGGCGCTCT-1_CZINY-0521-0          CZINY-0521  D534   NY    Male
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2          CZINY-0051  D503   NY  Female
# ACGTCAAAGACTCGGA-1_CZINY-0527-6          CZINY-0527  D534   NY    Male
#
#                                          sample chemistry tissue  ...  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14     D534-BAL-1      5'v2    BAL  ...
# ATTGGTGCAGGACCCT-1_CZINY-0296-7      D523-LNG-1      5'v2    LNG  ...
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  591C-LNG-3      5'v2    LNG  ...
# GTACTCCTCATGTCCC-1_CZINY-0415-14     D529-LNG-1      5'v2    LNG  ...
# CTCGAGGAGCAAATCA-1_CZINY-0718-5      D570-LNG-1      5'v2    LNG  ...
# ...                                         ...       ...    ...  ...
# CTACACCTCCAACCAA-1_CZINY-0533-11     D534-BAL-1      5'v2    BAL  ...
# AACACGTGTAAGCACG-1_CZINY-0289-0      D523-BAL-1      5'v2    BAL  ...
# GAATGAAAGGCGCTCT-1_CZINY-0521-0      D534-BAL-1      5'v2    BAL  ...
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      D503-BAL-1      3'v3    BAL  ...
# ACGTCAAAGACTCGGA-1_CZINY-0527-6      D534-LNG-1      5'v2    LNG  ...
#
#                                     sequenced_fragment sequencing_platform  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14           5 prime tag                 N/A
# ATTGGTGCAGGACCCT-1_CZINY-0296-7            5 prime tag                 N/A
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0        5 prime tag         EFO_0008637
# GTACTCCTCATGTCCC-1_CZINY-0415-14           5 prime tag                 N/A
# CTCGAGGAGCAAATCA-1_CZINY-0718-5            5 prime tag                 N/A
# ...                                                ...                 ...
# CTACACCTCCAACCAA-1_CZINY-0533-11           5 prime tag                 N/A
# AACACGTGTAAGCACG-1_CZINY-0289-0            5 prime tag                 N/A
# GAATGAAAGGCGCTCT-1_CZINY-0521-0            5 prime tag                 N/A
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2            3 prime tag                 N/A
# ACGTCAAAGACTCGGA-1_CZINY-0527-6            5 prime tag                 N/A
#
#                                     is_primary_data reference_genome  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14               true           GRCh38
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                true           GRCh38
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0            true           GRCh38
# GTACTCCTCATGTCCC-1_CZINY-0415-14               true           GRCh38
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                true           GRCh38
# ...                                             ...              ...
# CTACACCTCCAACCAA-1_CZINY-0533-11               true           GRCh38
# AACACGTGTAAGCACG-1_CZINY-0289-0                true           GRCh38
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                true           GRCh38
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2                true           GRCh38
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                true           GRCh38
#
#                                     gene_annotation_version  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14                        N/A
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                         N/A
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0                     N/A
# GTACTCCTCATGTCCC-1_CZINY-0415-14                        N/A
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                         N/A
# ...                                                     ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                        N/A
# AACACGTGTAAGCACG-1_CZINY-0289-0                         N/A
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                         N/A
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2                         N/A
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                         N/A
#
#                                     alignment_software intron_inclusion  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14     cell ranger 6.0.0              yes
# ATTGGTGCAGGACCCT-1_CZINY-0296-7      cell ranger 6.0.0              yes
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  cell ranger 6.0.0              yes
# GTACTCCTCATGTCCC-1_CZINY-0415-14     cell ranger 6.0.0              yes
# CTCGAGGAGCAAATCA-1_CZINY-0718-5      cell ranger 6.0.0              yes
# ...                                                ...              ...
# CTACACCTCCAACCAA-1_CZINY-0533-11     cell ranger 6.0.0              yes
# AACACGTGTAAGCACG-1_CZINY-0289-0      cell ranger 6.0.0              yes
# GAATGAAAGGCGCTCT-1_CZINY-0521-0      cell ranger 6.0.0              yes
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      cell ranger 6.0.0              yes
# ACGTCAAAGACTCGGA-1_CZINY-0527-6      cell ranger 6.0.0              yes
#
#                                     disease_ontology_term_id  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14                PATO:0000461
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                 PATO:0000461
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0             PATO:0000461
# GTACTCCTCATGTCCC-1_CZINY-0415-14                PATO:0000461
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                 PATO:0000461
# ...                                                      ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                PATO:0000461
# AACACGTGTAAGCACG-1_CZINY-0289-0                 PATO:0000461
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                 PATO:0000461
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2                 PATO:0000461
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                 PATO:0000461
#
#                                     self_reported_ethnicity_ontology_term_id  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14                                       White
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                                     Hispanic
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0                                    White
# GTACTCCTCATGTCCC-1_CZINY-0415-14                                    Hispanic
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                                        White
# ...                                                                      ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                                       White
# AACACGTGTAAGCACG-1_CZINY-0289-0                                     Hispanic
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                                        White
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2                                        White
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                                        White
#
#                                     development_stage_ontology_term_id
# CGAATGTCAATAAGCA-1_CZINY-0536-14                        HsapDv:0000238
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                         HsapDv:0000237
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0                     HsapDv:0000238
# GTACTCCTCATGTCCC-1_CZINY-0415-14                        HsapDv:0000241
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                         HsapDv:0000242
# ...                                                                ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                        HsapDv:0000238
# AACACGTGTAAGCACG-1_CZINY-0289-0                         HsapDv:0000237
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                         HsapDv:0000238
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2                         HsapDv:0000241
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                         HsapDv:0000238
#
# [213154 rows x 53 columns]

# %% [markdown]
# # Add author cell type markers to UNS

# %%
marker_genes = pd.read_excel("/home/icb/raphael.kfuri-rubens/data/hlca_v2/Jones_Yosef_Teichmann_Farber_Sims_unpubl/Jones_Yosef_Teichmann_Farber_Sims_unpubl_marker_genes.xlsx")

marker_genes.drop(marker_genes.columns[0], axis=1, inplace=True)

marker_genes
# Out:
#                    Subset        Parent  \
# 0              lymphocyte           All
# 1               myelocyte           All
# 2               mast_cell           All
# 3              neutrophil           All
# 4                  mo_mac     myelocyte
# 5                      dc     myelocyte
# 6                    mpdc     myelocyte
# 7              macrophage        mo_mac
# 8      monocyte_classical        mo_mac
# 9   monocyte_nonclassical        mo_mac
# 10                    dc1            dc
# 11                    dc2            dc
# 12           dc_migratORy            dc
# 13                 t_cell    lymphocyte
# 14            b_cell_like    lymphocyte
# 15                 nk_ilc    lymphocyte
# 16                   ab_t        t_cell
# 17                   gd_t        t_cell
# 18                  cd4_t          ab_t
# 19                  cd8_t          ab_t
# 20           cd4_naive_cm         cd4_t
# 21               cd4_treg         cd4_t
# 22                 cd4_em         cd4_t
# 23              cd4_temra         cd4_t
# 24              cd4_naive  cd4_naive_cm
# 25                 cd4_cm  cd4_naive_cm
# 26                cd4_trm        cd4_em
# 27                cd4_tem        cd4_em
# 28           cd8_naive_cm         cd8_t
# 29           cd8_tem_mait         cd8_t
# 30              cd8_temra         cd8_t
# 31              cd8_naive  cd8_naive_cm
# 32                 cd8_cm  cd8_naive_cm
# 33               cd8_mait  cd8_tem_mait
# 34           cd8_not_mait  cd8_tem_mait
# 35                cd8_trm  cd8_not_mait
# 36                cd8_tem  cd8_not_mait
# 37                 b_cell   b_cell_like
# 38                 plasma   b_cell_like
# 39                    pdc   b_cell_like
# 40                b_naive        b_cell
# 41               b_memory        b_cell
# 42                   b_gc        b_cell
# 43                  b_age        b_cell
# 44            plasma_cell        plasma
# 45            plasmablast        plasma
# 46             nk_cd56dim        nk_ilc
# 47              nk_cd56br        nk_ilc
# 48                   ilc1        nk_ilc
# 49                   ilc3        nk_ilc
# 50       nk_ilc_precursor        nk_ilc
#
#                                     Positive Features  \
# 0   2 of (CD3, CD19, CD20, JCHAIN_gex, CD2_gex, LI...
# 1   1 of (CD163, CD64, OLR1_gex) OR 2 of (LAMP3_ge...
# 2                 CD33 AND 1 of (TPSB2_gex, CPA3_gex)
# 3   1 of (S100A8_gex, S100A9_gex) AND 2 of (MMP9_g...
# 4   1 of (MARCO_gex, MRC1_gex, SELENOP_gex, MERTK_...
# 5   1 of (CD1C_gex, CD1c, CLEC9A_gex, CCL19_gex, L...
# 6      2 of (LILRA4_gex, PLD4_gex, JCHAIN_gex, CD123)
# 7   1 of (C1QA_gex, C1QB_gex, C1QC_gex, MARCO_gex,...
# 8   FCN1_gex, CD33_hi AND 2 of (S100A9_gex, S100A8...
# 9   2 of (CX3CR1, MS4A7_gex, C1QA_gex, C1QB_gex, C...
# 10             1 of (XCR1_gex, CLEC9A_gex, CADM1_gex)
# 11               1 of (CLEC10A_gex, FCER1A, CD1C_gex)
# 12                         1 of (CCR7_gex, CCL19_gex)
# 13  1 of (CD3) OR 1 of (TRDV1_gex, TRDV2_gex, TRDV...
# 14  1 of (CD19, CD20, MZB1_gex, JCHAIN_gex, LILRA4...
# 15  1 of (IL7R_gex, KIT_gex, IL4I1_gex, RORC_gex, ...
# 16                            1 of (TCR_ab, TRAC_gex)
# 17  2 of (TRDC_gex, TCR_Vd2, TRDV1_gex, TRDV2_gex,...
# 18                                1 of (CD4, CD4_gex)
# 19                               1 of (CD8, CD8A_gex)
# 20                   1 of (CD62L, SELL_gex, CCR7_gex)
# 21              1 of (FOXP3_gex, IL10_gex, IKZF2_gex)
# 22  1 of (CD69, GZMA_gex, GZMB_gex, GZMK_gex, GZMH...
# 23  1 of (CD45RA) AND 1 of (CCL5_gex, FCGR3A_gex, ...
# 24                                             CD45RA
# 25                                               CD95
# 26  2 of (CD69, ITGAE_gex, CD103, ITGA1_gex, CD49a...
# 27                                                NaN
# 28                                              CD62L
# 29  1 of (CD69, CCL5_gex, GZMB_gex, GZMK_gex, GZMA...
# 30  1 of (CD45RA) AND 1 of (CCL5_gex, FCGR3A_gex, ...
# 31                                             CD45RA
# 32                      1 of (CD95, CD45RO, CCL5_gex)
# 33  3 of (TRAV1-2_gex, DPP4_gex, SLC4A10_gex, KLRB...
# 34                            1 of (TRAC_gex, TCR_ab)
# 35  1 of (CD69) OR 2 of (ITGAE_gex, CD103, ITGA1_g...
# 36                                                NaN
# 37                                  1 of (CD19, CD20)
# 38  2 of (JCHAIN_gex_hi, MZB1_gex, JCHAIN_gex, CD3...
# 39  2 of (LILRA4_gex, PLD4_gex, JCHAIN_gex, CD123,...
# 40  IgD AND 1 of (TCL1A_gex, YBX3_gex, IL4R_gex, B...
# 41  CD27_gex AND 2 of (CD27, SCIMP_gex, IGHG1_gex,...
# 42  2 of (AICDA_gex, SUGCT_gex, RGS13_gex, LMO2_ge...
# 43        2 of (CD11c, ITGAX_gex, TBX21_gex, FGR_gex)
# 44                      1 of (SDC1_gex, TNFRSF18_gex)
# 45                        1 of (MKI67_gex, TOP2A_gex)
# 46                    FCGR3A_gex, GZMB_gex, EOMES_gex
# 47         CD335_NKp46 AND 1 of (GZMK_gex, EOMES_gex)
# 48                                    1 of (NCR2_gex)
# 49      2 of (IL7R_gex, KIT_gex, IL4I1_gex, RORC_gex)
# 50                             1 of (SELL_gex, CD62L)
#
#                                     Negative Features
# 0   CD163, MRC1_gex, CD64, OLR1_gex, MPO_gex, ELAN...
# 1   CD2_gex, CD19, CD20, CD127, TPSB2_gex, CD3, MM...
# 2   MRC1_gex, OLR1_gex, CD64, CLEC9A_gex, LILRA4_g...
# 3   MRC1_gex, OLR1_gex, CLEC9A_gex, LILRA4_gex, PL...
# 4   CD1c, CD1C_gex, MPO_gex, ELANE_gex, PRSS57_gex...
# 5   MPO_gex, ELANE_gex, PRSS57_gex, CYTL1_gex, FCN...
# 6   MARCO_gex, MRC1_gex, SELENOP_gex, C1QA_gex, C1...
# 7                          FCN1_gex, CLEC12A_lo, CD99
# 8   MERTK_gex, MARCO_gex, SELENOP_gex, MS4A7_gex, ...
# 9   MARCO_gex, SELENOP_gex, SELL_gex, APOE_gex, AP...
# 10                      CLEC10A_gex, FCER1A, CD1C_gex
# 11                    XCR1_gex, CLEC9A_gex, CADM1_gex
# 12                    XCR1_gex, CLEC9A_gex, CADM1_gex
# 13  CD19, CD20, MZB1_gex, JCHAIN_gex, NCR2_gex, LI...
# 14                                      CD3, IL7R_gex
# 15  CD3, CD19, CD20, MZB1_gex, TCR_Vd2, TRDV1_gex,...
# 16  TRDC_gex, TCR_Vd2, TRDV1_gex, TRDV2_gex, TRDV3...
# 17                                             TCR_ab
# 18                                      CD8, CD8A_gex
# 19                                       CD4, CD4_gex
# 20  FOXP3_gex, IKZF2_gex, CCL5_gex, FCGR3A_gex, FG...
# 21                                    CCL5_gex, CD127
# 22                CD62L, CD45RA, FOXP3_gex, IKZF2_gex
# 23    FOXP3_gex, CD62L, SELL_gex, CCR7_gex, IKZF2_gex
# 24                                               CD95
# 25                                             CD45RA
# 26                                                NaN
# 27           CD69, CD103, CD49a, ITGA1_gex, CXCR6_gex
# 28  CCL5_gex, NKG7_gex, FCGR3A_gex, CD57, FGFBP2_g...
# 29                                      CD62L, CD45RA
# 30                          CD62L, SELL_gex, CCR7_gex
# 31                             CD95, CD45RO, CCL5_gex
# 32                                             CD45RA
# 33                                                NaN
# 34  TRAV1-2_gex, DPP4_gex, SLC4A10_gex, KLRB1_gex,...
# 35                                                NaN
# 36           CD69, CD103, CD49a, ITGA1_gex, CXCR6_gex
# 37  MZB1_gex, JCHAIN_gex, LILRA4_gex, CD319_CRACC,...
# 38         LILRA4_gex, PLD4_gex, CD20, CD123, CLEC12A
# 39                          CD19, CD20, JCHAIN_gex_hi
# 40  CD27, CD27_gex, SCIMP_gex, IGHG1_gex, IGHA1_ge...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                               MKI67_gex, TOP2A_gex
# 45                                           SDC1_gex
# 46   GZMK_gex, KIT_gex, IL4I1_gex, RORC_gex, NCR2_gex
# 47  FCGR3A_gex, KIT_gex, IL4I1_gex, RORC_gex, NCR2...
# 48                     FCGR3A_gex, EOMES_gex, KIT_gex
# 49  FCGR3A_gex, GZMK_gex, GZMH_gex, GZMB_gex, EOME...
# 50         FCGR3A_gex, NCR2_gex, RORC_gex, CD57, CD69

# %%
adata.uns[MARKER_GENES] = marker_genes.astype('category')

adata.uns.keys()
# Out:
# dict_keys(['gross_annotation_colors', 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments', 'author_cell_type_markers'])

# %% [markdown]
# # Check author cell type annotations and Cell Ontology IDs

# %%
adata.obs.columns
# Out:
# Index(['n_genes', 'n_genes_by_counts', 'total_counts', 'library', 'donor',
#        'site', 'sex', 'sample', 'chemistry', 'tissue', 'batch',
#        'MMoCHi_annotation', 'Cell_ontology', 'gross_annotation', 'cmv', 'ages',
#        'sample_ID', 'donor_id', 'protocol_URL', 'institute',
#        'sample_collection_site', 'sample_collection_relative_time_point',
#        'library_ID', 'library_ID_repository', 'author_batch_notes',
#        'organism_ontology_term_id', 'manner_of_death', 'sample_source',
#        'sex_ontology_term_id', 'sample_collection_method', 'tissue_type',
#        'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text',
#        'sample_preservation_method', 'suspension_type', 'cell_enrichment',
#        'cell_viability_percentage', 'cell_number_loaded',
#        'sample_collection_year', 'assay_ontology_term_id',
#        'library_preparation_batch', 'library_sequencing_run',
#        'sequenced_fragment', 'sequencing_platform', 'is_primary_data',
#        'reference_genome', 'gene_annotation_version', 'alignment_software',
#        'intron_inclusion', 'disease_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id',
#        'development_stage_ontology_term_id'],
#       dtype='object')

# %%
# MMoCHi_annotation in obs corresponds to author cell type annotation, so creating new obs column

adata.obs[AUTHOR_CELL_TYPE] = adata.obs['MMoCHi_annotation']

adata.obs
# Out:
#                                      n_genes  n_genes_by_counts  total_counts  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14        4809               4809       24285.0
# ATTGGTGCAGGACCCT-1_CZINY-0296-7         1651               1651        3246.0
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0     1708               1708        4865.0
# GTACTCCTCATGTCCC-1_CZINY-0415-14        1323               1323        2611.0
# CTCGAGGAGCAAATCA-1_CZINY-0718-5          622                622        1470.0
# ...                                      ...                ...           ...
# CTACACCTCCAACCAA-1_CZINY-0533-11        1786               1786        4039.0
# AACACGTGTAAGCACG-1_CZINY-0289-0         1387               1387        3420.0
# GAATGAAAGGCGCTCT-1_CZINY-0521-0         4026               4026       17359.0
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2         2270               2270        5138.0
# ACGTCAAAGACTCGGA-1_CZINY-0527-6         3320               3320       11283.0
#
#                                             library donor site     sex  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14         CZINY-0536  D534   NY    Male
# ATTGGTGCAGGACCCT-1_CZINY-0296-7          CZINY-0296  D523   NY  Female
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  CZI-IA10034924  591C   UK    Male
# GTACTCCTCATGTCCC-1_CZINY-0415-14         CZINY-0415  D529   NY  Female
# CTCGAGGAGCAAATCA-1_CZINY-0718-5          CZINY-0718  D570   NY    Male
# ...                                             ...   ...  ...     ...
# CTACACCTCCAACCAA-1_CZINY-0533-11         CZINY-0533  D534   NY    Male
# AACACGTGTAAGCACG-1_CZINY-0289-0          CZINY-0289  D523   NY  Female
# GAATGAAAGGCGCTCT-1_CZINY-0521-0          CZINY-0521  D534   NY    Male
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2          CZINY-0051  D503   NY  Female
# ACGTCAAAGACTCGGA-1_CZINY-0527-6          CZINY-0527  D534   NY    Male
#
#                                          sample chemistry tissue  ...  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14     D534-BAL-1      5'v2    BAL  ...
# ATTGGTGCAGGACCCT-1_CZINY-0296-7      D523-LNG-1      5'v2    LNG  ...
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  591C-LNG-3      5'v2    LNG  ...
# GTACTCCTCATGTCCC-1_CZINY-0415-14     D529-LNG-1      5'v2    LNG  ...
# CTCGAGGAGCAAATCA-1_CZINY-0718-5      D570-LNG-1      5'v2    LNG  ...
# ...                                         ...       ...    ...  ...
# CTACACCTCCAACCAA-1_CZINY-0533-11     D534-BAL-1      5'v2    BAL  ...
# AACACGTGTAAGCACG-1_CZINY-0289-0      D523-BAL-1      5'v2    BAL  ...
# GAATGAAAGGCGCTCT-1_CZINY-0521-0      D534-BAL-1      5'v2    BAL  ...
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      D503-BAL-1      3'v3    BAL  ...
# ACGTCAAAGACTCGGA-1_CZINY-0527-6      D534-LNG-1      5'v2    LNG  ...
#
#                                     sequencing_platform is_primary_data  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14                    N/A            true
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                     N/A            true
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0         EFO_0008637            true
# GTACTCCTCATGTCCC-1_CZINY-0415-14                    N/A            true
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                     N/A            true
# ...                                                 ...             ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                    N/A            true
# AACACGTGTAAGCACG-1_CZINY-0289-0                     N/A            true
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                     N/A            true
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2                     N/A            true
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                     N/A            true
#
#                                     reference_genome gene_annotation_version  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14              GRCh38                     N/A
# ATTGGTGCAGGACCCT-1_CZINY-0296-7               GRCh38                     N/A
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0           GRCh38                     N/A
# GTACTCCTCATGTCCC-1_CZINY-0415-14              GRCh38                     N/A
# CTCGAGGAGCAAATCA-1_CZINY-0718-5               GRCh38                     N/A
# ...                                              ...                     ...
# CTACACCTCCAACCAA-1_CZINY-0533-11              GRCh38                     N/A
# AACACGTGTAAGCACG-1_CZINY-0289-0               GRCh38                     N/A
# GAATGAAAGGCGCTCT-1_CZINY-0521-0               GRCh38                     N/A
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2               GRCh38                     N/A
# ACGTCAAAGACTCGGA-1_CZINY-0527-6               GRCh38                     N/A
#
#                                     alignment_software intron_inclusion  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14     cell ranger 6.0.0              yes
# ATTGGTGCAGGACCCT-1_CZINY-0296-7      cell ranger 6.0.0              yes
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  cell ranger 6.0.0              yes
# GTACTCCTCATGTCCC-1_CZINY-0415-14     cell ranger 6.0.0              yes
# CTCGAGGAGCAAATCA-1_CZINY-0718-5      cell ranger 6.0.0              yes
# ...                                                ...              ...
# CTACACCTCCAACCAA-1_CZINY-0533-11     cell ranger 6.0.0              yes
# AACACGTGTAAGCACG-1_CZINY-0289-0      cell ranger 6.0.0              yes
# GAATGAAAGGCGCTCT-1_CZINY-0521-0      cell ranger 6.0.0              yes
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      cell ranger 6.0.0              yes
# ACGTCAAAGACTCGGA-1_CZINY-0527-6      cell ranger 6.0.0              yes
#
#                                     disease_ontology_term_id  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14                PATO:0000461
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                 PATO:0000461
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0             PATO:0000461
# GTACTCCTCATGTCCC-1_CZINY-0415-14                PATO:0000461
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                 PATO:0000461
# ...                                                      ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                PATO:0000461
# AACACGTGTAAGCACG-1_CZINY-0289-0                 PATO:0000461
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                 PATO:0000461
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2                 PATO:0000461
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                 PATO:0000461
#
#                                     self_reported_ethnicity_ontology_term_id  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14                                       White
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                                     Hispanic
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0                                    White
# GTACTCCTCATGTCCC-1_CZINY-0415-14                                    Hispanic
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                                        White
# ...                                                                      ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                                       White
# AACACGTGTAAGCACG-1_CZINY-0289-0                                     Hispanic
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                                        White
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2                                        White
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                                        White
#
#                                     development_stage_ontology_term_id  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14                        HsapDv:0000238
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                         HsapDv:0000237
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0                     HsapDv:0000238
# GTACTCCTCATGTCCC-1_CZINY-0415-14                        HsapDv:0000241
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                         HsapDv:0000242
# ...                                                                ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                        HsapDv:0000238
# AACACGTGTAAGCACG-1_CZINY-0289-0                         HsapDv:0000237
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                         HsapDv:0000238
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2                         HsapDv:0000241
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                         HsapDv:0000238
#
#                                     author_cell_type
# CGAATGTCAATAAGCA-1_CZINY-0536-14          macrophage
# ATTGGTGCAGGACCCT-1_CZINY-0296-7           macrophage
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0          cd4_tem
# GTACTCCTCATGTCCC-1_CZINY-0415-14          nk_cd56dim
# CTCGAGGAGCAAATCA-1_CZINY-0718-5           macrophage
# ...                                              ...
# CTACACCTCCAACCAA-1_CZINY-0533-11             b_naive
# AACACGTGTAAGCACG-1_CZINY-0289-0             b_memory
# GAATGAAAGGCGCTCT-1_CZINY-0521-0           macrophage
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2           nk_cd56dim
# ACGTCAAAGACTCGGA-1_CZINY-0527-6           macrophage
#
# [213154 rows x 54 columns]

# %%
# Cell_ontology does not correspond to ID format -> Revise
adata.obs['Cell_ontology'].value_counts()
# Out:
# macrophage                                                                    111047
# CD16-positive, CD56-dim natural killer cell, human                             22196
# classical monocyte                                                             18166
# central memory CD4-positive, alpha-beta T cell                                  7632
# effector memory CD4-positive, alpha-beta T cell                                 7575
# effector memory CD8-positive, alpha-beta T cell, terminally differentiated      5224
# non-classical monocyte                                                          4558
# CD4-positive, alpha-beta T cell                                                 4304
# CD16-negative, CD56-bright natural killer cell, human                           4185
# CD4-positive, CD25-positive, alpha-beta regulatory T cell                       3793
# CD8-positive, alpha-beta T cell                                                 3112
# effector memory CD8-positive, alpha-beta T cell                                 2948
# mast cell                                                                       2629
# immature innate lymphoid cell                                                   2158
# naive thymus-derived CD4-positive, alpha-beta T cell                            2076
# memory b cell                                                                   2025
# gamma-delta T cell                                                              1721
# dendritic cell                                                                  1575
# naive b cell                                                                    1262
# effector memory CD4-positive, alpha-beta T cellra                               1201
# naive thymus-derived CD8-positive, alpha-beta T cell                             995
# mucosal invariant T cell                                                         779
# plasmablast                                                                      625
# progenitor cell                                                                  339
# plasma cell                                                                      271
# group 3 innate lymphoid cell                                                     266
# group 1 innate lymphoid cell                                                     242
# plasmacytoid dendritic cell                                                      228
# germinal center B cell                                                            22
# Name: Cell_ontology, dtype: int64

# %%
cell_ontology_mapping = {
    'macrophage': 'CL:0000235',
    'CD16-positive, CD56-dim natural killer cell, human': 'CL:0000939',
    'classical monocyte': 'CL:0000860',
    'central memory CD4-positive, alpha-beta T cell': 'CL:0000904',
    'effector memory CD4-positive, alpha-beta T cell': 'CL:0000905',
    'effector memory CD8-positive, alpha-beta T cell, terminally differentiated': 'CL:0001062',
    'non-classical monocyte': 'CL:0000875',
    'CD4-positive, alpha-beta T cell': 'CL:0000624',
    'CD16-negative, CD56-bright natural killer cell, human': 'CL:0000938',
    'CD4-positive, CD25-positive, alpha-beta regulatory T cell': 'CL:0000792',
    'CD8-positive, alpha-beta T cell': 'CL:0000625',
    'effector memory CD8-positive, alpha-beta T cell': 'CL:0000913',
    'mast cell': 'CL:0000097',
    'immature innate lymphoid cell': 'CL:0001082',
    'naive thymus-derived CD4-positive, alpha-beta T cell': 'CL:0000895',
    'memory b cell': 'CL:0000787',
    'gamma-delta T cell': 'CL:0000798',
    'dendritic cell': 'CL:0000451',
    'naive b cell': 'CL:0000788',
    'effector memory CD4-positive, alpha-beta T cellra': 'CL:0000905',
    'naive thymus-derived CD8-positive, alpha-beta T cell': 'CL:0000900',
    'mucosal invariant T cell': 'CL:0000940',
    'plasmablast': 'CL:0000980',
    'progenitor cell': 'CL:0011026',
    'plasma cell': 'CL:0000786',
    'group 3 innate lymphoid cell': 'CL:0001071',
    'group 1 innate lymphoid cell': 'CL:0001067',
    'plasmacytoid dendritic cell': 'CL:0000784',
    'germinal center B cell': 'CL:0000844'
}

# %%
adata.obs[CELL_TYPE_ONTOLOGY_ID] = adata.obs['Cell_ontology'].map(cell_ontology_mapping)

adata.obs[CELL_TYPE_ONTOLOGY_LABEL] = adata.obs['Cell_ontology']

adata.obs[CELL_TYPE_ONTOLOGY_LABEL].value_counts(dropna=False)
# Out:
# macrophage                                                                    111047
# CD16-positive, CD56-dim natural killer cell, human                             22196
# classical monocyte                                                             18166
# central memory CD4-positive, alpha-beta T cell                                  7632
# effector memory CD4-positive, alpha-beta T cell                                 7575
# effector memory CD8-positive, alpha-beta T cell, terminally differentiated      5224
# non-classical monocyte                                                          4558
# CD4-positive, alpha-beta T cell                                                 4304
# CD16-negative, CD56-bright natural killer cell, human                           4185
# CD4-positive, CD25-positive, alpha-beta regulatory T cell                       3793
# CD8-positive, alpha-beta T cell                                                 3112
# effector memory CD8-positive, alpha-beta T cell                                 2948
# mast cell                                                                       2629
# immature innate lymphoid cell                                                   2158
# naive thymus-derived CD4-positive, alpha-beta T cell                            2076
# memory b cell                                                                   2025
# gamma-delta T cell                                                              1721
# dendritic cell                                                                  1575
# naive b cell                                                                    1262
# effector memory CD4-positive, alpha-beta T cellra                               1201
# naive thymus-derived CD8-positive, alpha-beta T cell                             995
# mucosal invariant T cell                                                         779
# plasmablast                                                                      625
# progenitor cell                                                                  339
# plasma cell                                                                      271
# group 3 innate lymphoid cell                                                     266
# group 1 innate lymphoid cell                                                     242
# plasmacytoid dendritic cell                                                      228
# germinal center B cell                                                            22
# Name: cell_type_ontology_term_label, dtype: int64

# %%
adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False)
# Out:
# macrophage               111047
# nk_cd56dim                22196
# monocyte_classical        18166
# cd4_tem                    7575
# cd4_cm                     7395
# cd8_temra                  5224
# monocyte_nonclassical      4558
# cd4_trm                    4304
# nk_cd56br                  4185
# cd4_treg                   3793
# cd8_trm                    3112
# cd8_tem                    2948
# mast_cell                  2629
# nk_ilc_precursor           2158
# cd4_naive                  2076
# b_memory                   1998
# cd3_gd                     1721
# b_naive                    1262
# dc2                        1205
# cd4_temra                  1201
# cd8_naive                   995
# cd8_mait                    779
# plasmablast                 625
# progenitor                  339
# plasma_cell                 271
# ilc3                        266
# ilc1                        242
# cd8_cm                      237
# pdc                         228
# dc_migratory                221
# dc1                         149
# b_age                        27
# b_gc                         22
# Name: author_cell_type, dtype: int64

# %%
# make mapping dict with unique values from adata.obs[AUTHOR_CELL_TYPE] and adata.obs[CELL_TYPE_ONTOLOGY_ID]

ontology_mapping = dict(zip(adata.obs[AUTHOR_CELL_TYPE], adata.obs[CELL_TYPE_ONTOLOGY_ID]))

ontology_mapping
# Out:
# {'macrophage': 'CL:0000235',
#  'cd4_tem': 'CL:0000905',
#  'nk_cd56dim': 'CL:0000939',
#  'cd8_tem': 'CL:0000913',
#  'monocyte_classical': 'CL:0000860',
#  'cd4_trm': 'CL:0000624',
#  'monocyte_nonclassical': 'CL:0000875',
#  'cd4_treg': 'CL:0000792',
#  'ilc1': 'CL:0001067',
#  'cd8_temra': 'CL:0001062',
#  'cd4_cm': 'CL:0000904',
#  'dc_migratory': 'CL:0000451',
#  'cd8_mait': 'CL:0000940',
#  'cd4_temra': 'CL:0000905',
#  'dc2': 'CL:0000451',
#  'mast_cell': 'CL:0000097',
#  'cd8_trm': 'CL:0000625',
#  'cd3_gd': 'CL:0000798',
#  'b_memory': 'CL:0000787',
#  'b_naive': 'CL:0000788',
#  'nk_cd56br': 'CL:0000938',
#  'cd4_naive': 'CL:0000895',
#  'plasmablast': 'CL:0000980',
#  'nk_ilc_precursor': 'CL:0001082',
#  'cd8_cm': 'CL:0000904',
#  'plasma_cell': 'CL:0000786',
#  'cd8_naive': 'CL:0000900',
#  'ilc3': 'CL:0001071',
#  'dc1': 'CL:0000451',
#  'progenitor': 'CL:0011026',
#  'pdc': 'CL:0000784',
#  'b_age': 'CL:0000787',
#  'b_gc': 'CL:0000844'}

# %%
marker_genes[CELL_TYPE_ONTOLOGY_ID] = marker_genes['Subset'].map(ontology_mapping)
marker_genes
# Out:
#                    Subset        Parent  \
# 0              lymphocyte           All
# 1               myelocyte           All
# 2               mast_cell           All
# 3              neutrophil           All
# 4                  mo_mac     myelocyte
# 5                      dc     myelocyte
# 6                    mpdc     myelocyte
# 7              macrophage        mo_mac
# 8      monocyte_classical        mo_mac
# 9   monocyte_nonclassical        mo_mac
# 10                    dc1            dc
# 11                    dc2            dc
# 12           dc_migratORy            dc
# 13                 t_cell    lymphocyte
# 14            b_cell_like    lymphocyte
# 15                 nk_ilc    lymphocyte
# 16                   ab_t        t_cell
# 17                   gd_t        t_cell
# 18                  cd4_t          ab_t
# 19                  cd8_t          ab_t
# 20           cd4_naive_cm         cd4_t
# 21               cd4_treg         cd4_t
# 22                 cd4_em         cd4_t
# 23              cd4_temra         cd4_t
# 24              cd4_naive  cd4_naive_cm
# 25                 cd4_cm  cd4_naive_cm
# 26                cd4_trm        cd4_em
# 27                cd4_tem        cd4_em
# 28           cd8_naive_cm         cd8_t
# 29           cd8_tem_mait         cd8_t
# 30              cd8_temra         cd8_t
# 31              cd8_naive  cd8_naive_cm
# 32                 cd8_cm  cd8_naive_cm
# 33               cd8_mait  cd8_tem_mait
# 34           cd8_not_mait  cd8_tem_mait
# 35                cd8_trm  cd8_not_mait
# 36                cd8_tem  cd8_not_mait
# 37                 b_cell   b_cell_like
# 38                 plasma   b_cell_like
# 39                    pdc   b_cell_like
# 40                b_naive        b_cell
# 41               b_memory        b_cell
# 42                   b_gc        b_cell
# 43                  b_age        b_cell
# 44            plasma_cell        plasma
# 45            plasmablast        plasma
# 46             nk_cd56dim        nk_ilc
# 47              nk_cd56br        nk_ilc
# 48                   ilc1        nk_ilc
# 49                   ilc3        nk_ilc
# 50       nk_ilc_precursor        nk_ilc
#
#                                     Positive Features  \
# 0   2 of (CD3, CD19, CD20, JCHAIN_gex, CD2_gex, LI...
# 1   1 of (CD163, CD64, OLR1_gex) OR 2 of (LAMP3_ge...
# 2                 CD33 AND 1 of (TPSB2_gex, CPA3_gex)
# 3   1 of (S100A8_gex, S100A9_gex) AND 2 of (MMP9_g...
# 4   1 of (MARCO_gex, MRC1_gex, SELENOP_gex, MERTK_...
# 5   1 of (CD1C_gex, CD1c, CLEC9A_gex, CCL19_gex, L...
# 6      2 of (LILRA4_gex, PLD4_gex, JCHAIN_gex, CD123)
# 7   1 of (C1QA_gex, C1QB_gex, C1QC_gex, MARCO_gex,...
# 8   FCN1_gex, CD33_hi AND 2 of (S100A9_gex, S100A8...
# 9   2 of (CX3CR1, MS4A7_gex, C1QA_gex, C1QB_gex, C...
# 10             1 of (XCR1_gex, CLEC9A_gex, CADM1_gex)
# 11               1 of (CLEC10A_gex, FCER1A, CD1C_gex)
# 12                         1 of (CCR7_gex, CCL19_gex)
# 13  1 of (CD3) OR 1 of (TRDV1_gex, TRDV2_gex, TRDV...
# 14  1 of (CD19, CD20, MZB1_gex, JCHAIN_gex, LILRA4...
# 15  1 of (IL7R_gex, KIT_gex, IL4I1_gex, RORC_gex, ...
# 16                            1 of (TCR_ab, TRAC_gex)
# 17  2 of (TRDC_gex, TCR_Vd2, TRDV1_gex, TRDV2_gex,...
# 18                                1 of (CD4, CD4_gex)
# 19                               1 of (CD8, CD8A_gex)
# 20                   1 of (CD62L, SELL_gex, CCR7_gex)
# 21              1 of (FOXP3_gex, IL10_gex, IKZF2_gex)
# 22  1 of (CD69, GZMA_gex, GZMB_gex, GZMK_gex, GZMH...
# 23  1 of (CD45RA) AND 1 of (CCL5_gex, FCGR3A_gex, ...
# 24                                             CD45RA
# 25                                               CD95
# 26  2 of (CD69, ITGAE_gex, CD103, ITGA1_gex, CD49a...
# 27                                                NaN
# 28                                              CD62L
# 29  1 of (CD69, CCL5_gex, GZMB_gex, GZMK_gex, GZMA...
# 30  1 of (CD45RA) AND 1 of (CCL5_gex, FCGR3A_gex, ...
# 31                                             CD45RA
# 32                      1 of (CD95, CD45RO, CCL5_gex)
# 33  3 of (TRAV1-2_gex, DPP4_gex, SLC4A10_gex, KLRB...
# 34                            1 of (TRAC_gex, TCR_ab)
# 35  1 of (CD69) OR 2 of (ITGAE_gex, CD103, ITGA1_g...
# 36                                                NaN
# 37                                  1 of (CD19, CD20)
# 38  2 of (JCHAIN_gex_hi, MZB1_gex, JCHAIN_gex, CD3...
# 39  2 of (LILRA4_gex, PLD4_gex, JCHAIN_gex, CD123,...
# 40  IgD AND 1 of (TCL1A_gex, YBX3_gex, IL4R_gex, B...
# 41  CD27_gex AND 2 of (CD27, SCIMP_gex, IGHG1_gex,...
# 42  2 of (AICDA_gex, SUGCT_gex, RGS13_gex, LMO2_ge...
# 43        2 of (CD11c, ITGAX_gex, TBX21_gex, FGR_gex)
# 44                      1 of (SDC1_gex, TNFRSF18_gex)
# 45                        1 of (MKI67_gex, TOP2A_gex)
# 46                    FCGR3A_gex, GZMB_gex, EOMES_gex
# 47         CD335_NKp46 AND 1 of (GZMK_gex, EOMES_gex)
# 48                                    1 of (NCR2_gex)
# 49      2 of (IL7R_gex, KIT_gex, IL4I1_gex, RORC_gex)
# 50                             1 of (SELL_gex, CD62L)
#
#                                     Negative Features  \
# 0   CD163, MRC1_gex, CD64, OLR1_gex, MPO_gex, ELAN...
# 1   CD2_gex, CD19, CD20, CD127, TPSB2_gex, CD3, MM...
# 2   MRC1_gex, OLR1_gex, CD64, CLEC9A_gex, LILRA4_g...
# 3   MRC1_gex, OLR1_gex, CLEC9A_gex, LILRA4_gex, PL...
# 4   CD1c, CD1C_gex, MPO_gex, ELANE_gex, PRSS57_gex...
# 5   MPO_gex, ELANE_gex, PRSS57_gex, CYTL1_gex, FCN...
# 6   MARCO_gex, MRC1_gex, SELENOP_gex, C1QA_gex, C1...
# 7                          FCN1_gex, CLEC12A_lo, CD99
# 8   MERTK_gex, MARCO_gex, SELENOP_gex, MS4A7_gex, ...
# 9   MARCO_gex, SELENOP_gex, SELL_gex, APOE_gex, AP...
# 10                      CLEC10A_gex, FCER1A, CD1C_gex
# 11                    XCR1_gex, CLEC9A_gex, CADM1_gex
# 12                    XCR1_gex, CLEC9A_gex, CADM1_gex
# 13  CD19, CD20, MZB1_gex, JCHAIN_gex, NCR2_gex, LI...
# 14                                      CD3, IL7R_gex
# 15  CD3, CD19, CD20, MZB1_gex, TCR_Vd2, TRDV1_gex,...
# 16  TRDC_gex, TCR_Vd2, TRDV1_gex, TRDV2_gex, TRDV3...
# 17                                             TCR_ab
# 18                                      CD8, CD8A_gex
# 19                                       CD4, CD4_gex
# 20  FOXP3_gex, IKZF2_gex, CCL5_gex, FCGR3A_gex, FG...
# 21                                    CCL5_gex, CD127
# 22                CD62L, CD45RA, FOXP3_gex, IKZF2_gex
# 23    FOXP3_gex, CD62L, SELL_gex, CCR7_gex, IKZF2_gex
# 24                                               CD95
# 25                                             CD45RA
# 26                                                NaN
# 27           CD69, CD103, CD49a, ITGA1_gex, CXCR6_gex
# 28  CCL5_gex, NKG7_gex, FCGR3A_gex, CD57, FGFBP2_g...
# 29                                      CD62L, CD45RA
# 30                          CD62L, SELL_gex, CCR7_gex
# 31                             CD95, CD45RO, CCL5_gex
# 32                                             CD45RA
# 33                                                NaN
# 34  TRAV1-2_gex, DPP4_gex, SLC4A10_gex, KLRB1_gex,...
# 35                                                NaN
# 36           CD69, CD103, CD49a, ITGA1_gex, CXCR6_gex
# 37  MZB1_gex, JCHAIN_gex, LILRA4_gex, CD319_CRACC,...
# 38         LILRA4_gex, PLD4_gex, CD20, CD123, CLEC12A
# 39                          CD19, CD20, JCHAIN_gex_hi
# 40  CD27, CD27_gex, SCIMP_gex, IGHG1_gex, IGHA1_ge...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                               MKI67_gex, TOP2A_gex
# 45                                           SDC1_gex
# 46   GZMK_gex, KIT_gex, IL4I1_gex, RORC_gex, NCR2_gex
# 47  FCGR3A_gex, KIT_gex, IL4I1_gex, RORC_gex, NCR2...
# 48                     FCGR3A_gex, EOMES_gex, KIT_gex
# 49  FCGR3A_gex, GZMK_gex, GZMH_gex, GZMB_gex, EOME...
# 50         FCGR3A_gex, NCR2_gex, RORC_gex, CD57, CD69
#
#    cell_type_ontology_term_id
# 0                         NaN
# 1                         NaN
# 2                  CL:0000097
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                  CL:0000235
# 8                  CL:0000860
# 9                  CL:0000875
# 10                 CL:0000451
# 11                 CL:0000451
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                 CL:0000792
# 22                        NaN
# 23                 CL:0000905
# 24                 CL:0000895
# 25                 CL:0000904
# 26                 CL:0000624
# 27                 CL:0000905
# 28                        NaN
# 29                        NaN
# 30                 CL:0001062
# 31                 CL:0000900
# 32                 CL:0000904
# 33                 CL:0000940
# 34                        NaN
# 35                 CL:0000625
# 36                 CL:0000913
# 37                        NaN
# 38                        NaN
# 39                 CL:0000784
# 40                 CL:0000788
# 41                 CL:0000787
# 42                 CL:0000844
# 43                 CL:0000787
# 44                 CL:0000786
# 45                 CL:0000980
# 46                 CL:0000939
# 47                 CL:0000938
# 48                 CL:0001067
# 49                 CL:0001071
# 50                 CL:0001082

# %%
adata.uns[MARKER_GENES] = marker_genes.astype('category')

# %% [markdown]
# # Check whether ENSEMBL IDs in var

# %%
adata.var
# Out:
#                     gene_ids  is_highly_variable_gene_batch_key_donor_id
# MIR1302-2HG  ENSG00000243485                                        True
# FAM138A      ENSG00000237613                                       False
# OR4F5        ENSG00000186092                                       False
# AL627309.1   ENSG00000238009                                       False
# AL627309.3   ENSG00000239945                                       False
# ...                      ...                                         ...
# AC141272.1   ENSG00000277836                                        True
# AC023491.2   ENSG00000278633                                       False
# AC007325.1   ENSG00000276017                                       False
# AC007325.4   ENSG00000278817                                       False
# AC007325.2   ENSG00000277196                                        True
#
# [36587 rows x 2 columns]

# %%
adata.var['gene_symbol'] = adata.var.index
adata.var.index.name = 'index'
adata.var.rename(columns={'gene_ids': 'ensembl_id'}, inplace=True)
adata.var
# Out:
#                   ensembl_id  is_highly_variable_gene_batch_key_donor_id  \
# index
# MIR1302-2HG  ENSG00000243485                                        True
# FAM138A      ENSG00000237613                                       False
# OR4F5        ENSG00000186092                                       False
# AL627309.1   ENSG00000238009                                       False
# AL627309.3   ENSG00000239945                                       False
# ...                      ...                                         ...
# AC141272.1   ENSG00000277836                                        True
# AC023491.2   ENSG00000278633                                       False
# AC007325.1   ENSG00000276017                                       False
# AC007325.4   ENSG00000278817                                       False
# AC007325.2   ENSG00000277196                                        True
#
#              gene_symbol
# index
# MIR1302-2HG  MIR1302-2HG
# FAM138A          FAM138A
# OR4F5              OR4F5
# AL627309.1    AL627309.1
# AL627309.3    AL627309.3
# ...                  ...
# AC141272.1    AC141272.1
# AC023491.2    AC023491.2
# AC007325.1    AC007325.1
# AC007325.4    AC007325.4
# AC007325.2    AC007325.2
#
# [36587 rows x 3 columns]

# %%
adata.var.dtypes
# Out:
# ensembl_id                                    object
# is_highly_variable_gene_batch_key_donor_id      bool
# gene_symbol                                   object
# dtype: object

# %% [markdown]
# # Check raw data

# %%
adata.X.toarray().max()
# Out:
# 28535.0

# %%
adata.obs
# Out:
#                                      n_genes  n_genes_by_counts  total_counts  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14        4809               4809       24285.0
# ATTGGTGCAGGACCCT-1_CZINY-0296-7         1651               1651        3246.0
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0     1708               1708        4865.0
# GTACTCCTCATGTCCC-1_CZINY-0415-14        1323               1323        2611.0
# CTCGAGGAGCAAATCA-1_CZINY-0718-5          622                622        1470.0
# ...                                      ...                ...           ...
# CTACACCTCCAACCAA-1_CZINY-0533-11        1786               1786        4039.0
# AACACGTGTAAGCACG-1_CZINY-0289-0         1387               1387        3420.0
# GAATGAAAGGCGCTCT-1_CZINY-0521-0         4026               4026       17359.0
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2         2270               2270        5138.0
# ACGTCAAAGACTCGGA-1_CZINY-0527-6         3320               3320       11283.0
#
#                                             library donor site     sex  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14         CZINY-0536  D534   NY    Male
# ATTGGTGCAGGACCCT-1_CZINY-0296-7          CZINY-0296  D523   NY  Female
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  CZI-IA10034924  591C   UK    Male
# GTACTCCTCATGTCCC-1_CZINY-0415-14         CZINY-0415  D529   NY  Female
# CTCGAGGAGCAAATCA-1_CZINY-0718-5          CZINY-0718  D570   NY    Male
# ...                                             ...   ...  ...     ...
# CTACACCTCCAACCAA-1_CZINY-0533-11         CZINY-0533  D534   NY    Male
# AACACGTGTAAGCACG-1_CZINY-0289-0          CZINY-0289  D523   NY  Female
# GAATGAAAGGCGCTCT-1_CZINY-0521-0          CZINY-0521  D534   NY    Male
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2          CZINY-0051  D503   NY  Female
# ACGTCAAAGACTCGGA-1_CZINY-0527-6          CZINY-0527  D534   NY    Male
#
#                                          sample chemistry tissue  ...  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14     D534-BAL-1      5'v2    BAL  ...
# ATTGGTGCAGGACCCT-1_CZINY-0296-7      D523-LNG-1      5'v2    LNG  ...
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  591C-LNG-3      5'v2    LNG  ...
# GTACTCCTCATGTCCC-1_CZINY-0415-14     D529-LNG-1      5'v2    LNG  ...
# CTCGAGGAGCAAATCA-1_CZINY-0718-5      D570-LNG-1      5'v2    LNG  ...
# ...                                         ...       ...    ...  ...
# CTACACCTCCAACCAA-1_CZINY-0533-11     D534-BAL-1      5'v2    BAL  ...
# AACACGTGTAAGCACG-1_CZINY-0289-0      D523-BAL-1      5'v2    BAL  ...
# GAATGAAAGGCGCTCT-1_CZINY-0521-0      D534-BAL-1      5'v2    BAL  ...
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      D503-BAL-1      3'v3    BAL  ...
# ACGTCAAAGACTCGGA-1_CZINY-0527-6      D534-LNG-1      5'v2    LNG  ...
#
#                                     reference_genome gene_annotation_version  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14              GRCh38                     N/A
# ATTGGTGCAGGACCCT-1_CZINY-0296-7               GRCh38                     N/A
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0           GRCh38                     N/A
# GTACTCCTCATGTCCC-1_CZINY-0415-14              GRCh38                     N/A
# CTCGAGGAGCAAATCA-1_CZINY-0718-5               GRCh38                     N/A
# ...                                              ...                     ...
# CTACACCTCCAACCAA-1_CZINY-0533-11              GRCh38                     N/A
# AACACGTGTAAGCACG-1_CZINY-0289-0               GRCh38                     N/A
# GAATGAAAGGCGCTCT-1_CZINY-0521-0               GRCh38                     N/A
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2               GRCh38                     N/A
# ACGTCAAAGACTCGGA-1_CZINY-0527-6               GRCh38                     N/A
#
#                                     alignment_software intron_inclusion  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14     cell ranger 6.0.0              yes
# ATTGGTGCAGGACCCT-1_CZINY-0296-7      cell ranger 6.0.0              yes
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0  cell ranger 6.0.0              yes
# GTACTCCTCATGTCCC-1_CZINY-0415-14     cell ranger 6.0.0              yes
# CTCGAGGAGCAAATCA-1_CZINY-0718-5      cell ranger 6.0.0              yes
# ...                                                ...              ...
# CTACACCTCCAACCAA-1_CZINY-0533-11     cell ranger 6.0.0              yes
# AACACGTGTAAGCACG-1_CZINY-0289-0      cell ranger 6.0.0              yes
# GAATGAAAGGCGCTCT-1_CZINY-0521-0      cell ranger 6.0.0              yes
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      cell ranger 6.0.0              yes
# ACGTCAAAGACTCGGA-1_CZINY-0527-6      cell ranger 6.0.0              yes
#
#                                     disease_ontology_term_id  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14                PATO:0000461
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                 PATO:0000461
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0             PATO:0000461
# GTACTCCTCATGTCCC-1_CZINY-0415-14                PATO:0000461
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                 PATO:0000461
# ...                                                      ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                PATO:0000461
# AACACGTGTAAGCACG-1_CZINY-0289-0                 PATO:0000461
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                 PATO:0000461
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2                 PATO:0000461
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                 PATO:0000461
#
#                                     self_reported_ethnicity_ontology_term_id  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14                                       White
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                                     Hispanic
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0                                    White
# GTACTCCTCATGTCCC-1_CZINY-0415-14                                    Hispanic
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                                        White
# ...                                                                      ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                                       White
# AACACGTGTAAGCACG-1_CZINY-0289-0                                     Hispanic
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                                        White
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2                                        White
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                                        White
#
#                                     development_stage_ontology_term_id  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14                        HsapDv:0000238
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                         HsapDv:0000237
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0                     HsapDv:0000238
# GTACTCCTCATGTCCC-1_CZINY-0415-14                        HsapDv:0000241
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                         HsapDv:0000242
# ...                                                                ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                        HsapDv:0000238
# AACACGTGTAAGCACG-1_CZINY-0289-0                         HsapDv:0000237
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                         HsapDv:0000238
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2                         HsapDv:0000241
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                         HsapDv:0000238
#
#                                     author_cell_type  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14          macrophage
# ATTGGTGCAGGACCCT-1_CZINY-0296-7           macrophage
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0          cd4_tem
# GTACTCCTCATGTCCC-1_CZINY-0415-14          nk_cd56dim
# CTCGAGGAGCAAATCA-1_CZINY-0718-5           macrophage
# ...                                              ...
# CTACACCTCCAACCAA-1_CZINY-0533-11             b_naive
# AACACGTGTAAGCACG-1_CZINY-0289-0             b_memory
# GAATGAAAGGCGCTCT-1_CZINY-0521-0           macrophage
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2           nk_cd56dim
# ACGTCAAAGACTCGGA-1_CZINY-0527-6           macrophage
#
#                                     cell_type_ontology_term_id  \
# CGAATGTCAATAAGCA-1_CZINY-0536-14                    CL:0000235
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                     CL:0000235
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0                 CL:0000905
# GTACTCCTCATGTCCC-1_CZINY-0415-14                    CL:0000939
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                     CL:0000235
# ...                                                        ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                    CL:0000788
# AACACGTGTAAGCACG-1_CZINY-0289-0                     CL:0000787
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                     CL:0000235
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2                     CL:0000939
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                     CL:0000235
#
#                                                          cell_type_ontology_term_label
# CGAATGTCAATAAGCA-1_CZINY-0536-14                                            macrophage
# ATTGGTGCAGGACCCT-1_CZINY-0296-7                                             macrophage
# GATCTAGCAAGCTGGA-1_CZI-IA10034924-0    effector memory CD4-positive, alpha-beta T cell
# GTACTCCTCATGTCCC-1_CZINY-0415-14     CD16-positive, CD56-dim natural killer cell, h...
# CTCGAGGAGCAAATCA-1_CZINY-0718-5                                             macrophage
# ...                                                                                ...
# CTACACCTCCAACCAA-1_CZINY-0533-11                                          naive b cell
# AACACGTGTAAGCACG-1_CZINY-0289-0                                          memory b cell
# GAATGAAAGGCGCTCT-1_CZINY-0521-0                                             macrophage
# AGTCTCCTCTCAGGCG-1_CZINY-0051-2      CD16-positive, CD56-dim natural killer cell, h...
# ACGTCAAAGACTCGGA-1_CZINY-0527-6                                             macrophage
#
# [213154 rows x 56 columns]

# %%
#adata.obs = adata.obs.astype('category')

adata.obs['cell_viability_percentage'] = pd.to_numeric(adata.obs['cell_viability_percentage'], errors='coerce')
adata.obs['cell_number_loaded'] = pd.to_numeric(adata.obs['cell_number_loaded'], errors='coerce')
adata.obs['sample_collection_year'] = pd.to_numeric(adata.obs['sample_collection_year'], errors='coerce')

numeric_cols = ['n_genes', 'n_genes_by_counts', 'total_counts', 'batch', 'ages']
for col in numeric_cols:
    adata.obs[col] = pd.to_numeric(adata.obs[col], errors='coerce')

adata.uns[MARKER_GENES] = adata.uns[MARKER_GENES].astype('category')

adata.obs.index = adata.obs.index.astype('str')
adata.var.index = adata.var.index.astype('str')
adata.uns[MARKER_GENES].index = adata.uns[MARKER_GENES].index.astype('str')
adata.var_names = adata.var_names.astype('str')

# %%
adata.X = adata.X.astype(np.int64)

# %%
adata.raw = adata

# %%
adata.X
# Out:
# <213154x36587 sparse matrix of type '<class 'numpy.int64'>'
# 	with 536495167 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <213154x36587 sparse matrix of type '<class 'numpy.int64'>'
# 	with 536495167 stored elements in Compressed Sparse Row format>

# %%
adata.X.toarray().max()
# Out:
# 28535

# %%
adata.raw.X.toarray().max()
# Out:
# 28535

# %% [markdown]
# ## Validation result
#
# ### UNS Validation
# - OK: Tier 1 UNS Google Sheet
# - OK: Tier 1 UNS AnnData Object  same as Google Sheet
#
# ### OBS Validation
# - OK: Tier 1 OBS Google Sheet
# - OK: Tier 1 OBS AnnData Object same as Google Sheet

# %% [markdown]
# # Data Submission Status
#
# - CHECK: Raw counts in X and in raw
# - CHECK Tier 1 Metadata in OBS
# - CHECK: Cell Ontology IDs in OBS
# - CHECK: Author cell type in OBS
# - CHECK: Marker genes in UNS
# - CHECK: ENSEMBL IDs and gene symbols in var
#
# # Revisions:
#
# DONE

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"))
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"))
