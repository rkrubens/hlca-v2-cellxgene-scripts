# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import anndata2ri
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"
# Out:
# Warning message:
# package ‘methods’ was built under R version 4.3.3
# During startup - Warning messages:
# 1: package ‘datasets’ was built under R version 4.3.3
# 2: package ‘utils’ was built under R version 4.3.3
# 3: package ‘grDevices’ was built under R version 4.3.3
# 4: package ‘graphics’ was built under R version 4.3.3
# 5: package ‘stats’ was built under R version 4.3.3

# %%
DATASET_ID = "Meyer_02_unpubl"
H5AD_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/{DATASET_ID}.h5ad"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
# Name constants
AUTHOR_CELL_TYPE_L0 = 'author_cell_type_level_0'
AUTHOR_CELL_TYPE_L1 = 'author_cell_type_level_1'
AUTHOR_CELL_TYPE_L2 = 'author_cell_type_level_2'

CELL_TYPE_ONTOLOGY_ID_L0 = 'cell_type_ontology_term_id_level_0'
CELL_TYPE_ONTOLOGY_ID_L1 = 'cell_type_ontology_term_id_level_1'
CELL_TYPE_ONTOLOGY_ID_L2 = 'cell_type_ontology_term_id_level_2'

MARKER_GENES_L0 = 'author_cell_type_markers_level_0'
MARKER_GENES_L1 = 'author_cell_type_markers_level_1'
MARKER_GENES_L2 = 'author_cell_type_markers_level_2'

# Finest grained annotation will be generic dataset cell type
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'
MARKER_GENES = 'author_cell_type_markers'

# %% [markdown]
# # Load data

# %%
adata = sc.read_h5ad(H5AD_PATH)
obs = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "obs")
uns = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "uns")

# %%
adata.obs.columns
# Out:
# Index(['sample_ID', 'donor_id', 'protocol_URL', 'institute',
#        'sample_collection_site', 'sample_collection_relative_time_point',
#        'library_ID', 'library_ID_repository', 'author_batch_notes',
#        'organism_ontology_term_id', 'manner_of_death', 'sample_source',
#        'sex_ontology_term_id', 'sample_collection_method', 'tissue_type',
#        'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text',
#        'sample_preservation_method', 'suspension_type', 'cell_enrichment',
#        'cell_viability_percentage', 'cell_number_loaded',
#        'sample_collection_year', 'assay_ontology_term_id',
#        'library_preparation_batch', 'library_sequencing_run',
#        'sequenced_fragment', 'sequencing_platform', 'is_primary_data',
#        'reference_genome', 'gene_annotation_version', 'alignment_software',
#        'intron_inclusion', 'disease_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id',
#        'development_stage_ontology_term_id', 'cell_type_ontology_term_id',
#        'cell_type_ontology_term_status', 'author_cell_type', 'sample_ID_ATAC'],
#       dtype='object')

# %% [markdown]
# # Validate obs and uns from Tier 1 Metadata Template

# %%
val_workflow = ValidationWorkflow(
    input = uns,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                                                title  \
# 0  Human lung five locations multiome ATAC and RN...
#
#                                             study_PI  batch_condition  \
# 0  Sarah,A,Teichmann, Martijn,C,Nawijn, Kerstin,B...  SampleID, Donor
#
#   default_embedding              unpublished  \
# 0            X_umap  protected under embargo
#
#                                             comments
# 0  data was pooled and donor metadata per cell re...

# %%
val_workflow = ValidationWorkflow(
    input = obs,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation workflow successful. Returning OBS dataframe.
#             sample_ID donor_id protocol_URL                  institute  \
# 0   HCA_A_LNG12177506      A56          N/A  Wellcome Sanger Institute
# 1   HCA_A_LNG12177508      A60          N/A  Wellcome Sanger Institute
# 2   HCA_A_LNG12177516      A63          N/A  Wellcome Sanger Institute
# 3   HCA_A_LNG12177507      A56          N/A  Wellcome Sanger Institute
# 4   HCA_A_LNG12177507      A60          N/A  Wellcome Sanger Institute
# ..                ...      ...          ...                        ...
# 70  HCA_A_LNG12177510      A61          N/A  Wellcome Sanger Institute
# 71  HCA_A_LNG12177510      A63          N/A  Wellcome Sanger Institute
# 72  HCA_A_LNG12177509      A60          N/A  Wellcome Sanger Institute
# 73  HCA_A_LNG12177509      A56          N/A  Wellcome Sanger Institute
# 74  HCA_A_LNG12177510      A58          N/A  Wellcome Sanger Institute
#
#    sample_collection_site sample_collection_relative_time_point library_ID  \
# 0               Cambridge                                   N/A          B
# 1               Cambridge                                   N/A          B
# 2               Cambridge                                   N/A          E
# 3               Cambridge                                   N/A          B
# 4               Cambridge                                   N/A          B
# ..                    ...                                   ...        ...
# 70              Cambridge                                   N/A          C
# 71              Cambridge                                   N/A          C
# 72              Cambridge                                   N/A          C
# 73              Cambridge                                   N/A          C
# 74              Cambridge                                   N/A          C
#
#    library_ID_repository author_batch_notes organism_ontology_term_id  ...  \
# 0                    N/A                N/A            NCBITaxon:9606  ...
# 1                    N/A                N/A            NCBITaxon:9606  ...
# 2                    N/A                N/A            NCBITaxon:9606  ...
# 3                    N/A                N/A            NCBITaxon:9606  ...
# 4                    N/A                N/A            NCBITaxon:9606  ...
# ..                   ...                ...                       ...  ...
# 70                   N/A                N/A            NCBITaxon:9606  ...
# 71                   N/A                N/A            NCBITaxon:9606  ...
# 72                   N/A                N/A            NCBITaxon:9606  ...
# 73                   N/A                N/A            NCBITaxon:9606  ...
# 74                   N/A                N/A            NCBITaxon:9606  ...
#
#    sequencing_platform is_primary_data reference_genome  \
# 0          EFO:0008637            true           GRCh38
# 1          EFO:0008637            true           GRCh38
# 2          EFO:0008637            true           GRCh38
# 3          EFO:0008637            true           GRCh38
# 4          EFO:0008637            true           GRCh38
# ..                 ...             ...              ...
# 70         EFO:0008637            true           GRCh38
# 71         EFO:0008637            true           GRCh38
# 72         EFO:0008637            true           GRCh38
# 73         EFO:0008637            true           GRCh38
# 74         EFO:0008637            true           GRCh38
#
#    gene_annotation_version alignment_software intron_inclusion  \
# 0               Ensembl 93  cell ranger 3.0.2              yes
# 1               Ensembl 93  cell ranger 3.0.2              yes
# 2               Ensembl 93  cell ranger 3.0.2              yes
# 3               Ensembl 93  cell ranger 3.0.2              yes
# 4               Ensembl 93  cell ranger 3.0.2              yes
# ..                     ...                ...              ...
# 70              Ensembl 93  cell ranger 3.0.2              yes
# 71              Ensembl 93  cell ranger 3.0.2              yes
# 72              Ensembl 93  cell ranger 3.0.2              yes
# 73              Ensembl 93  cell ranger 3.0.2              yes
# 74              Ensembl 93  cell ranger 3.0.2              yes
#
#    disease_ontology_term_id self_reported_ethnicity_ontology_term_id  \
# 0              PATO:0000461                                  unknown
# 1              PATO:0000461                                  unknown
# 2              PATO:0000461                                  unknown
# 3              PATO:0000461                                  unknown
# 4              PATO:0000461                                  unknown
# ..                      ...                                      ...
# 70             PATO:0000461                                  unknown
# 71             PATO:0000461                                  unknown
# 72             PATO:0000461                                  unknown
# 73             PATO:0000461                                  unknown
# 74             PATO:0000461                                  unknown
#
#    development_stage_ontology_term_id     sample_ID_ATAC
# 0                      HsapDv:0000237  HCA_A_LNG11986508
# 1                      HsapDv:0000240  HCA_A_LNG11986510
# 2                      HsapDv:0000239  HCA_A_LNG11986518
# 3                      HsapDv:0000237  HCA_A_LNG11986509
# 4                      HsapDv:0000240  HCA_A_LNG11986509
# ..                                ...                ...
# 70                     HsapDv:0000241  HCA_A_LNG11986512
# 71                     HsapDv:0000239  HCA_A_LNG11986512
# 72                     HsapDv:0000240  HCA_A_LNG11986511
# 73                     HsapDv:0000237  HCA_A_LNG11986511
# 74                     HsapDv:0000241  HCA_A_LNG11986512
#
# [75 rows x 38 columns]

# %% [markdown]
# # Validate obs and uns from adata

# %%
val_workflow = ValidationWorkflow(
    input = adata,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                                                title  \
# 0  Human lung five locations multiome ATAC and RN...
#
#                                             study_PI              unpublished
# 0  Sarah,A,Teichmann, Martijn,C,Nawijn, Kerstin,B...  protected under embargo

# %%
val_workflow = ValidationWorkflow(
    input = adata,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation error(s) encountered.
# {
# │   'sample_preservation_method': "Must be a valid method such as 'fresh', 'frozen at -80C', etc. Invalid entries found."
# }
# Error containing field: sample_preservation_method
# Error message: Must be a valid method such as 'fresh', 'frozen at -80C', etc. Invalid entries found.
# Value counts:
# frozen    37339
# Name: sample_preservation_method, dtype: int64
# Returning error-containing OBS dataframe.
#                                               sample_ID donor_id protocol_URL  \
# rna_barcodes
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506  HCA_A_LNG12177506      A56          N/A
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508  HCA_A_LNG12177508      A60          N/A
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516  HCA_A_LNG12177516      A63          N/A
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508  HCA_A_LNG12177508      A60          N/A
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507  HCA_A_LNG12177507      A56          N/A
# ...                                                 ...      ...          ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506  HCA_A_LNG12177506      A61          N/A
# GACAATACACGTGCTG-1-HCA_A_LNG12177517  HCA_A_LNG12177517      A58          N/A
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505  HCA_A_LNG12177505      A56          N/A
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516  HCA_A_LNG12177516      A60          N/A
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517  HCA_A_LNG12177517      A63          N/A
#
#                                                       institute  \
# rna_barcodes
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506  Wellcome Sanger Institute
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508  Wellcome Sanger Institute
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516  Wellcome Sanger Institute
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508  Wellcome Sanger Institute
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507  Wellcome Sanger Institute
# ...                                                         ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506  Wellcome Sanger Institute
# GACAATACACGTGCTG-1-HCA_A_LNG12177517  Wellcome Sanger Institute
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505  Wellcome Sanger Institute
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516  Wellcome Sanger Institute
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517  Wellcome Sanger Institute
#
#                                      sample_collection_site  \
# rna_barcodes
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506              Cambridge
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508              Cambridge
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516              Cambridge
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508              Cambridge
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507              Cambridge
# ...                                                     ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506              Cambridge
# GACAATACACGTGCTG-1-HCA_A_LNG12177517              Cambridge
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505              Cambridge
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516              Cambridge
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517              Cambridge
#
#                                      sample_collection_relative_time_point  \
# rna_barcodes
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506                                   N/A
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508                                   N/A
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516                                   N/A
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508                                   N/A
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507                                   N/A
# ...                                                                    ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506                                   N/A
# GACAATACACGTGCTG-1-HCA_A_LNG12177517                                   N/A
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505                                   N/A
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516                                   N/A
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517                                   N/A
#
#                                      library_ID library_ID_repository  \
# rna_barcodes
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506          B                   N/A
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508          B                   N/A
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516          E                   N/A
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508          B                   N/A
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507          B                   N/A
# ...                                         ...                   ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506          B                   N/A
# GACAATACACGTGCTG-1-HCA_A_LNG12177517          E                   N/A
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505          A                   N/A
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516          E                   N/A
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517          E                   N/A
#
#                                      author_batch_notes  \
# rna_barcodes
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506                N/A
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508                N/A
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516                N/A
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508                N/A
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507                N/A
# ...                                                 ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506                N/A
# GACAATACACGTGCTG-1-HCA_A_LNG12177517                N/A
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505                N/A
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516                N/A
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517                N/A
#
#                                      organism_ontology_term_id  ...  \
# rna_barcodes                                                    ...
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506            NCBITaxon:9606  ...
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508            NCBITaxon:9606  ...
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516            NCBITaxon:9606  ...
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508            NCBITaxon:9606  ...
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507            NCBITaxon:9606  ...
# ...                                                        ...  ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506            NCBITaxon:9606  ...
# GACAATACACGTGCTG-1-HCA_A_LNG12177517            NCBITaxon:9606  ...
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505            NCBITaxon:9606  ...
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516            NCBITaxon:9606  ...
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517            NCBITaxon:9606  ...
#
#                                      sequenced_fragment sequencing_platform  \
# rna_barcodes
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506        3 prime tag         EFO:0008637
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508        3 prime tag         EFO:0008637
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516        3 prime tag         EFO:0008637
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508        3 prime tag         EFO:0008637
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507        3 prime tag         EFO:0008637
# ...                                                 ...                 ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506        3 prime tag         EFO:0008637
# GACAATACACGTGCTG-1-HCA_A_LNG12177517        3 prime tag         EFO:0008637
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505        3 prime tag         EFO:0008637
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516        3 prime tag         EFO:0008637
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517        3 prime tag         EFO:0008637
#
#                                      is_primary_data reference_genome  \
# rna_barcodes
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506            true           GRCh38
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508            true           GRCh38
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516            true           GRCh38
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508            true           GRCh38
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507            true           GRCh38
# ...                                              ...              ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506            true           GRCh38
# GACAATACACGTGCTG-1-HCA_A_LNG12177517            true           GRCh38
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505            true           GRCh38
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516            true           GRCh38
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517            true           GRCh38
#
#                                      gene_annotation_version  \
# rna_barcodes
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506              Ensembl 93
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508              Ensembl 93
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516              Ensembl 93
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508              Ensembl 93
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507              Ensembl 93
# ...                                                      ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506              Ensembl 93
# GACAATACACGTGCTG-1-HCA_A_LNG12177517              Ensembl 93
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505              Ensembl 93
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516              Ensembl 93
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517              Ensembl 93
#
#                                      alignment_software intron_inclusion  \
# rna_barcodes
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506  cell ranger 3.0.2              yes
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508  cell ranger 3.0.2              yes
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516  cell ranger 3.0.2              yes
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508  cell ranger 3.0.2              yes
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507  cell ranger 3.0.2              yes
# ...                                                 ...              ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506  cell ranger 3.0.2              yes
# GACAATACACGTGCTG-1-HCA_A_LNG12177517  cell ranger 3.0.2              yes
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505  cell ranger 3.0.2              yes
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516  cell ranger 3.0.2              yes
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517  cell ranger 3.0.2              yes
#
#                                      disease_ontology_term_id  \
# rna_barcodes
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506             PATO:0000461
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508             PATO:0000461
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516             PATO:0000461
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508             PATO:0000461
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507             PATO:0000461
# ...                                                       ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506             PATO:0000461
# GACAATACACGTGCTG-1-HCA_A_LNG12177517             PATO:0000461
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505             PATO:0000461
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516             PATO:0000461
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517             PATO:0000461
#
#                                      self_reported_ethnicity_ontology_term_id  \
# rna_barcodes
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506                                  unknown
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508                                  unknown
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516                                  unknown
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508                                  unknown
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507                                  unknown
# ...                                                                       ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506                                  unknown
# GACAATACACGTGCTG-1-HCA_A_LNG12177517                                  unknown
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505                                  unknown
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516                                  unknown
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517                                  unknown
#
#                                      development_stage_ontology_term_id
# rna_barcodes
# TATCCAGCAGCGCTTG-1-HCA_A_LNG12177506                     HsapDv:0000237
# GGTGATTTCAAACACC-1-HCA_A_LNG12177508                     HsapDv:0000240
# GCAAACAAGGCCATCA-1-HCA_A_LNG12177516                     HsapDv:0000239
# CCCAATTGTCCCGGAA-1-HCA_A_LNG12177508                     HsapDv:0000240
# GACCTCAAGGAAGCTA-1-HCA_A_LNG12177507                     HsapDv:0000237
# ...                                                                 ...
# CTATGAGGTGTGTGGT-1-HCA_A_LNG12177506                     HsapDv:0000241
# GACAATACACGTGCTG-1-HCA_A_LNG12177517                     HsapDv:0000241
# GTTAGGCGTAACTACG-1-HCA_A_LNG12177505                     HsapDv:0000237
# TACAAGCTCAAAGGCA-1-HCA_A_LNG12177516                     HsapDv:0000240
# GTACTGGTCCGCCTAT-1-HCA_A_LNG12177517                     HsapDv:0000239
#
# [37339 rows x 37 columns]

# %% [markdown]
# # Add author cell type markers to UNS

# %%
# Already in object
adata.uns.keys()
# Out:
# dict_keys(['annot_colors', 'author_cell_type_markers', 'study_PI', 'title', 'unpublished'])

# %%
adata.uns[MARKER_GENES]
# Out:
#                           author_cell_type  \
# 0                                      AT1
# 1                                      AT2
# 2                                 B-memory
# 3                                  B-naive
# 4                             B-plasma-IgA
# 5                             B-plasma-IgG
# 6                                    Basal
# 7                          CD4-EM-Effector
# 8                             CD4-naive-CM
# 9                                   CD8-EM
# 10                             CD8-EM-EMRA
# 11                                 CD8-TRM
# 12                              CD8-TRM-EM
# 13                             Chondrocyte
# 14                                Ciliated
# 15                                    Club
# 16                                    DC-1
# 17                                    DC-2
# 18                            DC-activated
# 19               Endothelia-vascular-Cap-a
# 20               Endothelia-vascular-Cap-g
# 21  Endothelia-vascular-arterial-pulmonary
# 22    Endothelia-vascular-venous-pulmonary
# 23     Endothelia-vascular-venous-systemic
# 24                       Fibro-adventitial
# 25                          Fibro-alveolar
# 26                     Fibro-myofibroblast
# 27                     Fibro-peribronchial
# 28                     Fibro-perichondrial
# 29                                     GdT
# 30                                  Goblet
# 31                                     ILC
# 32                                    MAIT
# 33                                Macro-AW
# 34                          Macro-alveolar
# 35                      Macro-interstitial
# 36                     Macro-intravascular
# 37                                    Mast
# 38                           Monocyte-CD14
# 39                           Monocyte-CD16
# 40               Muscle-pericyte-pulmonary
# 41   Muscle-perivascular-immune-recruiting
# 42                    Muscle-smooth-airway
# 43                 Muscle-smooth-pulmonary
# 44                           Myoepithelial
# 45                         NAF-perineurial
# 46                                     NKT
# 47                               NK_CD16hi
# 48                           NK_CD56bright
# 49                                SMG-duct
# 50                              SMG-mucous
# 51                              SMG-serous
# 52                              Suprabasal
# 53                                   T-reg
# 54                      neural / endocrine
#
#                              author_cell_type_markers
# 0                                    AGER;RTKN2;CLIC5
# 1    SFTPC;SFTPA1;SFTPA2;WIF1;HHIP;CA2;ETV5;WIF1;HHIP
# 2                                      CD27;TNFRSF13B
# 3                                    IGHD;FCER2;TCL1A
# 4                                   IGHA1;IGHA2;CCR10
# 5                                   IGHG1;IGHG3;IGHG2
# 6   KRT5;TP63;S100A2;KRT6A;TNS4;MMP10;KRT14;DLK2;K...
# 7                                           CCR6;IL7R
# 8                             LTB;LEF1;CD28;KLF2;SELL
# 9                                PDCD1;DUSP2;NKG7;CD7
# 10                               GZMH;KLRG1;PFN1;GZMA
# 11            GZMB;CCL4;CCL5;ITGA1;PDCD1;ITGAE;ZNF683
# 12                  GZMK;EOMES;DTHD1;CRTAM;LYST;TNIP3
# 13               ACAN;CHAD;COL9A3;HAPLN1;COL2A1;CYTL1
# 14                                 GSTA1;DTHD1;DCDC2B
# 15                                            SCGB3A2
# 16          CLEC9A;XCR1;C1orf54;WDFY4;LGALS2;DNASE1L3
# 17                         CD1C;CLEC10A;FCGR2B;FCER1A
# 18                       CCR7;BIRC3;RASSF4;TRAF1;EBI3
# 19                           HPGD;EDNRB;IL1RL1;S100A3
# 20                               CA4;FCN3;SLC6A4;IL7R
# 21                                      GJA5;DKK2;BMX
# 22  CPE;DKK3;PDZRN4;EFEMP1;CDH11;PTGS1;MMRN1;PKHD1...
# 23  COL15A1;ZNF385D;EBF1;TSHZ2;FLRT2;OLFM1;CPXM2;T...
# 24                       SFRP2;PI16;FBLN2;CD248;MFAP5
# 25                                  TCF21;ITGA8;FGFR4
# 26  ITGBL1;ASPN;TSPAN8;LMOD1;NALCN;ITGBL1;WISP2;F2...
# 27  TMEM132C;PAPPA;COL13A1;ATRNL1;PLPPR4;LHFPL3;RG...
# 28  KDR;FGFR2;TMTC1;COL12A1;CHI3L1;RUNX2;SCARA3;ZF...
# 29             KLRC2;TRDC;TRDV1;TRG-AS1;TRGC1;KIR2DL4
# 30            MUC5AC;TSPAN8;CYP2F1;CEACAM5;VSIG2;FUT6
# 31                             AREG;SOX4;KIT;TNFRSF18
# 32    KLRB1;IL7R;IFNGR1;SLC4A10;TRAV1-2;TRBV6-2;DUSP2
# 33  CX3CR1;RGS1;C3;PALD1;MEF2C;DOCK4;EPB41L2;ADAM2...
# 34  MARCO;MCEMP1;INHBA;TREM1;ABHD5;PPARG;RETN;CD5L...
# 35  CXCL10;CXCL9;CXCL11;GBP1;GBP5;GBP4;GBP2;PSTPIP...
# 36          LILRB5;F13A1;STAB1;RNASE1;MAF;FOLR2;LYVE1
# 37  TPSAB1;TPSB2;CPA3;HPGDS;MS4A2;SLC18A2;TPSD1;RG...
# 38                                  S100A12;EREG;CD14
# 39  FCGR3A;LILRB2;LILRB1;MTSS1;FAM110A;LRRC25;CDKN...
# 40                 HIGD1B;COX4I2;PTN;LAMC3;MEST;KCNK3
# 41  CCL19;CCL2;CXCL12;CCL21;FGF7;TNC;CLSTN2;CHSY3 ...
# 42  HPSE2;COL4A6;PRUNE2;NRP2;SEMA3E;PCDH7;DOCK3;GP...
# 43                              ELN;COL1A1;TGM2;TNNT2
# 44                                   LAMA1;PLD5;FHOD3
# 45     PDZRN4;FGL2;SLC2A1;ITGA6;SORBS1;STXBP6;SLC22A3
# 46                                         S1PR1;IL32
# 47         FCER1G;GNLY;KLRF1;KIR2DL1;GZMB;FGFBP2;NKG7
# 48                 XCL1;CMC1;CD7;CCL3;NCR1;IL2RB;SRGN
# 49  CLU;PROM1;RARRES1;CCL28;ALDH1A3;PI3;MIA;KRT23;...
# 50                             BPIFB2;MUC5B;TFF3;TFF1
# 51    PRR4;LPO;PIP;S100A1;PRB3;C6orf58;PRB4;ODAM;PRH2
# 52                                 LY6D;PLAT;SERPINB4
# 53               FOXP3;CCR4;CTLA4;IL2RA;TNFRSF4;TIGIT
# 54                     CHGA;CALCA;ASCL1;CHGB;GRP;BEX1

# %%
ontology_mapping = adata.obs[[AUTHOR_CELL_TYPE, CELL_TYPE_ONTOLOGY_ID]].drop_duplicates(AUTHOR_CELL_TYPE).reset_index(drop=True)

ontology_mapping
# Out:
#                           author_cell_type cell_type_ontology_term_id
# 0                              Chondrocyte                 CL:0000138
# 1                                NK_CD16hi                 CL:0000939
# 2                           Fibro-alveolar                 CL:0002553
# 3                                      AT2                 CL:0002063
# 4                        Fibro-adventitial                 CL:0002503
# 5                                      AT1                 CL:0002062
# 6                          CD4-EM-Effector                 CL:0000905
# 7                     Muscle-smooth-airway                 CL:0019019
# 8                               SMG-mucous                 CL:4033037
# 9                            Monocyte-CD14                 CL:0001054
# 10                                   Basal                 CL:0002633
# 11     Endothelia-vascular-venous-systemic                 CL:0002543
# 12                              CD8-TRM-EM                 CL:4033039
# 13               Endothelia-vascular-Cap-g                 CL:4028002
# 14                     Macro-intravascular                 CL:0000235
# 15                            CD4-naive-CM                 CL:0000904
# 16                      neural / endocrine                 CL:0000165
# 17                                    DC-1                 CL:0000990
# 18                              SMG-serous                 CL:4033005
# 19                                 CD8-TRM                 CL:4033039
# 20                                    Mast                 CL:0000097
# 21                          Macro-alveolar                 CL:0000583
# 22                                 B-naive                 CL:0000788
# 23                                    Club                 CL:0000158
# 24                             CD8-EM-EMRA                 CL:0001062
# 25                     Fibro-peribronchial                 CL:2000093
# 26                                     NKT                 CL:0000623
# 27                            B-plasma-IgG                 CL:0000985
# 28                           Monocyte-CD16                 CL:0002396
# 29                                    DC-2                 CL:0000840
# 30                                  Goblet                 CL:0000160
# 31                            B-plasma-IgA                 CL:0000987
# 32  Endothelia-vascular-arterial-pulmonary                 CL:1001568
# 33                                B-memory                 CL:0000787
# 34               Muscle-pericyte-pulmonary                 CL:0009089
# 35                           Myoepithelial                 CL:0000185
# 36                                   T-reg                 CL:0000815
# 37                                Macro-AW                 CL:0000235
# 38                                    MAIT                 CL:0000940
# 39                      Macro-interstitial                 CL:4033043
# 40                                SMG-duct                 CL:4033024
# 41                                     GdT                 CL:0000798
# 42               Endothelia-vascular-Cap-a                 CL:4028003
# 43                 Muscle-smooth-pulmonary                        NaN
# 44                                Ciliated                 CL:0000067
# 45                                     ILC                 CL:0001065
# 46    Endothelia-vascular-venous-pulmonary                 CL:4033008
# 47                           NK_CD56bright                 CL:0002338
# 48                     Fibro-myofibroblast                 CL:0000186
# 49                              Suprabasal                 CL:4033048
# 50                                  CD8-EM                 CL:0000913
# 51                         NAF-perineurial                 CL:0000057
# 52                            DC-activated                 CL:0000841
# 53                     Fibro-perichondrial                 CL:4033026
# 54   Muscle-perivascular-immune-recruiting                 CL:0009089

# %%
adata.uns[MARKER_GENES][CELL_TYPE_ONTOLOGY_ID] = adata.uns[MARKER_GENES][AUTHOR_CELL_TYPE].map(dict(zip(ontology_mapping[AUTHOR_CELL_TYPE], ontology_mapping[CELL_TYPE_ONTOLOGY_ID])))

adata.uns[MARKER_GENES]
# Out:
#                           author_cell_type  \
# 0                                      AT1
# 1                                      AT2
# 2                                 B-memory
# 3                                  B-naive
# 4                             B-plasma-IgA
# 5                             B-plasma-IgG
# 6                                    Basal
# 7                          CD4-EM-Effector
# 8                             CD4-naive-CM
# 9                                   CD8-EM
# 10                             CD8-EM-EMRA
# 11                                 CD8-TRM
# 12                              CD8-TRM-EM
# 13                             Chondrocyte
# 14                                Ciliated
# 15                                    Club
# 16                                    DC-1
# 17                                    DC-2
# 18                            DC-activated
# 19               Endothelia-vascular-Cap-a
# 20               Endothelia-vascular-Cap-g
# 21  Endothelia-vascular-arterial-pulmonary
# 22    Endothelia-vascular-venous-pulmonary
# 23     Endothelia-vascular-venous-systemic
# 24                       Fibro-adventitial
# 25                          Fibro-alveolar
# 26                     Fibro-myofibroblast
# 27                     Fibro-peribronchial
# 28                     Fibro-perichondrial
# 29                                     GdT
# 30                                  Goblet
# 31                                     ILC
# 32                                    MAIT
# 33                                Macro-AW
# 34                          Macro-alveolar
# 35                      Macro-interstitial
# 36                     Macro-intravascular
# 37                                    Mast
# 38                           Monocyte-CD14
# 39                           Monocyte-CD16
# 40               Muscle-pericyte-pulmonary
# 41   Muscle-perivascular-immune-recruiting
# 42                    Muscle-smooth-airway
# 43                 Muscle-smooth-pulmonary
# 44                           Myoepithelial
# 45                         NAF-perineurial
# 46                                     NKT
# 47                               NK_CD16hi
# 48                           NK_CD56bright
# 49                                SMG-duct
# 50                              SMG-mucous
# 51                              SMG-serous
# 52                              Suprabasal
# 53                                   T-reg
# 54                      neural / endocrine
#
#                              author_cell_type_markers  \
# 0                                    AGER;RTKN2;CLIC5
# 1    SFTPC;SFTPA1;SFTPA2;WIF1;HHIP;CA2;ETV5;WIF1;HHIP
# 2                                      CD27;TNFRSF13B
# 3                                    IGHD;FCER2;TCL1A
# 4                                   IGHA1;IGHA2;CCR10
# 5                                   IGHG1;IGHG3;IGHG2
# 6   KRT5;TP63;S100A2;KRT6A;TNS4;MMP10;KRT14;DLK2;K...
# 7                                           CCR6;IL7R
# 8                             LTB;LEF1;CD28;KLF2;SELL
# 9                                PDCD1;DUSP2;NKG7;CD7
# 10                               GZMH;KLRG1;PFN1;GZMA
# 11            GZMB;CCL4;CCL5;ITGA1;PDCD1;ITGAE;ZNF683
# 12                  GZMK;EOMES;DTHD1;CRTAM;LYST;TNIP3
# 13               ACAN;CHAD;COL9A3;HAPLN1;COL2A1;CYTL1
# 14                                 GSTA1;DTHD1;DCDC2B
# 15                                            SCGB3A2
# 16          CLEC9A;XCR1;C1orf54;WDFY4;LGALS2;DNASE1L3
# 17                         CD1C;CLEC10A;FCGR2B;FCER1A
# 18                       CCR7;BIRC3;RASSF4;TRAF1;EBI3
# 19                           HPGD;EDNRB;IL1RL1;S100A3
# 20                               CA4;FCN3;SLC6A4;IL7R
# 21                                      GJA5;DKK2;BMX
# 22  CPE;DKK3;PDZRN4;EFEMP1;CDH11;PTGS1;MMRN1;PKHD1...
# 23  COL15A1;ZNF385D;EBF1;TSHZ2;FLRT2;OLFM1;CPXM2;T...
# 24                       SFRP2;PI16;FBLN2;CD248;MFAP5
# 25                                  TCF21;ITGA8;FGFR4
# 26  ITGBL1;ASPN;TSPAN8;LMOD1;NALCN;ITGBL1;WISP2;F2...
# 27  TMEM132C;PAPPA;COL13A1;ATRNL1;PLPPR4;LHFPL3;RG...
# 28  KDR;FGFR2;TMTC1;COL12A1;CHI3L1;RUNX2;SCARA3;ZF...
# 29             KLRC2;TRDC;TRDV1;TRG-AS1;TRGC1;KIR2DL4
# 30            MUC5AC;TSPAN8;CYP2F1;CEACAM5;VSIG2;FUT6
# 31                             AREG;SOX4;KIT;TNFRSF18
# 32    KLRB1;IL7R;IFNGR1;SLC4A10;TRAV1-2;TRBV6-2;DUSP2
# 33  CX3CR1;RGS1;C3;PALD1;MEF2C;DOCK4;EPB41L2;ADAM2...
# 34  MARCO;MCEMP1;INHBA;TREM1;ABHD5;PPARG;RETN;CD5L...
# 35  CXCL10;CXCL9;CXCL11;GBP1;GBP5;GBP4;GBP2;PSTPIP...
# 36          LILRB5;F13A1;STAB1;RNASE1;MAF;FOLR2;LYVE1
# 37  TPSAB1;TPSB2;CPA3;HPGDS;MS4A2;SLC18A2;TPSD1;RG...
# 38                                  S100A12;EREG;CD14
# 39  FCGR3A;LILRB2;LILRB1;MTSS1;FAM110A;LRRC25;CDKN...
# 40                 HIGD1B;COX4I2;PTN;LAMC3;MEST;KCNK3
# 41  CCL19;CCL2;CXCL12;CCL21;FGF7;TNC;CLSTN2;CHSY3 ...
# 42  HPSE2;COL4A6;PRUNE2;NRP2;SEMA3E;PCDH7;DOCK3;GP...
# 43                              ELN;COL1A1;TGM2;TNNT2
# 44                                   LAMA1;PLD5;FHOD3
# 45     PDZRN4;FGL2;SLC2A1;ITGA6;SORBS1;STXBP6;SLC22A3
# 46                                         S1PR1;IL32
# 47         FCER1G;GNLY;KLRF1;KIR2DL1;GZMB;FGFBP2;NKG7
# 48                 XCL1;CMC1;CD7;CCL3;NCR1;IL2RB;SRGN
# 49  CLU;PROM1;RARRES1;CCL28;ALDH1A3;PI3;MIA;KRT23;...
# 50                             BPIFB2;MUC5B;TFF3;TFF1
# 51    PRR4;LPO;PIP;S100A1;PRB3;C6orf58;PRB4;ODAM;PRH2
# 52                                 LY6D;PLAT;SERPINB4
# 53               FOXP3;CCR4;CTLA4;IL2RA;TNFRSF4;TIGIT
# 54                     CHGA;CALCA;ASCL1;CHGB;GRP;BEX1
#
#    cell_type_ontology_term_id
# 0                  CL:0002062
# 1                  CL:0002063
# 2                  CL:0000787
# 3                  CL:0000788
# 4                  CL:0000987
# 5                  CL:0000985
# 6                  CL:0002633
# 7                  CL:0000905
# 8                  CL:0000904
# 9                  CL:0000913
# 10                 CL:0001062
# 11                 CL:4033039
# 12                 CL:4033039
# 13                 CL:0000138
# 14                 CL:0000067
# 15                 CL:0000158
# 16                 CL:0000990
# 17                 CL:0000840
# 18                 CL:0000841
# 19                 CL:4028003
# 20                 CL:4028002
# 21                 CL:1001568
# 22                 CL:4033008
# 23                 CL:0002543
# 24                 CL:0002503
# 25                 CL:0002553
# 26                 CL:0000186
# 27                 CL:2000093
# 28                 CL:4033026
# 29                 CL:0000798
# 30                 CL:0000160
# 31                 CL:0001065
# 32                 CL:0000940
# 33                 CL:0000235
# 34                 CL:0000583
# 35                 CL:4033043
# 36                 CL:0000235
# 37                 CL:0000097
# 38                 CL:0001054
# 39                 CL:0002396
# 40                 CL:0009089
# 41                 CL:0009089
# 42                 CL:0019019
# 43                        NaN
# 44                 CL:0000185
# 45                 CL:0000057
# 46                 CL:0000623
# 47                 CL:0000939
# 48                 CL:0002338
# 49                 CL:4033024
# 50                 CL:4033037
# 51                 CL:4033005
# 52                 CL:4033048
# 53                 CL:0000815
# 54                 CL:0000165

# %%
adata.uns[MARKER_GENES] = adata.uns[MARKER_GENES].astype(str)

# %% [markdown]
# # Check author cell type annotations and Cell Ontology IDs

# %%
adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False)
# Out:
# AT2                                       6333
# SMG-mucous                                3399
# AT1                                       2990
# SMG-serous                                2691
# Macro-alveolar                            2149
# NK_CD16hi                                 1677
# Monocyte-CD14                             1428
# Chondrocyte                               1271
# Fibro-alveolar                            1229
# Macro-intravascular                       1049
# CD4-EM-Effector                            993
# CD4-naive-CM                               984
# Fibro-adventitial                          942
# Mast                                       831
# Endothelia-vascular-Cap-g                  789
# CD8-TRM-EM                                 768
# Monocyte-CD16                              673
# Club                                       634
# Basal                                      467
# Ciliated                                   413
# CD8-EM-EMRA                                385
# B-plasma-IgA                               351
# Macro-interstitial                         312
# B-memory                                   304
# T-reg                                      301
# Goblet                                     297
# GdT                                        289
# CD8-TRM                                    283
# B-naive                                    282
# Fibro-peribronchial                        220
# DC-2                                       214
# NK_CD56bright                              201
# Endothelia-vascular-Cap-a                  196
# Muscle-pericyte-pulmonary                  194
# Endothelia-vascular-arterial-pulmonary     190
# B-plasma-IgG                               178
# Muscle-smooth-pulmonary                    167
# MAIT                                       136
# Macro-AW                                   131
# NKT                                        131
# SMG-duct                                   126
# Endothelia-vascular-venous-pulmonary        97
# Muscle-smooth-airway                        89
# neural / endocrine                          77
# DC-1                                        68
# Myoepithelial                               59
# Endothelia-vascular-venous-systemic         59
# Fibro-myofibroblast                         56
# Suprabasal                                  54
# CD8-EM                                      43
# ILC                                         33
# Muscle-perivascular-immune-recruiting       30
# DC-activated                                30
# Fibro-perichondrial                         27
# NAF-perineurial                             19
# Name: author_cell_type, dtype: int64

# %%
adata.obs[CELL_TYPE_ONTOLOGY_ID].value_counts(dropna=False)
# Out:
# CL:0002063    6333
# CL:4033037    3399
# CL:0002062    2990
# CL:4033005    2691
# CL:0000583    2149
# CL:0000939    1677
# CL:0001054    1428
# CL:0000138    1271
# CL:0002553    1229
# CL:0000235    1180
# CL:4033039    1051
# CL:0000905     993
# CL:0000904     984
# CL:0002503     942
# CL:0000097     831
# CL:4028002     789
# CL:0002396     673
# CL:0000158     634
# CL:0002633     467
# CL:0000067     413
# CL:0001062     385
# CL:0000987     351
# CL:4033043     312
# CL:0000787     304
# CL:0000815     301
# CL:0000160     297
# CL:0000798     289
# CL:0000788     282
# CL:0009089     224
# CL:2000093     220
# CL:0000840     214
# CL:0002338     201
# CL:4028003     196
# CL:1001568     190
# CL:0000985     178
# NaN            167
# CL:0000940     136
# CL:0000623     131
# CL:4033024     126
# CL:4033008      97
# CL:0019019      89
# CL:0000165      77
# CL:0000990      68
# CL:0002543      59
# CL:0000185      59
# CL:0000186      56
# CL:4033048      54
# CL:0000913      43
# CL:0001065      33
# CL:0000841      30
# CL:4033026      27
# CL:0000057      19
# Name: cell_type_ontology_term_id, dtype: int64

# %%
adata.obs[MARKER_GENES] = adata.obs[AUTHOR_CELL_TYPE].map(dict(zip(adata.uns[MARKER_GENES][AUTHOR_CELL_TYPE], adata.uns[MARKER_GENES][MARKER_GENES])))
adata.obs[MARKER_GENES].value_counts(dropna=False)
# Out:
# SFTPC;SFTPA1;SFTPA2;WIF1;HHIP;CA2;ETV5;WIF1;HHIP                                                                                                           6333
# BPIFB2;MUC5B;TFF3;TFF1                                                                                                                                     3399
# AGER;RTKN2;CLIC5                                                                                                                                           2990
# PRR4;LPO;PIP;S100A1;PRB3;C6orf58;PRB4;ODAM;PRH2                                                                                                            2691
# MARCO;MCEMP1;INHBA;TREM1;ABHD5;PPARG;RETN;CD5L;FABP4                                                                                                       2149
# FCER1G;GNLY;KLRF1;KIR2DL1;GZMB;FGFBP2;NKG7                                                                                                                 1677
# S100A12;EREG;CD14                                                                                                                                          1428
# ACAN;CHAD;COL9A3;HAPLN1;COL2A1;CYTL1                                                                                                                       1271
# TCF21;ITGA8;FGFR4                                                                                                                                          1229
# LILRB5;F13A1;STAB1;RNASE1;MAF;FOLR2;LYVE1                                                                                                                  1049
# CCR6;IL7R                                                                                                                                                   993
# LTB;LEF1;CD28;KLF2;SELL                                                                                                                                     984
# SFRP2;PI16;FBLN2;CD248;MFAP5                                                                                                                                942
# TPSAB1;TPSB2;CPA3;HPGDS;MS4A2;SLC18A2;TPSD1;RGS13;HDC                                                                                                       831
# CA4;FCN3;SLC6A4;IL7R                                                                                                                                        789
# GZMK;EOMES;DTHD1;CRTAM;LYST;TNIP3                                                                                                                           768
# FCGR3A;LILRB2;LILRB1;MTSS1;FAM110A;LRRC25;CDKN1C;ABI3                                                                                                       673
# SCGB3A2                                                                                                                                                     634
# KRT5;TP63;S100A2;KRT6A;TNS4;MMP10;KRT14;DLK2;KRT15;COL17A1;LOXL4                                                                                            467
# GSTA1;DTHD1;DCDC2B                                                                                                                                          413
# GZMH;KLRG1;PFN1;GZMA                                                                                                                                        385
# IGHA1;IGHA2;CCR10                                                                                                                                           351
# CXCL10;CXCL9;CXCL11;GBP1;GBP5;GBP4;GBP2;PSTPIP2;SLAMF7;WARS;STAT1;GCH1;APOL3                                                                                312
# CD27;TNFRSF13B                                                                                                                                              304
# FOXP3;CCR4;CTLA4;IL2RA;TNFRSF4;TIGIT                                                                                                                        301
# MUC5AC;TSPAN8;CYP2F1;CEACAM5;VSIG2;FUT6                                                                                                                     297
# KLRC2;TRDC;TRDV1;TRG-AS1;TRGC1;KIR2DL4                                                                                                                      289
# GZMB;CCL4;CCL5;ITGA1;PDCD1;ITGAE;ZNF683                                                                                                                     283
# IGHD;FCER2;TCL1A                                                                                                                                            282
# TMEM132C;PAPPA;COL13A1;ATRNL1;PLPPR4;LHFPL3;RGN;CORIN;F13A1;LINC01436;FGF14;CHN1;PAPPA;PLCL1;NTRK3;SUGCT;PRDM6;ENOX1;ENTPD1;PDE3B;ATRNL1;COL15A1;PAG1       220
# CD1C;CLEC10A;FCGR2B;FCER1A                                                                                                                                  214
# XCL1;CMC1;CD7;CCL3;NCR1;IL2RB;SRGN                                                                                                                          201
# HPGD;EDNRB;IL1RL1;S100A3                                                                                                                                    196
# HIGD1B;COX4I2;PTN;LAMC3;MEST;KCNK3                                                                                                                          194
# GJA5;DKK2;BMX                                                                                                                                               190
# IGHG1;IGHG3;IGHG2                                                                                                                                           178
# ELN;COL1A1;TGM2;TNNT2                                                                                                                                       167
# KLRB1;IL7R;IFNGR1;SLC4A10;TRAV1-2;TRBV6-2;DUSP2                                                                                                             136
# CX3CR1;RGS1;C3;PALD1;MEF2C;DOCK4;EPB41L2;ADAM28;SERPINB9;ST6GAL1;FCGBP;SRGAP1;NFATC2;IGSF21;BCL2;SFMBT2;ATP8B4;INPP5D;SLC4A7;SIGLEC8;SIGLEC10;PLD4;HAMP     131
# S1PR1;IL32                                                                                                                                                  131
# CLU;PROM1;RARRES1;CCL28;ALDH1A3;PI3;MIA;KRT23;KRT7;SCGB3A1;RARRES1;ZNHIT6;KRT7;WNT5B                                                                        126
# CPE;DKK3;PDZRN4;EFEMP1;CDH11;PTGS1;MMRN1;PKHD1L1;HDAC9                                                                                                       97
# HPSE2;COL4A6;PRUNE2;NRP2;SEMA3E;PCDH7;DOCK3;GPM6A;HS6ST3;LGR6;PRUNE2;BCHE;#SCARA3;SCUBE1                                                                     89
# CHGA;CALCA;ASCL1;CHGB;GRP;BEX1                                                                                                                               77
# CLEC9A;XCR1;C1orf54;WDFY4;LGALS2;DNASE1L3                                                                                                                    68
# LAMA1;PLD5;FHOD3                                                                                                                                             59
# COL15A1;ZNF385D;EBF1;TSHZ2;FLRT2;OLFM1;CPXM2;TPD52L1                                                                                                         59
# ITGBL1;ASPN;TSPAN8;LMOD1;NALCN;ITGBL1;WISP2;F2R;WIF1;CCDC68;CHRM2                                                                                            56
# LY6D;PLAT;SERPINB4                                                                                                                                           54
# PDCD1;DUSP2;NKG7;CD7                                                                                                                                         43
# AREG;SOX4;KIT;TNFRSF18                                                                                                                                       33
# CCL19;CCL2;CXCL12;CCL21;FGF7;TNC;CLSTN2;CHSY3 ;FABP4;STEAP4                                                                                                  30
# CCR7;BIRC3;RASSF4;TRAF1;EBI3                                                                                                                                 30
# KDR;FGFR2;TMTC1;COL12A1;CHI3L1;RUNX2;SCARA3;ZFHX4;GRID2;PCDH11X                                                                                              27
# PDZRN4;FGL2;SLC2A1;ITGA6;SORBS1;STXBP6;SLC22A3                                                                                                               19
# Name: author_cell_type_markers, dtype: int64

# %% [markdown]
# # Check whether ENSEMBL IDs in var

# %%
adata.var
# Out:
#                  gene_symbol    feature_types  genome
# gene_ids
# ENSG00000243485  MIR1302-2HG  Gene Expression  GRCh38
# ENSG00000186092        OR4F5  Gene Expression  GRCh38
# ENSG00000238009   AL627309.1  Gene Expression  GRCh38
# ENSG00000239945   AL627309.3  Gene Expression  GRCh38
# ENSG00000239906   AL627309.2  Gene Expression  GRCh38
# ...                      ...              ...     ...
# ENSG00000277761   AC136616.2  Gene Expression  GRCh38
# ENSG00000278633   AC023491.2  Gene Expression  GRCh38
# ENSG00000276017   AC007325.1  Gene Expression  GRCh38
# ENSG00000278817   AC007325.4  Gene Expression  GRCh38
# ENSG00000277196   AC007325.2  Gene Expression  GRCh38
#
# [35045 rows x 3 columns]

# %%
adata.var['ensembl_id'] = adata.var.index
adata.var.index.name = 'index'
adata.var
# Out:
#                  gene_symbol    feature_types  genome       ensembl_id
# index
# ENSG00000243485  MIR1302-2HG  Gene Expression  GRCh38  ENSG00000243485
# ENSG00000186092        OR4F5  Gene Expression  GRCh38  ENSG00000186092
# ENSG00000238009   AL627309.1  Gene Expression  GRCh38  ENSG00000238009
# ENSG00000239945   AL627309.3  Gene Expression  GRCh38  ENSG00000239945
# ENSG00000239906   AL627309.2  Gene Expression  GRCh38  ENSG00000239906
# ...                      ...              ...     ...              ...
# ENSG00000277761   AC136616.2  Gene Expression  GRCh38  ENSG00000277761
# ENSG00000278633   AC023491.2  Gene Expression  GRCh38  ENSG00000278633
# ENSG00000276017   AC007325.1  Gene Expression  GRCh38  ENSG00000276017
# ENSG00000278817   AC007325.4  Gene Expression  GRCh38  ENSG00000278817
# ENSG00000277196   AC007325.2  Gene Expression  GRCh38  ENSG00000277196
#
# [35045 rows x 4 columns]

# %% [markdown]
# # Check raw data

# %%
adata.X.toarray().max()
# Out:
# 1448

# %%
adata.X = adata.X.astype(np.int64)

# %%
adata.raw = adata

# %%
adata.X
# Out:
# <37339x35045 sparse matrix of type '<class 'numpy.int64'>'
# 	with 78476531 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <37339x35045 sparse matrix of type '<class 'numpy.int64'>'
# 	with 78476531 stored elements in Compressed Sparse Row format>

# %%
adata.X.toarray().max()
# Out:
# 1448

# %%
adata.raw.X.toarray().max()
# Out:
# 1448

# %% [markdown]
# ## Validation result
#
# ### UNS Validation
# - OK: Tier 1 UNS Google Sheet
# - OK: Tier 1 UNS AnnData Object
#
# ### OBS Validation
# - Validation Error: Tier 1 OBS Google Sheet: 'Frozen' is not among available categories
# - Validation Error: Tier 1 OBS Anndata Object: 'Frozen' is not among available categories

# %% [markdown]
# # Data Submission Status
#
# - CHECK: Raw counts in X and in raw
# - REVISE: Tier 1 Metadata in OBS
# - CHECK: Cell Ontology IDs in OBS
# - CHECK: Author cell type in OBS
# - CHECK: Marker genes in UNS
# - CHECK: ENSEMBL IDs in var
#
# ### Revision:
#
# DONE

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
