# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import anndata2ri
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"
# Out:
# Warning message:
# package ‘methods’ was built under R version 4.3.3
# During startup - Warning messages:
# 1: package ‘datasets’ was built under R version 4.3.3
# 2: package ‘utils’ was built under R version 4.3.3
# 3: package ‘grDevices’ was built under R version 4.3.3
# 4: package ‘graphics’ was built under R version 4.3.3
# 5: package ‘stats’ was built under R version 4.3.3

# %%
DATASET_ID = "lungMAP"
H5AD_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/{DATASET_ID}.h5ad"
ONTOLOGIES_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/CellRef.ontologyID-mapping_20240508.xlsx"
MARKERS_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/cellref_marker_genes.xlsx"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
# Name constants
AUTHOR_CELL_TYPE_L0 = 'author_cell_type_level_0'
AUTHOR_CELL_TYPE_L1 = 'author_cell_type_level_1'
AUTHOR_CELL_TYPE_L2 = 'author_cell_type_level_2'

CELL_TYPE_ONTOLOGY_ID_L0 = 'cell_type_ontology_term_id_level_0'
CELL_TYPE_ONTOLOGY_ID_L1 = 'cell_type_ontology_term_id_level_1'
CELL_TYPE_ONTOLOGY_ID_L2 = 'cell_type_ontology_term_id_level_2'

MARKER_GENES_L0 = 'author_cell_type_markers_level_0'
MARKER_GENES_L1 = 'author_cell_type_markers_level_1'
MARKER_GENES_L2 = 'author_cell_type_markers_level_2'

# Finest grained annotation will be generic dataset cell type
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'
MARKER_GENES = 'author_cell_type_markers'

# %% [markdown]
# # Load data

# %%
obs = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "obs")
uns = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "uns")
adata = sc.read_h5ad(H5AD_PATH)

# %% [markdown]
# # Validate obs and uns from Tier 1 Metadata Template

# %%
val_workflow = ValidationWorkflow(
    input = uns,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                                                title                study_PI  \
# 0  Cells of human bronchus submucosal gland and l...  Whitsett, Xu, Morrisey
#
#   batch_condition default_embedding              unpublished comments
# 0          DataID              UMAP  protected under embargo

# %%
val_workflow = ValidationWorkflow(
    input = obs,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation error(s) encountered.
# {'manner_of_death': "Must be one of {1, 2, 3, 4, 0, 'unknown', 'not applicable'}. Invalid entries found."}
# Error containing field: manner_of_death
# Error message: Must be one of {1, 2, 3, 4, 0, 'unknown', 'not applicable'}. Invalid entries found.
# Value counts:
# N/A    22
# 2       3
# 1       2
# Name: manner_of_death, dtype: int64
# Returning error-containing OBS dataframe.
#             sample_ID           donor_id  \
# 0   CCHMC_SMG_Donor27  CCHMC_SMG_Donor27
# 1   CCHMC_SMG_Donor28  CCHMC_SMG_Donor28
# 2   CCHMC_SMG_Donor29  CCHMC_SMG_Donor29
# 3   CCHMC_SMG_Donor33  CCHMC_SMG_Donor33
# 4   CCHMC_SMG_Donor38  CCHMC_SMG_Donor38
# 5       EEM-scRNA-005          UPENN0424
# 6       EEM-scRNA-006          UPENN0070
# 7       EEM-scRNA-022          UPENN0056
# 8       EEM-scRNA-026          UPENN0004
# 9       EEM-scRNA-062          UPENN0457
# 10      EEM-scRNA-067          UPENN0078
# 11      EEM-scRNA-073          UPENN0058
# 12      EEM-scRNA-078          UPENN0423
# 13      EEM-scRNA-079          UPENN0191
# 14    EEM-scRNA-R05-1          UPENN5388
# 15    EEM-scRNA-R05-2          UPENN5388
# 16    EEM-scRNA-R06-1          UPENN4146
# 17    EEM-scRNA-R06-2          UPENN4146
# 18    EEM-scRNA-R07-1          UPENN0328
# 19    EEM-scRNA-R07-2          UPENN0328
# 20    EEM-scRNA-R15-1          UPENN0459
# 21    EEM-scRNA-R15-2          UPENN0459
# 22    EEM-scRNA-R20-1          UPENN0420
# 23    EEM-scRNA-R20-2          UPENN0420
# 24      EEM-scRNA-R36          UPENN0055
# 25    EEM-scRNA-R39-1          UPENN0121
# 26    EEM-scRNA-R39-2          UPENN0121
#
#                                      protocol_URL                   institute  \
# 0   In method section of CellRef (PMID: 37516747)                       CCHMC
# 1   In method section of CellRef (PMID: 37516747)                       CCHMC
# 2   In method section of CellRef (PMID: 37516747)                       CCHMC
# 3   In method section of CellRef (PMID: 37516747)                       CCHMC
# 4   In method section of CellRef (PMID: 37516747)                       CCHMC
# 5       dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 6       dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 7       dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 8       dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 9       dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 10      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 11      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 12      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 13      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 14      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 15      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 16      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 17      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 18      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 19      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 20      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 21      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 22      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 23      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 24      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 25      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
# 26      dx.doi.org/10.17504/protocols.io.b54gq8tw  University of Pennsylvania
#
#         sample_collection_site sample_collection_relative_time_point  \
# 0                        CCHMC
# 1                        CCHMC
# 2                        CCHMC
# 3                        CCHMC
# 4                        CCHMC
# 5   University of Pennsylvania
# 6   University of Pennsylvania
# 7   University of Pennsylvania
# 8   University of Pennsylvania
# 9   University of Pennsylvania
# 10  University of Pennsylvania
# 11  University of Pennsylvania
# 12  University of Pennsylvania
# 13  University of Pennsylvania
# 14  University of Pennsylvania
# 15  University of Pennsylvania
# 16  University of Pennsylvania
# 17  University of Pennsylvania
# 18  University of Pennsylvania
# 19  University of Pennsylvania
# 20  University of Pennsylvania
# 21  University of Pennsylvania
# 22  University of Pennsylvania
# 23  University of Pennsylvania
# 24  University of Pennsylvania
# 25  University of Pennsylvania
# 26  University of Pennsylvania
#
#            library_ID library_ID_repository author_batch_notes  \
# 0   CCHMC_SMG_Donor27                   N/A                N/A
# 1   CCHMC_SMG_Donor28                   N/A                N/A
# 2   CCHMC_SMG_Donor29                   N/A                N/A
# 3   CCHMC_SMG_Donor33                   N/A                N/A
# 4   CCHMC_SMG_Donor38                   N/A                N/A
# 5       EEM-scRNA-005            GSM5133604                N/A
# 6       EEM-scRNA-006                   N/A                N/A
# 7       EEM-scRNA-022                   N/A                N/A
# 8       EEM-scRNA-026                   N/A                N/A
# 9       EEM-scRNA-062                   N/A                N/A
# 10      EEM-scRNA-067                   N/A                N/A
# 11      EEM-scRNA-073                   N/A                N/A
# 12      EEM-scRNA-078                   N/A                N/A
# 13      EEM-scRNA-079                   N/A                N/A
# 14    EEM-scRNA-R05-1                   N/A                N/A
# 15    EEM-scRNA-R05-2                   N/A                N/A
# 16    EEM-scRNA-R06-1            GSM5133595                N/A
# 17    EEM-scRNA-R06-2            GSM5133596                N/A
# 18    EEM-scRNA-R07-1            GSM5133597                N/A
# 19    EEM-scRNA-R07-2            GSM5133598                N/A
# 20    EEM-scRNA-R15-1            GSM5133599                N/A
# 21    EEM-scRNA-R15-2            GSM5133600                N/A
# 22    EEM-scRNA-R20-1                   N/A                N/A
# 23    EEM-scRNA-R20-2                   N/A                N/A
# 24      EEM-scRNA-R36            GSM5133603                N/A
# 25    EEM-scRNA-R39-1                   N/A                N/A
# 26    EEM-scRNA-R39-2                   N/A                N/A
#
#    organism_ontology_term_id  ... sequenced_fragment sequencing_platform  \
# 0             NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 1             NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 2             NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 3             NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 4             NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 5             NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 6             NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 7             NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 8             NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 9             NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 10            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 11            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 12            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 13            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 14            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 15            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 16            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 17            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 18            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 19            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 20            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 21            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 22            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 23            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 24            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 25            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
# 26            NCBITaxon:9606  ...        3 prime tag         EFO:0008565
#
#    is_primary_data reference_genome gene_annotation_version  \
# 0             true           GRCh38   GENCODE v32/Ensembl98
# 1             true           GRCh38   GENCODE v32/Ensembl98
# 2             true           GRCh38   GENCODE v32/Ensembl98
# 3             true           GRCh38   GENCODE v32/Ensembl98
# 4             true           GRCh38   GENCODE v32/Ensembl98
# 5             true           GRCh38  GENCODE v44/Ensembl110
# 6             true           GRCh38  GENCODE v44/Ensembl110
# 7             true           GRCh38  GENCODE v44/Ensembl110
# 8             true           GRCh38  GENCODE v44/Ensembl110
# 9             true           GRCh38  GENCODE v44/Ensembl110
# 10            true           GRCh38  GENCODE v44/Ensembl110
# 11            true           GRCh38  GENCODE v44/Ensembl110
# 12            true           GRCh38  GENCODE v44/Ensembl110
# 13            true           GRCh38  GENCODE v44/Ensembl110
# 14            true           GRCh38  GENCODE v44/Ensembl110
# 15            true           GRCh38  GENCODE v44/Ensembl110
# 16            true           GRCh38  GENCODE v44/Ensembl110
# 17            true           GRCh38  GENCODE v44/Ensembl110
# 18            true           GRCh38  GENCODE v44/Ensembl110
# 19            true           GRCh38  GENCODE v44/Ensembl110
# 20            true           GRCh38  GENCODE v44/Ensembl110
# 21            true           GRCh38  GENCODE v44/Ensembl110
# 22            true           GRCh38  GENCODE v44/Ensembl110
# 23            true           GRCh38  GENCODE v44/Ensembl110
# 24            true           GRCh38  GENCODE v44/Ensembl110
# 25            true           GRCh38  GENCODE v44/Ensembl110
# 26            true           GRCh38  GENCODE v44/Ensembl110
#
#                alignment_software intron_inclusion disease_ontology_term_id  \
# 0               cell ranger 4.0.0               no             PATO:0000461
# 1               cell ranger 4.0.0               no             PATO:0000461
# 2               cell ranger 4.0.0               no             PATO:0000461
# 3               cell ranger 4.0.0               no             PATO:0000461
# 4               cell ranger 4.0.0               no             PATO:0000461
# 5   STARsolo 2.7.9a_EmptyDrops_CR               no             PATO:0000461
# 6   STARsolo 2.7.9a_EmptyDrops_CR               no             PATO:0000461
# 7   STARsolo 2.7.9a_EmptyDrops_CR               no             PATO:0000461
# 8   STARsolo 2.7.9a_EmptyDrops_CR               no             PATO:0000461
# 9   STARsolo 2.7.9a_EmptyDrops_CR               no             PATO:0000461
# 10  STARsolo 2.7.9a_EmptyDrops_CR               no             PATO:0000461
# 11  STARsolo 2.7.9a_EmptyDrops_CR               no             PATO:0000461
# 12  STARsolo 2.7.9a_EmptyDrops_CR               no             PATO:0000461
# 13  STARsolo 2.7.9a_EmptyDrops_CR               no             PATO:0000461
# 14               CellRanger 2.1.0               no             PATO:0000461
# 15               CellRanger 2.1.0               no             PATO:0000461
# 16               CellRanger 2.1.0               no             PATO:0000461
# 17               CellRanger 2.1.0               no             PATO:0000461
# 18               CellRanger 2.1.0               no             PATO:0000461
# 19               CellRanger 2.1.0               no             PATO:0000461
# 20               CellRanger 2.1.0               no             PATO:0000461
# 21               CellRanger 2.1.0               no             PATO:0000461
# 22               CellRanger 2.1.0               no             PATO:0000461
# 23               CellRanger 2.1.0               no             PATO:0000461
# 24               CellRanger 3.0.0               no             PATO:0000461
# 25               CellRanger 3.0.0               no             PATO:0000461
# 26               CellRanger 3.0.0               no             PATO:0000461
#
#    self_reported_ethnicity_ontology_term_id development_stage_ontology_term_id
# 0                                   unknown                     HsapDv:0000239
# 1                                   unknown                     HsapDv:0000237
# 2                                   unknown                     HsapDv:0000264
# 3                                   unknown                     HsapDv:0000240
# 4                                   unknown                     HsapDv:0000238
# 5                                   unknown                     HsapDv:0000237
# 6                                   unknown                     HsapDv:0000237
# 7                                   unknown                     HsapDv:0000268
# 8                                   unknown                     HsapDv:0000264
# 9                                   unknown                     HsapDv:0000240
# 10                                  unknown                     HsapDv:0000241
# 11                                  unknown                     HsapDv:0000240
# 12                                  unknown                     HsapDv:0000264
# 13                                  unknown                     HsapDv:0000239
# 14                                  unknown                     HsapDv:0000241
# 15                                  unknown                     HsapDv:0000241
# 16                                  unknown                     HsapDv:0000240
# 17                                  unknown                     HsapDv:0000240
# 18                                  unknown                     HsapDv:0000238
# 19                                  unknown                     HsapDv:0000238
# 20                                  unknown                     HsapDv:0000242
# 21                                  unknown                     HsapDv:0000242
# 22                                  unknown                     HsapDv:0000240
# 23                                  unknown                     HsapDv:0000240
# 24                                  unknown                     HsapDv:0000237
# 25                                  unknown                     HsapDv:0000242
# 26                                  unknown                     HsapDv:0000242
#
# [27 rows x 37 columns]

# %% [markdown]
# # Validate obs and uns from adata

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 347970 × 32284
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_SCT', 'nFeature_SCT', 'S.Score', 'G2M.Score', 'Phase', 'pMT', 'DataID', 'DonorID', 'Dataset', 'Age', 'Sex', 'lineage_level1', 'lineage_level2', 'celltype_level1', 'celltype_level2', 'celltype_level3', 'celltype_level3_fullname'
#     var: '_index', 'features'
#     obsm: 'X_pca', 'X_umap'

# %%
# When cross-checking lungMAP CellRef and HLCA v1, all were overlapping except for the following:
# Melms et al. 2021: A molecular single-cell lung atlas of lethal COVID-19
# https://www.nature.com/articles/s41586-021-03569-1

# %%
# subset to unpublished lungMAP datasets
adata = adata[adata.obs['Dataset'].isin(['UPenn_LungMAP', 'CCHMC_LungMAP'])].copy()

# %%
# check overlap between adata and obs
adata_ids = adata.obs['DataID'].value_counts().index.tolist()
obs_ids = obs['sample_ID'].value_counts().index.tolist()

non_overlap = list(set(adata_ids) - set(obs_ids))
non_overlap_other_side = list(set(obs_ids) - set(adata_ids))

# %%
merger = AnnDataMerger(
    adata = adata,
    uns_df = uns
)

adata = merger.add_uns_metadata()

adata
# Out:
# AnnData object with n_obs × n_vars = 122445 × 32284
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_SCT', 'nFeature_SCT', 'S.Score', 'G2M.Score', 'Phase', 'pMT', 'DataID', 'DonorID', 'Dataset', 'Age', 'Sex', 'lineage_level1', 'lineage_level2', 'celltype_level1', 'celltype_level2', 'celltype_level3', 'celltype_level3_fullname'
#     var: '_index', 'features'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments'
#     obsm: 'X_pca', 'X_umap'

# %%
# Merge obs and uns
merger = AnnDataMerger(
    adata = adata,
    obs_df = obs
)

adata = merger.add_obs_metadata(
    adata_col = 'DataID',
    df_col = 'sample_ID',
    skip = None
)

adata.obs['sample_ID'] = adata.obs['DataID']

adata.obs
# Out:
#                                            orig.ident  nCount_RNA  \
# Donor27_Donor27_AAACGAACACCGTGCA-1  CCHMC_SMG_Donor27     78067.0
# Donor27_Donor27_AAAGAACAGCGCCATC-1  CCHMC_SMG_Donor27     46370.0
# Donor27_Donor27_AAAGAACCAGGCAATG-1  CCHMC_SMG_Donor27     35041.0
# Donor27_Donor27_AAAGGATAGTAGCTCT-1  CCHMC_SMG_Donor27      6221.0
# Donor27_Donor27_AAAGTCCCATCCGGCA-1  CCHMC_SMG_Donor27      3455.0
# ...                                               ...         ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA              AICU191-1      2683.0
# EEM-scRNA-079_TTTGTTGAGGTAGGCT              AICU191-1      5823.0
# EEM-scRNA-079_TTTGTTGAGTTAACAG              AICU191-1     15731.0
# EEM-scRNA-079_TTTGTTGCACACGCCA              AICU191-1      3861.0
# EEM-scRNA-079_TTTGTTGCACAGAGCA              AICU191-1     25998.0
#
#                                     nFeature_RNA  nCount_SCT  nFeature_SCT  \
# Donor27_Donor27_AAACGAACACCGTGCA-1          5526     18752.0          2854
# Donor27_Donor27_AAAGAACAGCGCCATC-1          4765     18071.0          3371
# Donor27_Donor27_AAAGAACCAGGCAATG-1          4904     18520.0          4414
# Donor27_Donor27_AAAGGATAGTAGCTCT-1          2345     11826.0          2439
# Donor27_Donor27_AAAGTCCCATCCGGCA-1          1415     11196.0          1945
# ...                                          ...         ...           ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA              1224     10964.0          2190
# EEM-scRNA-079_TTTGTTGAGGTAGGCT              1916     12200.0          2186
# EEM-scRNA-079_TTTGTTGAGTTAACAG              3454     13043.0          3451
# EEM-scRNA-079_TTTGTTGCACACGCCA              2051     10594.0          2663
# EEM-scRNA-079_TTTGTTGCACAGAGCA              4263     12831.0          3832
#
#                                      S.Score  G2M.Score Phase        pMT  \
# Donor27_Donor27_AAACGAACACCGTGCA-1 -0.034438  -0.037647    G1   3.942845
# Donor27_Donor27_AAAGAACAGCGCCATC-1  0.000111  -0.053899     S   6.671827
# Donor27_Donor27_AAAGAACCAGGCAATG-1  0.006502  -0.042120     S   6.043456
# Donor27_Donor27_AAAGGATAGTAGCTCT-1 -0.018128  -0.012995    G1   5.891771
# Donor27_Donor27_AAAGTCCCATCCGGCA-1 -0.052171   0.041244   G2M   8.294931
# ...                                      ...        ...   ...        ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA     -0.029333  -0.050301    G1  10.266864
# EEM-scRNA-079_TTTGTTGAGGTAGGCT     -0.060900   0.021290   G2M   0.290499
# EEM-scRNA-079_TTTGTTGAGTTAACAG     -0.049283  -0.004591    G1   4.864282
# EEM-scRNA-079_TTTGTTGCACACGCCA     -0.049358  -0.021161    G1   6.606452
# EEM-scRNA-079_TTTGTTGCACAGAGCA     -0.039161  -0.026066    G1  11.383800
#
#                                                DataID  ...  \
# Donor27_Donor27_AAACGAACACCGTGCA-1  CCHMC_SMG_Donor27  ...
# Donor27_Donor27_AAAGAACAGCGCCATC-1  CCHMC_SMG_Donor27  ...
# Donor27_Donor27_AAAGAACCAGGCAATG-1  CCHMC_SMG_Donor27  ...
# Donor27_Donor27_AAAGGATAGTAGCTCT-1  CCHMC_SMG_Donor27  ...
# Donor27_Donor27_AAAGTCCCATCCGGCA-1  CCHMC_SMG_Donor27  ...
# ...                                               ...  ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA          EEM-scRNA-079  ...
# EEM-scRNA-079_TTTGTTGAGGTAGGCT          EEM-scRNA-079  ...
# EEM-scRNA-079_TTTGTTGAGTTAACAG          EEM-scRNA-079  ...
# EEM-scRNA-079_TTTGTTGCACACGCCA          EEM-scRNA-079  ...
# EEM-scRNA-079_TTTGTTGCACAGAGCA          EEM-scRNA-079  ...
#
#                                    sequencing_platform is_primary_data  \
# Donor27_Donor27_AAACGAACACCGTGCA-1         EFO:0008565            true
# Donor27_Donor27_AAAGAACAGCGCCATC-1         EFO:0008565            true
# Donor27_Donor27_AAAGAACCAGGCAATG-1         EFO:0008565            true
# Donor27_Donor27_AAAGGATAGTAGCTCT-1         EFO:0008565            true
# Donor27_Donor27_AAAGTCCCATCCGGCA-1         EFO:0008565            true
# ...                                                ...             ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA             EFO:0008565            true
# EEM-scRNA-079_TTTGTTGAGGTAGGCT             EFO:0008565            true
# EEM-scRNA-079_TTTGTTGAGTTAACAG             EFO:0008565            true
# EEM-scRNA-079_TTTGTTGCACACGCCA             EFO:0008565            true
# EEM-scRNA-079_TTTGTTGCACAGAGCA             EFO:0008565            true
#
#                                     reference_genome gene_annotation_version  \
# Donor27_Donor27_AAACGAACACCGTGCA-1            GRCh38   GENCODE v32/Ensembl98
# Donor27_Donor27_AAAGAACAGCGCCATC-1            GRCh38   GENCODE v32/Ensembl98
# Donor27_Donor27_AAAGAACCAGGCAATG-1            GRCh38   GENCODE v32/Ensembl98
# Donor27_Donor27_AAAGGATAGTAGCTCT-1            GRCh38   GENCODE v32/Ensembl98
# Donor27_Donor27_AAAGTCCCATCCGGCA-1            GRCh38   GENCODE v32/Ensembl98
# ...                                              ...                     ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA                GRCh38  GENCODE v44/Ensembl110
# EEM-scRNA-079_TTTGTTGAGGTAGGCT                GRCh38  GENCODE v44/Ensembl110
# EEM-scRNA-079_TTTGTTGAGTTAACAG                GRCh38  GENCODE v44/Ensembl110
# EEM-scRNA-079_TTTGTTGCACACGCCA                GRCh38  GENCODE v44/Ensembl110
# EEM-scRNA-079_TTTGTTGCACAGAGCA                GRCh38  GENCODE v44/Ensembl110
#
#                                                alignment_software  \
# Donor27_Donor27_AAACGAACACCGTGCA-1              cell ranger 4.0.0
# Donor27_Donor27_AAAGAACAGCGCCATC-1              cell ranger 4.0.0
# Donor27_Donor27_AAAGAACCAGGCAATG-1              cell ranger 4.0.0
# Donor27_Donor27_AAAGGATAGTAGCTCT-1              cell ranger 4.0.0
# Donor27_Donor27_AAAGTCCCATCCGGCA-1              cell ranger 4.0.0
# ...                                                           ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA      STARsolo 2.7.9a_EmptyDrops_CR
# EEM-scRNA-079_TTTGTTGAGGTAGGCT      STARsolo 2.7.9a_EmptyDrops_CR
# EEM-scRNA-079_TTTGTTGAGTTAACAG      STARsolo 2.7.9a_EmptyDrops_CR
# EEM-scRNA-079_TTTGTTGCACACGCCA      STARsolo 2.7.9a_EmptyDrops_CR
# EEM-scRNA-079_TTTGTTGCACAGAGCA      STARsolo 2.7.9a_EmptyDrops_CR
#
#                                    intron_inclusion disease_ontology_term_id  \
# Donor27_Donor27_AAACGAACACCGTGCA-1               no             PATO:0000461
# Donor27_Donor27_AAAGAACAGCGCCATC-1               no             PATO:0000461
# Donor27_Donor27_AAAGAACCAGGCAATG-1               no             PATO:0000461
# Donor27_Donor27_AAAGGATAGTAGCTCT-1               no             PATO:0000461
# Donor27_Donor27_AAAGTCCCATCCGGCA-1               no             PATO:0000461
# ...                                             ...                      ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA                   no             PATO:0000461
# EEM-scRNA-079_TTTGTTGAGGTAGGCT                   no             PATO:0000461
# EEM-scRNA-079_TTTGTTGAGTTAACAG                   no             PATO:0000461
# EEM-scRNA-079_TTTGTTGCACACGCCA                   no             PATO:0000461
# EEM-scRNA-079_TTTGTTGCACAGAGCA                   no             PATO:0000461
#
#                                    self_reported_ethnicity_ontology_term_id  \
# Donor27_Donor27_AAACGAACACCGTGCA-1                                  unknown
# Donor27_Donor27_AAAGAACAGCGCCATC-1                                  unknown
# Donor27_Donor27_AAAGAACCAGGCAATG-1                                  unknown
# Donor27_Donor27_AAAGGATAGTAGCTCT-1                                  unknown
# Donor27_Donor27_AAAGTCCCATCCGGCA-1                                  unknown
# ...                                                                     ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA                                      unknown
# EEM-scRNA-079_TTTGTTGAGGTAGGCT                                      unknown
# EEM-scRNA-079_TTTGTTGAGTTAACAG                                      unknown
# EEM-scRNA-079_TTTGTTGCACACGCCA                                      unknown
# EEM-scRNA-079_TTTGTTGCACAGAGCA                                      unknown
#
#                                    development_stage_ontology_term_id  \
# Donor27_Donor27_AAACGAACACCGTGCA-1                     HsapDv:0000239
# Donor27_Donor27_AAAGAACAGCGCCATC-1                     HsapDv:0000239
# Donor27_Donor27_AAAGAACCAGGCAATG-1                     HsapDv:0000239
# Donor27_Donor27_AAAGGATAGTAGCTCT-1                     HsapDv:0000239
# Donor27_Donor27_AAAGTCCCATCCGGCA-1                     HsapDv:0000239
# ...                                                               ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA                         HsapDv:0000239
# EEM-scRNA-079_TTTGTTGAGGTAGGCT                         HsapDv:0000239
# EEM-scRNA-079_TTTGTTGAGTTAACAG                         HsapDv:0000239
# EEM-scRNA-079_TTTGTTGCACACGCCA                         HsapDv:0000239
# EEM-scRNA-079_TTTGTTGCACAGAGCA                         HsapDv:0000239
#
#                                             sample_ID
# Donor27_Donor27_AAACGAACACCGTGCA-1  CCHMC_SMG_Donor27
# Donor27_Donor27_AAAGAACAGCGCCATC-1  CCHMC_SMG_Donor27
# Donor27_Donor27_AAAGAACCAGGCAATG-1  CCHMC_SMG_Donor27
# Donor27_Donor27_AAAGGATAGTAGCTCT-1  CCHMC_SMG_Donor27
# Donor27_Donor27_AAAGTCCCATCCGGCA-1  CCHMC_SMG_Donor27
# ...                                               ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA          EEM-scRNA-079
# EEM-scRNA-079_TTTGTTGAGGTAGGCT          EEM-scRNA-079
# EEM-scRNA-079_TTTGTTGAGTTAACAG          EEM-scRNA-079
# EEM-scRNA-079_TTTGTTGCACACGCCA          EEM-scRNA-079
# EEM-scRNA-079_TTTGTTGCACAGAGCA          EEM-scRNA-079
#
# [122445 rows x 57 columns]

# %% [markdown]
# # Add author cell type markers to UNS

# %%
ontologies = pd.read_excel(ONTOLOGIES_PATH, sheet_name = 'cellref celltype ontology ID')
ontologies
# Out:
#                  LungMAP Human Lung CellRef          Cell Ontology  \
# 0               Alveolar fibroblast 2 (AF2)             CL:4028006
# 1               Alveolar fibroblast 1 (AF1)             CL:4028004
# 2                  Alveolar macrophage (AM)             CL:0000583
# 3                Alveolar type 1 cell (AT1)             CL:0002062
# 4                Alveolar type 2 cell (AT2)             CL:0002063
# 5                                B cell (B)             CL:0000236
# 6                        Basal cell (Basal)             CL:0002633
# 7                       CD4+ T cell (CD4 T)             CL:0000624
# 8                       CD8+ T cell (CD8 T)             CL:0000625
# 9              Inflammatory monocyte (iMON)             CL:0000860
# 10               Secretory cell (Secretory)             CL:0000158
# 11             Classical DC subset 1 (cDC1)             CL:0000990
# 12             Classical DC subset 2 (cDC2)             CL:0002399
# 13         Deuterosomal cell (Deuterosomal)             CL:4033044
# 14                  Capillary 2 cell (CAP2)             CL:4028003
# 15          Arterial endothelial cell (AEC)             CL:1001568
# 16                  Capillary 1 cell (CAP1)             CL:4028002
# 17            Venous endothelial cell (VEC)             CL:0002543
# 18  Systemic venous endothelial cell (SVEC)         UBERON:0001592
# 19         Airway smooth muscle cell (ASMC)             CL:0019019
# 20                     Goblet cell (Goblet)             CL:0000160
# 21             Interstitial macrophage (IM)             CL:4033043
# 22                 Ionocyte cell (Ionocyte)             CL:0005006
# 23         Lymphatic endothelial cell (LEC)             CL:0002138
# 24            Mast/Basophil (Mast/Basophil)  CL:0000097/CL:0000767
# 25           Mesothelial cell (Mesothelial)             CL:0000077
# 26                  Mature DC subset (maDC)             CL_4033045
# 27                 Ciliated cell (Ciliated)             CL:4030034
# 28     Secondary crest myofibroblast (SCMF)             CL:0000186
# 29     Pulmonary neuroendocrine cell (PNEC)             CL:1000223
# 30                 Natural killer cell (NK)             CL:0000623
# 31               Patrolling monocyte (pMON)             CL:0000875
# 32                      Pericyte (Pericyte)             CL:0009089
# 33                     Plasma cell (Plasma)             CL:0000786
# 34                    Plasmacytoid DC (pDC)             CL:0000784
# 35     SMG Basal/Duct cell (SMG Basal/Duct)             CL:4033024
# 36                     Mucous cell (Mucous)             CL:4033022
# 37                     Serous cell (Serous)             CL:4033005
# 38       Vascular smooth muscle cell (VSMC)             CL:0000359
# 39             Suprabasal cell (Suprabasal)             CL_4033048
# 40  Respiratory airway secretory cell (RAS)         UBERON_0001955
# 41                         Tuft cell (Tuft)             CL:0002075
# 42                 Myoepithelial cell (MEC)             CL:4033003
# 43                               Neutrophil             CL:0000775
# 44                   Megakaryocyte/Platelet             CL:0000556
# 45                 T regulatory cell (Treg)             CL:0000815
# 46               Innate lymphoid cell (ILC)             CL:0001065
# 47                              Chondrocyte             CL:0000138
#
#                                                  NOTE  Unnamed: 3  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                 NaN         NaN
# 7                                                 NaN         NaN
# 8                                                 NaN         NaN
# 9                                                 NaN         NaN
# 10                                                NaN         NaN
# 11  Please advise if there is a better term for th...         NaN
# 12                                                NaN         NaN
# 13                                                NaN         NaN
# 14                                                NaN         NaN
# 15                                                NaN         NaN
# 16                                                NaN         NaN
# 17                                                NaN         NaN
# 18     Please advise if there is a cell ontology term         NaN
# 19            Please advise if there is a better term         NaN
# 20                                                NaN         NaN
# 21                                                NaN         NaN
# 22                                                NaN         NaN
# 23                                                NaN         NaN
# 24  if only a term is allowed, I think CL:0000097 ...         NaN
# 25                                                NaN         NaN
# 26  Based on the correlation mapping to HLCA migra...         NaN
# 27                                                NaN         NaN
# 28                                                NaN         NaN
# 29                                                NaN         NaN
# 30                                                NaN         NaN
# 31                                                NaN         NaN
# 32                                                NaN         NaN
# 33                                                NaN         NaN
# 34                                                NaN         NaN
# 35                                                NaN         NaN
# 36                                                NaN         NaN
# 37                                                NaN         NaN
# 38                                                NaN         NaN
# 39                                                NaN         NaN
# 40     Please advise if there is a cell ontology term         NaN
# 41                                                NaN         NaN
# 42                                                NaN         NaN
# 43                                                NaN         NaN
# 44                                                NaN         NaN
# 45                                                NaN         NaN
# 46                                                NaN         NaN
# 47                                                NaN         NaN
#
#     the mapping is updated
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31                     NaN
# 32                     NaN
# 33                     NaN
# 34                     NaN
# 35                     NaN
# 36                     NaN
# 37                     NaN
# 38                     NaN
# 39                     NaN
# 40                     NaN
# 41                     NaN
# 42                     NaN
# 43                     NaN
# 44                     NaN
# 45                     NaN
# 46                     NaN
# 47                     NaN

# %%
ontologies['Cell Ontology'] = ontologies['Cell Ontology'].str.replace('_', ':')

# replace 'CL:0000097/CL:0000767' in 'Cell Ontology' with 'CL:0000097'
ontologies['Cell Ontology'] = ontologies['Cell Ontology'].str.replace('/CL:0000767', '')

# Replace 'if only a term is allowed, I think CL:0000097 is a better match' in 'NOTE' with 'Not unambiguous, could be either CL:0000097 or CL:0000767'
ontologies['NOTE'] = ontologies['NOTE'].str.replace('if only a term is allowed, I think CL:0000097 is a better match', 'Not unambiguous, could be either CL:0000097 or CL:0000767')

ontologies.drop(columns = ['Unnamed: 3', 'the mapping is updated'], inplace = True)

ontologies.columns = [AUTHOR_CELL_TYPE, CELL_TYPE_ONTOLOGY_ID, 'Comment']

ontologies[['full_name', 'abbreviation']] = ontologies[AUTHOR_CELL_TYPE].str.extract(r'^(.*) \((.*)\)$')

ontologies['abbreviation'] = ontologies['abbreviation'].fillna(ontologies['author_cell_type'])
ontologies['full_name'] = ontologies['full_name'].fillna(ontologies['author_cell_type'])

ontologies
# Out:
#                            author_cell_type cell_type_ontology_term_id  \
# 0               Alveolar fibroblast 2 (AF2)                 CL:4028006
# 1               Alveolar fibroblast 1 (AF1)                 CL:4028004
# 2                  Alveolar macrophage (AM)                 CL:0000583
# 3                Alveolar type 1 cell (AT1)                 CL:0002062
# 4                Alveolar type 2 cell (AT2)                 CL:0002063
# 5                                B cell (B)                 CL:0000236
# 6                        Basal cell (Basal)                 CL:0002633
# 7                       CD4+ T cell (CD4 T)                 CL:0000624
# 8                       CD8+ T cell (CD8 T)                 CL:0000625
# 9              Inflammatory monocyte (iMON)                 CL:0000860
# 10               Secretory cell (Secretory)                 CL:0000158
# 11             Classical DC subset 1 (cDC1)                 CL:0000990
# 12             Classical DC subset 2 (cDC2)                 CL:0002399
# 13         Deuterosomal cell (Deuterosomal)                 CL:4033044
# 14                  Capillary 2 cell (CAP2)                 CL:4028003
# 15          Arterial endothelial cell (AEC)                 CL:1001568
# 16                  Capillary 1 cell (CAP1)                 CL:4028002
# 17            Venous endothelial cell (VEC)                 CL:0002543
# 18  Systemic venous endothelial cell (SVEC)             UBERON:0001592
# 19         Airway smooth muscle cell (ASMC)                 CL:0019019
# 20                     Goblet cell (Goblet)                 CL:0000160
# 21             Interstitial macrophage (IM)                 CL:4033043
# 22                 Ionocyte cell (Ionocyte)                 CL:0005006
# 23         Lymphatic endothelial cell (LEC)                 CL:0002138
# 24            Mast/Basophil (Mast/Basophil)                 CL:0000097
# 25           Mesothelial cell (Mesothelial)                 CL:0000077
# 26                  Mature DC subset (maDC)                 CL:4033045
# 27                 Ciliated cell (Ciliated)                 CL:4030034
# 28     Secondary crest myofibroblast (SCMF)                 CL:0000186
# 29     Pulmonary neuroendocrine cell (PNEC)                 CL:1000223
# 30                 Natural killer cell (NK)                 CL:0000623
# 31               Patrolling monocyte (pMON)                 CL:0000875
# 32                      Pericyte (Pericyte)                 CL:0009089
# 33                     Plasma cell (Plasma)                 CL:0000786
# 34                    Plasmacytoid DC (pDC)                 CL:0000784
# 35     SMG Basal/Duct cell (SMG Basal/Duct)                 CL:4033024
# 36                     Mucous cell (Mucous)                 CL:4033022
# 37                     Serous cell (Serous)                 CL:4033005
# 38       Vascular smooth muscle cell (VSMC)                 CL:0000359
# 39             Suprabasal cell (Suprabasal)                 CL:4033048
# 40  Respiratory airway secretory cell (RAS)             UBERON:0001955
# 41                         Tuft cell (Tuft)                 CL:0002075
# 42                 Myoepithelial cell (MEC)                 CL:4033003
# 43                               Neutrophil                 CL:0000775
# 44                   Megakaryocyte/Platelet                 CL:0000556
# 45                 T regulatory cell (Treg)                 CL:0000815
# 46               Innate lymphoid cell (ILC)                 CL:0001065
# 47                              Chondrocyte                 CL:0000138
#
#                                               Comment  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Please advise if there is a better term for th...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18     Please advise if there is a cell ontology term
# 19            Please advise if there is a better term
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  Not unambiguous, could be either CL:0000097 or...
# 25                                                NaN
# 26  Based on the correlation mapping to HLCA migra...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40     Please advise if there is a cell ontology term
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
#
#                             full_name            abbreviation
# 0               Alveolar fibroblast 2                     AF2
# 1               Alveolar fibroblast 1                     AF1
# 2                 Alveolar macrophage                      AM
# 3                Alveolar type 1 cell                     AT1
# 4                Alveolar type 2 cell                     AT2
# 5                              B cell                       B
# 6                          Basal cell                   Basal
# 7                         CD4+ T cell                   CD4 T
# 8                         CD8+ T cell                   CD8 T
# 9               Inflammatory monocyte                    iMON
# 10                     Secretory cell               Secretory
# 11              Classical DC subset 1                    cDC1
# 12              Classical DC subset 2                    cDC2
# 13                  Deuterosomal cell            Deuterosomal
# 14                   Capillary 2 cell                    CAP2
# 15          Arterial endothelial cell                     AEC
# 16                   Capillary 1 cell                    CAP1
# 17            Venous endothelial cell                     VEC
# 18   Systemic venous endothelial cell                    SVEC
# 19          Airway smooth muscle cell                    ASMC
# 20                        Goblet cell                  Goblet
# 21            Interstitial macrophage                      IM
# 22                      Ionocyte cell                Ionocyte
# 23         Lymphatic endothelial cell                     LEC
# 24                      Mast/Basophil           Mast/Basophil
# 25                   Mesothelial cell             Mesothelial
# 26                   Mature DC subset                    maDC
# 27                      Ciliated cell                Ciliated
# 28      Secondary crest myofibroblast                    SCMF
# 29      Pulmonary neuroendocrine cell                    PNEC
# 30                Natural killer cell                      NK
# 31                Patrolling monocyte                    pMON
# 32                           Pericyte                Pericyte
# 33                        Plasma cell                  Plasma
# 34                    Plasmacytoid DC                     pDC
# 35                SMG Basal/Duct cell          SMG Basal/Duct
# 36                        Mucous cell                  Mucous
# 37                        Serous cell                  Serous
# 38        Vascular smooth muscle cell                    VSMC
# 39                    Suprabasal cell              Suprabasal
# 40  Respiratory airway secretory cell                     RAS
# 41                          Tuft cell                    Tuft
# 42                 Myoepithelial cell                     MEC
# 43                         Neutrophil              Neutrophil
# 44             Megakaryocyte/Platelet  Megakaryocyte/Platelet
# 45                  T regulatory cell                    Treg
# 46               Innate lymphoid cell                     ILC
# 47                        Chondrocyte             Chondrocyte

# %%
cell_markers = pd.read_excel(MARKERS_PATH, sheet_name = 'Data S5', skiprows=2)

grouped_data = cell_markers.groupby('Cell type')['Genes'].agg(lambda x: '; '.join(x)).reset_index()
grouped_data.columns = ['Cell type', 'Marker genes']

grouped_data
# Out:
#                  Cell type                                       Marker genes
# 0                      AEC  DKK2; GJA5; BMX; IGFBP3; FAM107A; MT1A; PTPRB;...
# 1                      AF1  TCF21; PCDH15; WNT2; ROBO2; LUM; SLIT2; DCN; P...
# 2                      AF2  MFAP5; SCARA5; CDON; DCN; PLA2G2A; SFRP2; LUM;...
# 3                       AM  FABP4; MARCO; CYP27A1; PPARG; ABCG1; SIGLEC1; ...
# 4                     ASMC  DES; LGR6; BCHE; PLN; ASPN; PRUNE2; HSPB7; GRE...
# 5                      AT1  AGER; RTKN2; SEMA3B; NTM; NCKAP5; LMO7; KHDRBS...
# 6                      AT2  ABCA3; LAMP3; KCNJ15; SFTPC; SFTPA1; SFTPA2; S...
# 7                        B  BANK1; MS4A1; CD19; BACH2; IGHM; EBF1; CD79A; ...
# 8                    Basal  KRT5; TP63; NGFR; KRT15; KRT17; MMP10; S100A2;...
# 9                     CAP1  FCN3; IL7R; GPIHBP1; TMEM100; SLC6A4; IL1RL1; ...
# 10                    CAP2  HPGD; EDNRB; CA4; APLN; SOSTDC1; CLDN5; EMCN; ...
# 11                   CD4 T  CD3E; LEF1; CD40LG; MAL; CD4; CD69; ITK; LTB; ...
# 12                   CD8 T  CD8A; CD3E; CD8B; CCL5; NKG7; GZMA; GZMH; IL32...
# 13             Chondrocyte                         ACAN; HAPLN1; COL2A1; SOX9
# 14                Ciliated  RSPH1; CDHR3; FOXJ1; CDHR4; CAPS; C20orf85; C9...
# 15            Deuterosomal                       CDC20B; DEUP1; FOXN4; SHISA8
# 16                  Goblet  MUC5AC; AGR2; SPDEF; SLC4A11; PSCA; LYPD2; MUC...
# 17                     ILC                                 IL7R; CXCR3; TBX21
# 18                      IM  F13A1; STAB1; FOLR2; SLC40A1; CD163L1; MERTK; ...
# 19                Ionocyte  ASCL3; FOXI1; CFTR; CEL; TMEM61; SCNN1B; BPIFA...
# 20                     LEC  CCL21; MMRN1; PROX1; LYVE1; PPFIBP1; GNG11; SN...
# 21                     MEC  KRT14; MYH11; KRT17; SAA1; TPM2; ACTG2; MYLK; ...
# 22           Mast/Basophil  TPSB2; TPSAB1; MS4A2; CPA3; HPGDS; RGS1; VWA5A...
# 23  Megakaryocyte/Platelet  GP1BB; ITGA2B; ITGB3; PPBP; PF4; TUBB1; ACRBP;...
# 24             Mesothelial  UPK3B; CALB2; WT1; HP; ITLN1; PLA2G2A; PRG4; T...
# 25                  Mucous  BPIFB2; MUC5B; SPDEF; TFF1; AZGP1; TCN1; FAM3D...
# 26                      NK  NKG7; KLRD1; KLRC1; NCAM1; GNLY; GZMB; CCL4; P...
# 27              Neutrophil  FCGR3B; CSF3R; IL1B; S100A8; S100A12; G0S2; BC...
# 28                    PNEC  GRP; CALCA; ASCL1; NRXN1; PCSK1N; SCG2; CHGA; ...
# 29                Pericyte  PDGFRB; LAMC3; CSPG4; TRPC6; COX4I2; HIGD1B; B...
# 30                  Plasma  CD38; CD27; SDC1; JCHAIN; IGLC3; IGHM; IGHG1; ...
# 31                     RAS           SCGB3A2; MGP; SOX4; KLK11; TMEM45A; CTSE
# 32                    SCMF  ITGBL1; FGF18; PDGFRA; ASPN; CCN5; COL3A1; PRE...
# 33          SMG Basal/Duct  RARRES1; MIA; ALDH1A3; KRT14; SOX9; MMP7; SAA2...
# 34                    SVEC  ACKR1; COL15A1; VWA1; ABCB1; CCL14; PLVAP; AQP...
# 35               Secretory  SCGB1A1; BPIFB1; LCN2; TSPAN8; SCUBE2; SAA2; C...
# 36                  Serous  LYZ; LTF; LPO; PRB3; PRR4; PRB1; AC020656.1; P...
# 37              Suprabasal  KRT19; SERPINB4; NOTCH3; SERPINB3; S100A2; KRT...
# 38                    Treg  IL2RA; FOXP3; CTLA4; TRAC; LTB; TRBC1; CD3D; T...
# 39                    Tuft  IL23A; POU2F3; ASCL2; NREP; HEPACAM2; NMU; MYB...
# 40                     VEC  ACKR1; EPHB4; HDAC9; VWF; CCL23; C7; LIFR; PTP...
# 41                    VSMC  CNN1; NTRK3; ITGA7; TAGLN; MUSTN1; C11orf96; A...
# 42                    cDC1  CLEC9A; FLT3; ZBTB46; LGALS2; DNASE1L3; WDFY4;...
# 43                    cDC2  CD1E; CLEC10A; FCGR2B; CD1C; CCL17; FCER1A; MS...
# 44                    iMON  VCAN; FCN1; CD14; S100A8; JARID2; S100A12; THB...
# 45                    maDC  CCR7; LAD1; NCCRP1; CCL19; CCL22; CCL17; IL4I1...
# 46                     pDC  PLD4; LILRA4; CLEC4C; GZMB; IRF7; IRF8; GPR183...
# 47                    pMON  FCGR3A; FCN1; TNFRSF8; LST1; AIF1; SMIM25; SER...

# %%
ontologies[MARKER_GENES] = ontologies['abbreviation'].map(dict(zip(grouped_data['Cell type'], grouped_data['Marker genes'])))

ontologies
# Out:
#                            author_cell_type cell_type_ontology_term_id  \
# 0               Alveolar fibroblast 2 (AF2)                 CL:4028006
# 1               Alveolar fibroblast 1 (AF1)                 CL:4028004
# 2                  Alveolar macrophage (AM)                 CL:0000583
# 3                Alveolar type 1 cell (AT1)                 CL:0002062
# 4                Alveolar type 2 cell (AT2)                 CL:0002063
# 5                                B cell (B)                 CL:0000236
# 6                        Basal cell (Basal)                 CL:0002633
# 7                       CD4+ T cell (CD4 T)                 CL:0000624
# 8                       CD8+ T cell (CD8 T)                 CL:0000625
# 9              Inflammatory monocyte (iMON)                 CL:0000860
# 10               Secretory cell (Secretory)                 CL:0000158
# 11             Classical DC subset 1 (cDC1)                 CL:0000990
# 12             Classical DC subset 2 (cDC2)                 CL:0002399
# 13         Deuterosomal cell (Deuterosomal)                 CL:4033044
# 14                  Capillary 2 cell (CAP2)                 CL:4028003
# 15          Arterial endothelial cell (AEC)                 CL:1001568
# 16                  Capillary 1 cell (CAP1)                 CL:4028002
# 17            Venous endothelial cell (VEC)                 CL:0002543
# 18  Systemic venous endothelial cell (SVEC)             UBERON:0001592
# 19         Airway smooth muscle cell (ASMC)                 CL:0019019
# 20                     Goblet cell (Goblet)                 CL:0000160
# 21             Interstitial macrophage (IM)                 CL:4033043
# 22                 Ionocyte cell (Ionocyte)                 CL:0005006
# 23         Lymphatic endothelial cell (LEC)                 CL:0002138
# 24            Mast/Basophil (Mast/Basophil)                 CL:0000097
# 25           Mesothelial cell (Mesothelial)                 CL:0000077
# 26                  Mature DC subset (maDC)                 CL:4033045
# 27                 Ciliated cell (Ciliated)                 CL:4030034
# 28     Secondary crest myofibroblast (SCMF)                 CL:0000186
# 29     Pulmonary neuroendocrine cell (PNEC)                 CL:1000223
# 30                 Natural killer cell (NK)                 CL:0000623
# 31               Patrolling monocyte (pMON)                 CL:0000875
# 32                      Pericyte (Pericyte)                 CL:0009089
# 33                     Plasma cell (Plasma)                 CL:0000786
# 34                    Plasmacytoid DC (pDC)                 CL:0000784
# 35     SMG Basal/Duct cell (SMG Basal/Duct)                 CL:4033024
# 36                     Mucous cell (Mucous)                 CL:4033022
# 37                     Serous cell (Serous)                 CL:4033005
# 38       Vascular smooth muscle cell (VSMC)                 CL:0000359
# 39             Suprabasal cell (Suprabasal)                 CL:4033048
# 40  Respiratory airway secretory cell (RAS)             UBERON:0001955
# 41                         Tuft cell (Tuft)                 CL:0002075
# 42                 Myoepithelial cell (MEC)                 CL:4033003
# 43                               Neutrophil                 CL:0000775
# 44                   Megakaryocyte/Platelet                 CL:0000556
# 45                 T regulatory cell (Treg)                 CL:0000815
# 46               Innate lymphoid cell (ILC)                 CL:0001065
# 47                              Chondrocyte                 CL:0000138
#
#                                               Comment  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Please advise if there is a better term for th...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18     Please advise if there is a cell ontology term
# 19            Please advise if there is a better term
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  Not unambiguous, could be either CL:0000097 or...
# 25                                                NaN
# 26  Based on the correlation mapping to HLCA migra...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40     Please advise if there is a cell ontology term
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
#
#                             full_name            abbreviation  \
# 0               Alveolar fibroblast 2                     AF2
# 1               Alveolar fibroblast 1                     AF1
# 2                 Alveolar macrophage                      AM
# 3                Alveolar type 1 cell                     AT1
# 4                Alveolar type 2 cell                     AT2
# 5                              B cell                       B
# 6                          Basal cell                   Basal
# 7                         CD4+ T cell                   CD4 T
# 8                         CD8+ T cell                   CD8 T
# 9               Inflammatory monocyte                    iMON
# 10                     Secretory cell               Secretory
# 11              Classical DC subset 1                    cDC1
# 12              Classical DC subset 2                    cDC2
# 13                  Deuterosomal cell            Deuterosomal
# 14                   Capillary 2 cell                    CAP2
# 15          Arterial endothelial cell                     AEC
# 16                   Capillary 1 cell                    CAP1
# 17            Venous endothelial cell                     VEC
# 18   Systemic venous endothelial cell                    SVEC
# 19          Airway smooth muscle cell                    ASMC
# 20                        Goblet cell                  Goblet
# 21            Interstitial macrophage                      IM
# 22                      Ionocyte cell                Ionocyte
# 23         Lymphatic endothelial cell                     LEC
# 24                      Mast/Basophil           Mast/Basophil
# 25                   Mesothelial cell             Mesothelial
# 26                   Mature DC subset                    maDC
# 27                      Ciliated cell                Ciliated
# 28      Secondary crest myofibroblast                    SCMF
# 29      Pulmonary neuroendocrine cell                    PNEC
# 30                Natural killer cell                      NK
# 31                Patrolling monocyte                    pMON
# 32                           Pericyte                Pericyte
# 33                        Plasma cell                  Plasma
# 34                    Plasmacytoid DC                     pDC
# 35                SMG Basal/Duct cell          SMG Basal/Duct
# 36                        Mucous cell                  Mucous
# 37                        Serous cell                  Serous
# 38        Vascular smooth muscle cell                    VSMC
# 39                    Suprabasal cell              Suprabasal
# 40  Respiratory airway secretory cell                     RAS
# 41                          Tuft cell                    Tuft
# 42                 Myoepithelial cell                     MEC
# 43                         Neutrophil              Neutrophil
# 44             Megakaryocyte/Platelet  Megakaryocyte/Platelet
# 45                  T regulatory cell                    Treg
# 46               Innate lymphoid cell                     ILC
# 47                        Chondrocyte             Chondrocyte
#
#                              author_cell_type_markers
# 0   MFAP5; SCARA5; CDON; DCN; PLA2G2A; SFRP2; LUM;...
# 1   TCF21; PCDH15; WNT2; ROBO2; LUM; SLIT2; DCN; P...
# 2   FABP4; MARCO; CYP27A1; PPARG; ABCG1; SIGLEC1; ...
# 3   AGER; RTKN2; SEMA3B; NTM; NCKAP5; LMO7; KHDRBS...
# 4   ABCA3; LAMP3; KCNJ15; SFTPC; SFTPA1; SFTPA2; S...
# 5   BANK1; MS4A1; CD19; BACH2; IGHM; EBF1; CD79A; ...
# 6   KRT5; TP63; NGFR; KRT15; KRT17; MMP10; S100A2;...
# 7   CD3E; LEF1; CD40LG; MAL; CD4; CD69; ITK; LTB; ...
# 8   CD8A; CD3E; CD8B; CCL5; NKG7; GZMA; GZMH; IL32...
# 9   VCAN; FCN1; CD14; S100A8; JARID2; S100A12; THB...
# 10  SCGB1A1; BPIFB1; LCN2; TSPAN8; SCUBE2; SAA2; C...
# 11  CLEC9A; FLT3; ZBTB46; LGALS2; DNASE1L3; WDFY4;...
# 12  CD1E; CLEC10A; FCGR2B; CD1C; CCL17; FCER1A; MS...
# 13                       CDC20B; DEUP1; FOXN4; SHISA8
# 14  HPGD; EDNRB; CA4; APLN; SOSTDC1; CLDN5; EMCN; ...
# 15  DKK2; GJA5; BMX; IGFBP3; FAM107A; MT1A; PTPRB;...
# 16  FCN3; IL7R; GPIHBP1; TMEM100; SLC6A4; IL1RL1; ...
# 17  ACKR1; EPHB4; HDAC9; VWF; CCL23; C7; LIFR; PTP...
# 18  ACKR1; COL15A1; VWA1; ABCB1; CCL14; PLVAP; AQP...
# 19  DES; LGR6; BCHE; PLN; ASPN; PRUNE2; HSPB7; GRE...
# 20  MUC5AC; AGR2; SPDEF; SLC4A11; PSCA; LYPD2; MUC...
# 21  F13A1; STAB1; FOLR2; SLC40A1; CD163L1; MERTK; ...
# 22  ASCL3; FOXI1; CFTR; CEL; TMEM61; SCNN1B; BPIFA...
# 23  CCL21; MMRN1; PROX1; LYVE1; PPFIBP1; GNG11; SN...
# 24  TPSB2; TPSAB1; MS4A2; CPA3; HPGDS; RGS1; VWA5A...
# 25  UPK3B; CALB2; WT1; HP; ITLN1; PLA2G2A; PRG4; T...
# 26  CCR7; LAD1; NCCRP1; CCL19; CCL22; CCL17; IL4I1...
# 27  RSPH1; CDHR3; FOXJ1; CDHR4; CAPS; C20orf85; C9...
# 28  ITGBL1; FGF18; PDGFRA; ASPN; CCN5; COL3A1; PRE...
# 29  GRP; CALCA; ASCL1; NRXN1; PCSK1N; SCG2; CHGA; ...
# 30  NKG7; KLRD1; KLRC1; NCAM1; GNLY; GZMB; CCL4; P...
# 31  FCGR3A; FCN1; TNFRSF8; LST1; AIF1; SMIM25; SER...
# 32  PDGFRB; LAMC3; CSPG4; TRPC6; COX4I2; HIGD1B; B...
# 33  CD38; CD27; SDC1; JCHAIN; IGLC3; IGHM; IGHG1; ...
# 34  PLD4; LILRA4; CLEC4C; GZMB; IRF7; IRF8; GPR183...
# 35  RARRES1; MIA; ALDH1A3; KRT14; SOX9; MMP7; SAA2...
# 36  BPIFB2; MUC5B; SPDEF; TFF1; AZGP1; TCN1; FAM3D...
# 37  LYZ; LTF; LPO; PRB3; PRR4; PRB1; AC020656.1; P...
# 38  CNN1; NTRK3; ITGA7; TAGLN; MUSTN1; C11orf96; A...
# 39  KRT19; SERPINB4; NOTCH3; SERPINB3; S100A2; KRT...
# 40           SCGB3A2; MGP; SOX4; KLK11; TMEM45A; CTSE
# 41  IL23A; POU2F3; ASCL2; NREP; HEPACAM2; NMU; MYB...
# 42  KRT14; MYH11; KRT17; SAA1; TPM2; ACTG2; MYLK; ...
# 43  FCGR3B; CSF3R; IL1B; S100A8; S100A12; G0S2; BC...
# 44  GP1BB; ITGA2B; ITGB3; PPBP; PF4; TUBB1; ACRBP;...
# 45  IL2RA; FOXP3; CTLA4; TRAC; LTB; TRBC1; CD3D; T...
# 46                                 IL7R; CXCR3; TBX21
# 47                         ACAN; HAPLN1; COL2A1; SOX9

# %%
ontologies.to_csv("lungMAP_ontologies_marker_genes.csv", index = False)

# %%
adata.uns[MARKER_GENES] = ontologies.astype('category')
adata.uns[MARKER_GENES_L2] = ontologies.astype('category')
adata
# Out:
# AnnData object with n_obs × n_vars = 122445 × 32284
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_SCT', 'nFeature_SCT', 'S.Score', 'G2M.Score', 'Phase', 'pMT', 'DataID', 'DonorID', 'Dataset', 'Age', 'Sex', 'lineage_level1', 'lineage_level2', 'celltype_level1', 'celltype_level2', 'celltype_level3', 'celltype_level3_fullname', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'sample_ID'
#     var: '_index', 'features'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments', 'author_cell_type_markers', 'author_cell_type_markers_level_2'
#     obsm: 'X_pca', 'X_umap'

# %% [markdown]
# # Check author cell type annotations and Cell Ontology IDs

# %%
adata.obs.columns
# Out:
# Index(['orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_SCT',
#        'nFeature_SCT', 'S.Score', 'G2M.Score', 'Phase', 'pMT', 'DataID',
#        'DonorID', 'Dataset', 'Age', 'Sex', 'lineage_level1', 'lineage_level2',
#        'celltype_level1', 'celltype_level2', 'celltype_level3',
#        'celltype_level3_fullname', 'donor_id', 'protocol_URL', 'institute',
#        'sample_collection_site', 'sample_collection_relative_time_point',
#        'library_ID', 'library_ID_repository', 'author_batch_notes',
#        'organism_ontology_term_id', 'manner_of_death', 'sample_source',
#        'sex_ontology_term_id', 'sample_collection_method', 'tissue_type',
#        'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text',
#        'sample_preservation_method', 'suspension_type', 'cell_enrichment',
#        'cell_viability_percentage', 'cell_number_loaded',
#        'sample_collection_year', 'assay_ontology_term_id',
#        'library_preparation_batch', 'library_sequencing_run',
#        'sequenced_fragment', 'sequencing_platform', 'is_primary_data',
#        'reference_genome', 'gene_annotation_version', 'alignment_software',
#        'intron_inclusion', 'disease_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id',
#        'development_stage_ontology_term_id', 'sample_ID'],
#       dtype='object')

# %%
# celltype_level3 == finest annotation and maps to cell ontology ID dataframe
len(adata.obs['celltype_level3'].value_counts())
# Out:
# 47

# %%
# show non- overlap between celltype_level3 and 'abbreviation' of ontologies
non_overlap = list(set(adata.obs['celltype_level3'].value_counts().index.tolist()) - set(ontologies['abbreviation'].tolist()))
non_overlap_other_side = list(set(ontologies['abbreviation'].tolist()) - set(adata.obs['celltype_level3'].value_counts().index.tolist()))

# %%
# Deuterosomal in annotation but not in AnnData object
non_overlap_other_side
# Out:
# ['Deuterosomal']

# %%
# Specific annotations
adata.obs[AUTHOR_CELL_TYPE_L0] = adata.obs['celltype_level1']
adata.obs[AUTHOR_CELL_TYPE_L1] = adata.obs['celltype_level2']
adata.obs[AUTHOR_CELL_TYPE_L2] = adata.obs['celltype_level3']

adata.obs[CELL_TYPE_ONTOLOGY_ID_L2] = adata.obs['celltype_level3'].map(dict(zip(ontologies['abbreviation'], ontologies[CELL_TYPE_ONTOLOGY_ID])))

# Generic annotations
adata.obs[AUTHOR_CELL_TYPE] = adata.obs['celltype_level3']
adata.obs[CELL_TYPE_ONTOLOGY_ID] = adata.obs['celltype_level3'].map(dict(zip(ontologies['abbreviation'], ontologies[CELL_TYPE_ONTOLOGY_ID])))

# %% [markdown]
# # Check whether ENSEMBL IDs in var

# %%
adata.var
# Out:
#             _index     features
# 0      MIR1302-2HG  MIR1302-2HG
# 1          FAM138A      FAM138A
# 2            OR4F5        OR4F5
# 3       AL627309.1   AL627309.1
# 4       AL627309.3   AL627309.3
# ...            ...          ...
# 32279   AC141272.1   AC141272.1
# 32280   AC023491.2   AC023491.2
# 32281   AC007325.1   AC007325.1
# 32282   AC007325.4   AC007325.4
# 32283   AC007325.2   AC007325.2
#
# [32284 rows x 2 columns]

# %%
adata.var.index = adata.var['features']
adata.var.drop(columns = '_index', inplace = True)
adata.var.rename(columns={'features': 'gene_symbol'}, inplace = True)
adata.var.index.name = 'index'
adata.var
# Out:
#              gene_symbol
# index
# MIR1302-2HG  MIR1302-2HG
# FAM138A          FAM138A
# OR4F5              OR4F5
# AL627309.1    AL627309.1
# AL627309.3    AL627309.3
# ...                  ...
# AC141272.1    AC141272.1
# AC023491.2    AC023491.2
# AC007325.1    AC007325.1
# AC007325.4    AC007325.4
# AC007325.2    AC007325.2
#
# [32284 rows x 1 columns]

# %%
# get ensembl ids 
ensembl_mapping = pd.read_csv(f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/CellRef_genes.txt", sep="\t", header=0)

ensembl_mapping
# Out:
#                     id       symbol
# 0      ENSG00000243485  MIR1302-2HG
# 1      ENSG00000237613      FAM138A
# 2      ENSG00000186092        OR4F5
# 3      ENSG00000238009   AL627309.1
# 4      ENSG00000239945   AL627309.3
# ...                ...          ...
# 32279  ENSG00000277836   AC141272.1
# 32280  ENSG00000278633   AC023491.2
# 32281  ENSG00000276017   AC007325.1
# 32282  ENSG00000278817   AC007325.4
# 32283  ENSG00000277196   AC007325.2
#
# [32284 rows x 2 columns]

# %%
adata.var['ensembl_id'] = adata.var['gene_symbol'].map(dict(zip(ensembl_mapping['symbol'], ensembl_mapping['id'])))

adata.var
# Out:
#              gene_symbol       ensembl_id
# index
# MIR1302-2HG  MIR1302-2HG  ENSG00000243485
# FAM138A          FAM138A  ENSG00000237613
# OR4F5              OR4F5  ENSG00000186092
# AL627309.1    AL627309.1  ENSG00000238009
# AL627309.3    AL627309.3  ENSG00000239945
# ...                  ...              ...
# AC141272.1    AC141272.1  ENSG00000277836
# AC023491.2    AC023491.2  ENSG00000278633
# AC007325.1    AC007325.1  ENSG00000276017
# AC007325.4    AC007325.4  ENSG00000278817
# AC007325.2    AC007325.2  ENSG00000277196
#
# [32284 rows x 2 columns]

# %%
adata.var.dtypes
# Out:
# gene_symbol    object
# ensembl_id     object
# dtype: object

# %% [markdown]
# # Check raw data

# %%
adata.raw.X
# Out:
# <122445x32284 sparse matrix of type '<class 'numpy.float64'>'
# 	with 271059277 stored elements in Compressed Sparse Row format>

# %%
adata.obs['cell_viability_percentage'] = pd.to_numeric(adata.obs['cell_viability_percentage'], errors='coerce')
adata.obs['cell_number_loaded'] = pd.to_numeric(adata.obs['cell_number_loaded'], errors='coerce')
adata.obs['sample_collection_year'] = pd.to_numeric(adata.obs['sample_collection_year'], errors='coerce')
adata.obs['manner_of_death'] = pd.to_numeric(adata.obs['manner_of_death'], errors='coerce')

# %%
adata.obs
# Out:
#                                            orig.ident  nCount_RNA  \
# Donor27_Donor27_AAACGAACACCGTGCA-1  CCHMC_SMG_Donor27     78067.0
# Donor27_Donor27_AAAGAACAGCGCCATC-1  CCHMC_SMG_Donor27     46370.0
# Donor27_Donor27_AAAGAACCAGGCAATG-1  CCHMC_SMG_Donor27     35041.0
# Donor27_Donor27_AAAGGATAGTAGCTCT-1  CCHMC_SMG_Donor27      6221.0
# Donor27_Donor27_AAAGTCCCATCCGGCA-1  CCHMC_SMG_Donor27      3455.0
# ...                                               ...         ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA              AICU191-1      2683.0
# EEM-scRNA-079_TTTGTTGAGGTAGGCT              AICU191-1      5823.0
# EEM-scRNA-079_TTTGTTGAGTTAACAG              AICU191-1     15731.0
# EEM-scRNA-079_TTTGTTGCACACGCCA              AICU191-1      3861.0
# EEM-scRNA-079_TTTGTTGCACAGAGCA              AICU191-1     25998.0
#
#                                     nFeature_RNA  nCount_SCT  nFeature_SCT  \
# Donor27_Donor27_AAACGAACACCGTGCA-1          5526     18752.0          2854
# Donor27_Donor27_AAAGAACAGCGCCATC-1          4765     18071.0          3371
# Donor27_Donor27_AAAGAACCAGGCAATG-1          4904     18520.0          4414
# Donor27_Donor27_AAAGGATAGTAGCTCT-1          2345     11826.0          2439
# Donor27_Donor27_AAAGTCCCATCCGGCA-1          1415     11196.0          1945
# ...                                          ...         ...           ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA              1224     10964.0          2190
# EEM-scRNA-079_TTTGTTGAGGTAGGCT              1916     12200.0          2186
# EEM-scRNA-079_TTTGTTGAGTTAACAG              3454     13043.0          3451
# EEM-scRNA-079_TTTGTTGCACACGCCA              2051     10594.0          2663
# EEM-scRNA-079_TTTGTTGCACAGAGCA              4263     12831.0          3832
#
#                                      S.Score  G2M.Score Phase        pMT  \
# Donor27_Donor27_AAACGAACACCGTGCA-1 -0.034438  -0.037647    G1   3.942845
# Donor27_Donor27_AAAGAACAGCGCCATC-1  0.000111  -0.053899     S   6.671827
# Donor27_Donor27_AAAGAACCAGGCAATG-1  0.006502  -0.042120     S   6.043456
# Donor27_Donor27_AAAGGATAGTAGCTCT-1 -0.018128  -0.012995    G1   5.891771
# Donor27_Donor27_AAAGTCCCATCCGGCA-1 -0.052171   0.041244   G2M   8.294931
# ...                                      ...        ...   ...        ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA     -0.029333  -0.050301    G1  10.266864
# EEM-scRNA-079_TTTGTTGAGGTAGGCT     -0.060900   0.021290   G2M   0.290499
# EEM-scRNA-079_TTTGTTGAGTTAACAG     -0.049283  -0.004591    G1   4.864282
# EEM-scRNA-079_TTTGTTGCACACGCCA     -0.049358  -0.021161    G1   6.606452
# EEM-scRNA-079_TTTGTTGCACAGAGCA     -0.039161  -0.026066    G1  11.383800
#
#                                                DataID  ...  \
# Donor27_Donor27_AAACGAACACCGTGCA-1  CCHMC_SMG_Donor27  ...
# Donor27_Donor27_AAAGAACAGCGCCATC-1  CCHMC_SMG_Donor27  ...
# Donor27_Donor27_AAAGAACCAGGCAATG-1  CCHMC_SMG_Donor27  ...
# Donor27_Donor27_AAAGGATAGTAGCTCT-1  CCHMC_SMG_Donor27  ...
# Donor27_Donor27_AAAGTCCCATCCGGCA-1  CCHMC_SMG_Donor27  ...
# ...                                               ...  ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA          EEM-scRNA-079  ...
# EEM-scRNA-079_TTTGTTGAGGTAGGCT          EEM-scRNA-079  ...
# EEM-scRNA-079_TTTGTTGAGTTAACAG          EEM-scRNA-079  ...
# EEM-scRNA-079_TTTGTTGCACACGCCA          EEM-scRNA-079  ...
# EEM-scRNA-079_TTTGTTGCACAGAGCA          EEM-scRNA-079  ...
#
#                                    disease_ontology_term_id  \
# Donor27_Donor27_AAACGAACACCGTGCA-1             PATO:0000461
# Donor27_Donor27_AAAGAACAGCGCCATC-1             PATO:0000461
# Donor27_Donor27_AAAGAACCAGGCAATG-1             PATO:0000461
# Donor27_Donor27_AAAGGATAGTAGCTCT-1             PATO:0000461
# Donor27_Donor27_AAAGTCCCATCCGGCA-1             PATO:0000461
# ...                                                     ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA                 PATO:0000461
# EEM-scRNA-079_TTTGTTGAGGTAGGCT                 PATO:0000461
# EEM-scRNA-079_TTTGTTGAGTTAACAG                 PATO:0000461
# EEM-scRNA-079_TTTGTTGCACACGCCA                 PATO:0000461
# EEM-scRNA-079_TTTGTTGCACAGAGCA                 PATO:0000461
#
#                                    self_reported_ethnicity_ontology_term_id  \
# Donor27_Donor27_AAACGAACACCGTGCA-1                                  unknown
# Donor27_Donor27_AAAGAACAGCGCCATC-1                                  unknown
# Donor27_Donor27_AAAGAACCAGGCAATG-1                                  unknown
# Donor27_Donor27_AAAGGATAGTAGCTCT-1                                  unknown
# Donor27_Donor27_AAAGTCCCATCCGGCA-1                                  unknown
# ...                                                                     ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA                                      unknown
# EEM-scRNA-079_TTTGTTGAGGTAGGCT                                      unknown
# EEM-scRNA-079_TTTGTTGAGTTAACAG                                      unknown
# EEM-scRNA-079_TTTGTTGCACACGCCA                                      unknown
# EEM-scRNA-079_TTTGTTGCACAGAGCA                                      unknown
#
#                                     development_stage_ontology_term_id  \
# Donor27_Donor27_AAACGAACACCGTGCA-1                      HsapDv:0000239
# Donor27_Donor27_AAAGAACAGCGCCATC-1                      HsapDv:0000239
# Donor27_Donor27_AAAGAACCAGGCAATG-1                      HsapDv:0000239
# Donor27_Donor27_AAAGGATAGTAGCTCT-1                      HsapDv:0000239
# Donor27_Donor27_AAAGTCCCATCCGGCA-1                      HsapDv:0000239
# ...                                                                ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA                          HsapDv:0000239
# EEM-scRNA-079_TTTGTTGAGGTAGGCT                          HsapDv:0000239
# EEM-scRNA-079_TTTGTTGAGTTAACAG                          HsapDv:0000239
# EEM-scRNA-079_TTTGTTGCACACGCCA                          HsapDv:0000239
# EEM-scRNA-079_TTTGTTGCACAGAGCA                          HsapDv:0000239
#
#                                             sample_ID  \
# Donor27_Donor27_AAACGAACACCGTGCA-1  CCHMC_SMG_Donor27
# Donor27_Donor27_AAAGAACAGCGCCATC-1  CCHMC_SMG_Donor27
# Donor27_Donor27_AAAGAACCAGGCAATG-1  CCHMC_SMG_Donor27
# Donor27_Donor27_AAAGGATAGTAGCTCT-1  CCHMC_SMG_Donor27
# Donor27_Donor27_AAAGTCCCATCCGGCA-1  CCHMC_SMG_Donor27
# ...                                               ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA          EEM-scRNA-079
# EEM-scRNA-079_TTTGTTGAGGTAGGCT          EEM-scRNA-079
# EEM-scRNA-079_TTTGTTGAGTTAACAG          EEM-scRNA-079
# EEM-scRNA-079_TTTGTTGCACACGCCA          EEM-scRNA-079
# EEM-scRNA-079_TTTGTTGCACAGAGCA          EEM-scRNA-079
#
#                                    author_cell_type_level_0  \
# Donor27_Donor27_AAACGAACACCGTGCA-1                   Serous
# Donor27_Donor27_AAAGAACAGCGCCATC-1                   Serous
# Donor27_Donor27_AAAGAACCAGGCAATG-1                   Serous
# Donor27_Donor27_AAAGGATAGTAGCTCT-1                      LEC
# Donor27_Donor27_AAAGTCCCATCCGGCA-1                        T
# ...                                                     ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA                          AF1
# EEM-scRNA-079_TTTGTTGAGGTAGGCT                          AT2
# EEM-scRNA-079_TTTGTTGAGTTAACAG                           AM
# EEM-scRNA-079_TTTGTTGCACACGCCA                          AT1
# EEM-scRNA-079_TTTGTTGCACAGAGCA                           AM
#
#                                    author_cell_type_level_1  \
# Donor27_Donor27_AAACGAACACCGTGCA-1                   Serous
# Donor27_Donor27_AAAGAACAGCGCCATC-1                   Serous
# Donor27_Donor27_AAAGAACCAGGCAATG-1                   Serous
# Donor27_Donor27_AAAGGATAGTAGCTCT-1                      LEC
# Donor27_Donor27_AAAGTCCCATCCGGCA-1                    CD8 T
# ...                                                     ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA                          AF1
# EEM-scRNA-079_TTTGTTGAGGTAGGCT                          AT2
# EEM-scRNA-079_TTTGTTGAGTTAACAG                           AM
# EEM-scRNA-079_TTTGTTGCACACGCCA                          AT1
# EEM-scRNA-079_TTTGTTGCACAGAGCA                           AM
#
#                                    author_cell_type_level_2  \
# Donor27_Donor27_AAACGAACACCGTGCA-1                   Serous
# Donor27_Donor27_AAAGAACAGCGCCATC-1                   Serous
# Donor27_Donor27_AAAGAACCAGGCAATG-1                   Serous
# Donor27_Donor27_AAAGGATAGTAGCTCT-1                      LEC
# Donor27_Donor27_AAAGTCCCATCCGGCA-1                    CD8 T
# ...                                                     ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA                          AF1
# EEM-scRNA-079_TTTGTTGAGGTAGGCT                          AT2
# EEM-scRNA-079_TTTGTTGAGTTAACAG                           AM
# EEM-scRNA-079_TTTGTTGCACACGCCA                          AT1
# EEM-scRNA-079_TTTGTTGCACAGAGCA                           AM
#
#                                    cell_type_ontology_term_id_level_2  \
# Donor27_Donor27_AAACGAACACCGTGCA-1                         CL:4033005
# Donor27_Donor27_AAAGAACAGCGCCATC-1                         CL:4033005
# Donor27_Donor27_AAAGAACCAGGCAATG-1                         CL:4033005
# Donor27_Donor27_AAAGGATAGTAGCTCT-1                         CL:0002138
# Donor27_Donor27_AAAGTCCCATCCGGCA-1                         CL:0000625
# ...                                                               ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA                             CL:4028004
# EEM-scRNA-079_TTTGTTGAGGTAGGCT                             CL:0002063
# EEM-scRNA-079_TTTGTTGAGTTAACAG                             CL:0000583
# EEM-scRNA-079_TTTGTTGCACACGCCA                             CL:0002062
# EEM-scRNA-079_TTTGTTGCACAGAGCA                             CL:0000583
#
#                                    author_cell_type cell_type_ontology_term_id
# Donor27_Donor27_AAACGAACACCGTGCA-1           Serous                 CL:4033005
# Donor27_Donor27_AAAGAACAGCGCCATC-1           Serous                 CL:4033005
# Donor27_Donor27_AAAGAACCAGGCAATG-1           Serous                 CL:4033005
# Donor27_Donor27_AAAGGATAGTAGCTCT-1              LEC                 CL:0002138
# Donor27_Donor27_AAAGTCCCATCCGGCA-1            CD8 T                 CL:0000625
# ...                                             ...                        ...
# EEM-scRNA-079_TTTGGTTTCAGACCTA                  AF1                 CL:4028004
# EEM-scRNA-079_TTTGTTGAGGTAGGCT                  AT2                 CL:0002063
# EEM-scRNA-079_TTTGTTGAGTTAACAG                   AM                 CL:0000583
# EEM-scRNA-079_TTTGTTGCACACGCCA                  AT1                 CL:0002062
# EEM-scRNA-079_TTTGTTGCACAGAGCA                   AM                 CL:0000583
#
# [122445 rows x 63 columns]

# %%
adata.X.toarray().max()
# Out:
# 8.94130496645434

# %%
adata.X = adata.raw.X.astype(np.int64)

# %%
adata.raw = adata

# %%
adata.X
# Out:
# <122445x32284 sparse matrix of type '<class 'numpy.int64'>'
# 	with 271059277 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <122445x32284 sparse matrix of type '<class 'numpy.int64'>'
# 	with 271059277 stored elements in Compressed Sparse Row format>

# %%
adata.X.toarray().max()
# Out:
# 61871

# %%
adata.raw.X.toarray().max()
# Out:
# 61871

# %% [markdown]
# ## Validation result
#
# ### UNS Validation
# - OK: Tier 1 UNS Google Sheet
# - OK: Tier 1 UNS AnnData Object  same as Google Sheet
#
# ### OBS Validation
# - OK: Tier 1 OBS Google Sheet
# - OK: Tier 1 OBS AnnData Object same as Google Sheet

# %% [markdown]
# # Data Submission Status
#
# - CHECK: Raw data in X and in raw
# - CHECK: Tier 1 Metadata in OBS
# - CHECK: Cell Ontology IDs in OBS
# - CHECK: Author cell type in OBS
# - CHECK: Marker genes in UNS
# - MISSING: ENSEMBL IDs in var
#
# # Revisions:
#
# DONE

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
