# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import anndata2ri
from pathlib import Path
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"

pd.set_option('display.max_rows', 100)
# Out:
# Warning message:
# package ‘methods’ was built under R version 4.3.3
# During startup - Warning messages:
# 1: package ‘datasets’ was built under R version 4.3.3
# 2: package ‘utils’ was built under R version 4.3.3
# 3: package ‘grDevices’ was built under R version 4.3.3
# 4: package ‘graphics’ was built under R version 4.3.3
# 5: package ‘stats’ was built under R version 4.3.3

# %%
DATASET_ID = "Sauler_unpubl"
MTX_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/{DATASET_ID}.mtx"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
# Name constants
AUTHOR_CELL_TYPE_L0 = 'author_cell_type_level_0'
AUTHOR_CELL_TYPE_L1 = 'author_cell_type_level_1'

CELL_TYPE_ONTOLOGY_ID_L0 = 'cell_type_ontology_term_id_level_0'
CELL_TYPE_ONTOLOGY_ID_L1 = 'cell_type_ontology_term_id_level_1'

CELL_TYPE_ONTOLOGY_LABEL_L0 = 'cell_type_ontology_term_label_level_0'
CELL_TYPE_ONTOLOGY_LABEL_L1 = 'cell_type_ontology_term_label_level_1'

AUTHOR_CELL_TYPE_DESCRIPTION_L0 = 'author_cell_type_description_level_0'
AUTHOR_CELL_TYPE_DESCRIPTION_L1 = 'author_cell_type_description_level_1'

MARKER_GENES_L0 = 'author_cell_type_markers_level_0'
MARKER_GENES_L1 = 'author_cell_type_markers_level_1'

# Finest grained annotation will be generic dataset cell type
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'
CELL_TYPE_ONTOLOGY_LABEL = 'cell_type_ontology_term_label'
MARKER_GENES = 'author_cell_type_markers'
AUTHOR_CELL_TYPE_DESCRIPTION = 'author_cell_type_description'

# %% [markdown]
# # Load data

# %%
obs = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "obs")
uns = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "uns")

# %%
rds_dir = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/"
rds_files = [rds_dir+x for x in os.listdir(rds_dir) if x.endswith('RDS')]
rds_files
# Out:
# ['/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellVein.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellFibroblast_Adventitial.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellgCap.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellSecretory.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellPericyte.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellCiliated.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellAM.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellAT2.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellGoblet.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellSMC.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellAerocyte.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellT.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellBasal.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellMast.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellABC.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellFibroblast_PB.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellMonocyte.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellB_plasma.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellFibroblast_FRC.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellLymphatic.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellMesothelial.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellIM.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellSystemic.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellNK.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellArtery.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellFibroblast_Alveolar.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellPNEC.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellEndo_div.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellDC.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellFibroblast_CTHRC1.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellMac_div.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellAT1.RDS',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/rds_files/cellTuft.RDS']

# %%
anndata2ri.activate()
# %load_ext rpy2.ipython
# Out:
# /tmp/ipykernel_3780211/2547887543.py:1: DeprecationWarning: The global conversion available with activate() is deprecated and will be removed in the next major release. Use a local converter.
#   anndata2ri.activate()

# %%
# %%R -i rds_files
#
# mtx_dir = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/mtx_files/"
#
# for (rds_file in rds_files) {
#     rds = readRDS(rds_file)
#     barcodes = colnames(rds)
#     rds_basename = basename(rds_file)
#     rds_basename = sub("\\..*$", "", rds_basename)
#     rds_basename = substr(rds_basename, 5, nchar(rds_basename))
#     print(rds_basename)
#     print(length(barcodes))
#     print(dim(rds))
#     write.csv(barcodes, paste0(mtx_dir, rds_basename, "_barcodes.csv"))
#     writeMM(rds, paste0(mtx_dir, rds_basename, ".mtx"))
# }
# Out:
# [1] "Vein"
# [1] 2171
# [1] 36601  2171
# [1] "Fibroblast_Adventitial"
# [1] 5797
# [1] 36601  5797
# [1] "gCap"
# [1] 9131
# [1] 36601  9131
# [1] "Secretory"
# [1] 48914
# [1] 36601 48914
# [1] "Pericyte"
# [1] 1249
# [1] 36601  1249
# [1] "Ciliated"
# [1] 31003
# [1] 36601 31003
# [1] "AM"
# [1] 153741
# [1]  36601 153741
# [1] "AT2"
# [1] 596855
# [1]  36601 596855
# [1] "Goblet"
# [1] 9800
# [1] 36601  9800
# [1] "SMC"
# [1] 3545
# [1] 36601  3545
# [1] "Aerocyte"
# [1] 8001
# [1] 36601  8001
# [1] "T"
# [1] 10754
# [1] 36601 10754
# [1] "Basal"
# [1] 2584
# [1] 36601  2584
# [1] "Mast"
# [1] 786
# [1] 36601   786
# [1] "ABC"
# [1] 4155
# [1] 36601  4155
# [1] "Fibroblast_PB"
# [1] 2454
# [1] 36601  2454
# [1] "Monocyte"
# [1] 16477
# [1] 36601 16477
# [1] "B_plasma"
# [1] 1624
# [1] 36601  1624
# [1] "Fibroblast_FRC"
# [1] 528
# [1] 36601   528
# [1] "Lymphatic"
# [1] 7925
# [1] 36601  7925
# [1] "Mesothelial"
# [1] 3945
# [1] 36601  3945
# [1] "IM"
# [1] 12557
# [1] 36601 12557
# [1] "Systemic"
# [1] 1523
# [1] 36601  1523
# [1] "NK"
# [1] 2313
# [1] 36601  2313
# [1] "Artery"
# [1] 2891
# [1] 36601  2891
# [1] "Fibroblast_Alveolar"
# [1] 38338
# [1] 36601 38338
# [1] "PNEC"
# [1] 711
# [1] 36601   711
# [1] "Endo_div"
# [1] 127
# [1] 36601   127
# [1] "DC"
# [1] 1345
# [1] 36601  1345
# [1] "Fibroblast_CTHRC1"
# [1] 2311
# [1] 36601  2311
# [1] "Mac_div"
# [1] 5628
# [1] 36601  5628
# [1] "AT1"
# [1] 540665
# [1]  36601 540665
# [1] "Tuft"
# [1] 92
# [1] 36601    92

# %%
import scipy.io
import scipy.sparse

def read_mtx_file(file_path):
    return scipy.io.mmread(file_path)

dir_mtx = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/mtx_files/"

cell_types = [x.split('.')[0] for x in os.listdir(dir_mtx) if x.endswith('mtx')]

concatenated_matrix = None
cell_type_annotation = []
barcodes = []

for idx, cell_type in enumerate(cell_types):
    if idx == 0:
        print(f"First cell type: {cell_type}")
        concatenated_matrix = read_mtx_file(join(dir_mtx, f"{cell_type}.mtx"))
        barcodes += pd.read_csv(join(dir_mtx, f"{cell_type}_barcodes.csv"))['x'].tolist()
        cell_num = concatenated_matrix.shape[1]
        cell_type_annotation += [cell_type] * cell_num
        print(f"First cell type mtx shape: {concatenated_matrix.shape}")
        print(f"First cell type barcodes: {len(barcodes)}")
        print(f"First cell type cell num: {cell_num}")
        print("-----------------------------------------")
    else:
        print(f"Current cell type: {cell_type}")
        mtx = read_mtx_file(join(dir_mtx, f"{cell_type}.mtx"))
        concatenated_matrix = scipy.sparse.hstack([concatenated_matrix, mtx])
        barcodes += pd.read_csv(join(dir_mtx, f"{cell_type}_barcodes.csv"))['x'].tolist()
        cell_num = mtx.shape[1]
        cell_type_annotation += [cell_type] * cell_num
        print(f"Current cell type mtx shape: {mtx.shape}")
        print(f"Current cell type barcodes: {len(barcodes)}")
        print(f"Current cell type cell num: {cell_num}")
        print("-----------------------------------------")
# Out:
# First cell type: Fibroblast_Adventitial
# First cell type mtx shape: (36601, 5797)
# First cell type barcodes: 5797
# First cell type cell num: 5797
# -----------------------------------------
# Current cell type: Fibroblast_CTHRC1
# Current cell type mtx shape: (36601, 2311)
# Current cell type barcodes: 8108
# Current cell type cell num: 2311
# -----------------------------------------
# Current cell type: ABC
# Current cell type mtx shape: (36601, 4155)
# Current cell type barcodes: 12263
# Current cell type cell num: 4155
# -----------------------------------------
# Current cell type: NK
# Current cell type mtx shape: (36601, 2313)
# Current cell type barcodes: 14576
# Current cell type cell num: 2313
# -----------------------------------------
# Current cell type: Fibroblast_PB
# Current cell type mtx shape: (36601, 2454)
# Current cell type barcodes: 17030
# Current cell type cell num: 2454
# -----------------------------------------
# Current cell type: Fibroblast_Alveolar
# Current cell type mtx shape: (36601, 38338)
# Current cell type barcodes: 55368
# Current cell type cell num: 38338
# -----------------------------------------
# Current cell type: AT1
# Current cell type mtx shape: (36601, 540665)
# Current cell type barcodes: 596033
# Current cell type cell num: 540665
# -----------------------------------------
# Current cell type: Secretory
# Current cell type mtx shape: (36601, 48914)
# Current cell type barcodes: 644947
# Current cell type cell num: 48914
# -----------------------------------------
# Current cell type: AT2
# Current cell type mtx shape: (36601, 596855)
# Current cell type barcodes: 1241802
# Current cell type cell num: 596855
# -----------------------------------------
# Current cell type: Systemic
# Current cell type mtx shape: (36601, 1523)
# Current cell type barcodes: 1243325
# Current cell type cell num: 1523
# -----------------------------------------
# Current cell type: Vein
# Current cell type mtx shape: (36601, 2171)
# Current cell type barcodes: 1245496
# Current cell type cell num: 2171
# -----------------------------------------
# Current cell type: T
# Current cell type mtx shape: (36601, 10754)
# Current cell type barcodes: 1256250
# Current cell type cell num: 10754
# -----------------------------------------
# Current cell type: Monocyte
# Current cell type mtx shape: (36601, 16477)
# Current cell type barcodes: 1272727
# Current cell type cell num: 16477
# -----------------------------------------
# Current cell type: Tuft
# Current cell type mtx shape: (36601, 92)
# Current cell type barcodes: 1272819
# Current cell type cell num: 92
# -----------------------------------------
# Current cell type: Artery
# Current cell type mtx shape: (36601, 2891)
# Current cell type barcodes: 1275710
# Current cell type cell num: 2891
# -----------------------------------------
# Current cell type: Goblet
# Current cell type mtx shape: (36601, 9800)
# Current cell type barcodes: 1285510
# Current cell type cell num: 9800
# -----------------------------------------
# Current cell type: IM
# Current cell type mtx shape: (36601, 12557)
# Current cell type barcodes: 1298067
# Current cell type cell num: 12557
# -----------------------------------------
# Current cell type: Lymphatic
# Current cell type mtx shape: (36601, 7925)
# Current cell type barcodes: 1305992
# Current cell type cell num: 7925
# -----------------------------------------
# Current cell type: Basal
# Current cell type mtx shape: (36601, 2584)
# Current cell type barcodes: 1308576
# Current cell type cell num: 2584
# -----------------------------------------
# Current cell type: Mac_div
# Current cell type mtx shape: (36601, 5628)
# Current cell type barcodes: 1314204
# Current cell type cell num: 5628
# -----------------------------------------
# Current cell type: Aerocyte
# Current cell type mtx shape: (36601, 8001)
# Current cell type barcodes: 1322205
# Current cell type cell num: 8001
# -----------------------------------------
# Current cell type: Fibroblast_FRC
# Current cell type mtx shape: (36601, 528)
# Current cell type barcodes: 1322733
# Current cell type cell num: 528
# -----------------------------------------
# Current cell type: DC
# Current cell type mtx shape: (36601, 1345)
# Current cell type barcodes: 1324078
# Current cell type cell num: 1345
# -----------------------------------------
# Current cell type: Ciliated
# Current cell type mtx shape: (36601, 31003)
# Current cell type barcodes: 1355081
# Current cell type cell num: 31003
# -----------------------------------------
# Current cell type: Mast
# Current cell type mtx shape: (36601, 786)
# Current cell type barcodes: 1355867
# Current cell type cell num: 786
# -----------------------------------------
# Current cell type: Endo_div
# Current cell type mtx shape: (36601, 127)
# Current cell type barcodes: 1355994
# Current cell type cell num: 127
# -----------------------------------------
# Current cell type: Pericyte
# Current cell type mtx shape: (36601, 1249)
# Current cell type barcodes: 1357243
# Current cell type cell num: 1249
# -----------------------------------------
# Current cell type: B_plasma
# Current cell type mtx shape: (36601, 1624)
# Current cell type barcodes: 1358867
# Current cell type cell num: 1624
# -----------------------------------------
# Current cell type: AM
# Current cell type mtx shape: (36601, 153741)
# Current cell type barcodes: 1512608
# Current cell type cell num: 153741
# -----------------------------------------
# Current cell type: Mesothelial
# Current cell type mtx shape: (36601, 3945)
# Current cell type barcodes: 1516553
# Current cell type cell num: 3945
# -----------------------------------------
# Current cell type: gCap
# Current cell type mtx shape: (36601, 9131)
# Current cell type barcodes: 1525684
# Current cell type cell num: 9131
# -----------------------------------------
# Current cell type: SMC
# Current cell type mtx shape: (36601, 3545)
# Current cell type barcodes: 1529229
# Current cell type cell num: 3545
# -----------------------------------------
# Current cell type: PNEC
# Current cell type mtx shape: (36601, 711)
# Current cell type barcodes: 1529940
# Current cell type cell num: 711
# -----------------------------------------

# %%
# save sparse matrix
scipy.io.mmwrite("/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/count_matrix_all.mtx", concatenated_matrix)

# %%
# cell type annotation to dataframe
cell_type_annotation_df = pd.DataFrame(cell_type_annotation, columns=["cell_type"])
cell_type_annotation_df.to_csv("/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/cell_type_annotation.csv", index=False)

# %%
barcodes_df = pd.DataFrame(barcodes, columns=["barcode"])
barcodes_df.to_csv("/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/barcodes.csv", index=False)

# %%
# merged in separate script:
adata = sc.read_h5ad("/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/adata_raw.h5ad")

# %%
adata.obs['sample_ID'] = [x.split('_')[0] for x in adata.obs.index]

# %%
pd.set_option('display.max_rows', None)
adata.obs['sample_ID'].value_counts(dropna=False)
# Out:
# JN10XHT126    41152
# JN10XHT96     25920
# JN10XHT38     24653
# JN10XHT52     23215
# JN10XHT123    22563
# JN10XHT22     21997
# JN10XHT143    21902
# JN10XHT27     19992
# JN10XHT144    18758
# JN10XHT124    18667
# JN10XHT160    18574
# JN10XHT122    18513
# JN10XHT154    18327
# JN10XHT95     18300
# JN10XHT50     18267
# JN10XHT98     18226
# JN10XHT62     18123
# JN10XHT133    17454
# JN10XHT49     17450
# JN10XHT139    17361
# JN10XHT85     16950
# JN10XHT102    16711
# JN10XHT21     16595
# JN10XHT9      15776
# JN10XHT138    15589
# JN10XHT125    15483
# JN10XHT136    15210
# JN10XHT26     15146
# JN10XHT111    15137
# JN10XHT119    14998
# JN10XHT116    14970
# JN10XHT99     14945
# JN10XHT147    14796
# JN10XHT120    14707
# JN10XHT114    14411
# JN10XHT57     14398
# JN10XHT145    13955
# JN10XHT91     13878
# JN10XHT28     13865
# JN10XHT97     13851
# JN10XHT141    13830
# JN10XHT131    13771
# JN10XHT87     13578
# JN10XHT40     13437
# JN10XHT30     13269
# JN10XHT132    13254
# JN10XHT79     13217
# JN10XHT14     13125
# JN10XHT129    12917
# JN10XHT164    12805
# JN10XHT100    12752
# JN10XHT23     12748
# JN10XHT104    12679
# JN10XHT33     12560
# JN10XHT81     12526
# JN10XHT101    12512
# JN10XHT13     11800
# JN10XHT36     11675
# JN10XHT78     11601
# JN10XHT107    11540
# JN10XHT142    11259
# JN10XHT32     11170
# JN10XHT161    10803
# JN10XHT92     10749
# JN10XHT20     10685
# JN10XHT10     10484
# JN10XHT113    10465
# JN10XHT47     10377
# JN10XHT137    10173
# JN10XHT41     10135
# JN10XHT153    10062
# JN10XHT121    10032
# JN10XHT105     9983
# JN10XHT112     9945
# JN10XHT29      9847
# JN10XHT44      9824
# JN10XHT54      9605
# JN10XHT43      9582
# JN10XHT82      9517
# JN10XHT146     9483
# JN10XHT77      9459
# JN10XHT67      9108
# JN10XHT3       9031
# JN10XHT84      8937
# JN10XHT69      8841
# JN10XHT94      8826
# JN10XHT65      8732
# JN10XHT31      8730
# JN10XHT152     8125
# JN10XHT148     8037
# JN10XHT34      7979
# JN10XHT48      7659
# JN10XHT2       7632
# JN10XHT56      7593
# JN10XHT16      7451
# JN10XHT45      6932
# JN10XHT162     6909
# JN10XHT86      6842
# JN10XHT163     6829
# JN10XHT73      6785
# JN10XHT88      6405
# JN10XHT74      6249
# JN10XHT110     5984
# JN10XHT17      5870
# JN10XHT70      5763
# JN10XHT80      5711
# JN10XHT59      5485
# JN10XHT135     5426
# JN10XHT159     5393
# JN10XHT55      5383
# JN10XHT66      5335
# JN10XHT11      5177
# JN10XHT130     5098
# JN10XHT64      5060
# JN10XHT37      4860
# JN10XHT68      4689
# JN10XHT19      4643
# JN10XHT165     4524
# JN10XHT106     4455
# JN10XHT157     4404
# JN10XHT90      4259
# JN10XHT76      4237
# JN10XHT166     4125
# JN10XHT46      4085
# JN10XHT72      4049
# JN10XHT108     3905
# JN10XHT155     3728
# JN10XHT18      3542
# JN10XHT60      3484
# JN10XHT63      3291
# JN10XHT1       3260
# JN10XHT7       3154
# JN10XHT115     3084
# JN10XHT39      2906
# JN10XHT156     2798
# JN10XHT51      2741
# JN10XHT58      2526
# JN10XHT151     2487
# JN10XHT83      2295
# JN10XHT117     2290
# JN10XHT61      2089
# JN10XHT35      2086
# JN10XHT5       2038
# JN10XHT4       1946
# JN10XHT6       1871
# JN10XHT158     1848
# JN10XHT149     1794
# JN10XHT75      1567
# JN10XHT103     1522
# JN10XHT15        19
# JN10XHT128        2
# Name: sample_ID, dtype: int64

# %% [markdown]
# # Validate obs and uns from Tier 1 Metadata Template

# %%
val_workflow = ValidationWorkflow(
    input = uns,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                        title     study_PI batch_condition default_embedding  \
# 0  single NUQ RNA sequencing  Maor Sauler
#
#                                  unpublished comments
# 0  UNPUBLISHED Data, Protected under embargo

# %%
obs['donor_id'] = obs['donor_id'].astype(str)

val_workflow = ValidationWorkflow(
    input = obs,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation error(s) encountered.
# {
# │   'development_stage_ontology_term_id': "Must start with 'HsapDv:' or be 'na', 'NA', or 'N/A'. Invalid entries found."
# }
# Error containing field: development_stage_ontology_term_id
# Error message: Must start with 'HsapDv:' or be 'na', 'NA', or 'N/A'. Invalid entries found.
# Value counts:
# unknown    149
# Name: development_stage_ontology_term_id, dtype: int64
# Returning error-containing OBS dataframe.
#       sample_ID donor_id protocol_URL institute sample_collection_site  \
# 0      JN10XHT1      121          N/A      Yale                    N/A
# 1     JN10XHT10       71          N/A      Yale                    N/A
# 2    JN10XHT100       45          N/A      Yale                    N/A
# 3    JN10XHT101       46          N/A      Yale                    N/A
# 4    JN10XHT102       58          N/A      Yale                    N/A
# 5    JN10XHT103      142          N/A      Yale                    N/A
# 6    JN10XHT104       61          N/A      Yale                    N/A
# 7    JN10XHT105       37          N/A      Yale                    N/A
# 8    JN10XHT106       69          N/A      Yale                    N/A
# 9    JN10XHT107       23          N/A      Yale                    N/A
# 10   JN10XHT108      140          N/A      Yale                    N/A
# 11    JN10XHT11      132          N/A      Yale                    N/A
# 12   JN10XHT110      131          N/A      Yale                    N/A
# 13   JN10XHT111      124          N/A      Yale                    N/A
# 14   JN10XHT112      127          N/A      Yale                    N/A
# 15   JN10XHT113       15          N/A      Yale                    N/A
# 16   JN10XHT114      101          N/A      Yale                    N/A
# 17   JN10XHT115      120          N/A      Yale                    N/A
# 18   JN10XHT116       12          N/A      Yale                    N/A
# 19   JN10XHT117       67          N/A      Yale                    N/A
# 20   JN10XHT119       43          N/A      Yale                    N/A
# 21   JN10XHT120        3          N/A      Yale                    N/A
# 22   JN10XHT121       94          N/A      Yale                    N/A
# 23   JN10XHT122       92          N/A      Yale                    N/A
# 24   JN10XHT123       91          N/A      Yale                    N/A
# 25   JN10XHT124       42          N/A      Yale                    N/A
# 26   JN10XHT125       79          N/A      Yale                    N/A
# 27   JN10XHT126       76          N/A      Yale                    N/A
# 28   JN10XHT129       60          N/A      Yale                    N/A
# 29    JN10XHT13       93          N/A      Yale                    N/A
# 30   JN10XHT130       88          N/A      Yale                    N/A
# 31   JN10XHT131        9          N/A      Yale                    N/A
# 32   JN10XHT132       63          N/A      Yale                    N/A
# 33   JN10XHT133       72          N/A      Yale                    N/A
# 34   JN10XHT135       18          N/A      Yale                    N/A
# 35   JN10XHT136       59          N/A      Yale                    N/A
# 36   JN10XHT137       57          N/A      Yale                    N/A
# 37   JN10XHT138        6          N/A      Yale                    N/A
# 38   JN10XHT139       73          N/A      Yale                    N/A
# 39    JN10XHT14       52          N/A      Yale                    N/A
# 40   JN10XHT141       14          N/A      Yale                    N/A
# 41   JN10XHT142       17          N/A      Yale                    N/A
# 42   JN10XHT143       20          N/A      Yale                    N/A
# 43   JN10XHT144        2          N/A      Yale                    N/A
# 44   JN10XHT145       22          N/A      Yale                    N/A
# 45   JN10XHT146       38          N/A      Yale                    N/A
# 46   JN10XHT147      117          N/A      Yale                    N/A
# 47   JN10XHT148       77          N/A      Yale                    N/A
# 48   JN10XHT149       70          N/A      Yale                    N/A
# 49   JN10XHT151      121          N/A      Yale                    N/A
# 50   JN10XHT152       99          N/A      Yale                    N/A
# 51   JN10XHT153       64          N/A      Yale                    N/A
# 52   JN10XHT154       40          N/A      Yale                    N/A
# 53   JN10XHT155       36          N/A      Yale                    N/A
# 54   JN10XHT156       24          N/A      Yale                    N/A
# 55   JN10XHT157       25          N/A      Yale                    N/A
# 56   JN10XHT158       26          N/A      Yale                    N/A
# 57   JN10XHT159       47          N/A      Yale                    N/A
# 58    JN10XHT16      128          N/A      Yale                    N/A
# 59   JN10XHT160       34          N/A      Yale                    N/A
# 60   JN10XHT161       74          N/A      Yale                    N/A
# 61   JN10XHT162       49          N/A      Yale                    N/A
# 62   JN10XHT163       53          N/A      Yale                    N/A
# 63   JN10XHT164       84          N/A      Yale                    N/A
# 64   JN10XHT165       96          N/A      Yale                    N/A
# 65   JN10XHT166      108          N/A      Yale                    N/A
# 66    JN10XHT17      109          N/A      Yale                    N/A
# 67    JN10XHT18      130          N/A      Yale                    N/A
# 68    JN10XHT19       89          N/A      Yale                    N/A
# 69     JN10XHT2      114          N/A      Yale                    N/A
# 70    JN10XHT20       86          N/A      Yale                    N/A
# 71    JN10XHT21      105          N/A      Yale                    N/A
# 72    JN10XHT22      114          N/A      Yale                    N/A
# 73    JN10XHT23       13          N/A      Yale                    N/A
# 74    JN10XHT26       27          N/A      Yale                    N/A
# 75    JN10XHT27       39          N/A      Yale                    N/A
# 76    JN10XHT28      106          N/A      Yale                    N/A
# 77    JN10XHT29      125          N/A      Yale                    N/A
# 78     JN10XHT3      114          N/A      Yale                    N/A
# 79    JN10XHT30      136          N/A      Yale                    N/A
# 80    JN10XHT31       48          N/A      Yale                    N/A
# 81    JN10XHT32       82          N/A      Yale                    N/A
# 82    JN10XHT33      135          N/A      Yale                    N/A
# 83    JN10XHT34      133          N/A      Yale                    N/A
# 84    JN10XHT35       11          N/A      Yale                    N/A
# 85    JN10XHT36      138          N/A      Yale                    N/A
# 86    JN10XHT37       19          N/A      Yale                    N/A
# 87    JN10XHT38      119          N/A      Yale                    N/A
# 88    JN10XHT39      139          N/A      Yale                    N/A
# 89     JN10XHT4       99          N/A      Yale                    N/A
# 90    JN10XHT40      137          N/A      Yale                    N/A
# 91    JN10XHT41       55          N/A      Yale                    N/A
# 92    JN10XHT43       83          N/A      Yale                    N/A
# 93    JN10XHT44       95          N/A      Yale                    N/A
# 94    JN10XHT45        1          N/A      Yale                    N/A
# 95    JN10XHT46       44          N/A      Yale                    N/A
# 96    JN10XHT47        7          N/A      Yale                    N/A
# 97    JN10XHT48        8          N/A      Yale                    N/A
# 98    JN10XHT49      141          N/A      Yale                    N/A
# 99     JN10XHT5       99          N/A      Yale                    N/A
# 100   JN10XHT50      116          N/A      Yale                    N/A
# 101   JN10XHT51       97          N/A      Yale                    N/A
# 102   JN10XHT52      102          N/A      Yale                    N/A
# 103   JN10XHT54       68          N/A      Yale                    N/A
# 104   JN10XHT55       75          N/A      Yale                    N/A
# 105   JN10XHT56       78          N/A      Yale                    N/A
# 106   JN10XHT57       10          N/A      Yale                    N/A
# 107   JN10XHT58       16          N/A      Yale                    N/A
# 108   JN10XHT59       28          N/A      Yale                    N/A
# 109    JN10XHT6       33          N/A      Yale                    N/A
# 110   JN10XHT60       41          N/A      Yale                    N/A
# 111   JN10XHT61       81          N/A      Yale                    N/A
# 112   JN10XHT62       65          N/A      Yale                    N/A
# 113   JN10XHT63       85          N/A      Yale                    N/A
# 114   JN10XHT64       98          N/A      Yale                    N/A
# 115   JN10XHT65      110          N/A      Yale                    N/A
# 116   JN10XHT66      115          N/A      Yale                    N/A
# 117   JN10XHT67      129          N/A      Yale                    N/A
# 118   JN10XHT68      134          N/A      Yale                    N/A
# 119   JN10XHT69       62          N/A      Yale                    N/A
# 120    JN10XHT7        4          N/A      Yale                    N/A
# 121   JN10XHT70      123          N/A      Yale                    N/A
# 122   JN10XHT72       29          N/A      Yale                    N/A
# 123   JN10XHT73       14          N/A      Yale                    N/A
# 124   JN10XHT74       17          N/A      Yale                    N/A
# 125   JN10XHT75       50          N/A      Yale                    N/A
# 126   JN10XHT76       51          N/A      Yale                    N/A
# 127   JN10XHT77       54          N/A      Yale                    N/A
# 128   JN10XHT78       56          N/A      Yale                    N/A
# 129   JN10XHT79       21          N/A      Yale                    N/A
# 130   JN10XHT80       65          N/A      Yale                    N/A
# 131   JN10XHT81       66          N/A      Yale                    N/A
# 132   JN10XHT82      111          N/A      Yale                    N/A
# 133   JN10XHT83      113          N/A      Yale                    N/A
# 134   JN10XHT84      118          N/A      Yale                    N/A
# 135   JN10XHT85      122          N/A      Yale                    N/A
# 136   JN10XHT86        5          N/A      Yale                    N/A
# 137   JN10XHT87       87          N/A      Yale                    N/A
# 138   JN10XHT88       90          N/A      Yale                    N/A
# 139    JN10XHT9      126          N/A      Yale                    N/A
# 140   JN10XHT90       30          N/A      Yale                    N/A
# 141   JN10XHT91       31          N/A      Yale                    N/A
# 142   JN10XHT92       35          N/A      Yale                    N/A
# 143   JN10XHT94      100          N/A      Yale                    N/A
# 144   JN10XHT95      103          N/A      Yale                    N/A
# 145   JN10XHT96      104          N/A      Yale                    N/A
# 146   JN10XHT97      107          N/A      Yale                    N/A
# 147   JN10XHT98      112          N/A      Yale                    N/A
# 148   JN10XHT99       32          N/A      Yale                    N/A
#
#     sample_collection_relative_time_point library_ID library_ID_repository  \
# 0                                     N/A        N/A                   N/A
# 1                                     N/A        N/A                   N/A
# 2                                     N/A        N/A                   N/A
# 3                                     N/A        N/A                   N/A
# 4                                     N/A        N/A                   N/A
# 5                                     N/A        N/A                   N/A
# 6                                     N/A        N/A                   N/A
# 7                                     N/A        N/A                   N/A
# 8                                     N/A        N/A                   N/A
# 9                                     N/A        N/A                   N/A
# 10                                    N/A        N/A                   N/A
# 11                                    N/A        N/A                   N/A
# 12                                    N/A        N/A                   N/A
# 13                                    N/A        N/A                   N/A
# 14                                    N/A        N/A                   N/A
# 15                                    N/A        N/A                   N/A
# 16                                    N/A        N/A                   N/A
# 17                                    N/A        N/A                   N/A
# 18                                    N/A        N/A                   N/A
# 19                                    N/A        N/A                   N/A
# 20                                    N/A        N/A                   N/A
# 21                                    N/A        N/A                   N/A
# 22                                    N/A        N/A                   N/A
# 23                                    N/A        N/A                   N/A
# 24                                    N/A        N/A                   N/A
# 25                                    N/A        N/A                   N/A
# 26                                    N/A        N/A                   N/A
# 27                                    N/A        N/A                   N/A
# 28                                    N/A        N/A                   N/A
# 29                                    N/A        N/A                   N/A
# 30                                    N/A        N/A                   N/A
# 31                                    N/A        N/A                   N/A
# 32                                    N/A        N/A                   N/A
# 33                                    N/A        N/A                   N/A
# 34                                    N/A        N/A                   N/A
# 35                                    N/A        N/A                   N/A
# 36                                    N/A        N/A                   N/A
# 37                                    N/A        N/A                   N/A
# 38                                    N/A        N/A                   N/A
# 39                                    N/A        N/A                   N/A
# 40                                    N/A        N/A                   N/A
# 41                                    N/A        N/A                   N/A
# 42                                    N/A        N/A                   N/A
# 43                                    N/A        N/A                   N/A
# 44                                    N/A        N/A                   N/A
# 45                                    N/A        N/A                   N/A
# 46                                    N/A        N/A                   N/A
# 47                                    N/A        N/A                   N/A
# 48                                    N/A        N/A                   N/A
# 49                                    N/A        N/A                   N/A
# 50                                    N/A        N/A                   N/A
# 51                                    N/A        N/A                   N/A
# 52                                    N/A        N/A                   N/A
# 53                                    N/A        N/A                   N/A
# 54                                    N/A        N/A                   N/A
# 55                                    N/A        N/A                   N/A
# 56                                    N/A        N/A                   N/A
# 57                                    N/A        N/A                   N/A
# 58                                    N/A        N/A                   N/A
# 59                                    N/A        N/A                   N/A
# 60                                    N/A        N/A                   N/A
# 61                                    N/A        N/A                   N/A
# 62                                    N/A        N/A                   N/A
# 63                                    N/A        N/A                   N/A
# 64                                    N/A        N/A                   N/A
# 65                                    N/A        N/A                   N/A
# 66                                    N/A        N/A                   N/A
# 67                                    N/A        N/A                   N/A
# 68                                    N/A        N/A                   N/A
# 69                                    N/A        N/A                   N/A
# 70                                    N/A        N/A                   N/A
# 71                                    N/A        N/A                   N/A
# 72                                    N/A        N/A                   N/A
# 73                                    N/A        N/A                   N/A
# 74                                    N/A        N/A                   N/A
# 75                                    N/A        N/A                   N/A
# 76                                    N/A        N/A                   N/A
# 77                                    N/A        N/A                   N/A
# 78                                    N/A        N/A                   N/A
# 79                                    N/A        N/A                   N/A
# 80                                    N/A        N/A                   N/A
# 81                                    N/A        N/A                   N/A
# 82                                    N/A        N/A                   N/A
# 83                                    N/A        N/A                   N/A
# 84                                    N/A        N/A                   N/A
# 85                                    N/A        N/A                   N/A
# 86                                    N/A        N/A                   N/A
# 87                                    N/A        N/A                   N/A
# 88                                    N/A        N/A                   N/A
# 89                                    N/A        N/A                   N/A
# 90                                    N/A        N/A                   N/A
# 91                                    N/A        N/A                   N/A
# 92                                    N/A        N/A                   N/A
# 93                                    N/A        N/A                   N/A
# 94                                    N/A        N/A                   N/A
# 95                                    N/A        N/A                   N/A
# 96                                    N/A        N/A                   N/A
# 97                                    N/A        N/A                   N/A
# 98                                    N/A        N/A                   N/A
# 99                                    N/A        N/A                   N/A
# 100                                   N/A        N/A                   N/A
# 101                                   N/A        N/A                   N/A
# 102                                   N/A        N/A                   N/A
# 103                                   N/A        N/A                   N/A
# 104                                   N/A        N/A                   N/A
# 105                                   N/A        N/A                   N/A
# 106                                   N/A        N/A                   N/A
# 107                                   N/A        N/A                   N/A
# 108                                   N/A        N/A                   N/A
# 109                                   N/A        N/A                   N/A
# 110                                   N/A        N/A                   N/A
# 111                                   N/A        N/A                   N/A
# 112                                   N/A        N/A                   N/A
# 113                                   N/A        N/A                   N/A
# 114                                   N/A        N/A                   N/A
# 115                                   N/A        N/A                   N/A
# 116                                   N/A        N/A                   N/A
# 117                                   N/A        N/A                   N/A
# 118                                   N/A        N/A                   N/A
# 119                                   N/A        N/A                   N/A
# 120                                   N/A        N/A                   N/A
# 121                                   N/A        N/A                   N/A
# 122                                   N/A        N/A                   N/A
# 123                                   N/A        N/A                   N/A
# 124                                   N/A        N/A                   N/A
# 125                                   N/A        N/A                   N/A
# 126                                   N/A        N/A                   N/A
# 127                                   N/A        N/A                   N/A
# 128                                   N/A        N/A                   N/A
# 129                                   N/A        N/A                   N/A
# 130                                   N/A        N/A                   N/A
# 131                                   N/A        N/A                   N/A
# 132                                   N/A        N/A                   N/A
# 133                                   N/A        N/A                   N/A
# 134                                   N/A        N/A                   N/A
# 135                                   N/A        N/A                   N/A
# 136                                   N/A        N/A                   N/A
# 137                                   N/A        N/A                   N/A
# 138                                   N/A        N/A                   N/A
# 139                                   N/A        N/A                   N/A
# 140                                   N/A        N/A                   N/A
# 141                                   N/A        N/A                   N/A
# 142                                   N/A        N/A                   N/A
# 143                                   N/A        N/A                   N/A
# 144                                   N/A        N/A                   N/A
# 145                                   N/A        N/A                   N/A
# 146                                   N/A        N/A                   N/A
# 147                                   N/A        N/A                   N/A
# 148                                   N/A        N/A                   N/A
#
#     author_batch_notes organism_ontology_term_id  ... sequenced_fragment  \
# 0                  N/A            NCBITaxon:9606  ...        3 prime tag
# 1                  N/A            NCBITaxon:9606  ...        3 prime tag
# 2                  N/A            NCBITaxon:9606  ...        3 prime tag
# 3                  N/A            NCBITaxon:9606  ...        3 prime tag
# 4                  N/A            NCBITaxon:9606  ...        3 prime tag
# 5                  N/A            NCBITaxon:9606  ...        3 prime tag
# 6                  N/A            NCBITaxon:9606  ...        3 prime tag
# 7                  N/A            NCBITaxon:9606  ...        3 prime tag
# 8                  N/A            NCBITaxon:9606  ...        3 prime tag
# 9                  N/A            NCBITaxon:9606  ...        3 prime tag
# 10                 N/A            NCBITaxon:9606  ...        3 prime tag
# 11                 N/A            NCBITaxon:9606  ...        3 prime tag
# 12                 N/A            NCBITaxon:9606  ...        3 prime tag
# 13                 N/A            NCBITaxon:9606  ...        3 prime tag
# 14                 N/A            NCBITaxon:9606  ...        3 prime tag
# 15                 N/A            NCBITaxon:9606  ...        3 prime tag
# 16                 N/A            NCBITaxon:9606  ...        3 prime tag
# 17                 N/A            NCBITaxon:9606  ...        3 prime tag
# 18                 N/A            NCBITaxon:9606  ...        3 prime tag
# 19                 N/A            NCBITaxon:9606  ...        3 prime tag
# 20                 N/A            NCBITaxon:9606  ...        3 prime tag
# 21                 N/A            NCBITaxon:9606  ...        3 prime tag
# 22                 N/A            NCBITaxon:9606  ...        3 prime tag
# 23                 N/A            NCBITaxon:9606  ...        3 prime tag
# 24                 N/A            NCBITaxon:9606  ...        3 prime tag
# 25                 N/A            NCBITaxon:9606  ...        3 prime tag
# 26                 N/A            NCBITaxon:9606  ...        3 prime tag
# 27                 N/A            NCBITaxon:9606  ...        3 prime tag
# 28                 N/A            NCBITaxon:9606  ...        3 prime tag
# 29                 N/A            NCBITaxon:9606  ...        3 prime tag
# 30                 N/A            NCBITaxon:9606  ...        3 prime tag
# 31                 N/A            NCBITaxon:9606  ...        3 prime tag
# 32                 N/A            NCBITaxon:9606  ...        3 prime tag
# 33                 N/A            NCBITaxon:9606  ...        3 prime tag
# 34                 N/A            NCBITaxon:9606  ...        3 prime tag
# 35                 N/A            NCBITaxon:9606  ...        3 prime tag
# 36                 N/A            NCBITaxon:9606  ...        3 prime tag
# 37                 N/A            NCBITaxon:9606  ...        3 prime tag
# 38                 N/A            NCBITaxon:9606  ...        3 prime tag
# 39                 N/A            NCBITaxon:9606  ...        3 prime tag
# 40                 N/A            NCBITaxon:9606  ...        3 prime tag
# 41                 N/A            NCBITaxon:9606  ...        3 prime tag
# 42                 N/A            NCBITaxon:9606  ...        3 prime tag
# 43                 N/A            NCBITaxon:9606  ...        3 prime tag
# 44                 N/A            NCBITaxon:9606  ...        3 prime tag
# 45                 N/A            NCBITaxon:9606  ...        3 prime tag
# 46                 N/A            NCBITaxon:9606  ...        3 prime tag
# 47                 N/A            NCBITaxon:9606  ...        3 prime tag
# 48                 N/A            NCBITaxon:9606  ...        3 prime tag
# 49                 N/A            NCBITaxon:9606  ...        3 prime tag
# 50                 N/A            NCBITaxon:9606  ...        3 prime tag
# 51                 N/A            NCBITaxon:9606  ...        3 prime tag
# 52                 N/A            NCBITaxon:9606  ...        3 prime tag
# 53                 N/A            NCBITaxon:9606  ...        3 prime tag
# 54                 N/A            NCBITaxon:9606  ...        3 prime tag
# 55                 N/A            NCBITaxon:9606  ...        3 prime tag
# 56                 N/A            NCBITaxon:9606  ...        3 prime tag
# 57                 N/A            NCBITaxon:9606  ...        3 prime tag
# 58                 N/A            NCBITaxon:9606  ...        3 prime tag
# 59                 N/A            NCBITaxon:9606  ...        3 prime tag
# 60                 N/A            NCBITaxon:9606  ...        3 prime tag
# 61                 N/A            NCBITaxon:9606  ...        3 prime tag
# 62                 N/A            NCBITaxon:9606  ...        3 prime tag
# 63                 N/A            NCBITaxon:9606  ...        3 prime tag
# 64                 N/A            NCBITaxon:9606  ...        3 prime tag
# 65                 N/A            NCBITaxon:9606  ...        3 prime tag
# 66                 N/A            NCBITaxon:9606  ...        3 prime tag
# 67                 N/A            NCBITaxon:9606  ...        3 prime tag
# 68                 N/A            NCBITaxon:9606  ...        3 prime tag
# 69                 N/A            NCBITaxon:9606  ...        3 prime tag
# 70                 N/A            NCBITaxon:9606  ...        3 prime tag
# 71                 N/A            NCBITaxon:9606  ...        3 prime tag
# 72                 N/A            NCBITaxon:9606  ...        3 prime tag
# 73                 N/A            NCBITaxon:9606  ...        3 prime tag
# 74                 N/A            NCBITaxon:9606  ...        3 prime tag
# 75                 N/A            NCBITaxon:9606  ...        3 prime tag
# 76                 N/A            NCBITaxon:9606  ...        3 prime tag
# 77                 N/A            NCBITaxon:9606  ...        3 prime tag
# 78                 N/A            NCBITaxon:9606  ...        3 prime tag
# 79                 N/A            NCBITaxon:9606  ...        3 prime tag
# 80                 N/A            NCBITaxon:9606  ...        3 prime tag
# 81                 N/A            NCBITaxon:9606  ...        3 prime tag
# 82                 N/A            NCBITaxon:9606  ...        3 prime tag
# 83                 N/A            NCBITaxon:9606  ...        3 prime tag
# 84                 N/A            NCBITaxon:9606  ...        3 prime tag
# 85                 N/A            NCBITaxon:9606  ...        3 prime tag
# 86                 N/A            NCBITaxon:9606  ...        3 prime tag
# 87                 N/A            NCBITaxon:9606  ...        3 prime tag
# 88                 N/A            NCBITaxon:9606  ...        3 prime tag
# 89                 N/A            NCBITaxon:9606  ...        3 prime tag
# 90                 N/A            NCBITaxon:9606  ...        3 prime tag
# 91                 N/A            NCBITaxon:9606  ...        3 prime tag
# 92                 N/A            NCBITaxon:9606  ...        3 prime tag
# 93                 N/A            NCBITaxon:9606  ...        3 prime tag
# 94                 N/A            NCBITaxon:9606  ...        3 prime tag
# 95                 N/A            NCBITaxon:9606  ...        3 prime tag
# 96                 N/A            NCBITaxon:9606  ...        3 prime tag
# 97                 N/A            NCBITaxon:9606  ...        3 prime tag
# 98                 N/A            NCBITaxon:9606  ...        3 prime tag
# 99                 N/A            NCBITaxon:9606  ...        3 prime tag
# 100                N/A            NCBITaxon:9606  ...        3 prime tag
# 101                N/A            NCBITaxon:9606  ...        3 prime tag
# 102                N/A            NCBITaxon:9606  ...        3 prime tag
# 103                N/A            NCBITaxon:9606  ...        3 prime tag
# 104                N/A            NCBITaxon:9606  ...        3 prime tag
# 105                N/A            NCBITaxon:9606  ...        3 prime tag
# 106                N/A            NCBITaxon:9606  ...        3 prime tag
# 107                N/A            NCBITaxon:9606  ...        3 prime tag
# 108                N/A            NCBITaxon:9606  ...        3 prime tag
# 109                N/A            NCBITaxon:9606  ...        3 prime tag
# 110                N/A            NCBITaxon:9606  ...        3 prime tag
# 111                N/A            NCBITaxon:9606  ...        3 prime tag
# 112                N/A            NCBITaxon:9606  ...        3 prime tag
# 113                N/A            NCBITaxon:9606  ...        3 prime tag
# 114                N/A            NCBITaxon:9606  ...        3 prime tag
# 115                N/A            NCBITaxon:9606  ...        3 prime tag
# 116                N/A            NCBITaxon:9606  ...        3 prime tag
# 117                N/A            NCBITaxon:9606  ...        3 prime tag
# 118                N/A            NCBITaxon:9606  ...        3 prime tag
# 119                N/A            NCBITaxon:9606  ...        3 prime tag
# 120                N/A            NCBITaxon:9606  ...        3 prime tag
# 121                N/A            NCBITaxon:9606  ...        3 prime tag
# 122                N/A            NCBITaxon:9606  ...        3 prime tag
# 123                N/A            NCBITaxon:9606  ...        3 prime tag
# 124                N/A            NCBITaxon:9606  ...        3 prime tag
# 125                N/A            NCBITaxon:9606  ...        3 prime tag
# 126                N/A            NCBITaxon:9606  ...        3 prime tag
# 127                N/A            NCBITaxon:9606  ...        3 prime tag
# 128                N/A            NCBITaxon:9606  ...        3 prime tag
# 129                N/A            NCBITaxon:9606  ...        3 prime tag
# 130                N/A            NCBITaxon:9606  ...        3 prime tag
# 131                N/A            NCBITaxon:9606  ...        3 prime tag
# 132                N/A            NCBITaxon:9606  ...        3 prime tag
# 133                N/A            NCBITaxon:9606  ...        3 prime tag
# 134                N/A            NCBITaxon:9606  ...        3 prime tag
# 135                N/A            NCBITaxon:9606  ...        3 prime tag
# 136                N/A            NCBITaxon:9606  ...        3 prime tag
# 137                N/A            NCBITaxon:9606  ...        3 prime tag
# 138                N/A            NCBITaxon:9606  ...        3 prime tag
# 139                N/A            NCBITaxon:9606  ...        3 prime tag
# 140                N/A            NCBITaxon:9606  ...        3 prime tag
# 141                N/A            NCBITaxon:9606  ...        3 prime tag
# 142                N/A            NCBITaxon:9606  ...        3 prime tag
# 143                N/A            NCBITaxon:9606  ...        3 prime tag
# 144                N/A            NCBITaxon:9606  ...        3 prime tag
# 145                N/A            NCBITaxon:9606  ...        3 prime tag
# 146                N/A            NCBITaxon:9606  ...        3 prime tag
# 147                N/A            NCBITaxon:9606  ...        3 prime tag
# 148                N/A            NCBITaxon:9606  ...        3 prime tag
#
#     sequencing_platform is_primary_data reference_genome  \
# 0           EFO:0008637            true           GRCh38
# 1           EFO:0008637            true           GRCh38
# 2           EFO:0008637            true           GRCh38
# 3           EFO:0008637            true           GRCh38
# 4           EFO:0008637            true           GRCh38
# 5           EFO:0008637            true           GRCh38
# 6           EFO:0008637            true           GRCh38
# 7           EFO:0008637            true           GRCh38
# 8           EFO:0008637            true           GRCh38
# 9           EFO:0008637            true           GRCh38
# 10          EFO:0008637            true           GRCh38
# 11          EFO:0008637            true           GRCh38
# 12          EFO:0008637            true           GRCh38
# 13          EFO:0008637            true           GRCh38
# 14          EFO:0008637            true           GRCh38
# 15          EFO:0008637            true           GRCh38
# 16          EFO:0008637            true           GRCh38
# 17          EFO:0008637            true           GRCh38
# 18          EFO:0008637            true           GRCh38
# 19          EFO:0008637            true           GRCh38
# 20          EFO:0008637            true           GRCh38
# 21          EFO:0008637            true           GRCh38
# 22          EFO:0008637            true           GRCh38
# 23          EFO:0008637            true           GRCh38
# 24          EFO:0008637            true           GRCh38
# 25          EFO:0008637            true           GRCh38
# 26          EFO:0008637            true           GRCh38
# 27          EFO:0008637            true           GRCh38
# 28          EFO:0008637            true           GRCh38
# 29          EFO:0008637            true           GRCh38
# 30          EFO:0008637            true           GRCh38
# 31          EFO:0008637            true           GRCh38
# 32          EFO:0008637            true           GRCh38
# 33          EFO:0008637            true           GRCh38
# 34          EFO:0008637            true           GRCh38
# 35          EFO:0008637            true           GRCh38
# 36          EFO:0008637            true           GRCh38
# 37          EFO:0008637            true           GRCh38
# 38          EFO:0008637            true           GRCh38
# 39          EFO:0008637            true           GRCh38
# 40          EFO:0008637            true           GRCh38
# 41          EFO:0008637            true           GRCh38
# 42          EFO:0008637            true           GRCh38
# 43          EFO:0008637            true           GRCh38
# 44          EFO:0008637            true           GRCh38
# 45          EFO:0008637            true           GRCh38
# 46          EFO:0008637            true           GRCh38
# 47          EFO:0008637            true           GRCh38
# 48          EFO:0008637            true           GRCh38
# 49          EFO:0008637            true           GRCh38
# 50          EFO:0008637            true           GRCh38
# 51          EFO:0008637            true           GRCh38
# 52          EFO:0008637            true           GRCh38
# 53          EFO:0008637            true           GRCh38
# 54          EFO:0008637            true           GRCh38
# 55          EFO:0008637            true           GRCh38
# 56          EFO:0008637            true           GRCh38
# 57          EFO:0008637            true           GRCh38
# 58          EFO:0008637            true           GRCh38
# 59          EFO:0008637            true           GRCh38
# 60          EFO:0008637            true           GRCh38
# 61          EFO:0008637            true           GRCh38
# 62          EFO:0008637            true           GRCh38
# 63          EFO:0008637            true           GRCh38
# 64          EFO:0008637            true           GRCh38
# 65          EFO:0008637            true           GRCh38
# 66          EFO:0008637            true           GRCh38
# 67          EFO:0008637            true           GRCh38
# 68          EFO:0008637            true           GRCh38
# 69          EFO:0008637            true           GRCh38
# 70          EFO:0008637            true           GRCh38
# 71          EFO:0008637            true           GRCh38
# 72          EFO:0008637            true           GRCh38
# 73          EFO:0008637            true           GRCh38
# 74          EFO:0008637            true           GRCh38
# 75          EFO:0008637            true           GRCh38
# 76          EFO:0008637            true           GRCh38
# 77          EFO:0008637            true           GRCh38
# 78          EFO:0008637            true           GRCh38
# 79          EFO:0008637            true           GRCh38
# 80          EFO:0008637            true           GRCh38
# 81          EFO:0008637            true           GRCh38
# 82          EFO:0008637            true           GRCh38
# 83          EFO:0008637            true           GRCh38
# 84          EFO:0008637            true           GRCh38
# 85          EFO:0008637            true           GRCh38
# 86          EFO:0008637            true           GRCh38
# 87          EFO:0008637            true           GRCh38
# 88          EFO:0008637            true           GRCh38
# 89          EFO:0008637            true           GRCh38
# 90          EFO:0008637            true           GRCh38
# 91          EFO:0008637            true           GRCh38
# 92          EFO:0008637            true           GRCh38
# 93          EFO:0008637            true           GRCh38
# 94          EFO:0008637            true           GRCh38
# 95          EFO:0008637            true           GRCh38
# 96          EFO:0008637            true           GRCh38
# 97          EFO:0008637            true           GRCh38
# 98          EFO:0008637            true           GRCh38
# 99          EFO:0008637            true           GRCh38
# 100         EFO:0008637            true           GRCh38
# 101         EFO:0008637            true           GRCh38
# 102         EFO:0008637            true           GRCh38
# 103         EFO:0008637            true           GRCh38
# 104         EFO:0008637            true           GRCh38
# 105         EFO:0008637            true           GRCh38
# 106         EFO:0008637            true           GRCh38
# 107         EFO:0008637            true           GRCh38
# 108         EFO:0008637            true           GRCh38
# 109         EFO:0008637            true           GRCh38
# 110         EFO:0008637            true           GRCh38
# 111         EFO:0008637            true           GRCh38
# 112         EFO:0008637            true           GRCh38
# 113         EFO:0008637            true           GRCh38
# 114         EFO:0008637            true           GRCh38
# 115         EFO:0008637            true           GRCh38
# 116         EFO:0008637            true           GRCh38
# 117         EFO:0008637            true           GRCh38
# 118         EFO:0008637            true           GRCh38
# 119         EFO:0008637            true           GRCh38
# 120         EFO:0008637            true           GRCh38
# 121         EFO:0008637            true           GRCh38
# 122         EFO:0008637            true           GRCh38
# 123         EFO:0008637            true           GRCh38
# 124         EFO:0008637            true           GRCh38
# 125         EFO:0008637            true           GRCh38
# 126         EFO:0008637            true           GRCh38
# 127         EFO:0008637            true           GRCh38
# 128         EFO:0008637            true           GRCh38
# 129         EFO:0008637            true           GRCh38
# 130         EFO:0008637            true           GRCh38
# 131         EFO:0008637            true           GRCh38
# 132         EFO:0008637            true           GRCh38
# 133         EFO:0008637            true           GRCh38
# 134         EFO:0008637            true           GRCh38
# 135         EFO:0008637            true           GRCh38
# 136         EFO:0008637            true           GRCh38
# 137         EFO:0008637            true           GRCh38
# 138         EFO:0008637            true           GRCh38
# 139         EFO:0008637            true           GRCh38
# 140         EFO:0008637            true           GRCh38
# 141         EFO:0008637            true           GRCh38
# 142         EFO:0008637            true           GRCh38
# 143         EFO:0008637            true           GRCh38
# 144         EFO:0008637            true           GRCh38
# 145         EFO:0008637            true           GRCh38
# 146         EFO:0008637            true           GRCh38
# 147         EFO:0008637            true           GRCh38
# 148         EFO:0008637            true           GRCh38
#
#     gene_annotation_version alignment_software intron_inclusion  \
# 0                       v98     CellRanger 7.1              yes
# 1                       v98     CellRanger 7.1              yes
# 2                       v98     CellRanger 7.1              yes
# 3                       v98     CellRanger 7.1              yes
# 4                       v98     CellRanger 7.1              yes
# 5                       v98     CellRanger 7.1              yes
# 6                       v98     CellRanger 7.1              yes
# 7                       v98     CellRanger 7.1              yes
# 8                       v98     CellRanger 7.1              yes
# 9                       v98     CellRanger 7.1              yes
# 10                      v98     CellRanger 7.1              yes
# 11                      v98     CellRanger 7.1              yes
# 12                      v98     CellRanger 7.1              yes
# 13                      v98     CellRanger 7.1              yes
# 14                      v98     CellRanger 7.1              yes
# 15                      v98     CellRanger 7.1              yes
# 16                      v98     CellRanger 7.1              yes
# 17                      v98     CellRanger 7.1              yes
# 18                      v98     CellRanger 7.1              yes
# 19                      v98     CellRanger 7.1              yes
# 20                      v98     CellRanger 7.1              yes
# 21                      v98     CellRanger 7.1              yes
# 22                      v98     CellRanger 7.1              yes
# 23                      v98     CellRanger 7.1              yes
# 24                      v98     CellRanger 7.1              yes
# 25                      v98     CellRanger 7.1              yes
# 26                      v98     CellRanger 7.1              yes
# 27                      v98     CellRanger 7.1              yes
# 28                      v98     CellRanger 7.1              yes
# 29                      v98     CellRanger 7.1              yes
# 30                      v98     CellRanger 7.1              yes
# 31                      v98     CellRanger 7.1              yes
# 32                      v98     CellRanger 7.1              yes
# 33                      v98     CellRanger 7.1              yes
# 34                      v98     CellRanger 7.1              yes
# 35                      v98     CellRanger 7.1              yes
# 36                      v98     CellRanger 7.1              yes
# 37                      v98     CellRanger 7.1              yes
# 38                      v98     CellRanger 7.1              yes
# 39                      v98     CellRanger 7.1              yes
# 40                      v98     CellRanger 7.1              yes
# 41                      v98     CellRanger 7.1              yes
# 42                      v98     CellRanger 7.1              yes
# 43                      v98     CellRanger 7.1              yes
# 44                      v98     CellRanger 7.1              yes
# 45                      v98     CellRanger 7.1              yes
# 46                      v98     CellRanger 7.1              yes
# 47                      v98     CellRanger 7.1              yes
# 48                      v98     CellRanger 7.1              yes
# 49                      v98     CellRanger 7.1              yes
# 50                      v98     CellRanger 7.1              yes
# 51                      v98     CellRanger 7.1              yes
# 52                      v98     CellRanger 7.1              yes
# 53                      v98     CellRanger 7.1              yes
# 54                      v98     CellRanger 7.1              yes
# 55                      v98     CellRanger 7.1              yes
# 56                      v98     CellRanger 7.1              yes
# 57                      v98     CellRanger 7.1              yes
# 58                      v98     CellRanger 7.1              yes
# 59                      v98     CellRanger 7.1              yes
# 60                      v98     CellRanger 7.1              yes
# 61                      v98     CellRanger 7.1              yes
# 62                      v98     CellRanger 7.1              yes
# 63                      v98     CellRanger 7.1              yes
# ...
# 15              PATO:0000461                                  unknown
# 16              PATO:0000461                                  unknown
# 17              PATO:0000461                                  unknown
# 18              PATO:0000461                                  unknown
# 19              PATO:0000461                                  unknown
# 20              PATO:0000461                                  unknown
# 21              PATO:0000461                                  unknown
# 22              PATO:0000461                                  unknown
# 23              PATO:0000461                                  unknown
# 24              PATO:0000461                                  unknown
# 25              PATO:0000461                                  unknown
# 26              PATO:0000461                                  unknown
# 27              PATO:0000461                                  unknown
# 28              PATO:0000461                                  unknown
# 29              PATO:0000461                                  unknown
# 30              PATO:0000461                                  unknown
# 31              PATO:0000461                                  unknown
# 32              PATO:0000461                                  unknown
# 33              PATO:0000461                                  unknown
# 34              PATO:0000461                                  unknown
# 35              PATO:0000461                                  unknown
# 36              PATO:0000461                                  unknown
# 37              PATO:0000461                                  unknown
# 38              PATO:0000461                                  unknown
# 39              PATO:0000461                                  unknown
# 40              PATO:0000461                                  unknown
# 41              PATO:0000461                                  unknown
# 42              PATO:0000461                                  unknown
# 43              PATO:0000461                                  unknown
# 44              PATO:0000461                                  unknown
# 45              PATO:0000461                                  unknown
# 46              PATO:0000461                                  unknown
# 47              PATO:0000461                                  unknown
# 48              PATO:0000461                                  unknown
# 49              PATO:0000461                                  unknown
# 50              PATO:0000461                                  unknown
# 51              PATO:0000461                                  unknown
# 52              PATO:0000461                                  unknown
# 53              PATO:0000461                                  unknown
# 54              PATO:0000461                                  unknown
# 55              PATO:0000461                                  unknown
# 56              PATO:0000461                                  unknown
# 57              PATO:0000461                                  unknown
# 58              PATO:0000461                                  unknown
# 59              PATO:0000461                                  unknown
# 60              PATO:0000461                                  unknown
# 61              PATO:0000461                                  unknown
# 62              PATO:0000461                                  unknown
# 63              PATO:0000461                                  unknown
# 64              PATO:0000461                                  unknown
# 65              PATO:0000461                                  unknown
# 66              PATO:0000461                                  unknown
# 67              PATO:0000461                                  unknown
# 68              PATO:0000461                                  unknown
# 69              PATO:0000461                                  unknown
# 70              PATO:0000461                                  unknown
# 71              PATO:0000461                                  unknown
# 72              PATO:0000461                                  unknown
# 73              PATO:0000461                                  unknown
# 74              PATO:0000461                                  unknown
# 75              PATO:0000461                                  unknown
# 76              PATO:0000461                                  unknown
# 77              PATO:0000461                                  unknown
# 78              PATO:0000461                                  unknown
# 79              PATO:0000461                                  unknown
# 80              PATO:0000461                                  unknown
# 81              PATO:0000461                                  unknown
# 82              PATO:0000461                                  unknown
# 83              PATO:0000461                                  unknown
# 84              PATO:0000461                                  unknown
# 85              PATO:0000461                                  unknown
# 86              PATO:0000461                                  unknown
# 87              PATO:0000461                                  unknown
# 88              PATO:0000461                                  unknown
# 89              PATO:0000461                                  unknown
# 90              PATO:0000461                                  unknown
# 91              PATO:0000461                                  unknown
# 92              PATO:0000461                                  unknown
# 93              PATO:0000461                                  unknown
# 94              PATO:0000461                                  unknown
# 95              PATO:0000461                                  unknown
# 96              PATO:0000461                                  unknown
# 97              PATO:0000461                                  unknown
# 98              PATO:0000461                                  unknown
# 99              PATO:0000461                                  unknown
# 100             PATO:0000461                                  unknown
# 101             PATO:0000461                                  unknown
# 102             PATO:0000461                                  unknown
# 103             PATO:0000461                                  unknown
# 104             PATO:0000461                                  unknown
# 105             PATO:0000461                                  unknown
# 106             PATO:0000461                                  unknown
# 107             PATO:0000461                                  unknown
# 108             PATO:0000461                                  unknown
# 109             PATO:0000461                                  unknown
# 110             PATO:0000461                                  unknown
# 111             PATO:0000461                                  unknown
# 112             PATO:0000461                                  unknown
# 113             PATO:0000461                                  unknown
# 114             PATO:0000461                                  unknown
# 115             PATO:0000461                                  unknown
# 116             PATO:0000461                                  unknown
# 117             PATO:0000461                                  unknown
# 118             PATO:0000461                                  unknown
# 119             PATO:0000461                                  unknown
# 120             PATO:0000461                                  unknown
# 121             PATO:0000461                                  unknown
# 122             PATO:0000461                                  unknown
# 123             PATO:0000461                                  unknown
# 124             PATO:0000461                                  unknown
# 125             PATO:0000461                                  unknown
# 126             PATO:0000461                                  unknown
# 127             PATO:0000461                                  unknown
# 128             PATO:0000461                                  unknown
# 129             PATO:0000461                                  unknown
# 130             PATO:0000461                                  unknown
# 131             PATO:0000461                                  unknown
# 132             PATO:0000461                                  unknown
# 133             PATO:0000461                                  unknown
# 134             PATO:0000461                                  unknown
# 135             PATO:0000461                                  unknown
# 136             PATO:0000461                                  unknown
# 137             PATO:0000461                                  unknown
# 138             PATO:0000461                                  unknown
# 139             PATO:0000461                                  unknown
# 140             PATO:0000461                                  unknown
# 141             PATO:0000461                                  unknown
# 142             PATO:0000461                                  unknown
# 143             PATO:0000461                                  unknown
# 144             PATO:0000461                                  unknown
# 145             PATO:0000461                                  unknown
# 146             PATO:0000461                                  unknown
# 147             PATO:0000461                                  unknown
# 148             PATO:0000461                                  unknown
#
#     development_stage_ontology_term_id
# 0                              unknown
# 1                              unknown
# 2                              unknown
# 3                              unknown
# 4                              unknown
# 5                              unknown
# 6                              unknown
# 7                              unknown
# 8                              unknown
# 9                              unknown
# 10                             unknown
# 11                             unknown
# 12                             unknown
# 13                             unknown
# 14                             unknown
# 15                             unknown
# 16                             unknown
# 17                             unknown
# 18                             unknown
# 19                             unknown
# 20                             unknown
# 21                             unknown
# 22                             unknown
# 23                             unknown
# 24                             unknown
# 25                             unknown
# 26                             unknown
# 27                             unknown
# 28                             unknown
# 29                             unknown
# 30                             unknown
# 31                             unknown
# 32                             unknown
# 33                             unknown
# 34                             unknown
# 35                             unknown
# 36                             unknown
# 37                             unknown
# 38                             unknown
# 39                             unknown
# 40                             unknown
# 41                             unknown
# 42                             unknown
# 43                             unknown
# 44                             unknown
# 45                             unknown
# 46                             unknown
# 47                             unknown
# 48                             unknown
# 49                             unknown
# 50                             unknown
# 51                             unknown
# 52                             unknown
# 53                             unknown
# 54                             unknown
# 55                             unknown
# 56                             unknown
# 57                             unknown
# 58                             unknown
# 59                             unknown
# 60                             unknown
# 61                             unknown
# 62                             unknown
# 63                             unknown
# 64                             unknown
# 65                             unknown
# 66                             unknown
# 67                             unknown
# 68                             unknown
# 69                             unknown
# 70                             unknown
# 71                             unknown
# 72                             unknown
# 73                             unknown
# 74                             unknown
# 75                             unknown
# 76                             unknown
# 77                             unknown
# 78                             unknown
# 79                             unknown
# 80                             unknown
# 81                             unknown
# 82                             unknown
# 83                             unknown
# 84                             unknown
# 85                             unknown
# 86                             unknown
# 87                             unknown
# 88                             unknown
# 89                             unknown
# 90                             unknown
# 91                             unknown
# 92                             unknown
# 93                             unknown
# 94                             unknown
# 95                             unknown
# 96                             unknown
# 97                             unknown
# 98                             unknown
# 99                             unknown
# 100                            unknown
# 101                            unknown
# 102                            unknown
# 103                            unknown
# 104                            unknown
# 105                            unknown
# 106                            unknown
# 107                            unknown
# 108                            unknown
# 109                            unknown
# 110                            unknown
# 111                            unknown
# 112                            unknown
# 113                            unknown
# 114                            unknown
# 115                            unknown
# 116                            unknown
# 117                            unknown
# 118                            unknown
# 119                            unknown
# 120                            unknown
# 121                            unknown
# 122                            unknown
# 123                            unknown
# 124                            unknown
# 125                            unknown
# 126                            unknown
# 127                            unknown
# 128                            unknown
# 129                            unknown
# 130                            unknown
# 131                            unknown
# 132                            unknown
# 133                            unknown
# 134                            unknown
# 135                            unknown
# 136                            unknown
# 137                            unknown
# 138                            unknown
# 139                            unknown
# 140                            unknown
# 141                            unknown
# 142                            unknown
# 143                            unknown
# 144                            unknown
# 145                            unknown
# 146                            unknown
# 147                            unknown
# 148                            unknown
#
# [149 rows x 37 columns]

# %%
overlap = set(obs['sample_ID']) - set(adata.obs['sample_ID'])
overlap_other_side = set(adata.obs['sample_ID']) - set(obs['sample_ID'])

# %%
overlap
# Out:
# set()

# %%
overlap_other_side
# Out:
# {'JN10XHT128', 'JN10XHT15'}

# %%
# remove overlap_other_side from adata (== 21 cells, so probably low quality samples)
adata = adata[~adata.obs['sample_ID'].isin(overlap_other_side)].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 1529919 × 36601
#     obs: 'author_cell_type', 'sample_ID'

# %% [markdown]
# # Validate obs and uns from adata

# %%
merger = AnnDataMerger(
    adata = adata,
    uns_df = uns
)

adata = merger.add_uns_metadata()

adata
# Out:
# AnnData object with n_obs × n_vars = 1529919 × 36601
#     obs: 'author_cell_type', 'sample_ID'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments'

# %%
# Merge obs metadata
pd.set_option('display.max_rows', 100)
merged_df = pd.merge(adata.obs, obs, on='sample_ID', how='left')
merged_df.index = adata.obs.index
merged_df
# Out:
#                                          author_cell_type   sample_ID  \
# JN10XHT119_HHT_TCCTTCTCACTGATTG-1  Fibroblast_Adventitial  JN10XHT119
# JN10XHT123_HHT_AGAACCTTCCTTCTGG-1  Fibroblast_Adventitial  JN10XHT123
# JN10XHT129_HHT_AGACTCACATGTGGCC-1  Fibroblast_Adventitial  JN10XHT129
# JN10XHT129_HHT_TTCGGTCAGACTTCAC-1  Fibroblast_Adventitial  JN10XHT129
# JN10XHT137_HHT_CCGGTAGCAGTCTACA-1  Fibroblast_Adventitial  JN10XHT137
# ...                                                   ...         ...
# JN10XHT37_HHT_CCTGCATCATATAGCC-1                     PNEC   JN10XHT37
# JN10XHT37_HHT_CGGGTCAGTGTTTACG-1                     PNEC   JN10XHT37
# JN10XHT37_HHT_TCATGAGAGTGCGTCC-1                     PNEC   JN10XHT37
# JN10XHT79_HHT_TACCGGGAGAGCCATG-1                     PNEC   JN10XHT79
# JN10XHT125_HHT_CCCGGAAAGCTGGCTC-1                    PNEC  JN10XHT125
#
#                                   donor_id protocol_URL institute  \
# JN10XHT119_HHT_TCCTTCTCACTGATTG-1       43          N/A      Yale
# JN10XHT123_HHT_AGAACCTTCCTTCTGG-1       91          N/A      Yale
# JN10XHT129_HHT_AGACTCACATGTGGCC-1       60          N/A      Yale
# JN10XHT129_HHT_TTCGGTCAGACTTCAC-1       60          N/A      Yale
# JN10XHT137_HHT_CCGGTAGCAGTCTACA-1       57          N/A      Yale
# ...                                    ...          ...       ...
# JN10XHT37_HHT_CCTGCATCATATAGCC-1        19          N/A      Yale
# JN10XHT37_HHT_CGGGTCAGTGTTTACG-1        19          N/A      Yale
# JN10XHT37_HHT_TCATGAGAGTGCGTCC-1        19          N/A      Yale
# JN10XHT79_HHT_TACCGGGAGAGCCATG-1        21          N/A      Yale
# JN10XHT125_HHT_CCCGGAAAGCTGGCTC-1       79          N/A      Yale
#
#                                   sample_collection_site  \
# JN10XHT119_HHT_TCCTTCTCACTGATTG-1                    N/A
# JN10XHT123_HHT_AGAACCTTCCTTCTGG-1                    N/A
# JN10XHT129_HHT_AGACTCACATGTGGCC-1                    N/A
# JN10XHT129_HHT_TTCGGTCAGACTTCAC-1                    N/A
# JN10XHT137_HHT_CCGGTAGCAGTCTACA-1                    N/A
# ...                                                  ...
# JN10XHT37_HHT_CCTGCATCATATAGCC-1                     N/A
# JN10XHT37_HHT_CGGGTCAGTGTTTACG-1                     N/A
# JN10XHT37_HHT_TCATGAGAGTGCGTCC-1                     N/A
# JN10XHT79_HHT_TACCGGGAGAGCCATG-1                     N/A
# JN10XHT125_HHT_CCCGGAAAGCTGGCTC-1                    N/A
#
#                                   sample_collection_relative_time_point  \
# JN10XHT119_HHT_TCCTTCTCACTGATTG-1                                   N/A
# JN10XHT123_HHT_AGAACCTTCCTTCTGG-1                                   N/A
# JN10XHT129_HHT_AGACTCACATGTGGCC-1                                   N/A
# JN10XHT129_HHT_TTCGGTCAGACTTCAC-1                                   N/A
# JN10XHT137_HHT_CCGGTAGCAGTCTACA-1                                   N/A
# ...                                                                 ...
# JN10XHT37_HHT_CCTGCATCATATAGCC-1                                    N/A
# JN10XHT37_HHT_CGGGTCAGTGTTTACG-1                                    N/A
# JN10XHT37_HHT_TCATGAGAGTGCGTCC-1                                    N/A
# JN10XHT79_HHT_TACCGGGAGAGCCATG-1                                    N/A
# JN10XHT125_HHT_CCCGGAAAGCTGGCTC-1                                   N/A
#
#                                   library_ID library_ID_repository  \
# JN10XHT119_HHT_TCCTTCTCACTGATTG-1        N/A                   N/A
# JN10XHT123_HHT_AGAACCTTCCTTCTGG-1        N/A                   N/A
# JN10XHT129_HHT_AGACTCACATGTGGCC-1        N/A                   N/A
# JN10XHT129_HHT_TTCGGTCAGACTTCAC-1        N/A                   N/A
# JN10XHT137_HHT_CCGGTAGCAGTCTACA-1        N/A                   N/A
# ...                                      ...                   ...
# JN10XHT37_HHT_CCTGCATCATATAGCC-1         N/A                   N/A
# JN10XHT37_HHT_CGGGTCAGTGTTTACG-1         N/A                   N/A
# JN10XHT37_HHT_TCATGAGAGTGCGTCC-1         N/A                   N/A
# JN10XHT79_HHT_TACCGGGAGAGCCATG-1         N/A                   N/A
# JN10XHT125_HHT_CCCGGAAAGCTGGCTC-1        N/A                   N/A
#
#                                   author_batch_notes  ... sequenced_fragment  \
# JN10XHT119_HHT_TCCTTCTCACTGATTG-1                N/A  ...        3 prime tag
# JN10XHT123_HHT_AGAACCTTCCTTCTGG-1                N/A  ...        3 prime tag
# JN10XHT129_HHT_AGACTCACATGTGGCC-1                N/A  ...        3 prime tag
# JN10XHT129_HHT_TTCGGTCAGACTTCAC-1                N/A  ...        3 prime tag
# JN10XHT137_HHT_CCGGTAGCAGTCTACA-1                N/A  ...        3 prime tag
# ...                                              ...  ...                ...
# JN10XHT37_HHT_CCTGCATCATATAGCC-1                 N/A  ...        3 prime tag
# JN10XHT37_HHT_CGGGTCAGTGTTTACG-1                 N/A  ...        3 prime tag
# JN10XHT37_HHT_TCATGAGAGTGCGTCC-1                 N/A  ...        3 prime tag
# JN10XHT79_HHT_TACCGGGAGAGCCATG-1                 N/A  ...        3 prime tag
# JN10XHT125_HHT_CCCGGAAAGCTGGCTC-1                N/A  ...        3 prime tag
#
#                                   sequencing_platform is_primary_data  \
# JN10XHT119_HHT_TCCTTCTCACTGATTG-1         EFO:0008637            true
# JN10XHT123_HHT_AGAACCTTCCTTCTGG-1         EFO:0008637            true
# JN10XHT129_HHT_AGACTCACATGTGGCC-1         EFO:0008637            true
# JN10XHT129_HHT_TTCGGTCAGACTTCAC-1         EFO:0008637            true
# JN10XHT137_HHT_CCGGTAGCAGTCTACA-1         EFO:0008637            true
# ...                                               ...             ...
# JN10XHT37_HHT_CCTGCATCATATAGCC-1          EFO:0008637            true
# JN10XHT37_HHT_CGGGTCAGTGTTTACG-1          EFO:0008637            true
# JN10XHT37_HHT_TCATGAGAGTGCGTCC-1          EFO:0008637            true
# JN10XHT79_HHT_TACCGGGAGAGCCATG-1          EFO:0008637            true
# JN10XHT125_HHT_CCCGGAAAGCTGGCTC-1         EFO:0008637            true
#
#                                   reference_genome gene_annotation_version  \
# JN10XHT119_HHT_TCCTTCTCACTGATTG-1           GRCh38                     v98
# JN10XHT123_HHT_AGAACCTTCCTTCTGG-1           GRCh38                     v98
# JN10XHT129_HHT_AGACTCACATGTGGCC-1           GRCh38                     v98
# JN10XHT129_HHT_TTCGGTCAGACTTCAC-1           GRCh38                     v98
# JN10XHT137_HHT_CCGGTAGCAGTCTACA-1           GRCh38                     v98
# ...                                            ...                     ...
# JN10XHT37_HHT_CCTGCATCATATAGCC-1            GRCh38                     v98
# JN10XHT37_HHT_CGGGTCAGTGTTTACG-1            GRCh38                     v98
# JN10XHT37_HHT_TCATGAGAGTGCGTCC-1            GRCh38                     v98
# JN10XHT79_HHT_TACCGGGAGAGCCATG-1            GRCh38                     v98
# JN10XHT125_HHT_CCCGGAAAGCTGGCTC-1           GRCh38                     v98
#
#                                   alignment_software intron_inclusion  \
# JN10XHT119_HHT_TCCTTCTCACTGATTG-1     CellRanger 7.1              yes
# JN10XHT123_HHT_AGAACCTTCCTTCTGG-1     CellRanger 7.1              yes
# JN10XHT129_HHT_AGACTCACATGTGGCC-1     CellRanger 7.1              yes
# JN10XHT129_HHT_TTCGGTCAGACTTCAC-1     CellRanger 7.1              yes
# JN10XHT137_HHT_CCGGTAGCAGTCTACA-1     CellRanger 7.1              yes
# ...                                              ...              ...
# JN10XHT37_HHT_CCTGCATCATATAGCC-1      CellRanger 7.1              yes
# JN10XHT37_HHT_CGGGTCAGTGTTTACG-1      CellRanger 7.1              yes
# JN10XHT37_HHT_TCATGAGAGTGCGTCC-1      CellRanger 7.1              yes
# JN10XHT79_HHT_TACCGGGAGAGCCATG-1      CellRanger 7.1              yes
# JN10XHT125_HHT_CCCGGAAAGCTGGCTC-1     CellRanger 7.1              yes
#
#                                   disease_ontology_term_id  \
# JN10XHT119_HHT_TCCTTCTCACTGATTG-1             PATO:0000461
# JN10XHT123_HHT_AGAACCTTCCTTCTGG-1             PATO:0000461
# JN10XHT129_HHT_AGACTCACATGTGGCC-1             PATO:0000461
# JN10XHT129_HHT_TTCGGTCAGACTTCAC-1             PATO:0000461
# JN10XHT137_HHT_CCGGTAGCAGTCTACA-1             PATO:0000461
# ...                                                    ...
# JN10XHT37_HHT_CCTGCATCATATAGCC-1              PATO:0000461
# JN10XHT37_HHT_CGGGTCAGTGTTTACG-1              PATO:0000461
# JN10XHT37_HHT_TCATGAGAGTGCGTCC-1              PATO:0000461
# JN10XHT79_HHT_TACCGGGAGAGCCATG-1              PATO:0000461
# JN10XHT125_HHT_CCCGGAAAGCTGGCTC-1             PATO:0000461
#
#                                   self_reported_ethnicity_ontology_term_id  \
# JN10XHT119_HHT_TCCTTCTCACTGATTG-1                                  unknown
# JN10XHT123_HHT_AGAACCTTCCTTCTGG-1                                  unknown
# JN10XHT129_HHT_AGACTCACATGTGGCC-1                                  unknown
# JN10XHT129_HHT_TTCGGTCAGACTTCAC-1                                  unknown
# JN10XHT137_HHT_CCGGTAGCAGTCTACA-1                                  unknown
# ...                                                                    ...
# JN10XHT37_HHT_CCTGCATCATATAGCC-1                                   unknown
# JN10XHT37_HHT_CGGGTCAGTGTTTACG-1                                   unknown
# JN10XHT37_HHT_TCATGAGAGTGCGTCC-1                                   unknown
# JN10XHT79_HHT_TACCGGGAGAGCCATG-1                                   unknown
# JN10XHT125_HHT_CCCGGAAAGCTGGCTC-1                                  unknown
#
#                                   development_stage_ontology_term_id
# JN10XHT119_HHT_TCCTTCTCACTGATTG-1                            unknown
# JN10XHT123_HHT_AGAACCTTCCTTCTGG-1                            unknown
# JN10XHT129_HHT_AGACTCACATGTGGCC-1                            unknown
# JN10XHT129_HHT_TTCGGTCAGACTTCAC-1                            unknown
# JN10XHT137_HHT_CCGGTAGCAGTCTACA-1                            unknown
# ...                                                              ...
# JN10XHT37_HHT_CCTGCATCATATAGCC-1                             unknown
# JN10XHT37_HHT_CGGGTCAGTGTTTACG-1                             unknown
# JN10XHT37_HHT_TCATGAGAGTGCGTCC-1                             unknown
# JN10XHT79_HHT_TACCGGGAGAGCCATG-1                             unknown
# JN10XHT125_HHT_CCCGGAAAGCTGGCTC-1                            unknown
#
# [1529919 rows x 38 columns]

# %%
adata.obs = merged_df

# %% [markdown]
# # Add author cell type markers to UNS

# %%
# no cell type markers provided -> will be done by CAP

# %% [markdown]
# # Check author cell type annotations and Cell Ontology IDs

# %%
adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False).index.tolist()
# Out:
# ['AT2',
#  'AT1',
#  'AM',
#  'Secretory',
#  'Fibroblast_Alveolar',
#  'Ciliated',
#  'Monocyte',
#  'IM',
#  'T',
#  'Goblet',
#  'gCap',
#  'Aerocyte',
#  'Lymphatic',
#  'Fibroblast_Adventitial',
#  'Mac_div',
#  'ABC',
#  'Mesothelial',
#  'SMC',
#  'Artery',
#  'Basal',
#  'Fibroblast_PB',
#  'NK',
#  'Fibroblast_CTHRC1',
#  'Vein',
#  'B_plasma',
#  'Systemic',
#  'DC',
#  'Pericyte',
#  'Mast',
#  'PNEC',
#  'Fibroblast_FRC',
#  'Endo_div',
#  'Tuft']

# %%
cell_ontology_dict = {
    'AT2': 'CL:0002063',
    'AT1': 'CL:0002062',
    'AM': 'CL:0000583',
    'Secretory': 'CL:0000151',
    'Fibroblast_Alveolar': '',
    'Ciliated': 'CL:0000064',
    'Monocyte': 'CL:0000576',
    'IM': 'CL:4033043',
    'T': 'CL:0000084',
    'Goblet': 'CL:0000160',
    'gCap': 'CL:4028002',
    'Aerocyte': 'NaN', #NaN
    'Lymphatic': 'NaN', #NaN
    'Fibroblast_Adventitial': 'CL:0000057', #fibroblast
    'Mac_div': 'CL:0000235', # macrophage
    'ABC': 'CL:0000236', # B cell
    'Mesothelial': 'CL:0000077',
    'SMC': 'CL:0000192',
    'Artery': 'NaN', #NaN
    'Basal': 'CL:0000646',
    'Fibroblast_PB': 'CL:0000057', #fibroblast
    'NK': 'CL:0000623',
    'Fibroblast_CTHRC1': 'CL:0000057', #fibroblast
    'Vein': 'NaN', #NaN
    'B_plasma': 'CL:0000786',
    'Systemic': 'NaN',
    'DC': 'CL:0000451',
    'Pericyte': 'CL:0000669',
    'Mast': 'CL:0000097',
    'PNEC': 'CL:1000223',
    'Fibroblast_FRC': 'CL:0000057', #fibroblast
    'Endo_div': 'CL:0000115',
    'Tuft': 'CL:0002204' # brush cell
}

# %%
adata.obs[CELL_TYPE_ONTOLOGY_ID] = adata.obs[AUTHOR_CELL_TYPE].map(cell_ontology_dict)

adata.obs[CELL_TYPE_ONTOLOGY_ID].value_counts(dropna=False)
# Out:
# CL:0002063    596855
# CL:0002062    540665
# CL:0000583    153740
# CL:0000151     48914
#                38338
# CL:0000064     31003
# NaN            22511
# CL:0000576     16477
# CL:4033043     12557
# CL:0000057     11090
# CL:0000084     10754
# CL:0000160      9800
# CL:4028002      9131
# CL:0000235      5616
# CL:0000236      4155
# CL:0000077      3940
# CL:0000192      3545
# CL:0000646      2584
# CL:0000623      2313
# CL:0000786      1624
# CL:0000451      1342
# CL:0000669      1249
# CL:0000097       786
# CL:1000223       711
# CL:0000115       127
# CL:0002204        92
# Name: cell_type_ontology_term_id, dtype: int64

# %% [markdown]
# # Check whether ENSEMBL IDs in var

# %%
pd.set_option('display.max_rows', 100)
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [MIR1302-2HG, FAM138A, OR4F5, AL627309.1, AL627309.3, AL627309.2, AL627309.5, AL627309.4, AP006222.2, AL732372.1, OR4F29, AC114498.1, OR4F16, AL669831.2, LINC01409, FAM87B, LINC01128, LINC00115, FAM41C, AL645608.6, AL645608.2, AL645608.4, LINC02593, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.7, HES4, ISG15, AL645608.1, AGRN, AL645608.5, AL645608.8, RNF223, C1orf159, AL390719.3, LINC01342, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, AL162741.1, UBE2J2, LINC01786, SCNN1D, ACAP3, PUSL1, INTS11, AL139287.1, CPTP, TAS1R3, DVL1, MXRA8, AURKAIP1, CCNL2, MRPL20-AS1, MRPL20, AL391244.2, ANKRD65, AL391244.1, TMEM88B, LINC01770, VWA1, ATAD3C, ATAD3B, ATAD3A, TMEM240, SSU72, AL645728.1, FNDC10, AL691432.4, AL691432.2, MIB2, MMP23B, CDK11B, FO704657.1, SLC35E2B, CDK11A, SLC35E2A, NADK, GNB1, AL109917.1, CALML6, TMEM52, CFAP74, AL391845.2, GABRD, AL391845.1, PRKCZ, AL590822.2, PRKCZ-AS1, FAAP20, AL590822.1, SKI, ...]
#
# [36601 rows x 0 columns]

# %%
adata.var['gene_symbol'] = adata.var.index
adata.var
# Out:
#              gene_symbol
# MIR1302-2HG  MIR1302-2HG
# FAM138A          FAM138A
# OR4F5              OR4F5
# AL627309.1    AL627309.1
# AL627309.3    AL627309.3
# ...                  ...
# AC141272.1    AC141272.1
# AC023491.2    AC023491.2
# AC007325.1    AC007325.1
# AC007325.4    AC007325.4
# AC007325.2    AC007325.2
#
# [36601 rows x 1 columns]

# %%
ensembl_mapping = pd.read_csv("/ictstr01/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kaminski_unpubl/gene_symbols_Sauler_mapped.csv")
ensembl_mapping
# Out:
#        Unnamed: 0 hgnc_symbol  ensembl_gene_id
# 0               1     A3GALT2  ENSG00000184389
# 1               2     AADACL3  ENSG00000188984
# 2               3     AADACL4  ENSG00000204518
# 3               4        AAK1  ENSG00000115977
# 4               5       ABCA4  ENSG00000198691
# ...           ...         ...              ...
# 27096       27097      ZSWIM1  ENSG00000168612
# 27097       27098      ZSWIM3  ENSG00000132801
# 27098       27099      ZSWIM9  ENSG00000185453
# 27099       27100        ZXDA  ENSG00000198205
# 27100       27101        ZXDB  ENSG00000198455
#
# [27101 rows x 3 columns]

# %%
ensembl_mapping_dict = dict(zip(ensembl_mapping['hgnc_symbol'], ensembl_mapping['ensembl_gene_id']))

adata.var['ensembl_id'] = adata.var['gene_symbol'].map(ensembl_mapping_dict)

# %%
adata.var['ensembl_id'].value_counts(dropna=False)
# Out:
# NaN                12570
# ENSG00000243485        1
# ENSG00000258955        1
# ENSG00000258694        1
# ENSG00000087303        1
#                    ...
# ENSG00000137161        1
# ENSG00000171611        1
# ENSG00000221821        1
# ENSG00000146223        1
# ENSG00000274847        1
# Name: ensembl_id, Length: 24032, dtype: int64

# %%
adata.var.index.name = 'index'

adata.var
# Out:
#              gene_symbol       ensembl_id
# index
# MIR1302-2HG  MIR1302-2HG  ENSG00000243485
# FAM138A          FAM138A  ENSG00000237613
# OR4F5              OR4F5  ENSG00000186092
# AL627309.1    AL627309.1              NaN
# AL627309.3    AL627309.3              NaN
# ...                  ...              ...
# AC141272.1    AC141272.1              NaN
# AC023491.2    AC023491.2              NaN
# AC007325.1    AC007325.1              NaN
# AC007325.4    AC007325.4              NaN
# AC007325.2    AC007325.2              NaN
#
# [36601 rows x 2 columns]

# %% [markdown]
# # Check raw data

# %%
adata.X.toarray().max()
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
adata.X = adata.X.astype(np.int64)

# %%
adata.raw = adata

# %%
adata.X
# Out:
# <1529919x36601 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2616853086 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <1529919x36601 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2616853086 stored elements in Compressed Sparse Row format>

# %%
adata.X.toarray().max()

# %%
adata.raw.X.toarray().max()

# %% [markdown]
# ## Validation result
#
# ### UNS Validation
# - OK: Tier 1 UNS Google Sheet
# - OK: Tier 1 UNS AnnData Object  same as Google Sheet
#
# ### OBS Validation
# - OK: Tier 1 OBS Google Sheet
# - OK: Tier 1 OBS AnnData Object same as Google Sheet

# %% [markdown]
# # Data Submission Status
#
# - CHECK: Raw counts in X and in raw
# - CHECK: Tier 1 Metadata in OBS
# - CHECK: Cell ontology IDs mapped ourselves
# - CHECK: Author cell type in OBS
# - MISSING: Marker genes not provided -> CAP
# - CHECK: ENSEMBL IDs mapped ourselves -> 12570 could not me mapped using BiomaRt
#
# # Revisions:
#
# DONE

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"))
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"))
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
adata = sc.read_h5ad("/ictstr01/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision_reduced/Sauler_unpubl.h5ad")

# %%
# split adata into two datasets
adata_chunk_1 = adata[:adata.shape[0]//2].copy()
adata_chunk_2 = adata[adata.shape[0]//2:].copy()

# %%
adata_chunk_1
# Out:
# AnnData object with n_obs × n_vars = 764959 × 36601
#     obs: 'sample_ID', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'author_cell_type', 'cell_type_ontology_term_id', 'author_cell_type_markers', 'author_cell_type_description'
#     var: 'gene_symbol'
#     uns: 'batch_condition', 'comments', 'default_embedding', 'study_PI', 'title', 'unpublished'

# %%
adata_chunk_2
# Out:
# AnnData object with n_obs × n_vars = 764960 × 36601
#     obs: 'sample_ID', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'author_cell_type', 'cell_type_ontology_term_id', 'author_cell_type_markers', 'author_cell_type_description'
#     var: 'gene_symbol'
#     uns: 'batch_condition', 'comments', 'default_embedding', 'study_PI', 'title', 'unpublished'

# %%
adata_chunk_1.write_h5ad("/ictstr01/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision_reduced/Sauler_unpubl_1.h5ad")

# %%
adata_chunk_2.write_h5ad("/ictstr01/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision_reduced/Sauler_unpubl_2.h5ad")

# %%
adata_1 = sc.read_h5ad("/ictstr01/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision_reduced/Sauler_unpubl_1.h5ad")
