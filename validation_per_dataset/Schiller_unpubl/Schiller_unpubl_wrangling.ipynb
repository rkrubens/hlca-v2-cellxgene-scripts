# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import anndata2ri
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"

# %%
DATASET_ID = "Schiller_unpubl"
H5AD_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/{DATASET_ID}.h5ad"
MARKER_GENES_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/marker_genes_cell_ontologies.xlsx"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
# Name constants
AUTHOR_CELL_TYPE_L0 = 'author_cell_type_level_0'
AUTHOR_CELL_TYPE_L1 = 'author_cell_type_level_1'
AUTHOR_CELL_TYPE_L2 = 'author_cell_type_level_2'

CELL_TYPE_ONTOLOGY_ID_L0 = 'cell_type_ontology_term_id_level_0'
CELL_TYPE_ONTOLOGY_ID_L1 = 'cell_type_ontology_term_id_level_1'

CELL_TYPE_ONTOLOGY_LABEL_L0 = 'cell_type_ontology_term_label_level_0'
CELL_TYPE_ONTOLOGY_LABEL_L1 = 'cell_type_ontology_term_label_level_1'

AUTHOR_CELL_TYPE_DESCRIPTION_L0 = 'author_cell_type_description_level_0'
AUTHOR_CELL_TYPE_DESCRIPTION_L1 = 'author_cell_type_description_level_1'

MARKER_GENES_L0 = 'author_cell_type_markers_level_0'
MARKER_GENES_L1 = 'author_cell_type_markers_level_1'

# Finest grained annotation will be generic dataset cell type
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'
CELL_TYPE_ONTOLOGY_LABEL = 'cell_type_ontology_term_label'
MARKER_GENES = 'author_cell_type_markers'
AUTHOR_CELL_TYPE_DESCRIPTION = 'author_cell_type_description'

# %% [markdown]
# # Load data

# %%
adata = sc.read_h5ad(H5AD_PATH)
obs = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "obs")
uns = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "uns")

# %% [markdown]
# # Validate obs and uns from Tier 1 Metadata Template

# %%
val_workflow = ValidationWorkflow(
    input = uns,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                  title          study_PI      batch_condition  \
# 0  Schiller_single_nuc  Herbert Schiller  condition, donor_id
#
#   default_embedding              unpublished  \
# 0            X_hlca  protected under embargo
#
#                                             comments
# 0  Samples from patients with the same health sta...

# %%
val_workflow = ValidationWorkflow(
    input = obs,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation error(s) encountered.
# {
# │   'development_stage_ontology_term_id': "Must start with 'HsapDv:' or be 'na', 'NA', or 'N/A'. Invalid entries found."
# }
# Error containing field: development_stage_ontology_term_id
# Error message: Must start with 'HsapDv:' or be 'na', 'NA', or 'N/A'. Invalid entries found.
# Value counts:
# HsapDv:0000242    5
# HsapDv:0000241    4
# unknown           4
# HsapDv:0000240    3
# HsapDv:0000239    1
# Name: development_stage_ontology_term_id, dtype: int64
# Returning error-containing OBS dataframe.
#      sample_ID    donor_id                            protocol_URL  \
# 0       ASK612      ASK612  same multiplexed protocol, unpublished
# 1       ASK620      ASK620  same multiplexed protocol, unpublished
# 2       ASK633      ASK633  same multiplexed protocol, unpublished
# 3       ASK621      ASK621  same multiplexed protocol, unpublished
# 4       ASK627      ASK627  same multiplexed protocol, unpublished
# 5       ASK634      ASK634  same multiplexed protocol, unpublished
# 6       ASK543      ASK543  same multiplexed protocol, unpublished
# 7       ASK611      ASK611  same multiplexed protocol, unpublished
# 8       ASK631      ASK631  same multiplexed protocol, unpublished
# 9      M434WRC     M434WRC  same multiplexed protocol, unpublished
# 10      MLT220      MLT220  same multiplexed protocol, unpublished
# 11      MLT251      MLT251  same multiplexed protocol, unpublished
# 12      MLT255      MLT255  same multiplexed protocol, unpublished
# 13      COPDIV  unassigned  same multiplexed protocol, unpublished
# 14      COPDII  unassigned  same multiplexed protocol, unpublished
# 15      Smoker  unassigned  same multiplexed protocol, unpublished
# 16  Non-Smoker  unassigned  same multiplexed protocol, unpublished
#
#                            institute                  sample_collection_site  \
# 0   CPC/LHI, Helmholtz Center Munich  Asklepios Lungenklinik Gauting, Munich
# 1   CPC/LHI, Helmholtz Center Munich  Asklepios Lungenklinik Gauting, Munich
# 2   CPC/LHI, Helmholtz Center Munich  Asklepios Lungenklinik Gauting, Munich
# 3   CPC/LHI, Helmholtz Center Munich  Asklepios Lungenklinik Gauting, Munich
# 4   CPC/LHI, Helmholtz Center Munich  Asklepios Lungenklinik Gauting, Munich
# 5   CPC/LHI, Helmholtz Center Munich  Asklepios Lungenklinik Gauting, Munich
# 6   CPC/LHI, Helmholtz Center Munich  Asklepios Lungenklinik Gauting, Munich
# 7   CPC/LHI, Helmholtz Center Munich  Asklepios Lungenklinik Gauting, Munich
# 8   CPC/LHI, Helmholtz Center Munich  Asklepios Lungenklinik Gauting, Munich
# 9   CPC/LHI, Helmholtz Center Munich                    LMU Klinikum, Munich
# 10  CPC/LHI, Helmholtz Center Munich                    LMU Klinikum, Munich
# 11  CPC/LHI, Helmholtz Center Munich                    LMU Klinikum, Munich
# 12  CPC/LHI, Helmholtz Center Munich                    LMU Klinikum, Munich
# 13  CPC/LHI, Helmholtz Center Munich                    LMU Klinikum, Munich
# 14  CPC/LHI, Helmholtz Center Munich  Asklepios Lungenklinik Gauting, Munich
# 15  CPC/LHI, Helmholtz Center Munich  Asklepios Lungenklinik Gauting, Munich
# 16  CPC/LHI, Helmholtz Center Munich  Asklepios Lungenklinik Gauting, Munich
#
#    sample_collection_relative_time_point  library_ID library_ID_repository  \
# 0                                   day1  Non-Smoker        not applicable
# 1                                   day1  Non-Smoker        not applicable
# 2                                   day1  Non-Smoker        not applicable
# 3                                   day1      Smoker        not applicable
# 4                                   day1      Smoker        not applicable
# 5                                   day1      Smoker        not applicable
# 6                                   day1      COPDII        not applicable
# 7                                   day1      COPDII        not applicable
# 8                                   day1      COPDII        not applicable
# 9                                   day1      COPDIV        not applicable
# 10                                  day1      COPDIV        not applicable
# 11                                  day1      COPDIV        not applicable
# 12                                  day1      COPDIV        not applicable
# 13                                  day1      COPDIV        not applicable
# 14                                  day1      COPDII        not applicable
# 15                                  day1      Smoker        not applicable
# 16                                  day1  Non-Smoker        not applicable
#
#          author_batch_notes organism_ontology_term_id  ... sequenced_fragment  \
# 0   same personnel, batch 1            NCBITaxon:9606  ...        3 prime tag
# 1   same personnel, batch 1            NCBITaxon:9606  ...        3 prime tag
# 2   same personnel, batch 1            NCBITaxon:9606  ...        3 prime tag
# 3   same personnel, batch 1            NCBITaxon:9606  ...        3 prime tag
# 4   same personnel, batch 1            NCBITaxon:9606  ...        3 prime tag
# 5   same personnel, batch 1            NCBITaxon:9606  ...        3 prime tag
# 6   same personnel, batch 2            NCBITaxon:9606  ...        3 prime tag
# 7   same personnel, batch 2            NCBITaxon:9606  ...        3 prime tag
# 8   same personnel, batch 2            NCBITaxon:9606  ...        3 prime tag
# 9   same personnel, batch 2            NCBITaxon:9606  ...        3 prime tag
# 10  same personnel, batch 2            NCBITaxon:9606  ...        3 prime tag
# 11  same personnel, batch 2            NCBITaxon:9606  ...        3 prime tag
# 12  same personnel, batch 2            NCBITaxon:9606  ...        3 prime tag
# 13  same personnel, batch 2            NCBITaxon:9606  ...        3 prime tag
# 14  same personnel, batch 2            NCBITaxon:9606  ...        3 prime tag
# 15  same personnel, batch 1            NCBITaxon:9606  ...        3 prime tag
# 16  same personnel, batch 1            NCBITaxon:9606  ...        3 prime tag
#
#    sequencing_platform is_primary_data reference_genome  \
# 0          EFO:0008637            true           GRCh38
# 1          EFO:0008637            true           GRCh38
# 2          EFO:0008637            true           GRCh38
# 3          EFO:0008637            true           GRCh38
# 4          EFO:0008637            true           GRCh38
# 5          EFO:0008637            true           GRCh38
# 6          EFO:0008637            true           GRCh38
# 7          EFO:0008637            true           GRCh38
# 8          EFO:0008637            true           GRCh38
# 9          EFO:0008637            true           GRCh38
# 10         EFO:0008637            true           GRCh38
# 11         EFO:0008637            true           GRCh38
# 12         EFO:0008637            true           GRCh38
# 13         EFO:0008637            true           GRCh38
# 14         EFO:0008637            true           GRCh38
# 15         EFO:0008637            true           GRCh38
# 16         EFO:0008637            true           GRCh38
#
#    gene_annotation_version  alignment_software intron_inclusion  \
# 0                     v107  cell ranger 6.1.2.              yes
# 1                     v107  cell ranger 6.1.2.              yes
# 2                     v107  cell ranger 6.1.2.              yes
# 3                     v107  cell ranger 6.1.2.              yes
# 4                     v107  cell ranger 6.1.2.              yes
# 5                     v107  cell ranger 6.1.2.              yes
# 6                     v107  cell ranger 6.1.2.              yes
# 7                     v107  cell ranger 6.1.2.              yes
# 8                     v107  cell ranger 6.1.2.              yes
# 9                     v107  cell ranger 6.1.2.              yes
# 10                    v107  cell ranger 6.1.2.              yes
# 11                    v107  cell ranger 6.1.2.              yes
# 12                    v107  cell ranger 6.1.2.              yes
# 13                    v107  cell ranger 6.1.2.              yes
# 14                    v107  cell ranger 6.1.2.              yes
# 15                    v107  cell ranger 6.1.2.              yes
# 16                    v107  cell ranger 6.1.2.              yes
#
#    disease_ontology_term_id self_reported_ethnicity_ontology_term_id  \
# 0              PATO:0000461                                  unknown
# 1              PATO:0000461                                  unknown
# 2              PATO:0000461                                  unknown
# 3              PATO:0000461                                  unknown
# 4              PATO:0000461                                  unknown
# 5              PATO:0000461                                  unknown
# 6             MONDO:0005002                                  unknown
# 7             MONDO:0005002                                  unknown
# 8             MONDO:0005002                                  unknown
# 9             MONDO:0005002                                  unknown
# 10            MONDO:0005002                                  unknown
# 11            MONDO:0005002                                  unknown
# 12            MONDO:0005002                                  unknown
# 13            MONDO:0005002                                  unknown
# 14            MONDO:0005002                                  unknown
# 15             PATO:0000461                                  unknown
# 16             PATO:0000461                                  unknown
#
#    development_stage_ontology_term_id
# 0                      HsapDv:0000240
# 1                      HsapDv:0000242
# 2                      HsapDv:0000242
# 3                      HsapDv:0000242
# 4                      HsapDv:0000242
# 5                      HsapDv:0000240
# 6                      HsapDv:0000239
# 7                      HsapDv:0000241
# 8                      HsapDv:0000242
# 9                      HsapDv:0000241
# 10                     HsapDv:0000241
# 11                     HsapDv:0000240
# 12                     HsapDv:0000241
# 13                            unknown
# 14                            unknown
# 15                            unknown
# 16                            unknown
#
# [17 rows x 37 columns]

# %% [markdown]
# # Validate obs and uns from adata

# %%
# Merge obs and uns
merger = AnnDataMerger(
    adata = adata,
    obs_df = obs
)

adata = merger.add_obs_metadata(
    adata_col = 'sample_ID',
    df_col = 'sample_ID',
    skip = None,
)

adata.obs
# Out:
# Warning: Column donor_id already exists in AnnData OBS. Overwriting with new values.
# Warning: Column protocol_URL already exists in AnnData OBS. Overwriting with new values.
# Warning: Column institute already exists in AnnData OBS. Overwriting with new values.
# Warning: Column sample_collection_site already exists in AnnData OBS. Overwriting with new values.
# Warning: Column sample_collection_relative_time_point already exists in AnnData OBS. Overwriting with new values.
# Warning: Column library_ID already exists in AnnData OBS. Overwriting with new values.
# Warning: Column library_ID_repository already exists in AnnData OBS. Overwriting with new values.
# Warning: Column author_batch_notes already exists in AnnData OBS. Overwriting with new values.
# Warning: Column organism_ontology_term_id already exists in AnnData OBS. Overwriting with new values.
# Warning: Column manner_of_death already exists in AnnData OBS. Overwriting with new values.
# Warning: Column sample_source already exists in AnnData OBS. Overwriting with new values.
# Warning: Column sex_ontology_term_id already exists in AnnData OBS. Overwriting with new values.
# Warning: Column sample_collection_method already exists in AnnData OBS. Overwriting with new values.
# Warning: Column tissue_type already exists in AnnData OBS. Overwriting with new values.
# Warning: Column sampled_site_condition already exists in AnnData OBS. Overwriting with new values.
# Warning: Column tissue_ontology_term_id already exists in AnnData OBS. Overwriting with new values.
# Warning: Column tissue_free_text already exists in AnnData OBS. Overwriting with new values.
# Warning: Column sample_preservation_method already exists in AnnData OBS. Overwriting with new values.
# Warning: Column suspension_type already exists in AnnData OBS. Overwriting with new values.
# Warning: Column cell_enrichment already exists in AnnData OBS. Overwriting with new values.
# Warning: Column cell_viability_percentage already exists in AnnData OBS. Overwriting with new values.
# Warning: Column cell_number_loaded already exists in AnnData OBS. Overwriting with new values.
# Warning: Column sample_collection_year already exists in AnnData OBS. Overwriting with new values.
# Warning: Column assay_ontology_term_id already exists in AnnData OBS. Overwriting with new values.
# Warning: Column library_preparation_batch already exists in AnnData OBS. Overwriting with new values.
# Warning: Column library_sequencing_run already exists in AnnData OBS. Overwriting with new values.
# Warning: Column sequenced_fragment already exists in AnnData OBS. Overwriting with new values.
# Warning: Column sequencing_platform already exists in AnnData OBS. Overwriting with new values.
# Warning: Column is_primary_data already exists in AnnData OBS. Overwriting with new values.
# Warning: Column reference_genome already exists in AnnData OBS. Overwriting with new values.
# Warning: Column gene_annotation_version already exists in AnnData OBS. Overwriting with new values.
# Warning: Column alignment_software already exists in AnnData OBS. Overwriting with new values.
# Warning: Column intron_inclusion already exists in AnnData OBS. Overwriting with new values.
# Warning: Column disease_ontology_term_id already exists in AnnData OBS. Overwriting with new values.
# Warning: Column self_reported_ethnicity_ontology_term_id already exists in AnnData OBS. Overwriting with new
# values.
# Warning: Column development_stage_ontology_term_id already exists in AnnData OBS. Overwriting with new values.
#                    condition genotype   status demultiplex_sample  \
# AAACCCAAGCGAAACC-1    COPDII        1  singlet           COPDII_1
# AAACCCACAATCTGCA-1    COPDII        1  singlet           COPDII_1
# AAACCCACACACTTAG-1    COPDII        1  singlet           COPDII_1
# AAACCCAGTACCACGC-1    COPDII        1  doublet           COPDII_1
# AAACCCAGTGACTGAG-1    COPDII        1  singlet           COPDII_1
# ...                      ...      ...      ...                ...
# TTTGGAGTCGCTAATG-1    Smoker        0  singlet           Smoker_0
# TTTGGTTGTAGCTAAA-1    Smoker        0  singlet           Smoker_0
# TTTGGTTTCTCATTGT-1    Smoker        0  singlet           Smoker_0
# TTTGTTGTCCGTATGA-1    Smoker        0  singlet           Smoker_0
# TTTGTTGTCGCCTTGT-1    Smoker        0  singlet           Smoker_0
#
#                     n_genes_by_counts  log1p_n_genes_by_counts  total_counts  \
# AAACCCAAGCGAAACC-1               1617                 7.388946        2898.0
# AAACCCACAATCTGCA-1               2051                 7.626570        3268.0
# AAACCCACACACTTAG-1               1958                 7.580189        3132.0
# AAACCCAGTACCACGC-1               2184                 7.689371        3527.0
# AAACCCAGTGACTGAG-1               1456                 7.284135        2514.0
# ...                               ...                      ...           ...
# TTTGGAGTCGCTAATG-1                704                 6.558198        1130.0
# TTTGGTTGTAGCTAAA-1                728                 6.591674        1222.0
# TTTGGTTTCTCATTGT-1                674                 6.514713        1089.0
# TTTGTTGTCCGTATGA-1                813                 6.701960        1661.0
# TTTGTTGTCGCCTTGT-1                809                 6.697034        1179.0
#
#                     log1p_total_counts  pct_counts_in_top_50_genes  \
# AAACCCAAGCGAAACC-1            7.972121                   17.563837
# AAACCCACAATCTGCA-1            8.092239                   12.301102
# AAACCCACACACTTAG-1            8.049747                   14.112388
# AAACCCAGTACCACGC-1            8.168487                   11.256025
# AAACCCAGTGACTGAG-1            7.830028                   19.809069
# ...                                ...                         ...
# TTTGGAGTCGCTAATG-1            7.030858                   23.893805
# TTTGGTTGTAGCTAAA-1            7.109062                   26.595745
# TTTGGTTTCTCATTGT-1            6.993933                   28.466483
# TTTGTTGTCCGTATGA-1            7.415777                   31.727875
# TTTGTTGTCGCCTTGT-1            7.073270                   20.610687
#
#                     pct_counts_in_top_100_genes  ...  sequenced_fragment  \
# AAACCCAAGCGAAACC-1                    26.293996  ...         3 prime tag
# AAACCCACAATCTGCA-1                    19.033048  ...         3 prime tag
# AAACCCACACACTTAG-1                    21.328225  ...         3 prime tag
# AAACCCAGTACCACGC-1                    17.833853  ...         3 prime tag
# AAACCCAGTGACTGAG-1                    28.758950  ...         3 prime tag
# ...                                         ...  ...                 ...
# TTTGGAGTCGCTAATG-1                    36.460177  ...         3 prime tag
# TTTGGTTGTAGCTAAA-1                    38.952537  ...         3 prime tag
# TTTGGTTTCTCATTGT-1                    40.404040  ...         3 prime tag
# TTTGTTGTCCGTATGA-1                    42.865744  ...         3 prime tag
# TTTGTTGTCGCCTTGT-1                    31.382528  ...         3 prime tag
#
#                     sequencing_platform  is_primary_data  reference_genome  \
# AAACCCAAGCGAAACC-1          EFO:0008637             true            GRCh38
# AAACCCACAATCTGCA-1          EFO:0008637             true            GRCh38
# AAACCCACACACTTAG-1          EFO:0008637             true            GRCh38
# AAACCCAGTACCACGC-1          EFO:0008637             true            GRCh38
# AAACCCAGTGACTGAG-1          EFO:0008637             true            GRCh38
# ...                                 ...              ...               ...
# TTTGGAGTCGCTAATG-1          EFO:0008637             true            GRCh38
# TTTGGTTGTAGCTAAA-1          EFO:0008637             true            GRCh38
# TTTGGTTTCTCATTGT-1          EFO:0008637             true            GRCh38
# TTTGTTGTCCGTATGA-1          EFO:0008637             true            GRCh38
# TTTGTTGTCGCCTTGT-1          EFO:0008637             true            GRCh38
#
#                     gene_annotation_version  alignment_software  \
# AAACCCAAGCGAAACC-1                     v107  cell ranger 6.1.2.
# AAACCCACAATCTGCA-1                     v107  cell ranger 6.1.2.
# AAACCCACACACTTAG-1                     v107  cell ranger 6.1.2.
# AAACCCAGTACCACGC-1                     v107  cell ranger 6.1.2.
# AAACCCAGTGACTGAG-1                     v107  cell ranger 6.1.2.
# ...                                     ...                 ...
# TTTGGAGTCGCTAATG-1                     v107  cell ranger 6.1.2.
# TTTGGTTGTAGCTAAA-1                     v107  cell ranger 6.1.2.
# TTTGGTTTCTCATTGT-1                     v107  cell ranger 6.1.2.
# TTTGTTGTCCGTATGA-1                     v107  cell ranger 6.1.2.
# TTTGTTGTCGCCTTGT-1                     v107  cell ranger 6.1.2.
#
#                     intron_inclusion  disease_ontology_term_id  \
# AAACCCAAGCGAAACC-1               yes             MONDO:0005002
# AAACCCACAATCTGCA-1               yes             MONDO:0005002
# AAACCCACACACTTAG-1               yes             MONDO:0005002
# AAACCCAGTACCACGC-1               yes             MONDO:0005002
# AAACCCAGTGACTGAG-1               yes             MONDO:0005002
# ...                              ...                       ...
# TTTGGAGTCGCTAATG-1               yes              PATO:0000461
# TTTGGTTGTAGCTAAA-1               yes              PATO:0000461
# TTTGGTTTCTCATTGT-1               yes              PATO:0000461
# TTTGTTGTCCGTATGA-1               yes              PATO:0000461
# TTTGTTGTCGCCTTGT-1               yes              PATO:0000461
#
#                     self_reported_ethnicity_ontology_term_id  \
# AAACCCAAGCGAAACC-1                                   unknown
# AAACCCACAATCTGCA-1                                   unknown
# AAACCCACACACTTAG-1                                   unknown
# AAACCCAGTACCACGC-1                                   unknown
# AAACCCAGTGACTGAG-1                                   unknown
# ...                                                      ...
# TTTGGAGTCGCTAATG-1                                   unknown
# TTTGGTTGTAGCTAAA-1                                   unknown
# TTTGGTTTCTCATTGT-1                                   unknown
# TTTGTTGTCCGTATGA-1                                   unknown
# TTTGTTGTCGCCTTGT-1                                   unknown
#
#                    development_stage_ontology_term_id
# AAACCCAAGCGAAACC-1                     HsapDv:0000239
# AAACCCACAATCTGCA-1                            unknown
# AAACCCACACACTTAG-1                     HsapDv:0000239
# AAACCCAGTACCACGC-1                            unknown
# AAACCCAGTGACTGAG-1                     HsapDv:0000239
# ...                                               ...
# TTTGGAGTCGCTAATG-1                            unknown
# TTTGGTTGTAGCTAAA-1                            unknown
# TTTGGTTTCTCATTGT-1                     HsapDv:0000242
# TTTGTTGTCCGTATGA-1                            unknown
# TTTGTTGTCGCCTTGT-1                     HsapDv:0000242
#
# [48301 rows x 77 columns]

# %%
marker_genes_df = pd.read_excel(MARKER_GENES_PATH, sheet_name='Sheet1')

# remove rows with all NaNs
marker_genes_df = marker_genes_df.dropna(how='all')

# add to all values in 'ontology' column the prefix 'CL:'
marker_genes_df['ontology'] = 'CL:' + marker_genes_df['ontology'].astype(str)

marker_genes_df.columns = [AUTHOR_CELL_TYPE, CELL_TYPE_ONTOLOGY_ID, MARKER_GENES]


marker_genes_df[AUTHOR_CELL_TYPE] = marker_genes_df[AUTHOR_CELL_TYPE].replace('Macrophae MERTK+', 'Macrophage MERTK+')

marker_genes_df
# Out:
#            author_cell_type cell_type_ontology_term_id  \
# 0                       AT2               CL:0002063
# 1                       AT1               CL:0002062
# 2                Basal cell               CL:0000646
# 3             Multiciliated               CL:4030034
# 4                    Goblet               CL:0000160
# 5                      Club               CL:0000158
# 7      Alveolar macrophages                 CL:0000583
# 8         Macrophage CHIT1+                 CL:0000253
# 9   Macrophage interstitial               CL:4033043
# 10        Macrophage MERTK+                 CL:0000253
# 11                      DC1                 CL:0000990
# 12                      DC2                 CL:0001056
# 13         Plasmacytoid DCs                 CL:0001058
# 14             DC activated                 CL:0001056
# 15                Monocytes                 CL:0000860
# 16   Monocytes CSF3R+/CD16-                 CL:0000875
# 18                  B cells                 CL:0000236
# 19             Plasma cells                 CL:0000786
# 20        CD4 T cells naive                 CL:0000895
# 21          CD4 T cells TRM                 CL:4033038
# 22              CD8_EM/EMRA                 CL:0000913
# 23               CD8_TRM/EM                 CL:0000909
# 24          CD8 T cells TRM                 CL:4033039
# 25        Regulatory T cell                 CL:0000815
# 26                 NK cells                 CL:0000623
# 28               Mast cells               CL:0000097
# 30          Lipofibroblasts               CL:0002553
# 31  Adventitial fibroblasts               CL:0002553
# 32                     SMCs                CL:0000192
# 33                Pericytes                 CL:0009089
# 35     EC general capillary                 CL:0002144
# 36    EC aerocyte capillary                 CL:0002145
# 37      EC venous pulmonary                 CL:4033008
# 38       EC venous systemic               CL:0002543
# 39              EC arterial                 CL:1000413
# 40                     LECs                 CL:0009086
#
#                              author_cell_type_markers
# 0   RTKN2; AGER; NCKAP5; CLIC5; SCEL;  CAV2; COL4A...
# 1   SFTPC; SFTPA1; NAPSA; SFTPA2; WIF1; ACOXL; AGB...
# 2      KRT17; TP63; CACHD1; KRT5; KRT15; AQP3;  FGFR3
# 3   DNAH12;CCDC78; CAPS;  ZBBX; HYDIN; CFAP157;ERI...
# 4   BPIFB1;MUC5B;CP; PLEKHS1; BMPR1B; ERN2; MUC4; ...
# 5                  MET; STEAP4; BMP6; SCGB3A2; SFTPB;
# 7    MARCO; INHBA; TREM1; ABHD5; PPARG; FABP4;SLC11A1
# 8                                 SLC1A3; SDC2; CHIT1
# 9              F13A1; STAB1; MRC1; RBPJ; F13A1; CD163
# 10          MERTK; SLC9A9; RGL1;HK2; CTSL; SAT1; TNS3
# 11    CLEC9A; CLNK; CPVL; WDFY4; HDAC9;MCOLN2; LRRC18
# 12                 CD86; CLEC7A; MOB3B; PLAUR;CLEC10A
# 13                       CLEC4C; PLXNA4; RHEX; NIBAN3
# 14         CCR7; BIRC3; RASSF4; TRAF1; SLCO5A1; DAPP1
# 15                   CD300E; FCN1;  VCAN; ADGRE2; FGR
# 16           CSF3R; NAMPT; XPO6; SORL1; IL1R2; ADGRG3
# 18                CD19; MS4A1;BANK1; BLK; PAX5; FCRL1
# 19                MZB1; POU2AF1; TENT5C; FCRL5; NUGGC
# 20                    LEF1; BCL11B; IL7R;  CD69; CD28
# 21                              ITGA1;ITGAE; CD2; CD6
# 22                    GZMH;KLRG1;PZP;GNLY;KLRD1; CD8A
# 23                      GZMK;EOMES;DTHD1;CRTAM; TNIP3
# 24                          CCL5;ITGA1; ITGAE;ZNF683;
# 25                  FOXP3;CTLA4;IL2RA;CD28;TIGIT;ICOS
# 26          GNLY;KLRF1;MYBL1;APBA2; NCR1;FCGR3A; NKG7
# 28  TPSAB1; TPSB2; CPA3; HPGDS; MS4A2;SLC18A2; RGS...
# 30            ITGA8;MACF1;PIEZO2; SVEP1; CDH11; NCAM2
# 31     COL3A1; CCDC80; ABCA10; FBLN1; FBN1; CFH; PODN
# 32    LGR6; ACTA2; MYH11;  LMOD1; MYOCD; IRAG1; TAGLN
# 33  GUCY1A2; PDGFRB; ADARB2; LAMC3; AFF2; ADCY3; TBX5
# 35            CA4; EDN1; NOSTRIN; FCN3; SLC6A4; BTNL9
# 36                  EDNRB;  HPGD; EMCN; PDE1C; CYP3A5
# 37  CPE; PKHD1L1; TMTC1; ADGRG6; MYRIP;SELP; ACKR1...
# 38                        COL15A1; PLVAP; VWA1; KCNE3
# 39                            BMX; GJA5; DKK2;  EFNB2
# 40  PROX1; MMRN1; PDPN;RELN; CCL21; TBX1; FLT4; SE...

# %%
# Michael's object with cell type and ontology annotations
adata_new = sc.read_h5ad("/home/icb/raphael.kfuri-rubens/data/hlca_v2/Schiller_unpubl/COPD_29_04_2024.h5ad")

# %%
df = adata.obs.merge(adata_new.obs[['cell_type', 'Level_3', 'Level_2', 'Level_1', 'group']], left_index=True, right_index=True)

df
# Out:
#                    condition genotype   status demultiplex_sample  \
# AAACCCAAGCGAAACC-1    COPDII        1  singlet           COPDII_1
# AAACCCACAATCTGCA-1    COPDII        1  singlet           COPDII_1
# AAACCCAGTACCACGC-1    COPDII        1  doublet           COPDII_1
# AAACCCAGTGACTGAG-1    COPDII        1  singlet           COPDII_1
# AAACGAAAGATCCCGC-1    COPDII        1  singlet           COPDII_1
# ...                      ...      ...      ...                ...
# TTTGGAGTCGCTAATG-1    Smoker        0  singlet           Smoker_0
# TTTGGTTGTAGCTAAA-1    Smoker        0  singlet           Smoker_0
# TTTGGTTTCTCATTGT-1    Smoker        0  singlet           Smoker_0
# TTTGTTGTCCGTATGA-1    Smoker        0  singlet           Smoker_0
# TTTGTTGTCGCCTTGT-1    Smoker        0  singlet           Smoker_0
#
#                     n_genes_by_counts  log1p_n_genes_by_counts  total_counts  \
# AAACCCAAGCGAAACC-1               1617                 7.388946        2898.0
# AAACCCACAATCTGCA-1               2051                 7.626570        3268.0
# AAACCCAGTACCACGC-1               2184                 7.689371        3527.0
# AAACCCAGTGACTGAG-1               1456                 7.284135        2514.0
# AAACGAAAGATCCCGC-1               1469                 7.293018        2574.0
# ...                               ...                      ...           ...
# TTTGGAGTCGCTAATG-1                704                 6.558198        1130.0
# TTTGGTTGTAGCTAAA-1                728                 6.591674        1222.0
# TTTGGTTTCTCATTGT-1                674                 6.514713        1089.0
# TTTGTTGTCCGTATGA-1                813                 6.701960        1661.0
# TTTGTTGTCGCCTTGT-1                809                 6.697034        1179.0
#
#                     log1p_total_counts  pct_counts_in_top_50_genes  \
# AAACCCAAGCGAAACC-1            7.972121                   17.563837
# AAACCCACAATCTGCA-1            8.092239                   12.301102
# AAACCCAGTACCACGC-1            8.168487                   11.256025
# AAACCCAGTGACTGAG-1            7.830028                   19.809069
# AAACGAAAGATCCCGC-1            7.853605                   17.055167
# ...                                ...                         ...
# TTTGGAGTCGCTAATG-1            7.030858                   23.893805
# TTTGGTTGTAGCTAAA-1            7.109062                   26.595745
# TTTGGTTTCTCATTGT-1            6.993933                   28.466483
# TTTGTTGTCCGTATGA-1            7.415777                   31.727875
# TTTGTTGTCGCCTTGT-1            7.073270                   20.610687
#
#                     pct_counts_in_top_100_genes  ...  alignment_software  \
# AAACCCAAGCGAAACC-1                    26.293996  ...  cell ranger 6.1.2.
# AAACCCACAATCTGCA-1                    19.033048  ...  cell ranger 6.1.2.
# AAACCCAGTACCACGC-1                    17.833853  ...  cell ranger 6.1.2.
# AAACCCAGTGACTGAG-1                    28.758950  ...  cell ranger 6.1.2.
# AAACGAAAGATCCCGC-1                    26.107226  ...  cell ranger 6.1.2.
# ...                                         ...  ...                 ...
# TTTGGAGTCGCTAATG-1                    36.460177  ...  cell ranger 6.1.2.
# TTTGGTTGTAGCTAAA-1                    38.952537  ...  cell ranger 6.1.2.
# TTTGGTTTCTCATTGT-1                    40.404040  ...  cell ranger 6.1.2.
# TTTGTTGTCCGTATGA-1                    42.865744  ...  cell ranger 6.1.2.
# TTTGTTGTCGCCTTGT-1                    31.382528  ...  cell ranger 6.1.2.
#
#                     intron_inclusion  disease_ontology_term_id  \
# AAACCCAAGCGAAACC-1               yes             MONDO:0005002
# AAACCCACAATCTGCA-1               yes             MONDO:0005002
# AAACCCAGTACCACGC-1               yes             MONDO:0005002
# AAACCCAGTGACTGAG-1               yes             MONDO:0005002
# AAACGAAAGATCCCGC-1               yes             MONDO:0005002
# ...                              ...                       ...
# TTTGGAGTCGCTAATG-1               yes              PATO:0000461
# TTTGGTTGTAGCTAAA-1               yes              PATO:0000461
# TTTGGTTTCTCATTGT-1               yes              PATO:0000461
# TTTGTTGTCCGTATGA-1               yes              PATO:0000461
# TTTGTTGTCGCCTTGT-1               yes              PATO:0000461
#
#                     self_reported_ethnicity_ontology_term_id  \
# AAACCCAAGCGAAACC-1                                   unknown
# AAACCCACAATCTGCA-1                                   unknown
# AAACCCAGTACCACGC-1                                   unknown
# AAACCCAGTGACTGAG-1                                   unknown
# AAACGAAAGATCCCGC-1                                   unknown
# ...                                                      ...
# TTTGGAGTCGCTAATG-1                                   unknown
# TTTGGTTGTAGCTAAA-1                                   unknown
# TTTGGTTTCTCATTGT-1                                   unknown
# TTTGTTGTCCGTATGA-1                                   unknown
# TTTGTTGTCGCCTTGT-1                                   unknown
#
#                     development_stage_ontology_term_id  \
# AAACCCAAGCGAAACC-1                      HsapDv:0000239
# AAACCCACAATCTGCA-1                             unknown
# AAACCCAGTACCACGC-1                             unknown
# AAACCCAGTGACTGAG-1                      HsapDv:0000239
# AAACGAAAGATCCCGC-1                             unknown
# ...                                                ...
# TTTGGAGTCGCTAATG-1                             unknown
# TTTGGTTGTAGCTAAA-1                             unknown
# TTTGGTTTCTCATTGT-1                      HsapDv:0000242
# TTTGTTGTCCGTATGA-1                             unknown
# TTTGTTGTCGCCTTGT-1                      HsapDv:0000242
#
#                                   cell_type       Level_3  \
# AAACCCAAGCGAAACC-1           Lipofibroblast   Fibroblasts
# AAACCCACAATCTGCA-1     Alveolar macrophages   Macrophages
# AAACCCAGTACCACGC-1             Lymphatic EC  Lymphatic EC
# AAACCCAGTGACTGAG-1              EC arterial   EC arterial
# AAACGAAAGATCCCGC-1                      AT1           AT1
# ...                                     ...           ...
# TTTGGAGTCGCTAATG-1    EC aerocyte capillary  EC capillary
# TTTGGTTGTAGCTAAA-1  Adventitial fibroblasts   Fibroblasts
# TTTGGTTTCTCATTGT-1           Lipofibroblast   Fibroblasts
# TTTGTTGTCCGTATGA-1     EC general capillary  EC capillary
# TTTGTTGTCGCCTTGT-1           Lipofibroblast   Fibroblasts
#
#                                 Level_2      Level_1    group
# AAACCCAAGCGAAACC-1   Fibroblast lineage       Stroma  outside
# AAACCCACAATCTGCA-1              Myeloid       Immune  outside
# AAACCCAGTACCACGC-1         Lymphatic EC  Endothelial   within
# AAACCCAGTGACTGAG-1        Blood vessels  Endothelial  outside
# AAACGAAAGATCCCGC-1  Alveolar epithelium   Epithelial  outside
# ...                                 ...          ...      ...
# TTTGGAGTCGCTAATG-1        Blood vessels  Endothelial  outside
# TTTGGTTGTAGCTAAA-1   Fibroblast lineage       Stroma  outside
# TTTGGTTTCTCATTGT-1   Fibroblast lineage       Stroma  outside
# TTTGTTGTCCGTATGA-1        Blood vessels  Endothelial  outside
# TTTGTTGTCGCCTTGT-1   Fibroblast lineage       Stroma  outside
#
# [42241 rows x 82 columns]

# %%
adata = adata[adata.obs.index.isin(adata_new.obs.index)].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 42241 × 20669
#     obs: 'condition', 'genotype', 'status', 'demultiplex_sample', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'sample', 'n_counts', 'n_genes', 'doublet_scores', 'scDblFinder_class', 'soupx_groups', 'scrublet', 'Level_1_transfered_label', 'Level_1_transfer_uncert', 'Level_2_transfered_label', 'Level_2_transfer_uncert', 'Level_3_transfered_label', 'Level_3_transfer_uncert', 'Level_4_transfered_label', 'Level_4_transfer_uncert', 'Level_5_transfered_label', 'Level_5_transfer_uncert', 'condition_coarse', 'leiden_0.2', 'leiden_0.3', 'leiden_0.4', 'leiden_0.5', 'leiden_1.0', 'hlca_manual_lv1', 'hlca_manual_lv2', 'sample_ID', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'ensembl_ID', 'gene_name'
#     uns: 'Level_1_transfered_label_colors', 'Level_2_transfered_label_colors', 'Level_3_transfered_label_colors', 'Level_4_transfered_label_colors', 'Level_5_transfered_label_colors', 'batch_condition', 'comments', 'condition_colors', 'default_embedding', 'hlca_manual_lv1_colors', 'hlca_manual_lv2_colors', 'hvg', 'leiden', 'leiden_0.2_colors', 'leiden_0.3_colors', 'leiden_0.4_colors', 'leiden_0.5_colors', 'leiden_1.0_colors', 'log1p', 'neighbors', 'pca', 'sample_colors', 'scrublet_colors', 'study_PI', 'title', 'umap', 'unpublished'
#     obsm: 'X_hlca', 'X_hlca_umap', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts', 'soupX_counts'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs = df
adata.obs.columns
# Out:
# Index(['condition', 'genotype', 'status', 'demultiplex_sample',
#        'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts',
#        'log1p_total_counts', 'pct_counts_in_top_50_genes',
#        'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes',
#        'pct_counts_in_top_500_genes', 'total_counts_mito',
#        'log1p_total_counts_mito', 'pct_counts_mito', 'sample', 'n_counts',
#        'n_genes', 'doublet_scores', 'scDblFinder_class', 'soupx_groups',
#        'scrublet', 'Level_1_transfered_label', 'Level_1_transfer_uncert',
#        'Level_2_transfered_label', 'Level_2_transfer_uncert',
#        'Level_3_transfered_label', 'Level_3_transfer_uncert',
#        'Level_4_transfered_label', 'Level_4_transfer_uncert',
#        'Level_5_transfered_label', 'Level_5_transfer_uncert',
#        'condition_coarse', 'leiden_0.2', 'leiden_0.3', 'leiden_0.4',
#        'leiden_0.5', 'leiden_1.0', 'hlca_manual_lv1', 'hlca_manual_lv2',
#        'sample_ID', 'donor_id', 'protocol_URL', 'institute',
#        'sample_collection_site', 'sample_collection_relative_time_point',
#        'library_ID', 'library_ID_repository', 'author_batch_notes',
#        'organism_ontology_term_id', 'manner_of_death', 'sample_source',
#        'sex_ontology_term_id', 'sample_collection_method', 'tissue_type',
#        'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text',
#        'sample_preservation_method', 'suspension_type', 'cell_enrichment',
#        'cell_viability_percentage', 'cell_number_loaded',
#        'sample_collection_year', 'assay_ontology_term_id',
#        'library_preparation_batch', 'library_sequencing_run',
#        'sequenced_fragment', 'sequencing_platform', 'is_primary_data',
#        'reference_genome', 'gene_annotation_version', 'alignment_software',
#        'intron_inclusion', 'disease_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id',
#        'development_stage_ontology_term_id', 'cell_type', 'Level_3', 'Level_2',
#        'Level_1', 'group'],
#       dtype='object')

# %%
# check non-overlap of cell types with AUTHOR_CELL_TYPE in marker_genes_df

cell_type_adata = set(adata.obs['cell_type'].unique())
cell_type_marker_genes = set(marker_genes_df[AUTHOR_CELL_TYPE].unique())

cell_type_adata - cell_type_marker_genes
# Out:
# {'Basal',
#  'Interstitial macrophage',
#  'Lipofibroblast',
#  'Lymphatic EC',
#  'Regulatory T cells',
#  'Smooth muscle'}

# %%
cell_type_marker_genes - cell_type_adata
# Out:
# {'Basal cell',
#  'LECs',
#  'Lipofibroblasts',
#  'Macrophage interstitial',
#  'Regulatory T cell',
#  'SMCs'}

# %%
# create mapping dict for cell types
cell_type_mapping = {
    'Basal': 'Basal cell',
    'Interstitial macrophage': 'Macrophage interstitial',
    'Lipofibroblast': 'Lipofibroblasts',
    'Lymphatic EC': 'LECs',
    'Regulatory T cells': 'Regulatory T cell',
    'Smooth muscle': 'SMCs'
}

adata.obs[AUTHOR_CELL_TYPE] = adata.obs['cell_type'].replace(cell_type_mapping)

# %%
# map AUTHOR_CELL_TYPE and CELL_TYPE_ONTOLOGY_ID to cell type annotations
adata.obs[CELL_TYPE_ONTOLOGY_ID] = adata.obs[AUTHOR_CELL_TYPE].map(dict(zip(marker_genes_df[AUTHOR_CELL_TYPE], marker_genes_df[CELL_TYPE_ONTOLOGY_ID])))
adata.obs[MARKER_GENES] = adata.obs[AUTHOR_CELL_TYPE].map(dict(zip(marker_genes_df[AUTHOR_CELL_TYPE], marker_genes_df[MARKER_GENES])))

# %%
adata.obs[MARKER_GENES].value_counts(dropna=False)
# Out:
# RTKN2; AGER; NCKAP5; CLIC5; SCEL;  CAV2; COL4A3; LAMA3                     9254
# ITGA8;MACF1;PIEZO2; SVEP1; CDH11; NCAM2                                    5411
# SFTPC; SFTPA1; NAPSA; SFTPA2; WIF1; ACOXL; AGBL1; ABCA3; LAMP3             4953
# CA4; EDN1; NOSTRIN; FCN3; SLC6A4; BTNL9                                    3158
# MARCO; INHBA; TREM1; ABHD5; PPARG; FABP4;SLC11A1                           2046
# COL15A1; PLVAP; VWA1; KCNE3                                                1863
# COL3A1; CCDC80; ABCA10; FBLN1; FBN1; CFH; PODN                             1603
# EDNRB;  HPGD; EMCN; PDE1C; CYP3A5                                          1481
# ITGA1;ITGAE; CD2; CD6                                                      1445
# LGR6; ACTA2; MYH11;  LMOD1; MYOCD; IRAG1; TAGLN                            1253
# GUCY1A2; PDGFRB; ADARB2; LAMC3; AFF2; ADCY3; TBX5                           869
# DNAH12;CCDC78; CAPS;  ZBBX; HYDIN; CFAP157;ERICH3;CFAP47; CFAP73; CDHR4     718
# F13A1; STAB1; MRC1; RBPJ; F13A1; CD163                                      678
# BMX; GJA5; DKK2;  EFNB2                                                     670
# PROX1; MMRN1; PDPN;RELN; CCL21; TBX1; FLT4; SEMA3D; FLRT2                   628
# CD300E; FCN1;  VCAN; ADGRE2; FGR                                            608
# GZMH;KLRG1;PZP;GNLY;KLRD1; CD8A                                             590
# GNLY;KLRF1;MYBL1;APBA2; NCR1;FCGR3A; NKG7                                   572
# MZB1; POU2AF1; TENT5C; FCRL5; NUGGC                                         551
# LEF1; BCL11B; IL7R;  CD69; CD28                                             455
# MET; STEAP4; BMP6; SCGB3A2; SFTPB;                                          442
# CCL5;ITGA1; ITGAE;ZNF683;                                                   368
# SLC1A3; SDC2; CHIT1                                                         328
# GZMK;EOMES;DTHD1;CRTAM; TNIP3                                               323
# CD86; CLEC7A; MOB3B; PLAUR;CLEC10A                                          282
# MERTK; SLC9A9; RGL1;HK2; CTSL; SAT1; TNS3                                   272
# CPE; PKHD1L1; TMTC1; ADGRG6; MYRIP;SELP; ACKR1; PLA1A; IL33                 261
# TPSAB1; TPSB2; CPA3; HPGDS; MS4A2;SLC18A2; RGS13; HDC; CDK15                251
# CD19; MS4A1;BANK1; BLK; PAX5; FCRL1                                         242
# CSF3R; NAMPT; XPO6; SORL1; IL1R2; ADGRG3                                    156
# FOXP3;CTLA4;IL2RA;CD28;TIGIT;ICOS                                           155
# KRT17; TP63; CACHD1; KRT5; KRT15; AQP3;  FGFR3                              136
# BPIFB1;MUC5B;CP; PLEKHS1; BMPR1B; ERN2; MUC4; MUC16                          90
# CLEC9A; CLNK; CPVL; WDFY4; HDAC9;MCOLN2; LRRC18                              56
# CLEC4C; PLXNA4; RHEX; NIBAN3                                                 47
# CCR7; BIRC3; RASSF4; TRAF1; SLCO5A1; DAPP1                                   26
# Name: author_cell_type_markers, dtype: int64

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 42241 × 20669
#     obs: 'condition', 'genotype', 'status', 'demultiplex_sample', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'sample', 'n_counts', 'n_genes', 'doublet_scores', 'scDblFinder_class', 'soupx_groups', 'scrublet', 'Level_1_transfered_label', 'Level_1_transfer_uncert', 'Level_2_transfered_label', 'Level_2_transfer_uncert', 'Level_3_transfered_label', 'Level_3_transfer_uncert', 'Level_4_transfered_label', 'Level_4_transfer_uncert', 'Level_5_transfered_label', 'Level_5_transfer_uncert', 'condition_coarse', 'leiden_0.2', 'leiden_0.3', 'leiden_0.4', 'leiden_0.5', 'leiden_1.0', 'hlca_manual_lv1', 'hlca_manual_lv2', 'sample_ID', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'cell_type', 'Level_3', 'Level_2', 'Level_1', 'group', 'author_cell_type', 'cell_type_ontology_term_id', 'author_cell_type_markers'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'ensembl_ID', 'gene_name'
#     uns: 'Level_1_transfered_label_colors', 'Level_2_transfered_label_colors', 'Level_3_transfered_label_colors', 'Level_4_transfered_label_colors', 'Level_5_transfered_label_colors', 'batch_condition', 'comments', 'condition_colors', 'default_embedding', 'hlca_manual_lv1_colors', 'hlca_manual_lv2_colors', 'hvg', 'leiden', 'leiden_0.2_colors', 'leiden_0.3_colors', 'leiden_0.4_colors', 'leiden_0.5_colors', 'leiden_1.0_colors', 'log1p', 'neighbors', 'pca', 'sample_colors', 'scrublet_colors', 'study_PI', 'title', 'umap', 'unpublished'
#     obsm: 'X_hlca', 'X_hlca_umap', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts', 'soupX_counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# # Add author cell type markers to UNS

# %%
adata.uns[MARKER_GENES] = marker_genes_df

# %% [markdown]
# # Check author cell type annotations and Cell Ontology IDs

# %%
adata.obs.columns
# Out:
# Index(['condition', 'genotype', 'status', 'demultiplex_sample',
#        'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts',
#        'log1p_total_counts', 'pct_counts_in_top_50_genes',
#        'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes',
#        'pct_counts_in_top_500_genes', 'total_counts_mito',
#        'log1p_total_counts_mito', 'pct_counts_mito', 'sample', 'n_counts',
#        'n_genes', 'doublet_scores', 'scDblFinder_class', 'soupx_groups',
#        'scrublet', 'Level_1_transfered_label', 'Level_1_transfer_uncert',
#        'Level_2_transfered_label', 'Level_2_transfer_uncert',
#        'Level_3_transfered_label', 'Level_3_transfer_uncert',
#        'Level_4_transfered_label', 'Level_4_transfer_uncert',
#        'Level_5_transfered_label', 'Level_5_transfer_uncert',
#        'condition_coarse', 'leiden_0.2', 'leiden_0.3', 'leiden_0.4',
#        'leiden_0.5', 'leiden_1.0', 'hlca_manual_lv1', 'hlca_manual_lv2',
#        'sample_ID', 'donor_id', 'protocol_URL', 'institute',
#        'sample_collection_site', 'sample_collection_relative_time_point',
#        'library_ID', 'library_ID_repository', 'author_batch_notes',
#        'organism_ontology_term_id', 'manner_of_death', 'sample_source',
#        'sex_ontology_term_id', 'sample_collection_method', 'tissue_type',
#        'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text',
#        'sample_preservation_method', 'suspension_type', 'cell_enrichment',
#        'cell_viability_percentage', 'cell_number_loaded',
#        'sample_collection_year', 'assay_ontology_term_id',
#        'library_preparation_batch', 'library_sequencing_run',
#        'sequenced_fragment', 'sequencing_platform', 'is_primary_data',
#        'reference_genome', 'gene_annotation_version', 'alignment_software',
#        'intron_inclusion', 'disease_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id',
#        'development_stage_ontology_term_id', 'cell_type', 'Level_3', 'Level_2',
#        'Level_1', 'group', 'author_cell_type', 'cell_type_ontology_term_id',
#        'author_cell_type_markers'],
#       dtype='object')

# %%
adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False)
# Out:
# AT2                        9254
# Lipofibroblasts            5411
# AT1                        4953
# EC general capillary       3158
# Alveolar macrophages       2046
# EC venous systemic         1863
# Adventitial fibroblasts    1603
# EC aerocyte capillary      1481
# CD4 T cells TRM            1445
# SMCs                       1253
# Pericytes                   869
# Multiciliated               718
# Macrophage interstitial     678
# EC arterial                 670
# LECs                        628
# Monocytes                   608
# CD8_EM/EMRA                 590
# NK cells                    572
# Plasma cells                551
# CD4 T cells naive           455
# Club                        442
# CD8 T cells TRM             368
# Macrophage CHIT1+           328
# CD8_TRM/EM                  323
# DC2                         282
# Macrophage MERTK+           272
# EC venous pulmonary         261
# Mast cells                  251
# B cells                     242
# Monocytes CSF3R+/CD16-      156
# Regulatory T cell           155
# Basal cell                  136
# Goblet                       90
# DC1                          56
# Plasmacytoid DCs             47
# DC activated                 26
# Name: author_cell_type, dtype: int64

# %%
adata.obs['Level_1'].value_counts(dropna=False)
# Out:
# Epithelial     15593
# Immune          9451
# Stroma          9136
# Endothelial     8061
# Name: Level_1, dtype: int64

# %%
adata.obs['Level_2'].value_counts(dropna=False)
# Out:
# Alveolar epithelium    14207
# Fibroblast lineage      7883
# Blood vessels           7433
# Myeloid                 4750
# Lymphoid                4701
# Airway epithelium       1386
# Smooth muscle           1253
# Lymphatic EC             628
# Name: Level_2, dtype: int64

# %%
adata.obs['Level_3'].value_counts(dropna=False)
# Out:
# AT2                        9254
# Fibroblasts                7883
# AT1                        4953
# EC capillary               4639
# T cell lineage             3336
# Macrophages                3324
# EC venous                  2124
# Smooth muscle              1253
# B cell lineage              793
# Monocytes                   764
# Multiciliated               718
# EC arterial                 670
# Lymphatic EC                628
# Innate lymphoid cell NK     572
# Secretory                   532
# Dendritic cells             411
# Mast cells                  251
# Basal                       136
# Name: Level_3, dtype: int64

# %%
adata.obs[AUTHOR_CELL_TYPE_L0] = adata.obs['Level_1']
adata.obs[AUTHOR_CELL_TYPE_L1] = adata.obs['Level_2']
adata.obs[AUTHOR_CELL_TYPE_L2] = adata.obs['Level_3']

# %%
adata.obs[CELL_TYPE_ONTOLOGY_ID].value_counts(dropna=False)
# Out:
# CL:0002063      9254
# CL:0002553      7014
# CL:0002062      4953
# CL:0002144      3158
# CL:0000583      2046
# CL:0002543      1863
# CL:0002145      1481
# CL:4033038      1445
# CL:0000192      1253
# CL:0009089       869
# CL:4030034       718
# CL:4033043       678
# CL:1000413       670
# CL:0009086       628
# CL:0000860       608
# CL:0000253       600
# CL:0000913       590
# CL:0000623       572
# CL:0000786       551
# CL:0000895       455
# CL:0000158       442
# CL:4033039       368
# CL:0000909       323
# CL:0001056       308
# CL:4033008       261
# CL:0000097       251
# CL:0000236       242
# CL:0000875       156
# CL:0000815       155
# CL:0000646       136
# CL:0000160        90
# CL:0000990        56
# CL:0001058        47
# Name: cell_type_ontology_term_id, dtype: int64

# %% [markdown]
# # Check whether ENSEMBL IDs in var

# %%
adata.var
# Out:
#                  highly_variable     means  dispersions  dispersions_norm  \
# index
# ATAD3B                     False  0.036800     0.242076         -0.357507
# PRDM16                     False  0.168010     0.664629          0.025617
# PEX10                      False  0.010376     0.226664         -0.387448
# SKI                        False  0.261257     0.610046         -0.378022
# PEX14                      False  0.200704     0.592536         -0.165523
# ...                          ...       ...          ...               ...
# ENSG00000275063            False  0.000176     0.632660          0.991525
# ENSG00000277856            False  0.000064    -0.458416         -2.481308
# ENSG00000271254            False  0.009453     0.267841         -0.261455
# ENSG00000268674            False  0.000401     0.486345          0.468138
# ENSG00000277475            False  0.000123     0.235231         -0.307846
#
#                  highly_variable_nbatches  highly_variable_intersection  \
# index
# ATAD3B                                  0                         False
# PRDM16                                  0                         False
# PEX10                                   0                         False
# SKI                                     0                         False
# PEX14                                   0                         False
# ...                                   ...                           ...
# ENSG00000275063                         0                         False
# ENSG00000277856                         0                         False
# ENSG00000271254                         0                         False
# ENSG00000268674                         0                         False
# ENSG00000277475                         0                         False
#
#                       ensembl_id      gene_symbol
# index
# ATAD3B           ENSG00000160072           ATAD3B
# PRDM16           ENSG00000142611           PRDM16
# PEX10            ENSG00000157911            PEX10
# SKI              ENSG00000157933              SKI
# PEX14            ENSG00000142655            PEX14
# ...                          ...              ...
# ENSG00000275063  ENSG00000275063  ENSG00000275063
# ENSG00000277856  ENSG00000277856  ENSG00000277856
# ENSG00000271254  ENSG00000271254  ENSG00000271254
# ENSG00000268674  ENSG00000268674  ENSG00000268674
# ENSG00000277475  ENSG00000277475  ENSG00000277475
#
# [20669 rows x 8 columns]

# %%
adata.var.index.name = 'index'
adata.var.rename(columns={'gene_name': 'gene_symbol', 'ensembl_ID': 'ensembl_id'}, inplace=True)
adata.var
# Out:
#                  highly_variable     means  dispersions  dispersions_norm  \
# index
# ATAD3B                     False  0.036800     0.242076         -0.357507
# PRDM16                     False  0.168010     0.664629          0.025617
# PEX10                      False  0.010376     0.226664         -0.387448
# SKI                        False  0.261257     0.610046         -0.378022
# PEX14                      False  0.200704     0.592536         -0.165523
# ...                          ...       ...          ...               ...
# ENSG00000275063            False  0.000176     0.632660          0.991525
# ENSG00000277856            False  0.000064    -0.458416         -2.481308
# ENSG00000271254            False  0.009453     0.267841         -0.261455
# ENSG00000268674            False  0.000401     0.486345          0.468138
# ENSG00000277475            False  0.000123     0.235231         -0.307846
#
#                  highly_variable_nbatches  highly_variable_intersection  \
# index
# ATAD3B                                  0                         False
# PRDM16                                  0                         False
# PEX10                                   0                         False
# SKI                                     0                         False
# PEX14                                   0                         False
# ...                                   ...                           ...
# ENSG00000275063                         0                         False
# ENSG00000277856                         0                         False
# ENSG00000271254                         0                         False
# ENSG00000268674                         0                         False
# ENSG00000277475                         0                         False
#
#                       ensembl_id      gene_symbol
# index
# ATAD3B           ENSG00000160072           ATAD3B
# PRDM16           ENSG00000142611           PRDM16
# PEX10            ENSG00000157911            PEX10
# SKI              ENSG00000157933              SKI
# PEX14            ENSG00000142655            PEX14
# ...                          ...              ...
# ENSG00000275063  ENSG00000275063  ENSG00000275063
# ENSG00000277856  ENSG00000277856  ENSG00000277856
# ENSG00000271254  ENSG00000271254  ENSG00000271254
# ENSG00000268674  ENSG00000268674  ENSG00000268674
# ENSG00000277475  ENSG00000277475  ENSG00000277475
#
# [20669 rows x 8 columns]

# %%
adata.var['gene_symbol'] = adata.var['gene_symbol'].astype(str)
adata.var['ensembl_id'] = adata.var['ensembl_id'].astype(str)
adata.var.index = adata.var.index.astype(str)

# %%
adata.var.dtypes
# Out:
# highly_variable                    bool
# means                           float64
# dispersions                     float64
# dispersions_norm                float32
# highly_variable_nbatches          int64
# highly_variable_intersection       bool
# ensembl_id                       object
# gene_symbol                      object
# dtype: object

# %% [markdown]
# # Check raw data

# %%
adata.layers['soupX_counts'].toarray().max()
# Out:
# 3026.0

# %%
adata.X = adata.layers['soupX_counts']

# %%
adata.X = adata.X.astype(np.int64)

# %%
adata.var.dtypes
# Out:
# highly_variable                    bool
# means                           float64
# dispersions                     float64
# dispersions_norm                float32
# highly_variable_nbatches          int64
# highly_variable_intersection       bool
# ensembl_id                       object
# gene_symbol                      object
# dtype: object

# %%
adata.raw = adata

# %%
adata.raw.var.dtypes
# Out:
# highly_variable                    bool
# means                           float64
# dispersions                     float64
# dispersions_norm                float32
# highly_variable_nbatches          int64
# highly_variable_intersection       bool
# ensembl_id                       object
# gene_symbol                      object
# dtype: object

# %%
adata.X
# Out:
# <42241x20669 sparse matrix of type '<class 'numpy.int64'>'
# 	with 69689379 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <42241x20669 sparse matrix of type '<class 'numpy.int64'>'
# 	with 69689379 stored elements in Compressed Sparse Row format>

# %%
adata.X.toarray().max()
# Out:
# 3026

# %%
adata.raw.X.toarray().max()
# Out:
# 3026

# %% [markdown]
# ## Validation result
#
# ### UNS Validation
# - OK: Tier 1 UNS Google Sheet
# - OK: Tier 1 UNS AnnData Object  same as Google Sheet
#
# ### OBS Validation
# - OK: Tier 1 OBS Google Sheet
# - OK: Tier 1 OBS AnnData Object same as Google Sheet

# %% [markdown]
# # Data Submission Status
#
# - CHECK: Raw counts in X and in raw
# - CHECK: Tier 1 Metadata in OBS
# - CHECK: Cell Ontology IDs in OBS
# - CHECK: Author cell type in OBS
# - CHECK: Marker genes in UNS
# - CHECK: ENSEMBL IDs and gene symbols in var
#
# # Revisions:
#
# DONE

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
