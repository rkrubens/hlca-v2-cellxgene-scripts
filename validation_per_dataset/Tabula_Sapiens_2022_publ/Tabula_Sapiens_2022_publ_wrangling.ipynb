# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import anndata2ri
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"

# %%
DATASET_ID = "Tabula_Sapiens_2022_publ"
H5AD_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/{DATASET_ID}.h5ad"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
# Name constants
AUTHOR_CELL_TYPE_L0 = 'author_cell_type_level_0'
AUTHOR_CELL_TYPE_L1 = 'author_cell_type_level_1'

CELL_TYPE_ONTOLOGY_ID_L0 = 'cell_type_ontology_term_id_level_0'
CELL_TYPE_ONTOLOGY_ID_L1 = 'cell_type_ontology_term_id_level_1'

CELL_TYPE_ONTOLOGY_LABEL_L0 = 'cell_type_ontology_term_label_level_0'
CELL_TYPE_ONTOLOGY_LABEL_L1 = 'cell_type_ontology_term_label_level_1'

AUTHOR_CELL_TYPE_DESCRIPTION_L0 = 'author_cell_type_description_level_0'
AUTHOR_CELL_TYPE_DESCRIPTION_L1 = 'author_cell_type_description_level_1'

MARKER_GENES_L0 = 'author_cell_type_markers_level_0'
MARKER_GENES_L1 = 'author_cell_type_markers_level_1'

# Finest grained annotation will be generic dataset cell type
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'
CELL_TYPE_ONTOLOGY_LABEL = 'cell_type_ontology_term_label'
MARKER_GENES = 'author_cell_type_markers'
AUTHOR_CELL_TYPE_DESCRIPTION = 'author_cell_type_description'

# %% [markdown]
# # Load data

# %%
adata = sc.read_h5ad(H5AD_PATH)
obs = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "obs")
uns = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "uns")

# %% [markdown]
# # Validate obs and uns from Tier 1 Metadata Template

# %%
val_workflow = ValidationWorkflow(
    input = uns,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                  title       study_PI  \
# 0  Tabula Sapiens 2022  Stephen Quake
#
#                                      batch_condition default_embedding  \
# 0  donor,method (batch correction performed for l...            X_scvi
#
#   unpublished comments
# 0   published

# %%
val_workflow = ValidationWorkflow(
    input = obs,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation workflow successful. Returning OBS dataframe.
#   sample_ID donor_id                                       protocol_URL  \
# 0   Donor 1     TSP1  https://www.science.org/doi/10.1126/science.ab...
# 1   Donor 2     TSP2  https://www.science.org/doi/10.1126/science.ab...
# 2  Donor 14    TSP14  https://www.science.org/doi/10.1126/science.ab...
#
#                                institute sample_collection_site  \
# 0  Stanford University/UCSF/CZ Biohub SF                    N/A
# 1  Stanford University/UCSF/CZ Biohub SF                    N/A
# 2  Stanford University/UCSF/CZ Biohub SF                    N/A
#
#   sample_collection_relative_time_point  \
# 0                                   N/A
# 1                                   N/A
# 2                                   N/A
#
#                                           library_ID  \
# 0  10X_library column in obs or cDNA plate for sm...
# 1  10X_library column in obs or cDNA plate for sm...
# 2  10X_library column in obs or cDNA plate for sm...
#
#          library_ID_repository author_batch_notes organism_ontology_term_id  \
# 0  N/A (data available in AWS)                N/A            NCBITaxon:9606
# 1  N/A (data available in AWS)                N/A            NCBITaxon:9606
# 2  N/A (data available in AWS)                N/A            NCBITaxon:9606
#
#    ...  sequenced_fragment sequencing_platform is_primary_data  \
# 0  ...         3 prime tag         EFO:0008637            true
# 1  ...         3 prime tag         EFO:0008637            true
# 2  ...         3 prime tag         EFO:0008637            true
#
#   reference_genome gene_annotation_version alignment_software  \
# 0           GRCh38                     N/A  cell ranger 5.0.1
# 1           GRCh38                     N/A  cell ranger 5.0.1
# 2           GRCh38                     N/A  cell ranger 5.0.1
#
#   intron_inclusion disease_ontology_term_id  \
# 0               no             PATO:0000461
# 1               no             PATO:0000461
# 2               no             PATO:0000461
#
#   self_reported_ethnicity_ontology_term_id development_stage_ontology_term_id
# 0                           HANCESTRO:0005                     HsapDv:0000240
# 1                           HANCESTRO:0016                     HsapDv:0000241
# 2                           HANCESTRO:0005                     HsapDv:0000240
#
# [3 rows x 37 columns]

# %%
# Subset to lung only
adata = adata[adata.obs['tissue'] == 'lung']
adata
# Out:
# View of AnnData object with n_obs × n_vars = 35682 × 58482
#     obs: 'tissue_in_publication', 'assay_ontology_term_id', 'donor_id', 'anatomical_information', 'n_counts_UMIs', 'n_genes', 'cell_ontology_class', 'free_annotation', 'manually_annotated', 'compartment', 'sex_ontology_term_id', 'disease_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'suspension_type', 'cell_type_ontology_term_id', 'tissue_ontology_term_id', 'development_stage_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'feature_type', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length'
#     uns: '_scvi', '_training_mode', 'citation', 'dendrogram_cell_type_tissue', 'dendrogram_computational_compartment_assignment', 'dendrogram_consensus_prediction', 'dendrogram_tissue_cell_type', 'donor_id_colors', 'hvg', 'neighbors', 'schema_reference', 'schema_version', 'tissue_in_publication_colors', 'title', 'umap'
#     obsm: 'X_pca', 'X_scvi', 'X_scvi_umap', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
# Subset to only 10x (exclude Smart-seq2)
adata = adata[adata.obs['assay'] != 'Smart-seq2']

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 34092 × 58482
#     obs: 'tissue_in_publication', 'assay_ontology_term_id', 'donor_id', 'anatomical_information', 'n_counts_UMIs', 'n_genes', 'cell_ontology_class', 'free_annotation', 'manually_annotated', 'compartment', 'sex_ontology_term_id', 'disease_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'suspension_type', 'cell_type_ontology_term_id', 'tissue_ontology_term_id', 'development_stage_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'feature_type', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length'
#     uns: '_scvi', '_training_mode', 'citation', 'dendrogram_cell_type_tissue', 'dendrogram_computational_compartment_assignment', 'dendrogram_consensus_prediction', 'dendrogram_tissue_cell_type', 'donor_id_colors', 'hvg', 'neighbors', 'schema_reference', 'schema_version', 'tissue_in_publication_colors', 'title', 'umap'
#     obsm: 'X_pca', 'X_scvi', 'X_scvi_umap', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# # Validate obs and uns from adata

# %%
merger = AnnDataMerger(
    adata = adata,
    uns_df = uns
)

adata = merger.add_uns_metadata()

adata
# Out:
# Warning: Key title already exists in AnnData UNS. Overwriting with new values.
# /home/icb/raphael.kfuri-rubens/miniconda3/envs/hlcav2-env/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# AnnData object with n_obs × n_vars = 34092 × 58482
#     obs: 'tissue_in_publication', 'assay_ontology_term_id', 'donor_id', 'anatomical_information', 'n_counts_UMIs', 'n_genes', 'cell_ontology_class', 'free_annotation', 'manually_annotated', 'compartment', 'sex_ontology_term_id', 'disease_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'suspension_type', 'cell_type_ontology_term_id', 'tissue_ontology_term_id', 'development_stage_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'feature_type', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length'
#     uns: '_scvi', '_training_mode', 'citation', 'dendrogram_cell_type_tissue', 'dendrogram_computational_compartment_assignment', 'dendrogram_consensus_prediction', 'dendrogram_tissue_cell_type', 'donor_id_colors', 'hvg', 'neighbors', 'schema_reference', 'schema_version', 'tissue_in_publication_colors', 'title', 'umap', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments'
#     obsm: 'X_pca', 'X_scvi', 'X_scvi_umap', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
# Merge obs and uns
merger = AnnDataMerger(
    adata = adata,
    obs_df = obs
)

cols_to_skip = [
    'organism_ontology_term_id',
    'sex_ontology_term_id',
    'tissue_type',
    'tissue_ontology_term_id',
    'suspension_type',
    'assay_ontology_term_id',
    'is_primary_data',
    'disease_ontology_term_id',
    'self_reported_ethnicity_ontology_term_id'
]

adata_merged = merger.add_obs_metadata(
    adata_col = 'donor_id',
    df_col = 'donor_id',
    skip = cols_to_skip
)

adata_merged.obs
# Out:
# Warning: Column development_stage_ontology_term_id already exists in AnnData OBS. Overwriting with new values.
#                                                    tissue_in_publication  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                          Lung
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                          Lung
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                          Lung
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                          Lung
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                          Lung
# ...                                                                  ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...                  Lung
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...                  Lung
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...                  Lung
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...                  Lung
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...                  Lung
#
#                                                    assay_ontology_term_id  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                    EFO:0009922
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                    EFO:0009922
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                    EFO:0009922
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                    EFO:0009922
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                    EFO:0009922
# ...                                                                   ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...            EFO:0009922
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...            EFO:0009922
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...            EFO:0009922
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...            EFO:0009922
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...            EFO:0009922
#
#                                                    donor_id  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1            TSP14
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1            TSP14
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1            TSP14
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1            TSP14
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1            TSP14
# ...                                                     ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...     TSP2
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...     TSP2
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...     TSP2
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...     TSP2
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...     TSP2
#
#                                                    anatomical_information  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                         distal
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                         distal
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                         distal
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                         distal
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                         distal
# ...                                                                   ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...       proxmedialdistal
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...       proxmedialdistal
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...       proxmedialdistal
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...       proxmedialdistal
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...       proxmedialdistal
#
#                                                     n_counts_UMIs  n_genes  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                44221.0     6970
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                28563.0     5638
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                 4099.0     1929
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                24619.0     4021
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                28129.0     5278
# ...                                                           ...      ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...         2892.0     1349
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...         8952.0     3353
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...         3234.0     1566
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...         2824.0     1380
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...         7101.0     2679
#
#                                                                 cell_ontology_class  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                       type ii pneumocyte
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                       type ii pneumocyte
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                       type ii pneumocyte
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                       type ii pneumocyte
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                       type ii pneumocyte
# ...                                                                             ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...  cd4-positive, alpha-beta t cell
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...                       basal cell
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...  cd8-positive, alpha-beta t cell
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...           non-classical monocyte
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...          respiratory goblet cell
#
#                                                                     free_annotation  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                       type ii pneumocyte
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                       type ii pneumocyte
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                       type ii pneumocyte
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                       type ii pneumocyte
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                       type ii pneumocyte
# ...                                                                             ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...  cd4-positive, alpha-beta t cell
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...                       basal cell
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...  cd8-positive, alpha-beta t cell
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...           non-classical monocyte
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...          respiratory goblet cell
#
#                                                     manually_annotated  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                        True
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                        True
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                        True
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                        True
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                        True
# ...                                                                ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...                True
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...                True
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...                True
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...                True
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...                True
#
#                                                    compartment  ...  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1          epithelial  ...
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1          epithelial  ...
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1          epithelial  ...
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1          epithelial  ...
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1          epithelial  ...
# ...                                                        ...  ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...      immune  ...
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...  epithelial  ...
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...      immune  ...
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...      immune  ...
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...  epithelial  ...
#
#                                                    cell_number_loaded  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                      10000
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                      10000
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                      10000
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                      10000
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                      10000
# ...                                                               ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...              10000
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...              10000
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...              10000
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...              10000
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...              10000
#
#                                                    sample_collection_year  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                           2020
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                           2020
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                           2020
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                           2020
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                           2020
# ...                                                                   ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...                   2019
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...                   2019
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...                   2019
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...                   2019
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...                   2019
#
#                                                     library_preparation_batch  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                                N/A
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                                N/A
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                                N/A
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                                N/A
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                                N/A
# ...                                                                       ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...                        N/A
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...                        N/A
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...                        N/A
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...                        N/A
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...                        N/A
#
#                                                    library_sequencing_run  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                            N/A
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                            N/A
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                            N/A
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                            N/A
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                            N/A
# ...                                                                   ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...                    N/A
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...                    N/A
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...                    N/A
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...                    N/A
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...                    N/A
#
#                                                    sequenced_fragment  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                3 prime tag
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                3 prime tag
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                3 prime tag
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                3 prime tag
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                3 prime tag
# ...                                                               ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...        3 prime tag
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...        3 prime tag
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...        3 prime tag
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...        3 prime tag
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...        3 prime tag
#
#                                                    sequencing_platform  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                 EFO:0008637
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                 EFO:0008637
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                 EFO:0008637
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                 EFO:0008637
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                 EFO:0008637
# ...                                                                ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...         EFO:0008637
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...         EFO:0008637
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...         EFO:0008637
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...         EFO:0008637
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...         EFO:0008637
#
#                                                    reference_genome  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                   GRCh38
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                   GRCh38
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                   GRCh38
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                   GRCh38
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                   GRCh38
# ...                                                             ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...           GRCh38
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...           GRCh38
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...           GRCh38
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...           GRCh38
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...           GRCh38
#
#                                                    gene_annotation_version  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                             N/A
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                             N/A
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                             N/A
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                             N/A
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                             N/A
# ...                                                                    ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...                     N/A
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...                     N/A
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...                     N/A
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...                     N/A
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...                     N/A
#
#                                                    alignment_software  \
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1          cell ranger 5.0.1
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1          cell ranger 5.0.1
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1          cell ranger 5.0.1
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1          cell ranger 5.0.1
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1          cell ranger 5.0.1
# ...                                                               ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...  cell ranger 5.0.1
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...  cell ranger 5.0.1
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...  cell ranger 5.0.1
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...  cell ranger 5.0.1
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...  cell ranger 5.0.1
#
#                                                    intron_inclusion
# AAACCCAAGAACTCCT_TSP14_Lung_Distal_10X_1_1                       no
# AAACGAAAGGAGCTGT_TSP14_Lung_Distal_10X_1_1                       no
# AAACGAACACGCGTGT_TSP14_Lung_Distal_10X_1_1                       no
# AAACGAACATGCCGCA_TSP14_Lung_Distal_10X_1_1                       no
# AAAGAACGTTAAGGGC_TSP14_Lung_Distal_10X_1_1                       no
# ...                                                             ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X...               no
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X...               no
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X...               no
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X...               no
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X...               no
#
# [34092 rows x 55 columns]

# %% [markdown]
# # Add author cell type markers to UNS

# %%
sample_col = [x for x in adata.obs.columns.tolist() if 'cell' in x]
sample_col
# Out:
# ['cell_ontology_class',
#  'cell_type_ontology_term_id',
#  'cell_type',
#  'cell_enrichment',
#  'cell_viability_percentage',
#  'cell_number_loaded']

# %%
# No cell type markers available

# %% [markdown]
# # Check author cell type annotations and Cell Ontology IDs

# %%
adata.obs[AUTHOR_CELL_TYPE] = adata.obs['cell_type']

# %%
adata.obs[CELL_TYPE_ONTOLOGY_ID].value_counts()
# Out:
# CL:0000235    12034
# CL:0002063     8827
# CL:0000646     2055
# CL:0000860     1390
# CL:0002144     1374
# CL:0000158     1023
# CL:0000875      999
# CL:0002370      729
# CL:0000767      677
# CL:1000271      567
# CL:0000624      524
# CL:0000625      523
# CL:2000016      480
# CL:0002543      478
# CL:0000451      278
# CL:0002393      252
# CL:0000057      244
# CL:0002062      204
# CL:0000669      195
# CL:1000413      161
# CL:0000775      138
# CL:0001044      132
# CL:0000814      126
# CL:0000786      125
# CL:0000236       82
# CL:0001050       80
# CL:0002503       74
# CL:0000359       71
# CL:0002598       67
# CL:0000071       47
# CL:0002138       36
# CL:0000192       25
# CL:0017000       19
# CL:0000784       17
# CL:0000077       16
# CL:1000331       13
# CL:0000186       10
# Name: cell_type_ontology_term_id, dtype: int64

# %% [markdown]
# # Check whether ENSEMBL IDs in var

# %%
adata.var
# Out:
#                     feature_type  highly_variable         means  dispersions  \
# ENSG00000223972  Gene Expression            False  6.398244e-05     0.835044
# ENSG00000227232  Gene Expression            False  2.274395e-03     2.442280
# ENSG00000278267  Gene Expression            False  6.175251e-05     1.295335
# ENSG00000243485  Gene Expression            False  1.372886e-04     2.656352
# ENSG00000284332  Gene Expression            False  1.000000e-12          NaN
# ...                          ...              ...           ...          ...
# ENSG00000198695  Gene Expression            False  9.634841e-01     2.466404
# ENSG00000210194  Gene Expression            False  1.600667e-01     1.603787
# ENSG00000198727  Gene Expression            False  4.367693e+00     4.765751
# ENSG00000210195  Gene Expression            False  6.573967e-02     0.624316
# ENSG00000210196  Gene Expression             True  4.385102e-01     2.705558
#
#                  dispersions_norm      mean       std  feature_is_filtered  \
# ENSG00000223972         -0.573947  0.000039  0.005574                False
# ENSG00000227232          0.533203  0.001080  0.031731                False
# ENSG00000278267         -0.256874  0.000033  0.005634                False
# ENSG00000243485          0.680668  0.000048  0.008041                False
# ENSG00000284332          0.000000  0.000000  1.000000                False
# ...                           ...       ...       ...                  ...
# ENSG00000198695          0.154140  0.590065  0.741395                False
# ENSG00000210194         -0.044396  0.083929  0.301820                False
# ENSG00000198727         -0.499747  3.874830  1.104192                False
# ENSG00000210195         -0.719108  0.040580  0.186848                False
# ENSG00000210196          1.115482  0.204806  0.501265                False
#
#                 feature_name feature_reference feature_biotype feature_length
# ENSG00000223972      DDX11L1    NCBITaxon:9606            gene            632
# ENSG00000227232       WASH7P    NCBITaxon:9606            gene           1351
# ENSG00000278267    MIR6859-1    NCBITaxon:9606            gene             68
# ENSG00000243485  MIR1302-2HG    NCBITaxon:9606            gene           1021
# ENSG00000284332    MIR1302-2    NCBITaxon:9606            gene            138
# ...                      ...               ...             ...            ...
# ENSG00000198695       MT-ND6    NCBITaxon:9606            gene            525
# ENSG00000210194        MT-TE    NCBITaxon:9606            gene             69
# ENSG00000198727       MT-CYB    NCBITaxon:9606            gene           1141
# ENSG00000210195        MT-TT    NCBITaxon:9606            gene             66
# ENSG00000210196        MT-TP    NCBITaxon:9606            gene             68
#
# [58482 rows x 12 columns]

# %%
adata.var['ensembl_id'] = adata.var.index
adata.var.index = adata.var['feature_name']
adata.var.index.name = 'index'
adata.var.rename(columns = {'feature_name': 'gene_symbol'}, inplace = True)

adata.var
# Out:
#                 feature_type  highly_variable         means  dispersions  \
# index
# DDX11L1      Gene Expression            False  6.398244e-05     0.835044
# WASH7P       Gene Expression            False  2.274395e-03     2.442280
# MIR6859-1    Gene Expression            False  6.175251e-05     1.295335
# MIR1302-2HG  Gene Expression            False  1.372886e-04     2.656352
# MIR1302-2    Gene Expression            False  1.000000e-12          NaN
# ...                      ...              ...           ...          ...
# MT-ND6       Gene Expression            False  9.634841e-01     2.466404
# MT-TE        Gene Expression            False  1.600667e-01     1.603787
# MT-CYB       Gene Expression            False  4.367693e+00     4.765751
# MT-TT        Gene Expression            False  6.573967e-02     0.624316
# MT-TP        Gene Expression             True  4.385102e-01     2.705558
#
#              dispersions_norm      mean       std  feature_is_filtered  \
# index
# DDX11L1             -0.573947  0.000039  0.005574                False
# WASH7P               0.533203  0.001080  0.031731                False
# MIR6859-1           -0.256874  0.000033  0.005634                False
# MIR1302-2HG          0.680668  0.000048  0.008041                False
# MIR1302-2            0.000000  0.000000  1.000000                False
# ...                       ...       ...       ...                  ...
# MT-ND6               0.154140  0.590065  0.741395                False
# MT-TE               -0.044396  0.083929  0.301820                False
# MT-CYB              -0.499747  3.874830  1.104192                False
# MT-TT               -0.719108  0.040580  0.186848                False
# MT-TP                1.115482  0.204806  0.501265                False
#
#              gene_symbol feature_reference feature_biotype feature_length  \
# index
# DDX11L1          DDX11L1    NCBITaxon:9606            gene            632
# WASH7P            WASH7P    NCBITaxon:9606            gene           1351
# MIR6859-1      MIR6859-1    NCBITaxon:9606            gene             68
# MIR1302-2HG  MIR1302-2HG    NCBITaxon:9606            gene           1021
# MIR1302-2      MIR1302-2    NCBITaxon:9606            gene            138
# ...                  ...               ...             ...            ...
# MT-ND6            MT-ND6    NCBITaxon:9606            gene            525
# MT-TE              MT-TE    NCBITaxon:9606            gene             69
# MT-CYB            MT-CYB    NCBITaxon:9606            gene           1141
# MT-TT              MT-TT    NCBITaxon:9606            gene             66
# MT-TP              MT-TP    NCBITaxon:9606            gene             68
#
#                   ensembl_id
# index
# DDX11L1      ENSG00000223972
# WASH7P       ENSG00000227232
# MIR6859-1    ENSG00000278267
# MIR1302-2HG  ENSG00000243485
# MIR1302-2    ENSG00000284332
# ...                      ...
# MT-ND6       ENSG00000198695
# MT-TE        ENSG00000210194
# MT-CYB       ENSG00000198727
# MT-TT        ENSG00000210195
# MT-TP        ENSG00000210196
#
# [58482 rows x 13 columns]

# %% [markdown]
# # Check raw data

# %%
adata.raw.X.toarray().max()
# Out:
# 38165.0

# %%
adata.X = adata.raw.X

# %%
adata.X.toarray().max()
# Out:
# 38165.0

# %%
adata.X = adata.X.astype(np.int64)

# %%
adata.raw = adata

# %%
adata.X.toarray().max()
# Out:
# 38165

# %%
adata.raw.X.toarray().max()
# Out:
# 38165

# %% [markdown]
# ## Validation result
#
# ### UNS Validation
# - OK: Tier 1 UNS Google Sheet
# - OK: Tier 1 UNS AnnData Object
#
# ### OBS Validation
# - OK: Tier 1 OBS Google Sheet
# - OK: Tier 1 OBS AnnData Object

# %% [markdown]
# # Data Submission Status
#
# - CHECK: Raw data in X and in raw
# - CHECK: Tier 1 Metadata in OBS
# - CHECK: Cell Ontology IDs in OBS
# - CHECK: Author cell type in OBS
# - MISSING: Marker genes in UNS
# - CHECK: ENSEMBL IDs and gene symbols in var
#
# Marker genes not submitted. Not retrievable from publication upon first search. Check again.

# %%
adata.obs['cell_viability_percentage'] = pd.to_numeric(adata.obs['cell_viability_percentage'], errors='coerce')
adata.obs['cell_number_loaded'] = pd.to_numeric(adata.obs['cell_number_loaded'], errors='coerce')
adata.obs['sample_collection_year'] = pd.to_numeric(adata.obs['sample_collection_year'], errors='coerce')

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
