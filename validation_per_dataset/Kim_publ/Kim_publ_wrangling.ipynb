# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import anndata2ri
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"

# %%
DATASET_ID = "Kim_publ"
H5AD_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/{DATASET_ID}.h5ad"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
# Name constants
AUTHOR_CELL_TYPE_L0 = 'author_cell_type_level_0'
AUTHOR_CELL_TYPE_L1 = 'author_cell_type_level_1'
AUTHOR_CELL_TYPE_L2 = 'author_cell_type_level_2'

# Finest grained annotation will be generic dataset cell type
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'
CELL_TYPE_ONTOLOGY_LABEL = 'cell_type_ontology_term_label'
MARKER_GENES = 'author_cell_type_markers_rna'
MARKER_PROTEINS = 'author_cell_type_markers_protein'
MARKERS = 'author_cell_type_markers'
AUTHOR_CELL_TYPE_DESCRIPTION = 'author_cell_type_description'

# %% [markdown]
# # Load data

# %%
adata = sc.read_h5ad(H5AD_PATH)
obs = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "obs")
uns = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "uns")

# %% [markdown]
# # Validate obs and uns from Tier 1 Metadata Template

# %%
val_workflow = ValidationWorkflow(
    input = uns,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                                       title            study_PI  \
# 0  Cells of COPD lung patients and controls  Edy Kim, Jeong Yun
#
#   batch_condition default_embedding                               unpublished  \
# 0         patient          wnn.UMAP  Dataset published, consented for release
#
#   comments
# 0

# %%
val_workflow = ValidationWorkflow(
    input = obs,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation workflow successful. Returning OBS dataframe.
#                    donor_id sample_ID  \
# 0                V148_Donor      V148
# 1             V15_GOLD_I_II       V15
# 2       V159_End_stage_COPD      V159
# 3                V161_Donor      V161
# 4       V162_End_stage_COPD      V162
# 5                V169_Donor      V169
# 6               V17_Control       V17
# 7             V19_Emphysema       V19
# 8              V2_Emphysema        V2
# 9               V22_Control       V22
# 10               V226_Donor      V226
# 11              V23_Control       V23
# 12              V25_Control       V25
# 13            V26_Emphysema       V26
# 14            V28_GOLD_I_II       V28
# 15            V29_GOLD_I_II       V29
# 16              V30_Control       V30
# 17            V31_Emphysema       V31
# 18  V33_Smoking_related_ILD       V33
# 19            V35_GOLD_I_II       V35
# 20              V37_Control       V37
# 21            V38_GOLD_I_II       V38
# 22            V40_Emphysema       V40
# 23         V8_Bronchiolitis        V8
#
#                                  protocol_URL  \
# 0   https://pubmed.ncbi.nlm.nih.gov/35649411/
# 1   https://pubmed.ncbi.nlm.nih.gov/35649411/
# 2   https://pubmed.ncbi.nlm.nih.gov/35649411/
# 3   https://pubmed.ncbi.nlm.nih.gov/35649411/
# 4   https://pubmed.ncbi.nlm.nih.gov/35649411/
# 5   https://pubmed.ncbi.nlm.nih.gov/35649411/
# 6   https://pubmed.ncbi.nlm.nih.gov/35649411/
# 7   https://pubmed.ncbi.nlm.nih.gov/35649411/
# 8   https://pubmed.ncbi.nlm.nih.gov/35649411/
# 9   https://pubmed.ncbi.nlm.nih.gov/35649411/
# 10  https://pubmed.ncbi.nlm.nih.gov/35649411/
# 11  https://pubmed.ncbi.nlm.nih.gov/35649411/
# 12  https://pubmed.ncbi.nlm.nih.gov/35649411/
# 13  https://pubmed.ncbi.nlm.nih.gov/35649411/
# 14  https://pubmed.ncbi.nlm.nih.gov/35649411/
# 15  https://pubmed.ncbi.nlm.nih.gov/35649411/
# 16  https://pubmed.ncbi.nlm.nih.gov/35649411/
# 17  https://pubmed.ncbi.nlm.nih.gov/35649411/
# 18  https://pubmed.ncbi.nlm.nih.gov/35649411/
# 19  https://pubmed.ncbi.nlm.nih.gov/35649411/
# 20  https://pubmed.ncbi.nlm.nih.gov/35649411/
# 21  https://pubmed.ncbi.nlm.nih.gov/35649411/
# 22  https://pubmed.ncbi.nlm.nih.gov/35649411/
# 23  https://pubmed.ncbi.nlm.nih.gov/35649411/
#
#                                   institute sample_collection_site  \
# 0   Brigham and Women’s Hospital, Boston MA                    BWH
# 1   Brigham and Women’s Hospital, Boston MA                    BWH
# 2   Brigham and Women’s Hospital, Boston MA                    BWH
# 3   Brigham and Women’s Hospital, Boston MA                    BWH
# 4   Brigham and Women’s Hospital, Boston MA                    BWH
# 5   Brigham and Women’s Hospital, Boston MA                    BWH
# 6   Brigham and Women’s Hospital, Boston MA                    BWH
# 7   Brigham and Women’s Hospital, Boston MA                    BWH
# 8   Brigham and Women’s Hospital, Boston MA                    BWH
# 9   Brigham and Women’s Hospital, Boston MA                    BWH
# 10  Brigham and Women’s Hospital, Boston MA                    BWH
# 11  Brigham and Women’s Hospital, Boston MA                    BWH
# 12  Brigham and Women’s Hospital, Boston MA                    BWH
# 13  Brigham and Women’s Hospital, Boston MA                    BWH
# 14  Brigham and Women’s Hospital, Boston MA                    BWH
# 15  Brigham and Women’s Hospital, Boston MA                    BWH
# 16  Brigham and Women’s Hospital, Boston MA                    BWH
# 17  Brigham and Women’s Hospital, Boston MA                    BWH
# 18  Brigham and Women’s Hospital, Boston MA                    BWH
# 19  Brigham and Women’s Hospital, Boston MA                    BWH
# 20  Brigham and Women’s Hospital, Boston MA                    BWH
# 21  Brigham and Women’s Hospital, Boston MA                    BWH
# 22  Brigham and Women’s Hospital, Boston MA                    BWH
# 23  Brigham and Women’s Hospital, Boston MA                    BWH
#
#    sample_collection_relative_time_point library_ID library_ID_repository  \
# 0                                    N/A    BRI-959                   N/A
# 1                                    N/A    BRI-953                   N/A
# 2                                    N/A    BRI-962                   N/A
# 3                                    N/A    BRI-947                   N/A
# 4                                    N/A    BRI-965                   N/A
# 5                                    N/A    BRI-998                   N/A
# 6                                    N/A    BRI-980                   N/A
# 7                                    N/A    BRI-933                   N/A
# 8                                    N/A    BRI-977                   N/A
# 9                                    N/A    BRI-983                   N/A
# 10                                   N/A    BRI-968                   N/A
# 11                                   N/A    BRI-915                   N/A
# 12                                   N/A    BRI-918                   N/A
# 13                                   N/A    BRI-936                   N/A
# 14                                   N/A    BRI-939                   N/A
# 15                                   N/A    BRI-956                   N/A
# 16                                   N/A    BRI-942                   N/A
# 17                                   N/A    BRI-921                   N/A
# 18                                   N/A    BRI-992                   N/A
# 19                                   N/A    BRI-924                   N/A
# 20                                   N/A    BRI-986                   N/A
# 21                                   N/A    BRI-989                   N/A
# 22                                   N/A    BRI-995                   N/A
# 23                                   N/A    BRI-950                   N/A
#
#       author_batch_notes organism_ontology_term_id  ... sequenced_fragment  \
# 0   day4, same personnel            NCBITaxon:9606  ...        5 prime tag
# 1   day3, same personnel            NCBITaxon:9606  ...        5 prime tag
# 2   day4, same personnel            NCBITaxon:9606  ...        5 prime tag
# 3   day4, same personnel            NCBITaxon:9606  ...        5 prime tag
# 4   day4, same personnel            NCBITaxon:9606  ...        5 prime tag
# 5    N/A, same personnel            NCBITaxon:9606  ...        5 prime tag
# 6   day5, same personnel            NCBITaxon:9606  ...        5 prime tag
# 7   day2, same personnel            NCBITaxon:9606  ...        5 prime tag
# 8   day5, same personnel            NCBITaxon:9606  ...        5 prime tag
# 9   day5, same personnel            NCBITaxon:9606  ...        5 prime tag
# 10  day4, same personnel            NCBITaxon:9606  ...        5 prime tag
# 11  day1, same personnel            NCBITaxon:9606  ...        5 prime tag
# 12  day1, same personnel            NCBITaxon:9606  ...        5 prime tag
# 13  day2, same personnel            NCBITaxon:9606  ...        5 prime tag
# 14  day2, same personnel            NCBITaxon:9606  ...        5 prime tag
# 15  day4, same personnel            NCBITaxon:9606  ...        5 prime tag
# 16  day2, same personnel            NCBITaxon:9606  ...        5 prime tag
# 17  day1, same personnel            NCBITaxon:9606  ...        5 prime tag
# 18   N/A, same personnel            NCBITaxon:9606  ...        5 prime tag
# 19  day1, same personnel            NCBITaxon:9606  ...        5 prime tag
# 20  day5, same personnel            NCBITaxon:9606  ...        5 prime tag
# 21  day5, same personnel            NCBITaxon:9606  ...        5 prime tag
# 22   N/A, same personnel            NCBITaxon:9606  ...        5 prime tag
# 23   N/A, same personnel            NCBITaxon:9606  ...        5 prime tag
#
#    sequencing_platform is_primary_data reference_genome  \
# 0          EFO:0008367            true           GRCh38
# 1          EFO:0008367            true           GRCh38
# 2          EFO:0008367            true           GRCh38
# 3          EFO:0008367            true           GRCh38
# 4          EFO:0008367            true           GRCh38
# 5          EFO:0008367            true           GRCh38
# 6          EFO:0008367            true           GRCh38
# 7          EFO:0008367            true           GRCh38
# 8          EFO:0008367            true           GRCh38
# 9          EFO:0008367            true           GRCh38
# 10         EFO:0008367            true           GRCh38
# 11         EFO:0008367            true           GRCh38
# 12         EFO:0008367            true           GRCh38
# 13         EFO:0008367            true           GRCh38
# 14         EFO:0008367            true           GRCh38
# 15         EFO:0008367            true           GRCh38
# 16         EFO:0008367            true           GRCh38
# 17         EFO:0008367            true           GRCh38
# 18         EFO:0008367            true           GRCh38
# 19         EFO:0008367            true           GRCh38
# 20         EFO:0008367            true           GRCh38
# 21         EFO:0008367            true           GRCh38
# 22         EFO:0008367            true           GRCh38
# 23         EFO:0008367            true           GRCh38
#
#    gene_annotation_version alignment_software intron_inclusion  \
# 0                      v93      cell ranger 4               no
# 1                      v93      cell ranger 4               no
# 2                      v93      cell ranger 4               no
# 3                      v93      cell ranger 4               no
# 4                      v93      cell ranger 4               no
# 5                      v93      cell ranger 4               no
# 6                      v93      cell ranger 4               no
# 7                      v93      cell ranger 4               no
# 8                      v93      cell ranger 4               no
# 9                      v93      cell ranger 4               no
# 10                     v93      cell ranger 4               no
# 11                     v93      cell ranger 4               no
# 12                     v93      cell ranger 4               no
# 13                     v93      cell ranger 4               no
# 14                     v93      cell ranger 4               no
# 15                     v93      cell ranger 4               no
# 16                     v93      cell ranger 4               no
# 17                     v93      cell ranger 4               no
# 18                     v93      cell ranger 4               no
# 19                     v93      cell ranger 4               no
# 20                     v93      cell ranger 4               no
# 21                     v93      cell ranger 4               no
# 22                     v93      cell ranger 4               no
# 23                     v93      cell ranger 4               no
#
#    disease_ontology_term_id self_reported_ethnicity_ontology_term_id  \
# 0              PATO:0000461                                  unknown
# 1             MONDO:0005002                                  unknown
# 2             MONDO:0005002                                  unknown
# 3              PATO:0000461                                  unknown
# 4             MONDO:0005002                                  unknown
# 5              PATO:0000461                                  unknown
# 6              PATO:0000461                                  unknown
# 7             MONDO:0004849                                  unknown
# 8             MONDO:0004849                                  unknown
# 9              PATO:0000461                                  unknown
# 10             PATO:0000461                                  unknown
# 11             PATO:0000461                                  unknown
# 12             PATO:0000461                                  unknown
# 13            MONDO:0004849                                  unknown
# 14            MONDO:0005002                                  unknown
# 15            MONDO:0005002                                  unknown
# 16             PATO:0000461                                  unknown
# 17            MONDO:0004849                                  unknown
# 18            MONDO:0015925                                  unknown
# 19            MONDO:0005002                                  unknown
# 20             PATO:0000461                                  unknown
# 21            MONDO:0005002                                  unknown
# 22            MONDO:0004849                                  unknown
# 23            MONDO:0005607                                  unknown
#
#    development_stage_ontology_term_id
# 0                      HsapDv:0000238
# 1                      HsapDv:0000241
# 2                                 N/A
# 3                                 N/A
# 4                      HsapDv:0000242
# 5                      HsapDv:0000240
# 6                      HsapDv:0000240
# 7                      HsapDv:0000240
# 8                      HsapDv:0000240
# 9                      HsapDv:0000242
# 10                                N/A
# 11                     HsapDv:0000242
# 12                     HsapDv:0000242
# 13                     HsapDv:0000241
# 14                     HsapDv:0000243
# 15                     HsapDv:0000240
# 16                     HsapDv:0000242
# 17                     HsapDv:0000242
# 18                     HsapDv:0000241
# 19                     HsapDv:0000241
# 20                     HsapDv:0000241
# 21                     HsapDv:0000243
# 22                     HsapDv:0000242
# 23                     HsapDv:0000238
#
# [24 rows x 37 columns]

# %% [markdown]
# # Validate obs and uns from adata

# %%
# Merge obs and uns
merger = AnnDataMerger(
    adata = adata,
    obs_df = obs
)

adata_merged = merger.add_obs_metadata(
    adata_col = 'sample_id',
    df_col = 'sample_ID',
    skip = None
)

adata_merged.obs
# Out:
#                           orig.ident  nCount_RNA  nFeature_RNA  \
# BRI915_AAACCTGAGTAGCGGT-1    BRI-915      5032.0          1934
# BRI915_AAACCTGCAGACAAGC-1    BRI-915      7761.0          2745
# BRI915_AAACCTGCAGCATGAG-1    BRI-915      9515.0          2771
# BRI915_AAACCTGCATTCCTGC-1    BRI-915     11623.0          3248
# BRI915_AAACCTGGTACAGTGG-1    BRI-915     15134.0          3744
# ...                              ...         ...           ...
# BRI998_TTTGTCACACGTCAGC-1    BRI-998     18025.0          4252
# BRI998_TTTGTCACATTTCAGG-1    BRI-998      2870.0          1345
# BRI998_TTTGTCATCCAGAAGG-1    BRI-998      5801.0          2021
# BRI998_TTTGTCATCCTTAATC-1    BRI-998      4150.0          1538
# BRI998_TTTGTCATCTCAAGTG-1    BRI-998      2768.0          1413
#
#                            nCount_Protein  nFeature_Protein clonotype_id  \
# BRI915_AAACCTGAGTAGCGGT-1           549.0               133          NaN
# BRI915_AAACCTGCAGACAAGC-1          2101.0               183          NaN
# BRI915_AAACCTGCAGCATGAG-1          2069.0               180          NaN
# BRI915_AAACCTGCATTCCTGC-1          1238.0               138          NaN
# BRI915_AAACCTGGTACAGTGG-1          1671.0               176          NaN
# ...                                   ...               ...          ...
# BRI998_TTTGTCACACGTCAGC-1          1549.0               150          NaN
# BRI998_TTTGTCACATTTCAGG-1           387.0                89          NaN
# BRI998_TTTGTCATCCAGAAGG-1           529.0               102   clonotype1
# BRI998_TTTGTCATCCTTAATC-1           422.0                95          NaN
# BRI998_TTTGTCATCTCAAGTG-1           382.0                85          NaN
#
#                                 reads        umis  v_gene d_gene  ...  \
# BRI915_AAACCTGAGTAGCGGT-1 -2147483648 -2147483648     NaN    NaN  ...
# BRI915_AAACCTGCAGACAAGC-1 -2147483648 -2147483648     NaN    NaN  ...
# BRI915_AAACCTGCAGCATGAG-1 -2147483648 -2147483648     NaN    NaN  ...
# BRI915_AAACCTGCATTCCTGC-1 -2147483648 -2147483648     NaN    NaN  ...
# BRI915_AAACCTGGTACAGTGG-1 -2147483648 -2147483648     NaN    NaN  ...
# ...                               ...         ...     ...    ...  ...
# BRI998_TTTGTCACACGTCAGC-1 -2147483648 -2147483648     NaN    NaN  ...
# BRI998_TTTGTCACATTTCAGG-1 -2147483648 -2147483648     NaN    NaN  ...
# BRI998_TTTGTCATCCAGAAGG-1        3444           6  TRAV24   None  ...
# BRI998_TTTGTCATCCTTAATC-1 -2147483648 -2147483648     NaN    NaN  ...
# BRI998_TTTGTCATCTCAAGTG-1 -2147483648 -2147483648     NaN    NaN  ...
#
#                           sequenced_fragment sequencing_platform  \
# BRI915_AAACCTGAGTAGCGGT-1        5 prime tag         EFO:0008367
# BRI915_AAACCTGCAGACAAGC-1        5 prime tag         EFO:0008367
# BRI915_AAACCTGCAGCATGAG-1        5 prime tag         EFO:0008367
# BRI915_AAACCTGCATTCCTGC-1        5 prime tag         EFO:0008367
# BRI915_AAACCTGGTACAGTGG-1        5 prime tag         EFO:0008367
# ...                                      ...                 ...
# BRI998_TTTGTCACACGTCAGC-1        5 prime tag         EFO:0008367
# BRI998_TTTGTCACATTTCAGG-1        5 prime tag         EFO:0008367
# BRI998_TTTGTCATCCAGAAGG-1        5 prime tag         EFO:0008367
# BRI998_TTTGTCATCCTTAATC-1        5 prime tag         EFO:0008367
# BRI998_TTTGTCATCTCAAGTG-1        5 prime tag         EFO:0008367
#
#                           is_primary_data reference_genome  \
# BRI915_AAACCTGAGTAGCGGT-1            true           GRCh38
# BRI915_AAACCTGCAGACAAGC-1            true           GRCh38
# BRI915_AAACCTGCAGCATGAG-1            true           GRCh38
# BRI915_AAACCTGCATTCCTGC-1            true           GRCh38
# BRI915_AAACCTGGTACAGTGG-1            true           GRCh38
# ...                                   ...              ...
# BRI998_TTTGTCACACGTCAGC-1            true           GRCh38
# BRI998_TTTGTCACATTTCAGG-1            true           GRCh38
# BRI998_TTTGTCATCCAGAAGG-1            true           GRCh38
# BRI998_TTTGTCATCCTTAATC-1            true           GRCh38
# BRI998_TTTGTCATCTCAAGTG-1            true           GRCh38
#
#                           gene_annotation_version alignment_software  \
# BRI915_AAACCTGAGTAGCGGT-1                     v93      cell ranger 4
# BRI915_AAACCTGCAGACAAGC-1                     v93      cell ranger 4
# BRI915_AAACCTGCAGCATGAG-1                     v93      cell ranger 4
# BRI915_AAACCTGCATTCCTGC-1                     v93      cell ranger 4
# BRI915_AAACCTGGTACAGTGG-1                     v93      cell ranger 4
# ...                                           ...                ...
# BRI998_TTTGTCACACGTCAGC-1                     v93      cell ranger 4
# BRI998_TTTGTCACATTTCAGG-1                     v93      cell ranger 4
# BRI998_TTTGTCATCCAGAAGG-1                     v93      cell ranger 4
# BRI998_TTTGTCATCCTTAATC-1                     v93      cell ranger 4
# BRI998_TTTGTCATCTCAAGTG-1                     v93      cell ranger 4
#
#                            intron_inclusion  disease_ontology_term_id  \
# BRI915_AAACCTGAGTAGCGGT-1                no              PATO:0000461
# BRI915_AAACCTGCAGACAAGC-1                no              PATO:0000461
# BRI915_AAACCTGCAGCATGAG-1                no              PATO:0000461
# BRI915_AAACCTGCATTCCTGC-1                no              PATO:0000461
# BRI915_AAACCTGGTACAGTGG-1                no              PATO:0000461
# ...                                     ...                       ...
# BRI998_TTTGTCACACGTCAGC-1                no              PATO:0000461
# BRI998_TTTGTCACATTTCAGG-1                no              PATO:0000461
# BRI998_TTTGTCATCCAGAAGG-1                no              PATO:0000461
# BRI998_TTTGTCATCCTTAATC-1                no              PATO:0000461
# BRI998_TTTGTCATCTCAAGTG-1                no              PATO:0000461
#
#                            self_reported_ethnicity_ontology_term_id  \
# BRI915_AAACCTGAGTAGCGGT-1                                   unknown
# BRI915_AAACCTGCAGACAAGC-1                                   unknown
# BRI915_AAACCTGCAGCATGAG-1                                   unknown
# BRI915_AAACCTGCATTCCTGC-1                                   unknown
# BRI915_AAACCTGGTACAGTGG-1                                   unknown
# ...                                                             ...
# BRI998_TTTGTCACACGTCAGC-1                                   unknown
# BRI998_TTTGTCACATTTCAGG-1                                   unknown
# BRI998_TTTGTCATCCAGAAGG-1                                   unknown
# BRI998_TTTGTCATCCTTAATC-1                                   unknown
# BRI998_TTTGTCATCTCAAGTG-1                                   unknown
#
#                            development_stage_ontology_term_id
# BRI915_AAACCTGAGTAGCGGT-1                      HsapDv:0000242
# BRI915_AAACCTGCAGACAAGC-1                      HsapDv:0000242
# BRI915_AAACCTGCAGCATGAG-1                      HsapDv:0000242
# BRI915_AAACCTGCATTCCTGC-1                      HsapDv:0000242
# BRI915_AAACCTGGTACAGTGG-1                      HsapDv:0000242
# ...                                                       ...
# BRI998_TTTGTCACACGTCAGC-1                      HsapDv:0000240
# BRI998_TTTGTCACATTTCAGG-1                      HsapDv:0000240
# BRI998_TTTGTCATCCAGAAGG-1                      HsapDv:0000240
# BRI998_TTTGTCATCCTTAATC-1                      HsapDv:0000240
# BRI998_TTTGTCATCTCAAGTG-1                      HsapDv:0000240
#
# [109361 rows x 72 columns]

# %%
merger = AnnDataMerger(
    adata = adata,
    uns_df = uns
)

adata = merger.add_uns_metadata()

adata
# Out:
# AnnData object with n_obs × n_vars = 109361 × 36601
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_Protein', 'nFeature_Protein', 'clonotype_id', 'reads', 'umis', 'v_gene', 'd_gene', 'j_gene', 'c_gene', 'cdr3s_aa', 'cdr3s_nt', 'sample_ID', 'disease', 'cell_viability', 'percent.mt', 'G2M.Score', 'doublet_scrublet', 'percent.RPS', 'percent.RPL', 'qc.mit.Outlier', 'qc.nFeat.Outlier', 'qc.nCount.Outlier', 'qc.rps.Outlier', 'qc.rpl.Outlier', 'Level_1', 'Level_2', 'Level_3', 'Level_4', 'CellOntology', 'wnnUMAP_1', 'wnnUMAP_2', 'RNAmarkers', 'CITEmarkers', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id'
#     var: 'hgnc_symbol', 'ensembl_gene_id', 'gene_biotype', 'genes'
#     uns: 'X_name', 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments'

# %% [markdown]
# # Add author cell type markers to UNS

# %%
# RNAmarkers, CITEmarkers, CellOntology
columns_to_keep = ['Level_4', 'Level_3', 'Level_2', 'CellOntology', 'RNAmarkers', 'CITEmarkers']
unique_level_4 = adata.obs.drop_duplicates(subset=['Level_4'])[columns_to_keep].copy()
unique_level_4.reset_index(drop=True, inplace=True)
unique_level_4.rename(columns={'Level_2': AUTHOR_CELL_TYPE_L0, 'Level_3': AUTHOR_CELL_TYPE_L1, 'Level_4': AUTHOR_CELL_TYPE_L2, 'CellOntology': CELL_TYPE_ONTOLOGY_ID, 'RNAmarkers': MARKER_GENES, 'CITEmarkers': MARKER_PROTEINS}, inplace=True)
unique_level_4
# Out:
#    author_cell_type_level_2               author_cell_type_level_1  \
# 0              CD8+ T rm s3                           CD8 T memory
# 1                    ncMono                 Non-Classical Monocyte
# 2                 Mac intra  Macrophage interstitial intravascular
# 3                    AT2 s1                                 AT2 s1
# 4         Capillary cell s1                         Capillary Cell
# ..                      ...                                    ...
# 66             CD4+ T h1 s1                  CD4 T resident memory
# 67                 cMono s3                     Classical Monocyte
# 68              Plasmablast                         B Plasma cells
# 69    Pre-B Plasma Cell IgG                  Pre-B Plasma Cell IgG
# 70       Mucous/Goblet Cell                     Mucous/Goblet Cell
#
#    author_cell_type_level_0 cell_type_ontology_term_id  \
# 0               CD8+ T cell                 CL:4033040
# 1                  Monocyte                 CL:0002396
# 2                Mac Alv s1                 CL:4033043
# 3                    AT2 s1                 CL:0002063
# 4               Endothelium                 CL:0002144
# ..                      ...                        ...
# 66              CD4+ T cell                 CL:4033038
# 67                 Monocyte                 CL:0000860
# 68                   B cell                 CL:0000980
# 69              Plasma Cell                 CL:0000985
# 70       Mucous/Goblet Cell                 CL:1000143
#
#                          author_cell_type_markers_rna  \
# 0   PTGDS; SPON2; FGFBP2; FCER1G; FCGR3A; PRF1; TY...
# 1   HLA-DRA; CD79A; CD74; MS4A1; TCL1A; FCER2; HLA...
# 2   S100A9; RPS4Y1; PLAC8; PRELID1; AIF1; ACTB; CY...
# 3   SFTPA1; SFTPC; NNMT; PGC; LRRK2; SFTPA2; WIF1;...
# 4   IGFBP7; CLU; HSPG2; CD36; SELP; PROCR; FCN3; M...
# ..                                                ...
# 66  IGLV1-40; IGKV4-1; IGKV3-20; IGKC; RBPJ; NR3C1...
# 67  KLRC2; LINC02446; KRT86; IGKC; CSF1; IGKV1-5; ...
# 68  CCR7; LEF1; LTB; SOCS3; TCF7; SELL; MAL; IL7R;...
# 69  TRDV2; TRGV9; KLRG1; TRDC; S100B; RPS4Y1; KLRC...
# 70  BPIFB1; TRBV7-9; C1QC; C1QB; SCGB1A1; PTGDS; L...
#
#                      author_cell_type_markers_protein
# 0   CD16-prot; CD45RA-prot4; CD57Recombinant-prot;...
# 1   CD19-prot4; IgD-prot; CD21-prot4; IgM-prot2; C...
# 2   CLEC12A-prot4; CD35-prot6; Ig-light-chain-kapp...
# 3   CD326-or-Ep-CAM-prot2; CD324-or-E-Cadherin-pro...
# 4   CD144-or-VE-Cadherin-prot5; CD34-prot3; CD141-...
# ..                                                ...
# 66  CD103-or-IntegrinalphaE-prot1; CD5-prot6; CD4-...
# 67  CD57Recombinant-prot7; KLRG1-or-MAFA-prot5; CD...
# 68  CD5-prot2; CD3-prot1; TCR-alpha-or-beta-prot1;...
# 69  TCRVdelta2-prot; CD3-prot17; KLRG1-or-MAFA-pro...
# 70  CD235ab-prot1; CD204-prot2; CD169-or-Sialoadhe...
#
# [71 rows x 6 columns]

# %%
adata.uns[MARKERS] = unique_level_4

adata
# Out:
# AnnData object with n_obs × n_vars = 109361 × 36601
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_Protein', 'nFeature_Protein', 'clonotype_id', 'reads', 'umis', 'v_gene', 'd_gene', 'j_gene', 'c_gene', 'cdr3s_aa', 'cdr3s_nt', 'sample_ID', 'disease', 'cell_viability', 'percent.mt', 'G2M.Score', 'doublet_scrublet', 'percent.RPS', 'percent.RPL', 'qc.mit.Outlier', 'qc.nFeat.Outlier', 'qc.nCount.Outlier', 'qc.rps.Outlier', 'qc.rpl.Outlier', 'Level_1', 'Level_2', 'Level_3', 'Level_4', 'CellOntology', 'wnnUMAP_1', 'wnnUMAP_2', 'RNAmarkers', 'CITEmarkers', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id'
#     var: 'hgnc_symbol', 'ensembl_gene_id', 'gene_biotype', 'genes'
#     uns: 'X_name', 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments', 'author_cell_type_markers'

# %% [markdown]
# # Check author cell type annotations and Cell Ontology IDs

# %%
adata.obs[AUTHOR_CELL_TYPE] = adata.obs['Level_4']
adata.obs[CELL_TYPE_ONTOLOGY_ID] = adata.obs['CellOntology']
adata.obs[MARKER_GENES] = adata.obs['RNAmarkers']
adata.obs[MARKER_PROTEINS] = adata.obs['CITEmarkers']
adata.obs[MARKERS] = adata.obs['RNAmarkers']

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 109361 × 36601
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_Protein', 'nFeature_Protein', 'clonotype_id', 'reads', 'umis', 'v_gene', 'd_gene', 'j_gene', 'c_gene', 'cdr3s_aa', 'cdr3s_nt', 'sample_ID', 'disease', 'cell_viability', 'percent.mt', 'G2M.Score', 'doublet_scrublet', 'percent.RPS', 'percent.RPL', 'qc.mit.Outlier', 'qc.nFeat.Outlier', 'qc.nCount.Outlier', 'qc.rps.Outlier', 'qc.rpl.Outlier', 'Level_1', 'Level_2', 'Level_3', 'Level_4', 'CellOntology', 'wnnUMAP_1', 'wnnUMAP_2', 'RNAmarkers', 'CITEmarkers', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'author_cell_type', 'cell_type_ontology_term_id', 'author_cell_type_markers_rna', 'author_cell_type_markers_protein', 'author_cell_type_markers'
#     var: 'hgnc_symbol', 'ensembl_gene_id', 'gene_biotype', 'genes'
#     uns: 'X_name', 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments', 'author_cell_type_markers'

# %% [markdown]
# # Check whether ENSEMBL IDs in var

# %%
adata.var
# Out:
#              hgnc_symbol  ensembl_gene_id    gene_biotype        genes
# MIR1302-2HG  MIR1302-2HG  ENSG00000243485          lncRNA  MIR1302-2HG
# FAM138A          FAM138A  ENSG00000237613          lncRNA      FAM138A
# OR4F5              OR4F5  ENSG00000186092  protein_coding        OR4F5
# AL627309.1           NaN              NaN             NaN   AL627309.1
# AL627309.3           NaN              NaN             NaN   AL627309.3
# ...                  ...              ...             ...          ...
# AC141272.1           NaN              NaN             NaN   AC141272.1
# AC023491.2           NaN              NaN             NaN   AC023491.2
# AC007325.1           NaN              NaN             NaN   AC007325.1
# AC007325.4           NaN              NaN             NaN   AC007325.4
# AC007325.2           NaN              NaN             NaN   AC007325.2
#
# [36601 rows x 4 columns]

# %%
adata.var.rename(columns={'genes': 'gene_symbol', 'ensembl_gene_id': 'ensembl_id'}, inplace=True)
adata.var.index.name = 'index'
adata.var
# Out:
#              hgnc_symbol       ensembl_id    gene_biotype  gene_symbol
# index
# MIR1302-2HG  MIR1302-2HG  ENSG00000243485          lncRNA  MIR1302-2HG
# FAM138A          FAM138A  ENSG00000237613          lncRNA      FAM138A
# OR4F5              OR4F5  ENSG00000186092  protein_coding        OR4F5
# AL627309.1           NaN              NaN             NaN   AL627309.1
# AL627309.3           NaN              NaN             NaN   AL627309.3
# ...                  ...              ...             ...          ...
# AC141272.1           NaN              NaN             NaN   AC141272.1
# AC023491.2           NaN              NaN             NaN   AC023491.2
# AC007325.1           NaN              NaN             NaN   AC007325.1
# AC007325.4           NaN              NaN             NaN   AC007325.4
# AC007325.2           NaN              NaN             NaN   AC007325.2
#
# [36601 rows x 4 columns]

# %% [markdown]
# # Check raw data

# %%
adata.X.toarray().max()
# Out:
# 32554.0

# %%
adata.X = adata.X.astype(np.int64)

# %%
adata.raw = adata

# %%
adata.X
# Out:
# <109361x36601 sparse matrix of type '<class 'numpy.int64'>'
# 	with 234353414 stored elements in Compressed Sparse Column format>

# %%
adata.raw.X
# Out:
# <109361x36601 sparse matrix of type '<class 'numpy.int64'>'
# 	with 234353414 stored elements in Compressed Sparse Column format>

# %%
adata.X.toarray().max()
# Out:
# 32554

# %%
adata.raw.X.toarray().max()
# Out:
# 32554

# %% [markdown]
# ## Validation result
#
# ### UNS Validation
# - OK: Tier 1 UNS Google Sheet
# - OK: Tier 1 UNS AnnData Object
#
# ### OBS Validation
# - Validation Error: Tier 1 OBS Google Sheet: 'cryopreserved lung tissue' is not among available categories
# - Validation Error: Tier 1 OBS Anndata Object: 'cryopreserved lung tissue' is not among available categories

# %% [markdown]
# # Data Submission Status
#
# - CHECK: Raw data in X and in raw
# - REVISE: Tier 1 Metadata in OBS
# - CHECK: Cell Ontology IDs in OBS
# - CHECK: Author cell type in OBS
# - CHECK: Marker genes in UNS
# - CHECK: ENSEMBL IDs and gene symbols in var
#
# ### Revision
# DONE

# %%
adata.obs['cell_viability_percentage'] = pd.to_numeric(adata.obs['cell_viability_percentage'], errors='coerce')
adata.obs['cell_number_loaded'] = pd.to_numeric(adata.obs['cell_number_loaded'], errors='coerce')
adata.obs['sample_collection_year'] = pd.to_numeric(adata.obs['sample_collection_year'], errors='coerce')

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
