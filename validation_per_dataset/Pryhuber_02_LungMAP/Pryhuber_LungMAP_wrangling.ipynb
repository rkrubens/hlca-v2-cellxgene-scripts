# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import anndata2ri
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"
# Out:
# Warning message:
# package ‘methods’ was built under R version 4.3.3
# During startup - Warning messages:
# 1: package ‘datasets’ was built under R version 4.3.3
# 2: package ‘utils’ was built under R version 4.3.3
# 3: package ‘grDevices’ was built under R version 4.3.3
# 4: package ‘graphics’ was built under R version 4.3.3
# 5: package ‘stats’ was built under R version 4.3.3

# %%
DATASET_ID = "Pryhuber_02_LungMAP"
RDS_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/{DATASET_ID}.rds"
ENSEMBL_ID_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/features.tsv"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
# Name constants
AUTHOR_CELL_TYPE_L0 = 'author_cell_type_level_0'
AUTHOR_CELL_TYPE_L1 = 'author_cell_type_level_1'

CELL_TYPE_ONTOLOGY_ID_L0 = 'cell_type_ontology_term_id_level_0'
CELL_TYPE_ONTOLOGY_ID_L1 = 'cell_type_ontology_term_id_level_1'

CELL_TYPE_ONTOLOGY_LABEL_L0 = 'cell_type_ontology_term_label_level_0'
CELL_TYPE_ONTOLOGY_LABEL_L1 = 'cell_type_ontology_term_label_level_1'

AUTHOR_CELL_TYPE_DESCRIPTION_L0 = 'author_cell_type_description_level_0'
AUTHOR_CELL_TYPE_DESCRIPTION_L1 = 'author_cell_type_description_level_1'

MARKER_GENES_L0 = 'author_cell_type_markers_level_0'
MARKER_GENES_L1 = 'author_cell_type_markers_level_1'

# Finest grained annotation will be generic dataset cell type
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'
CELL_TYPE_ONTOLOGY_LABEL = 'cell_type_ontology_term_label'
MARKER_GENES = 'author_cell_type_markers'
AUTHOR_CELL_TYPE_DESCRIPTION = 'author_cell_type_description'

# %% [markdown]
# # Load data

# %%
obs = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "obs")
uns = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "uns")

# %% [markdown]
# # Validate obs and uns from Tier 1 Metadata Template

# %%
val_workflow = ValidationWorkflow(
    input = uns,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                                                title           study_PI  \
# 0  LungMAP Dissociated Adult Human Lung Cells - C...  Gloria,S,Pryhuber
#
#                               batch_condition default_embedding  unpublished  \
# 0  Donor.Id, capture batch, seq batch date ID          ref.umap  unpublished
#
#                                             comments
# 0  Reference genome: GRCh38 + SARS-CoV-2 (ncbi nu...

# %%
val_workflow = ValidationWorkflow(
    input = obs,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation error(s) encountered.
# {'disease_ontology_term_id': "Must start with 'PATO:' or 'MONDO:'. Invalid entries found."}
# Error containing field: disease_ontology_term_id
# Error message: Must start with 'PATO:' or 'MONDO:'. Invalid entries found.
# Value counts:
# PATO:0000461    10
# NCIT:C173483     4
# NCIT:C173484     3
# Name: disease_ontology_term_id, dtype: int64
# Returning error-containing OBS dataframe.
#          sample_ID donor_id  \
# 0   D116-RML-MIX-2     D116
# 1   D122-RML-MIX-2     D122
# 2   D239-CBL-MIX-3     D239
# 3   D271-RML-MIX-2     D271
# 4   D283-RML-MIX-2     D283
# 5   D291-RUL-MIX-3     D291
# 6   D292-RUL-MIX-3     D292
# 7   D305-RUL-MIX-2     D305
# 8   D307-CBL-MIX-2     D307
# 9   D312-RUL-MIX-3     D312
# 10  D341-RUL-MIX-2     D341
# 11  D356-RUL-MIX-3     D356
# 12  D373-RUL-MIX-2     D373
# 13  D376-RUL-MIX-4     D376
# 14  D391-CBL-MIX-2     D391
# 15  D403-RUL-MIX-2     D403
# 16  D404-CBL-MIX-2     D404
#
#                                          protocol_URL  \
# 0   https://www.protocols.io/view/lungmap2-urmc-ce...
# 1   https://www.protocols.io/view/lungmap2-urmc-ce...
# 2   https://www.protocols.io/view/lungmap2-urmc-ce...
# 3   https://www.protocols.io/view/lungmap2-urmc-ce...
# 4   https://www.protocols.io/view/lungmap2-urmc-ce...
# 5   https://www.protocols.io/view/lungmap2-urmc-ce...
# 6   https://www.protocols.io/view/lungmap2-urmc-ce...
# 7   https://www.protocols.io/view/lungmap2-urmc-ce...
# 8   https://www.protocols.io/view/lungmap2-urmc-ce...
# 9   https://www.protocols.io/view/lungmap2-urmc-ce...
# 10  https://www.protocols.io/view/lungmap2-urmc-ce...
# 11  https://www.protocols.io/view/lungmap2-urmc-ce...
# 12  https://www.protocols.io/view/lungmap2-urmc-ce...
# 13  https://www.protocols.io/view/lungmap2-urmc-ce...
# 14  https://www.protocols.io/view/lungmap2-urmc-ce...
# 15  https://www.protocols.io/view/lungmap2-urmc-ce...
# 16  https://www.protocols.io/view/lungmap2-urmc-ce...
#
#                   institute sample_collection_site  \
# 0   University of Rochester          BRINDL_site_2
# 1   University of Rochester          BRINDL_site_2
# 2   University of Rochester          BRINDL_site_2
# 3   University of Rochester          BRINDL_site_2
# 4   University of Rochester          BRINDL_site_2
# 5   University of Rochester          BRINDL_site_2
# 6   University of Rochester          BRINDL_site_2
# 7   University of Rochester          BRINDL_site_2
# 8   University of Rochester          BRINDL_site_2
# 9   University of Rochester          BRINDL_site_2
# 10  University of Rochester          BRINDL_site_2
# 11  University of Rochester          BRINDL_site_2
# 12  University of Rochester          BRINDL_site_2
# 13  University of Rochester          BRINDL_site_2
# 14  University of Rochester          BRINDL_site_2
# 15  University of Rochester          BRINDL_site_2
# 16  University of Rochester          BRINDL_site_2
#
#    sample_collection_relative_time_point library_ID library_ID_repository  \
# 0                                    N/A         A5                   N/A
# 1                                    N/A        A23                   N/A
# 2                                    N/A        A36                   N/A
# 3                                    N/A         A1                   N/A
# 4                                    N/A        A35                   N/A
# 5                                    N/A        A20                   N/A
# 6                                    N/A        A17                   N/A
# 7                                    N/A        A27                   N/A
# 8                                    N/A        A40                   N/A
# 9                                    N/A        A10                   N/A
# 10                                   N/A        A31                   N/A
# 11                                   N/A        A15                   N/A
# 12                                   N/A        A13                   N/A
# 13                                   N/A     Pilot1                   N/A
# 14                                   N/A        A38                   N/A
# 15                                   N/A         A4                   N/A
# 16                                   N/A        A44                   N/A
#
#    author_batch_notes organism_ontology_term_id  ...  sequenced_fragment  \
# 0                 N/A            NCBITaxon:9606  ...         3 prime tag
# 1                 N/A            NCBITaxon:9606  ...         3 prime tag
# 2                 N/A            NCBITaxon:9606  ...         3 prime tag
# 3                 N/A            NCBITaxon:9606  ...         3 prime tag
# 4                 N/A            NCBITaxon:9606  ...         3 prime tag
# 5                 N/A            NCBITaxon:9606  ...         3 prime tag
# 6                 N/A            NCBITaxon:9606  ...         3 prime tag
# 7                 N/A            NCBITaxon:9606  ...         3 prime tag
# 8                 N/A            NCBITaxon:9606  ...         3 prime tag
# 9                 N/A            NCBITaxon:9606  ...         3 prime tag
# 10                N/A            NCBITaxon:9606  ...         3 prime tag
# 11                N/A            NCBITaxon:9606  ...         3 prime tag
# 12                N/A            NCBITaxon:9606  ...         3 prime tag
# 13                N/A            NCBITaxon:9606  ...         3 prime tag
# 14                N/A            NCBITaxon:9606  ...         3 prime tag
# 15                N/A            NCBITaxon:9606  ...         3 prime tag
# 16                N/A            NCBITaxon:9606  ...         3 prime tag
#
#    sequencing_platform is_primary_data reference_genome  \
# 0          EFO_0008637            true           GRCh38
# 1          EFO_0008637            true           GRCh38
# 2          EFO_0008637            true           GRCh38
# 3          EFO_0008637            true           GRCh38
# 4          EFO_0008637            true           GRCh38
# 5          EFO_0008637            true           GRCh38
# 6          EFO_0008637            true           GRCh38
# 7          EFO_0008637            true           GRCh38
# 8          EFO_0008637            true           GRCh38
# 9          EFO_0008637            true           GRCh38
# 10         EFO_0008637            true           GRCh38
# 11         EFO_0008637            true           GRCh38
# 12         EFO_0008637            true           GRCh38
# 13         EFO_0008637            true           GRCh38
# 14         EFO_0008637            true           GRCh38
# 15         EFO_0008637            true           GRCh38
# 16         EFO_0008637            true           GRCh38
#
#                               gene_annotation_version alignment_software  \
# 0   GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 1   GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 2   GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 3   GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 4   GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 5   GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 6   GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 7   GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 8   GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 9   GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 10  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 11  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 12  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 13  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 14  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 15  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
# 16  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...   cellranger 6.0.1
#
#    intron_inclusion disease_ontology_term_id  \
# 0                no             NCIT:C173483
# 1                no             NCIT:C173483
# 2                no             NCIT:C173483
# 3                no             NCIT:C173484
# 4                no             PATO:0000461
# 5                no             NCIT:C173483
# 6                no             PATO:0000461
# 7                no             PATO:0000461
# 8                no             PATO:0000461
# 9                no             NCIT:C173484
# 10               no             PATO:0000461
# 11               no             PATO:0000461
# 12               no             PATO:0000461
# 13               no             NCIT:C173484
# 14               no             PATO:0000461
# 15               no             PATO:0000461
# 16               no             PATO:0000461
#
#    self_reported_ethnicity_ontology_term_id development_stage_ontology_term_id
# 0                                  Black/AA                     HsapDv:0000239
# 1                                  Hispanic                    HsapDv:0000238
# 2                                  Black/AA                    HsapDv:0000238
# 3                                     White                     HsapDv:0000240
# 4                                     White                     HsapDv:0000241
# 5                                     White                    HsapDv:0000237
# 6                                     White                    HsapDv:0000237
# 7                                     White                     HsapDv:0000241
# 8                                  Black/AA                    HsapDv:0000264
# 9                                     White                     HsapDv:0000240
# 10                                 Hispanic                     HsapDv:0000240
# 11                                    White                     HsapDv:0000241
# 12                                    White                     HsapDv:0000241
# 13                                    Asian                    HsapDv:0000237
# 14                                    White                     HsapDv:0000268
# 15                                    Asian                     HsapDv:0000239
# 16                         More than 1 race                    HsapDv:0000264
#
# [17 rows x 37 columns]

# %%
anndata2ri.activate()
# %load_ext rpy2.ipython
# Out:
# /tmp/ipykernel_56751/2547887543.py:1: DeprecationWarning: The global conversion available with activate() is deprecated and will be removed in the next major release. Use a local converter.
#   anndata2ri.activate()

# %%
# %%R -i RDS_PATH
#
# suppressPackageStartupMessages(library(Seurat))
# rds <- readRDS(file=RDS_PATH)
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# In addition: Warning message:
# package ‘tools’ was built under R version 4.3.3

# %%
# %%R -o adata
#
# adata <- as.SingleCellExperiment(rds)
# adata
# Out:
# class: SingleCellExperiment
# dim: 30669 110600
# metadata(0):
# assays(2): counts logcounts
# rownames(30669): OR4F5 AL627309.1 ... AC007325.2 Sars-CoV2
# rowData names(0):
# colnames(110600): AAACCCAAGCAGCCCT-1_3_1 AAACCCAAGTGACACG-1_3_1 ...
#   TTTGTTGTCAGCTGAT-1_7_7 TTTGTTGTCCATAGAC-1_7_7
# colData names(13): Donor.Id nCount_RNA ... annotation_type ident
# reducedDimNames(0):
# mainExpName: SCT
# altExpNames(2): ADT RNA
# In addition: Warning messages:
# 1: In .check_reddim_names(x, value, withDimnames) :
#   non-NULL 'rownames(value)' should be the same as 'colnames(x)' for
# 'reducedDim<-'. This will be an error in the next release of
# Bioconductor.
# 2: In .check_reddim_names(x, value, withDimnames) :
#   non-NULL 'rownames(value)' should be the same as 'colnames(x)' for
# 'reducedDim<-'. This will be an error in the next release of
# Bioconductor.
# /home/icb/raphael.kfuri-rubens/miniconda3/envs/hlcav2-env/lib/python3.10/site-packages/anndata2ri/_r2py.py:132: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   return AnnData(exprs, obs, var, uns, obsm, layers=layers)

# %% [markdown]
# # Validate obs and uns from adata

# %%
adata.obs.columns
# Out:
# Index(['Donor.Id', 'nCount_RNA', 'nFeature_RNA', 'nCount_ADT', 'percent.mt',
#        'predicted.ann_level_1', 'predicted.ann_level_2',
#        'predicted.ann_level_3', 'predicted.ann_level_4',
#        'predicted.ann_level_5', 'predicted.ann_finest_level',
#        'annotation_type', 'ident'],
#       dtype='object')

# %%
adata.obs['ident']
# Out:
# AAACCCAAGCAGCCCT-1_3_1      EC venous systemic
# AAACCCAAGTGACACG-1_3_1    Alveolar fibroblasts
# AAACCCACATGTGTCA-1_3_1             EC arterial
# AAACCCAGTACGTGTT-1_3_1                NK cells
# AAACCCAGTCCTGAAT-1_3_1     Monocyte-derived Mφ
#                                   ...
# TTTGTTGGTTGCCAAT-1_7_7    Alveolar macrophages
# TTTGTTGGTTTGAACC-1_7_7     Classical monocytes
# TTTGTTGTCACTCACC-1_7_7     Monocyte-derived Mφ
# TTTGTTGTCAGCTGAT-1_7_7    Alveolar macrophages
# TTTGTTGTCCATAGAC-1_7_7     Monocyte-derived Mφ
# Name: ident, Length: 110600, dtype: category
# Categories (48, object): ['EC venous systemic', 'Alveolar fibroblasts', 'EC arterial', 'NK cells', ..., 'Mesothelium', 'Goblet (nasal)', 'Plasmacytoid DCs', 'Neuroendocrine']

# %%
non_overlap = [x for x in adata.obs['Donor.Id'].value_counts().index if x not in obs['donor_id'].unique()]

non_overlap_other_side = [x for x in obs['donor_id'].unique() if x not in adata.obs['Donor.Id'].value_counts().index]

# %%
non_overlap
# Out:
# []

# %%
non_overlap_other_side
# Out:
# []

# %%
merger = AnnDataMerger(
    adata = adata,
    uns_df = uns
)

adata = merger.add_uns_metadata()

adata
# Out:
# AnnData object with n_obs × n_vars = 110600 × 30669
#     obs: 'Donor.Id', 'nCount_RNA', 'nFeature_RNA', 'nCount_ADT', 'percent.mt', 'predicted.ann_level_1', 'predicted.ann_level_2', 'predicted.ann_level_3', 'predicted.ann_level_4', 'predicted.ann_level_5', 'predicted.ann_finest_level', 'annotation_type', 'ident'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments'
#     layers: 'logcounts'

# %%
merger = AnnDataMerger(
    adata = adata,
    obs_df = obs
)

adata = merger.add_obs_metadata(
    adata_col = 'Donor.Id',
    df_col = 'donor_id',
    skip = None
)

adata.obs.rename(columns={'Donor.Id': 'donor_id'}, inplace=True)

adata.obs
# Out:
#                        donor_id  nCount_RNA  nFeature_RNA  nCount_ADT  \
# AAACCCAAGCAGCCCT-1_3_1     D376      9072.0          2954       118.0
# AAACCCAAGTGACACG-1_3_1     D376     10798.0          3512        56.0
# AAACCCACATGTGTCA-1_3_1     D376      3209.0          1633       100.0
# AAACCCAGTACGTGTT-1_3_1     D376      4064.0          1569       126.0
# AAACCCAGTCCTGAAT-1_3_1     D376      7436.0          2521        91.0
# ...                         ...         ...           ...         ...
# TTTGTTGGTTGCCAAT-1_7_7     D404      1327.0           735       382.0
# TTTGTTGGTTTGAACC-1_7_7     D404     16326.0          4232       510.0
# TTTGTTGTCACTCACC-1_7_7     D404      3671.0          1707       306.0
# TTTGTTGTCAGCTGAT-1_7_7     D404      1065.0           728     19199.0
# TTTGTTGTCCATAGAC-1_7_7     D404     23305.0          5244       412.0
#
#                         percent.mt predicted.ann_level_1  \
# AAACCCAAGCAGCCCT-1_3_1    3.516314           Endothelial
# AAACCCAAGTGACACG-1_3_1    2.046675                Stroma
# AAACCCACATGTGTCA-1_3_1    4.144593           Endothelial
# AAACCCAGTACGTGTT-1_3_1    5.634843                Immune
# AAACCCAGTCCTGAAT-1_3_1   15.935987                Immune
# ...                            ...                   ...
# TTTGTTGGTTGCCAAT-1_7_7    2.788244                Immune
# TTTGTTGGTTTGAACC-1_7_7    3.613867                Immune
# TTTGTTGTCACTCACC-1_7_7    5.502588                Immune
# TTTGTTGTCAGCTGAT-1_7_7    5.915493                Immune
# TTTGTTGTCCATAGAC-1_7_7    2.565973                Immune
#
#                        predicted.ann_level_2    predicted.ann_level_3  \
# AAACCCAAGCAGCCCT-1_3_1         Blood vessels                EC venous
# AAACCCAAGTGACACG-1_3_1    Fibroblast lineage              Fibroblasts
# AAACCCACATGTGTCA-1_3_1         Blood vessels              EC arterial
# AAACCCAGTACGTGTT-1_3_1              Lymphoid  Innate lymphoid cell NK
# AAACCCAGTCCTGAAT-1_3_1               Myeloid              Macrophages
# ...                                      ...                      ...
# TTTGTTGGTTGCCAAT-1_7_7               Myeloid              Macrophages
# TTTGTTGGTTTGAACC-1_7_7               Myeloid                Monocytes
# TTTGTTGTCACTCACC-1_7_7               Myeloid              Macrophages
# TTTGTTGTCAGCTGAT-1_7_7               Myeloid              Macrophages
# TTTGTTGTCCATAGAC-1_7_7               Myeloid              Macrophages
#
#                            predicted.ann_level_4 predicted.ann_level_5  ...  \
# AAACCCAAGCAGCCCT-1_3_1        EC venous systemic                  None  ...
# AAACCCAAGTGACACG-1_3_1      Alveolar fibroblasts                  None  ...
# AAACCCACATGTGTCA-1_3_1                      None                  None  ...
# AAACCCAGTACGTGTT-1_3_1                  NK cells                  None  ...
# AAACCCAGTCCTGAAT-1_3_1  Interstitial macrophages   Monocyte-derived Mφ  ...
# ...                                          ...                   ...  ...
# TTTGTTGGTTGCCAAT-1_7_7      Alveolar macrophages                  None  ...
# TTTGTTGGTTTGAACC-1_7_7       Classical monocytes                  None  ...
# TTTGTTGTCACTCACC-1_7_7  Interstitial macrophages   Monocyte-derived Mφ  ...
# TTTGTTGTCAGCTGAT-1_7_7  Interstitial macrophages                  None  ...
# TTTGTTGTCCATAGAC-1_7_7  Interstitial macrophages   Monocyte-derived Mφ  ...
#
#                        sequenced_fragment sequencing_platform is_primary_data  \
# AAACCCAAGCAGCCCT-1_3_1        3 prime tag         EFO_0008637            true
# AAACCCAAGTGACACG-1_3_1        3 prime tag         EFO_0008637            true
# AAACCCACATGTGTCA-1_3_1        3 prime tag         EFO_0008637            true
# AAACCCAGTACGTGTT-1_3_1        3 prime tag         EFO_0008637            true
# AAACCCAGTCCTGAAT-1_3_1        3 prime tag         EFO_0008637            true
# ...                                   ...                 ...             ...
# TTTGTTGGTTGCCAAT-1_7_7        3 prime tag         EFO_0008637            true
# TTTGTTGGTTTGAACC-1_7_7        3 prime tag         EFO_0008637            true
# TTTGTTGTCACTCACC-1_7_7        3 prime tag         EFO_0008637            true
# TTTGTTGTCAGCTGAT-1_7_7        3 prime tag         EFO_0008637            true
# TTTGTTGTCCATAGAC-1_7_7        3 prime tag         EFO_0008637            true
#
#                        reference_genome  \
# AAACCCAAGCAGCCCT-1_3_1           GRCh38
# AAACCCAAGTGACACG-1_3_1           GRCh38
# AAACCCACATGTGTCA-1_3_1           GRCh38
# AAACCCAGTACGTGTT-1_3_1           GRCh38
# AAACCCAGTCCTGAAT-1_3_1           GRCh38
# ...                                 ...
# TTTGTTGGTTGCCAAT-1_7_7           GRCh38
# TTTGTTGGTTTGAACC-1_7_7           GRCh38
# TTTGTTGTCACTCACC-1_7_7           GRCh38
# TTTGTTGTCAGCTGAT-1_7_7           GRCh38
# TTTGTTGTCCATAGAC-1_7_7           GRCh38
#
#                                                   gene_annotation_version  \
# AAACCCAAGCAGCCCT-1_3_1  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...
# AAACCCAAGTGACACG-1_3_1  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...
# AAACCCACATGTGTCA-1_3_1  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...
# AAACCCAGTACGTGTT-1_3_1  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...
# AAACCCAGTCCTGAAT-1_3_1  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...
# ...                                                                   ...
# TTTGTTGGTTGCCAAT-1_7_7  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...
# TTTGTTGGTTTGAACC-1_7_7  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...
# TTTGTTGTCACTCACC-1_7_7  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...
# TTTGTTGTCAGCTGAT-1_7_7  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...
# TTTGTTGTCCATAGAC-1_7_7  GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nu...
#
#                        alignment_software intron_inclusion  \
# AAACCCAAGCAGCCCT-1_3_1   cellranger 6.0.1               no
# AAACCCAAGTGACACG-1_3_1   cellranger 6.0.1               no
# AAACCCACATGTGTCA-1_3_1   cellranger 6.0.1               no
# AAACCCAGTACGTGTT-1_3_1   cellranger 6.0.1               no
# AAACCCAGTCCTGAAT-1_3_1   cellranger 6.0.1               no
# ...                                   ...              ...
# TTTGTTGGTTGCCAAT-1_7_7   cellranger 6.0.1               no
# TTTGTTGGTTTGAACC-1_7_7   cellranger 6.0.1               no
# TTTGTTGTCACTCACC-1_7_7   cellranger 6.0.1               no
# TTTGTTGTCAGCTGAT-1_7_7   cellranger 6.0.1               no
# TTTGTTGTCCATAGAC-1_7_7   cellranger 6.0.1               no
#
#                        disease_ontology_term_id  \
# AAACCCAAGCAGCCCT-1_3_1             NCIT:C173484
# AAACCCAAGTGACACG-1_3_1             NCIT:C173484
# AAACCCACATGTGTCA-1_3_1             NCIT:C173484
# AAACCCAGTACGTGTT-1_3_1             NCIT:C173484
# AAACCCAGTCCTGAAT-1_3_1             NCIT:C173484
# ...                                         ...
# TTTGTTGGTTGCCAAT-1_7_7             PATO:0000461
# TTTGTTGGTTTGAACC-1_7_7             PATO:0000461
# TTTGTTGTCACTCACC-1_7_7             PATO:0000461
# TTTGTTGTCAGCTGAT-1_7_7             PATO:0000461
# TTTGTTGTCCATAGAC-1_7_7             PATO:0000461
#
#                        self_reported_ethnicity_ontology_term_id  \
# AAACCCAAGCAGCCCT-1_3_1                                    Asian
# AAACCCAAGTGACACG-1_3_1                                    Asian
# AAACCCACATGTGTCA-1_3_1                                    Asian
# AAACCCAGTACGTGTT-1_3_1                                    Asian
# AAACCCAGTCCTGAAT-1_3_1                                    Asian
# ...                                                         ...
# TTTGTTGGTTGCCAAT-1_7_7                         More than 1 race
# TTTGTTGGTTTGAACC-1_7_7                         More than 1 race
# TTTGTTGTCACTCACC-1_7_7                         More than 1 race
# TTTGTTGTCAGCTGAT-1_7_7                         More than 1 race
# TTTGTTGTCCATAGAC-1_7_7                         More than 1 race
#
#                        development_stage_ontology_term_id
# AAACCCAAGCAGCCCT-1_3_1                    HsapDv:0000237
# AAACCCAAGTGACACG-1_3_1                    HsapDv:0000237
# AAACCCACATGTGTCA-1_3_1                    HsapDv:0000237
# AAACCCAGTACGTGTT-1_3_1                    HsapDv:0000237
# AAACCCAGTCCTGAAT-1_3_1                    HsapDv:0000237
# ...                                                   ...
# TTTGTTGGTTGCCAAT-1_7_7                    HsapDv:0000264
# TTTGTTGGTTTGAACC-1_7_7                    HsapDv:0000264
# TTTGTTGTCACTCACC-1_7_7                    HsapDv:0000264
# TTTGTTGTCAGCTGAT-1_7_7                    HsapDv:0000264
# TTTGTTGTCCATAGAC-1_7_7                    HsapDv:0000264
#
# [110600 rows x 49 columns]

# %% [markdown]
# # Add author cell type markers to UNS

# %%
marker_data = {
    AUTHOR_CELL_TYPE: [
        "Alveolar macrophages", "NK cells", "AT2", "Alveolar Mφ CCL3+", "Suprabasal", "Basal resting",
        "EC venous pulmonary", "CD8 T cells", "EC arterial", "Peribronchial fibroblasts", "CD4 T cells", 
        "AT1", "Multiciliated (non-nasal)", "Plasma cells", "Goblet (nasal)", "Club (nasal)", 
        "SM activated stress response", "Classical monocytes", "Monocyte derived Mφ", 
        "Alveolar Mφ proliferating", "Club (non-nasal)", "SMG serous (bronchial)", "EC venous systemic", 
        "Non classical monocytes", "EC general capillary", "Adventitial fibroblasts", "Lymphatic EC mature", 
        "EC aerocyte capillary", "Smooth muscle", "Alveolar fibroblasts", "Multiciliated (nasal)", 
        "Goblet (bronchial)", "Neuroendocrine", "Lymphatic EC differentiating", "DC2", "Transitional Club AT2", 
        "DC1", "Myofibroblasts", "B cells", "Mast cells", "Interstitial Mφ perivascular", 
        "SMG mucous", "AT2 proliferating", "Goblet (subsegmental)", "Pericytes", "SMG duct", 
        "Mesothelium", "SMG serous (nasal)", "Ionocyte", "Alveolar Mφ MT-positive", "Fibromyocytes", 
        "Deuterosomal", "Tuft", "Plasmacytoid DCs", "T cells proliferating", "Subpleural fibroblasts", 
        "Lymphatic EC proliferating", "Migratory DCs"
    ],
    MARKER_GENES: [
        "MS4A7;C1QA;HLA-DQB1;HLA-DMA;HLA-DPB1;HLA-DPA1;ACP5;C1QC;CTSS;HLA-DQA1",
        "GZMA;CD7;CCL4;CST7;NKG7;GNLY;CTSW;CCL5;GZMB;PRF1",
        "SEPP1;PGC;NAPSA;SFTPD;SLC34A2;CYB5A;MUC1;S100A14;SFTA2;SFTA3",
        "MCEMP1;UPP1;HLA-DQA1;C5AR1;HLA-DMA;AIF1;LST1;LINC01272;MRC1;CCL18",
        "PRDX2;KRT19;SFN;TACSTD2;KRT5;LDHB;KRT17;KLK11;S100A2;SERPINB4",
        "CYR61;PERP;IGFBP2;KRT19;KRT5;KRT17;KRT15;S100A2;LAMB3;BCAM",
        "VWF;MGP;GNG11;RAMP2;SPARCL1;IGFBP7;IFI27;CLDN5;ACKR1;AQP1",
        "CD8A;CD3E;CCL4;CD2;CXCR4;GZMA;NKG7;IL32;CD3D;CCL5",
        "SPARCL1;SOX17;IFI27;TM4SF1;A2M;CLEC14A;GIMAP7;CRIP2;CLDN5;PECAM1",
        "IGFBP7;COL1A2;COL3A1;A2M;BGN;DCN;MGP;LUM;MFAP4;C1S",
        "CORO1A;KLRB1;CD3E;LTB;CXCR4;IL7R;TRAC;IL32;CD2;CD3D",
        "SFTA2;CEACAM6;FXYD3;CAV1;TSPAN13;KRT7;ADIRF;HOPX;AGER;EMP2",
        "SNTN;FAM229B;TMEM231;C5orf49;C12orf75;GSTA1;C11orf97;RP11-356K23.1;CD24;RP11-295M3.4",
        "ITM2C;TNFRSF17;FKBP11;IGKC;IGHA1;IGHG1;CD79A;JCHAIN;MZB1;ISG20",
        "KRT7;MUC1;MUC5AC;MSMB;CP;LMO7;LCN2;CEACAM6;BPIFB1;PIGR",
        "ELF3;C19orf33;KRT8;KRT19;TACSTD2;MUC1;S100A14;CXCL17;PSCA;FAM3D",
        "C11orf96;HES4;PLAC9;FLNA;KANK2;TPM2;PLN;SELM;GPX3;LBH",
        "LST1;IL1B;LYZ;COTL1;S100A9;VCAN;S100A8;S100A12;AIF1;FCN1",
        "LYZ;ACP5;TYROBP;LGALS1;CD68;AIF1;CTSL;EMP3;FCER1G;LAPTM5",
        "H2AFV;STMN1;LSM4;GYPC;PTTG1;KIAA0101;FABP4;CKS1B;UBE2C;HMGN2",
        "SCGB3A1;CYP2F1;GSTA1;HES4;TSPAN8;TFF3;MSMB;BPIFB1;SCGB1A1;PIGR",
        "AZGP1;ZG16B;PIGR;NDRG2;LPO;C6orf58;DMBT1;PRB3;FAM3D;RP11-1143G9.4",
        "VWF;MGP;GNG11;PLVAP;RAMP2;SPARCL1;IGFBP7;A2M;CLEC14A;ACKR1",
        "PSAP;FCGR3A;FCN1;CORO1A;COTL1;FCER1G;LAPTM5;CTSS;AIF1;LST1",
        "EPAS1;GNG11;IFI27;TM4SF1;EGFL7;AQP1;VWF;FCN3;SPARCL1;CLDN5",
        "COL6A2;SFRP2;IGFBP7;IGFBP6;COL3A1;C1S;MMP2;MGP;SPARC;COL1A2",
        "PPFIBP1;GNG11;RAMP2;CCL21;MMRN1;IGFBP7;SDPR;TM4SF1;CLDN5;ECSCR",
        "EMCN;HPGD;IFI27;CA4;EGFL7;AQP1;IL1RL1;SPARCL1;SDPR;CLDN5",
        "PRKCDBP;NDUFA4L2;MYL9;ACTA2;MGP;CALD1;TPM1;TAGLN;IGFBP7;TPM2",
        "LUM;COL6A1;CYR61;C1R;COL1A2;MFAP4;A2M;C1S;ADH1B;GPX3",
        "RP11-356K23.1;EFHC1;CAPS;ROPN1L;RSPH1;C9orf116;TMEM190;DNALI1;PIFO;ODF3B",
        "MUC5AC;MSMB;PI3;MDK;ANKRD36C;TFF3;PIGR;SAA1;CP;BPIFB1",
        "UCHL1;TFF3;APOA1BP;CLDN3;SEC11C;NGFRAP1;SCG5;HIGD1A;PHGR1;CD24",
        "AKAP12;TFF3;SDPR;CLDN5;TCF4;TFPI;TIMP3;GNG11;CCL21;IGFBP7",
        "ITGB2;LAPTM5;HLA-DRB1;HLA-DPB1;HLA-DPA1;HLA-DMB;HLA-DQB1;HLA-DQA1;HLA-DMA;LST1",
        "CXCL17;C16orf89;RNASE1;KRT7;SCGB1A1;PIGR;SCGB3A2;KLK11;SFTA1P;FOLR1",
        "HLA-DPA1;CPNE3;CORO1A;CPVL;C1orf54;WDFY4;LSP1;HLA-DQB1;HLA-DQA1;HLA-DMA",
        "CALD1;CYR61;TAGLN;MT1X;PRELP;TPM2;GPX3;CTGF;IGFBP5;SPARCL1",
        "CD69;CORO1A;LIMD2;BANK1;LAPTM5;CXCR4;LTB;CD79A;CD37;MS4A1",
        "VWA5A;RGS13;C1orf186;HPGDS;CPA3;GATA2;MS4A2;KIT;TPSAB1;TPSB2",
        "MRC1;RNASE1;FGL2;RNASE6;HLA-DPA1;GPR183;CD14;HLA-DPB1;MS4A6A;AIF1",
        "FKBP11;TCN1;GOLM1;TFF3;PIGR;KLK11;MARCKSL1;CRACR2B;SELM;MSMB",
        "CDK1;LSM3;CKS1B;EIF1AX;UBE2C;MRPL14;PRC1;CENPW;EMP2;DHFR",
        "MDK;MUC5B;SCGB1A1;CP;C3;TSPAN8;TFF3;MSMB;PIGR;BPIFB1",
        "MYL9;SPARC;SPARCL1;IGFBP7;COL4A1;GPX3;PDGFRB;CALD1;COX4I2;TPM2",
        "PIP;ZG16B;PIGR;SAA1;MARCKSL1;ALDH1A3;SELM;LTF;RARRES1;AZGP1",
        "CEBPD;LINC01133;MRPL33;UPK3B;CFB;SEPP1;EID1;HP;CUX1;MRPS21",
        "ZG16B;MUC7;C6orf58;PRB3;LTF;LYZ;PRR4;AZGP1;PIGR;RP11-1143G9.4",
        "FOXI1;ATP6V1A;GOLM1;TMEM61;SEC11C;SCNN1B;ASCL3;CLCNKB;HEPACAM2;CD24",
        "GSTO1;LGALS1;CTSZ;MT2A;APOC1;CTSL;UPP1;CCL18;FABP4;MT1X",
        "NEXN;ACTG2;LMOD1;IGFBP7;PPP1R14A;DES;FLNA;TPM2;PLN;SELM",
        "RSPH9;PIFO;RUVBL2;C11orf88;FAM183A;MORN2;SAXO2;CFAP126;FAM229B;C5orf49",
        "MUC20;KHDRBS1;ZNF428;BIK;CRYM;LRMP;HES6;KIT;AZGP1;RASSF6",
        "IL3RA;TCF4;LTB;GZMB;JCHAIN;ITM2C;IRF8;PLD4;IRF7;C12orf75",
        "TRAC;HMGN2;IL32;CORO1A;ARHGDIB;STMN1;RAC2;IL2RG;HMGB2;CD3D",
        "SERPING1;C1R;COL1A2;NNMT;COL3A1;MT1E;MT1X;PLA2G2A;SELM;MT1M",
        "S100A16;TUBB;HMGN2;COX20;LSM2;HMGN1;ARPC1A;ECSCR;EID1;MARCKS",
        "IL2RG;HLA-DRB5;TMEM176A;BIRC3;TYMP;CCL22;SYNGR2;CD83;LSP1;HLA-DQA1"
    ]
}

marker_genes_df = pd.DataFrame(marker_data)

marker_genes_df
# Out:
#                 author_cell_type  \
# 0           Alveolar macrophages
# 1                       NK cells
# 2                            AT2
# 3              Alveolar Mφ CCL3+
# 4                     Suprabasal
# 5                  Basal resting
# 6            EC venous pulmonary
# 7                    CD8 T cells
# 8                    EC arterial
# 9      Peribronchial fibroblasts
# 10                   CD4 T cells
# 11                           AT1
# 12     Multiciliated (non-nasal)
# 13                  Plasma cells
# 14                Goblet (nasal)
# 15                  Club (nasal)
# 16  SM activated stress response
# 17           Classical monocytes
# 18           Monocyte derived Mφ
# 19     Alveolar Mφ proliferating
# 20              Club (non-nasal)
# 21        SMG serous (bronchial)
# 22            EC venous systemic
# 23       Non classical monocytes
# 24          EC general capillary
# 25       Adventitial fibroblasts
# 26           Lymphatic EC mature
# 27         EC aerocyte capillary
# 28                 Smooth muscle
# 29          Alveolar fibroblasts
# 30         Multiciliated (nasal)
# 31            Goblet (bronchial)
# 32                Neuroendocrine
# 33  Lymphatic EC differentiating
# 34                           DC2
# 35         Transitional Club AT2
# 36                           DC1
# 37                Myofibroblasts
# 38                       B cells
# 39                    Mast cells
# 40  Interstitial Mφ perivascular
# 41                    SMG mucous
# 42             AT2 proliferating
# 43         Goblet (subsegmental)
# 44                     Pericytes
# 45                      SMG duct
# 46                   Mesothelium
# 47            SMG serous (nasal)
# 48                      Ionocyte
# 49       Alveolar Mφ MT-positive
# 50                 Fibromyocytes
# 51                  Deuterosomal
# 52                          Tuft
# 53              Plasmacytoid DCs
# 54         T cells proliferating
# 55        Subpleural fibroblasts
# 56    Lymphatic EC proliferating
# 57                 Migratory DCs
#
#                              author_cell_type_markers
# 0   MS4A7;C1QA;HLA-DQB1;HLA-DMA;HLA-DPB1;HLA-DPA1;...
# 1    GZMA;CD7;CCL4;CST7;NKG7;GNLY;CTSW;CCL5;GZMB;PRF1
# 2   SEPP1;PGC;NAPSA;SFTPD;SLC34A2;CYB5A;MUC1;S100A...
# 3   MCEMP1;UPP1;HLA-DQA1;C5AR1;HLA-DMA;AIF1;LST1;L...
# 4   PRDX2;KRT19;SFN;TACSTD2;KRT5;LDHB;KRT17;KLK11;...
# 5   CYR61;PERP;IGFBP2;KRT19;KRT5;KRT17;KRT15;S100A...
# 6   VWF;MGP;GNG11;RAMP2;SPARCL1;IGFBP7;IFI27;CLDN5...
# 7   CD8A;CD3E;CCL4;CD2;CXCR4;GZMA;NKG7;IL32;CD3D;CCL5
# 8   SPARCL1;SOX17;IFI27;TM4SF1;A2M;CLEC14A;GIMAP7;...
# 9   IGFBP7;COL1A2;COL3A1;A2M;BGN;DCN;MGP;LUM;MFAP4...
# 10  CORO1A;KLRB1;CD3E;LTB;CXCR4;IL7R;TRAC;IL32;CD2...
# 11  SFTA2;CEACAM6;FXYD3;CAV1;TSPAN13;KRT7;ADIRF;HO...
# 12  SNTN;FAM229B;TMEM231;C5orf49;C12orf75;GSTA1;C1...
# 13  ITM2C;TNFRSF17;FKBP11;IGKC;IGHA1;IGHG1;CD79A;J...
# 14  KRT7;MUC1;MUC5AC;MSMB;CP;LMO7;LCN2;CEACAM6;BPI...
# 15  ELF3;C19orf33;KRT8;KRT19;TACSTD2;MUC1;S100A14;...
# 16  C11orf96;HES4;PLAC9;FLNA;KANK2;TPM2;PLN;SELM;G...
# 17  LST1;IL1B;LYZ;COTL1;S100A9;VCAN;S100A8;S100A12...
# 18  LYZ;ACP5;TYROBP;LGALS1;CD68;AIF1;CTSL;EMP3;FCE...
# 19  H2AFV;STMN1;LSM4;GYPC;PTTG1;KIAA0101;FABP4;CKS...
# 20  SCGB3A1;CYP2F1;GSTA1;HES4;TSPAN8;TFF3;MSMB;BPI...
# 21  AZGP1;ZG16B;PIGR;NDRG2;LPO;C6orf58;DMBT1;PRB3;...
# 22  VWF;MGP;GNG11;PLVAP;RAMP2;SPARCL1;IGFBP7;A2M;C...
# 23  PSAP;FCGR3A;FCN1;CORO1A;COTL1;FCER1G;LAPTM5;CT...
# 24  EPAS1;GNG11;IFI27;TM4SF1;EGFL7;AQP1;VWF;FCN3;S...
# 25  COL6A2;SFRP2;IGFBP7;IGFBP6;COL3A1;C1S;MMP2;MGP...
# 26  PPFIBP1;GNG11;RAMP2;CCL21;MMRN1;IGFBP7;SDPR;TM...
# 27  EMCN;HPGD;IFI27;CA4;EGFL7;AQP1;IL1RL1;SPARCL1;...
# 28  PRKCDBP;NDUFA4L2;MYL9;ACTA2;MGP;CALD1;TPM1;TAG...
# 29  LUM;COL6A1;CYR61;C1R;COL1A2;MFAP4;A2M;C1S;ADH1...
# 30  RP11-356K23.1;EFHC1;CAPS;ROPN1L;RSPH1;C9orf116...
# 31  MUC5AC;MSMB;PI3;MDK;ANKRD36C;TFF3;PIGR;SAA1;CP...
# 32  UCHL1;TFF3;APOA1BP;CLDN3;SEC11C;NGFRAP1;SCG5;H...
# 33  AKAP12;TFF3;SDPR;CLDN5;TCF4;TFPI;TIMP3;GNG11;C...
# 34  ITGB2;LAPTM5;HLA-DRB1;HLA-DPB1;HLA-DPA1;HLA-DM...
# 35  CXCL17;C16orf89;RNASE1;KRT7;SCGB1A1;PIGR;SCGB3...
# 36  HLA-DPA1;CPNE3;CORO1A;CPVL;C1orf54;WDFY4;LSP1;...
# 37  CALD1;CYR61;TAGLN;MT1X;PRELP;TPM2;GPX3;CTGF;IG...
# 38  CD69;CORO1A;LIMD2;BANK1;LAPTM5;CXCR4;LTB;CD79A...
# 39  VWA5A;RGS13;C1orf186;HPGDS;CPA3;GATA2;MS4A2;KI...
# 40  MRC1;RNASE1;FGL2;RNASE6;HLA-DPA1;GPR183;CD14;H...
# 41  FKBP11;TCN1;GOLM1;TFF3;PIGR;KLK11;MARCKSL1;CRA...
# 42  CDK1;LSM3;CKS1B;EIF1AX;UBE2C;MRPL14;PRC1;CENPW...
# 43  MDK;MUC5B;SCGB1A1;CP;C3;TSPAN8;TFF3;MSMB;PIGR;...
# 44  MYL9;SPARC;SPARCL1;IGFBP7;COL4A1;GPX3;PDGFRB;C...
# 45  PIP;ZG16B;PIGR;SAA1;MARCKSL1;ALDH1A3;SELM;LTF;...
# 46  CEBPD;LINC01133;MRPL33;UPK3B;CFB;SEPP1;EID1;HP...
# 47  ZG16B;MUC7;C6orf58;PRB3;LTF;LYZ;PRR4;AZGP1;PIG...
# 48  FOXI1;ATP6V1A;GOLM1;TMEM61;SEC11C;SCNN1B;ASCL3...
# 49  GSTO1;LGALS1;CTSZ;MT2A;APOC1;CTSL;UPP1;CCL18;F...
# 50  NEXN;ACTG2;LMOD1;IGFBP7;PPP1R14A;DES;FLNA;TPM2...
# 51  RSPH9;PIFO;RUVBL2;C11orf88;FAM183A;MORN2;SAXO2...
# 52  MUC20;KHDRBS1;ZNF428;BIK;CRYM;LRMP;HES6;KIT;AZ...
# 53  IL3RA;TCF4;LTB;GZMB;JCHAIN;ITM2C;IRF8;PLD4;IRF...
# 54  TRAC;HMGN2;IL32;CORO1A;ARHGDIB;STMN1;RAC2;IL2R...
# 55  SERPING1;C1R;COL1A2;NNMT;COL3A1;MT1E;MT1X;PLA2...
# 56  S100A16;TUBB;HMGN2;COX20;LSM2;HMGN1;ARPC1A;ECS...
# 57  IL2RG;HLA-DRB5;TMEM176A;BIRC3;TYMP;CCL22;SYNGR...

# %% [markdown]
# # Check author cell type annotations and Cell Ontology IDs

# %%
object_cell_types = adata.obs['ident'].value_counts(dropna=False).index.tolist()

# %%
# get hlca v1 ontology mapping
pd.set_option('display.max_rows', 100)
hlca_v1_ontology_mapping_df = pd.read_csv("../HLCA_v1/hlca_v1_finest_annot_ontology_id_mapping.csv")

hlca_v1_ontology_mapping_dict = dict(zip(hlca_v1_ontology_mapping_df['ann_finest_level'], hlca_v1_ontology_mapping_df['cell_type_ontology_term_id']))
hlca_v1_ontology_mapping_dict
# Out:
# {'Alveolar macrophages': 'CL:0000583',
#  'NK cells': 'CL:0000623',
#  'AT2': 'CL:0002063',
#  'Alveolar Mph CCL3+': 'CL:0000583',
#  'Suprabasal': 'CL:0002633',
#  'Basal resting': 'CL:0002633',
#  'EC venous pulmonary': 'CL:0002543',
#  'CD8 T cells': 'CL:0000625',
#  'EC arterial': 'CL:1001568',
#  'Peribronchial fibroblasts': 'CL:2000093',
#  'CD4 T cells': 'CL:0000624',
#  'AT1': 'CL:0002062',
#  'Multiciliated (non-nasal)': 'CL:0002145',
#  'Plasma cells': 'CL:0000786',
#  'Hillock-like': 'CL:4030023',
#  'Goblet (nasal)': 'CL:0002480',
#  'Club (nasal)': 'CL:0000158',
#  'SM activated stress response': 'CL:0000192',
#  'Classical monocytes': 'CL:0000860',
#  'Monocyte-derived Mph': 'CL:0000861',
#  'Alveolar Mph proliferating': 'CL:0000583',
#  'Club (non-nasal)': 'CL:0000158',
#  'SMG serous (bronchial)': 'CL:0019001',
#  'EC venous systemic': 'CL:0002543',
#  'Non-classical monocytes': 'CL:0000875',
#  'EC general capillary': 'CL:0002144',
#  'Adventitial fibroblasts': 'CL:4028006',
#  'Lymphatic EC mature': 'CL:0002138',
#  'EC aerocyte capillary': 'CL:0002144',
#  'pre-TB secretory': 'CL:0002632',
#  'Smooth muscle': 'CL:0019019',
#  'Alveolar fibroblasts': 'CL:4028004',
#  'Multiciliated (nasal)': 'CL:0005012',
#  'Goblet (bronchial)': 'CL:1000312',
#  'Neuroendocrine': 'CL:1000223',
#  'Lymphatic EC differentiating': 'CL:0002138',
#  'DC2': 'CL:0002399',
#  'DC1': 'CL:0000990',
#  'Myofibroblasts': 'CL:0000186',
#  'B cells': 'CL:0000236',
#  'Mast cells': 'CL:0000097',
#  'Interstitial Mph perivascular': 'CL:1001603',
#  'SMG mucous': 'CL:0000319',
#  'AT2 proliferating': 'CL:0002063',
#  'Goblet (subsegmental)': 'CL:0019003',
#  'Pericytes': 'CL:0009089',
#  'AT0': 'CL:0010003',
#  'SMG duct': 'CL:0000622',
#  'Mesothelium': 'CL:0000077',
#  'SMG serous (nasal)': 'CL:0000313',
#  'Ionocyte': 'CL:0005006',
#  'Alveolar Mph MT-positive': 'CL:0000583',
#  'Smooth muscle FAM83D+': 'CL:0000499',
#  'Deuterosomal': 'CL:0005012',
#  'Tuft': 'CL:0002075',
#  'Plasmacytoid DCs': 'CL:0000784',
#  'T cells proliferating': 'CL:0000084',
#  'Subpleural fibroblasts': 'CL:0000057',
#  'Hematopoietic stem cells': 'CL:0000037',
#  'Lymphatic EC proliferating': 'CL:0002138',
#  'Migratory DCs': 'CL:0000451'}

# %%
final_mapping_dict = {key: hlca_v1_ontology_mapping_dict.get(key, None) for key in object_cell_types}

final_mapping_dict
# Out:
# {'Classical monocytes': 'CL:0000860',
#  'Monocyte-derived Mφ': None,
#  'Alveolar macrophages': 'CL:0000583',
#  'CD8 T cells': 'CL:0000625',
#  'NK cells': 'CL:0000623',
#  'EC general capillary': 'CL:0002144',
#  'Non-classical monocytes': 'CL:0000875',
#  'Interstitial Mφ perivascular': None,
#  'AT2': 'CL:0002063',
#  'CD4 T cells': 'CL:0000624',
#  'AT1': 'CL:0002062',
#  'Alveolar fibroblasts': 'CL:4028004',
#  'DC2': 'CL:0002399',
#  'Smooth muscle': 'CL:0019019',
#  'B cells': 'CL:0000236',
#  'EC arterial': 'CL:1001568',
#  'EC aerocyte capillary': 'CL:0002144',
#  'Mast cells': 'CL:0000097',
#  'EC venous pulmonary': 'CL:0002543',
#  'Plasma cells': 'CL:0000786',
#  'Transitional Club-AT2': None,
#  'Multiciliated (non-nasal)': 'CL:0002145',
#  'EC venous systemic': 'CL:0002543',
#  'Basal resting': 'CL:0002633',
#  'Adventitial fibroblasts': 'CL:4028006',
#  'Lymphatic EC mature': 'CL:0002138',
#  'Pericytes': 'CL:0009089',
#  'Alveolar Mφ proliferating': None,
#  'Club (nasal)': 'CL:0000158',
#  'Myofibroblasts': 'CL:0000186',
#  'Peribronchial fibroblasts': 'CL:2000093',
#  'Club (non-nasal)': 'CL:0000158',
#  'Lymphatic EC differentiating': 'CL:0002138',
#  'T cells proliferating': 'CL:0000084',
#  'AT2 proliferating': 'CL:0002063',
#  'Suprabasal': 'CL:0002633',
#  'Migratory DCs': 'CL:0000451',
#  'Plasmacytoid DCs': 'CL:0000784',
#  'SM activated stress response': 'CL:0000192',
#  'Multiciliated (nasal)': 'CL:0005012',
#  'Ionocyte': 'CL:0005006',
#  'Alveolar Mφ CCL3+': None,
#  'Goblet (nasal)': 'CL:0002480',
#  'Deuterosomal': 'CL:0005012',
#  'Alveolar Mφ MT-positive': None,
#  'Mesothelium': 'CL:0000077',
#  'Neuroendocrine': 'CL:1000223',
#  'Subpleural fibroblasts': 'CL:0000057'}

# %%
# fill in Nones:
final_mapping_dict['Monocyte-derived Mφ'] = 'CL:0000861'
final_mapping_dict['Interstitial Mφ perivascular'] = 'CL:1001603'
final_mapping_dict['Transitional Club-AT2'] = 'CL:0002632'
final_mapping_dict['Alveolar Mφ proliferating'] = 'CL:0000583'
final_mapping_dict['Alveolar Mφ CCL3+'] = 'CL:0000583'
final_mapping_dict['Alveolar Mφ MT-positive'] = 'CL:0000583'

final_mapping_dict
# Out:
# {'Classical monocytes': 'CL:0000860',
#  'Monocyte-derived Mφ': 'CL:0000861',
#  'Alveolar macrophages': 'CL:0000583',
#  'CD8 T cells': 'CL:0000625',
#  'NK cells': 'CL:0000623',
#  'EC general capillary': 'CL:0002144',
#  'Non-classical monocytes': 'CL:0000875',
#  'Interstitial Mφ perivascular': 'CL:1001603',
#  'AT2': 'CL:0002063',
#  'CD4 T cells': 'CL:0000624',
#  'AT1': 'CL:0002062',
#  'Alveolar fibroblasts': 'CL:4028004',
#  'DC2': 'CL:0002399',
#  'Smooth muscle': 'CL:0019019',
#  'B cells': 'CL:0000236',
#  'EC arterial': 'CL:1001568',
#  'EC aerocyte capillary': 'CL:0002144',
#  'Mast cells': 'CL:0000097',
#  'EC venous pulmonary': 'CL:0002543',
#  'Plasma cells': 'CL:0000786',
#  'Transitional Club-AT2': 'CL:0002632',
#  'Multiciliated (non-nasal)': 'CL:0002145',
#  'EC venous systemic': 'CL:0002543',
#  'Basal resting': 'CL:0002633',
#  'Adventitial fibroblasts': 'CL:4028006',
#  'Lymphatic EC mature': 'CL:0002138',
#  'Pericytes': 'CL:0009089',
#  'Alveolar Mφ proliferating': 'CL:0000583',
#  'Club (nasal)': 'CL:0000158',
#  'Myofibroblasts': 'CL:0000186',
#  'Peribronchial fibroblasts': 'CL:2000093',
#  'Club (non-nasal)': 'CL:0000158',
#  'Lymphatic EC differentiating': 'CL:0002138',
#  'T cells proliferating': 'CL:0000084',
#  'AT2 proliferating': 'CL:0002063',
#  'Suprabasal': 'CL:0002633',
#  'Migratory DCs': 'CL:0000451',
#  'Plasmacytoid DCs': 'CL:0000784',
#  'SM activated stress response': 'CL:0000192',
#  'Multiciliated (nasal)': 'CL:0005012',
#  'Ionocyte': 'CL:0005006',
#  'Alveolar Mφ CCL3+': 'CL:0000583',
#  'Goblet (nasal)': 'CL:0002480',
#  'Deuterosomal': 'CL:0005012',
#  'Alveolar Mφ MT-positive': 'CL:0000583',
#  'Mesothelium': 'CL:0000077',
#  'Neuroendocrine': 'CL:1000223',
#  'Subpleural fibroblasts': 'CL:0000057'}

# %%
adata.obs[AUTHOR_CELL_TYPE] = adata.obs['ident']
adata.obs[CELL_TYPE_ONTOLOGY_ID] = adata.obs[AUTHOR_CELL_TYPE].map(final_mapping_dict)

# %%
adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False)
# Out:
# Classical monocytes             28301
# Monocyte-derived Mφ             22705
# Alveolar macrophages            13493
# CD8 T cells                      9086
# NK cells                         5328
# EC general capillary             4053
# Non-classical monocytes          3752
# Interstitial Mφ perivascular     3735
# AT2                              3130
# CD4 T cells                      2920
# AT1                              1994
# Alveolar fibroblasts             1521
# DC2                              1364
# Smooth muscle                    1347
# B cells                          1155
# EC arterial                       990
# EC aerocyte capillary             790
# Mast cells                        713
# EC venous pulmonary               597
# Plasma cells                      534
# Transitional Club-AT2             491
# Multiciliated (non-nasal)         461
# EC venous systemic                411
# Basal resting                     319
# Adventitial fibroblasts           237
# Lymphatic EC mature               195
# Pericytes                         184
# Alveolar Mφ proliferating         160
# Club (nasal)                      131
# Myofibroblasts                     98
# Peribronchial fibroblasts          89
# Club (non-nasal)                   72
# Lymphatic EC differentiating       71
# T cells proliferating              32
# AT2 proliferating                  25
# Suprabasal                         25
# Migratory DCs                      19
# Plasmacytoid DCs                   15
# SM activated stress response       14
# Multiciliated (nasal)              11
# Ionocyte                           10
# Alveolar Mφ CCL3+                   9
# Goblet (nasal)                      3
# Deuterosomal                        3
# Alveolar Mφ MT-positive             2
# Mesothelium                         2
# Neuroendocrine                      2
# Subpleural fibroblasts              1
# Name: author_cell_type, dtype: int64

# %%
adata.obs[CELL_TYPE_ONTOLOGY_ID].value_counts(dropna=False)
# Out:
# CL:0000860    28301
# CL:0000861    22705
# CL:0000583    13664
# CL:0000625     9086
# CL:0000623     5328
# CL:0002144     4843
# CL:0000875     3752
# CL:1001603     3735
# CL:0002063     3155
# CL:0000624     2920
# CL:0002062     1994
# CL:4028004     1521
# CL:0002399     1364
# CL:0019019     1347
# CL:0000236     1155
# CL:0002543     1008
# CL:1001568      990
# CL:0000097      713
# CL:0000786      534
# CL:0002632      491
# CL:0002145      461
# CL:0002633      344
# CL:0002138      266
# CL:4028006      237
# CL:0000158      203
# CL:0009089      184
# CL:0000186       98
# CL:2000093       89
# CL:0000084       32
# CL:0000451       19
# CL:0000784       15
# CL:0005012       14
# CL:0000192       14
# CL:0005006       10
# CL:0002480        3
# CL:0000077        2
# CL:1000223        2
# CL:0000057        1
# Name: cell_type_ontology_term_id, dtype: int64

# %%
cell_types_adata = adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=True).index.tolist()

marker_genes_df = marker_genes_df[marker_genes_df[AUTHOR_CELL_TYPE].isin(cell_types_adata)]

marker_genes_df[CELL_TYPE_ONTOLOGY_ID] = marker_genes_df[AUTHOR_CELL_TYPE].map(final_mapping_dict)

marker_genes_df
# Out:
# /tmp/ipykernel_56751/229048695.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker_genes_df[CELL_TYPE_ONTOLOGY_ID] = marker_genes_df[AUTHOR_CELL_TYPE].map(final_mapping_dict)
#                 author_cell_type  \
# 0           Alveolar macrophages
# 1                       NK cells
# 2                            AT2
# 3              Alveolar Mφ CCL3+
# 4                     Suprabasal
# 5                  Basal resting
# 6            EC venous pulmonary
# 7                    CD8 T cells
# 8                    EC arterial
# 9      Peribronchial fibroblasts
# 10                   CD4 T cells
# 11                           AT1
# 12     Multiciliated (non-nasal)
# 13                  Plasma cells
# 14                Goblet (nasal)
# 15                  Club (nasal)
# 16  SM activated stress response
# 17           Classical monocytes
# 19     Alveolar Mφ proliferating
# 20              Club (non-nasal)
# 22            EC venous systemic
# 24          EC general capillary
# 25       Adventitial fibroblasts
# 26           Lymphatic EC mature
# 27         EC aerocyte capillary
# 28                 Smooth muscle
# 29          Alveolar fibroblasts
# 30         Multiciliated (nasal)
# 32                Neuroendocrine
# 33  Lymphatic EC differentiating
# 34                           DC2
# 37                Myofibroblasts
# 38                       B cells
# 39                    Mast cells
# 40  Interstitial Mφ perivascular
# 42             AT2 proliferating
# 44                     Pericytes
# 46                   Mesothelium
# 48                      Ionocyte
# 49       Alveolar Mφ MT-positive
# 51                  Deuterosomal
# 53              Plasmacytoid DCs
# 54         T cells proliferating
# 55        Subpleural fibroblasts
# 57                 Migratory DCs
#
#                              author_cell_type_markers  \
# 0   MS4A7;C1QA;HLA-DQB1;HLA-DMA;HLA-DPB1;HLA-DPA1;...
# 1    GZMA;CD7;CCL4;CST7;NKG7;GNLY;CTSW;CCL5;GZMB;PRF1
# 2   SEPP1;PGC;NAPSA;SFTPD;SLC34A2;CYB5A;MUC1;S100A...
# 3   MCEMP1;UPP1;HLA-DQA1;C5AR1;HLA-DMA;AIF1;LST1;L...
# 4   PRDX2;KRT19;SFN;TACSTD2;KRT5;LDHB;KRT17;KLK11;...
# 5   CYR61;PERP;IGFBP2;KRT19;KRT5;KRT17;KRT15;S100A...
# 6   VWF;MGP;GNG11;RAMP2;SPARCL1;IGFBP7;IFI27;CLDN5...
# 7   CD8A;CD3E;CCL4;CD2;CXCR4;GZMA;NKG7;IL32;CD3D;CCL5
# 8   SPARCL1;SOX17;IFI27;TM4SF1;A2M;CLEC14A;GIMAP7;...
# 9   IGFBP7;COL1A2;COL3A1;A2M;BGN;DCN;MGP;LUM;MFAP4...
# 10  CORO1A;KLRB1;CD3E;LTB;CXCR4;IL7R;TRAC;IL32;CD2...
# 11  SFTA2;CEACAM6;FXYD3;CAV1;TSPAN13;KRT7;ADIRF;HO...
# 12  SNTN;FAM229B;TMEM231;C5orf49;C12orf75;GSTA1;C1...
# 13  ITM2C;TNFRSF17;FKBP11;IGKC;IGHA1;IGHG1;CD79A;J...
# 14  KRT7;MUC1;MUC5AC;MSMB;CP;LMO7;LCN2;CEACAM6;BPI...
# 15  ELF3;C19orf33;KRT8;KRT19;TACSTD2;MUC1;S100A14;...
# 16  C11orf96;HES4;PLAC9;FLNA;KANK2;TPM2;PLN;SELM;G...
# 17  LST1;IL1B;LYZ;COTL1;S100A9;VCAN;S100A8;S100A12...
# 19  H2AFV;STMN1;LSM4;GYPC;PTTG1;KIAA0101;FABP4;CKS...
# 20  SCGB3A1;CYP2F1;GSTA1;HES4;TSPAN8;TFF3;MSMB;BPI...
# 22  VWF;MGP;GNG11;PLVAP;RAMP2;SPARCL1;IGFBP7;A2M;C...
# 24  EPAS1;GNG11;IFI27;TM4SF1;EGFL7;AQP1;VWF;FCN3;S...
# 25  COL6A2;SFRP2;IGFBP7;IGFBP6;COL3A1;C1S;MMP2;MGP...
# 26  PPFIBP1;GNG11;RAMP2;CCL21;MMRN1;IGFBP7;SDPR;TM...
# 27  EMCN;HPGD;IFI27;CA4;EGFL7;AQP1;IL1RL1;SPARCL1;...
# 28  PRKCDBP;NDUFA4L2;MYL9;ACTA2;MGP;CALD1;TPM1;TAG...
# 29  LUM;COL6A1;CYR61;C1R;COL1A2;MFAP4;A2M;C1S;ADH1...
# 30  RP11-356K23.1;EFHC1;CAPS;ROPN1L;RSPH1;C9orf116...
# 32  UCHL1;TFF3;APOA1BP;CLDN3;SEC11C;NGFRAP1;SCG5;H...
# 33  AKAP12;TFF3;SDPR;CLDN5;TCF4;TFPI;TIMP3;GNG11;C...
# 34  ITGB2;LAPTM5;HLA-DRB1;HLA-DPB1;HLA-DPA1;HLA-DM...
# 37  CALD1;CYR61;TAGLN;MT1X;PRELP;TPM2;GPX3;CTGF;IG...
# 38  CD69;CORO1A;LIMD2;BANK1;LAPTM5;CXCR4;LTB;CD79A...
# 39  VWA5A;RGS13;C1orf186;HPGDS;CPA3;GATA2;MS4A2;KI...
# 40  MRC1;RNASE1;FGL2;RNASE6;HLA-DPA1;GPR183;CD14;H...
# 42  CDK1;LSM3;CKS1B;EIF1AX;UBE2C;MRPL14;PRC1;CENPW...
# 44  MYL9;SPARC;SPARCL1;IGFBP7;COL4A1;GPX3;PDGFRB;C...
# 46  CEBPD;LINC01133;MRPL33;UPK3B;CFB;SEPP1;EID1;HP...
# 48  FOXI1;ATP6V1A;GOLM1;TMEM61;SEC11C;SCNN1B;ASCL3...
# 49  GSTO1;LGALS1;CTSZ;MT2A;APOC1;CTSL;UPP1;CCL18;F...
# 51  RSPH9;PIFO;RUVBL2;C11orf88;FAM183A;MORN2;SAXO2...
# 53  IL3RA;TCF4;LTB;GZMB;JCHAIN;ITM2C;IRF8;PLD4;IRF...
# 54  TRAC;HMGN2;IL32;CORO1A;ARHGDIB;STMN1;RAC2;IL2R...
# 55  SERPING1;C1R;COL1A2;NNMT;COL3A1;MT1E;MT1X;PLA2...
# 57  IL2RG;HLA-DRB5;TMEM176A;BIRC3;TYMP;CCL22;SYNGR...
#
#    cell_type_ontology_term_id
# 0                  CL:0000583
# 1                  CL:0000623
# 2                  CL:0002063
# 3                  CL:0000583
# 4                  CL:0002633
# 5                  CL:0002633
# 6                  CL:0002543
# 7                  CL:0000625
# 8                  CL:1001568
# 9                  CL:2000093
# 10                 CL:0000624
# 11                 CL:0002062
# 12                 CL:0002145
# 13                 CL:0000786
# 14                 CL:0002480
# 15                 CL:0000158
# 16                 CL:0000192
# 17                 CL:0000860
# 19                 CL:0000583
# 20                 CL:0000158
# 22                 CL:0002543
# 24                 CL:0002144
# 25                 CL:4028006
# 26                 CL:0002138
# 27                 CL:0002144
# 28                 CL:0019019
# 29                 CL:4028004
# 30                 CL:0005012
# 32                 CL:1000223
# 33                 CL:0002138
# 34                 CL:0002399
# 37                 CL:0000186
# 38                 CL:0000236
# 39                 CL:0000097
# 40                 CL:1001603
# 42                 CL:0002063
# 44                 CL:0009089
# 46                 CL:0000077
# 48                 CL:0005006
# 49                 CL:0000583
# 51                 CL:0005012
# 53                 CL:0000784
# 54                 CL:0000084
# 55                 CL:0000057
# 57                 CL:0000451

# %%
adata.uns[MARKER_GENES] = marker_genes_df.astype(str)

# %% [markdown]
# # Check whether ENSEMBL IDs in var

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [OR4F5, AL627309.1, AL627309.3, AL627309.5, AL627309.4, AP006222.2, AL669831.2, LINC01409, FAM87B, LINC01128, LINC00115, FAM41C, AL645608.6, AL645608.2, AL645608.4, LINC02593, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.7, HES4, ISG15, AL645608.1, AGRN, AL645608.8, RNF223, C1orf159, AL390719.3, LINC01342, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, AL162741.1, UBE2J2, LINC01786, SCNN1D, ACAP3, PUSL1, INTS11, AL139287.1, CPTP, TAS1R3, DVL1, MXRA8, AURKAIP1, CCNL2, MRPL20-AS1, MRPL20, AL391244.2, ANKRD65, AL391244.1, LINC01770, VWA1, ATAD3C, ATAD3B, ATAD3A, TMEM240, SSU72, AL645728.1, FNDC10, AL691432.4, AL691432.2, MIB2, MMP23B, CDK11B, FO704657.1, SLC35E2B, CDK11A, SLC35E2A, NADK, GNB1, AL109917.1, CALML6, TMEM52, CFAP74, AL391845.2, GABRD, AL391845.1, PRKCZ, AL590822.2, PRKCZ-AS1, FAAP20, AL590822.1, SKI, AL590822.3, MORN1, AL589739.1, AL513477.2, RER1, PEX10, PLCH2, AL139246.1, AL139246.4, ...]
#
# [30669 rows x 0 columns]

# %%
gene_names = pd.read_csv(ENSEMBL_ID_PATH, sep='\t', header=None, names=['gene_id', 'gene_name', 'feature_type'])

gene_names
# Out:
#                gene_id         gene_name      feature_type
# 0      ENSG00000243485       MIR1302-2HG   Gene Expression
# 1      ENSG00000237613           FAM138A   Gene Expression
# 2      ENSG00000186092             OR4F5   Gene Expression
# 3      ENSG00000238009        AL627309.1   Gene Expression
# 4      ENSG00000239945        AL627309.3   Gene Expression
# ...                ...               ...               ...
# 36653       Podoplanin  Podoplanin_A0127  Antibody Capture
# 36654           VEGFR3      VEGFR3_A0865  Antibody Capture
# 36655            CD186       CD186_A0804  Antibody Capture
# 36656             CCR5        CCR5_A0141  Antibody Capture
# 36657             CD16        CD16_A0083  Antibody Capture
#
# [36658 rows x 3 columns]

# %%
gene_names
# Out:
#                gene_id         gene_name      feature_type
# 0      ENSG00000243485       MIR1302-2HG   Gene Expression
# 1      ENSG00000237613           FAM138A   Gene Expression
# 2      ENSG00000186092             OR4F5   Gene Expression
# 3      ENSG00000238009        AL627309.1   Gene Expression
# 4      ENSG00000239945        AL627309.3   Gene Expression
# ...                ...               ...               ...
# 36653       Podoplanin  Podoplanin_A0127  Antibody Capture
# 36654           VEGFR3      VEGFR3_A0865  Antibody Capture
# 36655            CD186       CD186_A0804  Antibody Capture
# 36656             CCR5        CCR5_A0141  Antibody Capture
# 36657             CD16        CD16_A0083  Antibody Capture
#
# [36658 rows x 3 columns]

# %%
# 9 non-mapped ENSEMBL IDs
len(np.intersect1d(adata.var.index.tolist(), gene_names['gene_name'].tolist()))
# Out:
# 30660

# %%
#show non-mapped ENSEMBL IDs
non_mapped = np.setdiff1d(adata.var.index.tolist(), gene_names['gene_name'].tolist())

#remove '.1' at end of non-mapped ENSEMBL IDs
non_mapped_mod = [x[:-2] if x[-2:] == '.1' else x for x in non_mapped]

non_mapped
# Out:
# array(['ARMCX5-GPRASP2.1', 'CYB561D2.1', 'GGT1.1', 'GOLGA8M.1',
#        'HSPA14.1', 'LINC01238.1', 'MATR3.1', 'TBCE.1', 'TMSB15B.1'],
#       dtype='<U17')

# %%
# show rows in gene_names with non_mapped_mod
gene_names[gene_names['gene_name'].isin(non_mapped_mod)]
# Out:
#                gene_id       gene_name     feature_type
# 3235   ENSG00000285053            TBCE  Gene Expression
# 3237   ENSG00000284770            TBCE  Gene Expression
# 5946   ENSG00000237940       LINC01238  Gene Expression
# 5950   ENSG00000261186       LINC01238  Gene Expression
# 6504   ENSG00000114395        CYB561D2  Gene Expression
# 6507   ENSG00000271858        CYB561D2  Gene Expression
# 10565  ENSG00000280987           MATR3  Gene Expression
# 10567  ENSG00000015479           MATR3  Gene Expression
# 17692  ENSG00000284024          HSPA14  Gene Expression
# 17693  ENSG00000187522          HSPA14  Gene Expression
# 25271  ENSG00000188626         GOLGA8M  Gene Expression
# 25272  ENSG00000261480         GOLGA8M  Gene Expression
# 34714  ENSG00000286070            GGT1  Gene Expression
# 34716  ENSG00000100031            GGT1  Gene Expression
# 35965  ENSG00000271147  ARMCX5-GPRASP2  Gene Expression
# 35970  ENSG00000286237  ARMCX5-GPRASP2  Gene Expression
# 36001  ENSG00000158427         TMSB15B  Gene Expression
# 36004  ENSG00000269226         TMSB15B  Gene Expression

# %%
# change gene_name in row of non_unique gene names to unmapped
gene_names.loc[gene_names['gene_id'] == 'ENSG00000285053', 'gene_name'] = 'TBCE.1'
gene_names.loc[gene_names['gene_id'] == 'ENSG00000261186', 'gene_name'] = 'LINC01238.1'
gene_names.loc[gene_names['gene_id'] == 'ENSG00000271858', 'gene_name'] = 'CYB561D2.1'
gene_names.loc[gene_names['gene_id'] == 'ENSG00000015479', 'gene_name'] = 'MATR3.1'
gene_names.loc[gene_names['gene_id'] == 'ENSG00000284024', 'gene_name'] = 'HSPA14.1'
gene_names.loc[gene_names['gene_id'] == 'ENSG00000261480', 'gene_name'] = 'GOLGA8M.1'
gene_names.loc[gene_names['gene_id'] == 'ENSG00000286070', 'gene_name'] = 'GGT1.1'
gene_names.loc[gene_names['gene_id'] == 'ENSG00000286237', 'gene_name'] = 'ARMCX5-GPRASP2.1'
gene_names.loc[gene_names['gene_id'] == 'ENSG00000269226', 'gene_name'] = 'TMSB15B.1'

# %%
np.setdiff1d(adata.var.index.tolist(), gene_names['gene_name'].tolist())
# Out:
# array([], dtype='<U17')

# %%
ensembl_dict = dict(zip(gene_names['gene_name'], gene_names['gene_id']))
ensembl_dict
# Out:
# {'MIR1302-2HG': 'ENSG00000243485',
#  'FAM138A': 'ENSG00000237613',
#  'OR4F5': 'ENSG00000186092',
#  'AL627309.1': 'ENSG00000238009',
#  'AL627309.3': 'ENSG00000239945',
#  'AL627309.2': 'ENSG00000239906',
#  'EBNA1BP2': 'ENSG00000117395',
#  'CFAP57': 'ENSG00000243710',
#  'TMEM125': 'ENSG00000179178',
#  'C1orf210': 'ENSG00000253313',
#  'TIE1': 'ENSG00000066056',
#  'MPL': 'ENSG00000117400',
#  'AL139289.3': 'ENSG00000287113',
#  'AL139289.2': 'ENSG00000234694',
#  'CDC20': 'ENSG00000117399',
#  'ELOVL1': 'ENSG00000066322',
#  'MED8': 'ENSG00000159479',
#  'AL139289.1': 'ENSG00000229431',
#  'SZT2': 'ENSG00000198198',
#  'SZT2-AS1': 'ENSG00000229372',
#  'HYI': 'ENSG00000178922',
#  'HYI-AS1': 'ENSG00000229348',
#  'PTPRF': 'ENSG00000142949',
#  'KDM4A': 'ENSG00000066135',
#  'KDM4A-AS1': 'ENSG00000236200',
#  'ST3GAL3': 'ENSG00000126091',
#  'AL451062.1': 'ENSG00000229444',
#  'ARTN': 'ENSG00000117407',
#  'AL357079.1': 'ENSG00000237950',
#  'IPO13': 'ENSG00000117408',
#  'AL357079.2': 'ENSG00000285649',
#  'DPH2': 'ENSG00000132768',
#  'ATP6V0B': 'ENSG00000117410',
#  'B4GALT2': 'ENSG00000117411',
#  'CCDC24': 'ENSG00000159214',
#  'SLC6A9': 'ENSG00000196517',
#  'AL139220.2': 'ENSG00000230615',
#  'KLF17': 'ENSG00000171872',
#  'KLF18': 'ENSG00000283039',
#  'DMAP1': 'ENSG00000178028',
#  'ERI3': 'ENSG00000117419',
#  'ERI3-IT1': 'ENSG00000233602',
#  'RNF220': 'ENSG00000187147',
#  'TMEM53': 'ENSG00000126106',
#  'ARMH1': 'ENSG00000198520',
#  'KIF2C': 'ENSG00000142945',
#  'AL592166.1': 'ENSG00000225721',
#  'RPS8': 'ENSG00000142937',
#  'BEST4': 'ENSG00000142959',
#  'PLK3': 'ENSG00000173846',
#  'TCTEX1D4': 'ENSG00000188396',
#  'BTBD19': 'ENSG00000222009',
#  'PTCH2': 'ENSG00000117425',
#  'EIF2B3': 'ENSG00000070785',
#  'HECTD3': 'ENSG00000126107',
#  'UROD': 'ENSG00000126088',
#  'ZSWIM5': 'ENSG00000162415',
#  'LINC01144': 'ENSG00000281912',
#  'HPDL': 'ENSG00000186603',
#  'MUTYH': 'ENSG00000132781',
#  'TOE1': 'ENSG00000132773',
#  'TESK2': 'ENSG00000070759',
#  'CCDC163': 'ENSG00000280670',
#  'MMACHC': 'ENSG00000132763',
#  'PRDX1': 'ENSG00000117450',
#  'AKR1A1': 'ENSG00000117448',
#  'NASP': 'ENSG00000132780',
#  'CCDC17': 'ENSG00000159588',
#  'GPBP1L1': 'ENSG00000159592',
#  'TMEM69': 'ENSG00000159596',
#  'IPP': 'ENSG00000197429',
#  'AL604028.1': 'ENSG00000230896',
#  ...}

# %%
feature_dict = dict(zip(gene_names['gene_name'], gene_names['feature_type']))

# %%
adata.var['gene_symbol'] = adata.var.index
adata.var['ensembl_id'] = adata.var['gene_symbol'].map(ensembl_dict)
adata.var['feature_type'] = adata.var['gene_symbol'].map(feature_dict)
adata.var.index.name = 'index'

adata.var
# Out:
#            gene_symbol             ensembl_id     feature_type
# index
# OR4F5            OR4F5        ENSG00000186092  Gene Expression
# AL627309.1  AL627309.1        ENSG00000238009  Gene Expression
# AL627309.3  AL627309.3        ENSG00000239945  Gene Expression
# AL627309.5  AL627309.5        ENSG00000241860  Gene Expression
# AL627309.4  AL627309.4        ENSG00000241599  Gene Expression
# ...                ...                    ...              ...
# AC023491.2  AC023491.2        ENSG00000278633  Gene Expression
# AC007325.1  AC007325.1        ENSG00000276017  Gene Expression
# AC007325.4  AC007325.4        ENSG00000278817  Gene Expression
# AC007325.2  AC007325.2        ENSG00000277196  Gene Expression
# Sars-CoV2    Sars-CoV2  Sars-CoV2_NC_045512.2  Gene Expression
#
# [30669 rows x 3 columns]

# %%
adata.var['ensembl_id'].isna().sum()
# Out:
# 0

# %%
adata.var['gene_symbol'].isna().sum()
# Out:
# 0

# %%
adata.var['feature_type'].isna().sum()
# Out:
# 0

# %%
adata.var = adata.var.astype(str)

adata.var.index = adata.var.index.astype(str)

# %%
adata.var
# Out:
#            gene_symbol             ensembl_id     feature_type
# index
# OR4F5            OR4F5        ENSG00000186092  Gene Expression
# AL627309.1  AL627309.1        ENSG00000238009  Gene Expression
# AL627309.3  AL627309.3        ENSG00000239945  Gene Expression
# AL627309.5  AL627309.5        ENSG00000241860  Gene Expression
# AL627309.4  AL627309.4        ENSG00000241599  Gene Expression
# ...                ...                    ...              ...
# AC023491.2  AC023491.2        ENSG00000278633  Gene Expression
# AC007325.1  AC007325.1        ENSG00000276017  Gene Expression
# AC007325.4  AC007325.4        ENSG00000278817  Gene Expression
# AC007325.2  AC007325.2        ENSG00000277196  Gene Expression
# Sars-CoV2    Sars-CoV2  Sars-CoV2_NC_045512.2  Gene Expression
#
# [30669 rows x 3 columns]

# %%
adata.var.dtypes
# Out:
# gene_symbol     object
# ensembl_id      object
# feature_type    object
# dtype: object

# %%
adata.obs.columns
# Out:
# Index(['donor_id', 'nCount_RNA', 'nFeature_RNA', 'nCount_ADT', 'percent.mt',
#        'predicted.ann_level_1', 'predicted.ann_level_2',
#        'predicted.ann_level_3', 'predicted.ann_level_4',
#        'predicted.ann_level_5', 'predicted.ann_finest_level',
#        'annotation_type', 'ident', 'sample_ID', 'protocol_URL', 'institute',
#        'sample_collection_site', 'sample_collection_relative_time_point',
#        'library_ID', 'library_ID_repository', 'author_batch_notes',
#        'organism_ontology_term_id', 'manner_of_death', 'sample_source',
#        'sex_ontology_term_id', 'sample_collection_method', 'tissue_type',
#        'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text',
#        'sample_preservation_method', 'suspension_type', 'cell_enrichment',
#        'cell_viability_percentage', 'cell_number_loaded',
#        'sample_collection_year', 'assay_ontology_term_id',
#        'library_preparation_batch', 'library_sequencing_run',
#        'sequenced_fragment', 'sequencing_platform', 'is_primary_data',
#        'reference_genome', 'gene_annotation_version', 'alignment_software',
#        'intron_inclusion', 'disease_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id',
#        'development_stage_ontology_term_id', 'author_cell_type',
#        'cell_type_ontology_term_id'],
#       dtype='object')

# %%
adata.uns[MARKER_GENES].dtypes
# Out:
# author_cell_type              object
# author_cell_type_markers      object
# cell_type_ontology_term_id    object
# dtype: object

# %% [markdown]
# # Check raw data

# %%
# make checks for adata before saving raw

string_cols = ['cell_number_loaded', 'library_sequencing_run']

for col in string_cols:
    adata.obs[col] = adata.obs[col].astype(str)

numeric_cols = ['nCount_RNA', 'nFeature_RNA', 'nCount_ADT', 'percent.mt',
    'cell_viability_percentage', 'sample_collection_year',
    'manner_of_death']

for col in numeric_cols:
    adata.obs[col] = pd.to_numeric(adata.obs[col], errors='coerce')

# Make df indices str
adata.obs.index = adata.obs.index.astype(str)
adata.var.index = adata.var.index.astype(str)
adata.var_names = adata.var_names.astype(str)

adata.var = adata.var.astype(str)

# %%
for col in adata.obs.columns:
    print(f"Column: {col}")
    print(adata.obs[col].dtype)
    print(adata.obs[col].value_counts(dropna=False))
    print("------------------------------------")
# Out:
# Column: donor_id
# category
# D116    11182
# D291     9790
# D312     9700
# D122     8721
# D239     8041
# D404     7855
# D373     6623
# D341     6526
# D292     6251
# D305     6123
# D356     5894
# D271     5559
# D307     4538
# D391     4128
# D403     3853
# D376     3217
# D283     2599
# Name: donor_id, dtype: int64
# ------------------------------------
# Column: nCount_RNA
# float64
# 577.0      74
# 600.0      63
# 578.0      63
# 584.0      62
# 575.0      61
#            ..
# 27297.0     1
# 63452.0     1
# 19881.0     1
# 71064.0     1
# 23410.0     1
# Name: nCount_RNA, Length: 35134, dtype: int64
# ------------------------------------
# Column: nFeature_RNA
# Int32
# 430     98
# 391     93
# 442     91
# 396     90
# 389     90
#         ..
# 8452     1
# 8556     1
# 7817     1
# 7316     1
# <NA>     0
# Name: nFeature_RNA, Length: 7452, dtype: Int64
# ------------------------------------
# Column: nCount_ADT
# float64
# 625.0      164
# 640.0      160
# 633.0      155
# 678.0      153
# 604.0      152
#           ...
# 4305.0       1
# 3875.0       1
# 3226.0       1
# 7674.0       1
# 19199.0      1
# Name: nCount_ADT, Length: 4110, dtype: int64
# ------------------------------------
# Column: percent.mt
# float64
# 12.500000    38
# 8.333333     29
# 10.000000    27
# 9.090909     25
# 16.666667    24
#              ..
# 5.922438      1
# 18.592965     1
# 13.510101     1
# 8.378049      1
# 2.565973      1
# Name: percent.mt, Length: 103877, dtype: int64
# ------------------------------------
# Column: predicted.ann_level_1
# category
# Immune         93435
# Epithelial      6997
# Endothelial     6733
# Stroma          3435
# Name: predicted.ann_level_1, dtype: int64
# ------------------------------------
# Column: predicted.ann_level_2
# category
# Myeloid                74680
# Lymphoid               18798
# Blood vessels           6531
# Alveolar epithelium     5295
# Fibroblast lineage      2142
# Airway epithelium       1590
# Smooth muscle           1300
# Lymphatic EC             263
# Mesothelium                1
# Name: predicted.ann_level_2, dtype: int64
# ------------------------------------
# Column: predicted.ann_level_3
# category
# Macrophages                     41119
# Monocytes                       31503
# T cell lineage                  12325
# Innate lymphoid cell NK          5322
# EC capillary                     4603
# AT2                              3145
# Fibroblasts                      2073
# AT1                              1745
# B cell lineage                   1664
# None                             1317
# Dendritic cells                  1231
# EC venous                        1018
# EC arterial                       984
# Mast cells                        709
# Secretory                         653
# Multiciliated lineage             511
# Basal                             309
# Lymphatic EC mature               194
# Myofibroblasts                     81
# Lymphatic EC differentiating       70
# SM activated stress response       14
# Rare                               10
# Name: predicted.ann_level_3, dtype: int64
# ------------------------------------
# Column: predicted.ann_level_4
# category
# Interstitial macrophages     28928
# Classical monocytes          27578
# Alveolar macrophages         12419
# None                          9178
# CD8 T cells                   9049
# NK cells                      5328
# EC general capillary          3923
# Non-classical monocytes       3416
# CD4 T cells                   2559
# Alveolar fibroblasts          1505
# DC2                           1215
# B cells                       1155
# EC aerocyte capillary          790
# EC venous pulmonary            596
# Plasma cells                   534
# Multiciliated                  516
# Transitional Club-AT2          480
# EC venous systemic             406
# Adventitial fibroblasts        228
# Basal resting                  218
# Club                           187
# Pericytes                      171
# Peribronchial fibroblasts       87
# T cells proliferating           32
# AT2 proliferating               25
# Suprabasal                      24
# Migratory DCs                   19
# Plasmacytoid DCs                15
# Ionocyte                         9
# Goblet                           4
# Deuterosomal                     3
# Neuroendocrine                   2
# Subpleural fibroblasts           1
# Name: predicted.ann_level_4, dtype: int64
# ------------------------------------
# Column: predicted.ann_level_5
# category
# None                            87947
# Monocyte-derived Mφ             19688
# Interstitial Mφ perivascular     2307
# Multiciliated (non-nasal)         428
# Alveolar Mφ proliferating         152
# Club (non-nasal)                   61
# Alveolar Mφ CCL3+                   9
# Club (nasal)                        3
# Goblet (nasal)                      3
# Alveolar Mφ MT-positive             2
# Name: predicted.ann_level_5, dtype: int64
# ------------------------------------
# Column: predicted.ann_finest_level
# category
# Classical monocytes             28301
# Monocyte-derived Mφ             22705
# Alveolar macrophages            13493
# CD8 T cells                      9086
# NK cells                         5328
# EC general capillary             4053
# Non-classical monocytes          3752
# Interstitial Mφ perivascular     3735
# AT2                              3130
# CD4 T cells                      2920
# AT1                              1994
# Alveolar fibroblasts             1521
# DC2                              1364
# Smooth muscle                    1347
# B cells                          1155
# EC arterial                       990
# EC aerocyte capillary             790
# Mast cells                        713
# EC venous pulmonary               597
# Plasma cells                      534
# Transitional Club-AT2             491
# Multiciliated (non-nasal)         461
# EC venous systemic                411
# Basal resting                     319
# Adventitial fibroblasts           237
# Lymphatic EC mature               195
# Pericytes                         184
# Alveolar Mφ proliferating         160
# Club (nasal)                      131
# Myofibroblasts                     98
# Peribronchial fibroblasts          89
# Club (non-nasal)                   72
# Lymphatic EC differentiating       71
# T cells proliferating              32
# Suprabasal                         25
# AT2 proliferating                  25
# Migratory DCs                      19
# Plasmacytoid DCs                   15
# SM activated stress response       14
# Multiciliated (nasal)              11
# Ionocyte                           10
# Alveolar Mφ CCL3+                   9
# Deuterosomal                        3
# Goblet (nasal)                      3
# Alveolar Mφ MT-positive             2
# Neuroendocrine                      2
# Mesothelium                         2
# Subpleural fibroblasts              1
# Name: predicted.ann_finest_level, dtype: int64
# ------------------------------------
# Column: annotation_type
# category
# Automated, Seurat_5.0.3, Azimuth_0.5.0, Lung v2 (HLCA)    110600
# Name: annotation_type, dtype: int64
# ------------------------------------
# Column: ident
# category
# Classical monocytes             28301
# Monocyte-derived Mφ             22705
# Alveolar macrophages            13493
# CD8 T cells                      9086
# NK cells                         5328
# EC general capillary             4053
# Non-classical monocytes          3752
# Interstitial Mφ perivascular     3735
# AT2                              3130
# CD4 T cells                      2920
# AT1                              1994
# Alveolar fibroblasts             1521
# DC2                              1364
# Smooth muscle                    1347
# B cells                          1155
# EC arterial                       990
# EC aerocyte capillary             790
# Mast cells                        713
# EC venous pulmonary               597
# Plasma cells                      534
# Transitional Club-AT2             491
# Multiciliated (non-nasal)         461
# EC venous systemic                411
# Basal resting                     319
# Adventitial fibroblasts           237
# Lymphatic EC mature               195
# Pericytes                         184
# Alveolar Mφ proliferating         160
# Club (nasal)                      131
# Myofibroblasts                     98
# Peribronchial fibroblasts          89
# Club (non-nasal)                   72
# Lymphatic EC differentiating       71
# T cells proliferating              32
# AT2 proliferating                  25
# Suprabasal                         25
# Migratory DCs                      19
# Plasmacytoid DCs                   15
# SM activated stress response       14
# Multiciliated (nasal)              11
# Ionocyte                           10
# Alveolar Mφ CCL3+                   9
# Goblet (nasal)                      3
# Deuterosomal                        3
# Alveolar Mφ MT-positive             2
# Mesothelium                         2
# Neuroendocrine                      2
# Subpleural fibroblasts              1
# Name: ident, dtype: int64
# ------------------------------------
# Column: sample_ID
# category
# D116-RML-MIX-2    11182
# D291-RUL-MIX-3     9790
# D312-RUL-MIX-3     9700
# D122-RML-MIX-2     8721
# D239-CBL-MIX-3     8041
# D404-CBL-MIX-2     7855
# D373-RUL-MIX-2     6623
# D341-RUL-MIX-2     6526
# D292-RUL-MIX-3     6251
# D305-RUL-MIX-2     6123
# D356-RUL-MIX-3     5894
# D271-RML-MIX-2     5559
# D307-CBL-MIX-2     4538
# D391-CBL-MIX-2     4128
# D403-RUL-MIX-2     3853
# D376-RUL-MIX-4     3217
# D283-RML-MIX-2     2599
# Name: sample_ID, dtype: int64
# ------------------------------------
# Column: protocol_URL
# category
# https://www.protocols.io/view/lungmap2-urmc-cellular-indexing-of-transcriptomes-81wgbzzyqgpk/v1    110600
# Name: protocol_URL, dtype: int64
# ------------------------------------
# Column: institute
# category
# University of Rochester    110600
# Name: institute, dtype: int64
# ------------------------------------
# Column: sample_collection_site
# category
# BRINDL_site_2    110600
# Name: sample_collection_site, dtype: int64
# ------------------------------------
# Column: sample_collection_relative_time_point
# category
# N/A    110600
# Name: sample_collection_relative_time_point, dtype: int64
# ------------------------------------
# Column: library_ID
# category
# A5        11182
# A20        9790
# A10        9700
# A23        8721
# A36        8041
# A44        7855
# A13        6623
# A31        6526
# A17        6251
# A27        6123
# A15        5894
# A1         5559
# A40        4538
# A38        4128
# A4         3853
# Pilot1     3217
# A35        2599
# Name: library_ID, dtype: int64
# ------------------------------------
# Column: library_ID_repository
# category
# N/A    110600
# Name: library_ID_repository, dtype: int64
# ------------------------------------
# Column: author_batch_notes
# category
# N/A    110600
# Name: author_batch_notes, dtype: int64
# ------------------------------------
# Column: organism_ontology_term_id
# category
# NCBITaxon:9606    110600
# Name: organism_ontology_term_id, dtype: int64
# ------------------------------------
# Column: manner_of_death
# int64
# 0    110600
# Name: manner_of_death, dtype: int64
# ------------------------------------
# Column: sample_source
# category
# postmortem donor    110600
# Name: sample_source, dtype: int64
# ------------------------------------
# Column: sex_ontology_term_id
# category
# PATO:0000384    61465
# PATO:0000383    49135
# Name: sex_ontology_term_id, dtype: int64
# ------------------------------------
# Column: sample_collection_method
# category
# surgical resection    110600
# Name: sample_collection_method, dtype: int64
# ------------------------------------
# Column: tissue_type
# category
# tissue    110600
# Name: tissue_type, dtype: int64
# ------------------------------------
# Column: sampled_site_condition
# category
# healthy    110600
# Name: sampled_site_condition, dtype: int64
# ------------------------------------
# Column: tissue_ontology_term_id
# category
# UBERON:0002170    57977
# UBERON:0002174    28061
# UBERON:0006518    24562
# Name: tissue_ontology_term_id, dtype: int64
# ------------------------------------
# Column: tissue_free_text
# category
# Mixture of right upper lung lobe cells               48187
# Mixture of right middle and upper lung lobe cells    34352
# Mixture of right middle lung lobe cells              28061
# Name: tissue_free_text, dtype: int64
# ------------------------------------
# Column: sample_preservation_method
# category
# frozen at -80C    110600
# Name: sample_preservation_method, dtype: int64
# ------------------------------------
# Column: suspension_type
# category
# cell    110600
# Name: suspension_type, dtype: int64
# ------------------------------------
# Column: cell_enrichment
# category
# CL:0000000    110600
# Name: cell_enrichment, dtype: int64
# ------------------------------------
# Column: cell_viability_percentage
# int64
# 50    16041
# 54    15896
# 52    11453
# 63    11182
# 45    10379
# 59     9700
# 66     8721
# 44     6727
# 40     6623
# 42     6123
# 20     4538
# 32     3217
# Name: cell_viability_percentage, dtype: int64
# ------------------------------------
# Column: cell_number_loaded
# category
# NaN    110600
# Name: cell_number_loaded, dtype: int64
# ------------------------------------
# Column: sample_collection_year
# int64
# 2020    44560
# 2021    38096
# 2017    19903
# 2019     8041
# Name: sample_collection_year, dtype: int64
# ------------------------------------
# Column: assay_ontology_term_id
# category
# EFO_0009294    110600
# Name: assay_ontology_term_id, dtype: int64
# ------------------------------------
# Column: library_preparation_batch
# category
# Pryhuber_CITEseq_012022    16041
# Pryhuber_CITEseq_012722    12649
# Pryhuber_CITEseq_011422    12517
# Pryhuber_CITEseq_010722    11182
# Pryhuber_CITEseq_020322    10640
# Pryhuber_CITEseq_011322     9700
# Pryhuber_CITEseq_010622     9412
# Pryhuber_CITEseq_012122     8721
# Pryhuber_CITEseq_020422     8666
# Pryhuber_CITEseq_021422     7855
# Pryhuber_CITEseq_113021     3217
# Name: library_preparation_batch, dtype: int64
# ------------------------------------
# Column: library_sequencing_run
# category
# 20822       24762
# 012622_B    22217
# 012622_A    20594
# 22122       19306
# 21622       12649
# 30222        7855
# 120921       3217
# Name: library_sequencing_run, dtype: int64
# ------------------------------------
# Column: sequenced_fragment
# category
# 3 prime tag    110600
# Name: sequenced_fragment, dtype: int64
# ------------------------------------
# Column: sequencing_platform
# category
# EFO_0008637    110600
# Name: sequencing_platform, dtype: int64
# ------------------------------------
# Column: is_primary_data
# category
# true    110600
# Name: is_primary_data, dtype: int64
# ------------------------------------
# Column: reference_genome
# category
# GRCh38    110600
# Name: reference_genome, dtype: int64
# ------------------------------------
# Column: gene_annotation_version
# category
# GENCODE v32 / Ensembl 98 + SARS-CoV-2 (ncbi nuccore MT547814)    110600
# Name: gene_annotation_version, dtype: int64
# ------------------------------------
# Column: alignment_software
# category
# cellranger 6.0.1    110600
# Name: alignment_software, dtype: int64
# ------------------------------------
# Column: intron_inclusion
# category
# no    110600
# Name: intron_inclusion, dtype: int64
# ------------------------------------
# Column: disease_ontology_term_id
# category
# PATO:0000461    54390
# NCIT:C173483    37734
# NCIT:C173484    18476
# Name: disease_ontology_term_id, dtype: int64
# ------------------------------------
# Column: self_reported_ethnicity_ontology_term_id
# category
# White               56667
# Black/AA            23761
# Hispanic            15247
# More than 1 race     7855
# Asian                7070
# Name: self_reported_ethnicity_ontology_term_id, dtype: int64
# ------------------------------------
# Column: development_stage_ontology_term_id
# category
# HsapDv:0000240     21785
# HsapDv:0000241     21239
# HsapDv:0000237     19258
# HsapDv:0000238     16762
# HsapDv:0000239     15035
# HsapDv:0000264     12393
# HsapDv:0000268      4128
# Name: development_stage_ontology_term_id, dtype: int64
# ------------------------------------
# Column: author_cell_type
# category
# Classical monocytes             28301
# Monocyte-derived Mφ             22705
# Alveolar macrophages            13493
# CD8 T cells                      9086
# NK cells                         5328
# EC general capillary             4053
# Non-classical monocytes          3752
# Interstitial Mφ perivascular     3735
# AT2                              3130
# CD4 T cells                      2920
# AT1                              1994
# Alveolar fibroblasts             1521
# DC2                              1364
# Smooth muscle                    1347
# B cells                          1155
# EC arterial                       990
# EC aerocyte capillary             790
# Mast cells                        713
# EC venous pulmonary               597
# Plasma cells                      534
# Transitional Club-AT2             491
# Multiciliated (non-nasal)         461
# EC venous systemic                411
# Basal resting                     319
# Adventitial fibroblasts           237
# Lymphatic EC mature               195
# Pericytes                         184
# Alveolar Mφ proliferating         160
# Club (nasal)                      131
# Myofibroblasts                     98
# Peribronchial fibroblasts          89
# Club (non-nasal)                   72
# Lymphatic EC differentiating       71
# T cells proliferating              32
# AT2 proliferating                  25
# Suprabasal                         25
# Migratory DCs                      19
# Plasmacytoid DCs                   15
# SM activated stress response       14
# Multiciliated (nasal)              11
# Ionocyte                           10
# Alveolar Mφ CCL3+                   9
# Goblet (nasal)                      3
# Deuterosomal                        3
# Alveolar Mφ MT-positive             2
# Mesothelium                         2
# Neuroendocrine                      2
# Subpleural fibroblasts              1
# Name: author_cell_type, dtype: int64
# ------------------------------------
# Column: cell_type_ontology_term_id
# category
# CL:0000860    28301
# CL:0000861    22705
# CL:0000583    13664
# CL:0000625     9086
# CL:0000623     5328
# CL:0002144     4843
# CL:0000875     3752
# CL:1001603     3735
# CL:0002063     3155
# CL:0000624     2920
# CL:0002062     1994
# CL:4028004     1521
# CL:0002399     1364
# CL:0019019     1347
# CL:0000236     1155
# CL:0002543     1008
# CL:1001568      990
# CL:0000097      713
# CL:0000786      534
# CL:0002632      491
# CL:0002145      461
# CL:0002633      344
# CL:0002138      266
# CL:4028006      237
# CL:0000158      203
# CL:0009089      184
# CL:0000186       98
# CL:2000093       89
# CL:0000084       32
# CL:0000451       19
# CL:0000784       15
# CL:0005012       14
# CL:0000192       14
# CL:0005006       10
# CL:0002480        3
# CL:0000077        2
# CL:1000223        2
# CL:0000057        1
# Name: cell_type_ontology_term_id, dtype: int64
# ------------------------------------

# %%
adata.obs.dtypes
# Out:
# donor_id                                    category
# nCount_RNA                                   float64
# nFeature_RNA                                   Int32
# nCount_ADT                                   float64
# percent.mt                                   float64
# predicted.ann_level_1                       category
# predicted.ann_level_2                       category
# predicted.ann_level_3                       category
# predicted.ann_level_4                       category
# predicted.ann_level_5                       category
# predicted.ann_finest_level                  category
# annotation_type                             category
# ident                                       category
# sample_ID                                   category
# protocol_URL                                category
# institute                                   category
# sample_collection_site                      category
# sample_collection_relative_time_point       category
# library_ID                                  category
# library_ID_repository                       category
# author_batch_notes                          category
# organism_ontology_term_id                   category
# manner_of_death                                int64
# sample_source                               category
# sex_ontology_term_id                        category
# sample_collection_method                    category
# tissue_type                                 category
# sampled_site_condition                      category
# tissue_ontology_term_id                     category
# tissue_free_text                            category
# sample_preservation_method                  category
# suspension_type                             category
# cell_enrichment                             category
# cell_viability_percentage                      int64
# cell_number_loaded                          category
# sample_collection_year                         int64
# assay_ontology_term_id                      category
# library_preparation_batch                   category
# library_sequencing_run                      category
# sequenced_fragment                          category
# sequencing_platform                         category
# is_primary_data                             category
# reference_genome                            category
# gene_annotation_version                     category
# alignment_software                          category
# intron_inclusion                            category
# disease_ontology_term_id                    category
# self_reported_ethnicity_ontology_term_id    category
# development_stage_ontology_term_id          category
# author_cell_type                            category
# cell_type_ontology_term_id                  category
# dtype: object

# %%
adata.X.toarray().max()
# Out:
# 15619.0

# %%
adata.X = adata.X.astype(np.int64)

# %%
adata.raw = adata

# %%
adata.X
# Out:
# <110600x30669 sparse matrix of type '<class 'numpy.int64'>'
# 	with 292010395 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <110600x30669 sparse matrix of type '<class 'numpy.int64'>'
# 	with 292010395 stored elements in Compressed Sparse Row format>

# %%
adata.X.toarray().max()
# Out:
# 15619

# %%
adata.raw.X.toarray().max()
# Out:
# 15619

# %% [markdown]
# ## Validation result
#
# ### UNS Validation
# - OK: Tier 1 UNS Google Sheet
# - OK: Tier 1 UNS AnnData Object
#
# ### OBS Validation
# - OK: Tier 1 OBS Google Sheet
# - OK: Tier 1 OBS AnnData Object

# %% [markdown]
# # Data Submission Status
#
# - CHECK: Data in X
# - CHECK: Tier 1 Metadata in OBS
# - CHECK: Cell Ontology IDs in OBS
# - CHECK: Author cell type in OBS
# - CHECK: Marker genes in UNS
# - CHECK: ENSEMBL IDs in var
#
#
# ### REVISION
#
# DONE

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"))
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"))
