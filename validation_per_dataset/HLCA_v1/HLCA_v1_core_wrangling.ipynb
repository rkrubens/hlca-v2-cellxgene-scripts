# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import anndata2ri
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"
# Out:
# Warning message:
# package ‘methods’ was built under R version 4.3.3
# During startup - Warning messages:
# 1: package ‘datasets’ was built under R version 4.3.3
# 2: package ‘utils’ was built under R version 4.3.3
# 3: package ‘grDevices’ was built under R version 4.3.3
# 4: package ‘graphics’ was built under R version 4.3.3
# 5: package ‘stats’ was built under R version 4.3.3

# %%
DATASET_ID = "HLCA_v1_core"
H5AD_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/{DATASET_ID}.h5ad"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'

# %% [markdown]
# # Load data

# %%
adata = sc.read_h5ad(H5AD_PATH)

# %%
adata.obs['dataset'].value_counts(dropna=False)
# Out:
# Banovich_Kropski_2020        121894
# Barbry_Leroy_2020             74487
# Nawijn_2021                   70402
# Misharin_2021                 64843
# Krasnow_2020                  60982
# Misharin_Budinger_2018        41220
# Meyer_2019                    35554
# Jain_Misharin_2021_10Xv2      33135
# Seibold_2020_10Xv3            21466
# Lafyatis_Rojas_2019_10Xv2     21260
# Jain_Misharin_2021_10Xv1      12422
# Teichmann_Meyer_2019          12231
# Seibold_2020_10Xv2            12127
# Lafyatis_Rojas_2019_10Xv1      2921
# Name: dataset, dtype: int64

# %%
barcodes = [x+"-HLCA_v1_core" for x in adata.obs.index]
dataset_ids = adata.obs['dataset']

df = pd.DataFrame({'barcode': barcodes, 'dataset_id': dataset_ids})

df.to_csv("/ictstr01/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/HLCA_v1_core_barcodes.csv", index=False)

# %%
adata.obs.columns
# Out:
# Index(['suspension_type', 'donor_id', 'is_primary_data',
#        'assay_ontology_term_id', 'cell_type_ontology_term_id',
#        'development_stage_ontology_term_id', 'disease_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id', 'tissue_ontology_term_id',
#        'organism_ontology_term_id', 'sex_ontology_term_id', 'BMI',
#        'age_or_mean_of_age_range', 'age_range', 'anatomical_region_ccf_score',
#        'ann_coarse_for_GWAS_and_modeling', 'ann_finest_level', 'ann_level_1',
#        'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5',
#        'cause_of_death', 'dataset', 'entropy_dataset_leiden_3',
#        'entropy_original_ann_level_1_leiden_3',
#        'entropy_original_ann_level_2_clean_leiden_3',
#        'entropy_original_ann_level_3_clean_leiden_3',
#        'entropy_subject_ID_leiden_3', 'fresh_or_frozen', 'leiden_1',
#        'leiden_2', 'leiden_3', 'leiden_4', 'leiden_5', 'log10_total_counts',
#        'lung_condition', 'mixed_ancestry', 'n_genes_detected',
#        'original_ann_highest_res', 'original_ann_level_1',
#        'original_ann_level_2', 'original_ann_level_3', 'original_ann_level_4',
#        'original_ann_level_5', 'original_ann_nonharmonized',
#        'reannotation_type', 'reference_genome', 'sample', 'scanvi_label',
#        'sequencing_platform', 'size_factors', 'smoking_status', 'study',
#        'subject_type', 'tissue_dissociation_protocol', 'tissue_level_2',
#        'tissue_level_3', 'tissue_sampling_method', 'tissue_type', 'cell_type',
#        'assay', 'disease', 'organism', 'sex', 'tissue',
#        'self_reported_ethnicity', 'development_stage', 'observation_joinid'],
#       dtype='object')

# %%
# show mappings between cell type annotations and cell type ontology terms
pd.set_option('display.max_rows', None)

ann_levels = [
    'ann_level_1',
    'ann_level_2',
    'ann_level_3',
    'ann_level_4',
    'ann_level_5',
    'ann_finest_level'
]

df_all = None

for ann_level in ann_levels:
    df = adata.obs[[ann_level, 'cell_type_ontology_term_id']].drop_duplicates(subset=ann_level)
    df.rename(columns={ann_level: 'cell_type_annotation'}, inplace=True)
    if ann_level == 'ann_level_1':
        df_all = df
    else:
        df_all = pd.concat([df_all, df], ignore_index=True)

df_all
# Out:
#               cell_type_annotation cell_type_ontology_term_id
# 0                           Immune                 CL:0000583
# 1                       Epithelial                 CL:0002063
# 2                      Endothelial                 CL:0002543
# 3                           Stroma                 CL:2000093
# 4                          Myeloid                 CL:0000583
# 5                         Lymphoid                 CL:0000623
# 6              Alveolar epithelium                 CL:0002063
# 7                Airway epithelium                 CL:0002633
# 8                    Blood vessels                 CL:0002543
# 9               Fibroblast lineage                 CL:2000093
# 10                   Smooth muscle                 CL:0000192
# 11                Submucosal Gland                 CL:0019001
# 12                    Lymphatic EC                 CL:0002138
# 13                     Mesothelium                 CL:0000077
# 14        Hematopoietic stem cells                 CL:0000037
# 15                     Macrophages                 CL:0000583
# 16         Innate lymphoid cell NK                 CL:0000623
# 17                             AT2                 CL:0002063
# 18                           Basal                 CL:0002633
# 19                       EC venous                 CL:0002543
# 20                  T cell lineage                 CL:0000625
# 21                     EC arterial                 CL:1001568
# 22                     Fibroblasts                 CL:2000093
# 23                             AT1                 CL:0002062
# 24           Multiciliated lineage                 CL:0002145
# 25                  B cell lineage                 CL:0000786
# 26                       Secretory                 CL:0002480
# 27    SM activated stress response                 CL:0000192
# 28                       Monocytes                 CL:0000860
# 29            Submucosal Secretory                 CL:0019001
# 30                    EC capillary                 CL:0002144
# 31             Lymphatic EC mature                 CL:0002138
# 32                            None                 CL:0019019
# 33                            Rare                 CL:1000223
# 34    Lymphatic EC differentiating                 CL:0002138
# 35                 Dendritic cells                 CL:0002399
# 36                  Myofibroblasts                 CL:0000186
# 37                      Mast cells                 CL:0000097
# 38           Smooth muscle FAM83D+                 CL:0000499
# 39      Lymphatic EC proliferating                 CL:0002138
# 40            Alveolar macrophages                 CL:0000583
# 41                        NK cells                 CL:0000623
# 42                            None                 CL:0002063
# 43                      Suprabasal                 CL:0002633
# 44                   Basal resting                 CL:0002633
# 45             EC venous pulmonary                 CL:0002543
# 46                     CD8 T cells                 CL:0000625
# 47       Peribronchial fibroblasts                 CL:2000093
# 48                     CD4 T cells                 CL:0000624
# 49                   Multiciliated                 CL:0002145
# 50                    Plasma cells                 CL:0000786
# 51                    Hillock-like                 CL:4030023
# 52                          Goblet                 CL:0002480
# 53                            Club                 CL:0000158
# 54             Classical monocytes                 CL:0000860
# 55        Interstitial macrophages                 CL:0000861
# 56                      SMG serous                 CL:0019001
# 57              EC venous systemic                 CL:0002543
# 58         Non-classical monocytes                 CL:0000875
# 59            EC general capillary                 CL:0002144
# 60         Adventitial fibroblasts                 CL:4028006
# 61           EC aerocyte capillary                 CL:0002144
# 62           Transitional Club-AT2                 CL:0002632
# 63            Alveolar fibroblasts                 CL:4028004
# 64                  Neuroendocrine                 CL:1000223
# 65                             DC2                 CL:0002399
# 66                             DC1                 CL:0000990
# 67                         B cells                 CL:0000236
# 68                      SMG mucous                 CL:0000319
# 69               AT2 proliferating                 CL:0002063
# 70                       Pericytes                 CL:0009089
# 71                        SMG duct                 CL:0000622
# 72                        Ionocyte                 CL:0005006
# 73                    Deuterosomal                 CL:0005012
# 74                            Tuft                 CL:0002075
# 75                Plasmacytoid DCs                 CL:0000784
# 76           T cells proliferating                 CL:0000084
# 77          Subpleural fibroblasts                 CL:0000057
# 78                   Migratory DCs                 CL:0000451
# 79                            None                 CL:0000583
# 80              Alveolar Mph CCL3+                 CL:0000583
# 81       Multiciliated (non-nasal)                 CL:0002145
# 82                  Goblet (nasal)                 CL:0002480
# 83                    Club (nasal)                 CL:0000158
# 84            Monocyte-derived Mph                 CL:0000861
# 85      Alveolar Mph proliferating                 CL:0000583
# 86                Club (non-nasal)                 CL:0000158
# 87          SMG serous (bronchial)                 CL:0019001
# 88                pre-TB secretory                 CL:0002632
# 89           Multiciliated (nasal)                 CL:0005012
# 90              Goblet (bronchial)                 CL:1000312
# 91   Interstitial Mph perivascular                 CL:1001603
# 92           Goblet (subsegmental)                 CL:0019003
# 93                             AT0                 CL:0010003
# 94              SMG serous (nasal)                 CL:0000313
# 95        Alveolar Mph MT-positive                 CL:0000583
# 96            Alveolar macrophages                 CL:0000583
# 97                        NK cells                 CL:0000623
# 98                             AT2                 CL:0002063
# 99              Alveolar Mph CCL3+                 CL:0000583
# 100                     Suprabasal                 CL:0002633
# 101                  Basal resting                 CL:0002633
# 102            EC venous pulmonary                 CL:0002543
# 103                    CD8 T cells                 CL:0000625
# 104                    EC arterial                 CL:1001568
# 105      Peribronchial fibroblasts                 CL:2000093
# 106                    CD4 T cells                 CL:0000624
# 107                            AT1                 CL:0002062
# 108      Multiciliated (non-nasal)                 CL:0002145
# 109                   Plasma cells                 CL:0000786
# 110                   Hillock-like                 CL:4030023
# 111                 Goblet (nasal)                 CL:0002480
# 112                   Club (nasal)                 CL:0000158
# 113   SM activated stress response                 CL:0000192
# 114            Classical monocytes                 CL:0000860
# 115           Monocyte-derived Mph                 CL:0000861
# 116     Alveolar Mph proliferating                 CL:0000583
# 117               Club (non-nasal)                 CL:0000158
# 118         SMG serous (bronchial)                 CL:0019001
# 119             EC venous systemic                 CL:0002543
# 120        Non-classical monocytes                 CL:0000875
# 121           EC general capillary                 CL:0002144
# 122        Adventitial fibroblasts                 CL:4028006
# 123            Lymphatic EC mature                 CL:0002138
# 124          EC aerocyte capillary                 CL:0002144
# 125               pre-TB secretory                 CL:0002632
# 126                  Smooth muscle                 CL:0019019
# 127           Alveolar fibroblasts                 CL:4028004
# 128          Multiciliated (nasal)                 CL:0005012
# 129             Goblet (bronchial)                 CL:1000312
# 130                 Neuroendocrine                 CL:1000223
# 131   Lymphatic EC differentiating                 CL:0002138
# 132                            DC2                 CL:0002399
# 133                            DC1                 CL:0000990
# 134                 Myofibroblasts                 CL:0000186
# 135                        B cells                 CL:0000236
# 136                     Mast cells                 CL:0000097
# 137  Interstitial Mph perivascular                 CL:1001603
# 138                     SMG mucous                 CL:0000319
# 139              AT2 proliferating                 CL:0002063
# 140          Goblet (subsegmental)                 CL:0019003
# 141                      Pericytes                 CL:0009089
# 142                            AT0                 CL:0010003
# 143                       SMG duct                 CL:0000622
# 144                    Mesothelium                 CL:0000077
# 145             SMG serous (nasal)                 CL:0000313
# 146                       Ionocyte                 CL:0005006
# 147       Alveolar Mph MT-positive                 CL:0000583
# 148          Smooth muscle FAM83D+                 CL:0000499
# 149                   Deuterosomal                 CL:0005012
# 150                           Tuft                 CL:0002075
# 151               Plasmacytoid DCs                 CL:0000784
# 152          T cells proliferating                 CL:0000084
# 153         Subpleural fibroblasts                 CL:0000057
# 154       Hematopoietic stem cells                 CL:0000037
# 155     Lymphatic EC proliferating                 CL:0002138
# 156                  Migratory DCs                 CL:0000451

# %%
df_all.to_csv('hlca_v1_annot_ontology_id_mapping_all.csv', index=False)

# %% [markdown]
# # Add comparable author cell type and ontology ID labels into obs

# %%
adata.obs[AUTHOR_CELL_TYPE] = adata.obs['ann_finest_level']
adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False)
# Out:
# Alveolar macrophages          68487
# AT2                           61429
# Suprabasal                    41158
# Basal resting                 38955
# Goblet (nasal)                35833
#                               ...
# Mesothelium                     230
# Tuft                            165
# Neuroendocrine                  159
# Hematopoietic stem cells         60
# Lymphatic EC proliferating       28
# Name: author_cell_type, Length: 61, dtype: int64

# %%
# show column names with 'ontology' in it
adata.obs[CELL_TYPE_ONTOLOGY_ID].value_counts(dropna=False)
# Out:
# CL:0002633    80113
# CL:0000583    78816
# CL:0002063    62405
# CL:0000158    36023
# CL:0002480    35833
# CL:0002145    35225
# CL:0000625    29074
# CL:0000861    28223
# CL:0002144    23205
# CL:0000624    21285
# CL:0000860    17695
# CL:0000623    16978
# CL:0002543    12975
# CL:4028006    10321
# CL:0002399     9133
# CL:0000875     8834
# CL:0002062     7937
# CL:1001568     7391
# CL:0000097     6623
# CL:0005012     5873
# CL:4028004     5182
# CL:1001603     4805
# CL:4030023     4600
# CL:0002138     4595
# CL:0000236     4511
# CL:0002632     4393
# CL:0009089     3032
# CL:0019019     2996
# CL:0000786     1773
# CL:1000312     1670
# CL:2000093     1573
# CL:0000313     1472
# CL:0010003     1440
# CL:0019001     1417
# CL:0000622     1274
# CL:0019003      968
# CL:0000186      716
# CL:0005006      561
# CL:0000192      556
# CL:0000784      552
# CL:0000319      537
# CL:0000084      500
# CL:0000499      335
# CL:0000990      322
# CL:0000451      312
# CL:0000057      276
# CL:0000077      230
# CL:0002075      165
# CL:1000223      159
# CL:0000037       60
# Name: cell_type_ontology_term_id, dtype: int64

# %% [markdown]
# # Check var

# %%
adata.var
# Out:
#                  feature_is_filtered       feature_name feature_reference  \
# ENSG00000000003                False             TSPAN6    NCBITaxon:9606
# ENSG00000000005                False               TNMD    NCBITaxon:9606
# ENSG00000000419                False               DPM1    NCBITaxon:9606
# ENSG00000000457                False              SCYL3    NCBITaxon:9606
# ENSG00000000460                False           C1orf112    NCBITaxon:9606
# ...                              ...                ...               ...
# ENSG00000283078                False  ENSG00000283078.1    NCBITaxon:9606
# ENSG00000283103                False  ENSG00000283103.5    NCBITaxon:9606
# ENSG00000283117                False            MGC4859    NCBITaxon:9606
# ENSG00000283118                False  ENSG00000283118.1    NCBITaxon:9606
# ENSG00000283125                False  ENSG00000283125.1    NCBITaxon:9606
#
#                 feature_biotype feature_length
# ENSG00000000003            gene           4530
# ENSG00000000005            gene           1476
# ENSG00000000419            gene           9276
# ENSG00000000457            gene           6883
# ENSG00000000460            gene           5970
# ...                         ...            ...
# ENSG00000283078            gene           1608
# ENSG00000283103            gene           4585
# ENSG00000283117            gene           3118
# ENSG00000283118            gene            644
# ENSG00000283125            gene            547
#
# [27957 rows x 5 columns]

# %%
adata.var['ensembl_id'] = adata.var.index.astype(str)
adata.var.rename(columns={'feature_name': 'gene_symbol'}, inplace=True)
adata.var.index.name = 'index'

adata.var
# Out:
#                  feature_is_filtered        gene_symbol feature_reference  \
# index
# ENSG00000000003                False             TSPAN6    NCBITaxon:9606
# ENSG00000000005                False               TNMD    NCBITaxon:9606
# ENSG00000000419                False               DPM1    NCBITaxon:9606
# ENSG00000000457                False              SCYL3    NCBITaxon:9606
# ENSG00000000460                False           C1orf112    NCBITaxon:9606
# ...                              ...                ...               ...
# ENSG00000283078                False  ENSG00000283078.1    NCBITaxon:9606
# ENSG00000283103                False  ENSG00000283103.5    NCBITaxon:9606
# ENSG00000283117                False            MGC4859    NCBITaxon:9606
# ENSG00000283118                False  ENSG00000283118.1    NCBITaxon:9606
# ENSG00000283125                False  ENSG00000283125.1    NCBITaxon:9606
#
#                 feature_biotype feature_length       ensembl_id
# index
# ENSG00000000003            gene           4530  ENSG00000000003
# ENSG00000000005            gene           1476  ENSG00000000005
# ENSG00000000419            gene           9276  ENSG00000000419
# ENSG00000000457            gene           6883  ENSG00000000457
# ENSG00000000460            gene           5970  ENSG00000000460
# ...                         ...            ...              ...
# ENSG00000283078            gene           1608  ENSG00000283078
# ENSG00000283103            gene           4585  ENSG00000283103
# ENSG00000283117            gene           3118  ENSG00000283117
# ENSG00000283118            gene            644  ENSG00000283118
# ENSG00000283125            gene            547  ENSG00000283125
#
# [27957 rows x 6 columns]

# %% [markdown]
# # Check raw data

# %%
adata.raw.X.toarray().max()
# Out:
# 34950.0

# %%
adata.X = adata.raw.X

# %%
adata.X = adata.X.astype(np.int32)

# %%
adata.raw = adata

# %%
adata.X
# Out:
# <584944x27957 sparse matrix of type '<class 'numpy.int32'>'
# 	with 1139652728 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <584944x27957 sparse matrix of type '<class 'numpy.int32'>'
# 	with 1139652728 stored elements in Compressed Sparse Row format>

# %%
adata.X.toarray().max()
# Out:
# 34950

# %%
adata.raw.X.toarray().max()
# Out:
# 34950

# %% [markdown]
# # Data Status
#
# - CHECK: Raw data in X
# - CHECK: Cell Ontology IDs in OBS
# - CHECK: Author cell type in OBS
# - CHECK: ENSEMBL IDs in var

# %%
adata.obs['sample_ID'] = adata.obs['sample']

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')

# %%
adata.write_zarr("/ictstr01/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision_reduced_zarr/HLCA_v1_core.zarr")
# Out:
# /home/icb/raphael.kfuri-rubens/miniconda3/envs/hlcav2-env/lib/python3.10/site-packages/zarr/creation.py:300: UserWarning: ignoring keyword argument 'maxshape'
#   warn(f"ignoring keyword argument {k!r}")

# %%
import scanpy as sc
import anndata as ad
from os.path import join

adata_1 = sc.read_h5ad(join(OUTPUT_PATH_PREREVISION, "lungMAP.h5ad"))
adata_2 = sc.read_h5ad(join(OUTPUT_PATH_PREREVISION, "Tabula_Sapiens_2022_publ.h5ad"))
# Out:
# /home/icb/raphael.kfuri-rubens/miniconda3/envs/hlcav2-env/lib/python3.10/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adatas = {'lungMAP': adata_1, 'Tabula_Sapiens_2022_publ': adata_2}

for adata in adatas.values():
    adata.var.index = adata.var['gene_symbol']
    adata.var.index.name = 'index'

# concatenate adatas with outer join

adata_merged = ad.concat(
    adatas,
    join='outer',
    label='dataset_ID',
    index_unique='_'
)

# %%
adata_1.var
# Out:
#              gene_symbol
# index
# MIR1302-2HG  MIR1302-2HG
# FAM138A          FAM138A
# OR4F5              OR4F5
# AL627309.1    AL627309.1
# AL627309.3    AL627309.3
# ...                  ...
# AC141272.1    AC141272.1
# AC023491.2    AC023491.2
# AC007325.1    AC007325.1
# AC007325.4    AC007325.4
# AC007325.2    AC007325.2
#
# [32284 rows x 1 columns]

# %%
adata_2.var
# Out:
#                 feature_type  highly_variable         means  dispersions  \
# index
# DDX11L1      Gene Expression            False  6.398244e-05     0.835044
# WASH7P       Gene Expression            False  2.274395e-03     2.442280
# MIR6859-1    Gene Expression            False  6.175251e-05     1.295335
# MIR1302-2HG  Gene Expression            False  1.372886e-04     2.656352
# MIR1302-2    Gene Expression            False  1.000000e-12          NaN
# ...                      ...              ...           ...          ...
# MT-ND6       Gene Expression            False  9.634841e-01     2.466404
# MT-TE        Gene Expression            False  1.600667e-01     1.603787
# MT-CYB       Gene Expression            False  4.367693e+00     4.765751
# MT-TT        Gene Expression            False  6.573967e-02     0.624316
# MT-TP        Gene Expression             True  4.385102e-01     2.705558
#
#              dispersions_norm      mean       std  feature_is_filtered  \
# index
# DDX11L1             -0.573947  0.000039  0.005574                False
# WASH7P               0.533203  0.001080  0.031731                False
# MIR6859-1           -0.256874  0.000033  0.005634                False
# MIR1302-2HG          0.680668  0.000048  0.008041                False
# MIR1302-2            0.000000  0.000000  1.000000                False
# ...                       ...       ...       ...                  ...
# MT-ND6               0.154140  0.590065  0.741395                False
# MT-TE               -0.044396  0.083929  0.301820                False
# MT-CYB              -0.499747  3.874830  1.104192                False
# MT-TT               -0.719108  0.040580  0.186848                False
# MT-TP                1.115482  0.204806  0.501265                False
#
#              gene_symbol feature_reference feature_biotype feature_length  \
# index
# DDX11L1          DDX11L1    NCBITaxon:9606            gene            632
# WASH7P            WASH7P    NCBITaxon:9606            gene           1351
# MIR6859-1      MIR6859-1    NCBITaxon:9606            gene             68
# MIR1302-2HG  MIR1302-2HG    NCBITaxon:9606            gene           1021
# MIR1302-2      MIR1302-2    NCBITaxon:9606            gene            138
# ...                  ...               ...             ...            ...
# MT-ND6            MT-ND6    NCBITaxon:9606            gene            525
# MT-TE              MT-TE    NCBITaxon:9606            gene             69
# MT-CYB            MT-CYB    NCBITaxon:9606            gene           1141
# MT-TT              MT-TT    NCBITaxon:9606            gene             66
# MT-TP              MT-TP    NCBITaxon:9606            gene             68
#
#                   ensembl_id
# index
# DDX11L1      ENSG00000223972
# WASH7P       ENSG00000227232
# MIR6859-1    ENSG00000278267
# MIR1302-2HG  ENSG00000243485
# MIR1302-2    ENSG00000284332
# ...                      ...
# MT-ND6       ENSG00000198695
# MT-TE        ENSG00000210194
# MT-CYB       ENSG00000198727
# MT-TT        ENSG00000210195
# MT-TP        ENSG00000210196
#
# [58482 rows x 13 columns]

# %%
adata_merged.obs['dataset_ID']
# Out:
# Donor27_Donor27_AAACGAACACCGTGCA-1_lungMAP                                                       lungMAP
# Donor27_Donor27_AAAGAACAGCGCCATC-1_lungMAP                                                       lungMAP
# Donor27_Donor27_AAAGAACCAGGCAATG-1_lungMAP                                                       lungMAP
# Donor27_Donor27_AAAGGATAGTAGCTCT-1_lungMAP                                                       lungMAP
# Donor27_Donor27_AAAGTCCCATCCGGCA-1_lungMAP                                                       lungMAP
#                                                                                           ...
# TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ    Tabula_Sapiens_2022_publ
# TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ    Tabula_Sapiens_2022_publ
# TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ    Tabula_Sapiens_2022_publ
# TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ    Tabula_Sapiens_2022_publ
# TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ    Tabula_Sapiens_2022_publ
# Name: dataset_ID, Length: 156537, dtype: category
# Categories (2, object): ['lungMAP', 'Tabula_Sapiens_2022_publ']

# %%
adata_merged.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [5S_rRNA_ENSG00000276861, 5S_rRNA_ENSG00000277411, 5S_rRNA_ENSG00000277488, 5S_rRNA_ENSG00000285609, 5S_rRNA_ENSG00000285626, 5S_rRNA_ENSG00000285674, 5S_rRNA_ENSG00000285776, 5S_rRNA_ENSG00000285912, 5_8S_rRNA_ENSG00000275877, 5_8S_rRNA_ENSG00000276871, 5_8S_rRNA_ENSG00000277739, 5_8S_rRNA_ENSG00000283274, 5_8S_rRNA_ENSG00000283291, 5_8S_rRNA_ENSG00000283568, 7SK_ENSG00000202198, 7SK_ENSG00000271394, 7SK_ENSG00000273591, 7SK_ENSG00000274303, 7SK_ENSG00000275933, 7SK_ENSG00000276626, 7SK_ENSG00000277313, A1BG, A1BG-AS1, A1CF, A2M, A2M-AS1, A2ML1, A2ML1-AS1, A2ML1-AS2, A2MP1_ENSG00000256069, A3GALT2, A4GALT, A4GNT, AA06, AAAS, AACS, AACSP1_ENSG00000250420, AADAC, AADACL2, AADACL2-AS1, AADACL3, AADACL4, AADACP1_ENSG00000240602, AADAT, AAGAB, AAK1, AAMDC, AAMP, AANAT, AAR2, AARD, AARS, AARS1, AARS1P1, AARS2, AARSD1, AARSD1P1, AASDH, AASDHPPT, AASS, AATBC, AATF, AATK, ABALON, ABAT, ABCA1, ABCA10, ABCA11P, ABCA12, ABCA13, ABCA15P, ABCA17P, ABCA2, ABCA3, ABCA3P1, ABCA4, ABCA5, ABCA6, ABCA7, ABCA8, ABCA9, ABCA9-AS1, ABCB1, ABCB10, ABCB10P1, ABCB10P3, ABCB10P4, ABCB11, ABCB4, ABCB5, ABCB6, ABCB7, ABCB8, ABCB9, ABCC1, ABCC10, ABCC11, ABCC12, ABCC13_ENSG00000243064, ABCC2, ...]
#
# [67983 rows x 0 columns]

# %%
adata_1.var
# Out:
#              gene_symbol
# index
# MIR1302-2HG  MIR1302-2HG
# FAM138A          FAM138A
# OR4F5              OR4F5
# AL627309.1    AL627309.1
# AL627309.3    AL627309.3
# ...                  ...
# AC141272.1    AC141272.1
# AC023491.2    AC023491.2
# AC007325.1    AC007325.1
# AC007325.4    AC007325.4
# AC007325.2    AC007325.2
#
# [32284 rows x 1 columns]

# %%
adata_2.var
# Out:
#                 feature_type  highly_variable         means  dispersions  \
# index
# DDX11L1      Gene Expression            False  6.398244e-05     0.835044
# WASH7P       Gene Expression            False  2.274395e-03     2.442280
# MIR6859-1    Gene Expression            False  6.175251e-05     1.295335
# MIR1302-2HG  Gene Expression            False  1.372886e-04     2.656352
# MIR1302-2    Gene Expression            False  1.000000e-12          NaN
# ...                      ...              ...           ...          ...
# MT-ND6       Gene Expression            False  9.634841e-01     2.466404
# MT-TE        Gene Expression            False  1.600667e-01     1.603787
# MT-CYB       Gene Expression            False  4.367693e+00     4.765751
# MT-TT        Gene Expression            False  6.573967e-02     0.624316
# MT-TP        Gene Expression             True  4.385102e-01     2.705558
#
#              dispersions_norm      mean       std  feature_is_filtered  \
# index
# DDX11L1             -0.573947  0.000039  0.005574                False
# WASH7P               0.533203  0.001080  0.031731                False
# MIR6859-1           -0.256874  0.000033  0.005634                False
# MIR1302-2HG          0.680668  0.000048  0.008041                False
# MIR1302-2            0.000000  0.000000  1.000000                False
# ...                       ...       ...       ...                  ...
# MT-ND6               0.154140  0.590065  0.741395                False
# MT-TE               -0.044396  0.083929  0.301820                False
# MT-CYB              -0.499747  3.874830  1.104192                False
# MT-TT               -0.719108  0.040580  0.186848                False
# MT-TP                1.115482  0.204806  0.501265                False
#
#              gene_symbol feature_reference feature_biotype feature_length  \
# index
# DDX11L1          DDX11L1    NCBITaxon:9606            gene            632
# WASH7P            WASH7P    NCBITaxon:9606            gene           1351
# MIR6859-1      MIR6859-1    NCBITaxon:9606            gene             68
# MIR1302-2HG  MIR1302-2HG    NCBITaxon:9606            gene           1021
# MIR1302-2      MIR1302-2    NCBITaxon:9606            gene            138
# ...                  ...               ...             ...            ...
# MT-ND6            MT-ND6    NCBITaxon:9606            gene            525
# MT-TE              MT-TE    NCBITaxon:9606            gene             69
# MT-CYB            MT-CYB    NCBITaxon:9606            gene           1141
# MT-TT              MT-TT    NCBITaxon:9606            gene             66
# MT-TP              MT-TP    NCBITaxon:9606            gene             68
#
#                   ensembl_id
# index
# DDX11L1      ENSG00000223972
# WASH7P       ENSG00000227232
# MIR6859-1    ENSG00000278267
# MIR1302-2HG  ENSG00000243485
# MIR1302-2    ENSG00000284332
# ...                      ...
# MT-ND6       ENSG00000198695
# MT-TE        ENSG00000210194
# MT-CYB       ENSG00000198727
# MT-TT        ENSG00000210195
# MT-TP        ENSG00000210196
#
# [58482 rows x 13 columns]

# %%
adata_merged.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [5S_rRNA_ENSG00000276861, 5S_rRNA_ENSG00000277411, 5S_rRNA_ENSG00000277488, 5S_rRNA_ENSG00000285609, 5S_rRNA_ENSG00000285626, 5S_rRNA_ENSG00000285674, 5S_rRNA_ENSG00000285776, 5S_rRNA_ENSG00000285912, 5_8S_rRNA_ENSG00000275877, 5_8S_rRNA_ENSG00000276871, 5_8S_rRNA_ENSG00000277739, 5_8S_rRNA_ENSG00000283274, 5_8S_rRNA_ENSG00000283291, 5_8S_rRNA_ENSG00000283568, 7SK_ENSG00000202198, 7SK_ENSG00000271394, 7SK_ENSG00000273591, 7SK_ENSG00000274303, 7SK_ENSG00000275933, 7SK_ENSG00000276626, 7SK_ENSG00000277313, A1BG, A1BG-AS1, A1CF, A2M, A2M-AS1, A2ML1, A2ML1-AS1, A2ML1-AS2, A2MP1_ENSG00000256069, A3GALT2, A4GALT, A4GNT, AA06, AAAS, AACS, AACSP1_ENSG00000250420, AADAC, AADACL2, AADACL2-AS1, AADACL3, AADACL4, AADACP1_ENSG00000240602, AADAT, AAGAB, AAK1, AAMDC, AAMP, AANAT, AAR2, AARD, AARS, AARS1, AARS1P1, AARS2, AARSD1, AARSD1P1, AASDH, AASDHPPT, AASS, AATBC, AATF, AATK, ABALON, ABAT, ABCA1, ABCA10, ABCA11P, ABCA12, ABCA13, ABCA15P, ABCA17P, ABCA2, ABCA3, ABCA3P1, ABCA4, ABCA5, ABCA6, ABCA7, ABCA8, ABCA9, ABCA9-AS1, ABCB1, ABCB10, ABCB10P1, ABCB10P3, ABCB10P4, ABCB11, ABCB4, ABCB5, ABCB6, ABCB7, ABCB8, ABCB9, ABCC1, ABCC10, ABCC11, ABCC12, ABCC13_ENSG00000243064, ABCC2, ...]
#
# [67983 rows x 0 columns]

# %%
adata_merged.uns['author_cell_type_markers']
# Out:
#                            author_cell_type cell_type_ontology_term_id  \
# 0               Alveolar fibroblast 2 (AF2)                 CL:4028006
# 1               Alveolar fibroblast 1 (AF1)                 CL:4028004
# 2                  Alveolar macrophage (AM)                 CL:0000583
# 3                Alveolar type 1 cell (AT1)                 CL:0002062
# 4                Alveolar type 2 cell (AT2)                 CL:0002063
# 5                                B cell (B)                 CL:0000236
# 6                        Basal cell (Basal)                 CL:0002633
# 7                       CD4+ T cell (CD4 T)                 CL:0000624
# 8                       CD8+ T cell (CD8 T)                 CL:0000625
# 9              Inflammatory monocyte (iMON)                 CL:0000860
# 10               Secretory cell (Secretory)                 CL:0000158
# 11             Classical DC subset 1 (cDC1)                 CL:0000990
# 12             Classical DC subset 2 (cDC2)                 CL:0002399
# 13         Deuterosomal cell (Deuterosomal)                 CL:4033044
# 14                  Capillary 2 cell (CAP2)                 CL:4028003
# 15          Arterial endothelial cell (AEC)                 CL:1001568
# 16                  Capillary 1 cell (CAP1)                 CL:4028002
# 17            Venous endothelial cell (VEC)                 CL:0002543
# 18  Systemic venous endothelial cell (SVEC)             UBERON:0001592
# 19         Airway smooth muscle cell (ASMC)                 CL:0019019
# 20                     Goblet cell (Goblet)                 CL:0000160
# 21             Interstitial macrophage (IM)                 CL:4033043
# 22                 Ionocyte cell (Ionocyte)                 CL:0005006
# 23         Lymphatic endothelial cell (LEC)                 CL:0002138
# 24            Mast/Basophil (Mast/Basophil)                 CL:0000097
# 25           Mesothelial cell (Mesothelial)                 CL:0000077
# 26                  Mature DC subset (maDC)                 CL:4033045
# 27                 Ciliated cell (Ciliated)                 CL:4030034
# 28     Secondary crest myofibroblast (SCMF)                 CL:0000186
# 29     Pulmonary neuroendocrine cell (PNEC)                 CL:1000223
# 30                 Natural killer cell (NK)                 CL:0000623
# 31               Patrolling monocyte (pMON)                 CL:0000875
# 32                      Pericyte (Pericyte)                 CL:0009089
# 33                     Plasma cell (Plasma)                 CL:0000786
# 34                    Plasmacytoid DC (pDC)                 CL:0000784
# 35     SMG Basal/Duct cell (SMG Basal/Duct)                 CL:4033024
# 36                     Mucous cell (Mucous)                 CL:4033022
# 37                     Serous cell (Serous)                 CL:4033005
# 38       Vascular smooth muscle cell (VSMC)                 CL:0000359
# 39             Suprabasal cell (Suprabasal)                 CL:4033048
# 40  Respiratory airway secretory cell (RAS)             UBERON:0001955
# 41                         Tuft cell (Tuft)                 CL:0002075
# 42                 Myoepithelial cell (MEC)                 CL:4033003
# 43                               Neutrophil                 CL:0000775
# 44                   Megakaryocyte/Platelet                 CL:0000556
# 45                 T regulatory cell (Treg)                 CL:0000815
# 46               Innate lymphoid cell (ILC)                 CL:0001065
# 47                              Chondrocyte                 CL:0000138
#
#                                               Comment  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Please advise if there is a better term for th...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18     Please advise if there is a cell ontology term
# 19            Please advise if there is a better term
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  Not unambiguous, could be either CL:0000097 or...
# 25                                                NaN
# 26  Based on the correlation mapping to HLCA migra...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40     Please advise if there is a cell ontology term
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
#
#                             full_name            abbreviation  \
# 0               Alveolar fibroblast 2                     AF2
# 1               Alveolar fibroblast 1                     AF1
# 2                 Alveolar macrophage                      AM
# 3                Alveolar type 1 cell                     AT1
# 4                Alveolar type 2 cell                     AT2
# 5                              B cell                       B
# 6                          Basal cell                   Basal
# 7                         CD4+ T cell                   CD4 T
# 8                         CD8+ T cell                   CD8 T
# 9               Inflammatory monocyte                    iMON
# 10                     Secretory cell               Secretory
# 11              Classical DC subset 1                    cDC1
# 12              Classical DC subset 2                    cDC2
# 13                  Deuterosomal cell            Deuterosomal
# 14                   Capillary 2 cell                    CAP2
# 15          Arterial endothelial cell                     AEC
# 16                   Capillary 1 cell                    CAP1
# 17            Venous endothelial cell                     VEC
# 18   Systemic venous endothelial cell                    SVEC
# 19          Airway smooth muscle cell                    ASMC
# 20                        Goblet cell                  Goblet
# 21            Interstitial macrophage                      IM
# 22                      Ionocyte cell                Ionocyte
# 23         Lymphatic endothelial cell                     LEC
# 24                      Mast/Basophil           Mast/Basophil
# 25                   Mesothelial cell             Mesothelial
# 26                   Mature DC subset                    maDC
# 27                      Ciliated cell                Ciliated
# 28      Secondary crest myofibroblast                    SCMF
# 29      Pulmonary neuroendocrine cell                    PNEC
# 30                Natural killer cell                      NK
# 31                Patrolling monocyte                    pMON
# 32                           Pericyte                Pericyte
# 33                        Plasma cell                  Plasma
# 34                    Plasmacytoid DC                     pDC
# 35                SMG Basal/Duct cell          SMG Basal/Duct
# 36                        Mucous cell                  Mucous
# 37                        Serous cell                  Serous
# 38        Vascular smooth muscle cell                    VSMC
# 39                    Suprabasal cell              Suprabasal
# 40  Respiratory airway secretory cell                     RAS
# 41                          Tuft cell                    Tuft
# 42                 Myoepithelial cell                     MEC
# 43                         Neutrophil              Neutrophil
# 44             Megakaryocyte/Platelet  Megakaryocyte/Platelet
# 45                  T regulatory cell                    Treg
# 46               Innate lymphoid cell                     ILC
# 47                        Chondrocyte             Chondrocyte
#
#                              author_cell_type_markers
# 0   MFAP5; SCARA5; CDON; DCN; PLA2G2A; SFRP2; LUM;...
# 1   TCF21; PCDH15; WNT2; ROBO2; LUM; SLIT2; DCN; P...
# 2   FABP4; MARCO; CYP27A1; PPARG; ABCG1; SIGLEC1; ...
# 3   AGER; RTKN2; SEMA3B; NTM; NCKAP5; LMO7; KHDRBS...
# 4   ABCA3; LAMP3; KCNJ15; SFTPC; SFTPA1; SFTPA2; S...
# 5   BANK1; MS4A1; CD19; BACH2; IGHM; EBF1; CD79A; ...
# 6   KRT5; TP63; NGFR; KRT15; KRT17; MMP10; S100A2;...
# 7   CD3E; LEF1; CD40LG; MAL; CD4; CD69; ITK; LTB; ...
# 8   CD8A; CD3E; CD8B; CCL5; NKG7; GZMA; GZMH; IL32...
# 9   VCAN; FCN1; CD14; S100A8; JARID2; S100A12; THB...
# 10  SCGB1A1; BPIFB1; LCN2; TSPAN8; SCUBE2; SAA2; C...
# 11  CLEC9A; FLT3; ZBTB46; LGALS2; DNASE1L3; WDFY4;...
# 12  CD1E; CLEC10A; FCGR2B; CD1C; CCL17; FCER1A; MS...
# 13                       CDC20B; DEUP1; FOXN4; SHISA8
# 14  HPGD; EDNRB; CA4; APLN; SOSTDC1; CLDN5; EMCN; ...
# 15  DKK2; GJA5; BMX; IGFBP3; FAM107A; MT1A; PTPRB;...
# 16  FCN3; IL7R; GPIHBP1; TMEM100; SLC6A4; IL1RL1; ...
# 17  ACKR1; EPHB4; HDAC9; VWF; CCL23; C7; LIFR; PTP...
# 18  ACKR1; COL15A1; VWA1; ABCB1; CCL14; PLVAP; AQP...
# 19  DES; LGR6; BCHE; PLN; ASPN; PRUNE2; HSPB7; GRE...
# 20  MUC5AC; AGR2; SPDEF; SLC4A11; PSCA; LYPD2; MUC...
# 21  F13A1; STAB1; FOLR2; SLC40A1; CD163L1; MERTK; ...
# 22  ASCL3; FOXI1; CFTR; CEL; TMEM61; SCNN1B; BPIFA...
# 23  CCL21; MMRN1; PROX1; LYVE1; PPFIBP1; GNG11; SN...
# 24  TPSB2; TPSAB1; MS4A2; CPA3; HPGDS; RGS1; VWA5A...
# 25  UPK3B; CALB2; WT1; HP; ITLN1; PLA2G2A; PRG4; T...
# 26  CCR7; LAD1; NCCRP1; CCL19; CCL22; CCL17; IL4I1...
# 27  RSPH1; CDHR3; FOXJ1; CDHR4; CAPS; C20orf85; C9...
# 28  ITGBL1; FGF18; PDGFRA; ASPN; CCN5; COL3A1; PRE...
# 29  GRP; CALCA; ASCL1; NRXN1; PCSK1N; SCG2; CHGA; ...
# 30  NKG7; KLRD1; KLRC1; NCAM1; GNLY; GZMB; CCL4; P...
# 31  FCGR3A; FCN1; TNFRSF8; LST1; AIF1; SMIM25; SER...
# 32  PDGFRB; LAMC3; CSPG4; TRPC6; COX4I2; HIGD1B; B...
# 33  CD38; CD27; SDC1; JCHAIN; IGLC3; IGHM; IGHG1; ...
# 34  PLD4; LILRA4; CLEC4C; GZMB; IRF7; IRF8; GPR183...
# 35  RARRES1; MIA; ALDH1A3; KRT14; SOX9; MMP7; SAA2...
# 36  BPIFB2; MUC5B; SPDEF; TFF1; AZGP1; TCN1; FAM3D...
# 37  LYZ; LTF; LPO; PRB3; PRR4; PRB1; AC020656.1; P...
# 38  CNN1; NTRK3; ITGA7; TAGLN; MUSTN1; C11orf96; A...
# 39  KRT19; SERPINB4; NOTCH3; SERPINB3; S100A2; KRT...
# 40           SCGB3A2; MGP; SOX4; KLK11; TMEM45A; CTSE
# 41  IL23A; POU2F3; ASCL2; NREP; HEPACAM2; NMU; MYB...
# 42  KRT14; MYH11; KRT17; SAA1; TPM2; ACTG2; MYLK; ...
# 43  FCGR3B; CSF3R; IL1B; S100A8; S100A12; G0S2; BC...
# 44  GP1BB; ITGA2B; ITGB3; PPBP; PF4; TUBB1; ACRBP;...
# 45  IL2RA; FOXP3; CTLA4; TRAC; LTB; TRBC1; CD3D; T...
# 46                                 IL7R; CXCR3; TBX21
# 47                         ACAN; HAPLN1; COL2A1; SOX9

# %%
dict(adata_merged.uns).keys()
# Out:
# dict_keys(['author_cell_type_markers', 'author_cell_type_markers_level_2', 'comments', '_scvi', '_training_mode', 'citation', 'dendrogram_cell_type_tissue', 'dendrogram_computational_compartment_assignment', 'dendrogram_consensus_prediction', 'dendrogram_tissue_cell_type', 'donor_id_colors', 'hvg', 'neighbors', 'schema_reference', 'schema_version', 'tissue_in_publication_colors', 'umap'])

# %%
adata_merged
# Out:
# AnnData object with n_obs × n_vars = 156537 × 67983
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_SCT', 'nFeature_SCT', 'S.Score', 'G2M.Score', 'Phase', 'pMT', 'DataID', 'DonorID', 'Dataset', 'Age', 'Sex', 'lineage_level1', 'lineage_level2', 'celltype_level1', 'celltype_level2', 'celltype_level3', 'celltype_level3_fullname', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'sample_ID', 'author_cell_type_level_0', 'author_cell_type_level_1', 'author_cell_type_level_2', 'cell_type_ontology_term_id_level_2', 'author_cell_type', 'cell_type_ontology_term_id', 'tissue_in_publication', 'anatomical_information', 'n_counts_UMIs', 'n_genes', 'cell_ontology_class', 'free_annotation', 'manually_annotated', 'compartment', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'dataset_ID'
#     uns: 'author_cell_type_markers', 'author_cell_type_markers_level_2', 'comments', '_scvi', '_training_mode', 'citation', 'dendrogram_cell_type_tissue', 'dendrogram_computational_compartment_assignment', 'dendrogram_consensus_prediction', 'dendrogram_tissue_cell_type', 'donor_id_colors', 'hvg', 'neighbors', 'schema_reference', 'schema_version', 'tissue_in_publication_colors', 'umap'
#     obsm: 'X_pca', 'X_umap', 'X_scvi', 'X_scvi_umap'

# %%
adata_merged.obs.index
# Out:
# Index(['Donor27_Donor27_AAACGAACACCGTGCA-1_lungMAP',
#        'Donor27_Donor27_AAAGAACAGCGCCATC-1_lungMAP',
#        'Donor27_Donor27_AAAGAACCAGGCAATG-1_lungMAP',
#        'Donor27_Donor27_AAAGGATAGTAGCTCT-1_lungMAP',
#        'Donor27_Donor27_AAAGTCCCATCCGGCA-1_lungMAP',
#        'Donor27_Donor27_AAAGTGACACGGCCAT-1_lungMAP',
#        'Donor27_Donor27_AAATGGACAAAGGAGA-1_lungMAP',
#        'Donor27_Donor27_AAATGGACACAAGCCC-1_lungMAP',
#        'Donor27_Donor27_AACAACCGTCTCACAA-1_lungMAP',
#        'Donor27_Donor27_AACAACCGTGACTATC-1_lungMAP',
#        ...
#        'TTTGGTTTCCAGCTCT_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ',
#        'TTTGGTTTCGAGATAA_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ',
#        'TTTGTTGAGCCTAGGA_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ',
#        'TTTGTTGAGGCCACTC_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ',
#        'TTTGTTGGTTCCGCTT_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ',
#        'TTTGTTGTCAAGCCCG_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ',
#        'TTTGTTGTCGTCAACA_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ',
#        'TTTGTTGTCTACCACC_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ',
#        'TTTGTTGTCTAGCCAA_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ',
#        'TTTGTTGTCTATCGGA_TSP2_Lung_proxmedialdistal_10X_1_2_Tabula_Sapiens_2022_publ'],
#       dtype='object', length=156537)

# %%
adata_merged.obs['dataset'].value_counts()
# Out:
# lungMAP                     122445
# Tabula_Sapiens_2022_publ     34092
# Name: dataset, dtype: int64

# %%
adata_merged.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [5S_rRNA_ENSG00000276861, 5S_rRNA_ENSG00000277411, 5S_rRNA_ENSG00000277488, 5S_rRNA_ENSG00000285609, 5S_rRNA_ENSG00000285626, 5S_rRNA_ENSG00000285674, 5S_rRNA_ENSG00000285776, 5S_rRNA_ENSG00000285912, 5_8S_rRNA_ENSG00000275877, 5_8S_rRNA_ENSG00000276871, 5_8S_rRNA_ENSG00000277739, 5_8S_rRNA_ENSG00000283274, 5_8S_rRNA_ENSG00000283291, 5_8S_rRNA_ENSG00000283568, 7SK_ENSG00000202198, 7SK_ENSG00000271394, 7SK_ENSG00000273591, 7SK_ENSG00000274303, 7SK_ENSG00000275933, 7SK_ENSG00000276626, 7SK_ENSG00000277313, A1BG, A1BG-AS1, A1CF, A2M, A2M-AS1, A2ML1, A2ML1-AS1, A2ML1-AS2, A2MP1_ENSG00000256069, A3GALT2, A4GALT, A4GNT, AA06, AAAS, AACS, AACSP1_ENSG00000250420, AADAC, AADACL2, AADACL2-AS1, AADACL3, AADACL4, AADACP1_ENSG00000240602, AADAT, AAGAB, AAK1, AAMDC, AAMP, AANAT, AAR2, AARD, AARS, AARS1, AARS1P1, AARS2, AARSD1, AARSD1P1, AASDH, AASDHPPT, AASS, AATBC, AATF, AATK, ABALON, ABAT, ABCA1, ABCA10, ABCA11P, ABCA12, ABCA13, ABCA15P, ABCA17P, ABCA2, ABCA3, ABCA3P1, ABCA4, ABCA5, ABCA6, ABCA7, ABCA8, ABCA9, ABCA9-AS1, ABCB1, ABCB10, ABCB10P1, ABCB10P3, ABCB10P4, ABCB11, ABCB4, ABCB5, ABCB6, ABCB7, ABCB8, ABCB9, ABCC1, ABCC10, ABCC11, ABCC12, ABCC13_ENSG00000243064, ABCC2, ...]
#
# [67983 rows x 0 columns]

# %%
adata = sc.read_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"))

# %%
adata.obs['sample'].value_counts(dropna=False).index.tolist()
# Out:
# ['SC144',
#  'distal 2',
#  'distal 3',
#  'SC182',
#  'GRO-09_biopsy',
#  'GRO-10_biopsy',
#  'medial 2',
#  'GRO-03_biopsy',
#  'VUHD67',
#  'F02617',
#  'F02611',
#  'F01851',
#  'GRO-04_biopsy',
#  'SC184',
#  'VUHD68',
#  'proximal 3',
#  'F02522',
#  'distal 1a',
#  'SC84',
#  'F02524',
#  'SC27',
#  'SC183',
#  'F02607',
#  'F01394',
#  'SC156',
#  'SC85',
#  'SC86',
#  'SC07',
#  'SC88',
#  'SC22',
#  'SC142',
#  'SC20',
#  'SC18',
#  '390C_12h',
#  'GRO-09_nasal_brush',
#  'SC173',
#  'SC29',
#  'D353_Brus_Nas1',
#  'GRO-07_biopsy',
#  'SC141',
#  'SC56',
#  'D353_Brus_Dis1',
#  'GRO-04_nasal_brush',
#  'D372_Biop_Pro1',
#  'F02528',
#  'SC155',
#  'SC24',
#  'F01607',
#  'D353_Biop_Pro1',
#  'SC143',
#  'SC10',
#  'D372_Biop_Int2',
#  '356C_0h',
#  '356C_24h',
#  'SC87',
#  'T85',
#  '390C_0h',
#  'GRO-06_biopsy',
#  'F02526',
#  '356C_12h',
#  'VUHD66',
#  'T153',
#  'SC185',
#  'SC45',
#  '390C_72h',
#  '368C_12h',
#  'T101',
#  'SC59',
#  'F01639',
#  'T164',
#  'SC174_SC172',
#  'D339_Biop_Int1',
#  'D363_Brus_Nas1',
#  'VUHD101',
#  'SC181',
#  'D367_Biop_Pro1',
#  'GRO-08_biopsy',
#  'T167',
#  'D326_Biop_Pro1',
#  'D344_Brus_Dis1',
#  '390C_24h',
#  'D354_Biop_Int2',
#  'T166',
#  '356C_72h',
#  'SC174_SC173',
#  'F01157',
#  '7185212',
#  'GRO-03_nasal_brush',
#  'D354_Brus_Dis1',
#  'VUHD70',
#  'D367_Brus_Nas1',
#  'T89',
#  'T90',
#  'D372_Brus_Nas1',
#  'D367_Biop_Int1',
#  'D353_Biop_Int2',
#  'GRO-11_biopsy',
#  'T165',
#  'GRO-10_nasal_brush',
#  '368C_24h',
#  'D344_Biop_Nas1',
#  'D367_Brus_Dis1',
#  'F02092',
#  'D322_Biop_Pro1',
#  'D339_Biop_Nas1',
#  '7239217',
#  'T120',
#  'T126',
#  'F02992',
#  'F01641',
#  'D322_Biop_Nas1',
#  'D354_Biop_Pro1',
#  'D372_Brus_Dis1',
#  'SC172',
#  'T154',
#  'F01365',
#  'D363_Brus_Dis1',
#  'F01366',
#  'D363_Biop_Pro1',
#  '7239218',
#  'F02509',
#  '7239220',
#  'T121',
#  '368C_72h',
#  'F02730',
#  'D337_Brus_Dis1',
#  '7135919',
#  'T137',
#  'F01853',
#  'F01367',
#  'F01403',
#  'D363_Biop_Int2',
#  '7185213',
#  'D372_Biop_Int1',
#  'D326_Biop_Int1',
#  'F00409',
#  'SC31D',
#  'D326_Brus_Dis1',
#  'SC31',
#  'F02613',
#  '7239219',
#  'D344_Biop_Int1',
#  'F01874',
#  'GRO-02_biopsy',
#  'F03045',
#  'F01692',
#  'D339_Biop_Pro1',
#  'SC14',
#  'GRO-01_nasal_brush',
#  '7135920',
#  'F01483',
#  '368C_0h',
#  'SC89',
#  'F01511',
#  'F01513',
#  'F01508',
#  '7239213',
#  'D344_Biop_Pro1',
#  'GRO-01_biopsy',
#  '7119453',
#  '7119452',
#  'F01494',
#  'F02609',
#  'F01495',
#  'F01506',
#  'F01869']

# %% [markdown]
# ### Adjustment for celltypist

# %%
adata = sc.read_h5ad("/ictstr01/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision_reduced/HLCA_v1_core.h5ad")

# %%
del adata.obsm['X_scanvi_emb']
del adata.obsm['X_umap']
del adata.obsp['connectivities']
del adata.obsp['distances']

# %%
adata.write_h5ad("/ictstr01/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision_reduced/HLCA_v1_core.h5ad")
