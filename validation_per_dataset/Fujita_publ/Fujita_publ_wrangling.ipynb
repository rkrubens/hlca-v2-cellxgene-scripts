# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import anndata2ri
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"

# %%
DATASET_ID = "Fujita_publ"
DATA_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}"
RDS_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/{DATASET_ID}.rds"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
# Name constants
AUTHOR_CELL_TYPE_L0 = 'author_cell_type_level_0'
AUTHOR_CELL_TYPE_L1 = 'author_cell_type_level_1'

CELL_TYPE_ONTOLOGY_ID_L0 = 'cell_type_ontology_term_id_level_0'
CELL_TYPE_ONTOLOGY_ID_L1 = 'cell_type_ontology_term_id_level_1'

CELL_TYPE_ONTOLOGY_LABEL_L0 = 'cell_type_ontology_term_label_level_0'
CELL_TYPE_ONTOLOGY_LABEL_L1 = 'cell_type_ontology_term_label_level_1'

AUTHOR_CELL_TYPE_DESCRIPTION_L0 = 'author_cell_type_description_level_0'
AUTHOR_CELL_TYPE_DESCRIPTION_L1 = 'author_cell_type_description_level_1'

MARKER_GENES_L0 = 'author_cell_type_markers_level_0'
MARKER_GENES_L1 = 'author_cell_type_markers_level_1'

# Finest grained annotation will be generic dataset cell type
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'
CELL_TYPE_ONTOLOGY_LABEL = 'cell_type_ontology_term_label'
MARKER_GENES = 'author_cell_type_markers'
AUTHOR_CELL_TYPE_DESCRIPTION = 'author_cell_type_description'

# %% [markdown]
# # Load data

# %%
obs = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "obs")
uns = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "uns")

# %%
anndata2ri.activate()
# %load_ext rpy2.ipython
# Out:
# /tmp/ipykernel_434585/2547887543.py:1: DeprecationWarning: The global conversion available with activate() is deprecated and will be removed in the next major release. Use a local converter.
#   anndata2ri.activate()

# %%
# %%R -i RDS_PATH
#
# suppressPackageStartupMessages(library(Seurat))
# rds <- readRDS(file=RDS_PATH)
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# In addition: Warning message:
# package ‘tools’ was built under R version 4.3.3

# %%
# %%R -o adata
#
# adata <- as.SingleCellExperiment(rds)
# adata
# Out:
# class: SingleCellExperiment
# dim: 38224 70051
# metadata(0):
# assays(1): counts
# rownames(38224): MIR1302-2HG FAM138A ... AC004556.1 FAM231C
# rowData names(0):
# colnames(70051): AAACCCAAGTGTTGAA-1_3 AAACCCACAAACACGG-1_3 ...
#   TTTGTTGTCGTAACTG-1_19 TTTGTTGTCTCGTTTA-1_19
# colData names(10): orig.ident nCount_RNA ... patientID ident
# reducedDimNames(0):
# mainExpName: RNA
# altExpNames(0):
# In addition: Warning messages:
# 1: Layer ‘data’ is empty
# 2: Layer ‘scale.data’ is empty
# /home/icb/raphael.kfuri-rubens/miniconda3/envs/hlcav2-env/lib/python3.10/site-packages/anndata2ri/_r2py.py:132: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   return AnnData(exprs, obs, var, uns, obsm, layers=layers)

# %%
obs['sample_ID'].value_counts()
# Out:
# JK05    1
# JK07    1
# JK08    1
# JK09    1
# JK10    1
# JK19    1
# JK21    1
# JK24    1
# JK27    1
# JK03    1
# JK04    1
# JK26    1
# JK29    1
# JK06    1
# JK11    1
# JK12    1
# Name: sample_ID, dtype: int64

# %%
adata.obs.columns
# Out:
# Index(['orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt',
#        'DoubletFinder', 'seurat_clusters', 'RNA_snn_res.0.5', 'anno',
#        'patientID', 'ident'],
#       dtype='object')

# %%
adata.obs['ident'].value_counts()
# Out:
# JK22_26    9167
# JK04       8271
# JK03       6033
# JK12       5285
# JK22_29    5027
# JK11       5005
# JK09       4558
# JK22_19    3808
# JK06       3634
# JK22_27    3606
# JK07       3574
# JK08       3149
# JK05       2890
# JK10       2322
# JK22_24    1941
# JK22_21    1781
# Name: ident, dtype: int64

# %%
adata.obs['patientID'].value_counts()
# Out:
# JK22_26    9167
# JK04       8271
# JK03       6033
# JK12       5285
# JK22_29    5027
# JK11       5005
# JK09       4558
# JK22_19    3808
# JK06       3634
# JK22_27    3606
# JK07       3574
# JK08       3149
# JK05       2890
# JK10       2322
# JK22_24    1941
# JK22_21    1781
# Name: patientID, dtype: int64

# %%
# show nonoverlap between obs['sample_ID'] and obs['ident']

adata_ids = adata.obs['ident'].unique()
obs_ids = obs['sample_ID'].unique()

non_overlap = set(adata_ids) - set(obs_ids)
non_overlap_other_side = set(obs_ids) - set(adata_ids)

# %%
non_overlap
# Out:
# {'JK22_19', 'JK22_21', 'JK22_24', 'JK22_26', 'JK22_27', 'JK22_29'}

# %%
non_overlap_other_side
# Out:
# {'JK19', 'JK21', 'JK24', 'JK26', 'JK27', 'JK29'}

# %%
sample_id_mapping_dict = {
    'JK22_19': 'JK19',
    'JK22_21': 'JK21',
    'JK22_24': 'JK24',
    'JK22_26': 'JK26',
    'JK22_27': 'JK27',
    'JK22_29': 'JK29'
}

# %%
adata.obs['sample_ID'] = adata.obs['ident'].map(sample_id_mapping_dict)
adata.obs['sample_ID'].fillna(adata.obs['ident'], inplace=True)

adata.obs['sample_ID'].value_counts(dropna=False)
# Out:
# JK26    9167
# JK04    8271
# JK03    6033
# JK12    5285
# JK29    5027
# JK11    5005
# JK09    4558
# JK19    3808
# JK06    3634
# JK27    3606
# JK07    3574
# JK08    3149
# JK05    2890
# JK10    2322
# JK24    1941
# JK21    1781
# Name: sample_ID, dtype: int64

# %%
adata.obs['anno'].value_counts(dropna=False)
# Out:
# NaN               12133
# CD4T              11365
# NK/NKT             8423
# Capillary_Cell     6393
# Macrophage         4289
# CD8T               4136
# Mono               3425
# Fibroblast         3022
# Mast_cell          2413
# AT2                2144
# DC1                2132
# Vein_cell          2015
# Cilia              1950
# SM/Pericyte        1279
# Artery_cell         912
# B_cell              712
# DC2                 676
# AT1                 554
# Club/Basal          529
# Neutrophil          521
# Plasma_cell         388
# Prolif.immune       376
# Lymphatic_Cell      264
# Name: anno, dtype: int64

# %%
val_workflow = ValidationWorkflow(
    input = uns,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                                                title   study_PI  \
# 0  Anomalous Epithelial Variations and Ectopic In...  YU FUJITA
#
#   batch_condition default_embedding  \
# 0         patient
#
#                                          unpublished comments
# 0  The dataset is published. https://www.atsjourn...

# %%
val_workflow = ValidationWorkflow(
    input = obs,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation error(s) encountered.
# {'sample_collection_year': "Entries must be integers, floats, or 'NA'/'na'/'N/A'."}
# Error containing field: sample_collection_year
# Error message: Entries must be integers, floats, or 'NA'/'na'/'N/A'.
# Value counts:
# 2019-2021    16
# Name: sample_collection_year, dtype: int64
# Returning error-containing OBS dataframe.
#    sample_ID donor_id                                       protocol_URL  \
# 0       JK05     JK05  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 1       JK07     JK07  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 2       JK08     JK08  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 3       JK09     JK09  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 4       JK10     JK10  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 5       JK19     JK19  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 6       JK21     JK21  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 7       JK24     JK24  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 8       JK27     JK27  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 9       JK03     JK03  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 10      JK04     JK04  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 11      JK26     JK26  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 12      JK29     JK29  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 13      JK06     JK06  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 14      JK11     JK11  https://www.atsjournals.org/doi/10.1165/rcmb.2...
# 15      JK12     JK12  https://www.atsjournals.org/doi/10.1165/rcmb.2...
#
#                                   institute sample_collection_site  \
# 0   The Jikei University School of Medicine                    N/A
# 1   The Jikei University School of Medicine                    N/A
# 2   The Jikei University School of Medicine                    N/A
# 3   The Jikei University School of Medicine                    N/A
# 4   The Jikei University School of Medicine                    N/A
# 5   The Jikei University School of Medicine                    N/A
# 6   The Jikei University School of Medicine                    N/A
# 7   The Jikei University School of Medicine                    N/A
# 8   The Jikei University School of Medicine                    N/A
# 9   The Jikei University School of Medicine                    N/A
# 10  The Jikei University School of Medicine                    N/A
# 11  The Jikei University School of Medicine                    N/A
# 12  The Jikei University School of Medicine                    N/A
# 13  The Jikei University School of Medicine                    N/A
# 14  The Jikei University School of Medicine                    N/A
# 15  The Jikei University School of Medicine                    N/A
#
#    sample_collection_relative_time_point library_ID library_ID_repository  \
# 0                                    N/A       JK05            GSM5282538
# 1                                    N/A       JK07            GSM5282539
# 2                                    N/A       JK08            GSM5282540
# 3                                    N/A       JK09            GSM5282541
# 4                                    N/A       JK10            GSM5282542
# 5                                    N/A       JK19            GSM7882055
# 6                                    N/A       JK21            GSM7882056
# 7                                    N/A       JK24            GSM7882057
# 8                                    N/A       JK27            GSM7882059
# 9                                    N/A       JK03            GSM5282544
# 10                                   N/A       JK04            GSM5282545
# 11                                   N/A       JK26            GSM7882058
# 12                                   N/A       JK29            GSM7882060
# 13                                   N/A       JK06            GSM5282546
# 14                                   N/A       JK11            GSM5282547
# 15                                   N/A       JK12            GSM5282548
#
#                author_batch_notes organism_ontology_term_id  ...  \
# 0   Batch run by different sample            NCBITaxon:9606  ...
# 1   Batch run by different sample            NCBITaxon:9606  ...
# 2   Batch run by different sample            NCBITaxon:9606  ...
# 3   Batch run by different sample            NCBITaxon:9606  ...
# 4   Batch run by different sample            NCBITaxon:9606  ...
# 5   Batch run by different sample            NCBITaxon:9606  ...
# 6   Batch run by different sample            NCBITaxon:9606  ...
# 7   Batch run by different sample            NCBITaxon:9606  ...
# 8   Batch run by different sample            NCBITaxon:9606  ...
# 9   Batch run by different sample            NCBITaxon:9606  ...
# 10  Batch run by different sample            NCBITaxon:9606  ...
# 11  Batch run by different sample            NCBITaxon:9606  ...
# 12  Batch run by different sample            NCBITaxon:9606  ...
# 13  Batch run by different sample            NCBITaxon:9606  ...
# 14  Batch run by different sample            NCBITaxon:9606  ...
# 15  Batch run by different sample            NCBITaxon:9606  ...
#
#    sequenced_fragment sequencing_platform is_primary_data reference_genome  \
# 0         3 prime tag         EFO:0008567            true           GRCh38
# 1         3 prime tag         EFO:0008567            true           GRCh38
# 2         3 prime tag         EFO:0008567            true           GRCh38
# 3         3 prime tag         EFO:0008567            true           GRCh38
# 4         3 prime tag         EFO:0008567            true           GRCh38
# 5         3 prime tag         EFO:0008567            true           GRCh38
# 6         3 prime tag         EFO:0008567            true           GRCh38
# 7         3 prime tag         EFO:0008567            true           GRCh38
# 8         3 prime tag         EFO:0008567            true           GRCh38
# 9         3 prime tag         EFO:0008567            true           GRCh38
# 10        3 prime tag         EFO:0008567            true           GRCh38
# 11        3 prime tag         EFO:0008567            true           GRCh38
# 12        3 prime tag         EFO:0008567            true           GRCh38
# 13        3 prime tag         EFO:0008567            true           GRCh38
# 14        3 prime tag         EFO:0008567            true           GRCh38
# 15        3 prime tag         EFO:0008567            true           GRCh38
#
#    gene_annotation_version alignment_software intron_inclusion  \
# 0                      N/A      version 6.1.2              yes
# 1                      N/A      version 6.1.2              yes
# 2                      N/A      version 6.1.2              yes
# 3                      N/A      version 6.1.2              yes
# 4                      N/A      version 6.1.2              yes
# 5                      N/A      version 6.1.2              yes
# 6                      N/A      version 6.1.2              yes
# 7                      N/A      version 6.1.2              yes
# 8                      N/A      version 6.1.2              yes
# 9                      N/A      version 6.1.2              yes
# 10                     N/A      version 6.1.2              yes
# 11                     N/A      version 6.1.2              yes
# 12                     N/A      version 6.1.2              yes
# 13                     N/A      version 6.1.2              yes
# 14                     N/A      version 6.1.2              yes
# 15                     N/A      version 6.1.2              yes
#
#    disease_ontology_term_id self_reported_ethnicity_ontology_term_id  \
# 0             MONDO:0005002                                    Asian
# 1             MONDO:0005002                                    Asian
# 2             MONDO:0005002                                    Asian
# 3             MONDO:0005002                                    Asian
# 4             MONDO:0005002                                    Asian
# 5             MONDO:0005002                                    Asian
# 6             MONDO:0005002                                    Asian
# 7             MONDO:0005002                                    Asian
# 8             MONDO:0005002                                    Asian
# 9              PATO:0000461                                    Asian
# 10             PATO:0000461                                    Asian
# 11             PATO:0000461                                    Asian
# 12             PATO:0000461                                    Asian
# 13             PATO:0000461                                    Asian
# 14             PATO:0000461                                    Asian
# 15             PATO:0000461                                    Asian
#
#    development_stage_ontology_term_id
# 0                      HsapDv:0000241
# 1                      HsapDv:0000243
# 2                      HsapDv:0000242
# 3                      HsapDv:0000242
# 4                      HsapDv:0000242
# 5                      HsapDv:0000241
# 6                      HsapDv:0000242
# 7                      HsapDv:0000242
# 8                      HsapDv:0000242
# 9                      HsapDv:0000241
# 10                     HsapDv:0000241
# 11                     HsapDv:0000240
# 12                     HsapDv:0000241
# 13                     HsapDv:0000240
# 14                     HsapDv:0000240
# 15                     HsapDv:0000240
#
# [16 rows x 37 columns]

# %% [markdown]
# # Validate obs and uns from adata

# %%
merger = AnnDataMerger(
    adata = adata,
    uns_df = uns
)

adata = merger.add_uns_metadata()

adata
# Out:
# AnnData object with n_obs × n_vars = 70051 × 38224
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'DoubletFinder', 'seurat_clusters', 'RNA_snn_res.0.5', 'anno', 'patientID', 'ident', 'sample_ID'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments'

# %%
merger = AnnDataMerger(
    adata = adata,
    obs_df = obs
)

adata = merger.add_obs_metadata(
    adata_col = 'sample_ID',
    df_col = 'sample_ID',
    skip = None
)

adata.obs
# Out:
#                       orig.ident  nCount_RNA  nFeature_RNA  percent.mt  \
# AAACCCAAGTGTTGAA-1_3        JK03      5979.0          2711    3.110888
# AAACCCACAAACACGG-1_3        JK03      8711.0          3072    2.938813
# AAACCCAGTAGGATAT-1_3        JK03     24013.0          4975    3.202432
# AAACCCAGTCGATTAC-1_3        JK03      6906.0          2496    5.589343
# AAACCCATCCGCTGTT-1_3        JK03     10166.0          3378    2.705095
# ...                          ...         ...           ...         ...
# TTTGTTGCAGGTCCGT-1_19    JK22_29      1567.0           640    9.125718
# TTTGTTGCATTGAGGG-1_19    JK22_29       576.0           363   17.361111
# TTTGTTGGTCTAGTGT-1_19    JK22_29      5079.0          2097    2.736759
# TTTGTTGTCGTAACTG-1_19    JK22_29      5333.0          2590    2.118882
# TTTGTTGTCTCGTTTA-1_19    JK22_29      6592.0          2583    8.115898
#
#                       DoubletFinder seurat_clusters RNA_snn_res.0.5  \
# AAACCCAAGTGTTGAA-1_3        Singlet              12              12
# AAACCCACAAACACGG-1_3        Singlet               1               1
# AAACCCAGTAGGATAT-1_3        Singlet               5               5
# AAACCCAGTCGATTAC-1_3        Singlet               0               0
# AAACCCATCCGCTGTT-1_3        Singlet               1               1
# ...                             ...             ...             ...
# TTTGTTGCAGGTCCGT-1_19       Singlet              13              13
# TTTGTTGCATTGAGGG-1_19          None             NaN             NaN
# TTTGTTGGTCTAGTGT-1_19       Singlet              10              10
# TTTGTTGTCGTAACTG-1_19       Singlet              13              13
# TTTGTTGTCTCGTTTA-1_19       Singlet               4               4
#
#                                  anno patientID    ident  ...  \
# AAACCCAAGTGTTGAA-1_3   Capillary_Cell      JK03     JK03  ...
# AAACCCACAAACACGG-1_3           NK/NKT      JK03     JK03  ...
# AAACCCAGTAGGATAT-1_3             Mono      JK03     JK03  ...
# AAACCCAGTCGATTAC-1_3             CD4T      JK03     JK03  ...
# AAACCCATCCGCTGTT-1_3           NK/NKT      JK03     JK03  ...
# ...                               ...       ...      ...  ...
# TTTGTTGCAGGTCCGT-1_19     SM/Pericyte   JK22_29  JK22_29  ...
# TTTGTTGCATTGAGGG-1_19             NaN   JK22_29  JK22_29  ...
# TTTGTTGGTCTAGTGT-1_19       Vein_cell   JK22_29  JK22_29  ...
# TTTGTTGTCGTAACTG-1_19     SM/Pericyte   JK22_29  JK22_29  ...
# TTTGTTGTCTCGTTTA-1_19            CD8T   JK22_29  JK22_29  ...
#
#                       sequenced_fragment sequencing_platform is_primary_data  \
# AAACCCAAGTGTTGAA-1_3         3 prime tag         EFO:0008567            true
# AAACCCACAAACACGG-1_3         3 prime tag         EFO:0008567            true
# AAACCCAGTAGGATAT-1_3         3 prime tag         EFO:0008567            true
# AAACCCAGTCGATTAC-1_3         3 prime tag         EFO:0008567            true
# AAACCCATCCGCTGTT-1_3         3 prime tag         EFO:0008567            true
# ...                                  ...                 ...             ...
# TTTGTTGCAGGTCCGT-1_19        3 prime tag         EFO:0008567            true
# TTTGTTGCATTGAGGG-1_19        3 prime tag         EFO:0008567            true
# TTTGTTGGTCTAGTGT-1_19        3 prime tag         EFO:0008567            true
# TTTGTTGTCGTAACTG-1_19        3 prime tag         EFO:0008567            true
# TTTGTTGTCTCGTTTA-1_19        3 prime tag         EFO:0008567            true
#
#                       reference_genome gene_annotation_version  \
# AAACCCAAGTGTTGAA-1_3            GRCh38                     N/A
# AAACCCACAAACACGG-1_3            GRCh38                     N/A
# AAACCCAGTAGGATAT-1_3            GRCh38                     N/A
# AAACCCAGTCGATTAC-1_3            GRCh38                     N/A
# AAACCCATCCGCTGTT-1_3            GRCh38                     N/A
# ...                                ...                     ...
# TTTGTTGCAGGTCCGT-1_19           GRCh38                     N/A
# TTTGTTGCATTGAGGG-1_19           GRCh38                     N/A
# TTTGTTGGTCTAGTGT-1_19           GRCh38                     N/A
# TTTGTTGTCGTAACTG-1_19           GRCh38                     N/A
# TTTGTTGTCTCGTTTA-1_19           GRCh38                     N/A
#
#                       alignment_software intron_inclusion  \
# AAACCCAAGTGTTGAA-1_3       version 6.1.2              yes
# AAACCCACAAACACGG-1_3       version 6.1.2              yes
# AAACCCAGTAGGATAT-1_3       version 6.1.2              yes
# AAACCCAGTCGATTAC-1_3       version 6.1.2              yes
# AAACCCATCCGCTGTT-1_3       version 6.1.2              yes
# ...                                  ...              ...
# TTTGTTGCAGGTCCGT-1_19      version 6.1.2              yes
# TTTGTTGCATTGAGGG-1_19      version 6.1.2              yes
# TTTGTTGGTCTAGTGT-1_19      version 6.1.2              yes
# TTTGTTGTCGTAACTG-1_19      version 6.1.2              yes
# TTTGTTGTCTCGTTTA-1_19      version 6.1.2              yes
#
#                       disease_ontology_term_id  \
# AAACCCAAGTGTTGAA-1_3              PATO:0000461
# AAACCCACAAACACGG-1_3              PATO:0000461
# AAACCCAGTAGGATAT-1_3              PATO:0000461
# AAACCCAGTCGATTAC-1_3              PATO:0000461
# AAACCCATCCGCTGTT-1_3              PATO:0000461
# ...                                        ...
# TTTGTTGCAGGTCCGT-1_19             PATO:0000461
# TTTGTTGCATTGAGGG-1_19             PATO:0000461
# TTTGTTGGTCTAGTGT-1_19             PATO:0000461
# TTTGTTGTCGTAACTG-1_19             PATO:0000461
# TTTGTTGTCTCGTTTA-1_19             PATO:0000461
#
#                       self_reported_ethnicity_ontology_term_id  \
# AAACCCAAGTGTTGAA-1_3                                     Asian
# AAACCCACAAACACGG-1_3                                     Asian
# AAACCCAGTAGGATAT-1_3                                     Asian
# AAACCCAGTCGATTAC-1_3                                     Asian
# AAACCCATCCGCTGTT-1_3                                     Asian
# ...                                                        ...
# TTTGTTGCAGGTCCGT-1_19                                    Asian
# TTTGTTGCATTGAGGG-1_19                                    Asian
# TTTGTTGGTCTAGTGT-1_19                                    Asian
# TTTGTTGTCGTAACTG-1_19                                    Asian
# TTTGTTGTCTCGTTTA-1_19                                    Asian
#
#                       development_stage_ontology_term_id
# AAACCCAAGTGTTGAA-1_3                      HsapDv:0000241
# AAACCCACAAACACGG-1_3                      HsapDv:0000241
# AAACCCAGTAGGATAT-1_3                      HsapDv:0000241
# AAACCCAGTCGATTAC-1_3                      HsapDv:0000241
# AAACCCATCCGCTGTT-1_3                      HsapDv:0000241
# ...                                                  ...
# TTTGTTGCAGGTCCGT-1_19                     HsapDv:0000241
# TTTGTTGCATTGAGGG-1_19                     HsapDv:0000241
# TTTGTTGGTCTAGTGT-1_19                     HsapDv:0000241
# TTTGTTGTCGTAACTG-1_19                     HsapDv:0000241
# TTTGTTGTCTCGTTTA-1_19                     HsapDv:0000241
#
# [70051 rows x 47 columns]

# %% [markdown]
# # Add author cell type markers to UNS

# %%
celltype_ontology = pd.read_csv(f"{DATA_PATH}/cellontology.csv")
celltype_markergenes = pd.read_csv(f"{DATA_PATH}/markergenes.csv")

# %%
celltype_ontology
# Out:
#                    annotation                Ontology
# 0              Capillary_Cell              CL_0002144
# 1                      NK/NKT  CL_0000623/BTO_0006501
# 2                        Mono              CL_0000576
# 3                        CD4T             NCIT:C12537
# 4                  Macrophage              CL_0000235
# 5                      B_cell              CL:0000236
# 6                  Neutrophil              CL_0000775
# 7                        CD8T             NCIT_C12542
# 8                   Mast_cell             NCIT_C12747
# 9              Dendritic_cell              CL_0000451
# 10                Artery_cell             NCIT_C49194
# 11                  Vein_cell              CL_0002543
# 12                      Cilia              CL_1000271
# 13                        AT2              CL_0002063
# 14                        AT1              CL_0002062
# 15                SM/Pericyte   CL_0000192/CL_0000669
# 16                Plasma_cell              CL_0000786
# 17                 Fibroblast              CL_0000057
# 18                 Club/Basal   CL_0000158/CL_0002633
# 19  proliferating_immune_cell            CMPO_0000241
# 20             Lymphatic_Cell              CL_0002138

# %%
celltype_markergenes
# Out:
#                                     Cell type  \
# 0                                  Epithelium
# 1                                   Club Cell
# 2                               Ciliated Cell
# 3                                  Basal Cell
# 4             Alveolar Epithelial Type 1 Cell
# 5             Alveolar Epithelial Type 2 Cell
# 6                                 Endothelium
# 7                                 Artery Cell
# 8                                   Vein Cell
# 9                              Capillary Cell
# 10                             Lymphatic Cell
# 11                                     Stroma
# 12                              Smooth Muscle
# 13                                   Pericyte
# 14                                 Fibroblast
# 15                                     Immune
# 16                                     B Cell
# 17                                Plasma Cell
# 18                                 CD8+ Tcell
# 19                                 CD4+ Tcell
# 20  Natural Killer Cell/Natural Killer T Cell
# 21                                 Neutrophil
# 22                                  Mast Cell
# 23                                 Macrophage
# 24                                   Monocyte
# 25                    Myeloid Dendritic Cell
#
#                           Canonical markers
# 0                                     EPCAM
# 1                                   SCGB3A2
# 2                       FOXJ1; TP73; CCDC78
# 3                                KRT5; TP63
# 4                         AGER; PDPN; CLIC5
# 5           SFTPB; SFTPC; SFTPD; MUC1; ETV5
# 6                                     CLDN5
# 7                                 GJA5; BMX
# 8                                     ACKR1
# 9                                       CA4
# 10                              PROX1; PDPN
# 11                                   COL1A2
# 12            CNN1; ACTA2; TAGLN; RGS5; DES
# 13                CSPG4; TRPC6; PDGFRB;RGS5
# 14                           COL1A1; PDGFRA
# 15                                    PTPRC
# 16                 CD79A; CD24; MS4A1; CD19
# 17                      CD79A; CD27; SLAMF7
# 18             CD3E; CD8A;GZMH; GZMB; DUSP2
# 19                          CD3E; CD4; LEF1
# 20  KLRD1; NKG7; TYROBP; CD3E; CD8A; FCER1G
# 21           S100A8; S100A9; IFITM2; FCGR3B
# 22                      MS4A2; CPA3; TPSAB1
# 23                        MARCO; MSR1; MRC1
# 24                     CD14; S100A8; FCGR3A
# 25         MHCII; CLEC9A; LAMP3; CD1C; PLD4

# %%
mapping_dict = {
    'Epithelium': None,  # No direct match; may need a generic or separate category
    'Club Cell': 'Club/Basal',
    'Ciliated Cell': 'Cilia',
    'Basal Cell': 'Club/Basal',
    'Alveolar Epithelial Type 1 Cell': 'AT1',
    'Alveolar Epithelial Type 2 Cell': 'AT2',
    'Endothelium': None,  # No direct match
    'Artery Cell': 'Artery_cell',
    'Vein Cell': 'Vein_cell',
    'Capillary Cell': 'Capillary_Cell',
    'Lymphatic Cell': 'Lymphatic_Cell',
    'Stroma': None,  # No direct match
    'Smooth Muscle': 'SM/Pericyte',
    'Pericyte': 'SM/Pericyte',
    'Fibroblast': 'Fibroblast',
    'Immune': None,  # No direct match; might include various immune cells
    'B Cell': 'B_cell',
    'Plasma Cell': 'Plasma_cell',
    'CD8+ Tcell': 'CD8T',
    'CD4+ Tcell': 'CD4T',
    'Natural Killer Cell/Natural Killer T Cell': 'NK/NKT',
    'Neutrophil': 'Neutrophil',
    'Mast Cell': 'Mast_cell',
    'Macrophage': 'Macrophage',
    'Monocyte': 'Mono',
    'Myeloid Dendritic Cell ': 'Dendritic_cell'
}

# %%
celltype_markergenes[AUTHOR_CELL_TYPE] = celltype_markergenes['Cell type'].map(mapping_dict)
celltype_markergenes
# Out:
#                                     Cell type  \
# 0                                  Epithelium
# 1                                   Club Cell
# 2                               Ciliated Cell
# 3                                  Basal Cell
# 4             Alveolar Epithelial Type 1 Cell
# 5             Alveolar Epithelial Type 2 Cell
# 6                                 Endothelium
# 7                                 Artery Cell
# 8                                   Vein Cell
# 9                              Capillary Cell
# 10                             Lymphatic Cell
# 11                                     Stroma
# 12                              Smooth Muscle
# 13                                   Pericyte
# 14                                 Fibroblast
# 15                                     Immune
# 16                                     B Cell
# 17                                Plasma Cell
# 18                                 CD8+ Tcell
# 19                                 CD4+ Tcell
# 20  Natural Killer Cell/Natural Killer T Cell
# 21                                 Neutrophil
# 22                                  Mast Cell
# 23                                 Macrophage
# 24                                   Monocyte
# 25                    Myeloid Dendritic Cell
#
#                           Canonical markers author_cell_type
# 0                                     EPCAM             None
# 1                                   SCGB3A2       Club/Basal
# 2                       FOXJ1; TP73; CCDC78            Cilia
# 3                                KRT5; TP63       Club/Basal
# 4                         AGER; PDPN; CLIC5              AT1
# 5           SFTPB; SFTPC; SFTPD; MUC1; ETV5              AT2
# 6                                     CLDN5             None
# 7                                 GJA5; BMX      Artery_cell
# 8                                     ACKR1        Vein_cell
# 9                                       CA4   Capillary_Cell
# 10                              PROX1; PDPN   Lymphatic_Cell
# 11                                   COL1A2             None
# 12            CNN1; ACTA2; TAGLN; RGS5; DES      SM/Pericyte
# 13                CSPG4; TRPC6; PDGFRB;RGS5      SM/Pericyte
# 14                           COL1A1; PDGFRA       Fibroblast
# 15                                    PTPRC             None
# 16                 CD79A; CD24; MS4A1; CD19           B_cell
# 17                      CD79A; CD27; SLAMF7      Plasma_cell
# 18             CD3E; CD8A;GZMH; GZMB; DUSP2             CD8T
# 19                          CD3E; CD4; LEF1             CD4T
# 20  KLRD1; NKG7; TYROBP; CD3E; CD8A; FCER1G           NK/NKT
# 21           S100A8; S100A9; IFITM2; FCGR3B       Neutrophil
# 22                      MS4A2; CPA3; TPSAB1        Mast_cell
# 23                        MARCO; MSR1; MRC1       Macrophage
# 24                     CD14; S100A8; FCGR3A             Mono
# 25         MHCII; CLEC9A; LAMP3; CD1C; PLD4   Dendritic_cell

# %%
len(celltype_markergenes[AUTHOR_CELL_TYPE].value_counts())
# Out:
# 20

# %%
author_cell_types_list = celltype_ontology['annotation']

# proliferating immune cell not in marker genes
non_overlap = [x for x in author_cell_types_list if x not in celltype_markergenes[AUTHOR_CELL_TYPE].unique()]
non_overlap
# Out:
# ['proliferating_immune_cell']

# %%
celltype_markergenes[CELL_TYPE_ONTOLOGY_ID] = celltype_markergenes[AUTHOR_CELL_TYPE].map(celltype_ontology.set_index('annotation')['Ontology'])

celltype_markergenes
# Out:
#                                     Cell type  \
# 0                                  Epithelium
# 1                                   Club Cell
# 2                               Ciliated Cell
# 3                                  Basal Cell
# 4             Alveolar Epithelial Type 1 Cell
# 5             Alveolar Epithelial Type 2 Cell
# 6                                 Endothelium
# 7                                 Artery Cell
# 8                                   Vein Cell
# 9                              Capillary Cell
# 10                             Lymphatic Cell
# 11                                     Stroma
# 12                              Smooth Muscle
# 13                                   Pericyte
# 14                                 Fibroblast
# 15                                     Immune
# 16                                     B Cell
# 17                                Plasma Cell
# 18                                 CD8+ Tcell
# 19                                 CD4+ Tcell
# 20  Natural Killer Cell/Natural Killer T Cell
# 21                                 Neutrophil
# 22                                  Mast Cell
# 23                                 Macrophage
# 24                                   Monocyte
# 25                    Myeloid Dendritic Cell
#
#                           Canonical markers author_cell_type  \
# 0                                     EPCAM             None
# 1                                   SCGB3A2       Club/Basal
# 2                       FOXJ1; TP73; CCDC78            Cilia
# 3                                KRT5; TP63       Club/Basal
# 4                         AGER; PDPN; CLIC5              AT1
# 5           SFTPB; SFTPC; SFTPD; MUC1; ETV5              AT2
# 6                                     CLDN5             None
# 7                                 GJA5; BMX      Artery_cell
# 8                                     ACKR1        Vein_cell
# 9                                       CA4   Capillary_Cell
# 10                              PROX1; PDPN   Lymphatic_Cell
# 11                                   COL1A2             None
# 12            CNN1; ACTA2; TAGLN; RGS5; DES      SM/Pericyte
# 13                CSPG4; TRPC6; PDGFRB;RGS5      SM/Pericyte
# 14                           COL1A1; PDGFRA       Fibroblast
# 15                                    PTPRC             None
# 16                 CD79A; CD24; MS4A1; CD19           B_cell
# 17                      CD79A; CD27; SLAMF7      Plasma_cell
# 18             CD3E; CD8A;GZMH; GZMB; DUSP2             CD8T
# 19                          CD3E; CD4; LEF1             CD4T
# 20  KLRD1; NKG7; TYROBP; CD3E; CD8A; FCER1G           NK/NKT
# 21           S100A8; S100A9; IFITM2; FCGR3B       Neutrophil
# 22                      MS4A2; CPA3; TPSAB1        Mast_cell
# 23                        MARCO; MSR1; MRC1       Macrophage
# 24                     CD14; S100A8; FCGR3A             Mono
# 25         MHCII; CLEC9A; LAMP3; CD1C; PLD4   Dendritic_cell
#
#    cell_type_ontology_term_id
# 0                         NaN
# 1       CL_0000158/CL_0002633
# 2                  CL_1000271
# 3       CL_0000158/CL_0002633
# 4                  CL_0002062
# 5                  CL_0002063
# 6                         NaN
# 7                 NCIT_C49194
# 8                  CL_0002543
# 9                  CL_0002144
# 10                 CL_0002138
# 11                        NaN
# 12      CL_0000192/CL_0000669
# 13      CL_0000192/CL_0000669
# 14                 CL_0000057
# 15                        NaN
# 16                 CL:0000236
# 17                 CL_0000786
# 18                NCIT_C12542
# 19                NCIT:C12537
# 20     CL_0000623/BTO_0006501
# 21                 CL_0000775
# 22                NCIT_C12747
# 23                 CL_0000235
# 24                 CL_0000576
# 25                 CL_0000451

# %%
set1 = set(celltype_markergenes[AUTHOR_CELL_TYPE])
set2 = set(celltype_ontology['annotation'])

non_overlap = set1 - set2
non_overlap_other_side = set2 - set1

non_overlap_other_side
# Out:
# {'proliferating_immune_cell'}

# %%
# add row with 'Proliferating Immune Cell', NaN, 'proliferating_immune_cell' and CMPO_0000241
celltype_markergenes = celltype_markergenes.append({
    'Cell type': 'Proliferating Immune Cell',
    'Canonical markers': np.nan,
    AUTHOR_CELL_TYPE: 'proliferating_immune_cell',
    CELL_TYPE_ONTOLOGY_ID: 'CMPO_0000241'
}, ignore_index=True)

celltype_markergenes
# Out:
# /tmp/ipykernel_2535127/1173941726.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   celltype_markergenes = celltype_markergenes.append({
#                                     Cell type  \
# 0                                  Epithelium
# 1                                   Club Cell
# 2                               Ciliated Cell
# 3                                  Basal Cell
# 4             Alveolar Epithelial Type 1 Cell
# 5             Alveolar Epithelial Type 2 Cell
# 6                                 Endothelium
# 7                                 Artery Cell
# 8                                   Vein Cell
# 9                              Capillary Cell
# 10                             Lymphatic Cell
# 11                                     Stroma
# 12                              Smooth Muscle
# 13                                   Pericyte
# 14                                 Fibroblast
# 15                                     Immune
# 16                                     B Cell
# 17                                Plasma Cell
# 18                                 CD8+ Tcell
# 19                                 CD4+ Tcell
# 20  Natural Killer Cell/Natural Killer T Cell
# 21                                 Neutrophil
# 22                                  Mast Cell
# 23                                 Macrophage
# 24                                   Monocyte
# 25                    Myeloid Dendritic Cell
# 26                  Proliferating Immune Cell
#
#                           Canonical markers           author_cell_type  \
# 0                                     EPCAM                       None
# 1                                   SCGB3A2                 Club/Basal
# 2                       FOXJ1; TP73; CCDC78                      Cilia
# 3                                KRT5; TP63                 Club/Basal
# 4                         AGER; PDPN; CLIC5                        AT1
# 5           SFTPB; SFTPC; SFTPD; MUC1; ETV5                        AT2
# 6                                     CLDN5                       None
# 7                                 GJA5; BMX                Artery_cell
# 8                                     ACKR1                  Vein_cell
# 9                                       CA4             Capillary_Cell
# 10                              PROX1; PDPN             Lymphatic_Cell
# 11                                   COL1A2                       None
# 12            CNN1; ACTA2; TAGLN; RGS5; DES                SM/Pericyte
# 13                CSPG4; TRPC6; PDGFRB;RGS5                SM/Pericyte
# 14                           COL1A1; PDGFRA                 Fibroblast
# 15                                    PTPRC                       None
# 16                 CD79A; CD24; MS4A1; CD19                     B_cell
# 17                      CD79A; CD27; SLAMF7                Plasma_cell
# 18             CD3E; CD8A;GZMH; GZMB; DUSP2                       CD8T
# 19                          CD3E; CD4; LEF1                       CD4T
# 20  KLRD1; NKG7; TYROBP; CD3E; CD8A; FCER1G                     NK/NKT
# 21           S100A8; S100A9; IFITM2; FCGR3B                 Neutrophil
# 22                      MS4A2; CPA3; TPSAB1                  Mast_cell
# 23                        MARCO; MSR1; MRC1                 Macrophage
# 24                     CD14; S100A8; FCGR3A                       Mono
# 25         MHCII; CLEC9A; LAMP3; CD1C; PLD4             Dendritic_cell
# 26                                      NaN  proliferating_immune_cell
#
#    cell_type_ontology_term_id
# 0                         NaN
# 1       CL_0000158/CL_0002633
# 2                  CL_1000271
# 3       CL_0000158/CL_0002633
# 4                  CL_0002062
# 5                  CL_0002063
# 6                         NaN
# 7                 NCIT_C49194
# 8                  CL_0002543
# 9                  CL_0002144
# 10                 CL_0002138
# 11                        NaN
# 12      CL_0000192/CL_0000669
# 13      CL_0000192/CL_0000669
# 14                 CL_0000057
# 15                        NaN
# 16                 CL:0000236
# 17                 CL_0000786
# 18                NCIT_C12542
# 19                NCIT:C12537
# 20     CL_0000623/BTO_0006501
# 21                 CL_0000775
# 22                NCIT_C12747
# 23                 CL_0000235
# 24                 CL_0000576
# 25                 CL_0000451
# 26               CMPO_0000241

# %%
celltype_markergenes.rename(columns={'Canonical markers': MARKER_GENES, 'Cell type': AUTHOR_CELL_TYPE_DESCRIPTION}, inplace=True)
celltype_markergenes
# Out:
#                  author_cell_type_description  \
# 0                                  Epithelium
# 1                                   Club Cell
# 2                               Ciliated Cell
# 3                                  Basal Cell
# 4             Alveolar Epithelial Type 1 Cell
# 5             Alveolar Epithelial Type 2 Cell
# 6                                 Endothelium
# 7                                 Artery Cell
# 8                                   Vein Cell
# 9                              Capillary Cell
# 10                             Lymphatic Cell
# 11                                     Stroma
# 12                              Smooth Muscle
# 13                                   Pericyte
# 14                                 Fibroblast
# 15                                     Immune
# 16                                     B Cell
# 17                                Plasma Cell
# 18                                 CD8+ Tcell
# 19                                 CD4+ Tcell
# 20  Natural Killer Cell/Natural Killer T Cell
# 21                                 Neutrophil
# 22                                  Mast Cell
# 23                                 Macrophage
# 24                                   Monocyte
# 25                    Myeloid Dendritic Cell
# 26                  Proliferating Immune Cell
#
#                    author_cell_type_markers           author_cell_type  \
# 0                                     EPCAM                       None
# 1                                   SCGB3A2                 Club/Basal
# 2                       FOXJ1; TP73; CCDC78                      Cilia
# 3                                KRT5; TP63                 Club/Basal
# 4                         AGER; PDPN; CLIC5                        AT1
# 5           SFTPB; SFTPC; SFTPD; MUC1; ETV5                        AT2
# 6                                     CLDN5                       None
# 7                                 GJA5; BMX                Artery_cell
# 8                                     ACKR1                  Vein_cell
# 9                                       CA4             Capillary_Cell
# 10                              PROX1; PDPN             Lymphatic_Cell
# 11                                   COL1A2                       None
# 12            CNN1; ACTA2; TAGLN; RGS5; DES                SM/Pericyte
# 13                CSPG4; TRPC6; PDGFRB;RGS5                SM/Pericyte
# 14                           COL1A1; PDGFRA                 Fibroblast
# 15                                    PTPRC                       None
# 16                 CD79A; CD24; MS4A1; CD19                     B_cell
# 17                      CD79A; CD27; SLAMF7                Plasma_cell
# 18             CD3E; CD8A;GZMH; GZMB; DUSP2                       CD8T
# 19                          CD3E; CD4; LEF1                       CD4T
# 20  KLRD1; NKG7; TYROBP; CD3E; CD8A; FCER1G                     NK/NKT
# 21           S100A8; S100A9; IFITM2; FCGR3B                 Neutrophil
# 22                      MS4A2; CPA3; TPSAB1                  Mast_cell
# 23                        MARCO; MSR1; MRC1                 Macrophage
# 24                     CD14; S100A8; FCGR3A                       Mono
# 25         MHCII; CLEC9A; LAMP3; CD1C; PLD4             Dendritic_cell
# 26                                      NaN  proliferating_immune_cell
#
#    cell_type_ontology_term_id
# 0                         NaN
# 1       CL_0000158/CL_0002633
# 2                  CL_1000271
# 3       CL_0000158/CL_0002633
# 4                  CL_0002062
# 5                  CL_0002063
# 6                         NaN
# 7                 NCIT_C49194
# 8                  CL_0002543
# 9                  CL_0002144
# 10                 CL_0002138
# 11                        NaN
# 12      CL_0000192/CL_0000669
# 13      CL_0000192/CL_0000669
# 14                 CL_0000057
# 15                        NaN
# 16                 CL:0000236
# 17                 CL_0000786
# 18                NCIT_C12542
# 19                NCIT:C12537
# 20     CL_0000623/BTO_0006501
# 21                 CL_0000775
# 22                NCIT_C12747
# 23                 CL_0000235
# 24                 CL_0000576
# 25                 CL_0000451
# 26               CMPO_0000241

# %%
# replace all '_' with ':' in CELL_TYPE_ONTOLOGY_ID of celltype_markergenes
celltype_markergenes[CELL_TYPE_ONTOLOGY_ID] = celltype_markergenes[CELL_TYPE_ONTOLOGY_ID].str.replace('_', ':')
celltype_markergenes[CELL_TYPE_ONTOLOGY_ID] = celltype_markergenes[CELL_TYPE_ONTOLOGY_ID].str.replace('/', ', ')

celltype_markergenes
# Out:
#                  author_cell_type_description  \
# 0                                  Epithelium
# 1                                   Club Cell
# 2                               Ciliated Cell
# 3                                  Basal Cell
# 4             Alveolar Epithelial Type 1 Cell
# 5             Alveolar Epithelial Type 2 Cell
# 6                                 Endothelium
# 7                                 Artery Cell
# 8                                   Vein Cell
# 9                              Capillary Cell
# 10                             Lymphatic Cell
# 11                                     Stroma
# 12                              Smooth Muscle
# 13                                   Pericyte
# 14                                 Fibroblast
# 15                                     Immune
# 16                                     B Cell
# 17                                Plasma Cell
# 18                                 CD8+ Tcell
# 19                                 CD4+ Tcell
# 20  Natural Killer Cell/Natural Killer T Cell
# 21                                 Neutrophil
# 22                                  Mast Cell
# 23                                 Macrophage
# 24                                   Monocyte
# 25                    Myeloid Dendritic Cell
# 26                  Proliferating Immune Cell
#
#                    author_cell_type_markers           author_cell_type  \
# 0                                     EPCAM                       None
# 1                                   SCGB3A2                 Club/Basal
# 2                       FOXJ1; TP73; CCDC78                      Cilia
# 3                                KRT5; TP63                 Club/Basal
# 4                         AGER; PDPN; CLIC5                        AT1
# 5           SFTPB; SFTPC; SFTPD; MUC1; ETV5                        AT2
# 6                                     CLDN5                       None
# 7                                 GJA5; BMX                Artery_cell
# 8                                     ACKR1                  Vein_cell
# 9                                       CA4             Capillary_Cell
# 10                              PROX1; PDPN             Lymphatic_Cell
# 11                                   COL1A2                       None
# 12            CNN1; ACTA2; TAGLN; RGS5; DES                SM/Pericyte
# 13                CSPG4; TRPC6; PDGFRB;RGS5                SM/Pericyte
# 14                           COL1A1; PDGFRA                 Fibroblast
# 15                                    PTPRC                       None
# 16                 CD79A; CD24; MS4A1; CD19                     B_cell
# 17                      CD79A; CD27; SLAMF7                Plasma_cell
# 18             CD3E; CD8A;GZMH; GZMB; DUSP2                       CD8T
# 19                          CD3E; CD4; LEF1                       CD4T
# 20  KLRD1; NKG7; TYROBP; CD3E; CD8A; FCER1G                     NK/NKT
# 21           S100A8; S100A9; IFITM2; FCGR3B                 Neutrophil
# 22                      MS4A2; CPA3; TPSAB1                  Mast_cell
# 23                        MARCO; MSR1; MRC1                 Macrophage
# 24                     CD14; S100A8; FCGR3A                       Mono
# 25         MHCII; CLEC9A; LAMP3; CD1C; PLD4             Dendritic_cell
# 26                                      NaN  proliferating_immune_cell
#
#    cell_type_ontology_term_id
# 0                         NaN
# 1      CL:0000158, CL:0002633
# 2                  CL:1000271
# 3      CL:0000158, CL:0002633
# 4                  CL:0002062
# 5                  CL:0002063
# 6                         NaN
# 7                 NCIT:C49194
# 8                  CL:0002543
# 9                  CL:0002144
# 10                 CL:0002138
# 11                        NaN
# 12     CL:0000192, CL:0000669
# 13     CL:0000192, CL:0000669
# 14                 CL:0000057
# 15                        NaN
# 16                 CL:0000236
# 17                 CL:0000786
# 18                NCIT:C12542
# 19                NCIT:C12537
# 20    CL:0000623, BTO:0006501
# 21                 CL:0000775
# 22                NCIT:C12747
# 23                 CL:0000235
# 24                 CL:0000576
# 25                 CL:0000451
# 26               CMPO:0000241

# %%
# make all columns dtype category
celltype_markergenes = celltype_markergenes.astype('category')
celltype_markergenes
# Out:
#                  author_cell_type_description  \
# 0                                  Epithelium
# 1                                   Club Cell
# 2                               Ciliated Cell
# 3                                  Basal Cell
# 4             Alveolar Epithelial Type 1 Cell
# 5             Alveolar Epithelial Type 2 Cell
# 6                                 Endothelium
# 7                                 Artery Cell
# 8                                   Vein Cell
# 9                              Capillary Cell
# 10                             Lymphatic Cell
# 11                                     Stroma
# 12                              Smooth Muscle
# 13                                   Pericyte
# 14                                 Fibroblast
# 15                                     Immune
# 16                                     B Cell
# 17                                Plasma Cell
# 18                                 CD8+ Tcell
# 19                                 CD4+ Tcell
# 20  Natural Killer Cell/Natural Killer T Cell
# 21                                 Neutrophil
# 22                                  Mast Cell
# 23                                 Macrophage
# 24                                   Monocyte
# 25                    Myeloid Dendritic Cell
# 26                  Proliferating Immune Cell
#
#                    author_cell_type_markers           author_cell_type  \
# 0                                     EPCAM                        NaN
# 1                                   SCGB3A2                 Club/Basal
# 2                       FOXJ1; TP73; CCDC78                      Cilia
# 3                                KRT5; TP63                 Club/Basal
# 4                         AGER; PDPN; CLIC5                        AT1
# 5           SFTPB; SFTPC; SFTPD; MUC1; ETV5                        AT2
# 6                                     CLDN5                        NaN
# 7                                 GJA5; BMX                Artery_cell
# 8                                     ACKR1                  Vein_cell
# 9                                       CA4             Capillary_Cell
# 10                              PROX1; PDPN             Lymphatic_Cell
# 11                                   COL1A2                        NaN
# 12            CNN1; ACTA2; TAGLN; RGS5; DES                SM/Pericyte
# 13                CSPG4; TRPC6; PDGFRB;RGS5                SM/Pericyte
# 14                           COL1A1; PDGFRA                 Fibroblast
# 15                                    PTPRC                        NaN
# 16                 CD79A; CD24; MS4A1; CD19                     B_cell
# 17                      CD79A; CD27; SLAMF7                Plasma_cell
# 18             CD3E; CD8A;GZMH; GZMB; DUSP2                       CD8T
# 19                          CD3E; CD4; LEF1                       CD4T
# 20  KLRD1; NKG7; TYROBP; CD3E; CD8A; FCER1G                     NK/NKT
# 21           S100A8; S100A9; IFITM2; FCGR3B                 Neutrophil
# 22                      MS4A2; CPA3; TPSAB1                  Mast_cell
# 23                        MARCO; MSR1; MRC1                 Macrophage
# 24                     CD14; S100A8; FCGR3A                       Mono
# 25         MHCII; CLEC9A; LAMP3; CD1C; PLD4             Dendritic_cell
# 26                                      NaN  proliferating_immune_cell
#
#    cell_type_ontology_term_id
# 0                         NaN
# 1      CL:0000158, CL:0002633
# 2                  CL:1000271
# 3      CL:0000158, CL:0002633
# 4                  CL:0002062
# 5                  CL:0002063
# 6                         NaN
# 7                 NCIT:C49194
# 8                  CL:0002543
# 9                  CL:0002144
# 10                 CL:0002138
# 11                        NaN
# 12     CL:0000192, CL:0000669
# 13     CL:0000192, CL:0000669
# 14                 CL:0000057
# 15                        NaN
# 16                 CL:0000236
# 17                 CL:0000786
# 18                NCIT:C12542
# 19                NCIT:C12537
# 20    CL:0000623, BTO:0006501
# 21                 CL:0000775
# 22                NCIT:C12747
# 23                 CL:0000235
# 24                 CL:0000576
# 25                 CL:0000451
# 26               CMPO:0000241

# %%
celltype_markergenes.dtypes
# Out:
# author_cell_type_description    category
# author_cell_type_markers        category
# author_cell_type                category
# cell_type_ontology_term_id      category
# dtype: object

# %%
adata.uns[MARKER_GENES] = celltype_markergenes

# %%
adata.obs.columns
# Out:
# Index(['orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt',
#        'DoubletFinder', 'seurat_clusters', 'RNA_snn_res.0.5', 'anno',
#        'patientID', 'ident', 'sample_ID', 'donor_id', 'protocol_URL',
#        'institute', 'sample_collection_site',
#        'sample_collection_relative_time_point', 'library_ID',
#        'library_ID_repository', 'author_batch_notes',
#        'organism_ontology_term_id', 'manner_of_death', 'sample_source',
#        'sex_ontology_term_id', 'sample_collection_method', 'tissue_type',
#        'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text',
#        'sample_preservation_method', 'suspension_type', 'cell_enrichment',
#        'cell_viability_percentage', 'cell_number_loaded',
#        'sample_collection_year', 'assay_ontology_term_id',
#        'library_preparation_batch', 'library_sequencing_run',
#        'sequenced_fragment', 'sequencing_platform', 'is_primary_data',
#        'reference_genome', 'gene_annotation_version', 'alignment_software',
#        'intron_inclusion', 'disease_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id',
#        'development_stage_ontology_term_id'],
#       dtype='object')

# %%
adata.obs[CELL_TYPE_ONTOLOGY_ID] = adata.obs['anno'].map(dict(zip(celltype_markergenes[AUTHOR_CELL_TYPE], celltype_markergenes[CELL_TYPE_ONTOLOGY_ID])))
adata.obs[MARKER_GENES] = adata.obs['anno'].map(dict(zip(celltype_markergenes[AUTHOR_CELL_TYPE], celltype_markergenes[MARKER_GENES])))

adata.obs
# Out:
#                       orig.ident  nCount_RNA  nFeature_RNA  percent.mt  \
# AAACCCAAGTGTTGAA-1_3        JK03      5979.0          2711    3.110888
# AAACCCACAAACACGG-1_3        JK03      8711.0          3072    2.938813
# AAACCCAGTAGGATAT-1_3        JK03     24013.0          4975    3.202432
# AAACCCAGTCGATTAC-1_3        JK03      6906.0          2496    5.589343
# AAACCCATCCGCTGTT-1_3        JK03     10166.0          3378    2.705095
# ...                          ...         ...           ...         ...
# TTTGTTGCAGGTCCGT-1_19    JK22_29      1567.0           640    9.125718
# TTTGTTGCATTGAGGG-1_19    JK22_29       576.0           363   17.361111
# TTTGTTGGTCTAGTGT-1_19    JK22_29      5079.0          2097    2.736759
# TTTGTTGTCGTAACTG-1_19    JK22_29      5333.0          2590    2.118882
# TTTGTTGTCTCGTTTA-1_19    JK22_29      6592.0          2583    8.115898
#
#                       DoubletFinder seurat_clusters RNA_snn_res.0.5  \
# AAACCCAAGTGTTGAA-1_3        Singlet              12              12
# AAACCCACAAACACGG-1_3        Singlet               1               1
# AAACCCAGTAGGATAT-1_3        Singlet               5               5
# AAACCCAGTCGATTAC-1_3        Singlet               0               0
# AAACCCATCCGCTGTT-1_3        Singlet               1               1
# ...                             ...             ...             ...
# TTTGTTGCAGGTCCGT-1_19       Singlet              13              13
# TTTGTTGCATTGAGGG-1_19          None             NaN             NaN
# TTTGTTGGTCTAGTGT-1_19       Singlet              10              10
# TTTGTTGTCGTAACTG-1_19       Singlet              13              13
# TTTGTTGTCTCGTTTA-1_19       Singlet               4               4
#
#                                  anno patientID    ident  ... is_primary_data  \
# AAACCCAAGTGTTGAA-1_3   Capillary_Cell      JK03     JK03  ...            true
# AAACCCACAAACACGG-1_3           NK/NKT      JK03     JK03  ...            true
# AAACCCAGTAGGATAT-1_3             Mono      JK03     JK03  ...            true
# AAACCCAGTCGATTAC-1_3             CD4T      JK03     JK03  ...            true
# AAACCCATCCGCTGTT-1_3           NK/NKT      JK03     JK03  ...            true
# ...                               ...       ...      ...  ...             ...
# TTTGTTGCAGGTCCGT-1_19     SM/Pericyte   JK22_29  JK22_29  ...            true
# TTTGTTGCATTGAGGG-1_19             NaN   JK22_29  JK22_29  ...            true
# TTTGTTGGTCTAGTGT-1_19       Vein_cell   JK22_29  JK22_29  ...            true
# TTTGTTGTCGTAACTG-1_19     SM/Pericyte   JK22_29  JK22_29  ...            true
# TTTGTTGTCTCGTTTA-1_19            CD8T   JK22_29  JK22_29  ...            true
#
#                       reference_genome gene_annotation_version  \
# AAACCCAAGTGTTGAA-1_3            GRCh38                     N/A
# AAACCCACAAACACGG-1_3            GRCh38                     N/A
# AAACCCAGTAGGATAT-1_3            GRCh38                     N/A
# AAACCCAGTCGATTAC-1_3            GRCh38                     N/A
# AAACCCATCCGCTGTT-1_3            GRCh38                     N/A
# ...                                ...                     ...
# TTTGTTGCAGGTCCGT-1_19           GRCh38                     N/A
# TTTGTTGCATTGAGGG-1_19           GRCh38                     N/A
# TTTGTTGGTCTAGTGT-1_19           GRCh38                     N/A
# TTTGTTGTCGTAACTG-1_19           GRCh38                     N/A
# TTTGTTGTCTCGTTTA-1_19           GRCh38                     N/A
#
#                       alignment_software intron_inclusion  \
# AAACCCAAGTGTTGAA-1_3       version 6.1.2              yes
# AAACCCACAAACACGG-1_3       version 6.1.2              yes
# AAACCCAGTAGGATAT-1_3       version 6.1.2              yes
# AAACCCAGTCGATTAC-1_3       version 6.1.2              yes
# AAACCCATCCGCTGTT-1_3       version 6.1.2              yes
# ...                                  ...              ...
# TTTGTTGCAGGTCCGT-1_19      version 6.1.2              yes
# TTTGTTGCATTGAGGG-1_19      version 6.1.2              yes
# TTTGTTGGTCTAGTGT-1_19      version 6.1.2              yes
# TTTGTTGTCGTAACTG-1_19      version 6.1.2              yes
# TTTGTTGTCTCGTTTA-1_19      version 6.1.2              yes
#
#                       disease_ontology_term_id  \
# AAACCCAAGTGTTGAA-1_3              PATO:0000461
# AAACCCACAAACACGG-1_3              PATO:0000461
# AAACCCAGTAGGATAT-1_3              PATO:0000461
# AAACCCAGTCGATTAC-1_3              PATO:0000461
# AAACCCATCCGCTGTT-1_3              PATO:0000461
# ...                                        ...
# TTTGTTGCAGGTCCGT-1_19             PATO:0000461
# TTTGTTGCATTGAGGG-1_19             PATO:0000461
# TTTGTTGGTCTAGTGT-1_19             PATO:0000461
# TTTGTTGTCGTAACTG-1_19             PATO:0000461
# TTTGTTGTCTCGTTTA-1_19             PATO:0000461
#
#                       self_reported_ethnicity_ontology_term_id  \
# AAACCCAAGTGTTGAA-1_3                                     Asian
# AAACCCACAAACACGG-1_3                                     Asian
# AAACCCAGTAGGATAT-1_3                                     Asian
# AAACCCAGTCGATTAC-1_3                                     Asian
# AAACCCATCCGCTGTT-1_3                                     Asian
# ...                                                        ...
# TTTGTTGCAGGTCCGT-1_19                                    Asian
# TTTGTTGCATTGAGGG-1_19                                    Asian
# TTTGTTGGTCTAGTGT-1_19                                    Asian
# TTTGTTGTCGTAACTG-1_19                                    Asian
# TTTGTTGTCTCGTTTA-1_19                                    Asian
#
#                       development_stage_ontology_term_id  \
# AAACCCAAGTGTTGAA-1_3                      HsapDv:0000241
# AAACCCACAAACACGG-1_3                      HsapDv:0000241
# AAACCCAGTAGGATAT-1_3                      HsapDv:0000241
# AAACCCAGTCGATTAC-1_3                      HsapDv:0000241
# AAACCCATCCGCTGTT-1_3                      HsapDv:0000241
# ...                                                  ...
# TTTGTTGCAGGTCCGT-1_19                     HsapDv:0000241
# TTTGTTGCATTGAGGG-1_19                     HsapDv:0000241
# TTTGTTGGTCTAGTGT-1_19                     HsapDv:0000241
# TTTGTTGTCGTAACTG-1_19                     HsapDv:0000241
# TTTGTTGTCTCGTTTA-1_19                     HsapDv:0000241
#
#                       cell_type_ontology_term_id  \
# AAACCCAAGTGTTGAA-1_3                  CL:0002144
# AAACCCACAAACACGG-1_3     CL:0000623, BTO:0006501
# AAACCCAGTAGGATAT-1_3                  CL:0000576
# AAACCCAGTCGATTAC-1_3                 NCIT:C12537
# AAACCCATCCGCTGTT-1_3     CL:0000623, BTO:0006501
# ...                                          ...
# TTTGTTGCAGGTCCGT-1_19     CL:0000192, CL:0000669
# TTTGTTGCATTGAGGG-1_19                        NaN
# TTTGTTGGTCTAGTGT-1_19                 CL:0002543
# TTTGTTGTCGTAACTG-1_19     CL:0000192, CL:0000669
# TTTGTTGTCTCGTTTA-1_19                NCIT:C12542
#
#                                       author_cell_type_markers
# AAACCCAAGTGTTGAA-1_3                                       CA4
# AAACCCACAAACACGG-1_3   KLRD1; NKG7; TYROBP; CD3E; CD8A; FCER1G
# AAACCCAGTAGGATAT-1_3                      CD14; S100A8; FCGR3A
# AAACCCAGTCGATTAC-1_3                           CD3E; CD4; LEF1
# AAACCCATCCGCTGTT-1_3   KLRD1; NKG7; TYROBP; CD3E; CD8A; FCER1G
# ...                                                        ...
# TTTGTTGCAGGTCCGT-1_19                CSPG4; TRPC6; PDGFRB;RGS5
# TTTGTTGCATTGAGGG-1_19                                      NaN
# TTTGTTGGTCTAGTGT-1_19                                    ACKR1
# TTTGTTGTCGTAACTG-1_19                CSPG4; TRPC6; PDGFRB;RGS5
# TTTGTTGTCTCGTTTA-1_19             CD3E; CD8A;GZMH; GZMB; DUSP2
#
# [70051 rows x 49 columns]

# %% [markdown]
# # Check author cell type annotations and Cell Ontology IDs

# %%
adata.obs[CELL_TYPE_ONTOLOGY_ID].value_counts(dropna=False)
# Out:
# NaN                        15317
# NCIT:C12537                11365
# CL:0000623, BTO:0006501     8423
# CL:0002144                  6393
# CL:0000235                  4289
# NCIT:C12542                 4136
# CL:0000576                  3425
# CL:0000057                  3022
# NCIT:C12747                 2413
# CL:0002063                  2144
# CL:0002543                  2015
# CL:1000271                  1950
# CL:0000192, CL:0000669      1279
# NCIT:C49194                  912
# CL:0000236                   712
# CL:0002062                   554
# CL:0000158, CL:0002633       529
# CL:0000775                   521
# CL:0000786                   388
# CL:0002138                   264
# Name: cell_type_ontology_term_id, dtype: int64

# %%
adata.obs[AUTHOR_CELL_TYPE] = adata.obs['anno']
adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False)
# Out:
# NaN               12133
# CD4T              11365
# NK/NKT             8423
# Capillary_Cell     6393
# Macrophage         4289
# CD8T               4136
# Mono               3425
# Fibroblast         3022
# Mast_cell          2413
# AT2                2144
# DC1                2132
# Vein_cell          2015
# Cilia              1950
# SM/Pericyte        1279
# Artery_cell         912
# B_cell              712
# DC2                 676
# AT1                 554
# Club/Basal          529
# Neutrophil          521
# Plasma_cell         388
# Prolif.immune       376
# Lymphatic_Cell      264
# Name: author_cell_type, dtype: int64

# %%
adata.obs[MARKER_GENES].value_counts(dropna=False)
# Out:
# NaN                                        15317
# CD3E; CD4; LEF1                            11365
# KLRD1; NKG7; TYROBP; CD3E; CD8A; FCER1G     8423
# CA4                                         6393
# MARCO; MSR1; MRC1                           4289
# CD3E; CD8A;GZMH; GZMB; DUSP2                4136
# CD14; S100A8; FCGR3A                        3425
# COL1A1; PDGFRA                              3022
# MS4A2; CPA3; TPSAB1                         2413
# SFTPB; SFTPC; SFTPD; MUC1; ETV5             2144
# ACKR1                                       2015
# FOXJ1; TP73; CCDC78                         1950
# CSPG4; TRPC6; PDGFRB;RGS5                   1279
# GJA5; BMX                                    912
# CD79A; CD24; MS4A1; CD19                     712
# AGER; PDPN; CLIC5                            554
# KRT5; TP63                                   529
# S100A8; S100A9; IFITM2; FCGR3B               521
# CD79A; CD27; SLAMF7                          388
# PROX1; PDPN                                  264
# Name: author_cell_type_markers, dtype: int64

# %% [markdown]
# # Check whether ENSEMBL IDs in var

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [MIR1302-2HG, FAM138A, OR4F5, AL627309.1, AL627309.3, AL627309.2, AL627309.5, AL627309.4, AP006222.2, AL732372.1, OR4F29, AC114498.1, OR4F16, AL669831.2, LINC01409, FAM87B, LINC01128, LINC00115, FAM41C, AL645608.6, AL645608.2, AL645608.4, LINC02593, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.7, HES4, ISG15, AL645608.1, AGRN, AL645608.5, AL645608.8, RNF223, C1orf159, AL390719.3, LINC01342, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, AL162741.1, UBE2J2, LINC01786, SCNN1D, ACAP3, PUSL1, INTS11, AL139287.1, CPTP, TAS1R3, DVL1, MXRA8, AURKAIP1, CCNL2, MRPL20-AS1, MRPL20, AL391244.2, ANKRD65, AL391244.1, TMEM88B, LINC01770, VWA1, ATAD3C, ATAD3B, ATAD3A, TMEM240, SSU72, AL645728.1, FNDC10, AL691432.4, AL691432.2, MIB2, MMP23B, CDK11B, FO704657.1, SLC35E2B, CDK11A, SLC35E2A, NADK, GNB1, AL109917.1, CALML6, TMEM52, CFAP74, AL391845.2, GABRD, AL391845.1, PRKCZ, AL590822.2, PRKCZ-AS1, FAAP20, AL590822.1, SKI, ...]
#
# [38224 rows x 0 columns]

# %%
adata.var['gene_symbol'] = adata.var.index.astype(str)
adata.var
# Out:
#              gene_symbol
# MIR1302-2HG  MIR1302-2HG
# FAM138A          FAM138A
# OR4F5              OR4F5
# AL627309.1    AL627309.1
# AL627309.3    AL627309.3
# ...                  ...
# C21orf2          C21orf2
# AP001065.1    AP001065.1
# AP001065.2    AP001065.2
# AC004556.1    AC004556.1
# FAM231C          FAM231C
#
# [38224 rows x 1 columns]

# %%
ensembl_ids = pd.read_csv(f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/JKdata_genenames_and_ENSEMBL_IDs.csv", index_col=0)
ensembl_ids
# Out:
#                     V1           V2
# 1      ENSG00000243485  MIR1302-2HG
# 2      ENSG00000237613      FAM138A
# 3      ENSG00000186092        OR4F5
# 4      ENSG00000238009   AL627309.1
# 5      ENSG00000239945   AL627309.3
# ...                ...          ...
# 38559  ENSG00000274225   AP001065.1
# 38560  ENSG00000277352   AP001065.2
# 38561  ENSG00000276345   AC004556.1
# 38562  ENSG00000277475   AC213203.1
# 38563  ENSG00000268674      FAM231C
#
# [38563 rows x 2 columns]

# %%
adata.var['ensembl_id'] = adata.var['gene_symbol'].map(dict(zip(ensembl_ids['V2'], ensembl_ids['V1'])))
adata.var
# Out:
#              gene_symbol       ensembl_id
# index
# MIR1302-2HG  MIR1302-2HG  ENSG00000243485
# FAM138A          FAM138A  ENSG00000237613
# OR4F5              OR4F5  ENSG00000186092
# AL627309.1    AL627309.1  ENSG00000238009
# AL627309.3    AL627309.3  ENSG00000239945
# ...                  ...              ...
# C21orf2          C21orf2  ENSG00000160226
# AP001065.1    AP001065.1  ENSG00000274225
# AP001065.2    AP001065.2  ENSG00000277352
# AC004556.1    AC004556.1  ENSG00000276345
# FAM231C          FAM231C  ENSG00000268674
#
# [38224 rows x 2 columns]

# %%
adata.var['ensembl_id'].value_counts(dropna=False)
# Out:
# NaN                27
# ENSG00000229611     2
# ENSG00000237980     2
# ENSG00000224535     2
# ENSG00000065600     2
#                    ..
# ENSG00000260418     1
# ENSG00000029363     1
# ENSG00000146410     1
# ENSG00000237596     1
# ENSG00000268674     1
# Name: ensembl_id, Length: 37300, dtype: int64

# %%
adata.var.index.name = 'index'
adata.var['gene_symbol'] = adata.var.index.astype('category')

# %%
adata.var = adata.var.astype(str)

# %%
adata.var.dtypes
# Out:
# gene_symbol    object
# ensembl_id     object
# dtype: object

# %% [markdown]
# # Check raw data

# %%
adata.X.toarray().max()
# Out:
# 71764.0

# %%
# make checks for adata before saving raw

# Make specific columns numeric
adata.obs['cell_viability_percentage'] = pd.to_numeric(adata.obs['cell_viability_percentage'], errors='coerce')
adata.obs['cell_number_loaded'] = pd.to_numeric(adata.obs['cell_number_loaded'], errors='coerce')
adata.obs['sample_collection_year'] = pd.to_numeric(adata.obs['sample_collection_year'], errors='coerce')


numeric_cols = ['nCount_RNA', 'nFeature_RNA', 'percent.mt', 'seurat_clusters', 'RNA_snn_res.0.5']
for col in numeric_cols:
    adata.obs[col] = pd.to_numeric(adata.obs[col], errors='coerce')

# Make df indices str
adata.obs.index = adata.obs.index.astype('str')
adata.var.index = adata.var.index.astype('str')
adata.uns[MARKER_GENES].index = adata.uns[MARKER_GENES].index.astype('str')
adata.var_names = adata.var_names.astype('str')

# %%
adata.X = adata.X.astype(np.int64)

# %%
adata.raw = adata

# %%
adata.X
# Out:
# <70051x38224 sparse matrix of type '<class 'numpy.int64'>'
# 	with 203942545 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <70051x38224 sparse matrix of type '<class 'numpy.int64'>'
# 	with 203942545 stored elements in Compressed Sparse Row format>

# %%
adata.X.toarray().max()
# Out:
# 71764

# %%
adata.raw.X.toarray().max()
# Out:
# 71764

# %% [markdown]
# ## Validation result
#
# ### UNS Validation
# - OK: Tier 1 UNS Google Sheet
# - OK: Tier 1 UNS AnnData Object
#
# ### OBS Validation
# - OK: Tier 1 OBS Google Sheet
# - OK: Tier 1 OBS AnnData Object

# %% [markdown]
# # Data Submission Status
#
# - CHECK: Raw counts in X and in raw
# - CHECK: Tier 1 Metadata in OBS
# - CHECK: Cell Ontology IDs in OBS
# - CHECK: Author cell type in OBS
# - CHECK: Marker genes in UNS
# - CHECK: ENSEMBL IDs in var
#
#
# ### Revisions:
#
# DONE

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
