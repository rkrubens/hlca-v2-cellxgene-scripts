# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import anndata2ri
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"

# %%
DATASET_ID = "Shaykhiev_publ"
H5AD_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/{DATASET_ID}.h5ad"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
# Name constants
AUTHOR_CELL_TYPE_L0 = 'author_cell_type_level_0'
AUTHOR_CELL_TYPE_L1 = 'author_cell_type_level_1'

CELL_TYPE_ONTOLOGY_ID_L0 = 'cell_type_ontology_term_id_level_0'
CELL_TYPE_ONTOLOGY_ID_L1 = 'cell_type_ontology_term_id_level_1'

CELL_TYPE_ONTOLOGY_LABEL_L0 = 'cell_type_ontology_term_label_level_0'
CELL_TYPE_ONTOLOGY_LABEL_L1 = 'cell_type_ontology_term_label_level_1'

AUTHOR_CELL_TYPE_DESCRIPTION_L0 = 'author_cell_type_description_level_0'
AUTHOR_CELL_TYPE_DESCRIPTION_L1 = 'author_cell_type_description_level_1'

MARKER_GENES_L0 = 'author_cell_type_markers_level_0'
MARKER_GENES_L1 = 'author_cell_type_markers_level_1'

# Finest grained annotation will be generic dataset cell type
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'
CELL_TYPE_ONTOLOGY_LABEL = 'cell_type_ontology_term_label'
MARKER_GENES = 'author_cell_type_markers'
AUTHOR_CELL_TYPE_DESCRIPTION = 'author_cell_type_description'

# %% [markdown]
# # Load data

# %%
adata = sc.read_h5ad(H5AD_PATH)
obs = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "obs")
uns = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "uns")

# %% [markdown]
# # Validate obs and uns from Tier 1 Metadata Template

# %%
val_workflow = ValidationWorkflow(
    input = uns,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                                                title         study_PI  \
# 0  A Unique Cellular Organization of Human Distal...  Renat Shaykhiev
#
#   batch_condition default_embedding unpublished comments
# 0       sample_ID              umap   published

# %%
val_workflow = ValidationWorkflow(
    input = obs,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation workflow successful. Returning OBS dataframe.
#       sample_ID donor_id                                       protocol_URL  \
# 0      N1_pre-T       N1  https://cdn.10xgenomics.com/image/upload/v1660...
# 1          N1_T       N1  https://cdn.10xgenomics.com/image/upload/v1660...
# 2      N2_pre-T       N2  https://cdn.10xgenomics.com/image/upload/v1660...
# 3          N2_P       N2  https://cdn.10xgenomics.com/image/upload/v1660...
# 4          N2_T       N2  https://cdn.10xgenomics.com/image/upload/v1660...
# 5      N3_pre-T       N3  https://assets.ctfassets.net/an68im79xiti/51xG...
# 6      N4_pre-T       N4  https://assets.ctfassets.net/an68im79xiti/51xG...
# 7          N4_P       N4  https://assets.ctfassets.net/an68im79xiti/51xG...
# 8          N4_T       N4  https://assets.ctfassets.net/an68im79xiti/51xG...
# 9      N5_pre-T       N5  https://assets.ctfassets.net/an68im79xiti/51xG...
# 10     N6_pre-T       N6  https://assets.ctfassets.net/an68im79xiti/51xG...
# 11         N6_P       N6  https://assets.ctfassets.net/an68im79xiti/51xG...
# 12         N6_T       N6  https://assets.ctfassets.net/an68im79xiti/51xG...
# 13     N7_pre-T       N7  https://assets.ctfassets.net/an68im79xiti/51xG...
# 14     N8_pre-T       N8  https://assets.ctfassets.net/an68im79xiti/51xG...
# 15         N8_P       N8  https://assets.ctfassets.net/an68im79xiti/51xG...
# 16         N8_T       N8  https://assets.ctfassets.net/an68im79xiti/51xG...
# 17     N9_pre-T       N9  https://assets.ctfassets.net/an68im79xiti/51xG...
# 18    N10_pre-T      N10  https://assets.ctfassets.net/an68im79xiti/51xG...
# 19        N10_P      N10  https://assets.ctfassets.net/an68im79xiti/51xG...
# 20        N10_T      N10  https://assets.ctfassets.net/an68im79xiti/51xG...
# 21  N11_pre-T-A      N11  https://cdn.10xgenomics.com/image/upload/v1660...
# 22  N11_pre-T-B      N11  https://cdn.10xgenomics.com/image/upload/v1660...
# 23        N11_T      N11  https://cdn.10xgenomics.com/image/upload/v1660...
# 24    N12_pre-T      N12  https://assets.ctfassets.net/an68im79xiti/51xG...
# 25      C1_COPD       C1  https://assets.ctfassets.net/an68im79xiti/51xG...
# 26      C2_COPD       C2  https://assets.ctfassets.net/an68im79xiti/51xG...
# 27      C3_COPD       C3  https://assets.ctfassets.net/an68im79xiti/51xG...
# 28      C4_COPD       C4  https://assets.ctfassets.net/an68im79xiti/51xG...
# 29      C5_COPD       C5  https://assets.ctfassets.net/an68im79xiti/51xG...
#
#                                   institute sample_collection_site  \
# 0   Weill Cornell Epigenomics Core Facility                    UNC
# 1   Weill Cornell Epigenomics Core Facility                    UNC
# 2   Weill Cornell Epigenomics Core Facility                    UNC
# 3   Weill Cornell Epigenomics Core Facility                    UNC
# 4   Weill Cornell Epigenomics Core Facility                    UNC
# 5   Weill Cornell Epigenomics Core Facility                    UNC
# 6   Weill Cornell Epigenomics Core Facility                    UNC
# 7   Weill Cornell Epigenomics Core Facility                    UNC
# 8   Weill Cornell Epigenomics Core Facility                    UNC
# 9   Weill Cornell Epigenomics Core Facility                    UNC
# 10  Weill Cornell Epigenomics Core Facility                    UNC
# 11  Weill Cornell Epigenomics Core Facility                    UNC
# 12  Weill Cornell Epigenomics Core Facility                    UNC
# 13  Weill Cornell Epigenomics Core Facility                    UNC
# 14  Weill Cornell Epigenomics Core Facility                    UNC
# 15  Weill Cornell Epigenomics Core Facility                    UNC
# 16  Weill Cornell Epigenomics Core Facility                    UNC
# 17  Weill Cornell Epigenomics Core Facility                    UNC
# 18  Weill Cornell Epigenomics Core Facility                    UNC
# 19  Weill Cornell Epigenomics Core Facility                    UNC
# 20  Weill Cornell Epigenomics Core Facility                    UNC
# 21  Weill Cornell Epigenomics Core Facility                     CU
# 22  Weill Cornell Epigenomics Core Facility                     CU
# 23  Weill Cornell Epigenomics Core Facility                     CU
# 24  Weill Cornell Epigenomics Core Facility                     VU
# 25  Weill Cornell Epigenomics Core Facility                    UNC
# 26  Weill Cornell Epigenomics Core Facility                    UNC
# 27  Weill Cornell Epigenomics Core Facility                    UNC
# 28  Weill Cornell Epigenomics Core Facility                     VU
# 29  Weill Cornell Epigenomics Core Facility                     VU
#
#    sample_collection_relative_time_point   library_ID library_ID_repository  \
# 0                                    N/A     N1_pre-T                   N/A
# 1                                    N/A         N1_T                   N/A
# 2                                    N/A     N2_pre-T                   N/A
# 3                                    N/A         N2_P                   N/A
# 4                                    N/A         N2_T                   N/A
# 5                                    N/A     N3_pre-T                   N/A
# 6                                    N/A     N4_pre-T                   N/A
# 7                                    N/A         N4_P                   N/A
# 8                                    N/A         N4_T                   N/A
# 9                                    N/A     N5_pre-T                   N/A
# 10                                   N/A     N6_pre-T                   N/A
# 11                                   N/A         N6_P                   N/A
# 12                                   N/A         N6_T                   N/A
# 13                                   N/A     N7_pre-T                   N/A
# 14                                   N/A     N8_pre-T                   N/A
# 15                                   N/A         N8_P                   N/A
# 16                                   N/A         N8_T                   N/A
# 17                                   N/A     N9_pre-T                   N/A
# 18                                   N/A    N10_pre-T                   N/A
# 19                                   N/A        N10_P                   N/A
# 20                                   N/A        N10_T                   N/A
# 21                                   N/A  N11_pre-T-A                   N/A
# 22                                   N/A  N11_pre-T-B                   N/A
# 23                                   N/A        N11_T                   N/A
# 24                                   N/A    N12_pre-T                   N/A
# 25                                   N/A      C1_COPD                   N/A
# 26                                   N/A      C2_COPD                   N/A
# 27                                   N/A      C3_COPD                   N/A
# 28                                   N/A      C4_COPD                   N/A
# 29                                   N/A      C5_COPD                   N/A
#
#    author_batch_notes organism_ontology_term_id  ... sequenced_fragment  \
# 0                 N/A            NCBITaxon:9606  ...        3 prime tag
# 1                 N/A            NCBITaxon:9606  ...        3 prime tag
# 2                 N/A            NCBITaxon:9606  ...        3 prime tag
# 3                 N/A            NCBITaxon:9606  ...        3 prime tag
# 4                 N/A            NCBITaxon:9606  ...        3 prime tag
# 5                 N/A            NCBITaxon:9606  ...        3 prime tag
# 6                 N/A            NCBITaxon:9606  ...        3 prime tag
# 7                 N/A            NCBITaxon:9606  ...        3 prime tag
# 8                 N/A            NCBITaxon:9606  ...        3 prime tag
# 9                 N/A            NCBITaxon:9606  ...        3 prime tag
# 10                N/A            NCBITaxon:9606  ...        3 prime tag
# 11                N/A            NCBITaxon:9606  ...        3 prime tag
# 12                N/A            NCBITaxon:9606  ...        3 prime tag
# 13                N/A            NCBITaxon:9606  ...        3 prime tag
# 14                N/A            NCBITaxon:9606  ...        3 prime tag
# 15                N/A            NCBITaxon:9606  ...        3 prime tag
# 16                N/A            NCBITaxon:9606  ...        3 prime tag
# 17                N/A            NCBITaxon:9606  ...        3 prime tag
# 18                N/A            NCBITaxon:9606  ...        3 prime tag
# 19                N/A            NCBITaxon:9606  ...        3 prime tag
# 20                N/A            NCBITaxon:9606  ...        3 prime tag
# 21                N/A            NCBITaxon:9606  ...        3 prime tag
# 22                N/A            NCBITaxon:9606  ...        3 prime tag
# 23                N/A            NCBITaxon:9606  ...        3 prime tag
# 24                N/A            NCBITaxon:9606  ...        3 prime tag
# 25                N/A            NCBITaxon:9606  ...        3 prime tag
# 26                N/A            NCBITaxon:9606  ...        3 prime tag
# 27                N/A            NCBITaxon:9606  ...        3 prime tag
# 28                N/A            NCBITaxon:9606  ...        3 prime tag
# 29                N/A            NCBITaxon:9606  ...        3 prime tag
#
#    sequencing_platform is_primary_data reference_genome  \
# 0          EFO:0008565            true           GRCh38
# 1          EFO:0008565            true           GRCh38
# 2          EFO:0008565            true           GRCh38
# 3          EFO:0008565            true           GRCh38
# 4          EFO:0008565            true           GRCh38
# 5          EFO:0008565            true           GRCh38
# 6          EFO:0008565            true           GRCh38
# 7          EFO:0008565            true           GRCh38
# 8          EFO:0008565            true           GRCh38
# 9          EFO:0008637            true           GRCh38
# 10         EFO:0008637            true           GRCh38
# 11         EFO:0008637            true           GRCh38
# 12         EFO:0008637            true           GRCh38
# 13         EFO:0008637            true           GRCh38
# 14         EFO:0008637            true           GRCh38
# 15         EFO:0008637            true           GRCh38
# 16         EFO:0008637            true           GRCh38
# 17         EFO:0008637            true           GRCh38
# 18         EFO:0008637            true           GRCh38
# 19         EFO:0008637            true           GRCh38
# 20         EFO:0008637            true           GRCh38
# 21         EFO:0008563            true           GRCh38
# 22         EFO:0008563            true           GRCh38
# 23         EFO:0008563            true           GRCh38
# 24         EFO:0008637            true           GRCh38
# 25         EFO:0008565            true           GRCh38
# 26         EFO:0008565            true           GRCh38
# 27         EFO:0008637            true           GRCh38
# 28         EFO:0008637            true           GRCh38
# 29         EFO:0008637            true           GRCh38
#
#    gene_annotation_version alignment_software intron_inclusion  \
# 0                      v98   cellranger-6.0.0               no
# 1                      v98   cellranger-6.0.0               no
# 2                      v98   cellranger-6.0.0               no
# 3                      v98   cellranger-6.0.0               no
# 4                      v98   cellranger-6.0.0               no
# 5                      v98   cellranger-6.0.0               no
# 6                      v98   cellranger-6.0.0               no
# 7                      v98   cellranger-6.0.0               no
# 8                      v98   cellranger-6.0.0               no
# 9                      v98   cellranger-6.0.0               no
# 10                     v98   cellranger-6.0.0               no
# 11                     v98   cellranger-6.0.0               no
# 12                     v98   cellranger-6.0.0               no
# 13                     v98   cellranger-6.0.0               no
# 14                     v98   cellranger-6.0.0               no
# 15                     v98   cellranger-6.0.0               no
# 16                     v98   cellranger-6.0.0               no
# 17                     v98   cellranger-6.0.0               no
# 18                     v98   cellranger-6.0.0               no
# 19                     v98   cellranger-6.0.0               no
# 20                     v98   cellranger-6.0.0               no
# 21                     v98   cellranger-6.0.0               no
# 22                     v98   cellranger-6.0.0               no
# 23                     v98   cellranger-6.0.0               no
# 24                     v98   cellranger-6.0.0               no
# 25                     v98   cellranger-6.0.0               no
# 26                     v98   cellranger-6.0.0               no
# 27                     v98   cellranger-6.0.0               no
# 28                     v98   cellranger-6.0.0               no
# 29                     v98   cellranger-6.0.0               no
#
#    disease_ontology_term_id self_reported_ethnicity_ontology_term_id  \
# 0              PATO:0000461                                  unknown
# 1              PATO:0000461                                  unknown
# 2              PATO:0000461                                  unknown
# 3              PATO:0000461                                  unknown
# 4              PATO:0000461                                  unknown
# 5              PATO:0000461                                  unknown
# 6              PATO:0000461                                  unknown
# 7              PATO:0000461                                  unknown
# 8              PATO:0000461                                  unknown
# 9              PATO:0000461                                  unknown
# 10             PATO:0000461                                  unknown
# 11             PATO:0000461                                  unknown
# 12             PATO:0000461                                  unknown
# 13             PATO:0000461                                  unknown
# 14             PATO:0000461                                  unknown
# 15             PATO:0000461                                  unknown
# 16             PATO:0000461                                  unknown
# 17             PATO:0000461                                  unknown
# 18             PATO:0000461                                  unknown
# 19             PATO:0000461                                  unknown
# 20             PATO:0000461                                  unknown
# 21             PATO:0000461                                  unknown
# 22             PATO:0000461                                  unknown
# 23             PATO:0000461                                  unknown
# 24             PATO:0000461                                  unknown
# 25            MONDO:0005002                                  unknown
# 26            MONDO:0005002                                  unknown
# 27            MONDO:0005002                                  unknown
# 28            MONDO:0005002                                  unknown
# 29            MONDO:0005002                                  unknown
#
#    development_stage_ontology_term_id
# 0                      HsapDv:0000237
# 1                      HsapDv:0000237
# 2                      HsapDv:0000264
# 3                      HsapDv:0000264
# 4                      HsapDv:0000264
# 5                      HsapDv:0000241
# 6                      HsapDv:0000238
# 7                      HsapDv:0000238
# 8                      HsapDv:0000238
# 9                      HsapDv:0000241
# 10                     HsapDv:0000241
# 11                     HsapDv:0000241
# 12                     HsapDv:0000241
# 13                     HsapDv:0000237
# 14                     HsapDv:0000238
# 15                     HsapDv:0000238
# 16                     HsapDv:0000238
# 17                     HsapDv:0000241
# 18                     HsapDv:0000238
# 19                     HsapDv:0000238
# 20                     HsapDv:0000238
# 21                     HsapDv:0000239
# 22                     HsapDv:0000239
# 23                     HsapDv:0000239
# 24                     HsapDv:0000264
# 25                     HsapDv:0000240
# 26                     HsapDv:0000240
# 27                     HsapDv:0000239
# 28                     HsapDv:0000240
# 29                     HsapDv:0000241
#
# [30 rows x 37 columns]

# %% [markdown]
# # Validate obs and uns from adata

# %%
merger = AnnDataMerger(
    adata = adata,
    uns_df = uns
)

adata = merger.add_uns_metadata()

adata
# Out:
# AnnData object with n_obs × n_vars = 115788 × 36591
#     obs: 'sample_ID', 'algorithm_resolution_version', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'author_cell_type', 'cell_type_ontology_term', 'cell_type_ontology_id', 'marker_genes'
#     var: 'feature_types', 'gene_ids', 'genome', 'name'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     layers: 'counts'

# %%
val_workflow = ValidationWorkflow(
    input = adata,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
# Out:
# Validation error(s) encountered.
# {
# │   'cell_viability_percentage': "Entries must be integers, floats, or 'NA'/'na'/'N/A'.",
# │   'cell_number_loaded': "Entries must be integers, floats, or 'NA'/'na'/'N/A'.",
# │   'sample_collection_year': "Entries must be integers, floats, or 'NA'/'na'/'N/A'."
# }
# Error containing field: cell_viability_percentage
# Error message: Entries must be integers, floats, or 'NA'/'na'/'N/A'.
# Value counts:
# 0.8    115788
# Name: cell_viability_percentage, dtype: int64
# Error containing field: cell_number_loaded
# Error message: Entries must be integers, floats, or 'NA'/'na'/'N/A'.
# Value counts:
# 10000.0    115788
# Name: cell_number_loaded, dtype: int64
# Error containing field: sample_collection_year
# Error message: Entries must be integers, floats, or 'NA'/'na'/'N/A'.
# Value counts:
# 2019.0    94239
# 2018.0    13699
# 2020.0     7850
# Name: sample_collection_year, dtype: int64
# Returning error-containing OBS dataframe.

# %% [markdown]
# # Add author cell type markers to UNS

# %%
adata.obs[MARKER_GENES] = adata.obs['marker_genes']
adata.obs[CELL_TYPE_ONTOLOGY_LABEL] = adata.obs['cell_type_ontology_term']
adata.obs[CELL_TYPE_ONTOLOGY_ID] = adata.obs['cell_type_ontology_id']
adata.obs.columns
# Out:
# Index(['sample_ID', 'algorithm_resolution_version', 'donor_id', 'protocol_URL',
#        'institute', 'sample_collection_site',
#        'sample_collection_relative_time_point', 'library_ID',
#        'library_ID_repository', 'author_batch_notes',
#        'organism_ontology_term_id', 'manner_of_death', 'sample_source',
#        'sex_ontology_term_id', 'sample_collection_method', 'tissue_type',
#        'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text',
#        'sample_preservation_method', 'suspension_type', 'cell_enrichment',
#        'cell_viability_percentage', 'cell_number_loaded',
#        'sample_collection_year', 'assay_ontology_term_id',
#        'library_preparation_batch', 'library_sequencing_run',
#        'sequenced_fragment', 'sequencing_platform', 'is_primary_data',
#        'reference_genome', 'gene_annotation_version', 'alignment_software',
#        'intron_inclusion', 'disease_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id',
#        'development_stage_ontology_term_id', 'author_cell_type',
#        'cell_type_ontology_term', 'cell_type_ontology_id', 'marker_genes',
#        'author_cell_type_markers', 'cell_type_ontology_term_label',
#        'cell_type_ontology_term_id'],
#       dtype='object')

# %%
cell_type_mapping_df = adata.obs[[AUTHOR_CELL_TYPE, CELL_TYPE_ONTOLOGY_ID, CELL_TYPE_ONTOLOGY_LABEL, MARKER_GENES]].copy().drop_duplicates(subset=AUTHOR_CELL_TYPE).reset_index(drop=True)
cell_type_mapping_df
# Out:
#                                    author_cell_type  \
# 0                 Alveolar epithelial cells, type 2
# 1           Secretory cells, major (common) subtype
# 2                                         Monocytes
# 3                       Fibroblasts, common subtype
# 4                    Macrophages, M1-2 intermediate
# 5          Terminal airway-enriched secretory cells
# 6          Smooth muscle cells, vascular enriched 2
# 7            Macrophages, non-inflammatory, M2-like
# 8            Fibroblasts, matrix and myofibroblasts
# 9                                Intermediate cells
# 10                   Ciliated cells, secretory-like
# 11                T cells, central memory and naïve
# 12                                      Basal cells
# 13         Smooth muscle cells, vascular enriched 1
# 14  Endothelial cells, capillary, aerocyte-enriched
# 15           Endothelial cells, venous; fenestrated
# 16             Endothelial cells, capillary, common
# 17                Pre-ciliated (deuterosomal) cells
# 18                             Neuroendocrine cells
# 19                                     Plasma cells
# 20                      Endothelial cells, arterial
# 21          Dendritic cells, conventional (myeloid)
# 22                     Endothelial cells, lymphatic
# 23                Fibroblasts, adventitial-enriched
# 24                                        Pericytes
# 25                            Undetermined or mixed
# 26                                          B cells
# 27                  CD8+ enriched T, common subtype
# 28                         T cells, resident memory
# 29             Smooth muscle cells, airway-enriched
# 30                          T-NK intermediate cells
# 31                             Natural killer cells
# 32                   Fibroblasts, alveolar-enriched
# 33            Endothelial cells, smooth muscle-like
# 34                          Secretory cells, mucous
# 35                    Chondrocytes, cartilage cells
# 36           Ciliated cells, major (common) subtype
# 37                             Glial, Schwann cells
# 38                                     Hybrid cells
# 39                                       Mast cells
# 40                Alveolar epithelial cells, type 1
# 41                   T cells, interferon-stimulated
# 42                                        Ionocytes
# 43                          Glandular, serous cells
# 44                               T cells, undefined
# 45                          Glandular, mucous cells
# 46                              Myoepithelial cells
# 47               Macrophages, inflammatory, M1-like
# 48                                      Neutrophils
# 49                    Dendritic cells, plasmacytoid
#
#    cell_type_ontology_term_id  \
# 0                  CL:0002063
# 1                  CL:0019001
# 2                  CL:0000576
# 3                  CL:2000093
# 4       CL:0000235;CL:0000890
# 5                  CL:1000333
# 6                  CL:0019018
# 7                  CL:0000890
# 8                         NaN
# 9                  CL:4033048
# 10                        NaN
# 11      CL:0000904;CL:0000895
# 12                 CL:0002633
# 13                 CL:0019018
# 14      CL:4028002;CL:4028003
# 15                 CL:4033008
# 16                 CL:2000016
# 17                 CL:4033044
# 18                 CL:1000223
# 19                 CL:0000786
# 20                 CL:1000413
# 21                 CL:0000990
# 22                 CL:0002138
# 23                        NaN
# 24                 CL:0000669
# 25                        NaN
# 26                 CL:0000236
# 27      CL:0000900;CL:0000909
# 28                 CL:4033039
# 29                 CL:4033017
# 30                 CL:0000814
# 31                 CL:0000623
# 32      CL:4028004;CL:4028006
# 33                 CL:0000359
# 34                 CL:0002370
# 35                 CL:0000138
# 36                 CL:0002145
# 37                 CL:0002573
# 38                        NaN
# 39                 CL:0000097
# 40                 CL:0002062
# 41     CL:0000545; CL:0000899
# 42                 CL:0017000
# 43                 CL:4033005
# 44                        NaN
# 45                 CL:4033022
# 46                 CL:4033003
# 47                 CL:0000235
# 48                 CL:0000775
# 49                 CL:0000784
#
#                         cell_type_ontology_term_label  \
# 0                                  type II pneumocyte
# 1                        tracheobronchial serous cell
# 2                                            monocyte
# 3                         bronchus fibroblast of lung
# 4   inflammatory macrophage;alternatively activate...
# 5     serous cell of epithelium of lobular bronchiole
# 6                     blood vessel smooth muscle cell
# 7                 alternatively activated macrophages
# 8                                      Myofibroblasts
# 9                         respiratory suprabasal cell
# 10                                 SAA+ ciliated cell
# 11  central memory CD4-positive, alpha-beta T cell...
# 12                             respiratory basal cell
# 13                    blood vessel smooth muscle cell
# 14  alveolar capillary type 1 endothelial cell;alv...
# 15        vein endothelial cell of respiratory system
# 16                lung microvascular endothelial cell
# 17                                  deuterosomal cell
# 18                           lung neuroendocrine cell
# 19                                        plasma cell
# 20                         endothelial cell of artery
# 21                        conventional dendritic cell
# 22               endothelial cell of lymphatic vessel
# 23                            Adventitial fibroblasts
# 24                                           pericyte
# 25                                        unkown cell
# 26                                             B cell
# 27  naive thymus-derived CD8-positive, alpha-beta ...
# 28  lung resident memory CD8-positive, alpha-beta ...
# 29                     bronchiolar smooth muscle cell
# 30                                   mature NK T cell
# 31                                natural killer cell
# 32  alveolar type 1 fibroblast cell;alveolar type ...
# 33             vascular associated smooth muscle cell
# 34                            respiratory goblet cell
# 35                                        chondrocyte
# 36                      ciliated cell of the bronchus
# 37                                       Schwann cell
# 38                              mucous ciliated cell
# 39                                          mast cell
# 40                                  type I pneumocyte
# 41                  T-helper 1 cell; T-helper 17 cell
# 42                                 pulmonary ionocyte
# 43  serous secreting cell of bronchus submucosal g...
# 44                                      unkown T cell
# 45  mucus secreting cell of bronchus submucosal gland
# 46    myoepithelial cell of bronchus submucosal gland
# 47                            inflammatory macrophage
# 48                                         neutrophil
# 49                        plasmacytoid dendritic cell
#
#                              author_cell_type_markers
# 0                                               SFTPC
# 1                    SCGB1A1; negative for BC markers
# 2   VCAN; FCN1; CD163 (shared with macrophages; bu...
# 3                                                 NaN
# 4                                                 NaN
# 5   SFTPB and/or SCGB3A2; a bridge cluster between...
# 6   higher expression of ADIRF than in other SM cl...
# 7                      APOE; CCL18; MSR1; MRC1; FABP4
# 8   ELN; COL1A1; MMP2 - higher expession of these ...
# 9   intermediate expression of BC and secretory ma...
# 10                        ciliated + SAA1; SAA2; SAA4
# 11                             LEF1; CCR7; SELL; IL7R
# 12                     high expression of KRT5; KRT15
# 13                                                NaN
# 14  HPGD; EDNRB; IL1RL1 - higher expression than i...
# 15                          ACKR1; PLVAP; SELE; POSTN
# 16                                                NaN
# 17                                 CCNO; HES6; CDC20B
# 18                           CHGA; GRP; CALCA; SEC11C
# 19  JCHAIN; MZB1; IGHA1; IGKC (also express B cell...
# 20                                 IGFBP3; GJA5; DKK2
# 21  FCER1A; CD86; CD1C; CD1E; high expression of H...
# 22                         CCL21; MMRN1; LYVE1; PROX1
# 23                                       CCL19; SFRP2
# 24                              COX4I2; KCNK3; PDGFRB
# 25                                                NaN
# 26                          MS4A1; BANK1; CD19; CD79A
# 27                                                NaN
# 28                         PDCD1; ITGA1; CXCR6; CD101
# 29                       DES; TPP2; CNN1; BCHE; PRUNE
# 30                 combined markers of T and NK cells
# 31  GNLY; NKG7; negative for T cell markers CD3D a...
# 32                           GPC3; FGFR4; VEGFD; WNT2
# 33                combined markers of En and SM cells
# 34                    MUC5AC; negative for BC markers
# 35                                SNORC; COL2A1; ACAN
# 36                                 FOXJ1; CAPS; TPPP3
# 37                           CDH19; GPM6B; MPZ; NRXN1
# 38             ciliated + secretory SCGB1A1 or MUC5AC
# 39                           TPSB2; TPSAB1; CPA3; KIT
# 40                                               AGER
# 41                   IFIT1; IFIT2; OASL; ISG15; HERC5
# 42                             ATP6V0B; FOXI1; TMEM61
# 43                                     LYZ; LTF; PRR4
# 44                                                NaN
# 45                                      MUC5B; BPIFB2
# 46  KRT14; ACTA2; cluster located within SMG clust...
# 47                          SPP1; CCL3; CXCL9; CXCL10
# 48                      CSF3R; S100A8; FCGR3B; IFITM2
# 49                            IL3RA; IRF4; IRF7; GZMB

# %%
adata.uns[MARKER_GENES] = cell_type_mapping_df
adata
# Out:
# AnnData object with n_obs × n_vars = 115788 × 36591
#     obs: 'sample_ID', 'algorithm_resolution_version', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'author_cell_type', 'cell_type_ontology_term', 'cell_type_ontology_id', 'marker_genes', 'author_cell_type_markers', 'cell_type_ontology_term_label', 'cell_type_ontology_term_id'
#     var: 'feature_types', 'gene_ids', 'genome', 'name'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments', 'author_cell_type_markers'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     layers: 'counts'

# %% [markdown]
# # Check author cell type annotations and Cell Ontology IDs

# %%
adata.obs[AUTHOR_CELL_TYPE].value_counts()
# Out:
# T cells, central memory and naïve                  10103
# Ciliated cells, major (common) subtype              9580
# Endothelial cells, venous; fenestrated              6759
# Monocytes                                           6247
# Alveolar epithelial cells, type 2                   6246
# Fibroblasts, common subtype                         5139
# T-NK intermediate cells                             4836
# Secretory cells, major (common) subtype             4734
# B cells                                             4601
# Ciliated cells, secretory-like                      4487
# Neutrophils                                         4142
# CD8+ enriched T, common subtype                     3577
# Smooth muscle cells, vascular enriched 1            3523
# Endothelial cells, capillary, common                3430
# Endothelial cells, capillary, aerocyte-enriched     3420
# Basal cells                                         2916
# Mast cells                                          2713
# Macrophages, non-inflammatory, M2-like              2390
# Intermediate cells                                  2355
# Natural killer cells                                2303
# Macrophages, M1-2 intermediate                      1946
# Dendritic cells, conventional (myeloid)             1643
# Secretory cells, mucous                             1544
# T cells, undefined                                  1477
# Fibroblasts, matrix and myofibroblasts              1320
# Smooth muscle cells, vascular enriched 2            1281
# Macrophages, inflammatory, M1-like                  1263
# Glandular, serous cells                             1249
# Fibroblasts, adventitial-enriched                   1081
# Pre-ciliated (deuterosomal) cells                    900
# Hybrid cells                                         876
# Endothelial cells, lymphatic                         870
# Undetermined or mixed                                783
# Terminal airway-enriched secretory cells             719
# T cells, resident memory                             643
# Smooth muscle cells, airway-enriched                 634
# Pericytes                                            619
# Chondrocytes, cartilage cells                        536
# Plasma cells                                         523
# Endothelial cells, smooth muscle-like                502
# Glandular, mucous cells                              295
# T cells, interferon-stimulated                       286
# Fibroblasts, alveolar-enriched                       254
# Endothelial cells, arterial                          254
# Glial, Schwann cells                                 206
# Alveolar epithelial cells, type 1                    180
# Neuroendocrine cells                                 135
# Ionocytes                                            107
# Myoepithelial cells                                   82
# Dendritic cells, plasmacytoid                         79
# Name: author_cell_type, dtype: int64

# %%
adata.obs[CELL_TYPE_ONTOLOGY_ID].value_counts()
# Out:
# CL:0000904;CL:0000895     10103
# CL:0002145                 9580
# CL:4033008                 6759
# CL:0000576                 6247
# CL:0002063                 6246
# CL:2000093                 5139
# CL:0000814                 4836
# CL:0019018                 4804
# CL:0019001                 4734
# CL:0000236                 4601
# CL:0000775                 4142
# CL:0000900;CL:0000909      3577
# CL:2000016                 3430
# CL:4028002;CL:4028003      3420
# CL:0002633                 2916
# CL:0000097                 2713
# CL:0000890                 2390
# CL:4033048                 2355
# CL:0000623                 2303
# CL:0000235;CL:0000890      1946
# CL:0000990                 1643
# CL:0002370                 1544
# CL:0000235                 1263
# CL:4033005                 1249
# CL:4033044                  900
# CL:0002138                  870
# CL:1000333                  719
# CL:4033039                  643
# CL:4033017                  634
# CL:0000669                  619
# CL:0000138                  536
# CL:0000786                  523
# CL:0000359                  502
# CL:4033022                  295
# CL:0000545; CL:0000899      286
# CL:1000413                  254
# CL:4028004;CL:4028006       254
# CL:0002573                  206
# CL:0002062                  180
# CL:1000223                  135
# CL:0017000                  107
# CL:4033003                   82
# CL:0000784                   79
# Name: cell_type_ontology_term_id, dtype: int64

# %%
adata.obs[CELL_TYPE_ONTOLOGY_LABEL].value_counts()
# Out:
# central memory CD4-positive, alpha-beta T cell;naive thymus-derived CD4-positive, alpha-beta T cell    10103
# ciliated cell of the bronchus                                                                           9580
# vein endothelial cell of respiratory system                                                             6759
# monocyte                                                                                                6247
# type II pneumocyte                                                                                      6246
# bronchus fibroblast of lung                                                                             5139
# mature NK T cell                                                                                        4836
# blood vessel smooth muscle cell                                                                         4804
# tracheobronchial serous cell                                                                            4734
# B cell                                                                                                  4601
# SAA+ ciliated cell                                                                                      4487
# neutrophil                                                                                              4142
# naive thymus-derived CD8-positive, alpha-beta T cell;CD8-positive, alpha-beta memory T cell             3577
# lung microvascular endothelial cell                                                                     3430
# alveolar capillary type 1 endothelial cell;alveolar capillary type 2 endothelial cell                   3420
# respiratory basal cell                                                                                  2916
# mast cell                                                                                               2713
# alternatively activated macrophages                                                                     2390
# respiratory suprabasal cell                                                                             2355
# natural killer cell                                                                                     2303
# inflammatory macrophage;alternatively activated macrophages                                             1946
# conventional dendritic cell                                                                             1643
# respiratory goblet cell                                                                                 1544
# unkown T cell                                                                                           1477
# Myofibroblasts                                                                                          1320
# inflammatory macrophage                                                                                 1263
# serous secreting cell of bronchus submucosal gland                                                      1249
# Adventitial fibroblasts                                                                                 1081
# deuterosomal cell                                                                                        900
# mucous ciliated cell                                                                                     876
# endothelial cell of lymphatic vessel                                                                     870
# unkown cell                                                                                              783
# serous cell of epithelium of lobular bronchiole                                                          719
# lung resident memory CD8-positive, alpha-beta T cell                                                     643
# bronchiolar smooth muscle cell                                                                           634
# pericyte                                                                                                 619
# chondrocyte                                                                                              536
# plasma cell                                                                                              523
# vascular associated smooth muscle cell                                                                   502
# mucus secreting cell of bronchus submucosal gland                                                        295
# T-helper 1 cell; T-helper 17 cell                                                                        286
# alveolar type 1 fibroblast cell;alveolar type 2 fibroblast cell                                          254
# endothelial cell of artery                                                                               254
# Schwann cell                                                                                             206
# type I pneumocyte                                                                                        180
# lung neuroendocrine cell                                                                                 135
# pulmonary ionocyte                                                                                       107
# myoepithelial cell of bronchus submucosal gland                                                           82
# plasmacytoid dendritic cell                                                                               79
# Name: cell_type_ontology_term_label, dtype: int64

# %%
adata.obs[MARKER_GENES].value_counts()
# Out:
# LEF1; CCR7; SELL; IL7R                                                                         10103
# FOXJ1; CAPS; TPPP3                                                                              9580
# ACKR1; PLVAP; SELE; POSTN                                                                       6759
# VCAN; FCN1; CD163 (shared with macrophages; but distinguishing from Neu which are negative)     6247
# SFTPC                                                                                           6246
# combined markers of T and NK cells                                                              4836
# SCGB1A1; negative for BC markers                                                                4734
# MS4A1; BANK1; CD19; CD79A                                                                       4601
# ciliated + SAA1; SAA2; SAA4                                                                     4487
# CSF3R; S100A8; FCGR3B; IFITM2                                                                   4142
# HPGD; EDNRB; IL1RL1 - higher expression than in other En clusters                               3420
# high expression of KRT5; KRT15                                                                  2916
# TPSB2; TPSAB1; CPA3; KIT                                                                        2713
# APOE; CCL18; MSR1; MRC1; FABP4                                                                  2390
# intermediate expression of BC and secretory markers                                             2355
# GNLY; NKG7; negative for T cell markers CD3D and CD3E                                           2303
# FCER1A; CD86; CD1C; CD1E; high expression of HLA family genes (HLA-DPB1 and others)             1643
# MUC5AC; negative for BC markers                                                                 1544
# ELN; COL1A1; MMP2 - higher expession of these and other ECM genes than other Fb clusters        1320
# higher expression of ADIRF than in other SM clusters                                            1281
# SPP1; CCL3; CXCL9; CXCL10                                                                       1263
# LYZ; LTF; PRR4                                                                                  1249
# CCL19; SFRP2                                                                                    1081
# CCNO; HES6; CDC20B                                                                               900
# ciliated + secretory SCGB1A1 or MUC5AC                                                           876
# CCL21; MMRN1; LYVE1; PROX1                                                                       870
# SFTPB and/or SCGB3A2; a bridge cluster between airway secretory and AT2 cells                    719
# PDCD1; ITGA1; CXCR6; CD101                                                                       643
# DES; TPP2; CNN1; BCHE; PRUNE                                                                     634
# COX4I2; KCNK3; PDGFRB                                                                            619
# SNORC; COL2A1; ACAN                                                                              536
# JCHAIN; MZB1; IGHA1; IGKC (also express B cell markers CD19 and CD79A)                           523
# combined markers of En and SM cells                                                              502
# MUC5B; BPIFB2                                                                                    295
# IFIT1; IFIT2; OASL; ISG15; HERC5                                                                 286
# GPC3; FGFR4; VEGFD; WNT2                                                                         254
# IGFBP3; GJA5; DKK2                                                                               254
# CDH19; GPM6B; MPZ; NRXN1                                                                         206
# AGER                                                                                             180
# CHGA; GRP; CALCA; SEC11C                                                                         135
# ATP6V0B; FOXI1; TMEM61                                                                           107
# KRT14; ACTA2; cluster located within SMG cluster region; distinct from BC and SM clusters         82
# IL3RA; IRF4; IRF7; GZMB                                                                           79
# Name: author_cell_type_markers, dtype: int64

# %% [markdown]
# # Check whether ENSEMBL IDs in var

# %%
adata.var.index = adata.var['name']
adata.var.index.name = 'index'
adata.var.rename(columns={'gene_ids': 'ensembl_id', 'name': 'gene_symbol'}, inplace=True)

adata.var
# Out:
#                feature_types       ensembl_id  genome  gene_symbol
# index
# MIR1302-2HG  Gene Expression  ENSG00000243485  GRCh38  MIR1302-2HG
# FAM138A      Gene Expression  ENSG00000237613  GRCh38      FAM138A
# OR4F5        Gene Expression  ENSG00000186092  GRCh38        OR4F5
# AL627309.1   Gene Expression  ENSG00000238009  GRCh38   AL627309.1
# AL627309.3   Gene Expression  ENSG00000239945  GRCh38   AL627309.3
# ...                      ...              ...     ...          ...
# AC141272.1   Gene Expression  ENSG00000277836  GRCh38   AC141272.1
# AC023491.2   Gene Expression  ENSG00000278633  GRCh38   AC023491.2
# AC007325.1   Gene Expression  ENSG00000276017  GRCh38   AC007325.1
# AC007325.4   Gene Expression  ENSG00000278817  GRCh38   AC007325.4
# AC007325.2   Gene Expression  ENSG00000277196  GRCh38   AC007325.2
#
# [36591 rows x 4 columns]

# %% [markdown]
# # Check raw data

# %%
if not sp.issparse(adata.X):
    adata.X = sp.csr_matrix(adata.X)

# %%
np.max(adata.X.toarray())
# Out:
# 34567

# %%
adata.raw = adata

# %%
adata.raw.X
# Out:
# <115788x36591 sparse matrix of type '<class 'numpy.int64'>'
# 	with 224323233 stored elements in Compressed Sparse Column format>

# %%
adata.obs.columns
# Out:
# Index(['sample_ID', 'algorithm_resolution_version', 'donor_id', 'protocol_URL',
#        'institute', 'sample_collection_site',
#        'sample_collection_relative_time_point', 'library_ID',
#        'library_ID_repository', 'author_batch_notes',
#        'organism_ontology_term_id', 'manner_of_death', 'sample_source',
#        'sex_ontology_term_id', 'sample_collection_method', 'tissue_type',
#        'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text',
#        'sample_preservation_method', 'suspension_type', 'cell_enrichment',
#        'cell_viability_percentage', 'cell_number_loaded',
#        'sample_collection_year', 'assay_ontology_term_id',
#        'library_preparation_batch', 'library_sequencing_run',
#        'sequenced_fragment', 'sequencing_platform', 'is_primary_data',
#        'reference_genome', 'gene_annotation_version', 'alignment_software',
#        'intron_inclusion', 'disease_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id',
#        'development_stage_ontology_term_id', 'author_cell_type',
#        'cell_type_ontology_term', 'cell_type_ontology_id', 'marker_genes',
#        'author_cell_type_markers', 'cell_type_ontology_term_label',
#        'cell_type_ontology_term_id'],
#       dtype='object')

# %% [markdown]
# ## Validation result
#
# ### UNS Validation
# - OK: Tier 1 UNS Google Sheet
# - OK: Tier 1 UNS AnnData Object
#
# ### OBS Validation
# - OK: Tier 1 OBS Google Sheet
# - OK: Tier 1 OBS AnnData Object

# %% [markdown]
# # Data Submission Status
#
# - CHECK: Raw data in X and in raw
# - CHECK: Tier 1 Metadata in OBS
# - CHECK: Cell Ontology IDs in OBS
# - CHECK: Author cell type in OBS
# - CHECK: Marker genes in UNS
# - CHECK: ENSEMBL IDs and gene symbols in var
#
# Everything great, just need to check whether comma seperated list of Cell Ontology Term IDs are okay

# %%
adata.obs['cell_viability_percentage'] = pd.to_numeric(adata.obs['cell_viability_percentage'], errors='coerce')
adata.obs['cell_number_loaded'] = pd.to_numeric(adata.obs['cell_number_loaded'], errors='coerce')
adata.obs['sample_collection_year'] = pd.to_numeric(adata.obs['sample_collection_year'], errors='coerce')

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"), compression='gzip')
