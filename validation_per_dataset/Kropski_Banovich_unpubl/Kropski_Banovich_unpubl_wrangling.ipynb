# %%
import scanpy as sc
import pandas as pd
import anndata as ad
#import anndata2ri
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"

# %%
DATASET_ID = "Kropski_Banovich_unpubl"
H5AD_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/{DATASET_ID}.h5ad"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
# Name constants
AUTHOR_CELL_TYPE_L0 = 'author_cell_type_level_0'
AUTHOR_CELL_TYPE_L1 = 'author_cell_type_level_1'
AUTHOR_CELL_TYPE_L2 = 'author_cell_type_level_2'

CELL_TYPE_ONTOLOGY_ID_L0 = 'cell_type_ontology_term_id_level_0'
CELL_TYPE_ONTOLOGY_ID_L1 = 'cell_type_ontology_term_id_level_1'
CELL_TYPE_ONTOLOGY_ID_L2 = 'cell_type_ontology_term_id_level_2'

MARKER_GENES_L0 = 'author_cell_type_markers_level_0'
MARKER_GENES_L1 = 'author_cell_type_markers_level_1'
MARKER_GENES_L2 = 'author_cell_type_markers_level_2'

# Finest grained annotation will be generic dataset cell type
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'
MARKER_GENES = 'author_cell_type_markers'

# %% [markdown]
# # Load data

# %%
adata = sc.read_h5ad(H5AD_PATH)
obs = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "obs")
uns = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "uns")

# %%
indices_split = np.array_split(range(adata.shape[0]), 4)
indices_split
# Out:
# [array([    0,     1,     2, ..., 72274, 72275, 72276]),
#  array([ 72277,  72278,  72279, ..., 144550, 144551, 144552]),
#  array([144553, 144554, 144555, ..., 216826, 216827, 216828]),
#  array([216829, 216830, 216831, ..., 289102, 289103, 289104])]

# %%
# Parse adata in right format for Archmap mapping
adata.obs_names_make_unique()
adata.var.index = adata.var['gene_id'].astype(str)
adata.var_names_make_unique()
adata.obs['scanvi_label'] = 'unlabeled'
adata.obs['dataset'] = 'Kropski_Banovich_unpubl'

for i, index_chunk in enumerate(indices_split):
    adata_chunk = adata[index_chunk].copy()
    adata_chunk.write_h5ad(join(f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}", f'{DATASET_ID}_adata_chunk_{i}.h5ad'))

# %%
mapped_adata_files = [f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/"+x for x in os.listdir(f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}") if x.endswith('mapped.h5ad')]

mapped_adata_files
# Out:
# ['/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kropski_Banovich_unpubl/chunk_1_mapped.h5ad',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kropski_Banovich_unpubl/chunk_0_mapped.h5ad',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kropski_Banovich_unpubl/chunk_2_mapped.h5ad',
#  '/home/icb/raphael.kfuri-rubens/data/hlca_v2/Kropski_Banovich_unpubl/chunk_3_mapped.h5ad']

# %%
# Load chunked and mapped Archmap AnnData objects
mapped_adatas = []
for adata_file in mapped_adata_files:
    adata = sc.read_h5ad(adata_file)
    mapped_adatas.append(adata)

adata_archmap = ad.concat(mapped_adatas,axis=0)

adata_archmap
# Out:
# /home/icb/raphael.kfuri-rubens/miniconda3/envs/hlcav2-env/lib/python3.10/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 2628881 × 2000
#     obs: 'dataset', 'scanvi_label', '_scvi_batch', '_scvi_labels', 'type', 'query', 'scanvi_label_uncertainty_euclidean', 'uncertainty_mahalanobis', 'prediction_xgb', 'donor_id', 'tissue_ontology_term_id', 'sample_collection_site', 'disease_ontology_term_id', 'library_ID', 'suspension_type', 'cell_number_loaded', 'sample_collection_relative_time_point', 'is_primary_data', 'protocol_URL', 'sample_collection_year', 'tissue_type', 'development_stage_ontology_term_id', 'sampled_site_condition', 'author_batch_notes', 'scanvi_label_user_input', 'sequenced_fragment', 'sample_ID', 'cell_size', 'intron_inclusion', 'cell_viability_percentage', 'manner_of_death', 'sample_source', 'sequencing_platform', 'reference_genome', 'alignment_software', 'sample_collection_method', 'gene_annotation_version', 'cell_enrichment', 'library_sequencing_run', 'tissue_free_text', 'sample_preservation_method', 'institute', 'prediction_xgb_filtered_by_uncert>0.5', 'library_preparation_batch', 'droplet_efficiency', 'library_ID_repository', 'cell_probability', 'sex_ontology_term_id', 'organism_ontology_term_id', 'assay_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'background_fraction'
#     obsm: 'latent_rep'

# %%
adata_archmap = adata_archmap[adata_archmap.obs['dataset'] == 'Kropski_Banovich_unpubl'].copy()

# %%
non_overlap_barcodes = set(adata.obs.index) - set(adata_archmap.obs.index)
non_overlap_barcodes_other_side = set(adata_archmap.obs.index) - set(adata.obs.index)

# %%
len(non_overlap_barcodes)
# Out:
# 584944

# %%
len(non_overlap_barcodes_other_side)
# Out:
# 216829

# %%
pd.DataFrame({
    'non_overlap_barcodes': list(non_overlap_barcodes),
    'non_overlap_barcodes_other_side': list(non_overlap_barcodes_other_side)
})

# %%
# add to non_overlap_barcodes in adata '-1' at the end of the barcode
adata.obs['barcode'] = adata.obs.index
adata.obs['barcode'] = adata.obs['barcode'].apply(lambda x: x + '-1' if x in non_overlap_barcodes else x)
adata.obs.index = adata.obs['barcode']

# %%
set(adata.obs.index) - set(adata_archmap.obs.index)
# Out:
# {'GACGGCTCAGGGAGAG_F01157-1',
#  'GGCTGGTCAATCGAAA-1-HCATisStab7747199-1',
#  'ATTACCTTCAAATGCC_SC84-1',
#  'CCCTCCTGTTATCACG_HD67-1',
#  'GCCTCTATCCGATATG_T85-1',
#  '7239220_TTGACTTCAAGCTGGA-1',
#  'GTTACAGTCCTCGCAT-1-2-1',
#  'TCGCGAGTCTCATTCA_HD101-1',
#  'CGGACTGCAATGCCAT_F02522-1',
#  'P2_1_TCAATCTAGGATGGTC-1',
#  'GTGTGCGCATGCATGT_F01851-1',
#  'TCTTCGGTCTGATAC_GRO-08_biopsy-1',
#  'TTATGCTGTGTGCCTG_SC29-1',
#  'D344_Brus_Dis1_AACTCAGCAACCGCCA-1-14-1',
#  'P3_3_TCTTTCCAGTGCGTGA-1',
#  'D353_Brus_Nas1_GGAGCAATCACCTCGT-1-16-1',
#  'GTATTCTTCGGCGCTA-1-4-1',
#  'D344_Biop_Int1_CACATAGCAGTCAGAG-1-13-1',
#  'TAAGCGTCATCTGGTA-SC45-1',
#  'D337_Brus_Dis1CGAACATCATGACGGA-1-6-1',
#  'TACAGTGTCTTTACAC_GRO-09_biopsy-1',
#  'CTCGTCACAAGCCGTC-1-HCATisStab7659970-1',
#  'TGATTTCTCAGCTCGG-1-5-1',
#  'GACTACACATAACCTG_SC18-1',
#  'P3_7_CTCTGGTGTTCCGGCA-1',
#  'GTCAAGTAGTCATCCA_T137-1',
#  'TTAAGCAGGCCGAAT_GRO-09_biopsy-1',
#  'ACTGCGAGTATCGAA_GRO-10_biopsy-1',
#  'P3_5_TTCTCAAAGTTAGCGG-1',
#  'D322_Biop_Nas1_ATAAGAGAGTACGATA-1-0-1',
#  'P3_7_GCGCCAAAGCAGCCTC-1',
#  'CGCTGGAGTTTCCACC_F02611-1',
#  'TCCCGATCAATGGAAT_HD70-1',
#  'GTCTTCGAGCTGAACG_F02611-1',
#  'AACTCAGAGAAGGACA-1-6-1',
#  'D367_Biop_Pro1_TGTGGTAAGTCAAGGC-1-28-1',
#  'P3_7_ATCCGAACATAGGATA-1',
#  'CTGAAACGTAACGACG_F02992-1',
#  'CACAGTAGTTAAGAAC_GRO-10_nasal_brush-1',
#  'CACATAGTCGTAGATC_SC27-1',
#  'GCGACCACACGAAAGC_F02607-1',
#  'CACAGGCTCGTCAC_GRO-04_nasal_brush-1',
#  'P3_5_GCTGCTTAGACCTAGG-1',
#  'TTGACTTGTAGCGCAA_F01641-1',
#  'AAAGCAAAGCCAGAAC_SC27-1',
#  'GTCTCGTCAATGGACG_SC10-1',
#  'D353_Biop_Pro1TGCCCATCAGCCACCA-1-17-1',
#  'P2_5_GTTCATTAGCGTTGCC-1',
#  'CGTCACTTCATCGGAT_GRO-07_biopsy-1',
#  'TAGACGTGTTGAGC-SC31D-1',
#  'TTTGGTTAGGGATCTG-1-HCATisStab7747198-1',
#  'AAATGCCCACGAAAGC-1-HCATisStab7587208-1',
#  '7135919_GACTACACACCTCGGA-1',
#  'GTGCGGTTCTATGTGG_F01157-1',
#  'AATGGCTGTTTGGG-SC31D-1',
#  'CACTCCACAGATTGCT_HD70-1',
#  'D353_Brus_Nas1_CCTAGCTAGCCGGTAA-1-16-1',
#  'GTATCTTGTAAAGTCA_F01641-1',
#  'D353_Biop_Pro1ACACCGGTCCACGAAT-1-17-1',
#  'ATCGTAGTCGATACAC_SC88-1',
#  'TTATGCTTCGGATGGA_SC10-1',
#  'GTATCTTCAGTCAGAG_HD66-1',
#  'CCTAGCTAGAGACTTA-1-HCATisStab7659970-1',
#  'CACAGTATCTCCA_GRO-07_biopsy-1',
#  'TCTGGAAGTGGTACAG-1-HCATisStab7747198-1',
#  'TCAATCTAGTGTGAAT_GRO-07_biopsy-1',
#  'GTTCTCGTCCCTAACC_F02522-1',
#  'AAAGAACGTCGTACTA_SC86-1',
#  'D353_Biop_Pro1AGGGTGATCATATCGG-1-17-1',
#  'D339_Biop_Int1_CTAGAGTAGTATCTCG-1-9-1',
#  'D372_Brus_Dis1_GCTTGAACATATGCTG-1-35-1',
#  'GTAGAGGGTTAGGCCC_SC144-1',
#  'CTTGGCTCACAGGAGT-1-2-1',
#  'CACGAATAGGATGCGT_SC144-1',
#  'GCGCAACTCGTAGGTT_SC24-1',
#  'CCTCTGAGTACCTACA_F01851-1',
#  'TAGAGCTGTCCTCCAT_SC20-1',
#  'GAACATCAGCTAACTC_F02528-1',
#  'TGGGATTTCAAGCGTT_SC88-1',
#  'ACAGCCGCAGTCGATT_F02607-1',
#  'GCGAGAAAGCGATAGC_F02992-1',
#  'P2_2_ACAGCCGCATCGGAAG-1',
#  'P1_4_TTTCCTCAGGAGTTTA-1',
#  'D354_Biop_Pro1_CTGAAGTCATCTGGTA-1-20-1',
#  'CGTAGCGAGATCTGCT_F02611-1',
#  'P2_7_TCAGGTATCAGCTGGC-1',
#  'TACTTACGTCGGCATC_F01851-1',
#  'GCCAACGAGTTCTACG_SC144-1',
#  'AGCTCAAGTGGGTATG_T90-1',
#  'GCATACAGTCACCCAG_SC22-1',
#  'TTGAACGGTCTAGCCG-1-1-1',
#  'D322_Biop_Nas1_ATTCTACAGATGTGGC-1-0-1',
#  'TATCAGGAGTATCTGC_SC88-1',
#  'ATTGGACCAAGTCATC-1-HCATisStab7747197-1',
#  'D363_Brus_Nas1_AACTGGTTCGATCCCT-1-23-1',
#  'D372_Brus_Nas1_TCGAGGCCATATACGC-1-31-1',
#  'D339_Biop_Int1_ACGGCCATCGTCGTTC-1-9-1',
#  'CCATAAGCATGCCGCA_SC144-1',
#  'GCATGTACATGAAGTA-1-1-1',
#  'CGATGGCTCGACAGCC_GRO-08_biopsy-1',
#  'ACATCAGGTCTCTCTG-1-HCATisStab7659971-1',
#  'P3_3_CCGGTAGCAGGGAGAG-1',
#  'TCTGAGAAGCGACGTA-1-HCATisStab7659971-1',
#  'ACTCCCATCTCAACCC_SC141-1',
#  'CCGTGGACACTATCTT-1-HCATisStab7747200-1',
#  'P2_8_GGCAATTCAACCGCCA-1',
#  'CCCAGTTGTAAGAGAG-1-HCATisStab7747199-1',
#  'TAGGAGGGTGTCCACG_SC84-1',
#  'TGAGCCGTCGTAGATC_GRO-11_biopsy-1',
#  'GGAGCAATCCTACCAC_SC85-1',
#  'CAGAATCCAACTGGCC_F01607-1',
#  'D367_Biop_Pro1_GTAACTGGTCAAACTC-1-28-1',
#  'ACCCACTTCGGACAAG_F02524-1',
#  'ACACCCTAGCTGCAAG_F02607-1',
#  'D339_Biop_Int1_TAGACCATCAACACGT-1-9-1',
#  'D363_Biop_Pro1_TGTTCCGGTCGCTTCT-1-24-1',
#  'CTCAGAATCGACAGCC_T85-1',
#  'ATCACGAAGGGCTAAC_SC84-1',
#  'AGGCCACCATATGGTC_F02613-1',
#  'CACAGGCGTTATCCGA_F02522-1',
#  'TCAACGATCGAGAACG_HD68-1',
#  '7239217_CATCAAGTCACTTACT-1',
#  'CTGGTCTCAGGTGGAT_T153-1',
#  'D372_Brus_Nas1_GACAGAGTCAGAGACG-1-31-1',
#  'TGTGCGCACGTAA_GRO-03_nasal_brush-1',
#  'ACGCCAGAGACCTTTG_F01394-1',
#  'CTGCTGTCATCTGGTA_HD66-1',
#  'GTCATTTAGTCTCGGC-1-HCATisStab7747200-1',
#  'P2_5_CTGAAACGTCACCTAA-1',
#  'TAAACCGGTAAACCTC_F02617-1',
#  'P2_5_ATGAGGGAGCAGATCG-1',
#  'D344_Biop_Nas1_TGATTTCAGAGGTTGC-1-11-1',
#  'D353_Brus_Dis1_CGACTTCCAGCTGGCT-1-19-1',
#  'GGGAGATAGGCCACTC_SC144-1',
#  'TTTGGTTGTTACGTCA_GRO-03_biopsy-1',
#  'GCATGCGTCAGAGACG_F02509-1',
#  'P3_3_GTGAAGGTCTCTAGGA-1',
#  'TCACGAATCTCCGGTT_F01607-1',
#  'GAAACCTCATAACCCA_SC87-1',
#  'GTCAAGTCACCTGGTG_SC27-1',
#  'ATGTTTCGTTACGA_GRO-04_nasal_brush-1',
#  'CACTCCATCGCTAGCG-1-HCATisStab7587202-1',
#  'TGCCCATAGATATGCA_F01851-1',
#  'P3_4_GTCATTTAGTTGTAGA-1',
#  'CGACCTTAGCTCCTTC_GRO-04_nasal_brush-1',
#  'TGGCCAGAGACTAGAT_GRO-03_biopsy-1',
#  'CTTGAAAGGATGGTC_GRO-10_biopsy-1',
#  'D344_Biop_Nas1_ACGGGCTTCCAAAGTC-1-11-1',
#  'AAGACCTTCGATAGAA-SC56-1',
#  'P2_5_GATCGCGAGAAGATTC-1',
#  'TTCTTGACATGCCATA_T153-1',
#  'AGAGCGACAAGTAGTA-1-4-1',
#  'D353_Brus_Nas1_TCATTACGTGCAGGTA-1-16-1',
#  'CCTACCACATGCCCGA_F02617-1',
#  'CTCTGGTTCTTTAGTC_GRO-10_nasal_brush-1',
#  'TTAATCCAGCCATTTG_SC84-1',
#  'GGGTTGCAGTTCGCAT_HD66-1',
#  'TCGTAGAAGCCACTAT_HD68-1',
#  'TATGCCCAGACTGTAA_GRO-09_biopsy-1',
#  'GTGGGTCTCTCTTGAT_F01851-1',
#  'CAGAGAGAGACATAAC_GRO-06_biopsy-1',
#  'TTTATGCAGATAGCAT_SC18-1',
#  '7185212_AACACGTCAATGGTCT-1',
#  'P1_4_TTGTAGGGTTCAGCGC-1',
#  'AGGGTGAGTTGCCTCT_F02524-1',
#  'GGTGTCGCAAGGCGTA_SC142-1',
#  'AACTCCCCAAGAGGCT_F02607-1',
#  'AACTGGTAGCCACGCT_T121-1',
#  'GTGGGTCAGGCGATAC_SC20-1',
#  'ACATGGTAGATGTAAC-SC156-1',
#  'GACTACAAGAGTTGGC_F02524-1',
#  'AGCTCAAAGTGTGTTC_SC144-1',
#  'CAACCAACATTTCACT_GRO-07_biopsy-1',
#  'D353_Biop_Pro1AAGCCGCCACAGGAGT-1-17-1',
#  'GTTCATTCACTCTGTC_SC18-1',
#  'CGTGTAATCGTAGATC_GRO-03_biopsy-1',
#  'CAACAGTTCCTACGAA_T166-1',
#  'D353_Biop_Int2_CAGCAGCGTCAATGTC-1-18-1',
#  'GTGTGCGAGCGAAGGG_F02522-1',
#  'CATCGAAAGGAGCGTT-1-7-1',
#  'AAGTCTGGTTACGTCA-SC59-1',
#  'TATACCTCACTTTATC_SC87-1',
#  'AGCGATTAGTTAGTAG_SC85-1',
#  'TCTCTAATCCCACTTG-SC56-1',
#  'D322_Biop_Pro1_GGTGTTAAGAGCAATT-1-1-1',
#  'CTTAGGATCACTTGTT_SC144-1',
#  'ACGAGGACATCGGTTA-1-HCATisStab7747198-1',
#  'GTTTCTAGTAGAGGAA_SC07-1',
#  'CGAATGTGTTATCGGT_GRO-10_biopsy-1',
#  'ATCCGAAAGATGTGTA_GRO-10_nasal_brush-1',
#  'P1_3_CCTCTGAGTGGAAAGA-1',
#  'GTCAAACTCCTAGCGG_SC85-1',
#  'CATCGGGCAGCTGTTA_F02611-1',
#  'P2_5_GGTGAAGCAAGACACG-1',
#  'CGAGAAGCATGGGACA_GRO-09_biopsy-1',
#  'ACGAGGAAGCCACTAT_SC22-1',
#  'GAAGCCCAGAAGGTAG_SC85-1',
#  'ACGTCCTAGCTACGTT_SC144-1',
#  'AGGTCCGAGCGTTGCC-1-6-1',
#  'D353_Biop_Pro1AACTCTTGTGATAAGT-1-17-1',
#  'AAGGAGCTCAAGAAGT_GRO-04_biopsy-1',
#  'TACCGAAAGCGATGGT_SC143-1',
#  'ATAAGAGCATGGAATA_F02607-1',
#  'P3_5_GGCAATTAGTGGGATC-1',
#  'D367_Brus_Nas1_GGTGAAGGTCACTGGC-1-27-1',
#  'D353_Biop_Pro1GACCTGGCATCGATGT-1-17-1',
#  'GAAGCCCGTCGTATGT_SC144-1',
#  'P2_3_GGCAATTGTGTAAGTA-1',
#  'AACTCTTTCCATGAAC-1-HCATisStab7587205-1',
#  'AACCCAACAATTGCTG_SC88-1',
#  'GCTCTGTGTAAATGTG-1-4-1',
#  'GTTCTATTCTATCGCC_SC144-1',
#  'ACTTGTTGTGTGACGA-SC56-1',
#  'CTGCGAGTGTGTGCC_GRO-08_biopsy-1',
#  'TTAGTTCTCTGTTTGT_F01403-1',
#  'CACCTTGAGTCCGTAT_F02607-1',
#  'TGCTACCTCTGGAGCC-1-7-1',
#  'D326_Biop_Pro1_AGCTCTCTCATGTGGT-1-3-1',
#  'CGGTTAAGTTCCCTTG_F01641-1',
#  'CGGACGTGTCCGCTGA_F01394-1',
#  'AGTGTCAAGCGTGTCC_GRO-04_biopsy-1',
#  'GCGCAGTTCCTCCTAG_F01367-1',
#  'P2_6_GGCTCGATCCCTTGCA-1',
#  'TCTTCGTCGAAT_GRO-04_nasal_brush-1',
#  'GCTGCTTCAGCTTCGG_SC24-1',
#  'AACGTTGGTCGGATCC-1-HCATisStab7587205-1',
#  'CTCTACGGTGACTACT_F02617-1',
#  'TCGGTCTTCCCATAGA_SC144-1',
#  'GACCAATCATGAACCT-1-7-1',
#  'AAACCCAGTCTTCTAT_SC86-1',
#  'TCGAACACATGGGATG_T165-1',
#  'TTGACTTGTGTCGCTG_F01365-1',
#  'TACCTATGTTCACGGC-1-5-1',
#  'D367_Biop_Pro1_TGCCCTAGTCACCTAA-1-28-1',
#  'GAGAGGTGTAGCTTAC_SC88-1',
#  'D372_Biop_Int2_AGCGGTCAGCCACGCT-1-34-1',
#  'P2_5_GACGCGTTCAGTTGAC-1',
#  'CGACCTTTCTTAGCCC_SC27-1',
#  'GCACATAAGAGCAATT_F01851-1',
#  'CGTTAGATCCGTTGGG_SC142-1',
#  'TCTGGAAAGTGTCCAT_F02613-1',
#  'TACTCATTCGTGGTC_GRO-11_biopsy-1',
#  'D353_Brus_Dis1_CATCGAAAGCTAGTTC-1-19-1',
#  'TACGTCCCATCAGTGT_T101-1',
#  'TCGGGACTCAGCTGGC_SC27-1',
#  'AACTCAGCATGGGACA-1-HCATisStab7587211-1',
#  'CAGCATATCTGTCTAT_SC22-1',
#  'GGCGTGTGTGGAAAGA_HD68-1',
#  'GGCACGTAGGGCCCTT_SC144-1',
#  'TTGGAACGTGAGGCTA_F02617-1',
#  'AACGAAAAGGTTGAGC_SC86-1',
#  'D372_Biop_Pro1_TTAGGCATCCGGGTGT-1-32-1',
#  'AAAGCAATCTGAGGGA_GRO-04_biopsy-1',
#  'CTCGAGCTAGGAGC-SC31-1',
#  'CGTCTACCAACACCCG_F02611-1',
#  'TCACGAATCCGAACGC_F02613-1',
#  'GACAGAGCAGCTCGAC_F02522-1',
#  'AGGTCCGAGTGACATA_F02524-1',
#  'D367_Biop_Pro1_TCTATTGCAGTATCTG-1-28-1',
#  'CTAACTTTCCTAAGT_GRO-11_biopsy-1',
#  'ACACCAAAGGTCGGAT-1-6-1',
#  'TCGTAGAGTCCTCCAT_GRO-03_biopsy-1',
#  'D354_Biop_Int2_GATGAGGTCTTCGGTC-1-21-1',
#  'GAATGAACAAACGCGA_HD68-1',
#  'ATTTCTGGTTTGAAAG_SC86-1',
#  'ACGATACAGGACTGGT_SC29-1',
#  'TCAGCAATCAAGGCTT_HD68-1',
#  'P3_7_CTTAGGAAGGTGTGGT-1',
#  'D363_Brus_Nas1_GTGCAGCCACATTTCT-1-23-1',
#  'D339_Biop_Int1_ACGAGCCCAAGAGGCT-1-9-1',
#  'D367_Brus_Dis1_GTCAAGTGTCATTAGC-1-30-1',
#  'GGCCGATTCCGAACGC-SC59-1',
#  'P1_4_TTCTCCTAGTGGGATC-1',
#  'CGAATTGAGGTGCTAG_SC144-1',
#  'AGGTGAGTCAGTGGA_GRO-10_biopsy-1',
#  'P2_1_GCTGGGTGTCATATCG-1',
#  '7135919_AGCGGTCGTAGCACGA-1',
#  'P3_7_TTGACTTGTGTTGGGA-1',
#  'CTGCGGAAGTTACCCA_F01365-1',
#  '7239219_CCTTTCTTCATAAAGG-1',
#  'TAGAGCTAGGATATAC_GRO-07_biopsy-1',
#  'TCAGGATTCGGTCTAA_HD68-1',
#  'CTGGTCTGTTATCCGA_HD66-1',
#  'P2_7_TGTATTCTCCCTTGTG-1',
#  'TCCACACCATACTCTT_F02092-1',
#  'GATTTCTTCCCTTTGG_SC87-1',
#  'CAAGACTGTAGATCCT_SC84-1',
#  'TATCTCAGTTCTGGTA-SC45-1',
#  'CCTTACGGTGATAAAC_F02522-1',
#  'GGAATAATCAGTTGAC_F02992-1',
#  'P2_3_ACGGGTCTCTATCCTA-1',
#  'CACTAAGAGTTGCGCC_SC84-1',
#  'P3_2_GTGCTTCAGCTAACAA-1',
#  'P3_6_ACGCCAGGTACGCACC-1',
#  'AGGGTGAAGGCATGT_GRO-09_biopsy-1',
#  'CGTGTAACAATCGAAA_F02992-1',
#  'CATTCGCGTCCGAACC_F02611-1',
#  'TACGGATAGATGTGTA-1-HCATisStab7587211-1',
#  'GGATGTTTCCGATATG-SC156-1',
#  'ACTTTCACAGTCCTTC-1-2-1',
#  'AGCGATTTCCTCTGCA_T164-1',
#  'TATATCCTCTGTGTGA_SC144-1',
#  'CTAACTTCATCACGTA-SC56-1',
#  'AGTGTTGCAAGATCCT_SC142-1',
#  'CAGCGACAGTCACGCC-1-HCATisStab7659971-1',
#  'D363_Brus_Dis1_CTCGTACTCGGAGGTA-1-26-1',
#  'CAGAATCGTCTGATCA_GRO-03_biopsy-1',
#  'CTTTGCGAGCAGCGTA-1-HCATisStab7587208-1',
#  'AACCGCGTCCAAAGTC-SC156-1',
#  'D326_Brus_Dis1_GAGGTGATCATTCACT-1-5-1',
#  'AGAAGCGCAGGAATCG_SC84-1',
#  'AGTGGGAGTCTCCACT_GRO-03_biopsy-1',
#  'TCGCGAGTCGGCCGAT_F02522-1',
#  'GTTCATTCATCAGTAC_HD67-1',
#  'ACACCCTGTGTAATGA_F02524-1',
#  'GAGCAGAAGAAGATTC-SC156-1',
#  'GTGTTAGTCCAGCTCT_T90-1',
#  'TCATTTGCAAACCTAC_GRO-04_nasal_brush-1',
#  'P1_3_CAGAGAGAGTCGCCGT-1',
#  'TGCCCTATCATGCATG-1-HCATisStab7747199-1',
#  'TGTATTCAGGCTAGAC-1-HCATisStab7659969-1',
#  'GTAGGCCCACGGCCAT-1-6-1',
#  'ATTTCTGGTCTCATCC-1-HCATisStab7587202-1',
#  'CCGTTCATCCGCTGTT_T121-1',
#  'CCACCTACATTGTGCA_SC20-1',
#  'AGTTGGTGTATTCTCT_F01851-1',
#  'CTAATGGCACCAGCAC-1-HCATisStab7747200-1',
#  'P3_6_CGCTATCCAATCACAC-1',
#  'P2_8_CACCTTGAGAACAACT-1',
#  'GTTCGGGAGTAGGTGC_HD68-1',
#  '7185213_TTAACTCTCCTCGCAT-1',
#  '7239219_CCTATTACATTTCAGG-1',
#  'P1_2_ACGCAGCCAGGCGATA-1',
#  'P2_5_CAGAATCGTAGAAGGA-1',
#  'CGAGTTACAGTAGATA_SC84-1',
#  'TACTTACGTCAGAAGC_F02611-1',
#  'ACTTCCGCATCGGTTA_SC84-1',
#  'ACTCTCGAGACTTCCA_SC144-1',
#  'TAGACCAGTCCGAAGA_SC20-1',
#  'TAAGTGCGTTTGGGCC_F02524-1',
#  'P3_2_ACGGGTCTCTTCATGT-1',
#  'P2_8_GCTTGAACATTGTGCA-1',
#  'ATCACAGCAGAGGGTT_SC142-1',
#  'CGTAGGCCATATGAGA_SC29-1',
#  'P3_7_TATGCCCGTCGAAAGC-1',
#  'AAAGCAGGCCCGTT_GRO-03_biopsy-1',
#  'ATAAGAGGTTATTCTC_GRO-03_nasal_brush-1',
#  'TATCAGGAGTGGGATC_HD68-1',
#  'P2_5_TGGCGCAGTAAACACA-1',
#  'P2_3_CGGACACGTTGATTCG-1',
#  'P3_7_CTGATCCAGGGAAACA-1',
#  'AGTGTCAGTCGGCACT-SC56-1',
#  'GCCAAATGTCCGTGAC_F02528-1',
#  'AACACGTCACGAAACG_SC27-1',
#  'AGCTCCTGTCTAAACC_GRO-04_biopsy-1',
#  'CTAACTTAGAGGGCTT_F01366-1',
#  'TAAGTGCTCTGCGTAA-1-1-1',
#  'CACCAGGTCGGTGTCG_HD68-1',
#  'D354_Biop_Pro1_AGTAGTCCAAGGACTG-1-20-1',
#  'GCAGTTAAGACAGACC_SC18-1',
#  'TGCCCATGTACCGAGA-SC156-1',
#  'P3_6_CTAGTGAAGAGTAATC-1',
#  'TAGACCAAGAGACTTA_SC07-1',
#  'CAGAGAGCAATTGCTG_F02524-1',
#  'GCAGGCTTCTGTCGTC_SC85-1',
#  'TCTGGAAAGTGTACTC-1-4-1',
#  'GCTGCGACAGAGTGTG-1-HCATisStab7659969-1',
#  'TTAGGACAGACTCGGA_F02613-1',
#  'CCTATTATCTTAGAGC-1-HCATisStab7587211-1',
#  'TTCCTCTCATGTTCGA_SC86-1',
#  'P3_4_TCATTACTCTAAGCCA-1',
#  'D344_Biop_Int1_CGCTTCACATTGGTAC-1-13-1',
#  'ACGGTCGGTAGGCTCC_T90-1',
#  'CATGACAGTGTAACGG_F02617-1',
#  'D344_Brus_Dis1_TGACGGCTCTGGTGTA-1-14-1',
#  'ACTTTCAGTTGCGCAC_F02617-1',
#  'P3_5_ACCTTTATCAGCATGT-1',
#  'GGACATTCAGGGAGAG-1-7-1',
#  'CTATCTACACACAGAG_SC143-1',
#  'P2_1_GGATGTTGTGCACTTA-1',
#  'D372_Biop_Int2_CCATGTCAGCAGGTCA-1-34-1',
#  'TGCTGCTTCTACTTAC_SC24-1',
#  'D322_Biop_Nas1_TGGGAAGGTCGCATCG-1-0-1',
#  'TTTCCTCAGCTGCAAG_HD67-1',
#  'GCGCAGTGTTAAGACA-1-HCATisStab7587211-1',
#  'AACTCAGAGGCAATTA_SC24-1',
#  'CGTCTACTCTTCAACT_SC18-1',
#  'CGAACATGTATCAGTC-1-5-1',
#  'P2_5_TTGACTTAGCGACGTA-1',
#  'D367_Brus_Dis1_TACTCATTCGCCTGTT-1-30-1',
#  'AGGGTGACAAAGCAAT-SC45-1',
#  'ATCGAGTTCCGGCACA-1-HCATisStab7747200-1',
#  'ACGATGTGTGAGGGAG_SC18-1',
#  'CTCGAGGTCTCGGACG_HD70-1',
#  'TACGGATCACACCGCA-SC56-1',
#  'AAACGGGTCGGCCGAT_F02526-1',
#  'GACCTGGCATCGATTG-SC155-1',
#  'TTGCCGTTCTGTCCGT_GRO-10_biopsy-1',
#  'CGATGTATCGCGGATC_F02613-1',
#  'TCTCTAAGTATAGTAG-1-7-1',
#  'GTGGGTCCATACAGCT-SC59-1',
#  'GATTCAGAGGACCACA-1-1-1',
#  'ATCAGGTTCCTTTGAT_SC142-1',
#  'CAATCAGTGCGGTAA_GRO-07_biopsy-1',
#  'TCTATTGCAGGAATGC_GRO-10_biopsy-1',
#  'CGCCAAGGTCTGCAAT-1-2-1',
#  'ATCCACCTCGGCTTGG_SC27-1',
#  'AGCAGCCAGCTAAACA_F01394-1',
#  'TTGTAGGAGATGCCTT_GRO-10_biopsy-1',
#  'GAGCAGACATTTCACT_HD68-1',
#  'GTGCAGCCATACGCCG_F02528-1',
#  'CGAGCACAGATATGGT_SC29-1',
#  'AGGGATGCAAGTTGTC_GRO-10_biopsy-1',
#  'TTGTAGGTCAGCTGGC-1-6-1',
#  'GCGCGATAGTCGTTTG-1-0-1',
#  'CCTTGTGTCGGATTAC_SC144-1',
#  'CGACCAGTACGACCC_GRO-08_biopsy-1',
#  'D344_Brus_Dis1_AAGGTTCGTTAAGAAC-1-14-1',
#  'ACGCAGCTCAAGAAGT_HD101-1',
#  'GCTGCTTCACATTCGA-1-HCATisStab7587202-1',
#  'GATGAAAGTAACGCGA-1-6-1',
#  'D353_Biop_Pro1CAGTAACTCCCTAACC-1-17-1',
#  'CAGAATCAGGTGATTA_F01607-1',
#  'AAATGCCCAACACCCG-1-HCATisStab7659971-1',
#  'P2_6_CATATGGGTATAAACG-1',
#  'TTCCCAGAGACTTGAA_HD68-1',
#  'ATCTGCCTCGTTACAG_T137-1',
#  'TCGTAGATCAAGATCC-1-6-1',
#  'TGATTTCGTTACCGAT_GRO-04_nasal_brush-1',
#  'D344_Biop_Nas1_TTTGTCACACAACGTT-1-11-1',
#  'GAACGGAAGACAGACC_HD68-1',
#  'CTCCTAGGTGCAGTAG-SC56-1',
#  'AAACGGGTCTACTATC-1-2-1',
#  'D344_Biop_Nas1_ACGAGCCCATTGCGGC-1-11-1',
#  'ACGAGGACACTGCCAG_F01607-1',
#  'D367_Biop_Pro1_TCTCTAATCAAAGACA-1-28-1',
#  'AACGTTGAGCTAGTTC_GRO-06_biopsy-1',
#  'GGAACTTCACCGGAAA_T85-1',
#  'TTTACTGGTACCATCA-1-7-1',
#  'GCAGCCAAGTGTTGAA-1-4-1',
#  'ACGAGGACAAATACAG_F01403-1',
#  'D367_Biop_Int1_GTAACTGGTGTGACCC-1-29-1',
#  'TGACAACAGTTAGGTA_GRO-04_biopsy-1',
#  'CATCGGGTCACCACCT_SC20-1',
#  'TCAACGAGTTCAGACT_HD67-1',
#  'AACCATGAGCTGAAAT_F02617-1',
#  'CTCGAGGAGTTGGACG_SC85-1',
#  'TAGCCGGCATAAGACA_F01851-1',
#  'GCCATGGAGAGATCGC_SC144-1',
#  'P1_2_GATCTAGAGCGTGAAC-1',
#  'TATCTCAAGATTACCC_F02617-1',
#  'AAAGATGGTTCAGACT-1-HCATisStab7747197-1',
#  'TCAAGTGGTAGACGTG_T101-1',
#  'TCCTCAGTTTGTGT_GRO-06_biopsy-1',
#  'P2_2_TTTGGTTAGCCCTAAT-1',
#  'CACCACTGTTCTCATT_GRO-07_biopsy-1',
#  'GGTTGTAGTAATGATG_SC144-1',
#  'ACATACGGTTAGAACA-1-6-1',
#  'D372_Biop_Int2_GGTGCGTGTTCCGTCT-1-34-1',
#  'CGAGAAGAGTCGCCGT_GRO-09_biopsy-1',
#  'CCCAGTTAGATAGGAG_F02607-1',
#  'AGAGCAGTCGGATACT_T166-1',
#  'AACGTTGAGATCTGAA-1-HCATisStab7747198-1',
#  'AGGCCGTAGCCATCGC_SC22-1',
#  'P1_3_GTATTCTTCCGGGTGT-1',
#  'AACTTTCTCTTAGAGC_F02522-1',
#  'CTACGTCTCCACGACG_F01366-1',
#  'AGTAGTCTCCACGCA_GRO-07_biopsy-1',
#  'ATTGGTGGTCCGAGTC_SC29-1',
#  'AGTTCCCGTAGGTTTC_SC142-1',
#  'CCCTCCTGTGAGTGAC-1-2-1',
#  'D363_Brus_Nas1_CAACTAGGTACAGTGG-1-23-1',
#  'GGTGTTACAGCTCCGA_F01851-1',
#  'GCGCCAACAGACACTT-1-1-1',
#  'AAGACCTCATCGATGT_F02607-1',
#  'CTCGTCATCTCTAGGA_F01366-1',
#  'ACGCCAGGTCCAGTTA-1-4-1',
#  'CGACCAAGACTAAGT_GRO-04_biopsy-1',
#  'GTAGTCACACTGCCAG-1-1-1',
#  'CTAAGACAGGTAGCTG-1-4-1',
#  'D339_Biop_Nas1_CACATTTCATGGTAGG-1-7-1',
#  'TGACAGTTCGCAGAGA_SC143-1',
#  'AAACCTGTCACCTTAT_GRO-08_biopsy-1',
#  'ACCGTAACAATAAGCA_SC18-1',
#  'AACAAAGCAGTTTGGT_SC88-1',
#  'CATATGGTCGGGAGTA_F02528-1',
#  'GGCGACTGTGAAAGAG-1-7-1',
#  'D326_Biop_Pro1_AGACGTTCATGGTCAT-1-3-1',
#  'CACAGTATCGTCACGG-1-7-1',
#  'CGGACACTCTCGTTTA_GRO-04_nasal_brush-1',
#  'CCGATTCACAGGCC_GRO-01_nasal_brush-1',
#  'D353_Brus_Dis1_TCACGAATCCAGTATG-1-19-1',
#  'P2_8_TTCTCCTGTCTGATTG-1',
#  'CCTCAGTAGCAGCCTC-1-4-1',
#  'P2_8_TATGCCCGTTCGCTAA-1',
#  'ATGATCGCACCTCAGG_SC84-1',
#  'TGAGCGCTCATTCCTA_SC144-1',
#  'GCCTCTACAGACGCCT-1-6-1',
#  'TCACAAGTCATTGCGA_F02617-1',
#  'GGTGAAGCAAGGGTCA_SC27-1',
#  'CAGCCGATCTACTTAC_F01641-1',
#  'CACCACTAGAGTACCG_SC22-1',
#  'P3_7_GTCGGGTGTAAATGTG-1',
#  'P3_5_GTCCTCATCCATGAGT-1',
#  'TTGGCAAGTCGCGGTT_GRO-10_biopsy-1',
#  'GATCAGTCATATGGTC_GRO-09_nasal_brush-1',
#  'GTGCAGCTCAGATTGC_SC144-1',
#  'TAGCCGGAGCTTTGGT_SC20-1',
#  'TGCTACCTCACCATAG_GRO-09_nasal_brush-1',
#  'TACTCGCAGCTCCTTC_GRO-04_biopsy-1',
#  'P2_4_ATCCGAATCAGAGGTG-1',
#  'P3_6_TAGCCGGTCACAAACC-1',
#  'P3_6_CGTTAGAAGGCTAGAC-1',
#  'GCCAAATCAGATGGGT-1-HCATisStab7747198-1',
#  'CTCCCTCCAGTTGCGC_SC86-1',
#  'GGCAATTGTACTCAAC-1-6-1',
#  'CTCAGGGAGTGGTTGG_SC144-1',
#  'P3_5_CAGAATCAGGTACTCT-1',
#  'GTTTGGAGTGTGACCC_T166-1',
#  'TACACGATCTGTTTGT_HD68-1',
#  'CTGCGGAAGAAGAAGC_HD101-1',
#  'TGGACGCTCCTAGAAC-1-2-1',
#  'TTAAGCCACAACTGT_GRO-11_biopsy-1',
#  'CGGAGTCTCCTTTCTC_F01506-1',
#  'TTAGGACTCAATACCG_SC18-1',
#  'CATTATCAGGTCGGAT-1-4-1',
#  'CACAGGCGTTGAACTC_F01851-1',
#  'CGTCACTAGCTCCTTC_HD68-1',
#  'TAGTGGTGTCGCTTCT-1-5-1',
#  'TTTCCTCAGTCGCCGT-1-2-1',
#  'GGTATTGCAGCTGGCT_SC24-1',
#  'AGGTCATAGCATCATC_F01639-1',
#  'TTTCCTCAGGGCTTCC_F01394-1',
#  'P2_7_GGGAGATCAAGTAATG-1',
#  'AGCGTATTCTGATTCT-1-1-1',
#  'CTTCCGAGTGGCTGAA_T90-1',
#  'P3_2_CAAGATCCAGATCTGT-1',
#  'TTCCCAGAGCCGGTAA_F03045-1',
#  'TGAGCCGGTAGTAGTA_F01851-1',
#  'CATTATCTCAGCATGT_F02611-1',
#  'ACTGCGGTCTAGTGT_GRO-07_biopsy-1',
#  'ACCCACTGTGCAGACA-SC56-1',
#  '7239213_GTCGGGTTCTCCAGGG-1',
#  'CTAGAGTAGCCAGGAT_GRO-09_biopsy-1',
#  'TGAGCCGCACCACGTG_F02524-1',
#  'TGGCCAGGTATTACCG-1-1-1',
#  'AGTTAGCGTTCGGTAT_SC143-1',
#  'TCTCATAAGACACGAC_F01851-1',
#  'ACGGGCTGTCACTGGC-SC45-1',
#  'TCCCGATGTAGTGAAT_GRO-11_biopsy-1',
#  'AACACGTAGGTGCACA-1-HCATisStab7587211-1',
#  'GTCCTCATCAGGATCT_F02522-1',
#  'P1_3_TAGTGGTCAGGGATTG-1',
#  'GACGTTAAGTTACGGG_F01157-1',
#  'GTAATCGAGAGCGACT_SC84-1',
#  'ACGATACAGGCACATG_F01607-1',
#  'GTGTTAGAGTACCGGA-1-2-1',
#  'P3_5_TATCTCATCCTGCAGG-1',
#  'P3_2_TACACGATCTTAGCCC-1',
#  'GTCATTTTCCAATGGT_SC29-1',
#  'D372_Brus_Nas1_CGAGCCAAGCCCAATT-1-31-1',
#  'CCTAAAGAGTGGCACA_SC10-1',
#  'ACAGATCAGAGGT_GRO-04_biopsy-1',
#  'ATTCTACCAAAGCGGT_T85-1',
#  'AGGGTGATCATATCGG_F01394-1',
#  'CGCGTTTAGGTGATAT_GRO-10_biopsy-1',
#  'ATTACCTAGTGGTTCT_SC88-1',
#  'TAGGCATAGGCTAGCA_HD67-1',
#  'CCTATTATCGTTGCCT_GRO-10_biopsy-1',
#  'D372_Brus_Dis1_CCTAAAGCACCAGGCT-1-35-1',
#  'GCAAACTTCGTCTGCT_F02526-1',
#  'CACGGGTGGGTATC-SC31D-1',
#  'GCTACAAAGATCCCGC_SC84-1',
#  'TGCCCATTCTGTTGAG_SC22-1',
#  'CAGTCCTAGCTTTGGT_GRO-09_biopsy-1',
#  'TTGTAGGAGCAGATCG-1-3-1',
#  'ATAGACCGTATTAAGG_SC142-1',
#  'CTGCGGACAGTCCTTC-SC56-1',
#  'ACTGAGTTCTGGTATG_F02524-1',
#  'P2_8_AACACGTTCGTGGTCG-1',
#  'CAAGATCCACAACGCC-SC59-1',
#  'AACACGTAGATCCCGC-1-2-1',
#  'GTAGAAACATAACCCA_SC84-1',
#  'GGAATAAAGCTGAACG_HD67-1',
#  'GTGTGCGGTCTCCATC-1-HCATisStab7587211-1',
#  'GCGCGATGTGGTCTCG_HD70-1',
#  'P3_3_CTCATTAAGTCAAGGC-1',
#  'TCAGGATGTGTAACGG-1-1-1',
#  'GCGCCAAGTGTGGTTT_T120-1',
#  'ACCCACTTCTCTAAGG_F02617-1',
#  'D339_Biop_Int1_CTCGAGGGTAAGGATT-1-9-1',
#  'P3_2_ATTCTACCAGTGACAG-1',
#  'P2_3_AGTCTTTAGTTCGATC-1',
#  'P2_8_GATGCTATCGCATGGC-1',
#  'CGTCTACGTCCAGTTA-1-HCATisStab7747197-1',
#  'ACACTGATCATGTGGT_F02522-1',
#  'TAATTCCCACGAGGTA_T167-1',
#  'GCTGCAGAGGGTCACA_SC86-1',
#  'TACGGGCCAAAGGCGT_T121-1',
#  'CACAGTAAGCCACTAT_SC29-1',
#  'CTCCTATCAATACC_GRO-09_biopsy-1',
#  'CGCAGGTGTTGAATCC_SC144-1',
#  'CCATTCGCACACTGCG_SC24-1',
#  'D353_Biop_Int2_CTGGTCTAGCTAAGAT-1-18-1',
#  'GACTACAGTGAGGCTA-SC156-1',
#  'GCACTCTGTGTGAAAT_F01394-1',
#  'P3_2_GACTGCGGTAGCGCAA-1',
#  'ACATACGTCGGACAAG_SC10-1',
#  '7239217_ATGCGATTCTACCTGC-1',
#  'TCGCGAGGTGATGTGG_SC27-1',
#  'GAACGGATCTGCAGTA-1-6-1',
#  'CTTAGGAAGTGGTAGC_F02509-1',
#  '7239218_CTCGGGATCGTTACAG-1',
#  'GTCGTTCTCCAGCAAT_SC84-1',
#  'GTATTCTGTAGGGTAC_F02617-1',
#  'TCAGCTCTCCTATTCA-1-HCATisStab7587211-1',
#  'CTCAACCCAATTGAAG_SC141-1',
#  'GGGACCTAGTGTCTCA-1-2-1',
#  'GTTACAGCAAAGCGGT_SC29-1',
#  'TCCACCACAGGTGACA_SC84-1',
#  'P2_1_CGACTTCCAGACTCGC-1',
#  'GGGCACTGTGTTGAGG_F02611-1',
#  'D354_Biop_Int2_ACCCACTCATTCACTT-1-21-1',
#  'ACGTCAACAGTCGTGC_GRO-07_biopsy-1',
#  'GAATGAATCTCGTATT_F01639-1',
#  'GTTCGGGAGGTGCACA_F02611-1',
#  'AGTGTCACATCTCCCA-SC56-1',
#  'GCGCAGTTCTACTCAT_F01394-1',
#  'CCGGTAGGTGTCGCTG-1-HCATisStab7747199-1',
#  'AACTCCCCAATGGAGC_F02522-1',
#  'TCATGTTTCTCTTCAA_T166-1',
#  'TTCTCCTTCCGGCACA_GRO-09_nasal_brush-1',
#  'D367_Biop_Pro1_CTGTGCTGTAGTGAAT-1-28-1',
#  'TCTCTAAGTGTAATGA_GRO-08_biopsy-1',
#  'CTTCCAAGGCAATTA_GRO-03_nasal_brush-1',
#  'TTGCGTCCAAGTTGTC-1-4-1',
#  'CTTGGCTAGACAATAC_HD101-1',
#  'CTGCCTATCCGTTGCT_SC18-1',
#  'AACTCTTCAGATGAGC_F01394-1',
#  'CGTTGGGGTATGAGAT_SC144-1',
#  'CGGACACAGGGATGGG_T121-1',
#  'TATCTCACATGACATC_HD68-1',
#  'GATGCTAGTCACTTCC-1-HCATisStab7747198-1',
#  '7239218_TTCCCAGAGTGAAGTT-1',
#  'CGAACATCAGACGCCT_GRO-09_biopsy-1',
#  'AGTGAGGAGAGCTATA_F02526-1',
#  'CTCATTAGTCTTTCAT_GRO-09_biopsy-1',
#  'P2_3_CATCAAGGTAATCGTC-1',
#  'D353_Brus_Dis1_TTATGCTGTCCTCCAT-1-19-1',
#  '7135919_ACATCAGCAGCTCGCA-1',
#  'P3_6_CTTAGGAAGCCACGCT-1',
#  '7185212_CTCGGGACAGGGAGAG-1',
#  'P2_5_CTCGAGGCATCGGACC-1',
#  'GTGCTTCAGCGTGAGT_SC144-1',
#  'TTCATTGAGTGTGTTC_SC84-1',
#  'TAAGAGAGTCCAAGTT_SC07-1',
#  'TGTCCTGCATTCGATG_SC144-1',
#  'AAATGAGTCAGCTAT_GRO-10_biopsy-1',
#  'D353_Brus_Dis1_CGATCGGAGGACGAAA-1-19-1',
#  'CCGTTCAGTGCGCTTG-1-4-1',
#  'TGTTACTTCATCCTGC_T164-1',
#  'D372_Biop_Pro1_CTCTAATCAGATGGGT-1-32-1',
#  'TACGGTAGTGGCTACC_SC87-1',
#  'AGCTTCCCAACTGCTA_SC85-1',
#  'GATTCAGTCAAAGTAG_SC29-1',
#  'ATTCCATCAAGACGAC_SC144-1',
#  'ACTGTCCCATACGCCG-1-HCATisStab7747197-1',
#  'CCGTTCATCTCACATT_F02611-1',
#  'TCAGCTCCAATGAAAC_F00409-1',
#  'TACTTACTCCTTCAAT_HD68-1',
#  'D353_Brus_Nas1_TGTGTTTGTGCACGAA-1-16-1',
#  'P1_2_AACGTTGTCGAGAGCA-1',
#  'CACACTCCATGGAATA_F02092-1',
#  'CTATAGGTCCAGTACA_SC144-1',
#  'GAATAAGTCTTATCTG-1-4-1',
#  'TTGAACGCACGTTGGC-1-HCATisStab7747199-1',
#  'TCTATTGTCTGTGCAA_SC07-1',
#  'TGTGGTACAATGTAAG_SC27-1',
#  'CAGAATCCAGACAGGT-1-0-1',
#  'TCACAAGGTTTGTTGG_F02524-1',
#  'D344_Brus_Dis1_GCTGCGACAAGGCTCC-1-14-1',
#  'D372_Biop_Int2_CGTGTAATCATCGATG-1-34-1',
#  'P3_5_AGCTTGATCCTACAGA-1',
#  'D354_Biop_Int2_TTAACTCAGGGATACC-1-21-1',
#  'CCAATCCCACGAAAGC_SC22-1',
#  'AGATCTGTCTGCAAGT_T126-1',
#  'P3_3_TACGGGCAGTGGAGAA-1',
#  'ACGTCAAAGACAGGCT_SC27-1',
#  'TTTCACGACAGGAG-SC14-1',
#  'P2_6_GGGTCTGGTTACCGAT-1',
#  'TAGGCATAGGGTGTTG_SC24-1',
#  'AAGTGAATCAGTGCGC_SC88-1',
#  'P1_3_GGGAGATGTGATGTGG-1',
#  'GGGCCATGTATCCCTC_SC144-1',
#  'TGCTGCTAGTAGCGGT_F02607-1',
#  'ATCTACTAGATGGGTC_F01365-1',
#  'TGCCGAGGTCCTGAAT_T101-1',
#  'CAGGTATTCGACATTG_SC144-1',
#  'TTATTGCTCCTATGGA_T164-1',
#  'TCTTCGGCATGAACCT_F01851-1',
#  'D353_Brus_Dis1_AGGTCCGTCTTCTGGC-1-19-1',
#  'P2_2_AAGTCTGAGAAGAAGC-1',
#  'ATGGGAGAGTCACAGG_SC84-1',
#  'GGGAGATTCCTTCAGC_T164-1',
#  'CACCACTTCGTTTAGG-SC156-1',
#  'P1_3_GTGTTAGGTGATGTCT-1',
#  'TTGTAGGGTTCTGGTA_HD68-1',
#  'GTATCTTGTACAGTGG_F02611-1',
#  'GCCTCTATCCTCAATT_F01851-1',
#  'CCAGCGAAGCGATATA_GRO-03_biopsy-1',
#  'CGAGTTAAGGTTATAG_SC143-1',
#  'P2_2_GGTGAAGTCAGCAACT-1',
#  'GAAACTCCAACGATCT_F02528-1',
#  'D326_Biop_Int1_GTCGGGTGTGGGTCAA-1-4-1',
#  'D353_Brus_Nas1_ACTGTCCAGATAGCAT-1-16-1',
#  'ATCATGGGTGTAATGA_F02526-1',
#  'AGATGTTAGT_GRO-09_biopsy-1',
#  'ATCACGAAGGGTATCG-1-7-1',
#  '7239217_TTGAACGCAGACAGGT-1',
#  'CTAATGGCAGGAATGC-SC156-1',
#  'CCACGGAGTTCGGCAC-1-4-1',
#  'CCTTCGATCAGTCCCT-1-HCATisStab7587205-1',
#  'CGAGCCATCTTACCGC_F01851-1',
#  'TCTGAGATCTTGCAA_GRO-10_biopsy-1',
#  'CAGTCCTTCGTACGGC-SC155-1',
#  'CAGCGACGTAAGTGTA_SC18-1',
#  'ATCGGATAGGAAGAAC_T90-1',
#  'TGTGGTATCTTCGAGA_F02528-1',
#  'CTGCCTAAGCTAGGCA_T126-1',
#  'GATGAAATCACAGGCC_HD67-1',
#  'P3_7_AGCGTATTCGCTTAGA-1',
#  'CATGGCGAGCACAGGT_HD68-1',
#  'TCTCATAGTCACCCAG_HD67-1',
#  'P2_1_AGGGTGATCTGCAGTA-1',
#  'D339_Biop_Int1_TTCTCCTGTCCATGAT-1-9-1',
#  'CCCAGTTGTTTAGCTG-SC56-1',
#  'D367_Biop_Pro1_CACAGTACACGAGAGT-1-28-1',
#  'D322_Biop_Nas1_GAAACTCCATCATCCC-1-0-1',
#  'P2_1_GGAATAATCCGCAGTG-1',
#  'D339_Biop_Int1_GACTACATCCTTGCCA-1-9-1',
#  'ACGCAGCTCGGCATCG_F01874-1',
#  'CTCGAGGGTAAGTTCC-SC56-1',
#  'TACAGTGAGACTGTAA-1-4-1',
#  'P2_1_ACCGTAATCCTTCAAT-1',
#  'P2_2_ACATCAGAGCCTATGT-1',
#  'CTCCTAGTCATTATCC_F02611-1',
#  'CGATGGCTCTGCTGCT_GRO-06_biopsy-1',
#  'CCCATACTCCCACTTG_F02617-1',
#  'CAACCAACACGACGAA_F01607-1',
#  'CATAAGCGTAAGTTAG_T166-1',
#  'TGCCAAAAGCTAGCCC_F01365-1',
#  'GTTCTATTCGAATCCA_SC84-1',
#  'GAGTCCGAGTACGCGA_HD66-1',
#  'P3_3_GACACGCGTTCGTTGA-1',
#  'GTTCTCGAGGTGACCA_SC10-1',
#  'GAGTGAGAGACTCCGC_SC141-1',
#  'D372_Biop_Int2_TCAGGATAGGATTCGG-1-34-1',
#  'CCTTACGTCTCGTTTA_T137-1',
#  'P2_6_CGGACTGGTCCTAGCG-1',
#  'CATTATCAGCTGTTCA_SC18-1',
#  'D354_Brus_Dis1_CTCGAGGAGGATGGTC-1-22-1',
#  'CATCGGGAGGGCTAAC_SC86-1',
#  'TACCGAAGTGTGCCTG_SC144-1',
#  'GACACGCCAAACGCGA_GRO-09_nasal_brush-1',
#  'P1_2_TTCTCAAGTAGCGCAA-1',
#  'GCGCAACCATACCATG-SC155-1',
#  '7135920_ACTGAGTCATATGGTC-1',
#  'GTACGTAAGACTCGGA-1-HCATisStab7659969-1',
#  'CTCAGAATCAATCACG-SC156-1',
#  'GATTGGTTCCGGTTCT_SC84-1',
#  'CACACTCCAAGCGCTC_GRO-03_nasal_brush-1',
#  'GGAAAGCCAATCAGAA_SC18-1',
#  'GGCGACTGTACCTACA_F02524-1',
#  'D372_Biop_Pro1_GAGGTGACATTGGCGC-1-32-1',
#  'ACACCAATCGCAAGCC_GRO-09_nasal_brush-1',
#  'CGTTAGAGTTCCGGCA-1-6-1',
#  'GCAATCAGTGCTCTTC_SC24-1',
#  'AGGGATGTCTCCAGGG-1-HCATisStab7747198-1',
#  'CTCAGAAGTCATCCCT-1-4-1',
#  'TGACCCTAGGGAGTTC_SC85-1',
#  'TTCTTAGAGAAGCCCA-1-7-1',
#  'CAAGTTGTCACGCATA_F01365-1',
#  'D353_Brus_Dis1_AGAGCGAAGACAAGCC-1-19-1',
#  'CCTACCAAGCTAACAA_HD66-1',
#  'CGTTCTGCAGTTGTTG_SC144-1',
#  'P2_6_GTAGGCCTCCCTCAGT-1',
#  'AGGAGGTTCCGTCAAA_SC85-1',
#  'ATAGACCAGCGCTTAT_F02524-1',
#  'GTGCTTCTCACTCTTA-1-1-1',
#  'D367_Brus_Nas1_GTCAAGTGTAAACCTC-1-27-1',
#  'CTCCAACTCCTAACAG_SC89-1',
#  'GGTATTGTCATTGCGA_F02611-1',
#  'D353_Brus_Dis1_GGATGTTAGAAACGCC-1-19-1',
#  'TGCTACCCAGCTGGCT-1-HCATisStab7747198-1',
#  'D326_Biop_Int1_CGGAGCTGTTCACCTC-1-4-1',
#  'TGGCGCATCTTGGGTA_F01403-1',
#  'P2_5_AACTCCCTCTTGAGAC-1',
#  'GAAACTCTCTGCAGTA_F02611-1',
#  'P3_3_TACTCGCAGCAATCTC-1',
#  'AAGACCTTCGCCCTTA_F02617-1',
#  'TCACAAGAGGAACTAT_SC141-1',
#  'D344_Biop_Nas1_CACAAACCACCACCAG-1-11-1',
#  'D326_Biop_Int1_TCGTAGAGTCGAACAG-1-4-1',
#  'GCGGGTTAGGTCATCT-SC156-1',
#  'AGTGGGAAGACTAAGT-1-HCATisStab7587202-1',
#  'TCAGCAAAGACGGTTG_SC87-1',
#  'AGAGCTTAGACCTTTG-1-HCATisStab7587202-1',
#  'AGATTGCGTTAAGGGC-1-4-1',
#  'GCTTCCAAGTGTTAGA-1-HCATisStab7659970-1',
#  'P3_7_AGATCTGCAGAGTGTG-1',
#  'P2_8_CCTCAGTTCTAAGCCA-1',
#  'CTCGTACCATGTAAGA_GRO-01_nasal_brush-1',
#  'ATTTCTGAGATAGGAG_HD70-1',
#  'AACGTCACAATTGTGC_SC87-1',
#  'GGCTGGTCAGACAAGC_F02524-1',
#  'P2_3_CAACCTCAGGCAGTCA-1',
#  'CTCGGAGTCATGCAAC_GRO-07_biopsy-1',
#  'TCATGGATCCGAGAAG_SC144-1',
#  'CAGCCATCGTAGATC_GRO-04_biopsy-1',
#  'CATCAGAAGAAGGACA-1-2-1',
#  'GCACGGTTCCACCTGT_SC87-1',
#  'D326_Biop_Pro1_AAGGAGCCATTGAGCT-1-3-1',
#  'D372_Brus_Dis1_ACCAGTACACACATGT-1-35-1',
#  'GGCGACTTCAAAGTAG_HD66-1',
#  'AGTAGTCAGGCGATAC-SC45-1',
#  'TGTGGTACAATAGAGT-1-5-1',
#  'TGAAAGATCCACTCCA_HD68-1',
#  'D322_Biop_Pro1_AACTCAGGTGTCGCTG-1-1-1',
#  'ACGAGCCCATACGCTA-1-HCATisStab7659969-1',
#  'GCGCAGTGTCTAGTCA_F01851-1',
#  'CTAGTGACAGGAACGT_HD67-1',
#  'CACATTTGTTCCACTC_SC29-1',
#  'TGTGATGTCACCACAA_SC84-1',
#  'P3_6_TGTGGTAGTTGTGGAG-1',
#  'CCACGGATCTGGTGTA-1-6-1',
#  'GACGGCTGTGTAATGA_F02607-1',
#  'TAGTGCAGTGCCTGAC_SC143-1',
#  'D354_Biop_Pro1_CACTCCAAGTACGCGA-1-20-1',
#  'D372_Brus_Nas1_CACCACTGTAGCTTGT-1-31-1',
#  'TGGCGCAAGGGTCTCC_F01851-1',
#  'AATCCAGAGCGTCAA_GRO-08_biopsy-1',
#  'ATTACTCGTAGACGTG_T153-1',
#  'D363_Brus_Dis1_GCTTCCAGTTGAGTTC-1-26-1',
#  '7239219_ACTGCTCAGTGGACGT-1',
#  'CGCAACGTCAGATAA_GRO-03_biopsy-1',
#  'CTGATCCCAGTCCTTC-SC45-1',
#  'TGTGTTTAGACTACAA_F01851-1',
#  'ATTATCCAGAGGTACC-SC155-1',
#  'D353_Biop_Pro1CCCTCCTGTCGGGTCT-1-17-1',
#  'CGTGAATTCGCCACTT_T153-1',
#  '7239217_AACTTTCTCGGTTCGG-1',
#  'CCGGGATTCTGCTGCT-1-5-1',
#  'P1_2_TTCTACAGTGGTGTAG-1',
#  'CGACTTCCAATCCGAT_T89-1',
#  'ACTTTCAGTGCCTTGG-1-4-1',
#  'TGAGGGACAGCACACC_SC144-1',
#  'ACGATACGTCGCTTTC_GRO-07_biopsy-1',
#  'CGTCAGGGTGTGACCC_HD68-1',
#  'D372_Biop_Int2_ACTATCTCAAGCGAGT-1-34-1',
#  'CCACCATCAATGTTGC_T154-1',
#  'AATCCAGTCCGCTGTT_F01851-1',
#  'GGTGTCGTCCGAGATT_SC88-1',
#  'TCGCAGGAGGTGATAT_SC144-1',
#  'AAACCTGTCACTTATC_T126-1',
#  'CGAGCCAGTTCGAATC_F01365-1',
#  'TGGGAAGCAGGTCTCG_SC10-1',
#  'AGACGTTAGGCTCATT_F02524-1',
#  'P2_6_GCATGTAGTATGGTTC-1',
#  'CATCCACAGCTAGCCC_HD68-1',
#  'TATTACCCACGACTCG_SC24-1',
#  'P2_2_GACGCGTTCTGGTTCC-1',
#  'D353_Biop_Pro1GGCGACTAGGAGTTTA-1-17-1',
#  'P3_2_TGACTTTAGTAACCCT-1',
#  'TAGCCGGGTCTTCAAG-1-1-1',
#  'AATGAAGGTACAAGTA_SC144-1',
#  'GGTGTTAAGACTAGAT-1-1-1',
#  'TAGGTACGTGACCTGC_SC144-1',
#  'GGGCACTCATCAGTCA_F01157-1',
#  'TGGTTAGTCAGCACAT_GRO-10_biopsy-1',
#  'ACCTTTACAGTAGAGC-1-4-1',
#  'CTGATAGCAGGTTTCA_GRO-04_biopsy-1',
#  'GTTCATTCACCCATGG_F02611-1',
#  'TGCGGGTCATCATCCC_F02611-1',
#  'AGTGATCTCGTGAGAG_SC144-1',
#  'D367_Brus_Nas1_CGATCGGAGAACTCGG-1-27-1',
#  'D363_Brus_Nas1_ATGAGGGAGAGGTTGC-1-23-1',
#  'CACCAGGGTCAGAAGC_GRO-04_biopsy-1',
#  'GCAGCTGTCAGCGCAC_SC141-1',
#  'CCTCAGTCACTATCTT_SC18-1',
#  'CGATGTAAGGCGTACA_HD66-1',
#  'TGCCCTACAATGAAAC_F02524-1',
#  'CTTAACTGTCATACTG-1-HCATisStab7747199-1',
#  'AGGAATAGTCTACAGT_SC88-1',
#  'P3_3_CCTACACAGTTCGCGC-1',
#  'GACCAATGTTCAGCGC_F02522-1',
#  'GACCTGGAGCGTAATA_F02611-1',
#  'TTCCTTCGTACCAGAG_SC86-1',
#  'GCGACCAGTTACCGAT_F02522-1',
#  'GCGCAACAGTTCGCAT-SC156-1',
#  'ACGCACCTGAAACA-SC31-1',
#  'AGACGTTTCATTCACT_HD101-1',
#  'P3_7_GCTGGGTCAGGACCCT-1',
#  'GGTGAAGGTACTCGCG_HD67-1',
#  'TACTTGTGTAGTGAAT_HD66-1',
#  'AGCCTAACACAGACAG_F01639-1',
#  'D363_Brus_Nas1_AAGGTTCGTAGCTGCC-1-23-1',
#  'TGCGGGTAGACAGAGA-SC45-1',
#  'GCGCGATAGGTCGGAT_SC27-1',
#  'CGCCAAGTCATGCTCC_HD101-1',
#  'P2_3_CTGTTTATCAACACCA-1',
#  'TTGGCAACATGTAGTC-1-HCATisStab7659970-1',
#  'P3_2_CATATGGCATTCCTGC-1',
#  'GGGCATCTCAGTCCCT_F01639-1',
#  'TTAATCCCAGAGCGTA_SC144-1',
#  'TCGGTAAGTAATCACC_GRO-09_biopsy-1',
#  'ATAAGAGCAGGGATTG_F01851-1',
#  'TCGAGGCGTAAAGGA_GRO-11_biopsy-1',
#  'CTAAGACTCTGGGCCA_HD67-1',
#  'GTAGAAAAGATTCGCT_SC144-1',
#  'AAGGAGCAGTCTTGCA_F01851-1',
#  'CGGAGTCAGAAGGTGA-1-4-1',
#  'ACGTCAATCACCGTAA_SC29-1',
#  'D363_Biop_Int2_ATGAGGGAGGACAGAA-1-25-1',
#  'D344_Biop_Nas1_GAACCTACAGGTCGTC-1-11-1',
#  'P2_5_CGGCTAGGTTCCACTC-1',
#  'ATTACTCAGGTGCAAC-1-HCATisStab7587208-1',
#  'CTTAGGATCTTGCATT_SC24-1',
#  'P2_1_GGCGACTTCGTTGACA-1',
#  'P3_6_TCGCGTTCATGCGCAC-1',
#  'CAGTCCTGTCGATTGT_F02992-1',
#  'TTCTCAATCTATCGCC_SC07-1',
#  'D339_Biop_Int1_TCATTTGGTACGCACC-1-9-1',
#  'ATTCTACAGTGCCAGA-1-5-1',
#  'D322_Biop_Pro1_GCTGCTTTCGTCGTTC-1-1-1',
#  'GGTGAAGTCCAGGGCT_SC10-1',
#  'AGATCTGCATGACGGA-SC156-1',
#  'TCAGCAATCGAACGGA_F01483-1',
#  'P3_7_GCAGCCAAGTACGCCC-1',
#  'GATTCAGGTTAGGGTG-1-1-1',
#  'P2_1_TCACGAACAGTTAACC-1',
#  'TATTACCTCAGCATGT_GRO-04_biopsy-1',
#  'P1_4_CCTCTGACACGTGAGA-1',
#  'GATCGATGTCCAGTAT_F01851-1',
#  'ATGGAGGCAATGTTGC_SC85-1',
#  'CATTCGCCATGATCCA_HD68-1',
#  'ACGATACAGAAGCCCA_SC22-1',
#  'TACACGACAAGCCTAT-1-7-1',
#  'D354_Biop_Int2_GCGGGTTAGAACTCGG-1-21-1',
#  'D372_Biop_Int2_TACTTGTCATAGTAAG-1-34-1',
#  'AAACTCCACGGATA_GRO-03_nasal_brush-1',
#  'ATCTGCCGTGACCAAG_F02611-1',
#  'TGATGGTGTCACGCTG_SC88-1',
#  'ACGGCCAGTAGCGTCC_F02607-1',
#  'AAAGATGTCGCCAGCA_GRO-03_biopsy-1',
#  'TTCCCAGAGTGCGTGA_GRO-04_biopsy-1',
#  'TCGAGGCAGATACACA_HD101-1',
#  'CAGCCGAAGGCTCTTA-1-1-1',
#  'CGGACTGTCTCTGAGA-1-HCATisStab7659969-1',
#  'TCATTTGTCAACGCTA_GRO-10_biopsy-1',
#  'TCTTCGGAGATCCTGT_T120-1',
#  'CACTCCAGTCCCGACA_F02522-1',
#  'AGGTCATTCCCAAGAT_GRO-09_biopsy-1',
#  'AGTTGGTTCATGGTCA_F01157-1',
#  'ACGATACTCAGCATGT-SC56-1',
#  'TCGATTTAGTCATGAA_SC144-1',
#  'TCATGGACAGCAGAAC_SC144-1',
#  'GTCACGGAGATCCCAT_SC20-1',
#  'ACTTGTTTCTGTCTCG_F01851-1',
#  'GACTCAAGTCTACGAT_SC144-1',
#  'P2_5_CAGTAACTCGTTACGA-1',
#  'GTGCATAAGCAATATG_F02611-1',
#  'ATTCTACTCAAACCGT_F01851-1',
#  'P3_7_CAGGTGCGTGAACCTT-1',
#  'D372_Biop_Pro1_CGACTTCCAATGGAAT-1-32-1',
#  'GGTGTTACACTTGGAT_SC24-1',
#  'AAGGAGCAGCTTCGCG_F01851-1',
#  'ACAGAAGTGGACGT_GRO-10_biopsy-1',
#  'CTCGTCAGTATGCTTG_SC18-1',
#  'D372_Biop_Pro1_AGCAGCCAGTAAGTAC-1-32-1',
#  'TTGCCTGCATCAGTGT_T164-1',
#  'CGCGTTTAGGCAGTCA-SC155-1',
#  'AGTACTGTCCTCGCAT_SC144-1',
#  'D372_Biop_Int1_CTACATTGTACATGTC-1-33-1',
#  'D339_Biop_Int1_ACACTGACATAGACTC-1-9-1',
#  'TGCACCTAGATGAGAG_SC07-1',
#  'GCATGCGCAAGGTGTG_HD68-1',
#  'GAAATGACACCCATGG-1-HCATisStab7587208-1',
#  'AGTCTTTAGGTAAACT_T137-1',
#  'P3_3_TCGAGGCAGCTGCCCA-1',
#  'D344_Brus_Dis1_GTTCTCGGTCCAGTTA-1-14-1',
#  'D363_Biop_Int2_TCGCGAGCAAAGCGGT-1-25-1',
#  'ATCGTAAGACAGACC_GRO-03_biopsy-1',
#  'CTCAACCCAAGTGGTG_SC87-1',
#  'AGTGAGGTCCCACTTG-1-5-1',
#  'TCTCTAACAAGTCTGT_GRO-10_biopsy-1',
#  'CCCTCCTTCTTTAGTC-1-4-1',
#  'CTCGAAACACAACGTT_GRO-09_biopsy-1',
#  'CTCAGAATCGAGTACT_SC144-1',
#  'GCGAGAACAACCAACT_SC144-1',
#  'CTTCTCTAGAAACCGC_F02611-1',
#  ...}

# %%
# one cell in adata_archmap has a different barcode
set(adata_archmap.obs.index) - set(adata.obs.index)
# Out:
# {'CATTCGCCAGTACACT-1',
#  'ATAAGAGCATCTACGA-1-1',
#  'TCGGTAAGTATCACCA-1',
#  'GGGCATCCACATTAGC-1',
#  'ACTGATGCAACTTGAC-1',
#  'ATCGAGTTCTAACTCT-1',
#  'CCCATACAGTTAGCGG-1',
#  'AGTCTTTTCCGTTGTC-1',
#  'CATTCGCAGACCTAGG-1-1',
#  'CCTTTCTCAGTCTTCC-1-1',
#  'GGCGACTCACCCTATC-1',
#  'GAAATGAGTCGAAAGC-1',
#  'TGAGGGAGTCTCCCTA-1',
#  'ATAAGAGGTATATCCG-1',
#  'CTGCCTACAGGCTGAA-1',
#  'TGTATTCTCTAACGGT-1',
#  'TAAACCGTCAGCGATT-1',
#  'AGGGATGAGTGACATA-1',
#  'TAGACCAGTTGGTGGA-1',
#  'TGGGAAGTCGGTCCGA-1',
#  'GATCGTAAGCGTGAGT-1',
#  'TTTATGCTCTTGCAAG-1',
#  'ACGGGTCAGTCTTGCA-1',
#  'AGATTGCCATGGTTGT-1',
#  'CTCGGAGCATTATCTC-1-1',
#  'GCTGGGTTCTACGAGT-1',
#  'CCACGGAGTCAATACC-1',
#  'GGATGTTGTCAATACC-1',
#  'ATAACGCCAATGGAGC-1',
#  'TTGCGTCCAACGATGG-1',
#  'CCGTGGAAGCCTTGAT-1',
#  'CTGGTCTGTAGCTTGT-1',
#  'GGTATTGCATGTCTCC-1',
#  'CCGTACTAGCCTATGT-1',
#  'GGGCACTGTGAGTGAC-1',
#  'ATTACTCGTACGACCC-1',
#  'TCATTACTCACTCCTG-1',
#  'TATTACCAGATCCGAG-1',
#  'TGCCCATTCTCGAGTA-1-1',
#  'GCCTCTAGTCGAGATG-1',
#  'CAGTAACAGCCAGTTT-1',
#  'TACACGACAAGAAAGG-1',
#  'ATCATGGCACGGTGTC-1',
#  'ACATCAGAGAAGAAGC-1',
#  'CCCAATCCATGGAATA-1-1',
#  'GGGCACTCAATGAATG-1',
#  'AACCATGCATCTCGCT-1',
#  'TGCCCTAAGGAACTGC-1',
#  'GGGTCTGCACATAACC-1',
#  'GTTCATTCACAAGACG-1',
#  'GCTGGGTCAAAGGTGC-1',
#  'ACACCAAGTGTTTGTG-1',
#  'GTGTTAGTCGTTTATC-1',
#  'CCACTACGTTGGACCC-1',
#  'CTACGTCAGTTTGCGT-1',
#  'CATTCGCGTGTGACCC-1',
#  'CTCTACGCAACTGGCC-1',
#  'TTTACTGAGAGAGCTC-1',
#  'CCGTACTCACGCGAAA-1',
#  'CAGCGACGTTGAGGTG-1',
#  'AGGTCATCAGCTCGCA-1',
#  'CCCTCCTCACGCCAGT-1',
#  'CGTAGCGCAGCTTCGG-1',
#  'GTACTCCCAAACTGCT-1-1',
#  'GCATGATGTCCTCTTG-1',
#  'TTCTTAGTCAGTGTTG-1',
#  'CGTTCTGGTGCAACTT-1',
#  'CAGCAGCCAAGCCATT-1',
#  'AAGTCTGAGGCATGGT-1',
#  'TTGAACGGTCCATGAT-1',
#  'TTGGAACGTGACAAAT-1',
#  'CGTTCTGCAACACGCC-1',
#  'GACGCGTTCACTCTTA-1',
#  'TCTGGAAGTCCCTACT-1',
#  'ACTTACTCAGACGCTC-1',
#  'CTAATGGAGAGGTTGC-1',
#  'AGCAGCCAGTGGAGAA-1',
#  'AACTCAGAGAATGTTG-1',
#  'AACTCTTAGCTCAACT-1',
#  'TTCTACAAGTCATCCA-1',
#  'TATCAGGCATTCTCAT-1',
#  'GACTACACAGGACGTA-1',
#  'CATCCACAGGTGCTTT-1-1',
#  'CATTATCGTCCGAAGA-1',
#  'GGGAATGTCTTGGGTA-1',
#  'TACGGGCAGCACAGGT-1',
#  'CAAGAAAAGTGTACCT-1',
#  'TGTATTCTCCGCGGTA-1',
#  'ACTGCTCTCAGTTTGG-1',
#  'CTCGAAAAGGTGTGGT-1-1',
#  'TGTCCCAAGCTAGTTC-1-1',
#  'GACTAACAGGATGTAT-1',
#  'CTACACCGTGAGGGAG-1',
#  'AGCTCTCTCACAACGT-1',
#  'CGTGAGCCACCGGAAA-1',
#  'CACTCCAGTCTGGAGA-1',
#  'CCTTCCCAGAGTGAGA-1',
#  'AGGCCGTAGGCCCGTT-1',
#  'ACGTCAACACGAAATA-1',
#  'TGCGCAGCAATGTAAG-1',
#  'AGTTGGTGTGAGTGAC-1',
#  'CCCATACGTAAACACA-1',
#  'TTAGGCAAGACGCAAC-1',
#  'TGAGCATGTTACGGAG-1',
#  'TCCACACGTCATCCCT-1',
#  'CAACCTCCAGCTCGCA-1',
#  'ATGGGAGCACACCGAC-1',
#  'AGATCTGAGCCAGGAT-1',
#  'CACAAACTCCAGTAGT-1',
#  'CCTCTGAGTATCAGTC-1',
#  'CTCACACGTTCCATGA-1',
#  'TGGACGCCACTTCTGC-1',
#  'TCAGCTCCAGTTTACG-1',
#  'CCATTCGCAGCGTAAG-1',
#  'GACACGCAGCGGCTTC-1',
#  'CACCTTGAGCTACCTA-1',
#  'GGTGCGTAGTCATGCT-1-1',
#  'GGCGTGTGTGTGAATA-1',
#  'CAACCTCAGAGTTGGC-1',
#  'TGGGAAGTCCTGTAGA-1-1',
#  'ATGTGTGAGAAACCAT-1-1',
#  'TCTGAGAAGGTCATCT-1',
#  'TCTTCGGAGGAGCGTT-1',
#  'GTAACTGTCCGTCAAA-1',
#  'TCTGAGAGTGCACCAC-1',
#  'CCACCTATCTGATTCT-1',
#  'GTTTCTAGTCTCACCT-1',
#  'TGCCAAAGTCCGACGT-1',
#  'CTCGAGGTCGTTGCCT-1',
#  'GAGTCCGAGGGTCTCC-1',
#  'TAAGTGCGTTACCGAT-1',
#  'GATGAGGCATTCCTCG-1',
#  'CTACATTAGAGTACCG-1',
#  'CGACTTCAGCAGGTCA-1',
#  'TGCTGCTGTTCCAACA-1-1',
#  'GCATGTACATATACCG-1',
#  'TCTTTCCAGAGTACAT-1',
#  'CTGTGCTGTTAAAGTG-1',
#  'CCGGGATAGCTAGTTC-1',
#  'TACCTATTCTCCAACC-1',
#  'ACTGAGTTCTGTCCGT-1',
#  'GCGCCAAAGGTGTGGT-1',
#  'GACTACAGTAAGAGAG-1-1',
#  'GTCAAGTGTTCCAACA-1',
#  'CGAACATGTAGAGTGC-1',
#  'CTGATCCCAATAGAGT-1',
#  'TTCGGTCTCTCATTCA-1',
#  'AGTGGGAGTCGAGATG-1',
#  'CTGTGCTCACGAAAGC-1',
#  'CTACCCACAATCAGAA-1',
#  'TTTATGCAGGCCATAG-1',
#  'GTGCAGCAGATCTGCT-1',
#  'TACCTTAAGCGTCAAG-1',
#  'GATCTAGGTTAAGACA-1',
#  'ATGTGTGCATAGGATA-1',
#  'TACACGAAGACACGAC-1-2',
#  'TACGGATTCGGAAATA-1',
#  'GCACATAGTGGTCTCG-1-1',
#  'CGGACTGTCGGATGGA-1-1',
#  'CCTTACGGTGGCAAAC-1',
#  'GTTTCTATCACGCGGT-1-3',
#  'TCGCGAGAGGTGCTTT-1-1',
#  'ACCAGTAGTAAATACG-1-1',
#  'GACCAATCATAGTAAG-1',
#  'TTTGGTTGTTGGAGGT-1',
#  'CGATGGCTCAACGCTA-1',
#  'GGACATTCACAGACTT-1',
#  'GTGCAGCGTTAGATGA-1',
#  'CTGGTCTCATCCCATC-1',
#  'GGTGCGTGTGCACGAA-1',
#  'AACTCTTTCGAATCCA-1-1',
#  'CCTTCCCCAGGAATCG-1',
#  'GACAGAGTCAGTCCCT-1',
#  'GCTTCCATCCTAGGGC-1',
#  'CCTCAGTCACTTACGA-1',
#  'GAGGTGATCGCGTAGC-1',
#  'TGGTTCCTCTCGTTTA-1',
#  'GACGTTAGTTCGTGAT-1',
#  'TTTCCTCTCCAGATCA-1',
#  'CATCCACCAATCTACG-1',
#  'CATCGGGAGTAGATGT-1',
#  'TCAGGTAAGCGTAATA-1',
#  'CTAACTTCAGGATTGG-1',
#  'GACCAATCACCCAGTG-1',
#  'CAACCTCCACGGCCAT-1',
#  'GATGAGGGTAAGTGGC-1',
#  'GCCTCTATCTGATTCT-1',
#  'CCGTACTTCTGCGTAA-1-1',
#  'CTCGGGACAAGGTTTC-1',
#  'TGAAAGAGTAGATTAG-1',
#  'TGCCCTAGTGGTCCGT-1',
#  'TTCTACATCCAAAGTC-1',
#  'CTACACCTCTTGTTTG-1-1',
#  'ACGGAGAAGATCGGGT-1',
#  'GCGAGAACAATCGAAA-1',
#  'GTGCATACAATAACGA-1',
#  'GAATAAGTCCTTGACC-1',
#  'CGGTTAATCTCGCATC-1',
#  'CAGATCATCAGCTTAG-1',
#  'AGAGTGGCAACTTGAC-1',
#  'AGCTTGACAAACCCAT-1',
#  'ACTATCTTCCCAGGTG-1',
#  'CGTAGGCAGACAGAGA-1',
#  'TGATTTCAGGCGATAC-1',
#  'GTCCTCAAGTCGTTTG-1',
#  'CCACGGACATCTACGA-1-1',
#  'CACACAAAGATGGGTC-1',
#  'CACCACTAGGGATCTG-1',
#  'CGATTGAGTCGATTGT-1',
#  'CCTACACGTAAGTAGT-1',
#  'TCGTAGATCTGTACGA-1',
#  'AGCTTGACAAGCCATT-1-1',
#  'GACCAATTCATGTCTT-1',
#  'TAGGCATAGGTTACCT-1',
#  'CACCTTGAGTGCGATG-1',
#  'AGCTCTCGTGCCTGCA-1',
#  'GTTTCTAAGGCCCGTT-1',
#  'CTTTGCGAGGCTATCT-1',
#  'CTCGGAGAGCTGTCTA-1',
#  'GAGGTGACACAAGTAA-1-1',
#  'CCGTACTAGATCTGAA-1',
#  'ACGATACCAGATGAGC-1',
#  'CAAGAAAGTTTGACAC-1',
#  'CTAACTTCATCCCACT-1',
#  'CATGGCGCAGTTCATG-1',
#  'GGAATAAGTCTCAACA-1',
#  'CTGATAGCACAGTCGC-1',
#  'GGGCACTCAGCTTAAC-1',
#  'GTGTTAGCATTGGCGC-1',
#  'ATCGAGTCATTCTTAC-1',
#  'GTATTCTTCAATACCG-1',
#  'ACACCGGAGGAATCGC-1',
#  'TGAAAGATCTTCGGTC-1',
#  'GACTAACTCACGAAGG-1',
#  'ACAGCTAGTACCATCA-1',
#  'GAATAAGCAGATTGCT-1',
#  'ACGAGCCCACGACGAA-1',
#  'GCACTCTGTTATTCTC-1',
#  'GATCAGTGTATGCTTG-1',
#  'CTCCTAGTCTCGTATT-1',
#  'TTCTCAATCTGGTGTA-1-1',
#  'AGCGTATTCGCCAAAT-1',
#  'CACCACTTCGCAAGCC-1',
#  'CGGACACAGATGCCTT-1-1',
#  'AAATGCCTCGATGAGG-1',
#  'CGGACGTTCTGCCAGG-1',
#  'GAATAAGTCTCTAAGG-1',
#  'CTTAACTAGAGAACAG-1',
#  'CGCGTTTTCGCGTTTC-1',
#  'GTCAAGTTCCGCGTTT-1',
#  'GAGGTGACATACAGCT-1',
#  'TTCTCCTCATACTACG-1',
#  'TACAGTGGTATTCGTG-1',
#  'AGGGAGTTCAGCTTAG-1',
#  'GGCTGGTGTTGTACAC-1',
#  'CATGGCGGTACCAGTT-1',
#  'GCCAAATTCAGAGACG-1',
#  'GCTCTGTCACGAAAGC-1',
#  'CAGAGAGGTCCAGTTA-1',
#  'CGGAGCTTCGCCATAA-1',
#  'TTGGAACGTAATTGGA-1',
#  'TTAGGACGTTACTGAC-1',
#  'GATCGCGTCTACTATC-1-1',
#  'CAACCTCAGAAGGTGA-1',
#  'GCGCGATAGAGGTACC-1',
#  'AGATCTGTCTTGCCGT-1',
#  'TGAGGGAAGATCGATA-1',
#  'AAGGAGCGTGAGTATA-1',
#  'GGTGAAGAGCCAGAAC-1',
#  'CTCATTATCGTCGTTC-1',
#  'CATGGCGAGTATGACA-1',
#  'CCATGTCGTTACGTCA-1',
#  'GAACCTACATGTTCCC-1',
#  'TACAGTGTCTGGTTCC-1',
#  'ACTTGTTCAGATCGGA-1-1',
#  'TCACAAGGTAGCGCAA-1',
#  'ACAGCCGTCCTAAGTG-1',
#  'CACATAGTCCTATTCA-1',
#  'AAACGGGTCACAAACC-1',
#  'TCACGAAAGTGTGAAT-1',
#  'CACATAGAGGATCGCA-1',
#  'ACTATCTCAGGATTGG-1-1',
#  'ATAAGAGAGCATGGCA-1',
#  'CGATTGAAGTACGTAA-1',
#  'CTCTAATAGCAAATCA-1',
#  'TACTCATAGACAATAC-1',
#  'TTCTTAGGTGATAAAC-1-1',
#  'GGGACCTTCATCGATG-1',
#  'AGGGTGATCTACTATC-1',
#  'TGGGCGTTCGCATGAT-1-1',
#  'CCACTACCAGCAGTTT-1',
#  'CCGTACTGTCTCATCC-1',
#  'CGGACACGTATCAGTC-1',
#  'GGTGTTAAGGCCATAG-1',
#  'AGGGATGTCCTGTACC-1',
#  'ACCCACTGTCTAGTCA-1-2',
#  'AGGGTGAGTGTGTGCC-1',
#  'GGGTTGCGTGACAAAT-1',
#  'TCGAGGCAGTTAACGA-1',
#  'ACGCCGAGTTACCGAT-1',
#  'TGAGAGGCACATCCAA-1',
#  'GTCACAATCTGCTGTC-1-1',
#  'CAGAATCAGTCACGCC-1',
#  'ATGAGGGCAACTTGAC-1',
#  'GTAACTGCACGAGAGT-1',
#  'TTAGTTCCATCCGGGT-1',
#  'GTATCTTAGGGAAACA-1',
#  'TTGCGTCAGTACGTAA-1',
#  'ATCCGAAGTAGAAGGA-1',
#  'TATCTCAGTTCCTCCA-1',
#  'GTCCTCACATATACCG-1',
#  'GGAAAGCAGCTAACAA-1',
#  'CTTAGGAAGGGATACC-1',
#  'ATGGGAGAGAAAGTGG-1',
#  'CGCTTCAAGACCACGA-1',
#  'TTCTTAGTCACGATGT-1-1',
#  'GTACTTTGTACCGTAT-1',
#  'AGCAGCCGTTATCACG-1',
#  'GGCAATTGTTCCACTC-1',
#  'CTCCTAGGTTGCGCAC-1',
#  'AAAGTAGTCTGAGTGT-1',
#  'TTCTCAATCCAAATGC-1',
#  'CGTGTCTAGGACCACA-1',
#  'CATCAAGTCAGAGGTG-1-1',
#  'CTCTAATAGGCTCTTA-1',
#  'CACACCTTCGGTGTTA-1-2',
#  'CAGTAACAGTAACCCT-1',
#  'TGGACGCGTTCCGGCA-1',
#  'AGGCCGTCAGGCAGTA-1',
#  'CTGTTTAAGCTACCGC-1',
#  'ACTTTCAGTTCGGCAC-1',
#  'TTTGGTTCATGGTCAT-1',
#  'CTAGCCTAGCTCAACT-1',
#  'CTCGGGACATCAGTAC-1',
#  'CGGAGTCCACGCTTTC-1',
#  'TTTCCTCAGACAGGCT-1',
#  'ACGCCGATCGTGACAT-1',
#  'CCAGCGACAGTTCATG-1',
#  'CCGTTCAGTTTGTTTC-1',
#  'CAAGTTGGTTCCTCCA-1',
#  'CGGACGTAGGCGTACA-1',
#  'TGAAAGAGTAAACGCG-1',
#  'GTCTTCGGTGGGTCAA-1',
#  'CCTAGCTTCCTATGTT-1',
#  'CGATGTATCCCAAGAT-1',
#  'CGTGAGCGTGCTAGCC-1',
#  'GTAACTGCAGTCCTTC-1',
#  'ACTTGTTTCACAAACC-1',
#  'TGCACCTGTGGCAAAC-1',
#  'CTGAAACGTCGGCACT-1-1',
#  'CTAAGACAGCAATATG-1',
#  'CTAACTTAGCTCCTTC-1',
#  'TAGACCACAGCGATCC-1',
#  'GCAGTTAAGTGGTAAT-1',
#  'ATCCGAAGTCTAGAGG-1',
#  'CATCGAACATGGATGG-1-1',
#  'CAGCTAACATTTGCCC-1',
#  'CACCTTGTCAGCTTAG-1',
#  'TACTCATCAACCGCCA-1',
#  'TCATTTGTCAACGAAA-1',
#  'CAGCCGAAGACTACAA-1',
#  'ATCTACTCAGTGAGTG-1-1',
#  'CCCAGTTGTTCGCGAC-1',
#  'ACCCACTCACCTCGGA-1',
#  'ACCGTAATCCGTCAAA-1',
#  'CGATGTAAGAGCTGGT-1',
#  'GTGGGTCTCTTGACGA-1',
#  'TACAGTGAGGGTATCG-1',
#  'AAGGCAGTCTGCTGTC-1',
#  'GTGGGTCAGAGACTTA-1',
#  'TGGCTGGCAATGTAAG-1',
#  'GTAACTGCATCCCATC-1',
#  'CGATGGCCAAGTAGTA-1',
#  'GTGTGCGTCGCAAGCC-1-1',
#  'CTGATAGTCGGCGCAT-1',
#  'CTCGAAATCCAAGCCG-1',
#  'CCATGTCAGGTCATCT-1',
#  'GCTGCTTCATGCATGT-1',
#  'CAGAGAGCACATGTGT-1-1',
#  'ACGATGTGTTTGTTGG-1',
#  'GACGTGCAGCTAAGAT-1',
#  'AGCAGCCCATCATCCC-1',
#  'GGACAGATCACGCATA-1',
#  'GGTGCGTAGAGATGAG-1',
#  'TGCACCTTCGGAAACG-1',
#  'GCAATCAAGCGTCTAT-1-1',
#  'TGAGGGAGTGAGGGAG-1-1',
#  'CAAGGCCCATCCCACT-1',
#  'CACAGGCTCGTCCAGG-1',
#  'TAAGAGAAGAGTCGGT-1',
#  'CTTACCGAGGCTATCT-1',
#  'AGCAGCCTCCGGGTGT-1',
#  'CCAGCGATCTAACTCT-1',
#  'ACGCCAGAGTGTACCT-1',
#  'GAAACTCGTAGCGCAA-1',
#  'TTGACTTCAAGAAGAG-1',
#  'GTAACTGAGGCGTACA-1',
#  'TAGTTGGAGAAGGTGA-1',
#  'ACGGGCTTCCCGACTT-1',
#  'GTACGTACATCCGGGT-1',
#  'CAGCAGCGTCCGTCAG-1',
#  'CCGTTCATCAGCCTAA-1',
#  'CTTAGGAAGATCGGGT-1',
#  'ATAAGAGCAAGCTGTT-1',
#  'CGAGCCACACGCTTTC-1',
#  'TAGTGGTTCTCTTGAT-1-1',
#  'AGGGATGAGACTACAA-1',
#  'GGGATGAGTCATGCCG-1',
#  'GTCATTTAGGCTCAGA-1',
#  'GTCATTTTCCTAAGTG-1',
#  'GGGACCTCAGTATAAG-1',
#  'TCAGGATAGTATTGGA-1',
#  'ACACTGAAGCTGTTCA-1',
#  'CATTCGCCAATTCCTT-1',
#  'ACATGGTGTACCAGTT-1',
#  'GTACTTTTCCTGCTTG-1-2',
#  'CGCCAAGGTACCGCTG-1',
#  'TTAACTCCACGACGAA-1-3',
#  'ACGGCCACAAGACGTG-1',
#  'GACGCGTAGCTGATAA-1',
#  'TGCGGGTGTTCCACTC-1',
#  'CTACATTCAATTGCTG-1',
#  'CGTGTAACATCGGACC-1',
#  'CCTTCGAGTCAACTGT-1',
#  'TTAGTTCGTCTAGAGG-1-1',
#  'TGCCCTATCCGAACGC-1',
#  'GCCTCTAAGTTTAGGA-1',
#  'GATCGCGGTTGGAGGT-1',
#  'ATCTGCCCAGGATCGA-1',
#  'CACATAGCACATTTCT-1',
#  'ACTTACTTCCAAATGC-1',
#  'GCGAGAAAGTGAACAT-1',
#  'TACTTGTAGCTATGCT-1',
#  'ACATACGAGGTGCACA-1-1',
#  'ACAGCCGCAACGCACC-1',
#  'CAACCAAAGTCTCGGC-1',
#  'GCGCAACAGTTGAGTA-1',
#  'AAACGGGTCATCGCTC-1',
#  'TATGCCCAGCATGGCA-1',
#  'CCGTTCACAGACGTAG-1',
#  'ATGAGGGGTTCAACCA-1',
#  'CTGGTCTAGATGTGTA-1',
#  'CGATGTAAGCTAGTTC-1',
#  'ATCCGAACACCAACCG-1',
#  'GAATAAGCATGCGCAC-1',
#  'TGTATTCTCTGGTATG-1',
#  'TCGCGTTTCGTCTGAA-1-1',
#  'GGACATTTCAGGCGAA-1',
#  'CGAGCACTCTCCCTGA-1',
#  'TATCTCATCTTCATGT-1',
#  'TTGTAGGCATGCCTAA-1',
#  'AGTTGGTTCTACCTGC-1',
#  'GTCTTCGTCCGTCATC-1-1',
#  'CGTAGGCAGCTGAACG-1',
#  'CAAGTTGGTCTAAAGA-1-1',
#  'TGGGCGTCACCACCAG-1',
#  'TATCAGGAGGGATCTG-1',
#  'CTAAGACAGGAATCGC-1',
#  'ATCGAGTTCCAGTATG-1',
#  'TGCGCAGAGTGCTGCC-1',
#  'TATTACCCAGCTTCGG-1',
#  'AAAGTAGTCTCACATT-1',
#  'GGGCATCTCCAAACAC-1',
#  'TCCACACTCACTGGGC-1',
#  'CACCACTGTATAAACG-1',
#  'GCACTCTGTCAGTGGA-1',
#  'GAGGTGATCAGGTTCA-1',
#  'CATCAGAGTTAAAGTG-1',
#  'GCTTCCATCCACGTGG-1',
#  'CATATGGAGTTCCACA-1',
#  'GGACAGAAGAGTGAGA-1',
#  'CGGCTAGCAGCTGTGC-1',
#  'CTCTGGTCATGAACCT-1',
#  'CCATTCGGTGATAAAC-1',
#  'TCAATCTAGAGATGAG-1-1',
#  'AGATCTGTCCTATGTT-1',
#  'GAATAAGAGGTGGGTT-1',
#  'CAGGTGCAGTGTACCT-1',
#  'TGAGCCGCATTCTCAT-1',
#  'CCTAAAGAGCGCCTCA-1',
#  'TCGGGACTCACATACG-1',
#  'GCGCCAATCGTGGTCG-1',
#  'ATCCGAACAGCTATTG-1',
#  'TGGCCAGGTTAAGATG-1',
#  'CTACCCACAAGCCTAT-1',
#  'CATTCGCTCTGCGGCA-1',
#  'ACGCAGCGTTTAAGCC-1',
#  'GTCTTCGTCTGTCTAT-1',
#  'CTAGTGAAGGCCCTCA-1-1',
#  'CGCGTTTCATTGTGCA-1',
#  'CGGGTCACAGACTCGC-1-1',
#  'CAACCAATCTTCCTTC-1-1',
#  'CTAGTGAGTGATGATA-1',
#  'CCTTCGACACGGCCAT-1',
#  'TGCTACCCATTTCAGG-1',
#  'CAGCCGAAGTTCGATC-1',
#  'CTCTACGTCCTCAATT-1-1',
#  'ATCATGGAGAGGGCTT-1',
#  'ATAAGAGCAGGACCCT-1',
#  'CATTATCGTTGACGTT-1',
#  'CTGATCCGTGTGCGTC-1',
#  'ACACTGATCTCCCTGA-1',
#  'ACGGCCAGTTATGCGT-1',
#  'AACCATGCATTCCTCG-1',
#  'TACTTGTTCCACGTGG-1',
#  'GGCTGGTGTATCTGCA-1',
#  'TCGTAGATCCGAATGT-1',
#  'AAGCCGCTCGTACGGC-1',
#  'TGGACGCAGCCCAACC-1',
#  'CACACAAAGGATCGCA-1',
#  'CAGAATCGTTCGGCAC-1',
#  'CACATAGTCTTAACCT-1',
#  'CGCTTCACATAGAAAC-1',
#  'GAACATCGTAGGGTAC-1',
#  'GCTTCCAAGCGTCAAG-1',
#  'TGACGGCGTTGTGGAG-1',
#  'AGAGTGGCATTGGTAC-1',
#  'CAAGAAAAGTTGTAGA-1',
#  'ACGGGTCCAGGGTACA-1',
#  'CATGGCGGTACAAGTA-1',
#  'TCTATTGCAAATCCGT-1',
#  'CAGTCCTAGAAGGTTT-1',
#  'CATGACACAGTATCTG-1',
#  'CTACGTCAGGGCTTGA-1',
#  'AGGGAGTTCGGTCCGA-1',
#  'ACTATCTCACAGGTTT-1',
#  'TACGGTAGTTTAGCTG-1',
#  'GCTGCTTAGGTCATCT-1',
#  'GACAGAGTCCTATTCA-1',
#  'CTGATAGTCTCGAGTA-1',
#  'TTCTCAACACCGGAAA-1',
#  'TCAGGTATCTGTTGAG-1',
#  'TTGGAACAGCTAGCCC-1',
#  'CGTCACTCAAGGCTCC-1',
#  'CATTATCGTCGCGGTT-1',
#  'AAGCCGCCAGCGTTCG-1',
#  'TCTCATATCGGAGGTA-1',
#  'ACGATGTCAGGCGATA-1',
#  'CAAGTTGCAAGTTGTC-1-1',
#  'AGCGGTCAGCACACAG-1',
#  'TACAGTGTCACTCCTG-1',
#  'CTGATAGAGTCCTCCT-1',
#  'GACAGAGGTCTGCAAT-1',
#  'TCGAGGCTCACAGTAC-1',
#  'TGAAAGAGTCGAATCT-1-1',
#  'AGCGTATGTGATAAAC-1',
#  'TACGGTATCTACCTGC-1',
#  'CGGTTAATCGGAAATA-1',
#  'GTACGTAGTGCCTTGG-1',
#  'GCCAAATTCAAACGGG-1',
#  'GAACCTATCTGCAGTA-1',
#  'CAAGATCGTCTGGAGA-1',
#  'ACACCCTGTTCCCGAG-1',
#  'CTCAGAAGTGATGTGG-1',
#  'TACCTATGTCGCGGTT-1',
#  'GGAATAAGTGAGTGAC-1',
#  'ACTTACTAGCGCTCCA-1',
#  'GTAGGCCGTCCGAAGA-1',
#  'GACGTTATCTCAAACG-1',
#  'CAGCGACTCCCAAGAT-1-1',
#  'GCTGCTTCATGATCCA-1-1',
#  'GCGACCAAGATGTTAG-1',
#  'AGAATAGCATCGATGT-1',
#  'ACGCAGCAGTATTGGA-1',
#  'CATCAAGTCACCGGGT-1',
#  'TGAGCCGTCACTCCTG-1',
#  'ATAGACCTCAAACAAG-1',
#  'AATCGGTTCGCTTAGA-1',
#  'TCAGATGAGCTAAGAT-1',
#  'AACTTTCCAGATGGCA-1',
#  'ACAGCTAGTCTGATTG-1',
#  'TGCACCTGTAGAAGGA-1',
#  'AGAGCTTTCATGTCTT-1-1',
#  'TGAGCATAGAAGGCCT-1',
#  'GTGCATAAGATGTGTA-1',
#  'TTCTTAGGTTAAGTAG-1',
#  'AGCTTGACAAGTCTAC-1',
#  'GATCGCGTCAGTGCAT-1',
#  'CTCTGGTCATGCAATC-1',
#  'GACTGCGGTACTCAAC-1',
#  'CTTACCGCAGCTGCAC-1',
#  'TCTATTGAGCGATCCC-1',
#  'ACATGGTAGGCTAGCA-1',
#  'TAGCCGGCATCCCATC-1',
#  'GTACTCCAGCAATATG-1',
#  'CAGCTAACATCTCCCA-1-1',
#  'CTTACCGGTACACCGC-1',
#  'GCGACCACAATAGAGT-1',
#  'TCCCGATTCAGTTCGA-1',
#  'CCTTCCCCAGCGTAAG-1',
#  'AACTCAGAGGGTCGAT-1',
#  'CTACCCATCACAGTAC-1',
#  'CCACCTATCTAACCGA-1',
#  'TGACTAGCAGTAACGG-1',
#  'GGGATGAAGGCTCAGA-1-1',
#  'CATCGAAAGTGAATTG-1',
#  'TTAACTCGTACGACCC-1',
#  'GGTGAAGCAAACGCGA-1',
#  'GACAGAGCACCTATCC-1',
#  'TTGAACGCAATGGTCT-1',
#  'ATCATCTTCCTAGTGA-1',
#  'CTCTAATCACACAGAG-1',
#  'CGTCACTAGGCTCATT-1',
#  'CACATAGCATCGACGC-1',
#  'ATTGGTGCAAGAAAGG-1',
#  'CGCTATCAGCAGACTG-1-1',
#  'CATCCACGTCAGAAGC-1',
#  'GAGCAGACATCCTTGC-1',
#  'ATCACGAAGCCAACAG-1',
#  'ATTGGACCACGACTCG-1',
#  'ACGAGCCTCGCCTGAG-1',
#  'AACCGCGCATTACGAC-1',
#  'TCGAGGCTCGTTTGCC-1',
#  'GGTGCGTGTCATGCAT-1',
#  'CGATTGAAGGCTCATT-1',
#  'AAACGGGAGCCAGGAT-1',
#  'GCATGCGCATACGCCG-1-1',
#  'GTGCATAGTATAGTAG-1',
#  'GGAGCAACATGCCTAA-1-1',
#  'TTAGGACTCAAAGACA-1',
#  'GCATGTACACAACGCC-1',
#  'ATTACTCGTGACGGTA-1',
#  'CGTGTCTGTTTGGGCC-1',
#  'CTACATTCAGTTCATG-1',
#  'TTCTACATCCGTCATC-1',
#  'ACATCAGTCTCGAGTA-1',
#  'TTGTAGGAGGCTAGCA-1',
#  'CGTGAGCAGCGTAATA-1',
#  'TGACTTTTCAATCACG-1',
#  'ACGAGCCCACTCAGGC-1',
#  'AGAATAGTCTATCCTA-1',
#  'CCCATACCATCGGGTC-1',
#  'CAAGGCCAGGTCGGAT-1',
#  'GTAACGTTCAACCAAC-1',
#  'GCATACACAAGCCTAT-1',
#  'ATGTGTGGTGGCCCTA-1',
#  'CAGATCAGTCTAAACC-1',
#  'TTCTCCTTCTTGAGGT-1-1',
#  'GCTGCAGCACACCGAC-1-1',
#  'AGACGTTTCGCGGATC-1',
#  'CCATGTCTCCGCGCAA-1',
#  'CCGTACTAGTGCGATG-1',
#  'CAGCGACGTGGACGAT-1',
#  'GGACGTCGTCGATTGT-1',
#  'AAGGCAGTCACCCTCA-1',
#  'CATCAGAAGCCTATGT-1-1',
#  'TGCTGCTTCTAACTGG-1',
#  'GGTGAAGTCCACGTGG-1',
#  'CCACGGAGTCCAACTA-1',
#  'TTCTCCTGTTTAGCTG-1',
#  'TAAGAGACAGTATAAG-1',
#  'TGCGTGGAGAGTGAGA-1',
#  'CAGCGACCAGCTCCGA-1',
#  'ATAACGCCAGCCTTTC-1',
#  'TGAGCATCAGTTTACG-1',
#  'GGACATTCAGGCTCAC-1',
#  'ACCCACTTCTTAGCCC-1',
#  'GGGACCTGTTTCCACC-1-1',
#  'GGAATAAGTACCAGTT-1',
#  'CTGAAGTCATGGTTGT-1',
#  'TCTCATAAGGCAAAGA-1',
#  'CTTACCGGTCAATGTC-1',
#  'GTGGGTCGTAAATGAC-1',
#  'TGTCCCAGTAGCGTCC-1',
#  'GGGCACTAGGGTGTTG-1',
#  'GGGAATGTCGCAAACT-1',
#  'ACACCGGTCAAACCGT-1',
#  'CAGCTAAGTTCAGACT-1-1',
#  'CTCATTAAGGACACCA-1',
#  'CGAGCACGTTCGGCAC-1',
#  'AGTGAGGAGGCACATG-1',
#  'ATTGGTGTCACTATTC-1-1',
#  'CCAGCGATCCCTTGTG-1',
#  'CGTCACTAGAATAGGG-1',
#  'ACAGCCGAGAGGGATA-1',
#  'GCCTCTATCGCAAGCC-1',
#  'TCGGGACTCCGAAGAG-1',
#  'GGTGCGTCAGACACTT-1',
#  'GACAGAGAGTGCCAGA-1',
#  'AACCATGGTAAGAGGA-1',
#  'GCATGATAGCGATGAC-1',
#  'CAAGTTGAGAGAGCTC-1',
#  'TACTCGCAGTACGTTC-1',
#  'TCGGGACCAGATCGGA-1',
#  'GACACGCAGCGTCTAT-1',
#  'CGAGCACGTTTAGGAA-1',
#  'GACAGAGGTCTCATCC-1',
#  'ACGATGTTCACTGGGC-1',
#  'TACTCGCAGTATCGAA-1',
#  'GTAGGCCGTTGCCTCT-1',
#  'CTGAAACCAGATCGGA-1',
#  'CGTCAGGTCTACTCAT-1',
#  'CCACGGACATTGTGCA-1',
#  'AGATCTGAGACATAAC-1',
#  'CATCGAACATATGAGA-1',
#  'TTCCCAGTCAGGCAAG-1',
#  'CCTTTCTTCGCCGTGA-1-1',
#  'TCAACGATCAGCCTAA-1',
#  'GTACGTAGTCTCTCTG-1',
#  'ATGAGGGTCATCGGAT-1',
#  'AGATCTGTCCTAGGGC-1',
#  'GATTCAGAGAATTCCC-1',
#  'TTATGCTTCAGAGGTG-1-1',
#  'GCAGCCAGTGGTGTAG-1-1',
#  'TTGTAGGGTTACGCGC-1',
#  'AACTTTCCACTGTCGG-1',
#  'TGAGAGGTCTGGCGTG-1',
#  'GGTGTTATCAGGTAAA-1',
#  'AGGCCACAGAGGTACC-1',
#  'GTAGGCCTCTTCAACT-1',
#  'ATCCGAACAATAGAGT-1',
#  'GACGTGCTCTCGGACG-1',
#  'CATCGAATCGGTGTTA-1',
#  'GCAGCCAAGAATGTTG-1',
#  'TCTGAGAAGTTGAGAT-1',
#  'GCCAAATAGCTAGTTC-1',
#  'GGACGTCAGCCATCGC-1',
#  'ATGAGGGTCAACTCTT-1',
#  'AACCATGCAATCTACG-1',
#  'TACTTGTGTACATCCA-1',
#  'TACAGTGGTCTGCCAG-1',
#  'AGATTGCGTTGCGCAC-1',
#  'GAACATCAGAGGTTGC-1',
#  'CAGTCCTCATTGGGCC-1-2',
#  'GGACAGAAGAGTGACC-1',
#  'TTTGGTTTCTCATTCA-1',
#  'AACTCCCGTCAAAGAT-1',
#  'TTAGGACCACGAAGCA-1',
#  'TCTTTCCGTGCCTGCA-1',
#  'AGCATACCACATAACC-1',
#  'GATGAGGAGTACGACG-1',
#  'GCCAAATAGTGAATTG-1',
#  'TCCCGATTCTCGAGTA-1',
#  'CTCTACGCAACTGCTA-1',
#  'CGGACTGGTCGAATCT-1',
#  'GGCGACTTCACATAGC-1',
#  'CATCCACCACGTCAGC-1',
#  'TGTGTTTAGAAAGTGG-1',
#  'TTTCCTCGTGCGGTAA-1-2',
#  'CCGGTAGAGACCCACC-1',
#  'ACAGCCGGTCACCTAA-1',
#  'CTTACCGAGAATAGGG-1',
#  'GCCTCTACAGGAATGC-1-1',
#  'TACTTACAGTGTCCAT-1',
#  'TCTCTAAGTCGACTAT-1',
#  'CAGCATAAGAATGTTG-1',
#  'AGGGATGCATTAACCG-1',
#  'CTGTTTAGTCGCGAAA-1',
#  'TTCGGTCTCTCGTATT-1',
#  'ACGCCGAAGCCATCGC-1',
#  'CTAACTTAGTGCTGCC-1',
#  'TGATTTCGTGGCTCCA-1',
#  'AACTGGTAGACTGGGT-1',
#  'CTCGAAAGTCTGATTG-1',
#  'ACTGAGTTCTCCAGGG-1',
#  'CGACTTCGTCACCTAA-1',
#  'TTGCCGTTCGGAGGTA-1',
#  'CACATTTAGATCGGGT-1',
#  'GACTACACAAGCGAGT-1',
#  'TAGGCATTCACTCTTA-1-1',
#  'ACTGCTCTCTGTACGA-1',
#  'AAAGATGAGTTACGGG-1',
#  'TGGGAAGGTCGCGGTT-1',
#  'TCAGCAACATGAGCGA-1',
#  'GATCGATTCTTCTGGC-1',
#  'CAGCATATCAGTCAGT-1',
#  'TGCCCATGTGCAACTT-1',
#  'CGCTATCAGTTCGCGC-1',
#  'GACGTGCCACATCTTT-1',
#  'GACAGAGTCGAGAGCA-1',
#  'AACCGCGTCATGGTCA-1-1',
#  'ATTTCTGAGTCCTCCT-1',
#  'ACTGAGTTCCAAACTG-1-1',
#  'TCTGAGAGTCCTCTTG-1',
#  'GTGAAGGGTAGGACAC-1-1',
#  'GCGCCAAGTAGATTAG-1',
#  'CATGCCTGTACAGTGG-1',
#  'GAGGTGAGTCAATACC-1-2',
#  'GTAACTGTCGCATGGC-1',
#  'GACTGCGTCCGCGTTT-1',
#  'GTGAAGGAGAACTGTA-1',
#  'CATCAGAAGTGAAGAG-1',
#  'TGGCTGGAGGTTCCTA-1-1',
#  'TATCAGGTCTAAGCCA-1',
#  'CAACTAGTCACCAGGC-1-1',
#  'CAACCTCTCGGAGCAA-1',
#  'GATGAAAAGTTTCCTT-1',
#  'CTAACTTAGAGCCCAA-1',
#  'GTACTCCTCATCGGAT-1',
#  'GTGCAGCTCAGCGATT-1',
#  'TGTTCCGCAAGAGTCG-1',
#  'CACAGTAGTCAAGCGA-1',
#  'GTGAAGGCACAGGTTT-1-1',
#  'TCTATTGCATCGGTTA-1',
#  'ACGTCAACATGAACCT-1',
#  'CGTCTACCAAGCGCTC-1',
#  'CCCAATCGTAAGGGCT-1',
#  'TCTCATAAGTCATCCA-1',
#  'GCAGCCAAGCTAGTGG-1',
#  'CAGCCGAAGAAACCTA-1',
#  'GCAATCATCCAGTATG-1',
#  'CACTCCAGTAAACGCG-1-1',
#  'CCCATACTCTAACTTC-1',
#  'CACACTCGTGTATGGG-1',
#  'TTGCCGTAGGATGGAA-1',
#  'TTAACTCGTGCCTGGT-1',
#  'GTTAAGCGTAGGAGTC-1',
#  'CGGACTGTCGCGGATC-1-1',
#  'CGAATGTTCACCGTAA-1',
#  'GGTGTTATCATAGCAC-1',
#  'CAGCTAACAAGCGTAG-1',
#  'CTGGTCTCACGAAACG-1',
#  'AGAGCTTCAGTCTTCC-1',
#  'TCTTCGGGTCTTGATG-1',
#  'TGGCCAGTCTAGCACA-1',
#  'TACCTATCAGACGTAG-1',
#  'ACTTTCAGTGCGATAG-1',
#  'GCGAGAAGTTGCGCAC-1',
#  'CACACAAGTTGGTAAA-1',
#  'GCATGTACAGGATCGA-1',
#  'CGAGCACTCCGCAAGC-1',
#  'CGAACATGTAGGAGTC-1',
#  'CCTACCATCATGCATG-1-1',
#  'CCACTACTCTACTATC-1',
#  'TTTCCTCTCAGTCAGT-1',
#  'GTACTCCCAATCTACG-1-1',
#  'TTGCCGTCATGGGAAC-1',
#  'TATGCCCGTAAGGATT-1',
#  'AAGACCTTCCACGTGG-1',
#  'CGGACGTGTCAAAGAT-1',
#  'GGCTCGAAGAGCCTAG-1-1',
#  'ACATGGTAGTCAAGGC-1',
#  'AGAATAGTCAGGCAAG-1',
#  'CTAAGACTCAGTTGAC-1-1',
#  'AGCCTAAGTACCGCTG-1',
#  'TCAGCAATCCACGTGG-1',
#  'TCAGATGTCGCTGATA-1',
#  'GGGTCTGGTTACGGAG-1',
#  'GGACAAGTCGATGAGG-1',
#  'CATCAGAGTGTGCCTG-1',
#  'TCTTCGGTCACCTTAT-1',
#  'CTCTACGTCAATAAGG-1',
#  'TCGTAGAGTGACCAAG-1',
#  'CGAATGTAGCGCCTCA-1',
#  'GGGTCTGCATGAGCGA-1',
#  'CTCATTAGTAGCGCTC-1',
#  'GCGCGATCAGTCACTA-1',
#  'CGTGTAAAGCACCGTC-1',
#  'GAACCTACAAACCTAC-1',
#  'CTAGAGTAGATCCTGT-1',
#  'CTAATGGCAAGCCATT-1',
#  'AACCGCGGTCCCTTGT-1',
#  'GGGACCTCACAGATTC-1',
#  'TAGCCGGCAGTCAGAG-1-1',
#  'CTTTGCGGTCTTGTCC-1',
#  'CGTTGGGAGCTAAACA-1',
#  'CGTGTAAGTGGCGAAT-1',
#  'CAGCTAAAGAAGGCCT-1',
#  'GTCACGGGTCTAAACC-1',
#  'TTAACTCGTGCACTTA-1',
#  'TATCAGGCATGCGCAC-1-1',
#  'AATCGGTTCTGCTTGC-1',
#  'CACACTCAGCTAAACA-1',
#  'CATATGGCAGGGTTAG-1',
#  'CATTATCTCATTGCGA-1',
#  'ACGAGCCAGCTGTTCA-1-1',
#  'CAGATCATCAAGAAGT-1',
#  'AGATCTGCATATGCTG-1',
#  'AGCGTATTCTAACCGA-1',
#  'GTAACGTAGTCCCACG-1-1',
#  'GATGCTAAGAGACTAT-1',
#  'GGGCACTAGGTGGGTT-1',
#  'GCACATAGTCCGTCAG-1',
#  'TCTCTAACAAGAAAGG-1-1',
#  'CCTTCGAAGATGAGAG-1',
#  'CGTGTAATCTCTAGGA-1',
#  'ATGCGATTCAATACCG-1',
#  'TTAGGACTCACGACTA-1-1',
#  'AGCTCCTAGACAAGCC-1',
#  'GTACGTACACTGCCAG-1',
#  'CCTCTGAAGGACCACA-1',
#  'TTGGCAAGTCGGATCC-1',
#  'CTGCCTATCCTCCTAG-1',
#  'GTCAAGTAGGAGTACC-1',
#  'CTCGTACCAGATGGCA-1',
#  'TCGAGGCAGAGTCTGG-1',
#  'TGCGCAGCATGCATGT-1',
#  'AGTTGGTTCTGTCAAG-1',
#  'ATGAGGGGTGCTCTTC-1',
#  'GACGTTAAGCTACCGC-1',
#  'CTGCGGACATAAAGGT-1',
#  'GCTGGGTCAGTTCATG-1-1',
#  'ACTGATGTCTCAAGTG-1',
#  'ATTATCCTCACCTTAT-1',
#  'CCTTCGAAGGAGCGTT-1',
#  'CGTTAGATCCTGTACC-1',
#  'GCTTCCATCTAACGGT-1',
#  'GGACAAGAGTACGTAA-1',
#  'GGTGTTAGTACATGTC-1',
#  'GTCAAGTCAGTGAGTG-1',
#  'GAGTCCGCACCAGATT-1',
#  'TGGTTAGTCCTATTCA-1',
#  'TGCACCTGTGAGCGAT-1-1',
#  'CAGATCATCAGAAATG-1',
#  'ACCGTAAGTACCTACA-1-1',
#  'CTGGTCTCAGCTGCAC-1',
#  'CTCACACAGGATGCGT-1',
#  'AAATGCCTCTGTCAAG-1',
#  'AGCTTGATCAACCAAC-1-1',
#  'CTGCCTATCTTGAGGT-1',
#  'TTCGAAGGTACAGTGG-1',
#  'TGTATTCGTGTCTGAT-1',
#  'CGTTGGGAGAGACGAA-1',
#  'TCAGATGTCGGGAGTA-1',
#  'CCTCAGTTCCTTAATC-1',
#  'TCATTACAGATGCCAG-1',
#  'TCTCTAACAATGGTCT-1',
#  'GGGCACTGTACTCAAC-1',
#  'CAGGTGCTCTGCTGCT-1',
#  'AATCGGTCATTACCTT-1',
#  'TAGAGCTAGATGGCGT-1',
#  'TCAGGTAGTCTCTCTG-1-1',
#  'TGCCCATCAAATCCGT-1',
#  'TCCCGATTCCTCCTAG-1',
#  'CGTAGCGGTGTATGGG-1',
#  'CATGGCGCACGGCTAC-1',
#  'AAGTCTGAGGATGGAA-1',
#  'TATTACCAGTTACCCA-1-1',
#  'AAGGTTCCAGATCGGA-1',
#  'TTGTAGGTCCCGACTT-1',
#  'AACTTTCAGCCGCCTA-1',
#  'GATGCTAAGAGTACCG-1',
#  'GAGTCCGAGCTCCCAG-1',
#  'CCTTTCTGTCTCCACT-1',
#  'GTACGTACATTATCTC-1',
#  'TTCTCCTAGTATGACA-1',
#  'TCAGGTATCATCTGCC-1',
#  'CCTACCAGTGACGCCT-1',
#  'ATCTACTAGTGTCCCG-1',
#  'ATGTGTGAGATCTGAA-1',
#  'GTGTGCGAGGATGGAA-1',
#  'TACGGTAAGATAGTCA-1',
#  'TCTTCGGAGTCCGTAT-1',
#  'GCTTCCACAATGAATG-1-1',
#  'ACACCCTTCTGCTGCT-1',
#  'GCGAGAATCGTGGGAA-1',
#  'CTCAGAATCGCCATAA-1-1',
#  'GCACATATCTACTTAC-1-1',
#  'GAACCTAAGGCAATTA-1',
#  'CCTACACCAGTCAGAG-1',
#  'AGCGTATTCACTCTTA-1-1',
#  'TCGAGGCGTAACGTTC-1',
#  'TCAGCAATCCACTGGG-1-1',
#  'TGGTTAGTCACGCGGT-1',
#  'ACATCAGAGAATAGGG-1',
#  'CCTTTCTAGCGACGTA-1',
#  'GTTCATTAGTTAGGTA-1-1',
#  'AGCGTATTCATCACCC-1',
#  'TACTCATGTGCATCTA-1',
#  'CAAGAAACAGGAACGT-1',
#  'TCGCGAGTCTCCGGTT-1',
#  'CTCGGGAAGATCGATA-1',
#  'CAGAATCAGGCAAAGA-1',
#  'GCACTCTTCCAACCAA-1',
#  'CAACTAGAGAAGGCCT-1',
#  'CAGCGACTCCAGATCA-1',
#  'CACAGTACATAACCTG-1',
#  'ACTATCTTCGAATGGG-1',
#  'GATTCAGGTCGAGATG-1',
#  'AAGCCGCAGATCCTGT-1',
#  'ACGCCGATCCTTAATC-1',
#  'TCATTACCAGTAACGG-1',
#  'TGTTCCGTCAGAGGTG-1',
#  'AGAGCGACACATTTCT-1',
#  'CTCACACCACAGATTC-1',
#  'CCGGTAGTCTTCGAGA-1',
#  'TCCCGATAGGCGACAT-1',
#  'GAGGTGAAGGCGTACA-1',
#  'TTTGGTTCAAGGGTCA-1',
#  'CAGCATAGTACCGGCT-1',
#  'GTACGTATCTGTTGAG-1',
#  'GCGCCAATCCGAGCCA-1-1',
#  'CGTGTAAAGCCGCCTA-1',
#  'CCAGCGACAATGTTGC-1',
#  'CCGGGATCACATTCGA-1',
#  'GATCGTAGTGACCAAG-1',
#  'ACTGCTCGTGTTCTTT-1',
#  'CATCGAACACAGGCCT-1',
#  'CCCAGTTTCTGCCAGG-1',
#  'CGAATGTAGTTCGATC-1',
#  'TTTGTCAGTCGCCATG-1',
#  'AGATCTGAGAATCTCC-1',
#  'TACCTTAAGCCTATGT-1',
#  'GTTACAGCATTCTCAT-1',
#  'CGCTATCCACGTAAGG-1',
#  'TAGCCGGTCCTCATTA-1',
#  'CAAGATCTCGCGTAGC-1',
#  'GATCGCGTCTCCAGGG-1',
#  'AAGGTTCGTGCTCTTC-1',
#  'AGGTCCGGTCTTGATG-1',
#  ...}

# %%
cell_annotation_dict = dict(zip(adata_archmap.obs.index, adata_archmap.obs['prediction_xgb']))

# %%
adata.obs[AUTHOR_CELL_TYPE] = adata.obs.index.map(cell_annotation_dict)

adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False)
# Out:
# NaN                             584634
# EC venous pulmonary              26642
# 3_AT2                            16614
# Adventitial fibroblasts          14555
# EC aerocyte capillary             4545
# 3_AT1                             2418
# 3_Lymphatic EC mature             2246
# B cells                           1307
# 3_Lymphatic EC proliferating      1240
# 3_Smooth muscle FAM83D+           1013
# AT2 proliferating                  731
# CD4 T cells                        518
# EC general capillary               489
# 3_Myofibroblasts                   174
# Classical monocytes                 35
# CD8 T cells                         28
# 2_Smooth muscle                     21
# 2_Hematopoietic stem cells           3
# Club                                 3
# DC1                                  2
# 2_Mesothelium                        2
# Name: author_cell_type, dtype: int64

# %%
adata.obs_names_make_unique()

# %% [markdown]
# # Validate obs and uns from Tier 1 Metadata Template

# %%
val_workflow = ValidationWorkflow(
    input = uns,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                                title  \
# 0  Control and COPD lung, 2024-04-30
#
#                                     study_PI            batch_condition  \
# 0  Jonathan A. Kropski, Nicholas E. Banovich  library_preparation_batch
#
#   default_embedding              unpublished comments
# 0                    protected under embargo

# %%
val_workflow = ValidationWorkflow(
    input = obs,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation error(s) encountered.
# {
# │   'sex_ontology_term_id': "Must be one of {'PATO:0000383', 'PATO:0000384'} for male or female. Invalid entries found.",
# │   'sample_preservation_method': "Must be a valid method such as 'fresh', 'frozen at -80C', etc. Invalid entries found."
# }
# Error containing field: sex_ontology_term_id
# Error message: Must be one of {'PATO:0000383', 'PATO:0000384'} for male or female. Invalid entries found.
# Value counts:
# PATO:0000383    18
# PATO:0000384    11
# unknown          3
# Name: sex_ontology_term_id, dtype: int64
# Error containing field: sample_preservation_method
# Error message: Must be a valid method such as 'fresh', 'frozen at -80C', etc. Invalid entries found.
# Value counts:
# frozen in liquid nitrogen    17
# fresh                        13
# N/A                           2
# Name: sample_preservation_method, dtype: int64
# Returning error-containing OBS dataframe.
#    sample_ID donor_id                                       protocol_URL  \
# 0    THD0002  THD0002  https://www.science.org/doi/full/10.1126/sciad...
# 1    THD0024  THD0024  https://www.science.org/doi/full/10.1126/sciad...
# 2    THD0025  THD0025  https://www.science.org/doi/full/10.1126/sciad...
# 3    THD0027  THD0027  https://www.science.org/doi/full/10.1126/sciad...
# 4    THD0028  THD0028  https://www.science.org/doi/full/10.1126/sciad...
# 5    THD0029  THD0029  https://www.science.org/doi/full/10.1126/sciad...
# 6    THD0030  THD0030  https://www.science.org/doi/full/10.1126/sciad...
# 7    THD0031  THD0031  https://www.science.org/doi/full/10.1126/sciad...
# 8    THD0032  THD0032  https://www.science.org/doi/full/10.1126/sciad...
# 9    THD0034  THD0034  https://www.science.org/doi/full/10.1126/sciad...
# 10   THD0035  THD0035  https://www.science.org/doi/full/10.1126/sciad...
# 11   THD0036  THD0036  https://www.science.org/doi/full/10.1126/sciad...
# 12   THD0037  THD0037  https://www.science.org/doi/full/10.1126/sciad...
# 13   THD0038  THD0038  https://www.science.org/doi/full/10.1126/sciad...
# 14   THD0039  THD0039  https://www.science.org/doi/full/10.1126/sciad...
# 15   THD0040  THD0040  https://www.science.org/doi/full/10.1126/sciad...
# 16   THD0041  THD0041  https://www.science.org/doi/full/10.1126/sciad...
# 17   THD0042  THD0042  https://www.science.org/doi/full/10.1126/sciad...
# 18   THD0043  THD0043  https://www.science.org/doi/full/10.1126/sciad...
# 19   THD0044  THD0044  https://www.science.org/doi/full/10.1126/sciad...
# 20    VUHD65   VUHD65  https://www.science.org/doi/full/10.1126/sciad...
# 21   VUHD072  VUHD072  https://www.science.org/doi/full/10.1126/sciad...
# 22   VUHD073  VUHD073  https://www.science.org/doi/full/10.1126/sciad...
# 23   VUHD075  VUHD075  https://www.science.org/doi/full/10.1126/sciad...
# 24   VUHD116  VUHD116  https://www.science.org/doi/full/10.1126/sciad...
# 25   VUHD122  VUHD122  https://www.science.org/doi/full/10.1126/sciad...
# 26    COPD49   COPD49                           10.1165/rcmb.2021-0548OC
# 27     RICH1    RICH1                           10.1165/rcmb.2021-0548OC
# 28     RICH3    RICH3                           10.1165/rcmb.2021-0548OC
# 29     RICH7    RICH7                           10.1165/rcmb.2021-0548OC
# 30     RICH9    RICH9                           10.1165/rcmb.2021-0548OC
# 31    RICH10   RICH10                           10.1165/rcmb.2021-0548OC
#
#                                   institute sample_collection_site  \
# 0   Translation Genomics Research Institute              TGen/VUMC
# 1   Translation Genomics Research Institute              TGen/VUMC
# 2   Translation Genomics Research Institute              TGen/VUMC
# 3   Translation Genomics Research Institute              TGen/VUMC
# 4   Translation Genomics Research Institute              TGen/VUMC
# 5   Translation Genomics Research Institute              TGen/VUMC
# 6   Translation Genomics Research Institute              TGen/VUMC
# 7   Translation Genomics Research Institute              TGen/VUMC
# 8   Translation Genomics Research Institute              TGen/VUMC
# 9   Translation Genomics Research Institute              TGen/VUMC
# 10  Translation Genomics Research Institute              TGen/VUMC
# 11  Translation Genomics Research Institute              TGen/VUMC
# 12  Translation Genomics Research Institute              TGen/VUMC
# 13  Translation Genomics Research Institute              TGen/VUMC
# 14  Translation Genomics Research Institute              TGen/VUMC
# 15  Translation Genomics Research Institute              TGen/VUMC
# 16  Translation Genomics Research Institute              TGen/VUMC
# 17  Translation Genomics Research Institute              TGen/VUMC
# 18  Translation Genomics Research Institute              TGen/VUMC
# 19  Translation Genomics Research Institute              TGen/VUMC
# 20  Translation Genomics Research Institute              TGen/VUMC
# 21  Translation Genomics Research Institute              TGen/VUMC
# 22  Translation Genomics Research Institute              TGen/VUMC
# 23  Translation Genomics Research Institute              TGen/VUMC
# 24  Translation Genomics Research Institute              TGen/VUMC
# 25  Translation Genomics Research Institute              TGen/VUMC
# 26     Vanderbilt University Medical Center                   VUMC
# 27     Vanderbilt University Medical Center                   VUMC
# 28     Vanderbilt University Medical Center                   VUMC
# 29     Vanderbilt University Medical Center                   VUMC
# 30     Vanderbilt University Medical Center                   VUMC
# 31     Vanderbilt University Medical Center                   VUMC
#
#    sample_collection_relative_time_point     library_ID library_ID_repository  \
# 0                                    N/A         F01174            GSM4037324
# 1                                    N/A         F03576                   N/A
# 2                                    N/A         F03574                   N/A
# 3                                    N/A         F04005                F04005
# 4                                    N/A         F03861                   N/A
# 5                                    N/A         F04006                   N/A
# 6                                    N/A         F04007                   N/A
# 7                                    N/A         F04038                   N/A
# 8                                    N/A         F04127                   N/A
# 9                                    N/A         F04244                   N/A
# 10                                   N/A         F04348                   N/A
# 11                                   N/A         F04349                   N/A
# 12                                   N/A         F04484                   N/A
# 13                                   N/A         F04485                   N/A
# 14                                   N/A         F04490                   N/A
# 15                                   N/A         F04491                   N/A
# 16                                   N/A         F04632                   N/A
# 17                                   N/A         F04637                   N/A
# 18                                   N/A         F05206                   N/A
# 19                                   N/A         F05214                   N/A
# 20                                   N/A           HD65            GSM4037301
# 21                                   N/A         F01483                   N/A
# 22                                   N/A  F01495-F01494                   N/A
# 23                                   N/A         F01508                   N/A
# 24                                   N/A         F04013                   N/A
# 25                                   N/A         F04279                   N/A
# 26                                   N/A     7684_COPD1                   N/A
# 27                                   N/A     7684_COPD2                   N/A
# 28                                   N/A     7684_COPD3                   N/A
# 29                                   N/A     8282_COPD1                   N/A
# 30                                   N/A     8282_COPD2                   N/A
# 31                                   N/A     8282_COPD3                   N/A
#
#    author_batch_notes organism_ontology_term_id  ... sequenced_fragment  \
# 0                 N/A            NCBITaxon:9606  ...   5 prime end bias
# 1                 N/A            NCBITaxon:9606  ...   5 prime end bias
# 2                 N/A            NCBITaxon:9606  ...   5 prime end bias
# 3                 N/A            NCBITaxon:9606  ...   5 prime end bias
# 4                 N/A            NCBITaxon:9606  ...   5 prime end bias
# 5                 N/A            NCBITaxon:9606  ...   5 prime end bias
# 6                 N/A            NCBITaxon:9606  ...   5 prime end bias
# 7                 N/A            NCBITaxon:9606  ...   5 prime end bias
# 8                 N/A            NCBITaxon:9606  ...   5 prime end bias
# 9                 N/A            NCBITaxon:9606  ...   5 prime end bias
# 10                N/A            NCBITaxon:9606  ...   5 prime end bias
# 11                N/A            NCBITaxon:9606  ...   5 prime end bias
# 12                N/A            NCBITaxon:9606  ...   5 prime end bias
# 13                N/A            NCBITaxon:9606  ...   5 prime end bias
# 14                N/A            NCBITaxon:9606  ...   5 prime end bias
# 15                N/A            NCBITaxon:9606  ...   5 prime end bias
# 16                N/A            NCBITaxon:9606  ...   5 prime end bias
# 17                N/A            NCBITaxon:9606  ...   5 prime end bias
# 18                N/A            NCBITaxon:9606  ...   5 prime end bias
# 19                N/A            NCBITaxon:9606  ...   5 prime end bias
# 20                N/A            NCBITaxon:9606  ...   5 prime end bias
# 21                N/A            NCBITaxon:9606  ...   5 prime end bias
# 22                N/A            NCBITaxon:9606  ...   5 prime end bias
# 23                N/A            NCBITaxon:9606  ...   5 prime end bias
# 24                N/A            NCBITaxon:9606  ...   5 prime end bias
# 25                N/A            NCBITaxon:9606  ...   5 prime end bias
# 26                N/A            NCBITaxon:9606  ...   5 prime end bias
# 27                N/A            NCBITaxon:9606  ...   5 prime end bias
# 28                N/A            NCBITaxon:9606  ...   5 prime end bias
# 29                N/A            NCBITaxon:9606  ...   5 prime end bias
# 30                N/A            NCBITaxon:9606  ...   5 prime end bias
# 31                N/A            NCBITaxon:9606  ...   5 prime end bias
#
#    sequencing_platform is_primary_data reference_genome  \
# 0          EFO_0008637            true           GRCh38
# 1          EFO_0008637            true           GRCh38
# 2          EFO_0008637            true           GRCh38
# 3          EFO_0008637            true           GRCh38
# 4          EFO_0008637            true           GRCh38
# 5          EFO_0008637            true           GRCh38
# 6          EFO_0008637            true           GRCh38
# 7          EFO_0008637            true           GRCh38
# 8          EFO_0008637            true           GRCh38
# 9          EFO_0008637            true           GRCh38
# 10         EFO_0008637            true           GRCh38
# 11         EFO_0008637            true           GRCh38
# 12         EFO_0008637            true           GRCh38
# 13         EFO_0008637            true           GRCh38
# 14         EFO_0008637            true           GRCh38
# 15         EFO_0008637            true           GRCh38
# 16         EFO_0008637            true           GRCh38
# 17         EFO_0008637            true           GRCh38
# 18         EFO_0008637            true           GRCh38
# 19         EFO_0008637            true           GRCh38
# 20         EFO_0008637            true           GRCh38
# 21         EFO_0008637            true           GRCh38
# 22         EFO_0008637            true           GRCh38
# 23         EFO_0008637            true           GRCh38
# 24         EFO_0008637            true           GRCh38
# 25         EFO_0008637            true           GRCh38
# 26         EFO_0008637            true           GRCh38
# 27         EFO_0008637            true           GRCh38
# 28         EFO_0008637            true           GRCh38
# 29         EFO_0008637            true           GRCh38
# 30         EFO_0008637            true           GRCh38
# 31         EFO_0008637            true           GRCh38
#
#    gene_annotation_version alignment_software intron_inclusion  \
# 0                      v98  cell ranger 7.2.0              yes
# 1                      v98  cell ranger 7.2.0              yes
# 2                      v98  cell ranger 7.2.0              yes
# 3                      v98  cell ranger 7.2.0              yes
# 4                      v98  cell ranger 7.2.0              yes
# 5                      v98  cell ranger 7.2.0              yes
# 6                      v98  cell ranger 7.2.0              yes
# 7                      v98  cell ranger 7.2.0              yes
# 8                      v98  cell ranger 7.2.0              yes
# 9                      v98  cell ranger 7.2.0              yes
# 10                     v98  cell ranger 7.2.0              yes
# 11                     v98  cell ranger 7.2.0              yes
# 12                     v98  cell ranger 7.2.0              yes
# 13                     v98  cell ranger 7.2.0              yes
# 14                     v98  cell ranger 7.2.0              yes
# 15                     v98  cell ranger 7.2.0              yes
# 16                     v98  cell ranger 7.2.0              yes
# 17                     v98  cell ranger 7.2.0              yes
# 18                     v98  cell ranger 7.2.0              yes
# 19                     v98  cell ranger 7.2.0              yes
# 20                     v98  cell ranger 7.2.0              yes
# 21                     v98  cell ranger 7.2.0              yes
# 22                     v98  cell ranger 7.2.0              yes
# 23                     v98  cell ranger 7.2.0              yes
# 24                     v98  cell ranger 7.2.0              yes
# 25                     v98  cell ranger 7.2.0              yes
# 26                     v98  cell ranger 6.1.2               no
# 27                     v98  cell ranger 6.1.2               no
# 28                     v98  cell ranger 6.1.2               no
# 29                     v98  cell ranger 6.1.2               no
# 30                     v98  cell ranger 6.1.2               no
# 31                     v98  cell ranger 6.1.2               no
#
#    disease_ontology_term_id self_reported_ethnicity_ontology_term_id  \
# 0              PATO:0000461                                  unknown
# 1              PATO:0000461                                  unknown
# 2              PATO:0000461                                  unknown
# 3              PATO:0000461                                  unknown
# 4              PATO:0000461                                  unknown
# 5              PATO:0000461                                  unknown
# 6              PATO:0000461                                  unknown
# 7              PATO:0000461                                  unknown
# 8              PATO:0000461                                  unknown
# 9              PATO:0000461                                  unknown
# 10             PATO:0000461                                  unknown
# 11             PATO:0000461                                  unknown
# 12             PATO:0000461                                  unknown
# 13             PATO:0000461                                  unknown
# 14             PATO:0000461                                  unknown
# 15             PATO:0000461                                  unknown
# 16             PATO:0000461                                  unknown
# 17             PATO:0000461                                  unknown
# 18             PATO:0000461                                  unknown
# 19             PATO:0000461                                  unknown
# 20             PATO:0000461                                  unknown
# 21             PATO:0000461                                  unknown
# 22             PATO:0000461                                  unknown
# 23             PATO:0000461                                  unknown
# 24             PATO:0000461                                  unknown
# 25             PATO:0000461                                  unknown
# 26            MONDO:0005002                                  unknown
# 27            MONDO:0005002                                  unknown
# 28            MONDO:0005002                                  unknown
# 29            MONDO:0005002                                  unknown
# 30            MONDO:0005002                                  unknown
# 31            MONDO:0005002                                  unknown
#
#    development_stage_ontology_term_id
# 0                      HsapDv:0000238
# 1                      HsapDv:0000239
# 2                      HsapDv:0000240
# 3                      HsapDv:0000239
# 4                      HsapDv:0000239
# 5                      HsapDv:0000240
# 6                      HsapDv:0000240
# 7                      HsapDv:0000239
# 8                      HsapDv:0000241
# 9                      HsapDv:0000240
# 10                     HsapDv:0000237
# 11                     HsapDv:0000239
# 12                     HsapDv:0000237
# 13                     HsapDv:0000241
# 14                     HsapDv:0000239
# 15                     HsapDv:0000241
# 16                     HsapDv:0000240
# 17                     HsapDv:0000240
# 18                     HsapDv:0000241
# 19                     HsapDv:0000241
# 20                     HsapDv:0000268
# 21                     HsapDv:0000242
# 22                     HsapDv:0000240
# 23                     HsapDv:0000238
# 24                     HsapDv:0000237
# 25                     HsapDv:0000237
# 26                     HsapDv:0000241
# 27                     HsapDv:0000241
# 28                     HsapDv:0000240
# 29                     HsapDv:0000240
# 30                     HsapDv:0000241
# 31                     HsapDv:0000240
#
# [32 rows x 37 columns]

# %% [markdown]
# # Validate obs and uns from adata

# %%
merger = AnnDataMerger(
    adata = adata,
    uns_df = uns
)

adata = merger.add_uns_metadata()

adata
# Out:
# AnnData object with n_obs × n_vars = 289105 × 38224
#     obs: 'background_fraction', 'cell_probability', 'cell_size', 'droplet_efficiency', 'dataset', 'barcode', 'author_cell_type'
#     var: 'ambient_expression', 'feature_type', 'genome', 'gene_id', 'cellbender_analyzed', 'reference'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments'
#     obsm: 'gene_expression_encoding'

# %%
adata.obs['dataset'].value_counts(dropna=False).index.tolist()
# Out:
# ['RICH1',
#  'COPD49',
#  'VUHD116',
#  'RICH3',
#  'THD0036',
#  'VUHD122',
#  'THD0044',
#  'THD0043',
#  'THD0041',
#  'RICH7',
#  'THD0032',
#  'THD0025',
#  'RICH9',
#  'THD0040',
#  'THD0039',
#  'THD0024',
#  'THD0034',
#  'THD0042',
#  'THD0002',
#  'RICH10',
#  'VUHD65',
#  'THD0031',
#  'THD0028',
#  'THD0029',
#  'THD0027',
#  'THD0030',
#  'THD0037',
#  'THD0035',
#  'VUHD075',
#  'VUHD072',
#  'THD0038',
#  'VUHD073']

# %%
obs['sample_ID'].tolist()
# Out:
# ['THD0002',
#  'THD0024',
#  'THD0025',
#  'THD0027',
#  'THD0028',
#  'THD0029',
#  'THD0030',
#  'THD0031',
#  'THD0032',
#  'THD0034',
#  'THD0035',
#  'THD0036',
#  'THD0037',
#  'THD0038',
#  'THD0039',
#  'THD0040',
#  'THD0041',
#  'THD0042',
#  'THD0043',
#  'THD0044',
#  'VUHD65',
#  'VUHD072',
#  'VUHD073',
#  'VUHD075',
#  'VUHD116',
#  'VUHD122',
#  'COPD49',
#  'RICH1',
#  'RICH3',
#  'RICH7',
#  'RICH9',
#  'RICH10']

# %%
non_intersect_sample_id = set(obs['sample_ID'].tolist()) - set(adata.obs['dataset'].value_counts(dropna=False).index.tolist())
non_intersect_sample_id_other_side = set(adata.obs['dataset'].value_counts(dropna=False).index.tolist()) - set(obs['sample_ID'].tolist())

# %%
non_intersect_sample_id
# Out:
# set()

# %%
non_intersect_sample_id_other_side
# Out:
# set()

# %%
# Merge obs and uns
merger = AnnDataMerger(
    adata = adata,
    obs_df = obs
)

adata = merger.add_obs_metadata(
    adata_col = 'dataset',
    df_col = 'sample_ID',
    skip = None,
)

adata.obs['sample_ID'] = adata.obs['dataset']

adata.obs
# Out:
#                         background_fraction  cell_probability    cell_size  \
# barcode
# ACTGAGTCAATAGAGT-1                 0.000161          0.999955  2951.735596
# CACATTTTCCGAATGT-1                 0.000000          0.999955  2962.802246
# ATTGGACCACAGAGGT-1                 0.000000          0.999955  2777.117188
# GGCCGATCATTTGCCC-1                 0.000000          0.999955  2599.234375
# TTCTACATCCAAAGTC-1                 0.000210          0.999955  2611.243408
# ...                                     ...               ...          ...
# TACGGGCAGGAATTAC-1-1               0.249995          0.639784   144.171844
# TAGCCGGTCAAGATCC-1                 0.319142          0.893551   144.771790
# TGTCCCAAGATCGATA-1-1               0.127657          0.752691   145.850082
# TGACAACCAGTGACAG-1                 0.199996          0.536261   139.792664
# TTCGGTCGTCAACTGT-1-2-1             0.214281          0.880581   138.657501
#
#                         droplet_efficiency  dataset                 barcode  \
# barcode
# ACTGAGTCAATAGAGT-1                2.070680  VUHD075      ACTGAGTCAATAGAGT-1
# CACATTTTCCGAATGT-1                1.950150  VUHD075      CACATTTTCCGAATGT-1
# ATTGGACCACAGAGGT-1                1.762267  VUHD075      ATTGGACCACAGAGGT-1
# GGCCGATCATTTGCCC-1                1.788824  VUHD075      GGCCGATCATTTGCCC-1
# TTCTACATCCAAAGTC-1                1.770930  VUHD075      TTCTACATCCAAAGTC-1
# ...                                    ...      ...                     ...
# TACGGGCAGGAATTAC-1-1              0.663551  THD0040    TACGGGCAGGAATTAC-1-1
# TAGCCGGTCAAGATCC-1                0.644018  THD0040      TAGCCGGTCAAGATCC-1
# TGTCCCAAGATCGATA-1-1              0.634361  THD0040    TGTCCCAAGATCGATA-1-1
# TGACAACCAGTGACAG-1                0.662750  THD0040      TGACAACCAGTGACAG-1
# TTCGGTCGTCAACTGT-1-2-1            0.628727  THD0040  TTCGGTCGTCAACTGT-1-2-1
#
#                                author_cell_type donor_id  \
# barcode
# ACTGAGTCAATAGAGT-1                        3_AT2  VUHD075
# CACATTTTCCGAATGT-1      3_Smooth muscle FAM83D+  VUHD075
# ATTGGACCACAGAGGT-1                      B cells  VUHD075
# GGCCGATCATTTGCCC-1                        3_AT2  VUHD075
# TTCTACATCCAAAGTC-1          EC venous pulmonary  VUHD075
# ...                                         ...      ...
# TACGGGCAGGAATTAC-1-1                      3_AT2  THD0040
# TAGCCGGTCAAGATCC-1                        3_AT2  THD0040
# TGTCCCAAGATCGATA-1-1                      3_AT2  THD0040
# TGACAACCAGTGACAG-1                        3_AT2  THD0040
# TTCGGTCGTCAACTGT-1-2-1                    3_AT2  THD0040
#
#                                                              protocol_URL  \
# barcode
# ACTGAGTCAATAGAGT-1      https://www.science.org/doi/full/10.1126/sciad...
# CACATTTTCCGAATGT-1      https://www.science.org/doi/full/10.1126/sciad...
# ATTGGACCACAGAGGT-1      https://www.science.org/doi/full/10.1126/sciad...
# GGCCGATCATTTGCCC-1      https://www.science.org/doi/full/10.1126/sciad...
# TTCTACATCCAAAGTC-1      https://www.science.org/doi/full/10.1126/sciad...
# ...                                                                   ...
# TACGGGCAGGAATTAC-1-1    https://www.science.org/doi/full/10.1126/sciad...
# TAGCCGGTCAAGATCC-1      https://www.science.org/doi/full/10.1126/sciad...
# TGTCCCAAGATCGATA-1-1    https://www.science.org/doi/full/10.1126/sciad...
# TGACAACCAGTGACAG-1      https://www.science.org/doi/full/10.1126/sciad...
# TTCGGTCGTCAACTGT-1-2-1  https://www.science.org/doi/full/10.1126/sciad...
#
#                                                       institute  ...  \
# barcode                                                          ...
# ACTGAGTCAATAGAGT-1      Translation Genomics Research Institute  ...
# CACATTTTCCGAATGT-1      Translation Genomics Research Institute  ...
# ATTGGACCACAGAGGT-1      Translation Genomics Research Institute  ...
# GGCCGATCATTTGCCC-1      Translation Genomics Research Institute  ...
# TTCTACATCCAAAGTC-1      Translation Genomics Research Institute  ...
# ...                                                         ...  ...
# TACGGGCAGGAATTAC-1-1    Translation Genomics Research Institute  ...
# TAGCCGGTCAAGATCC-1      Translation Genomics Research Institute  ...
# TGTCCCAAGATCGATA-1-1    Translation Genomics Research Institute  ...
# TGACAACCAGTGACAG-1      Translation Genomics Research Institute  ...
# TTCGGTCGTCAACTGT-1-2-1  Translation Genomics Research Institute  ...
#
#                        sequencing_platform is_primary_data reference_genome  \
# barcode
# ACTGAGTCAATAGAGT-1             EFO_0008637            true           GRCh38
# CACATTTTCCGAATGT-1             EFO_0008637            true           GRCh38
# ATTGGACCACAGAGGT-1             EFO_0008637            true           GRCh38
# GGCCGATCATTTGCCC-1             EFO_0008637            true           GRCh38
# TTCTACATCCAAAGTC-1             EFO_0008637            true           GRCh38
# ...                                    ...             ...              ...
# TACGGGCAGGAATTAC-1-1           EFO_0008637            true           GRCh38
# TAGCCGGTCAAGATCC-1             EFO_0008637            true           GRCh38
# TGTCCCAAGATCGATA-1-1           EFO_0008637            true           GRCh38
# TGACAACCAGTGACAG-1             EFO_0008637            true           GRCh38
# TTCGGTCGTCAACTGT-1-2-1         EFO_0008637            true           GRCh38
#
#                        gene_annotation_version alignment_software  \
# barcode
# ACTGAGTCAATAGAGT-1                         v98  cell ranger 7.2.0
# CACATTTTCCGAATGT-1                         v98  cell ranger 7.2.0
# ATTGGACCACAGAGGT-1                         v98  cell ranger 7.2.0
# GGCCGATCATTTGCCC-1                         v98  cell ranger 7.2.0
# TTCTACATCCAAAGTC-1                         v98  cell ranger 7.2.0
# ...                                        ...                ...
# TACGGGCAGGAATTAC-1-1                       v98  cell ranger 7.2.0
# TAGCCGGTCAAGATCC-1                         v98  cell ranger 7.2.0
# TGTCCCAAGATCGATA-1-1                       v98  cell ranger 7.2.0
# TGACAACCAGTGACAG-1                         v98  cell ranger 7.2.0
# TTCGGTCGTCAACTGT-1-2-1                     v98  cell ranger 7.2.0
#
#                        intron_inclusion disease_ontology_term_id  \
# barcode
# ACTGAGTCAATAGAGT-1                  yes             PATO:0000461
# CACATTTTCCGAATGT-1                  yes             PATO:0000461
# ATTGGACCACAGAGGT-1                  yes             PATO:0000461
# GGCCGATCATTTGCCC-1                  yes             PATO:0000461
# TTCTACATCCAAAGTC-1                  yes             PATO:0000461
# ...                                 ...                      ...
# TACGGGCAGGAATTAC-1-1                yes             PATO:0000461
# TAGCCGGTCAAGATCC-1                  yes             PATO:0000461
# TGTCCCAAGATCGATA-1-1                yes             PATO:0000461
# TGACAACCAGTGACAG-1                  yes             PATO:0000461
# TTCGGTCGTCAACTGT-1-2-1              yes             PATO:0000461
#
#                        self_reported_ethnicity_ontology_term_id  \
# barcode
# ACTGAGTCAATAGAGT-1                                      unknown
# CACATTTTCCGAATGT-1                                      unknown
# ATTGGACCACAGAGGT-1                                      unknown
# GGCCGATCATTTGCCC-1                                      unknown
# TTCTACATCCAAAGTC-1                                      unknown
# ...                                                         ...
# TACGGGCAGGAATTAC-1-1                                    unknown
# TAGCCGGTCAAGATCC-1                                      unknown
# TGTCCCAAGATCGATA-1-1                                    unknown
# TGACAACCAGTGACAG-1                                      unknown
# TTCGGTCGTCAACTGT-1-2-1                                  unknown
#
#                        development_stage_ontology_term_id sample_ID
# barcode
# ACTGAGTCAATAGAGT-1                         HsapDv:0000238   VUHD075
# CACATTTTCCGAATGT-1                         HsapDv:0000238   VUHD075
# ATTGGACCACAGAGGT-1                         HsapDv:0000238   VUHD075
# GGCCGATCATTTGCCC-1                         HsapDv:0000238   VUHD075
# TTCTACATCCAAAGTC-1                         HsapDv:0000238   VUHD075
# ...                                                   ...       ...
# TACGGGCAGGAATTAC-1-1                       HsapDv:0000241   THD0040
# TAGCCGGTCAAGATCC-1                         HsapDv:0000241   THD0040
# TGTCCCAAGATCGATA-1-1                       HsapDv:0000241   THD0040
# TGACAACCAGTGACAG-1                         HsapDv:0000241   THD0040
# TTCGGTCGTCAACTGT-1-2-1                     HsapDv:0000241   THD0040
#
# [289105 rows x 44 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 289105 × 38224
#     obs: 'background_fraction', 'cell_probability', 'cell_size', 'droplet_efficiency', 'dataset', 'barcode', 'author_cell_type', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_preparation_batch', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'sample_ID'
#     var: 'ambient_expression', 'feature_type', 'genome', 'gene_id', 'cellbender_analyzed', 'reference'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments'
#     obsm: 'gene_expression_encoding'

# %% [markdown]
# # Add author cell type markers to UNS

# %%
# correspond to HLCA v1 cell type markers

# %% [markdown]
# # Check author cell type annotations and Cell Ontology IDs

# %%
adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False)
# Out:
# EC venous pulmonary             101051
# 3_AT2                            87542
# Adventitial fibroblasts          47105
# 3_Lymphatic EC mature            11227
# EC aerocyte capillary             8168
# 3_AT1                             6984
# B cells                           6406
# 3_Lymphatic EC proliferating      5991
# 3_Smooth muscle FAM83D+           5458
# AT2 proliferating                 2766
# EC general capillary              2505
# CD4 T cells                       1968
# 3_Myofibroblasts                  1200
# CD8 T cells                        256
# Classical monocytes                201
# 2_Smooth muscle                    163
# Club                                52
# 2_Hematopoietic stem cells          28
# DC1                                 23
# 2_Mesothelium                        6
# DC2                                  3
# 3_Mast cells                         2
# Name: author_cell_type, dtype: int64

# %%
# from all cell types, remove '<number>_' prefix if present
adata.obs[AUTHOR_CELL_TYPE] = adata.obs[AUTHOR_CELL_TYPE].apply(lambda x: x.split('_')[1] if '_' in x else x)
adata.obs[AUTHOR_CELL_TYPE].value_counts(dropna=False)
# Out:
# EC venous pulmonary           101051
# AT2                            87542
# Adventitial fibroblasts        47105
# Lymphatic EC mature            11227
# EC aerocyte capillary           8168
# AT1                             6984
# B cells                         6406
# Lymphatic EC proliferating      5991
# Smooth muscle FAM83D+           5458
# AT2 proliferating               2766
# EC general capillary            2505
# CD4 T cells                     1968
# Myofibroblasts                  1200
# CD8 T cells                      256
# Classical monocytes              201
# Smooth muscle                    163
# Club                              52
# Hematopoietic stem cells          28
# DC1                               23
# Mesothelium                        6
# DC2                                3
# Mast cells                         2
# Name: author_cell_type, dtype: int64

# %%
ontology_mapping = pd.read_csv("/home/icb/raphael.kfuri-rubens/git/hlca-v2/notebooks/core_datasets/01_wrangling_validation_assembling/HLCA_v1/hlca_v1_annot_ontology_id_mapping_all.csv")

ontology_mapping_dict = dict(zip(ontology_mapping['cell_type_annotation'], ontology_mapping['cell_type_ontology_term_id']))

ontology_mapping_dict
# Out:
# {'Immune': 'CL:0000583',
#  'Epithelial': 'CL:0002063',
#  'Endothelial': 'CL:0002543',
#  'Stroma': 'CL:2000093',
#  'Myeloid': 'CL:0000583',
#  'Lymphoid': 'CL:0000623',
#  'Alveolar epithelium': 'CL:0002063',
#  'Airway epithelium': 'CL:0002633',
#  'Blood vessels': 'CL:0002543',
#  'Fibroblast lineage': 'CL:2000093',
#  'Smooth muscle': 'CL:0019019',
#  'Submucosal Gland': 'CL:0019001',
#  'Lymphatic EC': 'CL:0002138',
#  'Mesothelium': 'CL:0000077',
#  'Hematopoietic stem cells': 'CL:0000037',
#  'Macrophages': 'CL:0000583',
#  'Innate lymphoid cell NK': 'CL:0000623',
#  'AT2': 'CL:0002063',
#  'Basal': 'CL:0002633',
#  'EC venous': 'CL:0002543',
#  'T cell lineage': 'CL:0000625',
#  'EC arterial': 'CL:1001568',
#  'Fibroblasts': 'CL:2000093',
#  'AT1': 'CL:0002062',
#  'Multiciliated lineage': 'CL:0002145',
#  'B cell lineage': 'CL:0000786',
#  'Secretory': 'CL:0002480',
#  'SM activated stress response': 'CL:0000192',
#  'Monocytes': 'CL:0000860',
#  'Submucosal Secretory': 'CL:0019001',
#  'EC capillary': 'CL:0002144',
#  'Lymphatic EC mature': 'CL:0002138',
#  'None': 'CL:0000583',
#  'Rare': 'CL:1000223',
#  'Lymphatic EC differentiating': 'CL:0002138',
#  'Dendritic cells': 'CL:0002399',
#  'Myofibroblasts': 'CL:0000186',
#  'Mast cells': 'CL:0000097',
#  'Smooth muscle FAM83D+': 'CL:0000499',
#  'Lymphatic EC proliferating': 'CL:0002138',
#  'Alveolar macrophages': 'CL:0000583',
#  'NK cells': 'CL:0000623',
#  'Suprabasal': 'CL:0002633',
#  'Basal resting': 'CL:0002633',
#  'EC venous pulmonary': 'CL:0002543',
#  'CD8 T cells': 'CL:0000625',
#  'Peribronchial fibroblasts': 'CL:2000093',
#  'CD4 T cells': 'CL:0000624',
#  'Multiciliated': 'CL:0002145',
#  'Plasma cells': 'CL:0000786',
#  'Hillock-like': 'CL:4030023',
#  'Goblet': 'CL:0002480',
#  'Club': 'CL:0000158',
#  'Classical monocytes': 'CL:0000860',
#  'Interstitial macrophages': 'CL:0000861',
#  'SMG serous': 'CL:0019001',
#  'EC venous systemic': 'CL:0002543',
#  'Non-classical monocytes': 'CL:0000875',
#  'EC general capillary': 'CL:0002144',
#  'Adventitial fibroblasts': 'CL:4028006',
#  'EC aerocyte capillary': 'CL:0002144',
#  'Transitional Club-AT2': 'CL:0002632',
#  'Alveolar fibroblasts': 'CL:4028004',
#  'Neuroendocrine': 'CL:1000223',
#  'DC2': 'CL:0002399',
#  'DC1': 'CL:0000990',
#  'B cells': 'CL:0000236',
#  'SMG mucous': 'CL:0000319',
#  'AT2 proliferating': 'CL:0002063',
#  'Pericytes': 'CL:0009089',
#  'SMG duct': 'CL:0000622',
#  'Ionocyte': 'CL:0005006',
#  'Deuterosomal': 'CL:0005012',
#  'Tuft': 'CL:0002075',
#  'Plasmacytoid DCs': 'CL:0000784',
#  'T cells proliferating': 'CL:0000084',
#  'Subpleural fibroblasts': 'CL:0000057',
#  'Migratory DCs': 'CL:0000451',
#  'Alveolar Mph CCL3+': 'CL:0000583',
#  'Multiciliated (non-nasal)': 'CL:0002145',
#  'Goblet (nasal)': 'CL:0002480',
#  'Club (nasal)': 'CL:0000158',
#  'Monocyte-derived Mph': 'CL:0000861',
#  'Alveolar Mph proliferating': 'CL:0000583',
#  'Club (non-nasal)': 'CL:0000158',
#  'SMG serous (bronchial)': 'CL:0019001',
#  'pre-TB secretory': 'CL:0002632',
#  'Multiciliated (nasal)': 'CL:0005012',
#  'Goblet (bronchial)': 'CL:1000312',
#  'Interstitial Mph perivascular': 'CL:1001603',
#  'Goblet (subsegmental)': 'CL:0019003',
#  'AT0': 'CL:0010003',
#  'SMG serous (nasal)': 'CL:0000313',
#  'Alveolar Mph MT-positive': 'CL:0000583'}

# %%
adata.obs[CELL_TYPE_ONTOLOGY_ID] = adata.obs[AUTHOR_CELL_TYPE].map(ontology_mapping_dict)

adata.obs[CELL_TYPE_ONTOLOGY_ID].value_counts(dropna=False)
# Out:
# CL:0002543    101051
# CL:0002063     90308
# CL:4028006     47105
# CL:0002138     17218
# CL:0002144     10673
# CL:0002062      6984
# CL:0000236      6406
# CL:0000499      5458
# CL:0000624      1968
# CL:0000186      1200
# CL:0000625       256
# CL:0000860       201
# CL:0019019       163
# CL:0000158        52
# CL:0000037        28
# CL:0000990        23
# CL:0000077         6
# CL:0002399         3
# CL:0000097         2
# Name: cell_type_ontology_term_id, dtype: int64

# %% [markdown]
# # Check whether ENSEMBL IDs in var

# %%
adata.var['gene_symbol'] = adata.var.index
adata.var.index.name = 'index'
adata.var.rename(columns={'gene_id': 'ensembl_id'}, inplace=True)
adata.var
# Out:
#              ambient_expression     feature_type  genome       ensembl_id  \
# index
# MIR1302-2HG        0.000000e+00  Gene Expression  GRCh38  ENSG00000243485
# FAM138A            0.000000e+00  Gene Expression  GRCh38  ENSG00000237613
# OR4F5              0.000000e+00  Gene Expression  GRCh38  ENSG00000186092
# AL627309.1         0.000000e+00  Gene Expression  GRCh38  ENSG00000238009
# AL627309.3         0.000000e+00  Gene Expression  GRCh38  ENSG00000239945
# ...                         ...              ...     ...              ...
# AC010086.3         0.000000e+00  Gene Expression  GRCh38  ENSG00000288057
# AC024236.1         0.000000e+00  Gene Expression  GRCh38  ENSG00000286187
# PRYP3              0.000000e+00  Gene Expression  GRCh38  ENSG00000169763
# AC213203.2         0.000000e+00  Gene Expression  GRCh38  ENSG00000277475
# AC004556.3         4.760004e-07  Gene Expression  GRCh38  ENSG00000276345
#
#              cellbender_analyzed reference  gene_symbol
# index
# MIR1302-2HG                False    GRCh38  MIR1302-2HG
# FAM138A                    False    GRCh38      FAM138A
# OR4F5                      False    GRCh38        OR4F5
# AL627309.1                 False    GRCh38   AL627309.1
# AL627309.3                 False    GRCh38   AL627309.3
# ...                          ...       ...          ...
# AC010086.3                 False    GRCh38   AC010086.3
# AC024236.1                 False    GRCh38   AC024236.1
# PRYP3                      False    GRCh38        PRYP3
# AC213203.2                 False    GRCh38   AC213203.2
# AC004556.3                  True    GRCh38   AC004556.3
#
# [38224 rows x 7 columns]

# %% [markdown]
# # Check raw data

# %%
adata.X.toarray().max()
# Out:
# 32962

# %%
adata.X = adata.X.astype(np.int64)

# %%
adata.raw = adata

# %%
adata.X
# Out:
# <289105x38224 sparse matrix of type '<class 'numpy.int64'>'
# 	with 339344761 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <289105x38224 sparse matrix of type '<class 'numpy.int64'>'
# 	with 339344761 stored elements in Compressed Sparse Row format>

# %%
adata.X.toarray().max()
# Out:
# 32962

# %%
adata.raw.X.toarray().max()
# Out:
# 32962

# %% [markdown]
# ## Validation result
#
# ### UNS Validation
# - OK: Tier 1 UNS Google Sheet
# - OK: Tier 1 UNS AnnData Object
#
# ### OBS Validation
# - OK
# - OK

# %% [markdown]
# # Data Submission Status
#
# - CHECK: Raw counts in X and in raw
# - CHECK: Tier 1 Metadata in OBS
# - CHECK: Cell Ontology IDs in OBS
# - CHECK: Author cell type in OBS
# - MISSING: Marker genes correspond to HLCA v1 as mapped with Archmap
# - CHECK: ENSEMBL IDs in var
#
# ### Revision:
#
# DONE

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"))
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"))

# %%
adata = sc.read_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"))
# Out:
# /home/icb/raphael.kfuri-rubens/miniconda3/envs/hlcav2-env/lib/python3.10/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/icb/raphael.kfuri-rubens/miniconda3/envs/hlcav2-env/lib/python3.10/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata.obs.index = adata.obs.index.astype(str)
adata.obs_names_make_unique()

# %%
# check whether obs index unique
adata.obs.index.is_unique
# Out:
# False

# %%
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"))

# %%
adata = sc.read_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"))
# Out:
# /home/icb/raphael.kfuri-rubens/miniconda3/envs/hlcav2-env/lib/python3.10/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/icb/raphael.kfuri-rubens/miniconda3/envs/hlcav2-env/lib/python3.10/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
