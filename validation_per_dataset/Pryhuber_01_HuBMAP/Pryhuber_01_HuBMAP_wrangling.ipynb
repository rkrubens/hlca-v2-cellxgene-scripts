# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import anndata2ri
import os
from os.path import join
import scipy.sparse as sp
import numpy as np

from hlca_v2.ingestion_utils import get_gspread_df, ValidationWorkflow, AnnDataMerger

GSPREAD_JSON = "/home/icb/raphael.kfuri-rubens/data/hlca_v2/google_sheets_api/hlca-v2-8d5fea10d8f3.json"
# Out:
# Warning message:
# package ‘methods’ was built under R version 4.3.3
# During startup - Warning messages:
# 1: package ‘datasets’ was built under R version 4.3.3
# 2: package ‘utils’ was built under R version 4.3.3
# 3: package ‘grDevices’ was built under R version 4.3.3
# 4: package ‘graphics’ was built under R version 4.3.3
# 5: package ‘stats’ was built under R version 4.3.3

# %%
DATASET_ID = "Pryhuber_01_HuBMAP"
RDS_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/{DATASET_ID}.RDS"
ENESEMBL_PATH = f"/home/icb/raphael.kfuri-rubens/data/hlca_v2/{DATASET_ID}/features.tsv"
OUTPUT_PATH_PREREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_prerevision'
OUTPUT_PATH_POSTREVISION = '/home/icb/raphael.kfuri-rubens/data/hlca_v2/HLCA_V2_CORE/adata_postrevision'

# %%
# Name constants
AUTHOR_CELL_TYPE_L0 = 'author_cell_type_level_0'
AUTHOR_CELL_TYPE_L1 = 'author_cell_type_level_1'

CELL_TYPE_ONTOLOGY_ID_L0 = 'cell_type_ontology_term_id_level_0'
CELL_TYPE_ONTOLOGY_ID_L1 = 'cell_type_ontology_term_id_level_1'

CELL_TYPE_ONTOLOGY_LABEL_L0 = 'cell_type_ontology_term_label_level_0'
CELL_TYPE_ONTOLOGY_LABEL_L1 = 'cell_type_ontology_term_label_level_1'

AUTHOR_CELL_TYPE_DESCRIPTION_L0 = 'author_cell_type_description_level_0'
AUTHOR_CELL_TYPE_DESCRIPTION_L1 = 'author_cell_type_description_level_1'

MARKER_GENES_L0 = 'author_cell_type_markers_level_0'
MARKER_GENES_L1 = 'author_cell_type_markers_level_1'

# Finest grained annotation will be generic dataset cell type
AUTHOR_CELL_TYPE = 'author_cell_type'
CELL_TYPE_ONTOLOGY_ID = 'cell_type_ontology_term_id'
CELL_TYPE_ONTOLOGY_LABEL = 'cell_type_ontology_term_label'
MARKER_GENES = 'author_cell_type_markers'
AUTHOR_CELL_TYPE_DESCRIPTION = 'author_cell_type_description'

# %% [markdown]
# # Load data

# %%
anndata2ri.activate()
# %load_ext rpy2.ipython
# Out:
# /tmp/ipykernel_1929962/2547887543.py:1: DeprecationWarning: The global conversion available with activate() is deprecated and will be removed in the next major release. Use a local converter.
#   anndata2ri.activate()

# %%
# %%R -i RDS_PATH
#
# suppressPackageStartupMessages(library(Seurat))
# rds <- readRDS(file=RDS_PATH)
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# In addition: Warning message:
# package ‘tools’ was built under R version 4.3.3

# %%
# %%R -o adata
#
# adata <- as.SingleCellExperiment(rds)
# adata
# Out:
# class: SingleCellExperiment
# dim: 29800 348012
# metadata(0):
# assays(1): counts
# rownames(29800): A1BG A1BG-AS1 ... ZYX ZZEF1
# rowData names(0):
# colnames(348012): LAP40_AAACCCAAGATGCTAA LAP40_AAACCCAAGATTGACA ...
#   LAP191_TTTGTTGTCGAACCAT-1 LAP191_TTTGTTGTCGGCTGGT-1
# colData names(7): orig.ident nCount_RNA ... subclass.l5 ident
# reducedDimNames(0):
# mainExpName: RNA
# altExpNames(0):
# In addition: Warning messages:
# 1: Layer ‘data’ is empty
# 2: Layer ‘scale.data’ is empty
# /home/icb/raphael.kfuri-rubens/miniconda3/envs/hlcav2-env/lib/python3.10/site-packages/anndata2ri/_r2py.py:132: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   return AnnData(exprs, obs, var, uns, obsm, layers=layers)

# %%
adata.obs
# Out:
#                           orig.ident  nCount_RNA  nFeature_RNA sublass.l4  \
# LAP40_AAACCCAAGATGCTAA         LAP40      3962.0          1859        AT2
# LAP40_AAACCCAAGATTGACA         LAP40      5413.0          2587        AF1
# LAP40_AAACCCAGTTTCTATC         LAP40      2113.0          1140         AM
# LAP40_AAACCCATCCAACTAG         LAP40       645.0           480        RAS
# LAP40_AAACCCATCGCGGTAC         LAP40      7475.0          2958         AM
# ...                              ...         ...           ...        ...
# LAP191_TTTGGTTTCTGCCTCA-1     LAP191       865.0           691       CAP1
# LAP191_TTTGTTGGTTTGCAGT-1     LAP191      2191.0          1408        AT2
# LAP191_TTTGTTGTCACGTAGT-1     LAP191       559.0           479       CAP2
# LAP191_TTTGTTGTCGAACCAT-1     LAP191      1047.0           832   Ciliated
# LAP191_TTTGTTGTCGGCTGGT-1     LAP191      1533.0          1183      Basal
#
#                           CellOntology.ID subclass.l5   ident
# LAP40_AAACCCAAGATGCTAA            0002063       AT2-1   LAP40
# LAP40_AAACCCAAGATTGACA            4028004       AF1-1   LAP40
# LAP40_AAACCCAGTTTCTATC            0000583          AM   LAP40
# LAP40_AAACCCATCCAACTAG            1000272     PreTBSC   LAP40
# LAP40_AAACCCATCGCGGTAC            0000583          AM   LAP40
# ...                                   ...         ...     ...
# LAP191_TTTGGTTTCTGCCTCA-1         4028002        CAP1  LAP191
# LAP191_TTTGTTGGTTTGCAGT-1         0002063       AT2-2  LAP191
# LAP191_TTTGTTGTCACGTAGT-1         4028003        CAP2  LAP191
# LAP191_TTTGTTGTCGAACCAT-1         0002145  Ciliated-2  LAP191
# LAP191_TTTGTTGTCGGCTGGT-1         0002329       Basal  LAP191
#
# [348012 rows x 7 columns]

# %%
l4_annot = pd.read_csv("/home/icb/raphael.kfuri-rubens/data/hlca_v2/Pryhuber_01_HuBMAP/subclass.l4 Annotations Markers Lung 10X snRNA-seq HuBMAP1.csv", usecols=range(0,5))
l5_annot = pd.read_csv("/home/icb/raphael.kfuri-rubens/data/hlca_v2/Pryhuber_01_HuBMAP/subclass.l5 Annotations Markers Lung 10X snRNA-seq HuBMAP1.csv", usecols=range(0,5))

l4_col_dict = {
    'Full name': AUTHOR_CELL_TYPE_DESCRIPTION_L0,
    'subclass.l4': AUTHOR_CELL_TYPE_L0,
    'CL ID Label': CELL_TYPE_ONTOLOGY_LABEL_L0,
    'CL ID': CELL_TYPE_ONTOLOGY_ID_L0,
    'Marker Genes': MARKER_GENES_L0
}

l5_col_dict = {
    'Full name': AUTHOR_CELL_TYPE_DESCRIPTION_L1,
    'subclass.l5': AUTHOR_CELL_TYPE_L1,
    'CL ID Label': CELL_TYPE_ONTOLOGY_LABEL_L1,
    'CL ID': CELL_TYPE_ONTOLOGY_ID_L1,
    'Marker Genes': MARKER_GENES_L1
}

l4_annot = l4_annot.rename(columns=l4_col_dict)
l5_annot = l5_annot.rename(columns=l5_col_dict)

l5_annot
# Out:
#       author_cell_type_description_level_1 author_cell_type_level_1  \
# 0                               Basal cell                    Basal
# 1        Distal basal cell SFTPB+ subset 1            Basal.SFTPB-1
# 2   Distal basal cell SFTPB+ high subset 2            Basal.SFTPB-2
# 3                 Basal proliferating cell                  Basal.p
# 4                          Suprabasal cell               Suprabasal
# ..                                     ...                      ...
# 56                              Neutrophil               Neutrophil
# 57                    Neutrophil activated                Neu.activ
# 58                Neutrophil degranulating               Neu.degran
# 59                Neutrophil proliferating                    Neu.p
# 60                      Basophil/Mast cell                Baso.Mast
#
#                 cell_type_ontology_term_label_level_1  \
# 0      basal epithelial cell of tracheobronchial tree
# 1   basal epithelial cell of tracheobronchial tree...
# 2   basal epithelial cell of tracheobronchial tree...
# 3   basal epithelial cell of tracheobronchial tree...
# 4                       respiratory suprabasal cell\t
# ..                                                ...
# 56                                         neutrophil
# 57                               neutrophil;activated
# 58                           neutrophil;degranulating
# 59                           neutrophil;proliferating
# 60                                          mast cell
#
#    cell_type_ontology_term_id_level_1  \
# 0                          CL:0002329
# 1                          CL:0002329
# 2                          CL:0002329
# 3                          CL:0002329
# 4                          CL:4033048
# ..                                ...
# 56                         CL:0000775
# 57                         CL:0000775
# 58                         CL:0000775
# 59                         CL:0000775
# 60                         CL:0000097
#
#                      author_cell_type_markers_level_1
# 0                                  TP63;  KRT15; KRT5
# 1            TP63;  KRT15; SFTPB; IGFBP2; CNTN6; GPC3
# 2      TP63;  KRT15; SFTPB; MFSD2A; TMEM163;  SLC34A2
# 3               TP63;  KRT15; KRT5; MKI67, TOP2A, CIT
# 4   TP63;  KRT15; SERPPINB3;  SERPINB13; NOTCH3; K...
# ..                                                ...
# 56                                              CSF3R
# 57                         CSF3R; FCGR3B; MXD1; PADI4
# 58                            CSF3R; BPI; AZU1; DEFA3
# 59                           CSF3R; MKI67, TOP2A, CIT
# 60                                  KIT; MS4A2; TPSB2
#
# [61 rows x 5 columns]

# %%
obs = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "obs")
uns = get_gspread_df(GSPREAD_JSON, DATASET_ID, "tier_1", "uns")

# %%
val_workflow = ValidationWorkflow(
    input = uns,
    axis = 'uns'
)

validated_uns = val_workflow.init_workflow()
validated_uns
# Out:
# Validation workflow successful. Returning UNS dataframe.
#                                                title  \
# 0  Cell identification by single nuclear RNA sequ...
#
#                                             study_PI batch_condition  \
# 0  Elizabeth Duong, Kun Zhang, James Hagood, Xin ...      orig.ident
#
#   default_embedding                                     unpublished comments
# 0                    consented for release, protected under embargo

# %%
val_workflow = ValidationWorkflow(
    input = obs,
    axis = 'obs'
)

validated_obs = val_workflow.init_workflow()
validated_obs
# Out:
# Validation workflow successful. Returning OBS dataframe.
#         sample_ID donor_id                                       protocol_URL  \
# 0   D231-RML-10A4     D231  Master protocol (includes subprotocls for all ...
# 1   D231-RML-10B2     D231  Master protocol (includes subprotocls for all ...
# 2    D231-RML-2A3     D231  Master protocol (includes subprotocls for all ...
# 3    D231-RML-4B4     D231  Master protocol (includes subprotocls for all ...
# 4    D231-RML-6A4     D231  Master protocol (includes subprotocls for all ...
# 5   D239-RML-12A3     D239  Master protocol (includes subprotocls for all ...
# 6   D239-RML-12A4     D239  Master protocol (includes subprotocls for all ...
# 7    D239-RML-3A4     D239  Master protocol (includes subprotocls for all ...
# 8    D239-RML-7A2     D239  Master protocol (includes subprotocls for all ...
# 9    D239-RML-7A3     D239  Master protocol (includes subprotocls for all ...
# 10   D239-RML-9B3     D239  Master protocol (includes subprotocls for all ...
# 11   D239-RML-9B3     D239  Master protocol (includes subprotocls for all ...
# 12   D239-RML-9B3     D239  Master protocol (includes subprotocls for all ...
# 13   D239-RML-9B5     D239  Master protocol (includes subprotocls for all ...
# 14  D260-LUL-11A3     D260  Master protocol (includes subprotocls for all ...
# 15  D260-LUL-11C8     D260  Master protocol (includes subprotocls for all ...
# 16   D260-LUL-5A3     D260  Master protocol (includes subprotocls for all ...
# 17   D260-LUL-5C3     D260  Master protocol (includes subprotocls for all ...
# 18  D264-LUL-10A3     D264  Master protocol (includes subprotocls for all ...
# 19  D264-LUL-13B5     D264  Master protocol (includes subprotocls for all ...
# 20   D264-LUL-4A2     D264  Master protocol (includes subprotocls for all ...
# 21   D264-LUL-4A6     D264  Master protocol (includes subprotocls for all ...
# 22   D264-LUL-7B4     D264  Master protocol (includes subprotocls for all ...
# 23  D265-LUL-13B4     D265  Master protocol (includes subprotocls for all ...
# 24  D265-LUL-13B5     D265  Master protocol (includes subprotocls for all ...
# 25  D265-LUL-20A3     D265  Master protocol (includes subprotocls for all ...
# 26   D265-LUL-5B4     D265  Master protocol (includes subprotocls for all ...
# 27   D265-LUL-9B4     D265  Master protocol (includes subprotocls for all ...
# 28  D271-RML-10B3     D271  Master protocol (includes subprotocls for all ...
# 29   D271-RML-7B4     D271  Master protocol (includes subprotocls for all ...
# 30   D273-RML-9A5     D273  Master protocol (includes subprotocls for all ...
# 31  D292-RUL-10A5     D292  Master protocol (includes subprotocls for all ...
# 32   D292-RUL-5A2     D292  Master protocol (includes subprotocls for all ...
# 33   D292-RUL-5A5     D292  Master protocol (includes subprotocls for all ...
# 34   D292-RUL-5B5     D292  Master protocol (includes subprotocls for all ...
# 35   D292-RUL-5B7     D292  Master protocol (includes subprotocls for all ...
# 36   D341-RUL-3A2     D341  Master protocol (includes subprotocls for all ...
# 37   D341-RUL-3B4     D341  Master protocol (includes subprotocls for all ...
# 38   D341-RUL-9A3     D341  Master protocol (includes subprotocls for all ...
# 39   D341-RUL-9B5     D341  Master protocol (includes subprotocls for all ...
# 40   D346-RUL-4A4     D346  Master protocol (includes subprotocls for all ...
# 41   D346-RUL-4B5     D346  Master protocol (includes subprotocls for all ...
# 42   D346-RUL-9A2     D346  Master protocol (includes subprotocls for all ...
# 43   D346-RUL-9B4     D346  Master protocol (includes subprotocls for all ...
# 44   D403-RUL-5A2     D403  Master protocol (includes subprotocls for all ...
# 45   D403-RUL-5C2     D403  Master protocol (includes subprotocls for all ...
#
#                                             institute sample_collection_site  \
# 0   University of Rochester (tissue source and pre...                   URMC
# 1   University of Rochester (tissue source and pre...                   URMC
# 2   University of Rochester (tissue source and pre...                   URMC
# 3   University of Rochester (tissue source and pre...                   URMC
# 4   University of Rochester (tissue source and pre...                   URMC
# 5   University of Rochester (tissue source and pre...                   URMC
# 6   University of Rochester (tissue source and pre...                   URMC
# 7   University of Rochester (tissue source and pre...                   URMC
# 8   University of Rochester (tissue source and pre...                   URMC
# 9   University of Rochester (tissue source and pre...                   URMC
# 10  University of Rochester (tissue source and pre...                   URMC
# 11  University of Rochester (tissue source and pre...                   URMC
# 12  University of Rochester (tissue source and pre...                   URMC
# 13  University of Rochester (tissue source and pre...                   URMC
# 14  University of Rochester (tissue source and pre...                   URMC
# 15  University of Rochester (tissue source and pre...                   URMC
# 16  University of Rochester (tissue source and pre...                   URMC
# 17  University of Rochester (tissue source and pre...                   URMC
# 18  University of Rochester (tissue source and pre...                   URMC
# 19  University of Rochester (tissue source and pre...                   URMC
# 20  University of Rochester (tissue source and pre...                   URMC
# 21  University of Rochester (tissue source and pre...                   URMC
# 22  University of Rochester (tissue source and pre...                   URMC
# 23  University of Rochester (tissue source and pre...                   URMC
# 24  University of Rochester (tissue source and pre...                   URMC
# 25  University of Rochester (tissue source and pre...                   URMC
# 26  University of Rochester (tissue source and pre...                   URMC
# 27  University of Rochester (tissue source and pre...                   URMC
# 28  University of Rochester (tissue source and pre...                   URMC
# 29  University of Rochester (tissue source and pre...                   URMC
# 30  University of Rochester (tissue source and pre...                   URMC
# 31  University of Rochester (tissue source and pre...                   URMC
# 32  University of Rochester (tissue source and pre...                   URMC
# 33  University of Rochester (tissue source and pre...                   URMC
# 34  University of Rochester (tissue source and pre...                   URMC
# 35  University of Rochester (tissue source and pre...                   URMC
# 36  University of Rochester (tissue source and pre...                   URMC
# 37  University of Rochester (tissue source and pre...                   URMC
# 38  University of Rochester (tissue source and pre...                   URMC
# 39  University of Rochester (tissue source and pre...                   URMC
# 40  University of Rochester (tissue source and pre...                   URMC
# 41  University of Rochester (tissue source and pre...                   URMC
# 42  University of Rochester (tissue source and pre...                   URMC
# 43  University of Rochester (tissue source and pre...                   URMC
# 44  University of Rochester (tissue source and pre...                   URMC
# 45  University of Rochester (tissue source and pre...                   URMC
#
#    sample_collection_relative_time_point              library_ID  \
# 0                                    N/A  LAPMAP_20201216A_10X-R
# 1                                    N/A  LAPMAP_20211020A_10X-R
# 2                                    N/A  LAPMAP_20210514A_10X-R
# 3                                    N/A  LAPMAP_20210514B_10X-R
# 4                                    N/A  LAPMAP_20210514C_10X-R
# 5                                    N/A  LAPMAP_20200317M-10X-R
# 6                                    N/A  LAPMAP_20200317N-10X-R
# 7                                    N/A  LAPMAP_20200317H-10X-R
# 8                                    N/A  LAPMAP_20200317I-10X-R
# 9                                    N/A  LAPMAP_20200317J-10X-R
# 10                                   N/A  LAPMAP_20191217E_10X-R
# 11                                   N/A  LAPMAP_20191217G_10X-R
# 12                                   N/A  LAPMAP_20200317K-10X-R
# 13                                   N/A  LAPMAP_20200317L-10X-R
# 14                                   N/A  LAPMAP_20211202C_10X-R
# 15                                   N/A  LAPMAP_20211202D_10X-R
# 16                                   N/A  LAPMAP_20211202A_10X-R
# 17                                   N/A  LAPMAP_20211202B_10X-R
# 18                                   N/A  LAPMAP_20211020H_10X-R
# 19                                   N/A  LAPMAP_20201216B_10X-R
# 20                                   N/A  LAPMAP_20211020E_10X-R
# 21                                   N/A  LAPMAP_20211020F_10X-R
# 22                                   N/A  LAPMAP_20211020G_10X-R
# 23                                   N/A  LAPMAP_20211020C_10X-R
# 24                                   N/A  LAPMAP_20201216D_10X-R
# 25                                   N/A  LAPMAP_20210514E_10X-R
# 26                                   N/A  LAPMAP_20201216C_10X-R
# 27                                   N/A  LAPMAP_20210514D_10X-R
# 28                                   N/A  LAPMAP_20201216F_10X-R
# 29                                   N/A  LAPMAP_20201216E_10X-R
# 30                                   N/A  LAPMAP_20201216G_10X-R
# 31                                   N/A  LAPMAP_20210514G_10X-R
# 32                                   N/A  LAPMAP_20210514F_10X-R
# 33                                   N/A  LAPMAP_20201216H_10X-R
# 34                                   N/A  LAPMAP_20211020D_10X-R
# 35                                   N/A  LAPMAP_20210514H_10X-R
# 36                                   N/A  LAPMAP_20211117A_10X-R
# 37                                   N/A  LAPMAP_20211117B_10X-R
# 38                                   N/A  LAPMAP_20211117C_10X-R
# 39                                   N/A  LAPMAP_20211117D_10X-R
# 40                                   N/A  LAPMAP_20211202E_10X-R
# 41                                   N/A  LAPMAP_20211202F_10X-R
# 42                                   N/A  LAPMAP_20211202G_10X-R
# 43                                   N/A  LAPMAP_20211202H_10X-R
# 44                                   N/A  LAPMAP_20211117E_10X-R
# 45                                   N/A  LAPMAP_20211117F_10X-R
#
#    library_ID_repository author_batch_notes organism_ontology_term_id  ...  \
# 0        HBM443.VFRD.453                N/A            NCBITaxon:9606  ...
# 1        HBM443.VFRD.453                N/A            NCBITaxon:9606  ...
# 2        HBM443.VFRD.453                N/A            NCBITaxon:9606  ...
# 3        HBM443.VFRD.453                N/A            NCBITaxon:9606  ...
# 4        HBM443.VFRD.453                N/A            NCBITaxon:9606  ...
# 5        HBM943.SCQQ.877                N/A            NCBITaxon:9606  ...
# 6        HBM943.SCQQ.877                N/A            NCBITaxon:9606  ...
# 7        HBM943.SCQQ.877                N/A            NCBITaxon:9606  ...
# 8        HBM943.SCQQ.877                N/A            NCBITaxon:9606  ...
# 9        HBM943.SCQQ.877                N/A            NCBITaxon:9606  ...
# 10       HBM943.SCQQ.877                N/A            NCBITaxon:9606  ...
# 11       HBM943.SCQQ.877                N/A            NCBITaxon:9606  ...
# 12       HBM943.SCQQ.877                N/A            NCBITaxon:9606  ...
# 13       HBM943.SCQQ.877                N/A            NCBITaxon:9606  ...
# 14       HBM626.JCQZ.225                N/A            NCBITaxon:9606  ...
# 15       HBM626.JCQZ.225                N/A            NCBITaxon:9606  ...
# 16       HBM626.JCQZ.225                N/A            NCBITaxon:9606  ...
# 17       HBM626.JCQZ.225                N/A            NCBITaxon:9606  ...
# 18       HBM852.DHHR.655                N/A            NCBITaxon:9606  ...
# 19       HBM852.DHHR.655                N/A            NCBITaxon:9606  ...
# 20       HBM852.DHHR.655                N/A            NCBITaxon:9606  ...
# 21       HBM852.DHHR.655                N/A            NCBITaxon:9606  ...
# 22       HBM852.DHHR.655                N/A            NCBITaxon:9606  ...
# 23       HBM849.FBJV.474                N/A            NCBITaxon:9606  ...
# 24       HBM849.FBJV.474                N/A            NCBITaxon:9606  ...
# 25       HBM849.FBJV.474                N/A            NCBITaxon:9606  ...
# 26       HBM849.FBJV.474                N/A            NCBITaxon:9606  ...
# 27       HBM849.FBJV.474                N/A            NCBITaxon:9606  ...
# 28       HBM428.GRPJ.489                N/A            NCBITaxon:9606  ...
# 29       HBM428.GRPJ.489                N/A            NCBITaxon:9606  ...
# 30       HBM957.XGCL.285                N/A            NCBITaxon:9606  ...
# 31       HBM994.NXZC.854                N/A            NCBITaxon:9606  ...
# 32       HBM994.NXZC.854                N/A            NCBITaxon:9606  ...
# 33       HBM994.NXZC.854                N/A            NCBITaxon:9606  ...
# 34       HBM994.NXZC.854                N/A            NCBITaxon:9606  ...
# 35       HBM994.NXZC.854                N/A            NCBITaxon:9606  ...
# 36       HBM643.KCCK.866                N/A            NCBITaxon:9606  ...
# 37       HBM643.KCCK.866                N/A            NCBITaxon:9606  ...
# 38       HBM643.KCCK.866                N/A            NCBITaxon:9606  ...
# 39       HBM643.KCCK.866                N/A            NCBITaxon:9606  ...
# 40       HBM932.JNVS.672                N/A            NCBITaxon:9606  ...
# 41       HBM932.JNVS.672                N/A            NCBITaxon:9606  ...
# 42       HBM932.JNVS.672                N/A            NCBITaxon:9606  ...
# 43       HBM932.JNVS.672                N/A            NCBITaxon:9606  ...
# 44       HBM848.BMDK.429                N/A            NCBITaxon:9606  ...
# 45       HBM848.BMDK.429                N/A            NCBITaxon:9606  ...
#
#     sequenced_fragment sequencing_platform is_primary_data reference_genome  \
# 0          3 prime tag         EFO_0008637            true           GRCh38
# 1          3 prime tag         EFO_0008637            true           GRCh38
# 2          3 prime tag         EFO_0008637            true           GRCh38
# 3          3 prime tag         EFO_0008637            true           GRCh38
# 4          3 prime tag         EFO_0008637            true           GRCh38
# 5          3 prime tag         EFO_0008637            true           GRCh38
# 6          3 prime tag         EFO_0008637            true           GRCh38
# 7          3 prime tag         EFO_0008637            true           GRCh38
# 8          3 prime tag         EFO_0008637            true           GRCh38
# 9          3 prime tag         EFO_0008637            true           GRCh38
# 10         3 prime tag         EFO_0008637            true           GRCh38
# 11         3 prime tag         EFO_0008637            true           GRCh38
# 12         3 prime tag         EFO_0008637            true           GRCh38
# 13         3 prime tag         EFO_0008637            true           GRCh38
# 14         3 prime tag         EFO_0008637            true           GRCh38
# 15         3 prime tag         EFO_0008637            true           GRCh38
# 16         3 prime tag         EFO_0008637            true           GRCh38
# 17         3 prime tag         EFO_0008637            true           GRCh38
# 18         3 prime tag         EFO_0008637            true           GRCh38
# 19         3 prime tag         EFO_0008637            true           GRCh38
# 20         3 prime tag         EFO_0008637            true           GRCh38
# 21         3 prime tag         EFO_0008637            true           GRCh38
# 22         3 prime tag         EFO_0008637            true           GRCh38
# 23         3 prime tag         EFO_0008637            true           GRCh38
# 24         3 prime tag         EFO_0008637            true           GRCh38
# 25         3 prime tag         EFO_0008637            true           GRCh38
# 26         3 prime tag         EFO_0008637            true           GRCh38
# 27         3 prime tag         EFO_0008637            true           GRCh38
# 28         3 prime tag         EFO_0008637            true           GRCh38
# 29         3 prime tag         EFO_0008637            true           GRCh38
# 30         3 prime tag         EFO_0008637            true           GRCh38
# 31         3 prime tag         EFO_0008637            true           GRCh38
# 32         3 prime tag         EFO_0008637            true           GRCh38
# 33         3 prime tag         EFO_0008637            true           GRCh38
# 34         3 prime tag         EFO_0008637            true           GRCh38
# 35         3 prime tag         EFO_0008637            true           GRCh38
# 36         3 prime tag         EFO_0008637            true           GRCh38
# 37         3 prime tag         EFO_0008637            true           GRCh38
# 38         3 prime tag         EFO_0008637            true           GRCh38
# 39         3 prime tag         EFO_0008637            true           GRCh38
# 40         3 prime tag         EFO_0008637            true           GRCh38
# 41         3 prime tag         EFO_0008637            true           GRCh38
# 42         3 prime tag         EFO_0008637            true           GRCh38
# 43         3 prime tag         EFO_0008637            true           GRCh38
# 44         3 prime tag         EFO_0008637            true           GRCh38
# 45         3 prime tag         EFO_0008637            true           GRCh38
#
#    gene_annotation_version alignment_software intron_inclusion  \
# 0                     v110    cell ranger 3.0              yes
# 1                     v110    cell ranger 3.0              yes
# 2                     v110    cell ranger 3.0              yes
# 3                     v110    cell ranger 3.0              yes
# 4                     v110    cell ranger 3.0              yes
# 5                     v110    cell ranger 3.0              yes
# 6                     v110    cell ranger 3.0              yes
# 7                     v110    cell ranger 3.0              yes
# 8                     v110    cell ranger 3.0              yes
# 9                     v110    cell ranger 3.0              yes
# 10                    v110    cell ranger 3.0              yes
# 11                    v110    cell ranger 3.0              yes
# 12                    v110    cell ranger 3.0              yes
# 13                    v110    cell ranger 3.0              yes
# 14                    v110    cell ranger 3.0              yes
# 15                    v110    cell ranger 3.0              yes
# 16                    v110    cell ranger 3.0              yes
# 17                    v110    cell ranger 3.0              yes
# 18                    v110    cell ranger 3.0              yes
# 19                    v110    cell ranger 3.0              yes
# 20                    v110    cell ranger 3.0              yes
# 21                    v110    cell ranger 3.0              yes
# 22                    v110    cell ranger 3.0              yes
# 23                    v110    cell ranger 3.0              yes
# 24                    v110    cell ranger 3.0              yes
# 25                    v110    cell ranger 3.0              yes
# 26                    v110    cell ranger 3.0              yes
# 27                    v110    cell ranger 3.0              yes
# 28                    v110    cell ranger 3.0              yes
# 29                    v110    cell ranger 3.0              yes
# 30                    v110    cell ranger 3.0              yes
# 31                    v110    cell ranger 3.0              yes
# 32                    v110    cell ranger 3.0              yes
# 33                    v110    cell ranger 3.0              yes
# 34                    v110    cell ranger 3.0              yes
# 35                    v110    cell ranger 3.0              yes
# 36                    v110    cell ranger 3.0              yes
# 37                    v110    cell ranger 3.0              yes
# 38                    v110    cell ranger 3.0              yes
# 39                    v110    cell ranger 3.0              yes
# 40                    v110    cell ranger 3.0              yes
# 41                    v110    cell ranger 3.0              yes
# 42                    v110    cell ranger 3.0              yes
# 43                    v110    cell ranger 3.0              yes
# 44                    v110    cell ranger 3.0              yes
# 45                    v110    cell ranger 3.0              yes
#
#    disease_ontology_term_id self_reported_ethnicity_ontology_term_id  \
# 0              PATO:0000461                                  unknown
# 1              PATO:0000461                                  unknown
# 2              PATO:0000461                                  unknown
# 3              PATO:0000461                                  unknown
# 4              PATO:0000461                                  unknown
# 5              PATO:0000461                                  unknown
# 6              PATO:0000461                                  unknown
# 7              PATO:0000461                                  unknown
# 8              PATO:0000461                                  unknown
# 9              PATO:0000461                                  unknown
# 10             PATO:0000461                                  unknown
# 11             PATO:0000461                                  unknown
# 12             PATO:0000461                                  unknown
# 13             PATO:0000461                                  unknown
# 14             PATO:0000461                                  unknown
# 15             PATO:0000461                                  unknown
# 16             PATO:0000461                                  unknown
# 17             PATO:0000461                                  unknown
# 18             PATO:0000461                                  unknown
# 19             PATO:0000461                                  unknown
# 20             PATO:0000461                                  unknown
# 21             PATO:0000461                                  unknown
# 22             PATO:0000461                                  unknown
# 23             PATO:0000461                                  unknown
# 24             PATO:0000461                                  unknown
# 25             PATO:0000461                                  unknown
# 26             PATO:0000461                                  unknown
# 27             PATO:0000461                                  unknown
# 28             PATO:0000461                                  unknown
# 29             PATO:0000461                                  unknown
# 30             PATO:0000461                                  unknown
# 31             PATO:0000461                                  unknown
# 32             PATO:0000461                                  unknown
# 33             PATO:0000461                                  unknown
# 34             PATO:0000461                                  unknown
# 35             PATO:0000461                                  unknown
# 36             PATO:0000461                                  unknown
# 37             PATO:0000461                                  unknown
# 38             PATO:0000461                                  unknown
# 39             PATO:0000461                                  unknown
# 40             PATO:0000461                                  unknown
# 41             PATO:0000461                                  unknown
# 42             PATO:0000461                                  unknown
# 43             PATO:0000461                                  unknown
# 44             PATO:0000461                                  unknown
# 45             PATO:0000461                                  unknown
#
#    development_stage_ontology_term_id
# 0                      HsapDv:0000238
# 1                      HsapDv:0000238
# 2                      HsapDv:0000238
# 3                      HsapDv:0000238
# 4                      HsapDv:0000238
# 5                      HsapDv:0000238
# 6                      HsapDv:0000238
# 7                      HsapDv:0000238
# 8                      HsapDv:0000238
# 9                      HsapDv:0000238
# 10                     HsapDv:0000238
# 11                     HsapDv:0000238
# 12                     HsapDv:0000238
# 13                     HsapDv:0000238
# 14                     HsapDv:0000237
# 15                     HsapDv:0000237
# 16                     HsapDv:0000237
# 17                     HsapDv:0000237
# 18                     HsapDv:0000237
# 19                     HsapDv:0000237
# 20                     HsapDv:0000237
# 21                     HsapDv:0000237
# 22                     HsapDv:0000237
# 23                     HsapDv:0000237
# 24                     HsapDv:0000237
# 25                     HsapDv:0000237
# 26                     HsapDv:0000237
# 27                     HsapDv:0000237
# 28                     HsapDv:0000240
# 29                     HsapDv:0000240
# 30                     HsapDv:0000268
# 31                     HsapDv:0000237
# 32                     HsapDv:0000237
# 33                     HsapDv:0000237
# 34                     HsapDv:0000237
# 35                     HsapDv:0000237
# 36                     HsapDv:0000240
# 37                     HsapDv:0000240
# 38                     HsapDv:0000240
# 39                     HsapDv:0000240
# 40                     HsapDv:0000240
# 41                     HsapDv:0000240
# 42                     HsapDv:0000240
# 43                     HsapDv:0000240
# 44                     HsapDv:0000239
# 45                     HsapDv:0000239
#
# [46 rows x 37 columns]

# %%
# Add celltype annotatino to anndata

orig_obs = adata.obs.copy()

adata_dict = {
    'sublass.l4': AUTHOR_CELL_TYPE_L0,
    'subclass.l5': AUTHOR_CELL_TYPE_L1
}
orig_obs = orig_obs.rename(columns=adata_dict)
orig_obs = orig_obs.drop(columns='CellOntology.ID')

# L4 has multiple AT2 subsets, which however have the same cell name
# making it unique
l4_annot = l4_annot.drop_duplicates(subset=AUTHOR_CELL_TYPE_L0, keep='first')

left_index = orig_obs.index
orig_obs = orig_obs.merge(l4_annot, how='left', on=AUTHOR_CELL_TYPE_L0)
new_obs = orig_obs.merge(l5_annot, how='left', on=AUTHOR_CELL_TYPE_L1)
new_obs.index = left_index

new_obs
# Out:
#                           orig.ident  nCount_RNA  nFeature_RNA  \
# LAP40_AAACCCAAGATGCTAA         LAP40      3962.0          1859
# LAP40_AAACCCAAGATTGACA         LAP40      5413.0          2587
# LAP40_AAACCCAGTTTCTATC         LAP40      2113.0          1140
# LAP40_AAACCCATCCAACTAG         LAP40       645.0           480
# LAP40_AAACCCATCGCGGTAC         LAP40      7475.0          2958
# ...                              ...         ...           ...
# LAP191_TTTGGTTTCTGCCTCA-1     LAP191       865.0           691
# LAP191_TTTGTTGGTTTGCAGT-1     LAP191      2191.0          1408
# LAP191_TTTGTTGTCACGTAGT-1     LAP191       559.0           479
# LAP191_TTTGTTGTCGAACCAT-1     LAP191      1047.0           832
# LAP191_TTTGTTGTCGGCTGGT-1     LAP191      1533.0          1183
#
#                           author_cell_type_level_0 author_cell_type_level_1  \
# LAP40_AAACCCAAGATGCTAA                         AT2                    AT2-1
# LAP40_AAACCCAAGATTGACA                         AF1                    AF1-1
# LAP40_AAACCCAGTTTCTATC                          AM                       AM
# LAP40_AAACCCATCCAACTAG                         RAS                  PreTBSC
# LAP40_AAACCCATCGCGGTAC                          AM                       AM
# ...                                            ...                      ...
# LAP191_TTTGGTTTCTGCCTCA-1                     CAP1                     CAP1
# LAP191_TTTGTTGGTTTGCAGT-1                      AT2                    AT2-2
# LAP191_TTTGTTGTCACGTAGT-1                     CAP2                     CAP2
# LAP191_TTTGTTGTCGAACCAT-1                 Ciliated               Ciliated-2
# LAP191_TTTGTTGTCGGCTGGT-1                    Basal                    Basal
#
#                             ident author_cell_type_description_level_0  \
# LAP40_AAACCCAAGATGCTAA      LAP40      Alveolar epithelial type 2 cell
# LAP40_AAACCCAAGATTGACA      LAP40                Alveolar Fibroblast 1
# LAP40_AAACCCAGTTTCTATC      LAP40             Alveolar macrophage cell
# LAP40_AAACCCATCCAACTAG      LAP40    Respiratory airway secretory cell
# LAP40_AAACCCATCGCGGTAC      LAP40             Alveolar macrophage cell
# ...                           ...                                  ...
# LAP191_TTTGGTTTCTGCCTCA-1  LAP191   Capillary general endothelial cell
# LAP191_TTTGTTGGTTTGCAGT-1  LAP191      Alveolar epithelial type 2 cell
# LAP191_TTTGTTGTCACGTAGT-1  LAP191  Capillary aerocyte endothelial cell
# LAP191_TTTGTTGTCGAACCAT-1  LAP191                        Ciliated cell
# LAP191_TTTGTTGTCGGCTGGT-1  LAP191                           Basal cell
#
#                                        cell_type_ontology_term_label_level_0  \
# LAP40_AAACCCAAGATGCTAA                                    type II pneumocyte
# LAP40_AAACCCAAGATTGACA                            alveolar type 1 fibroblast
# LAP40_AAACCCAGTTTCTATC                                   alveolar macrophage
# LAP40_AAACCCATCCAACTAG     Lung secretory cell; Respiratory airway secret...
# LAP40_AAACCCATCGCGGTAC                                   alveolar macrophage
# ...                                                                      ...
# LAP191_TTTGGTTTCTGCCTCA-1         alveolar capillary type 1 endothelial cell
# LAP191_TTTGTTGGTTTGCAGT-1                                 type II pneumocyte
# LAP191_TTTGTTGTCACGTAGT-1         alveolar capillary type 2 endothelial cell
# LAP191_TTTGTTGTCGAACCAT-1    ciliated columnar cell of tracheobronchial tree
# LAP191_TTTGTTGTCGGCTGGT-1     basal epithelial cell of tracheobronchial tree
#
#                           cell_type_ontology_term_id_level_0  \
# LAP40_AAACCCAAGATGCTAA                            CL:0002063
# LAP40_AAACCCAAGATTGACA                            CL:4028004
# LAP40_AAACCCAGTTTCTATC                            CL:0000583
# LAP40_AAACCCATCCAACTAG                            CL:1000272
# LAP40_AAACCCATCGCGGTAC                            CL:0000583
# ...                                                      ...
# LAP191_TTTGGTTTCTGCCTCA-1                         CL:4028002
# LAP191_TTTGTTGGTTTGCAGT-1                         CL:0002063
# LAP191_TTTGTTGTCACGTAGT-1                         CL:4028003
# LAP191_TTTGTTGTCGAACCAT-1                        CL:0002145
# LAP191_TTTGTTGTCGGCTGGT-1                         CL:0002329
#
#                            author_cell_type_markers_level_0  \
# LAP40_AAACCCAAGATGCTAA     SFTPB; SFTPC; BMP1; ABCA3; LAMP3
# LAP40_AAACCCAAGATTGACA         ITGA8; CCBE1; GALNT17;  NKD1
# LAP40_AAACCCAGTTTCTATC                         PPARG; MARCO
# LAP40_AAACCCATCCAACTAG                SCGB3A2; GDF15; SFTPB
# LAP40_AAACCCATCGCGGTAC                         PPARG; MARCO
# ...                                                     ...
# LAP191_TTTGGTTTCTGCCTCA-1                 BTNL9; FCN3; IL7R
# LAP191_TTTGTTGGTTTGCAGT-1  SFTPB; SFTPC; BMP1; ABCA3; LAMP3
# LAP191_TTTGTTGTCACGTAGT-1                       HPGD; EDNRB
# LAP191_TTTGTTGTCGAACCAT-1               FOXJ1; CDHR3; RSPH1
# LAP191_TTTGTTGTCGGCTGGT-1                TP63;  KRT15; KRT5
#
#                                author_cell_type_description_level_1  \
# LAP40_AAACCCAAGATGCTAA     Alveolar epithelial type 2 cell subset 1
# LAP40_AAACCCAAGATTGACA               Alveolar Fibroblast 1 subset 1
# LAP40_AAACCCAGTTTCTATC                     Alveolar macrophage cell
# LAP40_AAACCCATCCAACTAG       Pre-terminal bronchiole secretory cell
# LAP40_AAACCCATCGCGGTAC                     Alveolar macrophage cell
# ...                                                             ...
# LAP191_TTTGGTTTCTGCCTCA-1        Capillary general endothelial cell
# LAP191_TTTGTTGGTTTGCAGT-1  Alveolar epithelial type 2 cell subset 2
# LAP191_TTTGTTGTCACGTAGT-1       Capillary aerocyte endothelial cell
# LAP191_TTTGTTGTCGAACCAT-1                    Ciliated cell subset 2
# LAP191_TTTGTTGTCGGCTGGT-1                                Basal cell
#
#                                        cell_type_ontology_term_label_level_1  \
# LAP40_AAACCCAAGATGCTAA                  type II pneumocyte; CCDC141 positive
# LAP40_AAACCCAAGATTGACA                alveolar type 1 fibroblast; PIEZO2 low
# LAP40_AAACCCAGTTTCTATC                                   alveolar macrophage
# LAP40_AAACCCATCCAACTAG     Lung secretory cell; RAS; Pre-terminal bronchiole
# LAP40_AAACCCATCGCGGTAC                                   alveolar macrophage
# ...                                                                      ...
# LAP191_TTTGGTTTCTGCCTCA-1         alveolar capillary type 1 endothelial cell
# LAP191_TTTGTTGGTTTGCAGT-1                  type II pneumocyte; LRP2 positive
# LAP191_TTTGTTGTCACGTAGT-1         alveolar capillary type 2 endothelial cell
# LAP191_TTTGTTGTCGAACCAT-1  tracheobronchial ciliated columnar cell; DHRS9...
# LAP191_TTTGTTGTCGGCTGGT-1     basal epithelial cell of tracheobronchial tree
#
#                           cell_type_ontology_term_id_level_1  \
# LAP40_AAACCCAAGATGCTAA                            CL:0002063
# LAP40_AAACCCAAGATTGACA                            CL:4028004
# LAP40_AAACCCAGTTTCTATC                            CL:0000583
# LAP40_AAACCCATCCAACTAG                            CL:1000272
# LAP40_AAACCCATCGCGGTAC                            CL:0000583
# ...                                                      ...
# LAP191_TTTGGTTTCTGCCTCA-1                         CL:4028002
# LAP191_TTTGTTGGTTTGCAGT-1                         CL:0002063
# LAP191_TTTGTTGTCACGTAGT-1                         CL:4028003
# LAP191_TTTGTTGTCGAACCAT-1                        CL:0002145
# LAP191_TTTGTTGTCGGCTGGT-1                         CL:0002329
#
#                                             author_cell_type_markers_level_1
# LAP40_AAACCCAAGATGCTAA             SFTPB; SFTPC; BMP1; ABCA3; LAMP3; CCDC141
# LAP40_AAACCCAAGATTGACA                          ITGA8; CCBE1; GALNT17;  NKD1
# LAP40_AAACCCAGTTTCTATC                                          PPARG; MARCO
# LAP40_AAACCCATCCAACTAG                        SCGB3A2; GDF15; SFTPB; SCGB1A1
# LAP40_AAACCCATCGCGGTAC                                          PPARG; MARCO
# ...                                                                      ...
# LAP191_TTTGGTTTCTGCCTCA-1                                  BTNL9; FCN3; IL7R
# LAP191_TTTGTTGGTTTGCAGT-1  SFTPB; SFTPC; BMP1; ABCA3; LAMP3; LRP2; SCN1A;...
# LAP191_TTTGTTGTCACGTAGT-1                                        HPGD; EDNRB
# LAP191_TTTGTTGTCGAACCAT-1                  FOXJ1; CDHR3; RSPH1; PRMT8; KCNN3
# LAP191_TTTGTTGTCGGCTGGT-1                                 TP63;  KRT15; KRT5
#
# [348012 rows x 14 columns]

# %%
adata.obs = new_obs

adata
# Out:
# AnnData object with n_obs × n_vars = 348012 × 29800
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'author_cell_type_level_0', 'author_cell_type_level_1', 'ident', 'author_cell_type_description_level_0', 'cell_type_ontology_term_label_level_0', 'cell_type_ontology_term_id_level_0', 'author_cell_type_markers_level_0', 'author_cell_type_description_level_1', 'cell_type_ontology_term_label_level_1', 'cell_type_ontology_term_id_level_1', 'author_cell_type_markers_level_1'

# %% [markdown]
# # Validate obs and uns from adata

# %%
adata.obs.columns
# Out:
# Index(['orig.ident', 'nCount_RNA', 'nFeature_RNA', 'author_cell_type_level_0',
#        'author_cell_type_level_1', 'ident',
#        'author_cell_type_description_level_0',
#        'cell_type_ontology_term_label_level_0',
#        'cell_type_ontology_term_id_level_0',
#        'author_cell_type_markers_level_0',
#        'author_cell_type_description_level_1',
#        'cell_type_ontology_term_label_level_1',
#        'cell_type_ontology_term_id_level_1',
#        'author_cell_type_markers_level_1'],
#       dtype='object')

# %%
adata.obs['orig.ident'].value_counts().index.tolist()
# Out:
# ['LAP186',
#  'LAP178',
#  'LAP102',
#  'LAP109',
#  'LAP107',
#  'LAP187',
#  'LAP108',
#  'LAP182',
#  'LAP180',
#  'LAP104',
#  'LAP106',
#  'LAP103',
#  'LAP184',
#  'LAP192',
#  'LAP41',
#  'LAP181',
#  'LAP101',
#  'LAP183',
#  'LAP100',
#  'LAP177',
#  'LAP95',
#  'LAP179',
#  'LAP94',
#  'LAP176',
#  'LAP96',
#  'LAP97',
#  'LAP194',
#  'LAP90',
#  'LAP174',
#  'LAP93',
#  'LAP193',
#  'LAP91',
#  'LAP99',
#  'LAP92',
#  'LAP40',
#  'LAP190',
#  'LAP195',
#  'LAP188',
#  'LAP191',
#  'LAP89',
#  'LAP185',
#  'LAP98',
#  'LAP88',
#  'LAP87',
#  'LAP105',
#  'LAP189']

# %%
# check non overlap between adata.obs['ident'] and obs['sample_ID']
adata_ids = adata.obs['orig.ident'].value_counts().index.tolist()
obs_ids = obs['library_preparation_batch'].tolist()

set(adata_ids).symmetric_difference(set(obs_ids))
# Out:
# set()

# %%
non_overlap = set(adata_ids) - set(obs_ids)
non_overlap_other_side = set(obs_ids) - set(adata_ids)

# %%
non_overlap
# Out:
# set()

# %%
non_overlap_other_side
# Out:
# set()

# %%
merger = AnnDataMerger(
    adata = adata,
    uns_df = uns
)

adata = merger.add_uns_metadata()

adata
# Out:
# AnnData object with n_obs × n_vars = 348012 × 29800
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'author_cell_type_level_0', 'author_cell_type_level_1', 'ident', 'author_cell_type_description_level_0', 'cell_type_ontology_term_label_level_0', 'cell_type_ontology_term_id_level_0', 'author_cell_type_markers_level_0', 'author_cell_type_description_level_1', 'cell_type_ontology_term_label_level_1', 'cell_type_ontology_term_id_level_1', 'author_cell_type_markers_level_1'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments'

# %%
merger = AnnDataMerger(
    adata = adata,
    obs_df = obs
)

adata = merger.add_obs_metadata(
    adata_col = 'orig.ident',
    df_col = 'library_preparation_batch',
    skip = None
)

adata.obs.rename(columns={'orig.ident': 'library_preparation_batch'}, inplace=True)

adata.obs
# Out:
#                           library_preparation_batch  nCount_RNA  nFeature_RNA  \
# LAP40_AAACCCAAGATGCTAA                        LAP40      3962.0          1859
# LAP40_AAACCCAAGATTGACA                        LAP40      5413.0          2587
# LAP40_AAACCCAGTTTCTATC                        LAP40      2113.0          1140
# LAP40_AAACCCATCCAACTAG                        LAP40       645.0           480
# LAP40_AAACCCATCGCGGTAC                        LAP40      7475.0          2958
# ...                                             ...         ...           ...
# LAP191_TTTGGTTTCTGCCTCA-1                    LAP191       865.0           691
# LAP191_TTTGTTGGTTTGCAGT-1                    LAP191      2191.0          1408
# LAP191_TTTGTTGTCACGTAGT-1                    LAP191       559.0           479
# LAP191_TTTGTTGTCGAACCAT-1                    LAP191      1047.0           832
# LAP191_TTTGTTGTCGGCTGGT-1                    LAP191      1533.0          1183
#
#                           author_cell_type_level_0 author_cell_type_level_1  \
# LAP40_AAACCCAAGATGCTAA                         AT2                    AT2-1
# LAP40_AAACCCAAGATTGACA                         AF1                    AF1-1
# LAP40_AAACCCAGTTTCTATC                          AM                       AM
# LAP40_AAACCCATCCAACTAG                         RAS                  PreTBSC
# LAP40_AAACCCATCGCGGTAC                          AM                       AM
# ...                                            ...                      ...
# LAP191_TTTGGTTTCTGCCTCA-1                     CAP1                     CAP1
# LAP191_TTTGTTGGTTTGCAGT-1                      AT2                    AT2-2
# LAP191_TTTGTTGTCACGTAGT-1                     CAP2                     CAP2
# LAP191_TTTGTTGTCGAACCAT-1                 Ciliated               Ciliated-2
# LAP191_TTTGTTGTCGGCTGGT-1                    Basal                    Basal
#
#                             ident author_cell_type_description_level_0  \
# LAP40_AAACCCAAGATGCTAA      LAP40      Alveolar epithelial type 2 cell
# LAP40_AAACCCAAGATTGACA      LAP40                Alveolar Fibroblast 1
# LAP40_AAACCCAGTTTCTATC      LAP40             Alveolar macrophage cell
# LAP40_AAACCCATCCAACTAG      LAP40    Respiratory airway secretory cell
# LAP40_AAACCCATCGCGGTAC      LAP40             Alveolar macrophage cell
# ...                           ...                                  ...
# LAP191_TTTGGTTTCTGCCTCA-1  LAP191   Capillary general endothelial cell
# LAP191_TTTGTTGGTTTGCAGT-1  LAP191      Alveolar epithelial type 2 cell
# LAP191_TTTGTTGTCACGTAGT-1  LAP191  Capillary aerocyte endothelial cell
# LAP191_TTTGTTGTCGAACCAT-1  LAP191                        Ciliated cell
# LAP191_TTTGTTGTCGGCTGGT-1  LAP191                           Basal cell
#
#                                        cell_type_ontology_term_label_level_0  \
# LAP40_AAACCCAAGATGCTAA                                    type II pneumocyte
# LAP40_AAACCCAAGATTGACA                            alveolar type 1 fibroblast
# LAP40_AAACCCAGTTTCTATC                                   alveolar macrophage
# LAP40_AAACCCATCCAACTAG     Lung secretory cell; Respiratory airway secret...
# LAP40_AAACCCATCGCGGTAC                                   alveolar macrophage
# ...                                                                      ...
# LAP191_TTTGGTTTCTGCCTCA-1         alveolar capillary type 1 endothelial cell
# LAP191_TTTGTTGGTTTGCAGT-1                                 type II pneumocyte
# LAP191_TTTGTTGTCACGTAGT-1         alveolar capillary type 2 endothelial cell
# LAP191_TTTGTTGTCGAACCAT-1    ciliated columnar cell of tracheobronchial tree
# LAP191_TTTGTTGTCGGCTGGT-1     basal epithelial cell of tracheobronchial tree
#
#                           cell_type_ontology_term_id_level_0  \
# LAP40_AAACCCAAGATGCTAA                            CL:0002063
# LAP40_AAACCCAAGATTGACA                            CL:4028004
# LAP40_AAACCCAGTTTCTATC                            CL:0000583
# LAP40_AAACCCATCCAACTAG                            CL:1000272
# LAP40_AAACCCATCGCGGTAC                            CL:0000583
# ...                                                      ...
# LAP191_TTTGGTTTCTGCCTCA-1                         CL:4028002
# LAP191_TTTGTTGGTTTGCAGT-1                         CL:0002063
# LAP191_TTTGTTGTCACGTAGT-1                         CL:4028003
# LAP191_TTTGTTGTCGAACCAT-1                        CL:0002145
# LAP191_TTTGTTGTCGGCTGGT-1                         CL:0002329
#
#                            author_cell_type_markers_level_0  ...  \
# LAP40_AAACCCAAGATGCTAA     SFTPB; SFTPC; BMP1; ABCA3; LAMP3  ...
# LAP40_AAACCCAAGATTGACA         ITGA8; CCBE1; GALNT17;  NKD1  ...
# LAP40_AAACCCAGTTTCTATC                         PPARG; MARCO  ...
# LAP40_AAACCCATCCAACTAG                SCGB3A2; GDF15; SFTPB  ...
# LAP40_AAACCCATCGCGGTAC                         PPARG; MARCO  ...
# ...                                                     ...  ...
# LAP191_TTTGGTTTCTGCCTCA-1                 BTNL9; FCN3; IL7R  ...
# LAP191_TTTGTTGGTTTGCAGT-1  SFTPB; SFTPC; BMP1; ABCA3; LAMP3  ...
# LAP191_TTTGTTGTCACGTAGT-1                       HPGD; EDNRB  ...
# LAP191_TTTGTTGTCGAACCAT-1               FOXJ1; CDHR3; RSPH1  ...
# LAP191_TTTGTTGTCGGCTGGT-1                TP63;  KRT15; KRT5  ...
#
#                           sequenced_fragment sequencing_platform  \
# LAP40_AAACCCAAGATGCTAA           3 prime tag         EFO_0008637
# LAP40_AAACCCAAGATTGACA           3 prime tag         EFO_0008637
# LAP40_AAACCCAGTTTCTATC           3 prime tag         EFO_0008637
# LAP40_AAACCCATCCAACTAG           3 prime tag         EFO_0008637
# LAP40_AAACCCATCGCGGTAC           3 prime tag         EFO_0008637
# ...                                      ...                 ...
# LAP191_TTTGGTTTCTGCCTCA-1        3 prime tag         EFO_0008637
# LAP191_TTTGTTGGTTTGCAGT-1        3 prime tag         EFO_0008637
# LAP191_TTTGTTGTCACGTAGT-1        3 prime tag         EFO_0008637
# LAP191_TTTGTTGTCGAACCAT-1        3 prime tag         EFO_0008637
# LAP191_TTTGTTGTCGGCTGGT-1        3 prime tag         EFO_0008637
#
#                           is_primary_data reference_genome  \
# LAP40_AAACCCAAGATGCTAA               true           GRCh38
# LAP40_AAACCCAAGATTGACA               true           GRCh38
# LAP40_AAACCCAGTTTCTATC               true           GRCh38
# LAP40_AAACCCATCCAACTAG               true           GRCh38
# LAP40_AAACCCATCGCGGTAC               true           GRCh38
# ...                                   ...              ...
# LAP191_TTTGGTTTCTGCCTCA-1            true           GRCh38
# LAP191_TTTGTTGGTTTGCAGT-1            true           GRCh38
# LAP191_TTTGTTGTCACGTAGT-1            true           GRCh38
# LAP191_TTTGTTGTCGAACCAT-1            true           GRCh38
# LAP191_TTTGTTGTCGGCTGGT-1            true           GRCh38
#
#                           gene_annotation_version alignment_software  \
# LAP40_AAACCCAAGATGCTAA                       v110    cell ranger 3.0
# LAP40_AAACCCAAGATTGACA                       v110    cell ranger 3.0
# LAP40_AAACCCAGTTTCTATC                       v110    cell ranger 3.0
# LAP40_AAACCCATCCAACTAG                       v110    cell ranger 3.0
# LAP40_AAACCCATCGCGGTAC                       v110    cell ranger 3.0
# ...                                           ...                ...
# LAP191_TTTGGTTTCTGCCTCA-1                    v110    cell ranger 3.0
# LAP191_TTTGTTGGTTTGCAGT-1                    v110    cell ranger 3.0
# LAP191_TTTGTTGTCACGTAGT-1                    v110    cell ranger 3.0
# LAP191_TTTGTTGTCGAACCAT-1                    v110    cell ranger 3.0
# LAP191_TTTGTTGTCGGCTGGT-1                    v110    cell ranger 3.0
#
#                           intron_inclusion disease_ontology_term_id  \
# LAP40_AAACCCAAGATGCTAA                 yes             PATO:0000461
# LAP40_AAACCCAAGATTGACA                 yes             PATO:0000461
# LAP40_AAACCCAGTTTCTATC                 yes             PATO:0000461
# LAP40_AAACCCATCCAACTAG                 yes             PATO:0000461
# LAP40_AAACCCATCGCGGTAC                 yes             PATO:0000461
# ...                                    ...                      ...
# LAP191_TTTGGTTTCTGCCTCA-1              yes             PATO:0000461
# LAP191_TTTGTTGGTTTGCAGT-1              yes             PATO:0000461
# LAP191_TTTGTTGTCACGTAGT-1              yes             PATO:0000461
# LAP191_TTTGTTGTCGAACCAT-1              yes             PATO:0000461
# LAP191_TTTGTTGTCGGCTGGT-1              yes             PATO:0000461
#
#                           self_reported_ethnicity_ontology_term_id  \
# LAP40_AAACCCAAGATGCTAA                                     unknown
# LAP40_AAACCCAAGATTGACA                                     unknown
# LAP40_AAACCCAGTTTCTATC                                     unknown
# LAP40_AAACCCATCCAACTAG                                     unknown
# LAP40_AAACCCATCGCGGTAC                                     unknown
# ...                                                            ...
# LAP191_TTTGGTTTCTGCCTCA-1                                  unknown
# LAP191_TTTGTTGGTTTGCAGT-1                                  unknown
# LAP191_TTTGTTGTCACGTAGT-1                                  unknown
# LAP191_TTTGTTGTCGAACCAT-1                                  unknown
# LAP191_TTTGTTGTCGGCTGGT-1                                  unknown
#
#                           development_stage_ontology_term_id
# LAP40_AAACCCAAGATGCTAA                        HsapDv:0000238
# LAP40_AAACCCAAGATTGACA                        HsapDv:0000238
# LAP40_AAACCCAGTTTCTATC                        HsapDv:0000238
# LAP40_AAACCCATCCAACTAG                        HsapDv:0000238
# LAP40_AAACCCATCGCGGTAC                        HsapDv:0000238
# ...                                                      ...
# LAP191_TTTGGTTTCTGCCTCA-1                     HsapDv:0000237
# LAP191_TTTGTTGGTTTGCAGT-1                     HsapDv:0000237
# LAP191_TTTGTTGTCACGTAGT-1                     HsapDv:0000237
# LAP191_TTTGTTGTCGAACCAT-1                     HsapDv:0000237
# LAP191_TTTGTTGTCGGCTGGT-1                     HsapDv:0000237
#
# [348012 rows x 50 columns]

# %% [markdown]
# # Add author cell type markers to UNS

# %%
adata.uns[MARKER_GENES_L0] = l4_annot
adata.uns[MARKER_GENES_L1] = l5_annot

adata
# Out:
# AnnData object with n_obs × n_vars = 348012 × 29800
#     obs: 'library_preparation_batch', 'nCount_RNA', 'nFeature_RNA', 'author_cell_type_level_0', 'author_cell_type_level_1', 'ident', 'author_cell_type_description_level_0', 'cell_type_ontology_term_label_level_0', 'cell_type_ontology_term_id_level_0', 'author_cell_type_markers_level_0', 'author_cell_type_description_level_1', 'cell_type_ontology_term_label_level_1', 'cell_type_ontology_term_id_level_1', 'author_cell_type_markers_level_1', 'sample_ID', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments', 'author_cell_type_markers_level_0', 'author_cell_type_markers_level_1'

# %% [markdown]
# # Check author cell type annotations and Cell Ontology IDs

# %%
adata.obs[AUTHOR_CELL_TYPE] = adata.obs[AUTHOR_CELL_TYPE_L1]
adata.obs[CELL_TYPE_ONTOLOGY_ID] = adata.obs[CELL_TYPE_ONTOLOGY_ID_L1]
adata.obs[CELL_TYPE_ONTOLOGY_LABEL] = adata.obs[CELL_TYPE_ONTOLOGY_LABEL_L1]
adata.obs[AUTHOR_CELL_TYPE_DESCRIPTION] = adata.obs[AUTHOR_CELL_TYPE_DESCRIPTION_L1]
adata.obs[MARKER_GENES] = adata.obs[MARKER_GENES_L1]

adata
# Out:
# AnnData object with n_obs × n_vars = 348012 × 29800
#     obs: 'library_preparation_batch', 'nCount_RNA', 'nFeature_RNA', 'author_cell_type_level_0', 'author_cell_type_level_1', 'ident', 'author_cell_type_description_level_0', 'cell_type_ontology_term_label_level_0', 'cell_type_ontology_term_id_level_0', 'author_cell_type_markers_level_0', 'author_cell_type_description_level_1', 'cell_type_ontology_term_label_level_1', 'cell_type_ontology_term_id_level_1', 'author_cell_type_markers_level_1', 'sample_ID', 'donor_id', 'protocol_URL', 'institute', 'sample_collection_site', 'sample_collection_relative_time_point', 'library_ID', 'library_ID_repository', 'author_batch_notes', 'organism_ontology_term_id', 'manner_of_death', 'sample_source', 'sex_ontology_term_id', 'sample_collection_method', 'tissue_type', 'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text', 'sample_preservation_method', 'suspension_type', 'cell_enrichment', 'cell_viability_percentage', 'cell_number_loaded', 'sample_collection_year', 'assay_ontology_term_id', 'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform', 'is_primary_data', 'reference_genome', 'gene_annotation_version', 'alignment_software', 'intron_inclusion', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'author_cell_type', 'cell_type_ontology_term_id', 'cell_type_ontology_term_label', 'author_cell_type_description', 'author_cell_type_markers'
#     uns: 'title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments', 'author_cell_type_markers_level_0', 'author_cell_type_markers_level_1'

# %% [markdown]
# # Check whether ENSEMBL IDs in var

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [A1BG, A1BG-AS1, A1CF, A2M, A2M-AS1, A2ML1, A2ML1-AS1, A3GALT2, A4GALT, A4GNT, AAAS, AACS, AADAC, AADACL2, AADACL2-AS1, AADACL3, AADACL4, AADAT, AAED1, AAGAB, AAK1, AAMDC, AAMP, AANAT, AAR2, AARD, AARS, AARS2, AASDH, AASDHPPT, AASS, AATBC, AATF, AATK, AB015752.1, ABALON, ABAT, ABCA1, ABCA10, ABCA12, ABCA13, ABCA2, ABCA3, ABCA4, ABCA5, ABCA6, ABCA7, ABCA8, ABCA9, ABCA9-AS1, ABCB1, ABCB10, ABCB11, ABCB4, ABCB5, ABCB6, ABCB7, ABCB8, ABCB9, ABCC1, ABCC10, ABCC11, ABCC12, ABCC2, ABCC3, ABCC4, ABCC5, ABCC5-AS1, ABCC6, ABCC8, ABCC9, ABCD1, ABCD2, ABCD3, ABCD4, ABCE1, ABCF1, ABCF2, ABCF2.1, ABCF3, ABCG1, ABCG2, ABCG4, ABCG5, ABCG8, ABHD1, ABHD10, ABHD11, ABHD12, ABHD12B, ABHD13, ABHD14A, ABHD14A-ACY1, ABHD14B, ABHD15, ABHD15-AS1, ABHD16A, ABHD16B, ABHD17A, ABHD17B, ...]
#
# [29800 rows x 0 columns]

# %%
ensembl_ids = pd.read_csv(ENESEMBL_PATH, sep='\t', header=None)
ensembl_ids
# Out:
#                      0            1                2
# 0      ENSG00000243485  MIR1302-2HG  Gene Expression
# 1      ENSG00000237613      FAM138A  Gene Expression
# 2      ENSG00000186092        OR4F5  Gene Expression
# 3      ENSG00000238009   AL627309.1  Gene Expression
# 4      ENSG00000239945   AL627309.3  Gene Expression
# ...                ...          ...              ...
# 33533  ENSG00000277856   AC233755.2  Gene Expression
# 33534  ENSG00000275063   AC233755.1  Gene Expression
# 33535  ENSG00000271254   AC240274.1  Gene Expression
# 33536  ENSG00000277475   AC213203.1  Gene Expression
# 33537  ENSG00000268674      FAM231C  Gene Expression
#
# [33538 rows x 3 columns]

# %%
len(np.intersect1d(adata.var.index.tolist(), ensembl_ids[1].tolist()))
# Out:
# 29785

# %%
ensembl_mapping = dict(zip(ensembl_ids[1], ensembl_ids[0]))
ensembl_mapping
# Out:
# {'MIR1302-2HG': 'ENSG00000243485',
#  'FAM138A': 'ENSG00000237613',
#  'OR4F5': 'ENSG00000186092',
#  'AL627309.1': 'ENSG00000238009',
#  'AL627309.3': 'ENSG00000239945',
#  'AL627309.2': 'ENSG00000239906',
#  'AL627309.4': 'ENSG00000241599',
#  'AL732372.1': 'ENSG00000236601',
#  'OR4F29': 'ENSG00000284733',
#  'AC114498.1': 'ENSG00000235146',
#  'OR4F16': 'ENSG00000284662',
#  'AL669831.2': 'ENSG00000229905',
#  'AL669831.5': 'ENSG00000237491',
#  'FAM87B': 'ENSG00000177757',
#  'LINC00115': 'ENSG00000225880',
#  'FAM41C': 'ENSG00000230368',
#  'AL645608.7': 'ENSG00000272438',
#  'AL645608.3': 'ENSG00000230699',
#  'AL645608.5': 'ENSG00000241180',
#  'AL645608.1': 'ENSG00000223764',
#  'SAMD11': 'ENSG00000187634',
#  'NOC2L': 'ENSG00000188976',
#  'KLHL17': 'ENSG00000187961',
#  'PLEKHN1': 'ENSG00000187583',
#  'PERM1': 'ENSG00000187642',
#  'AL645608.8': 'ENSG00000272512',
#  'HES4': 'ENSG00000188290',
#  'ISG15': 'ENSG00000187608',
#  'AL645608.2': 'ENSG00000224969',
#  'AGRN': 'ENSG00000188157',
#  'AL645608.9': 'ENSG00000273443',
#  'RNF223': 'ENSG00000237330',
#  'C1orf159': 'ENSG00000131591',
#  'LINC01342': 'ENSG00000223823',
#  'AL390719.2': 'ENSG00000272141',
#  'TTLL10-AS1': 'ENSG00000205231',
#  'TTLL10': 'ENSG00000162571',
#  'TNFRSF18': 'ENSG00000186891',
#  'TNFRSF4': 'ENSG00000186827',
#  'SDF4': 'ENSG00000078808',
#  'B3GALT6': 'ENSG00000176022',
#  'C1QTNF12': 'ENSG00000184163',
#  'AL162741.1': 'ENSG00000260179',
#  'UBE2J2': 'ENSG00000160087',
#  'LINC01786': 'ENSG00000230415',
#  'SCNN1D': 'ENSG00000162572',
#  'ACAP3': 'ENSG00000131584',
#  'PUSL1': 'ENSG00000169972',
#  'INTS11': 'ENSG00000127054',
#  'CPTP': 'ENSG00000224051',
#  'TAS1R3': 'ENSG00000169962',
#  'DVL1': 'ENSG00000107404',
#  'MXRA8': 'ENSG00000162576',
#  'AURKAIP1': 'ENSG00000175756',
#  'CCNL2': 'ENSG00000221978',
#  'MRPL20': 'ENSG00000242485',
#  'AL391244.3': 'ENSG00000272455',
#  'ANKRD65': 'ENSG00000235098',
#  'AL391244.2': 'ENSG00000225905',
#  'TMEM88B': 'ENSG00000205116',
#  'LINC01770': 'ENSG00000225285',
#  'VWA1': 'ENSG00000179403',
#  'ATAD3C': 'ENSG00000215915',
#  'ATAD3B': 'ENSG00000160072',
#  'AL109659.2': 'ENSG00000272491',
#  'SPATA6': 'ENSG00000132122',
#  'AGBL4': 'ENSG00000186094',
#  'BEND5': 'ENSG00000162373',
#  'AC099788.1': 'ENSG00000229846',
#  'AL590432.1': 'ENSG00000230114',
#  'ELAVL4': 'ENSG00000162374',
#  'AL592182.2': 'ENSG00000237337',
#  'AL592182.1': 'ENSG00000233407',
#  'AL596275.2': 'ENSG00000284696',
#  ...}

# %%
adata.var.index.name = 'index'
adata.var['gene_symbol'] = adata.var.index.astype('category')
adata.var.index = adata.var.index.astype(str)
adata.var['ensembl_id'] = adata.var['gene_symbol'].map(ensembl_mapping)

adata.var
# Out:
#          gene_symbol       ensembl_id
# index
# A1BG            A1BG  ENSG00000121410
# A1BG-AS1    A1BG-AS1  ENSG00000268895
# A1CF            A1CF  ENSG00000148584
# A2M              A2M  ENSG00000175899
# A2M-AS1      A2M-AS1  ENSG00000245105
# ...              ...              ...
# ZXDC            ZXDC  ENSG00000070476
# ZYG11A        ZYG11A  ENSG00000203995
# ZYG11B        ZYG11B  ENSG00000162378
# ZYX              ZYX  ENSG00000159840
# ZZEF1          ZZEF1  ENSG00000074755
#
# [29800 rows x 2 columns]

# %% [markdown]
# # Check raw data

# %%
adata.X
# Out:
# <348012x29800 sparse matrix of type '<class 'numpy.float32'>'
# 	with 580867730 stored elements in Compressed Sparse Row format>

# %%
adata.obs.columns
# Out:
# Index(['library_preparation_batch', 'nCount_RNA', 'nFeature_RNA',
#        'author_cell_type_level_0', 'author_cell_type_level_1', 'ident',
#        'author_cell_type_description_level_0',
#        'cell_type_ontology_term_label_level_0',
#        'cell_type_ontology_term_id_level_0',
#        'author_cell_type_markers_level_0',
#        'author_cell_type_description_level_1',
#        'cell_type_ontology_term_label_level_1',
#        'cell_type_ontology_term_id_level_1',
#        'author_cell_type_markers_level_1', 'sample_ID', 'donor_id',
#        'protocol_URL', 'institute', 'sample_collection_site',
#        'sample_collection_relative_time_point', 'library_ID',
#        'library_ID_repository', 'author_batch_notes',
#        'organism_ontology_term_id', 'manner_of_death', 'sample_source',
#        'sex_ontology_term_id', 'sample_collection_method', 'tissue_type',
#        'sampled_site_condition', 'tissue_ontology_term_id', 'tissue_free_text',
#        'sample_preservation_method', 'suspension_type', 'cell_enrichment',
#        'cell_viability_percentage', 'cell_number_loaded',
#        'sample_collection_year', 'assay_ontology_term_id',
#        'library_sequencing_run', 'sequenced_fragment', 'sequencing_platform',
#        'is_primary_data', 'reference_genome', 'gene_annotation_version',
#        'alignment_software', 'intron_inclusion', 'disease_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id',
#        'development_stage_ontology_term_id', 'author_cell_type',
#        'cell_type_ontology_term_id', 'cell_type_ontology_term_label',
#        'author_cell_type_description', 'author_cell_type_markers'],
#       dtype='object')

# %%
# make checks for adata before saving raw
adata.obs = adata.obs.astype('category')

# Make specific columns numeric
adata.obs['cell_viability_percentage'] = pd.to_numeric(adata.obs['cell_viability_percentage'], errors='coerce')
adata.obs['cell_number_loaded'] = pd.to_numeric(adata.obs['cell_number_loaded'], errors='coerce')
adata.obs['sample_collection_year'] = pd.to_numeric(adata.obs['sample_collection_year'], errors='coerce')

numeric_cols = ['nCount_RNA', 'nFeature_RNA']
for col in numeric_cols:
    adata.obs[col] = pd.to_numeric(adata.obs[col], errors='coerce')

# Make df indices str
adata.obs.index = adata.obs.index.astype('str')
adata.var.index = adata.var.index.astype('str')
adata.var_names = adata.var_names.astype('str')

adata.var = adata.var.astype(str)

# %%
adata.uns.keys()
# Out:
# odict_keys(['title', 'study_PI', 'batch_condition', 'default_embedding', 'unpublished', 'comments', 'author_cell_type_markers_level_0', 'author_cell_type_markers_level_1'])

# %%
adata.uns['author_cell_type_markers_level_0'] = adata.uns['author_cell_type_markers_level_0'].astype(str)
adata.uns['author_cell_type_markers_level_1'] = adata.uns['author_cell_type_markers_level_1'].astype(str)

# %%
adata.X = adata.X.astype(np.int64)

# %%
adata.raw = adata

# %%
adata.X
# Out:
# <348012x29800 sparse matrix of type '<class 'numpy.int64'>'
# 	with 580867730 stored elements in Compressed Sparse Row format>

# %%
adata.raw.X
# Out:
# <348012x29800 sparse matrix of type '<class 'numpy.int64'>'
# 	with 580867730 stored elements in Compressed Sparse Row format>

# %%
adata.X.toarray().max()
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
adata.raw.X.toarray().max()
# Out:
# 5322

# %%
adata.var_names
# Out:
# Index(['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2ML1-AS1',
#        'A3GALT2', 'A4GALT', 'A4GNT',
#        ...
#        'ZW10', 'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B',
#        'ZYX', 'ZZEF1'],
#       dtype='object', name='index', length=29800)

# %%
adata.var
# Out:
#          gene_symbol       ensembl_id
# index
# A1BG            A1BG  ENSG00000121410
# A1BG-AS1    A1BG-AS1  ENSG00000268895
# A1CF            A1CF  ENSG00000148584
# A2M              A2M  ENSG00000175899
# A2M-AS1      A2M-AS1  ENSG00000245105
# ...              ...              ...
# ZXDC            ZXDC  ENSG00000070476
# ZYG11A        ZYG11A  ENSG00000203995
# ZYG11B        ZYG11B  ENSG00000162378
# ZYX              ZYX  ENSG00000159840
# ZZEF1          ZZEF1  ENSG00000074755
#
# [29800 rows x 2 columns]

# %% [markdown]
# ## Validation result
#
# ### UNS Validation
# - OK: Tier 1 UNS Google Sheet
# - OK: Tier 1 UNS AnnData Object
#
# ### OBS Validation
# - OK: Tier 1 OBS Google Sheet
# - OK: Tier 1 OBS AnnData Object

# %% [markdown]
# # Data Submission Status
#
# - CHECK: Data in X
# - CHECJ: Tier 1 Metadata in OBS
# - CHECK: Cell Ontology IDs in OBS
# - CHECK: Author cell type in OBS
# - CHECK: Marker genes in UNS
# - CHECK: ENSEMBL IDs and gene symbols in var
#
#
# Revision Status:
# DONE

# %%
adata.write_h5ad(join(OUTPUT_PATH_PREREVISION, f"{DATASET_ID}.h5ad"))
adata.write_h5ad(join(OUTPUT_PATH_POSTREVISION, f"{DATASET_ID}.h5ad"))
